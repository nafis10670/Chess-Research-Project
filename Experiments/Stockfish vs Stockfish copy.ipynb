# %% [markdown]
# # High ELO Stockfish vs. Low ELO Stockfish

# %%
import chess
from stockfish import Stockfish
import pandas as pd
import asyncio

# %%
# STOCKFISH_PATH = r"C:\Users\nafis\Downloads\stockfish-windows-x86-64-avx2\stockfish\stockfish-windows-x86-64-avx2.exe"

HIGH_ELO = 3190
LOW_ELO = 1320

NUM_GAMES = 10

# %%
high_elo_engine = Stockfish()
high_elo_engine.update_engine_parameters({"Skill Level": 10, "Threads": 3, "Hash": 4096, "Minimum Thinking Time": 50})

low_elo_engine = Stockfish()
low_elo_engine.update_engine_parameters({"Skill Level": 10, "Threads": 3, "Hash": 4096, "Minimum Thinking Time": 50})

# %%
low_elo_engine.get_stockfish_major_version()
# Out:
# 17

# %%
low_elo_engine.get_parameters()
# Out:
# {'Debug Log File': '',
#  'Contempt': 0,
#  'Min Split Depth': 0,
#  'Ponder': 'false',
#  'MultiPV': 1,
#  'Skill Level': 10,
#  'Move Overhead': 10,
#  'Minimum Thinking Time': 50,
#  'Slow Mover': 100,
#  'UCI_Chess960': 'false',
#  'UCI_LimitStrength': 'false',
#  'UCI_Elo': 1350,
#  'Threads': 3,
#  'Hash': 4096}

# %%
high_elo_engine.get_parameters()
# Out:
# {'Debug Log File': '',
#  'Contempt': 0,
#  'Min Split Depth': 0,
#  'Ponder': 'false',
#  'MultiPV': 1,
#  'Skill Level': 10,
#  'Move Overhead': 10,
#  'Minimum Thinking Time': 50,
#  'Slow Mover': 100,
#  'UCI_Chess960': 'false',
#  'UCI_LimitStrength': 'false',
#  'UCI_Elo': 1350,
#  'Threads': 3,
#  'Hash': 4096}

# %%
high_elo_wins = 0
low_elo_wins = 0
draws = 0

# %%
for game_number in range(1, NUM_GAMES + 1):
    move_counter = 0
    print(f"Starting game {game_number}...")
    board = chess.Board()

    while not board.is_game_over():
        # Determine which engine to use based on turn
        current_engine = high_elo_engine if board.turn == chess.BLACK else low_elo_engine

        # Set the position on the board for the engine
        current_engine.set_fen_position(board.fen())

        # Get the best move from the engine
        best_move = current_engine.get_best_move()
        if best_move is None:
            print("Engine failed to provide a move.")
            break

        # Apply the move to the board
        move = chess.Move.from_uci(best_move)
        print(f"Move by {"White" if board.turn else "Black"}: {best_move}   Move: {move_counter}")
        board.push(move)
        move_counter += 1

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        high_elo_wins += 1
    elif result == "0-1":
        low_elo_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n")
# Out:
# Starting game 1...
# Move by White: d2d4   Move: 0
# Move by Black: g8f6   Move: 1
# Move by White: e2e3   Move: 2
# Move by Black: g7g6   Move: 3
# Move by White: c2c4   Move: 4
# Move by Black: d7d6   Move: 5
# Move by White: h2h3   Move: 6
# Move by Black: a7a5   Move: 7
# Move by White: g1f3   Move: 8
# Move by Black: f8g7   Move: 9
# Move by White: a2a3   Move: 10
# Move by Black: e8g8   Move: 11
# Move by White: c1d2   Move: 12
# Move by Black: f8e8   Move: 13
# Move by White: d2c3   Move: 14
# Move by Black: b8d7   Move: 15
# Move by White: b1d2   Move: 16
# Move by Black: b7b6   Move: 17
# Move by White: f1e2   Move: 18
# Move by Black: a5a4   Move: 19
# Move by White: e2d3   Move: 20
# Move by Black: c7c5   Move: 21
# Move by White: d3c2   Move: 22
# Move by Black: c5d4   Move: 23
# Move by White: e3d4   Move: 24
# Move by Black: b6b5   Move: 25
# Move by White: a1c1   Move: 26
# Move by Black: c8a6   Move: 27
# Move by White: e1g1   Move: 28
# Move by Black: g7h6   Move: 29
# Move by White: c1b1   Move: 30
# Move by Black: d7b6   Move: 31
# Move by White: c3a5   Move: 32
# Move by Black: a6b7   Move: 33
# Move by White: a5b6   Move: 34
# Move by Black: d8b6   Move: 35
# Move by White: b2b4   Move: 36
# Move by Black: e7e5   Move: 37
# Move by White: c4c5   Move: 38
# Move by Black: b6a6   Move: 39
# Move by White: h3h4   Move: 40
# Move by Black: e5d4   Move: 41
# Move by White: c2d3   Move: 42
# Move by Black: a6c6   Move: 43
# Move by White: d1c2   Move: 44
# Move by Black: a8c8   Move: 45
# Move by White: f1c1   Move: 46
# Move by Black: c6d7   Move: 47
# Move by White: c1e1   Move: 48
# Move by Black: e8e1   Move: 49
# Move by White: f3e1   Move: 50
# Move by Black: d6c5   Move: 51
# Move by White: b4c5   Move: 52
# Move by Black: h6d2   Move: 53
# Move by White: d3b5   Move: 54
# Move by Black: d7f5   Move: 55
# Move by White: b5d3   Move: 56
# Move by Black: f6e4   Move: 57
# Move by White: e1f3   Move: 58
# Move by Black: b7a8   Move: 59
# Move by White: b1b5   Move: 60
# Move by Black: d2f4   Move: 61
# Move by White: f3d4   Move: 62
# Move by Black: f5e5   Move: 63
# Move by White: d4f3   Move: 64
# Move by Black: e5d5   Move: 65
# Move by White: d3c4   Move: 66
# Move by Black: d5d7   Move: 67
# Move by White: b5b4   Move: 68
# Move by Black: c8c5   Move: 69
# Move by White: g2g3   Move: 70
# Move by Black: f4d6   Move: 71
# Move by White: c2a4   Move: 72
# Move by Black: d7a4   Move: 73
# Move by White: b4a4   Move: 74
# Move by Black: a8c6   Move: 75
# Move by White: a4b4   Move: 76
# Move by Black: g8g7   Move: 77
# Move by White: c4f1   Move: 78
# Move by Black: c5c3   Move: 79
# Move by White: b4b6   Move: 80
# Move by Black: d6c5   Move: 81
# Move by White: b6c6   Move: 82
# Move by Black: c5f2   Move: 83
# Move by White: g1h1   Move: 84
# Move by Black: e4g3   Move: 85
# Move by White: h1g2   Move: 86
# Move by Black: c3c6   Move: 87
# Move by White: g2f2   Move: 88
# Move by Black: g3f1   Move: 89
# Move by White: f2f1   Move: 90
# Move by Black: c6b6   Move: 91
# Move by White: f1e2   Move: 92
# Move by Black: f7f6   Move: 93
# Move by White: e2e3   Move: 94
# Move by Black: g7h6   Move: 95
# Move by White: f3d4   Move: 96
# Move by Black: h6h5   Move: 97
# Move by White: e3f2   Move: 98
# Move by Black: h5h6   Move: 99
# Move by White: h4h5   Move: 100
# Move by Black: h6g7   Move: 101
# Move by White: h5g6   Move: 102
# Move by Black: h7h5   Move: 103
# Move by White: f2g3   Move: 104
# Move by Black: g7g6   Move: 105
# Move by White: d4f3   Move: 106
# Move by Black: b6a6   Move: 107
# Move by White: g3h3   Move: 108
# Move by Black: a6a7   Move: 109
# Move by White: h3h4   Move: 110
# Move by Black: a7a3   Move: 111
# Move by White: f3g1   Move: 112
# Move by Black: g6f5   Move: 113
# Move by White: g1e2   Move: 114
# Move by Black: a3a2   Move: 115
# Move by White: e2d4   Move: 116
# Move by Black: f5e4   Move: 117
# Move by White: d4b5   Move: 118
# Move by Black: a2d2   Move: 119
# Move by White: b5c7   Move: 120
# Move by Black: f6f5   Move: 121
# Move by White: c7e6   Move: 122
# Move by Black: e4e3   Move: 123
# Move by White: h4h5   Move: 124
# Move by Black: d2g2   Move: 125
# Move by White: e6c7   Move: 126
# Move by Black: f5f4   Move: 127
# Move by White: c7e8   Move: 128
# Move by Black: g2g1   Move: 129
# Move by White: e8f6   Move: 130
# Move by Black: f4f3   Move: 131
# Move by White: f6g4   Move: 132
# Move by Black: e3f4   Move: 133
# Move by White: g4h6   Move: 134
# Move by Black: g1g5   Move: 135
# Move by White: h5h4   Move: 136
# Move by Black: g5g7   Move: 137
# Move by White: h4h5   Move: 138
# Move by Black: g7g5   Move: 139
# Move by White: h5h4   Move: 140
# Move by Black: g5g1   Move: 141
# Move by White: h4h5   Move: 142
# Move by Black: g1g5   Move: 143
# Move by White: h5h4   Move: 144
# Move by Black: g5g1   Move: 145
# Move by White: h4h5   Move: 146
# Move by Black: g1g5   Move: 147
# Move by White: h5h4   Move: 148
# Move by Black: f3f2   Move: 149
# Move by White: h6f7   Move: 150
# Move by Black: g5c5   Move: 151
# Move by White: f7h8   Move: 152
# Move by Black: c5c6   Move: 153
# Move by White: h4h5   Move: 154
# Move by Black: f4e3   Move: 155
# Move by White: h8g6   Move: 156
# Move by Black: f2f1q   Move: 157
# Move by White: g6h4   Move: 158
# Move by Black: e3e4   Move: 159
# Move by White: h4f3   Move: 160
# Move by Black: f1e2   Move: 161
# Move by White: h5g4   Move: 162
# Move by Black: c6c5   Move: 163
# Move by White: g4h3   Move: 164
# Move by Black: e2f1   Move: 165
# Move by White: h3g4   Move: 166
# Move by Black: f1e2   Move: 167
# Move by White: g4h3   Move: 168
# Move by Black: e2f1   Move: 169
# Move by White: h3g3   Move: 170
# Move by Black: c5c3   Move: 171
# Move by White: g3h2   Move: 172
# Move by Black: c3c2   Move: 173
# Move by White: h2g3   Move: 174
# Move by Black: f1f2   Move: 175
# Move by White: g3h3   Move: 176
# Move by Black: f2e3   Move: 177
# Move by White: h3h4   Move: 178
# Move by Black: e3f4   Move: 179
# Move by White: h4h3   Move: 180
# Move by Black: f4f5   Move: 181
# Move by White: h3h4   Move: 182
# Move by Black: f5f4   Move: 183
# Move by White: h4h3   Move: 184
# Move by Black: c2c3   Move: 185
# Move by White: h3g2   Move: 186
# Move by Black: f4g4   Move: 187
# Move by White: g2h2   Move: 188
# Move by Black: g4f3   Move: 189
# Move by White: h2g1   Move: 190
# Move by Black: c3c1   Move: 191
# Move by White: g1h2   Move: 192
# Move by Black: c1h1   Move: 193
# Game 1 result: 0-1
#
# Starting game 2...
# Move by White: e2e4   Move: 0
# Move by Black: c7c5   Move: 1
# Move by White: g1f3   Move: 2
# Move by Black: a7a6   Move: 3
# Move by White: c2c3   Move: 4
# Move by Black: d7d5   Move: 5
# Move by White: f1d3   Move: 6
# Move by Black: d5e4   Move: 7
# Move by White: d1a4   Move: 8
# Move by Black: b8c6   Move: 9
# Move by White: a4e4   Move: 10
# Move by Black: g7g5   Move: 11
# Move by White: d3c2   Move: 12
# Move by Black: g5g4   Move: 13
# Move by White: f3e5   Move: 14
# Move by Black: c8d7   Move: 15
# Move by White: e5d7   Move: 16
# Move by Black: d8d7   Move: 17
# Move by White: e4e2   Move: 18
# Move by Black: g8f6   Move: 19
# Move by White: d2d3   Move: 20
# Move by Black: h8g8   Move: 21
# Move by White: c1e3   Move: 22
# Move by Black: e7e6   Move: 23
# Move by White: a2a3   Move: 24
# Move by Black: a8c8   Move: 25
# Move by White: c2a4   Move: 26
# Move by Black: b7b5   Move: 27
# Move by White: a4b3   Move: 28
# Move by Black: c8d8   Move: 29
# Move by White: e1g1   Move: 30
# Move by Black: c6e5   Move: 31
# Move by White: b1d2   Move: 32
# Move by Black: d7d3   Move: 33
# Move by White: e2d3   Move: 34
# Move by Black: e5d3   Move: 35
# Move by White: a3a4   Move: 36
# Move by Black: f6d5   Move: 37
# Move by White: a4b5   Move: 38
# Move by Black: d5e3   Move: 39
# Move by White: d2e4   Move: 40
# Move by Black: g8g6   Move: 41
# Move by White: f2e3   Move: 42
# Move by Black: a6b5   Move: 43
# Move by White: b3c2   Move: 44
# Move by Black: f7f5   Move: 45
# Move by White: e4f2   Move: 46
# Move by Black: d3b2   Move: 47
# Move by White: e3e4   Move: 48
# Move by Black: f5f4   Move: 49
# Move by White: e4e5   Move: 50
# Move by Black: g6g7   Move: 51
# Move by White: f2e4   Move: 52
# Move by Black: e8f7   Move: 53
# Move by White: f1f4   Move: 54
# Move by Black: f7g8   Move: 55
# Move by White: a1a6   Move: 56
# Move by Black: b2d1   Move: 57
# Move by White: c2d1   Move: 58
# Move by Black: d8d1   Move: 59
# Move by White: g1f2   Move: 60
# Move by Black: d1d8   Move: 61
# Move by White: f2e3   Move: 62
# Move by Black: g4g3   Move: 63
# Move by White: h2h3   Move: 64
# Move by Black: g8h8   Move: 65
# Move by White: f4f6   Move: 66
# Move by Black: d8b8   Move: 67
# Move by White: a6e6   Move: 68
# Move by Black: b5b4   Move: 69
# Move by White: e6b6   Move: 70
# Move by Black: b8a8   Move: 71
# Move by White: e3f4   Move: 72
# Move by Black: b4c3   Move: 73
# Move by White: b6b3   Move: 74
# Move by Black: c3c2   Move: 75
# Move by White: b3c3   Move: 76
# Move by Black: c5c4   Move: 77
# Move by White: c3c4   Move: 78
# Move by Black: g7b7   Move: 79
# Move by White: c4c2   Move: 80
# Move by Black: f8g7   Move: 81
# Move by White: f6c6   Move: 82
# Move by Black: b7f7   Move: 83
# Move by White: e4f6   Move: 84
# Move by Black: g7f6   Move: 85
# Move by White: c6f6   Move: 86
# Move by Black: f7g7   Move: 87
# Move by White: c2c3   Move: 88
# Move by Black: a8g8   Move: 89
# Move by White: c3e3   Move: 90
# Move by Black: g7a7   Move: 91
# Move by White: e5e6   Move: 92
# Move by Black: a7a2   Move: 93
# Move by White: f4e5   Move: 94
# Move by Black: g8e8   Move: 95
# Move by White: e3g3   Move: 96
# Move by Black: a2a5   Move: 97
# Move by White: e5f4   Move: 98
# Move by Black: a5a7   Move: 99
# Move by White: g3f3   Move: 100
# Move by Black: h8g7   Move: 101
# Move by White: f4g3   Move: 102
# Move by Black: e8b8   Move: 103
# Move by White: f6f4   Move: 104
# Move by Black: a7e7   Move: 105
# Move by White: f4g4   Move: 106
# Move by Black: g7h8   Move: 107
# Move by White: f3e3   Move: 108
# Move by Black: b8f8   Move: 109
# Move by White: g4d4   Move: 110
# Move by Black: e7g7   Move: 111
# Move by White: g3h2   Move: 112
# Move by Black: f8g8   Move: 113
# Move by White: d4d2   Move: 114
# Move by Black: g8e8   Move: 115
# Move by White: d2e2   Move: 116
# Move by Black: g7g8   Move: 117
# Move by White: e3d3   Move: 118
# Move by Black: g8g7   Move: 119
# Move by White: h3h4   Move: 120
# Move by Black: g7a7   Move: 121
# Move by White: h2h3   Move: 122
# Move by Black: a7g7   Move: 123
# Move by White: d3d6   Move: 124
# Move by Black: h8g8   Move: 125
# Move by White: h4h5   Move: 126
# Move by Black: g7a7   Move: 127
# Move by White: h5h6   Move: 128
# Move by Black: a7a1   Move: 129
# Move by White: h3g4   Move: 130
# Move by Black: a1c1   Move: 131
# Move by White: g4g5   Move: 132
# Move by Black: c1h1   Move: 133
# Move by White: d6d3   Move: 134
# Move by Black: h1a1   Move: 135
# Move by White: d3d5   Move: 136
# Move by Black: a1a6   Move: 137
# Move by White: g5f6   Move: 138
# Move by Black: e8c8   Move: 139
# Move by White: d5g5   Move: 140
# Move by Black: g8h8   Move: 141
# Move by White: g5d5   Move: 142
# Move by Black: c8f8   Move: 143
# Move by White: f6g5   Move: 144
# Move by Black: h8g8   Move: 145
# Move by White: g2g4   Move: 146
# Move by Black: a6b6   Move: 147
# Move by White: e2e5   Move: 148
# Move by Black: b6c6   Move: 149
# Move by White: d5b5   Move: 150
# Move by Black: f8e8   Move: 151
# Move by White: g5h5   Move: 152
# Move by Black: c6c2   Move: 153
# Move by White: b5b7   Move: 154
# Move by Black: e8f8   Move: 155
# Move by White: b7g7   Move: 156
# Move by Black: g8h8   Move: 157
# Move by White: g7a7   Move: 158
# Move by Black: f8g8   Move: 159
# Move by White: h5h4   Move: 160
# Move by Black: g8e8   Move: 161
# Move by White: a7f7   Move: 162
# Move by Black: c2c6   Move: 163
# Move by White: h4h5   Move: 164
# Move by Black: c6c8   Move: 165
# Move by White: e6e7   Move: 166
# Move by Black: e8g8   Move: 167
# Move by White: g4g5   Move: 168
# Move by Black: c8b8   Move: 169
# Move by White: e5d5   Move: 170
# Move by Black: b8b7   Move: 171
# Move by White: d5d8   Move: 172
# Move by Black: b7e7   Move: 173
# Move by White: d8g8   Move: 174
# Move by Black: h8g8   Move: 175
# Move by White: f7e7   Move: 176
# Move by Black: g8f8   Move: 177
# Move by White: e7h7   Move: 178
# Move by Black: f8e8   Move: 179
# Move by White: h7a7   Move: 180
# Move by Black: e8d8   Move: 181
# Move by White: h6h7   Move: 182
# Move by Black: d8c8   Move: 183
# Move by White: a7g7   Move: 184
# Move by Black: c8b8   Move: 185
# Move by White: g5g6   Move: 186
# Move by Black: b8a8   Move: 187
# Move by White: g7d7   Move: 188
# Move by Black: a8b8   Move: 189
# Move by White: d7e7   Move: 190
# Move by Black: b8a8   Move: 191
# Move by White: h7h8q   Move: 192
# Game 2 result: 1-0
#
# Starting game 3...
# Move by White: e2e3   Move: 0
# Move by Black: e7e5   Move: 1
# Move by White: d2d4   Move: 2
# Move by Black: e5e4   Move: 3
# Move by White: c2c4   Move: 4
# Move by Black: g8f6   Move: 5
# Move by White: g1e2   Move: 6
# Move by Black: c7c6   Move: 7
# Move by White: b1c3   Move: 8
# Move by Black: d7d5   Move: 9
# Move by White: c1d2   Move: 10
# Move by Black: g7g6   Move: 11
# Move by White: d1a4   Move: 12
# Move by Black: c8d7   Move: 13
# Move by White: a4b3   Move: 14
# Move by Black: b7b5   Move: 15
# Move by White: c4b5   Move: 16
# Move by Black: f8h6   Move: 17
# Move by White: e2g3   Move: 18
# Move by Black: e8g8   Move: 19
# Move by White: f1e2   Move: 20
# Move by Black: d7e6   Move: 21
# Move by White: c3a4   Move: 22
# Move by Black: f8e8   Move: 23
# Move by White: e1g1   Move: 24
# Move by Black: h6f8   Move: 25
# Move by White: b5c6   Move: 26
# Move by Black: b8c6   Move: 27
# Move by White: f1c1   Move: 28
# Move by Black: a8c8   Move: 29
# Move by White: a4c5   Move: 30
# Move by Black: h7h5   Move: 31
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 14
#      11 current_engine.set_fen_position(board.fen())
#      13 # Get the best move from the engine
# ---> 14 best_move = current_engine.get_best_move()
#      15 if best_move is None:
#      16     print("Engine failed to provide a move.")
#
# File /opt/anaconda3/envs/env/lib/python3.12/site-packages/stockfish/models.py:338, in Stockfish.get_best_move(self, wtime, btime)
#     336 else:
#     337     self._go()
# --> 338 return self._get_best_move_from_sf_popen_process()
#
# File /opt/anaconda3/envs/env/lib/python3.12/site-packages/stockfish/models.py:358, in Stockfish._get_best_move_from_sf_popen_process(self)
#     356 last_text: str = ""
#     357 while True:
# --> 358     text = self._read_line()
#     359     splitted_text = text.split(" ")
#     360     if splitted_text[0] == "bestmove":
#
# File /opt/anaconda3/envs/env/lib/python3.12/site-packages/stockfish/models.py:161, in Stockfish._read_line(self)
#     159 if self._stockfish.poll() is not None:
#     160     raise StockfishException("The Stockfish process has crashed")
# --> 161 return self._stockfish.stdout.readline().strip()
#
# KeyboardInterrupt:

# %%
print(f"Final Results after {NUM_GAMES} games:")
print(f"High ELO Wins: {high_elo_wins}")
print(f"Low ELO Wins: {low_elo_wins}")
print(f"Draws: {draws}")
# Out:
# Final Results after 10 games:
# High ELO Wins: 5
# Low ELO Wins: 1
# Draws: 4
