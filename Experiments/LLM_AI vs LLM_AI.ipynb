# %% [markdown]
# # LLM + AI vs. LLM + AI (Qwen:32B)

# %%
import chess
from stockfish import Stockfish
from ollama import chat
from ollama import ChatResponse
import json
import random
import pandas as pd
import re

# %%
# STOCKFISH_PATH = r"C:\Users\nafis\Downloads\stockfish-windows-x86-64-avx2\stockfish\stockfish-windows-x86-64-avx2.exe"

STOCKFISH_ELO = 3500
MOVE_LIMIT = 100
NUM_GAMES = 60

# %%
stockfish = Stockfish()

stockfish.update_engine_parameters({"Threads": 8, "Hash": 2048})

# %%
qwen_white_wins = 0
qwen_black_wins = 0
draws = 0

# %%
def valid_move_to_string(board):
    legal_moves = [
        board.san(move) for move in board.legal_moves]
    
    if not legal_moves:
        return "No legal moves."
    else:
        return ", ".join(legal_moves)

# %%
def get_move_history(board: chess.Board) -> str:
    """Return a formatted move history string like '1. e4 e5 2. Nf3 d5'."""
    temp_board = chess.Board()  # Start from the initial position.
    move_history = []
    
    # Iterate over the moves in the board's move stack.
    for i, move in enumerate(board.move_stack):
        # Get the SAN for the move in the current temporary board.
        move_san = temp_board.san(move)
        # Push the move so that the board state is updated.
        temp_board.push(move)
        
        # For white moves (even index), start a new entry with move number.
        if i % 2 == 0:
            move_history.append(f"{i//2 + 1}. {move_san}")
        # For black moves, append to the last white move entry.
        else:
            move_history[-1] += f" {move_san}"
    
    # Join all entries with a space.
    return " ".join(move_history)

# %%
def get_qwen_move(board:chess.Board, fen:str, temp=0.0):
    valid_moves = valid_move_to_string(board)

    move_history = get_move_history(board)
    
    stockfish.set_fen_position(board.fen())
    best_move = stockfish.get_best_move()
    best_move = board.san(chess.Move.from_uci(best_move))
    
    response: ChatResponse = chat(model='qwen:32b', messages=[
        {
            'role': 'system',
            'content': 'You are a grand master chess player. You have an AI assitant that plays chess. The AI will suggest you the best move for the current board state. You are instructed to be heavilty reliant on the AI suggestion.'
        },
        {
            'role': 'user',
            'content': f"""You are playing chess and it is your turn. This is the current state of the game. Use this to work out where the pieces are on the board:

FEN: {fen}

The possible set of legal moves are: 

Legal Moves: {valid_moves}

+(You have to choose one from the provided list. Do not choose a move that is not in the list.)

The best move suggested by your AI Assistant is {best_move}. You are heavily reliant on your AI Assistant.

The move history is: {move_history}.

Output the best move in SAN format to follow this position. Use the following single blob of JSON. Do not include any other information.
{{
    "san": "The move in SAN format",
}}"""}], options={"temperature": temp})
    
    try:
        output = response.message.content
        # Use regex to extract the JSON object (brackets and everything inside)
        match = re.search(r'\{[\s\S]*?\}', output)
        if match:
            json_str = match.group(0)
            # Remove any trailing commas before the closing brace (e.g., after the colon with extra spaces)
            json_str = re.sub(r',\s*}', '}', json_str)
            parsed_json = json.loads(json_str)
            qwen_move = parsed_json["san"]
        else:
            raise ValueError("JSON object not found in response")
    except Exception as e:
        print(f"Wrong format given by Qwen. \nQwen Output: {response.message.content}")
        qwen_move = None

    print(f"Stockfish Suggested Move: {best_move}")

    return qwen_move

# %%
def get_random_move(board:chess.Board, fen:str, seed: int = 101):
    legal_moves = [
        board.san(move)
        for move in board.legal_moves
    ]

    random.seed(seed)

    # print(random.choice(legal_moves))
    return random.choice(legal_moves)

    # print(legal_moves[0])

# %%
for game_number in range(1, NUM_GAMES + 1):
    
    move_counter = 0

    print(f"Starting game {game_number}...")

    board = chess.Board()

    while not board.is_game_over() and move_counter <= MOVE_LIMIT:
        if board.turn == chess.WHITE and not board.is_game_over():
            qwen_move_white = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_move_white)
            except Exception as e:
                print(f"Invalid move by Qwen white. Move: {qwen_move_white}")
                qwen_move_white = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_move_white)
                print(f"New Move: {qwen_move_white}")
                # continue
            
        move_counter += 1        
        print(f"Qwen white move: {qwen_move_white} Move number: {move_counter}")

        if board.turn == chess.BLACK and not board.is_game_over():
            qwen_move_black = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_move_black)
            except Exception as e:
                print(f"Invalid move by Qwen black. Move: {qwen_move_black}")
                qwen_move_black = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_move_black)
                print(f"New Move: {qwen_move_black}")
                # continue
        move_counter += 1
        print(f"Qwen black move: {qwen_move_black} Move number: {move_counter}")   

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        qwen_white_wins += 1
    elif result == "0-1":
        qwen_black_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n\n")
# Out:
# Starting game 1...
# Stockfish Suggested Move: e4
# Qwen white move: e4 Move number: 1
# Stockfish Suggested Move: e5
# Qwen black move: e5 Move number: 2
# Stockfish Suggested Move: Nf3
# Qwen white move: Nf3 Move number: 3
# Stockfish Suggested Move: Nc6
# Qwen black move: Nc6 Move number: 4
# Stockfish Suggested Move: Bb5
# Qwen white move: Bb5 Move number: 5
# Stockfish Suggested Move: a6
# Qwen black move: a6 Move number: 6
# Stockfish Suggested Move: Ba4
# Qwen white move: Ba4 Move number: 7
# Stockfish Suggested Move: Nf6
# Qwen black move: Nf6 Move number: 8
# Stockfish Suggested Move: O-O
# Qwen white move: O-O Move number: 9
# Stockfish Suggested Move: Nxe4
# Qwen black move: Nxe4 Move number: 10
# Stockfish Suggested Move: d4
# Qwen white move: d4 Move number: 11
# Stockfish Suggested Move: b5
# Qwen black move: b5 Move number: 12
# Stockfish Suggested Move: Bb3
# Qwen white move: Bb3 Move number: 13
# Stockfish Suggested Move: d5
# Qwen black move: d5 Move number: 14
# Stockfish Suggested Move: dxe5
# Qwen white move: dxe5 Move number: 15
# Stockfish Suggested Move: Be6
# Qwen black move: Be6 Move number: 16
# Stockfish Suggested Move: c3
# Qwen white move: c3 Move number: 17
# Stockfish Suggested Move: Bc5
# Qwen black move: Bc5 Move number: 18
# Stockfish Suggested Move: Nbd2
# Qwen white move: Nbd2 Move number: 19
# Stockfish Suggested Move: O-O
# Qwen black move: O-O Move number: 20
# Stockfish Suggested Move: Bc2
# Qwen white move: Bc2 Move number: 21
# Stockfish Suggested Move: Bxf2+
# Qwen black move: Bxf2+ Move number: 22
# Stockfish Suggested Move: Rxf2
# Qwen white move: Rxf2 Move number: 23
# Stockfish Suggested Move: Nxf2
# Qwen black move: Nxf2 Move number: 24
# Stockfish Suggested Move: Kxf2
# Qwen white move: Kxf2 Move number: 25
# Stockfish Suggested Move: f6
# Qwen black move: f6 Move number: 26
# Stockfish Suggested Move: Nf1
# Qwen white move: Nf1 Move number: 27
# Stockfish Suggested Move: fxe5
# Qwen black move: fxe5 Move number: 28
# Stockfish Suggested Move: Kg1
# Qwen white move: Kg1 Move number: 29
# Stockfish Suggested Move: Bg4
# Qwen black move: Bg4 Move number: 30
# Stockfish Suggested Move: Ne3
# Qwen white move: Ne3 Move number: 31
# Stockfish Suggested Move: Be6
# Qwen black move: Be6 Move number: 32
# Stockfish Suggested Move: b4
# Qwen white move: b4 Move number: 33
# Stockfish Suggested Move: a5
# Qwen black move: a5 Move number: 34
# Stockfish Suggested Move: bxa5
# Qwen white move: bxa5 Move number: 35
# Stockfish Suggested Move: Rxa5
# Qwen black move: Rxa5 Move number: 36
# Stockfish Suggested Move: Bb3
# Qwen white move: Bb3 Move number: 37
# Stockfish Suggested Move: h6
# Qwen black move: h6 Move number: 38
# Stockfish Suggested Move: Bd2
# Qwen white move: Bd2 Move number: 39
# Stockfish Suggested Move: Qd6
# Qwen black move: Qd6 Move number: 40
# Stockfish Suggested Move: Be1
# Qwen white move: Be1 Move number: 41
# Stockfish Suggested Move: Ra3
# Qwen black move: Ra3 Move number: 42
# Stockfish Suggested Move: Nc2
# Qwen white move: Nc2 Move number: 43
# Stockfish Suggested Move: Ra6
# Invalid move by Qwen black. Move:  Ra6
# New Move: e4
# Qwen black move: e4 Move number: 44
# Stockfish Suggested Move: Nfd4
# Qwen white move: Nfd4 Move number: 45
# Stockfish Suggested Move: Nxd4
# Qwen black move: Nxd4 Move number: 46
# Stockfish Suggested Move: cxd4
# Qwen white move: cxd4 Move number: 47
# Stockfish Suggested Move: Raa8
# Qwen black move: Raa8 Move number: 48
# Stockfish Suggested Move: Bb4
# Qwen white move: Bb4 Move number: 49
# Stockfish Suggested Move: Qa6
# Qwen black move: Qa6 Move number: 50
# Stockfish Suggested Move: Bxf8
# Qwen white move: Bxf8 Move number: 51
# Stockfish Suggested Move: Rxf8
# Qwen black move: Rxf8 Move number: 52
# Stockfish Suggested Move: Qe1
# Qwen white move: Qe1 Move number: 53
# Stockfish Suggested Move: c6
# Qwen black move: c6 Move number: 54
# Stockfish Suggested Move: Nb4
# Qwen white move: Nb4 Move number: 55
# Stockfish Suggested Move: Qb6
# Qwen black move: Qb6 Move number: 56
# Stockfish Suggested Move: Qe3
# Qwen white move: Qe3 Move number: 57
# Stockfish Suggested Move: Bd7
# Qwen black move: Bd7 Move number: 58
# Stockfish Suggested Move: a3
# Qwen white move: a3 Move number: 59
# Stockfish Suggested Move: Kh8
# Qwen black move: Kh8 Move number: 60
# Stockfish Suggested Move: Rc1
# Qwen white move: Rc1 Move number: 61
# Stockfish Suggested Move: Rc8
# Qwen black move: Rc8 Move number: 62
# Stockfish Suggested Move: Bd1
# Qwen white move: Bd1 Move number: 63
# Stockfish Suggested Move: Kh7
# Qwen black move: Kh7 Move number: 64
# Stockfish Suggested Move: Be2
# Qwen white move: Be2 Move number: 65
# Stockfish Suggested Move: Kg8
# Qwen black move: Kg8 Move number: 66
# Stockfish Suggested Move: Rf1
# Qwen white move: Rf1 Move number: 67
# Stockfish Suggested Move: Ra8
# Qwen black move: Ra8 Move number: 68
# Stockfish Suggested Move: h4
# Qwen white move: h4 Move number: 69
# Stockfish Suggested Move: Qa7
# Qwen black move: Qa7 Move number: 70
# Stockfish Suggested Move: Nc2
# Qwen white move: Nc2 Move number: 71
# Stockfish Suggested Move: Qb8
# Qwen black move: Qb8 Move number: 72
# Stockfish Suggested Move: Bh5
# Qwen white move: Bh5 Move number: 73
# Stockfish Suggested Move: Qd6
# Qwen black move: Qd6 Move number: 74
# Stockfish Suggested Move: Bf7+
# Qwen white move: Bf7+ Move number: 75
# Stockfish Suggested Move: Kh8
# Qwen black move: Kh8 Move number: 76
# Stockfish Suggested Move: h5
# Qwen white move: h5 Move number: 77
# Stockfish Suggested Move: Rf8
# Qwen black move: Rf8 Move number: 78
# Stockfish Suggested Move: Bg6
# Qwen white move: Bg6 Move number: 79
# Stockfish Suggested Move: Rxf1+
# Qwen black move: Rxf1+ Move number: 80
# Stockfish Suggested Move: Kxf1
# Qwen white move: Kxf1 Move number: 81
# Stockfish Suggested Move: Be8
# Qwen black move: Be8 Move number: 82
# Stockfish Suggested Move: Bxe8
# Qwen white move: Bxe8 Move number: 83
# Stockfish Suggested Move: Qf8+
# Qwen black move: Qf8+ Move number: 84
# Stockfish Suggested Move: Ke2
# Qwen white move: Ke2 Move number: 85
# Stockfish Suggested Move: Qxe8
# Qwen black move: Qxe8 Move number: 86
# Stockfish Suggested Move: Qh3
# Qwen white move: Qh3 Move number: 87
# Stockfish Suggested Move: g6
# Qwen black move: g6 Move number: 88
# Stockfish Suggested Move: hxg6
# Qwen white move: hxg6 Move number: 89
# Stockfish Suggested Move: Qxg6
# Qwen black move: Qxg6 Move number: 90
# Stockfish Suggested Move: Ne3
# Qwen white move: Ne3 Move number: 91
# Stockfish Suggested Move: Qf6
# Qwen black move: Qf6 Move number: 92
# Stockfish Suggested Move: Nf5
# Qwen white move: Nf5 Move number: 93
# Stockfish Suggested Move: Kg8
# Qwen black move: Kg8 Move number: 94
# Stockfish Suggested Move: Nxh6+
# Qwen white move: Nxh6+ Move number: 95
# Stockfish Suggested Move: Kg7
# Qwen black move: Kg7 Move number: 96
# Stockfish Suggested Move: Nf5+
# Qwen white move: Nf5+ Move number: 97
# Stockfish Suggested Move: Kf7
# Qwen black move: Kf7 Move number: 98
# Stockfish Suggested Move: Qh5+
# Qwen white move: Qh5+ Move number: 99
# Stockfish Suggested Move: Kg8
# Qwen black move: Kg8 Move number: 100
# Stockfish Suggested Move: Qe8+
# Qwen white move: Qe8+ Move number: 101
# Stockfish Suggested Move: Kh7
# Qwen black move: Kh7 Move number: 102
# Game 1 result: *
#
#
# Starting game 2...
# Stockfish Suggested Move: e4
# Qwen white move: e4 Move number: 1
# Stockfish Suggested Move: e5
# Qwen black move: e5 Move number: 2
# Stockfish Suggested Move: Nf3
# Qwen white move: Nf3 Move number: 3
# Stockfish Suggested Move: Nc6
# Qwen black move: Nc6 Move number: 4
# Stockfish Suggested Move: Bb5
# Qwen white move: Bb5 Move number: 5
# Stockfish Suggested Move: Nf6
# Qwen black move: Nf6 Move number: 6
# Stockfish Suggested Move: O-O
# Qwen white move: O-O Move number: 7
# Stockfish Suggested Move: Nxe4
# Qwen black move: Nxe4 Move number: 8
# Stockfish Suggested Move: Re1
# Qwen white move: Re1 Move number: 9
# Stockfish Suggested Move: Nd6
# Qwen black move: Nd6 Move number: 10
# Stockfish Suggested Move: Nxe5
# Qwen white move: Nxe5 Move number: 11
# Stockfish Suggested Move: Nxe5
# Qwen black move: Nxe5 Move number: 12
# Stockfish Suggested Move: Rxe5+
# Qwen white move: Rxe5+ Move number: 13
# Stockfish Suggested Move: Be7
# Qwen black move: Be7 Move number: 14
# Stockfish Suggested Move: Bf1
# Qwen white move: Bf1 Move number: 15
# Stockfish Suggested Move: O-O
# Qwen black move: O-O Move number: 16
# Stockfish Suggested Move: d4
# Qwen white move: d4 Move number: 17
# Stockfish Suggested Move: Bf6
# Qwen black move: Bf6 Move number: 18
# Stockfish Suggested Move: Re1
# Qwen white move: Re1 Move number: 19
# Stockfish Suggested Move: Nf5
# Qwen black move: Nf5 Move number: 20
# Stockfish Suggested Move: c3
# Qwen white move: c3 Move number: 21
# Stockfish Suggested Move: d5
# Qwen black move: d5 Move number: 22
# Stockfish Suggested Move: a4
# Qwen white move: a4 Move number: 23
# Stockfish Suggested Move: a5
# Qwen black move: a5 Move number: 24
# Stockfish Suggested Move: Nd2
# Qwen white move: Nd2 Move number: 25
# Stockfish Suggested Move: c6
# Qwen black move: c6 Move number: 26
# Stockfish Suggested Move: Nf3
# Qwen white move: Nf3 Move number: 27
# Stockfish Suggested Move: Nd6
# Qwen black move: Nd6 Move number: 28
# Stockfish Suggested Move: Bf4
# Qwen white move: Bf4 Move number: 29
# Stockfish Suggested Move: Bf5
# Qwen black move: Bf5 Move number: 30
# Stockfish Suggested Move: h3
# Qwen white move: h3 Move number: 31
# Stockfish Suggested Move: Be4
# Qwen black move: Be4 Move number: 32
# Stockfish Suggested Move: Bd3
# Qwen white move: Bd3 Move number: 33
# Stockfish Suggested Move: Bxd3
# Qwen black move: Bxd3 Move number: 34
# Stockfish Suggested Move: Qxd3
# Qwen white move: Qxd3 Move number: 35
# Stockfish Suggested Move: Re8
# Qwen black move: Re8 Move number: 36
# Stockfish Suggested Move: Rxe8+
# Qwen white move: Rxe8+ Move number: 37
# Stockfish Suggested Move: Nxe8
# Qwen black move: Nxe8 Move number: 38
# Stockfish Suggested Move: Re1
# Qwen white move: Re1 Move number: 39
# Stockfish Suggested Move: Nd6
# Qwen black move: Nd6 Move number: 40
# Stockfish Suggested Move: Qd1
# Qwen white move: Qd1 Move number: 41
# Stockfish Suggested Move: Ne4
# Qwen black move: Ne4 Move number: 42
# Stockfish Suggested Move: g3
# Qwen white move: g3 Move number: 43
# Stockfish Suggested Move: Qd7
# Qwen black move: Qd7 Move number: 44
# Stockfish Suggested Move: h4
# Qwen white move: h4 Move number: 45
# Stockfish Suggested Move: Re8
# Qwen black move: Re8 Move number: 46
# Stockfish Suggested Move: Kg2
# Qwen white move: Kg2 Move number: 47
# Stockfish Suggested Move: h6
# Qwen black move: h6 Move number: 48
# Stockfish Suggested Move: Nh2
# Qwen white move: Nh2 Move number: 49
# Stockfish Suggested Move: Be7
# Qwen black move: Be7 Move number: 50
# Stockfish Suggested Move: Qg4
# Qwen white move: Qg4 Move number: 51
# Stockfish Suggested Move: Qxg4
# Qwen black move: Qxg4 Move number: 52
# Stockfish Suggested Move: Nxg4
# Qwen white move: Nxg4 Move number: 53
# Stockfish Suggested Move: Bd6
# Qwen black move: Bd6 Move number: 54
# Stockfish Suggested Move: Bxd6
# Qwen white move: Bxd6 Move number: 55
# Stockfish Suggested Move: Nxd6
# Qwen black move: Nxd6 Move number: 56
# Stockfish Suggested Move: Rxe8+
# Qwen white move: Rxe8+ Move number: 57
# Stockfish Suggested Move: Nxe8
# Qwen black move: Nxe8 Move number: 58
# Stockfish Suggested Move: b4
# Qwen white move: b4 Move number: 59
# Stockfish Suggested Move: Nd6
# Qwen black move: Nd6 Move number: 60
# Stockfish Suggested Move: Ne5
# Qwen white move: Ne5 Move number: 61
# Stockfish Suggested Move: f6
# Qwen black move: f6 Move number: 62
# Stockfish Suggested Move: Nd3
# Qwen white move: Nd3 Move number: 63
# Stockfish Suggested Move: b6
# Qwen black move: b6 Move number: 64
# Stockfish Suggested Move: bxa5
# Qwen white move: bxa5 Move number: 65
# Stockfish Suggested Move: bxa5
# Qwen black move: bxa5 Move number: 66
# Stockfish Suggested Move: Nc5
# Qwen white move: Nc5 Move number: 67
# Stockfish Suggested Move: g6
# Qwen black move: g6 Move number: 68
# Stockfish Suggested Move: g4
# Qwen white move: g4 Move number: 69
# Stockfish Suggested Move: Kf7
# Qwen black move: Kf7 Move number: 70
# Stockfish Suggested Move: h5
# Qwen white move: h5 Move number: 71
# Stockfish Suggested Move: f5
# Qwen black move: f5 Move number: 72
# Stockfish Suggested Move: gxf5
# Qwen white move: gxf5 Move number: 73
# Stockfish Suggested Move: gxf5
# Qwen black move: gxf5 Move number: 74
# Stockfish Suggested Move: Kf3
# Qwen white move: Kf3 Move number: 75
# Stockfish Suggested Move: Ne4
# Qwen black move: Ne4 Move number: 76
# Stockfish Suggested Move: Kf4
# Qwen white move: Kf4 Move number: 77
# Stockfish Suggested Move: Kf6
# Qwen black move: Kf6 Move number: 78
# Stockfish Suggested Move: Nxe4+
# Qwen white move: Nxe4+ Move number: 79
# Stockfish Suggested Move: fxe4
# Qwen black move: fxe4 Move number: 80
# Stockfish Suggested Move: Kg4
# Qwen white move: Kg4 Move number: 81
# Stockfish Suggested Move: Ke6
# Qwen black move: Ke6 Move number: 82
# Stockfish Suggested Move: Kf4
# Qwen white move: Kf4 Move number: 83
# Stockfish Suggested Move: Kf6
# Qwen black move: Kf6 Move number: 84
# Stockfish Suggested Move: Kg4
# Qwen white move: Kg4 Move number: 85
# Stockfish Suggested Move: Ke6
# Qwen black move: Ke6 Move number: 86
# Stockfish Suggested Move: Kf4
# Qwen white move: Kf4 Move number: 87
# Stockfish Suggested Move: Kf6
# Qwen black move: Kf6 Move number: 88
# Stockfish Suggested Move: Kg4
# Qwen white move: Kg4 Move number: 89
# Stockfish Suggested Move: Ke6
# Qwen black move: Ke6 Move number: 90
# Stockfish Suggested Move: Kf4
# Qwen white move: Kf4 Move number: 91
# Stockfish Suggested Move: Kf6
# Qwen black move: Kf6 Move number: 92
# Stockfish Suggested Move: Kg4
# Qwen white move: Kg4 Move number: 93
# Stockfish Suggested Move: Ke6
# Qwen black move: Ke6 Move number: 94
# Stockfish Suggested Move: Kf4
# Qwen white move: Kf4 Move number: 95
# Stockfish Suggested Move: Kf6
# Qwen black move: Kf6 Move number: 96
# Game 2 result: 1/2-1/2
#
#
# Starting game 3...
# Stockfish Suggested Move: e4
# Qwen white move: e4 Move number: 1
# Stockfish Suggested Move: e5
# Qwen black move: e5 Move number: 2
# Stockfish Suggested Move: Nf3
# Qwen white move: Nf3 Move number: 3
# Stockfish Suggested Move: Nc6
# Qwen black move: Nc6 Move number: 4
# Stockfish Suggested Move: Bb5
# Qwen white move: Bb5 Move number: 5
# Stockfish Suggested Move: a6
# Qwen black move: a6 Move number: 6
# Stockfish Suggested Move: Ba4
# Qwen white move: Ba4 Move number: 7
# Stockfish Suggested Move: Nf6
# Qwen black move: Nf6 Move number: 8
# Stockfish Suggested Move: O-O
# Qwen white move: O-O Move number: 9
# Stockfish Suggested Move: Nxe4
# Qwen black move: Nxe4 Move number: 10
# Stockfish Suggested Move: d4
# Qwen white move: d4 Move number: 11
# Stockfish Suggested Move: b5
# Qwen black move: b5 Move number: 12
# Stockfish Suggested Move: Bb3
# Qwen white move: Bb3 Move number: 13
# Stockfish Suggested Move: d5
# Qwen black move: d5 Move number: 14
# Stockfish Suggested Move: dxe5
# Qwen white move: dxe5 Move number: 15
# Stockfish Suggested Move: Be6
# Qwen black move: Be6 Move number: 16
# Stockfish Suggested Move: c3
# Qwen white move: c3 Move number: 17
# Stockfish Suggested Move: Bc5
# Qwen black move: Bc5 Move number: 18
# Stockfish Suggested Move: Nbd2
# Qwen white move: Nbd2 Move number: 19
# Stockfish Suggested Move: O-O
# Qwen black move: O-O Move number: 20
# Stockfish Suggested Move: Bc2
# Qwen white move: Bc2 Move number: 21
# Stockfish Suggested Move: Bf5
# Qwen black move: Bf5 Move number: 22
# Stockfish Suggested Move: Nb3
# Qwen white move: Nb3 Move number: 23
# Stockfish Suggested Move: Bg6
# Qwen black move: Bg6 Move number: 24
# Stockfish Suggested Move: Nfd4
# Qwen white move: Nfd4 Move number: 25
# Stockfish Suggested Move: Bxd4
# Qwen black move: Bxd4 Move number: 26
# Stockfish Suggested Move: Nxd4
# Qwen white move: Nxd4 Move number: 27
# Stockfish Suggested Move: Qd7
# Qwen black move: Qd7 Move number: 28
# Stockfish Suggested Move: f4
# Qwen white move: f4 Move number: 29
# Stockfish Suggested Move: Nxd4
# Qwen black move: Nxd4 Move number: 30
# Stockfish Suggested Move: cxd4
# Qwen white move: cxd4 Move number: 31
# Stockfish Suggested Move: f6
# Qwen black move: f6 Move number: 32
# Stockfish Suggested Move: Be3
# Qwen white move: Be3 Move number: 33
# Stockfish Suggested Move: Rad8
# Qwen black move: Rad8 Move number: 34
# Stockfish Suggested Move: Qe1
# Qwen white move: Qe1 Move number: 35
# Stockfish Suggested Move: c6
# Qwen black move: c6 Move number: 36
# Stockfish Suggested Move: h3
# Qwen white move: h3 Move number: 37
# Stockfish Suggested Move: Qc8
# Qwen black move: Qc8 Move number: 38
# Stockfish Suggested Move: exf6
# Qwen white move: exf6 Move number: 39
# Stockfish Suggested Move: Rxf6
# Qwen black move: Rxf6 Move number: 40
# Stockfish Suggested Move: g4
# Qwen white move: g4 Move number: 41
# Stockfish Suggested Move: Re8
# Qwen black move: Re8 Move number: 42
# Stockfish Suggested Move: f5
# Qwen white move: f5 Move number: 43
# Stockfish Suggested Move: Bf7
# Qwen black move: Bf7 Move number: 44
# Stockfish Suggested Move: Rc1
# Qwen white move: Rc1 Move number: 45
# Stockfish Suggested Move: Qb7
# Qwen black move: Qb7 Move number: 46
# Stockfish Suggested Move: Bb1
# Qwen white move: Bb1 Move number: 47
# Stockfish Suggested Move: h6
# Qwen black move: h6 Move number: 48
# Stockfish Suggested Move: Bf4
# Qwen white move: Bf4 Move number: 49
# Stockfish Suggested Move: c5
# Qwen black move: c5 Move number: 50
# Stockfish Suggested Move: dxc5
# Qwen white move: dxc5 Move number: 51
# Stockfish Suggested Move: Rc6
# Qwen black move: Rc6 Move number: 52
# Stockfish Suggested Move: Bxe4
# Qwen white move: Bxe4 Move number: 53
# Stockfish Suggested Move: Rxe4
# Qwen black move: Rxe4 Move number: 54
# Stockfish Suggested Move: Qf2
# Qwen white move: Qf2 Move number: 55
# Stockfish Suggested Move: Rc8
# Qwen black move: Rc8 Move number: 56
# Stockfish Suggested Move: Be3
# Qwen white move: Be3 Move number: 57
# Stockfish Suggested Move: d4
# Qwen black move: d4 Move number: 58
# Stockfish Suggested Move: Bxd4
# Qwen white move: Bxd4 Move number: 59
# Stockfish Suggested Move: Qc7
# Qwen black move: Qc7 Move number: 60
# Stockfish Suggested Move: Rfd1
# Qwen white move: Rfd1 Move number: 61
# Stockfish Suggested Move: h5
# Qwen black move: h5 Move number: 62
# Stockfish Suggested Move: c6
# Qwen white move: c6 Move number: 63
# Stockfish Suggested Move: Bc4
# Qwen black move: Bc4 Move number: 64
# Stockfish Suggested Move: Bc3
# Qwen white move: Bc3 Move number: 65
# Stockfish Suggested Move: Qxc6
# Qwen black move: Qxc6 Move number: 66
# Stockfish Suggested Move: gxh5
# Qwen white move: gxh5 Move number: 67
# Stockfish Suggested Move: Qh6
# Qwen black move: Qh6 Move number: 68
# Stockfish Suggested Move: f6
# Qwen white move: f6 Move number: 69
# Stockfish Suggested Move: Qg5+
# Qwen black move: Qg5+ Move number: 70
# Stockfish Suggested Move: Qg2
# Qwen white move: Qg2 Move number: 71
# Stockfish Suggested Move: Qxg2+
# Qwen black move: Qxg2+ Move number: 72
# Stockfish Suggested Move: Kxg2
# Qwen white move: Kxg2 Move number: 73
# Stockfish Suggested Move: gxf6
# Qwen black move: gxf6 Move number: 74
# Stockfish Suggested Move: Rd7
# Qwen white move: Rd7 Move number: 75
# Stockfish Suggested Move: Be6
# Qwen black move: Be6 Move number: 76
# Stockfish Suggested Move: Rd6
# Qwen white move: Rd6 Move number: 77
# Stockfish Suggested Move: Kf7
# Qwen black move: Kf7 Move number: 78
# Stockfish Suggested Move: Rf1
# Qwen white move: Rf1 Move number: 79
# Stockfish Suggested Move: Re2+
# Qwen black move: Re2+ Move number: 80
# Stockfish Suggested Move: Kg3
# Qwen white move: Kg3 Move number: 81
# Stockfish Suggested Move: Re3+
# Qwen black move: Re3+ Move number: 82
# Stockfish Suggested Move: Kf2
# Qwen white move: Kf2 Move number: 83
# Stockfish Suggested Move: Rxh3
# Qwen black move: Rxh3 Move number: 84
# Stockfish Suggested Move: Ke1
# Qwen white move: Ke1 Move number: 85
# Stockfish Suggested Move: f5
# Qwen black move: f5 Move number: 86
# Stockfish Suggested Move: Rxa6
# Qwen white move: Rxa6 Move number: 87
# Stockfish Suggested Move: b4
# Qwen black move: b4 Move number: 88
# Stockfish Suggested Move: Ra7+
# Qwen white move: Ra7+ Move number: 89
# Stockfish Suggested Move: Ke8
# Qwen black move: Ke8 Move number: 90
# Stockfish Suggested Move: Bd2
# Qwen white move: Bd2 Move number: 91
# Stockfish Suggested Move: Rxh5
# Qwen black move: Rxh5 Move number: 92
# Stockfish Suggested Move: b3
# Qwen white move: b3 Move number: 93
# Stockfish Suggested Move: Rc2
# Qwen black move: Rc2 Move number: 94
# Stockfish Suggested Move: Kd1
# Qwen white move: Kd1 Move number: 95
# Stockfish Suggested Move: Rxa2
# Qwen black move: Rxa2 Move number: 96
# Stockfish Suggested Move: Rxa2
# Qwen white move: Rxa2 Move number: 97
# Stockfish Suggested Move: Bxb3+
# Qwen black move: Bxb3+ Move number: 98
# Stockfish Suggested Move: Rc2
# Qwen white move: Rc2 Move number: 99
# Stockfish Suggested Move: Rh2
# Qwen black move: Rh2 Move number: 100
# Stockfish Suggested Move: Kc1
# Qwen white move: Kc1 Move number: 101
# Stockfish Suggested Move: Bxc2
# Qwen black move: Bxc2 Move number: 102
# Game 3 result: *
#
#
# Starting game 4...
# Stockfish Suggested Move: e4
# Qwen white move: e4 Move number: 1
# Stockfish Suggested Move: e5
# Qwen black move: e5 Move number: 2
# Stockfish Suggested Move: Nf3
# Qwen white move: Nf3 Move number: 3
# Stockfish Suggested Move: Nc6
# Qwen black move: Nc6 Move number: 4
# Stockfish Suggested Move: Bb5
# Qwen white move: Bb5 Move number: 5
# Stockfish Suggested Move: a6
# Qwen black move: a6 Move number: 6
# Stockfish Suggested Move: Ba4
# Qwen white move: Ba4 Move number: 7
# Stockfish Suggested Move: Nf6
# Qwen black move: Nf6 Move number: 8
# Stockfish Suggested Move: O-O
# Qwen white move: O-O Move number: 9
# Stockfish Suggested Move: Be7
# Qwen black move: Be7 Move number: 10
# Stockfish Suggested Move: Re1
# Qwen white move: Re1 Move number: 11
# Stockfish Suggested Move: b5
# Qwen black move: b5 Move number: 12
# Stockfish Suggested Move: Bb3
# Qwen white move: Bb3 Move number: 13
# Stockfish Suggested Move: O-O
# Qwen black move: O-O Move number: 14
# Stockfish Suggested Move: c3
# Qwen white move: c3 Move number: 15
# Stockfish Suggested Move: Na5
# Qwen black move: Na5 Move number: 16
# Stockfish Suggested Move: Bc2
# Qwen white move: Bc2 Move number: 17
# Stockfish Suggested Move: d5
# Qwen black move: d5 Move number: 18
# Stockfish Suggested Move: d4
# Qwen white move: d4 Move number: 19
# Stockfish Suggested Move: dxe4
# Qwen black move: dxe4 Move number: 20
# Stockfish Suggested Move: Nxe5
# Qwen white move: Nxe5 Move number: 21
# Stockfish Suggested Move: c5
# Qwen black move: c5 Move number: 22
# Stockfish Suggested Move: Be3
# Qwen white move: Be3 Move number: 23
# Stockfish Suggested Move: Bb7
# Qwen black move: Bb7 Move number: 24
# Stockfish Suggested Move: Nd2
# Qwen white move: Nd2 Move number: 25
# Stockfish Suggested Move: Rc8
# Qwen black move: Rc8 Move number: 26
# Stockfish Suggested Move: h3
# Qwen white move: h3 Move number: 27
# Stockfish Suggested Move: Re8
# Qwen black move: Re8 Move number: 28
# Stockfish Suggested Move: Ng4
# Qwen white move: Ng4 Move number: 29
# Stockfish Suggested Move: Nd5
# Qwen black move: Nd5 Move number: 30
# Stockfish Suggested Move: Bxe4
# Qwen white move: Bxe4 Move number: 31
# Stockfish Suggested Move: Nxe3
# Qwen black move: Nxe3 Move number: 32
# Stockfish Suggested Move: Nxe3
# Qwen white move: Nxe3 Move number: 33
# Stockfish Suggested Move: cxd4
# Qwen black move: cxd4 Move number: 34
# Stockfish Suggested Move: Nf5
# Qwen white move: Nf5 Move number: 35
# Stockfish Suggested Move: dxc3
# Qwen black move: dxc3 Move number: 36
# Stockfish Suggested Move: Bxb7
# Qwen white move: Bxb7 Move number: 37
# Stockfish Suggested Move: Nxb7
# Qwen black move: Nxb7 Move number: 38
# Stockfish Suggested Move: Rxe7
# Qwen white move: Rxe7 Move number: 39
# Stockfish Suggested Move: cxd2
# Qwen black move: cxd2 Move number: 40
# Stockfish Suggested Move: Rxe8+
# Qwen white move: Rxe8+ Move number: 41
# Stockfish Suggested Move: Qxe8
# Qwen black move: Qxe8 Move number: 42
# Stockfish Suggested Move: Qxd2
# Qwen white move: Qxd2 Move number: 43
# Stockfish Suggested Move: Qe5
# Qwen black move: Qe5 Move number: 44
# Stockfish Suggested Move: Qg5
# Qwen white move: Qg5 Move number: 45
# Stockfish Suggested Move: Kf8
# Qwen black move: Kf8 Move number: 46
# Stockfish Suggested Move: Rd1
# Qwen white move: Rd1 Move number: 47
# Stockfish Suggested Move: h6
# Qwen black move: h6 Move number: 48
# Stockfish Suggested Move: Qg4
# Qwen white move: Qg4 Move number: 49
# Stockfish Suggested Move: Rd8
# Qwen black move: Rd8 Move number: 50
# Stockfish Suggested Move: Rxd8+
# Qwen white move: Rxd8+ Move number: 51
# Stockfish Suggested Move: Nxd8
# Qwen black move: Nxd8 Move number: 52
# Stockfish Suggested Move: Qd1
# Qwen white move: Qd1 Move number: 53
# Stockfish Suggested Move: Nc6
# Qwen black move: Nc6 Move number: 54
# Stockfish Suggested Move: g4
# Qwen white move: g4 Move number: 55
# Stockfish Suggested Move: g6
# Qwen black move: g6 Move number: 56
# Stockfish Suggested Move: Qc1
# Qwen white move: Qc1 Move number: 57
# Stockfish Suggested Move: gxf5
# Qwen black move: gxf5 Move number: 58
# Stockfish Suggested Move: Qxh6+
# Qwen white move: Qxh6+ Move number: 59
# Stockfish Suggested Move: Kg8
# Qwen black move: Kg8 Move number: 60
# Stockfish Suggested Move: Qxc6
# Qwen white move: Qxc6 Move number: 61
# Stockfish Suggested Move: Qxb2
# Qwen black move: Qxb2 Move number: 62
# Stockfish Suggested Move: Qxa6
# Qwen white move: Qxa6 Move number: 63
# Stockfish Suggested Move: Kg7
# Qwen black move: Kg7 Move number: 64
# Stockfish Suggested Move: Qa7
# Qwen white move: Qa7 Move number: 65
# Stockfish Suggested Move: fxg4
# Qwen black move: fxg4 Move number: 66
# Stockfish Suggested Move: hxg4
# Qwen white move: hxg4 Move number: 67
# Stockfish Suggested Move: Qe2
# Qwen black move: Qe2 Move number: 68
# Stockfish Suggested Move: Qd4+
# Qwen white move: Qd4+ Move number: 69
# Stockfish Suggested Move: Kh7
# Qwen black move: Kh7 Move number: 70
# Stockfish Suggested Move: a3
# Qwen white move: a3 Move number: 71
# Stockfish Suggested Move: Qf3
# Qwen black move: Qf3 Move number: 72
# Stockfish Suggested Move: Qb4
# Qwen white move: Qb4 Move number: 73
# Stockfish Suggested Move: f6
# Qwen black move: f6 Move number: 74
# Stockfish Suggested Move: Kf1
# Qwen white move: Kf1 Move number: 75
# Stockfish Suggested Move: Kg8
# Qwen black move: Kg8 Move number: 76
# Stockfish Suggested Move: Kg1
# Qwen white move: Kg1 Move number: 77
# Stockfish Suggested Move: Kg7
# Qwen black move: Kg7 Move number: 78
# Stockfish Suggested Move: Qe7+
# Qwen white move: Qe7+ Move number: 79
# Stockfish Suggested Move: Kh6
# Qwen black move: Kh6 Move number: 80
# Stockfish Suggested Move: Qb4
# Qwen white move: Qb4 Move number: 81
# Stockfish Suggested Move: Kg6
# Qwen black move: Kg6 Move number: 82
# Stockfish Suggested Move: Kf1
# Qwen white move: Kf1 Move number: 83
# Stockfish Suggested Move: Kf7
# Qwen black move: Kf7 Move number: 84
# Stockfish Suggested Move: Ke1
# Qwen white move: Ke1 Move number: 85
# Stockfish Suggested Move: Qd3
# Qwen black move: Qd3 Move number: 86
# Stockfish Suggested Move: a4
# Qwen white move: a4 Move number: 87
# Stockfish Suggested Move: bxa4
# Qwen black move: bxa4 Move number: 88
# Stockfish Suggested Move: Qxa4
# Qwen white move: Qxa4 Move number: 89
# Stockfish Suggested Move: Kg6
# Qwen black move: Kg6 Move number: 90
# Stockfish Suggested Move: Qf4
# Qwen white move: Qf4 Move number: 91
# Stockfish Suggested Move: f5
# Qwen black move: f5 Move number: 92
# Stockfish Suggested Move: gxf5+
# Qwen white move: gxf5+ Move number: 93
# Stockfish Suggested Move: Qxf5
# Qwen black move: Qxf5 Move number: 94
# Stockfish Suggested Move: Qd6+
# Qwen white move: Qd6+ Move number: 95
# Stockfish Suggested Move: Kg5
# Qwen black move: Kg5 Move number: 96
# Stockfish Suggested Move: Ke2
# Qwen white move: Ke2 Move number: 97
# Stockfish Suggested Move: Qe4+
# Qwen black move: Qe4+ Move number: 98
# Stockfish Suggested Move: Kd2
# Qwen white move: Kd2 Move number: 99
# Stockfish Suggested Move: Qf4+
# Qwen black move: Qf4+ Move number: 100
# Stockfish Suggested Move: Qxf4+
# Qwen white move: Qxf4+ Move number: 101
# Stockfish Suggested Move: Kxf4
# Qwen black move: Kxf4 Move number: 102
# Game 4 result: *
#
#
# Starting game 5...
# Stockfish Suggested Move: e4
# Qwen white move: e4 Move number: 1
# Stockfish Suggested Move: e5
# Qwen black move: e5 Move number: 2
# Stockfish Suggested Move: Nf3
# Qwen white move: Nf3 Move number: 3
# Stockfish Suggested Move: Nc6
# Qwen black move: Nc6 Move number: 4
# Stockfish Suggested Move: Bb5
# Qwen white move: Bb5 Move number: 5
# Stockfish Suggested Move: a6
# Qwen black move: a6 Move number: 6
# Stockfish Suggested Move: Ba4
# Qwen white move: Ba4 Move number: 7
# Stockfish Suggested Move: Nf6
# Qwen black move: Nf6 Move number: 8
# Stockfish Suggested Move: O-O
# Qwen white move: O-O Move number: 9
# Stockfish Suggested Move: Nxe4
# Qwen black move: Nxe4 Move number: 10
# Stockfish Suggested Move: d4
# Qwen white move: d4 Move number: 11
# Stockfish Suggested Move: b5
# Qwen black move: b5 Move number: 12
# Stockfish Suggested Move: Bb3
# Qwen white move: Bb3 Move number: 13
# Stockfish Suggested Move: d5
# Qwen black move: d5 Move number: 14
# Stockfish Suggested Move: dxe5
# Qwen white move: dxe5 Move number: 15
# Stockfish Suggested Move: Be6
# Qwen black move: Be6 Move number: 16
# Stockfish Suggested Move: c3
# Qwen white move: c3 Move number: 17
# Stockfish Suggested Move: Bc5
# Qwen black move: Bc5 Move number: 18
# Stockfish Suggested Move: Bc2
# Qwen white move: Bc2 Move number: 19
# Stockfish Suggested Move: O-O
# Qwen black move: O-O Move number: 20
# Stockfish Suggested Move: Nbd2
# Qwen white move: Nbd2 Move number: 21
# Stockfish Suggested Move: f5
# Qwen black move: f5 Move number: 22
# Stockfish Suggested Move: Nb3
# Qwen white move: Nb3 Move number: 23
# Stockfish Suggested Move: Bb6
# Qwen black move: Bb6 Move number: 24
# Stockfish Suggested Move: Nbd4
# Qwen white move: Nbd4 Move number: 25
# Stockfish Suggested Move: Nxd4
# Qwen black move: Nxd4 Move number: 26
# Stockfish Suggested Move: Nxd4
# Qwen white move: Nxd4 Move number: 27
# Stockfish Suggested Move: Bd7
# Qwen black move: Bd7 Move number: 28
# Stockfish Suggested Move: f3
# Qwen white move: f3 Move number: 29
# Stockfish Suggested Move: c5
# Qwen black move: c5 Move number: 30
# Stockfish Suggested Move: Nb3
# Qwen white move: Nb3 Move number: 31
# Stockfish Suggested Move: c4+
# Qwen black move: c4+ Move number: 32
# Stockfish Suggested Move: Nd4
# Qwen white move: Nd4 Move number: 33
# Stockfish Suggested Move: Nc5
# Qwen black move: Nc5 Move number: 34
# Stockfish Suggested Move: f4
# Qwen white move: f4 Move number: 35
# Stockfish Suggested Move: Ne4
# Qwen black move: Ne4 Move number: 36
# Stockfish Suggested Move: Be3
# Qwen white move: Be3 Move number: 37
# Stockfish Suggested Move: a5
# Qwen black move: a5 Move number: 38
# Stockfish Suggested Move: h3
# Qwen white move: h3 Move number: 39
# Stockfish Suggested Move: h6
# Qwen black move: h6 Move number: 40
# Stockfish Suggested Move: Kh2
# Qwen white move: Kh2 Move number: 41
# Stockfish Suggested Move: Kh7
# Qwen black move: Kh7 Move number: 42
# Stockfish Suggested Move: Bxe4
# Qwen white move: Bxe4 Move number: 43
# Stockfish Suggested Move: dxe4
# Qwen black move: dxe4 Move number: 44
# Stockfish Suggested Move: Nc2
# Qwen white move: Nc2 Move number: 45
# Stockfish Suggested Move: Bxe3
# Qwen black move: Bxe3 Move number: 46
# Stockfish Suggested Move: Nxe3
# Qwen white move: Nxe3 Move number: 47
# Stockfish Suggested Move: Be6
# Qwen black move: Be6 Move number: 48
# Stockfish Suggested Move: Qe2
# Qwen white move: Qe2 Move number: 49
# Stockfish Suggested Move: Qe7
# Qwen black move: Qe7 Move number: 50
# Stockfish Suggested Move: Rad1
# Qwen white move: Rad1 Move number: 51
# Stockfish Suggested Move: Rad8
# Qwen black move: Rad8 Move number: 52
# Stockfish Suggested Move: Rd4
# Qwen white move: Rd4 Move number: 53
# Stockfish Suggested Move: b4
# Qwen black move: b4 Move number: 54
# Stockfish Suggested Move: Rfd1
# Qwen white move: Rfd1 Move number: 55
# Stockfish Suggested Move: Qh4
# Qwen black move: Qh4 Move number: 56
# Stockfish Suggested Move: Qf1
# Qwen white move: Qf1 Move number: 57
# Stockfish Suggested Move: Rg8
# Qwen black move: Rg8 Move number: 58
# Stockfish Suggested Move: Rd6
# Qwen white move: Rd6 Move number: 59
# Stockfish Suggested Move: Rxd6
# Qwen black move: Rxd6 Move number: 60
# Stockfish Suggested Move: Rxd6
# Qwen white move: Rxd6 Move number: 61
# Stockfish Suggested Move: Re8
# Qwen black move: Re8 Move number: 62
# Stockfish Suggested Move: a3
# Qwen white move: a3 Move number: 63
# Stockfish Suggested Move: bxa3
# Qwen black move: bxa3 Move number: 64
# Stockfish Suggested Move: bxa3
# Qwen white move: bxa3 Move number: 65
# Stockfish Suggested Move: Qe7
# Qwen black move: Qe7 Move number: 66
# Stockfish Suggested Move: Qd1
# Qwen white move: Qd1 Move number: 67
# Stockfish Suggested Move: Qh4
# Qwen black move: Qh4 Move number: 68
# Stockfish Suggested Move: Qf1
# Qwen white move: Qf1 Move number: 69
# Stockfish Suggested Move: Qe7
# Qwen black move: Qe7 Move number: 70
# Stockfish Suggested Move: Qe2
# Qwen white move: Qe2 Move number: 71
# Stockfish Suggested Move: Qh4
# Qwen black move: Qh4 Move number: 72
# Stockfish Suggested Move: Qf1
# Qwen white move: Qf1 Move number: 73
# Stockfish Suggested Move: Qe7
# Qwen black move: Qe7 Move number: 74
# Stockfish Suggested Move: Qb1
# Qwen white move: Qb1 Move number: 75
# Stockfish Suggested Move: Qh4
# Qwen black move: Qh4 Move number: 76
# Stockfish Suggested Move: Qf1
# Qwen white move: Qf1 Move number: 77
# Stockfish Suggested Move: Qe7
# Qwen black move: Qe7 Move number: 78
# Stockfish Suggested Move: Qe2
# Qwen white move: Qe2 Move number: 79
# Stockfish Suggested Move: Qh4
# Invalid move by Qwen black. Move: Qf1
# New Move: Qh4
# Qwen black move: Qh4 Move number: 80
# Stockfish Suggested Move: Qf1
# Qwen white move: Qf1 Move number: 81
# Qwen black move: Qh4 Move number: 82
# Game 5 result: 1/2-1/2
#
#
# Starting game 6...
# Stockfish Suggested Move: e4
# Qwen white move: e4 Move number: 1
# Stockfish Suggested Move: e5
# Qwen black move: e5 Move number: 2
# Stockfish Suggested Move: Nf3
# Qwen white move: Nf3 Move number: 3
# Stockfish Suggested Move: Nc6
# Qwen black move: Nc6 Move number: 4
# Stockfish Suggested Move: Bb5
# Qwen white move: Bb5 Move number: 5
# Stockfish Suggested Move: a6
# Qwen black move: a6 Move number: 6
# Stockfish Suggested Move: Ba4
# Qwen white move: Ba4 Move number: 7
# Stockfish Suggested Move: Nf6
# Qwen black move: Nf6 Move number: 8
# Stockfish Suggested Move: O-O
# Qwen white move: O-O Move number: 9
# Stockfish Suggested Move: Nxe4
# Qwen black move: Nxe4 Move number: 10
# Stockfish Suggested Move: d4
# Qwen white move: d4 Move number: 11
# Stockfish Suggested Move: b5
# Qwen black move: b5 Move number: 12
# Stockfish Suggested Move: Bb3
# Qwen white move: Bb3 Move number: 13
# Stockfish Suggested Move: d5
# Qwen black move: d5 Move number: 14
# Stockfish Suggested Move: dxe5
# Qwen white move: dxe5 Move number: 15
# Stockfish Suggested Move: Be6
# Qwen black move: Be6 Move number: 16
# Stockfish Suggested Move: c3
# Qwen white move: c3 Move number: 17
# Stockfish Suggested Move: Bc5
# Qwen black move: Bc5 Move number: 18
# Stockfish Suggested Move: Nbd2
# Qwen white move: Nbd2 Move number: 19
# Stockfish Suggested Move: O-O
# Qwen black move: O-O Move number: 20
# Stockfish Suggested Move: Bc2
# Qwen white move: Bc2 Move number: 21
# Stockfish Suggested Move: Nxf2
# Qwen black move: Nxf2 Move number: 22
# Stockfish Suggested Move: Rxf2
# Qwen white move: Rxf2 Move number: 23
# Stockfish Suggested Move: f6
# Qwen black move: f6 Move number: 24
# Stockfish Suggested Move: Qe1
# Qwen white move: Qe1 Move number: 25
# Stockfish Suggested Move: fxe5
# Qwen black move: fxe5 Move number: 26
# Stockfish Suggested Move: Nb3
# Qwen white move: Nb3 Move number: 27
# Stockfish Suggested Move: Bxf2+
# Qwen black move: Bxf2+ Move number: 28
# Stockfish Suggested Move: Qxf2
# Qwen white move: Qxf2 Move number: 29
# Stockfish Suggested Move: e4
# Qwen black move: e4 Move number: 30
# Stockfish Suggested Move: Qe1
# Qwen white move: Qe1 Move number: 31
# Stockfish Suggested Move: Qd6
# Qwen black move: Qd6 Move number: 32
# Stockfish Suggested Move: Nfd4
# Qwen white move: Nfd4 Move number: 33
# Stockfish Suggested Move: Ne5
# Qwen black move: Ne5 Move number: 34
# Stockfish Suggested Move: Qg3
# Qwen white move: Qg3 Move number: 35
# Stockfish Suggested Move: Rae8
# Qwen black move: Rae8 Move number: 36
# Stockfish Suggested Move: Bd1
# Qwen white move: Bd1 Move number: 37
# Stockfish Suggested Move: Bd7
# Qwen black move: Bd7 Move number: 38
# Stockfish Suggested Move: Be3
# Qwen white move: Be3 Move number: 39
# Stockfish Suggested Move: Nc4
# Qwen black move: Nc4 Move number: 40
# Stockfish Suggested Move: Qxd6
# Qwen white move: Qxd6 Move number: 41
# Stockfish Suggested Move: cxd6
# Qwen black move: cxd6 Move number: 42
# Stockfish Suggested Move: Bc1
# Qwen white move: Bc1 Move number: 43
# Stockfish Suggested Move: e3
# Qwen black move: e3 Move number: 44
# Stockfish Suggested Move: Bf3
# Qwen white move: Bf3 Move number: 45
# Stockfish Suggested Move: e2
# Qwen black move: e2 Move number: 46
# Stockfish Suggested Move: Bxe2
# Qwen white move: Bxe2 Move number: 47
# Stockfish Suggested Move: Bg4
# Qwen black move: Bg4 Move number: 48
# Stockfish Suggested Move: Bf3
# Qwen white move: Bf3 Move number: 49
# Stockfish Suggested Move: Re1+
# Qwen black move: Re1+ Move number: 50
# Stockfish Suggested Move: Kf2
# Qwen white move: Kf2 Move number: 51
# Stockfish Suggested Move: Rh1
# Qwen black move: Rh1 Move number: 52
# Stockfish Suggested Move: a4
# Qwen white move: a4 Move number: 53
# Stockfish Suggested Move: bxa4
# Qwen black move: bxa4 Move number: 54
# Stockfish Suggested Move: Rxa4
# Qwen white move: Rxa4 Move number: 55
# Stockfish Suggested Move: a5
# Qwen black move: a5 Move number: 56
# Stockfish Suggested Move: Kg3
# Qwen white move: Kg3 Move number: 57
# Stockfish Suggested Move: Bxf3
# Qwen black move: Bxf3 Move number: 58
# Stockfish Suggested Move: gxf3
# Qwen white move: gxf3 Move number: 59
# Stockfish Suggested Move: Rg1+
# Qwen black move: Rg1+ Move number: 60
# Stockfish Suggested Move: Kf2
# Qwen white move: Kf2 Move number: 61
# Stockfish Suggested Move: Rd1
# Qwen black move: Rd1 Move number: 62
# Stockfish Suggested Move: Ne2
# Qwen white move: Ne2 Move number: 63
# Stockfish Suggested Move: Ne5
# Qwen black move: Ne5 Move number: 64
# Stockfish Suggested Move: Bf4
# Qwen white move: Bf4 Move number: 65
# Stockfish Suggested Move: Rb1
# Qwen black move: Rb1 Move number: 66
# Stockfish Suggested Move: Bxe5
# Qwen white move: Bxe5 Move number: 67
# Stockfish Suggested Move: dxe5
# Qwen black move: dxe5 Move number: 68
# Stockfish Suggested Move: Nc5
# Qwen white move: Nc5 Move number: 69
# Stockfish Suggested Move: e4
# Qwen black move: e4 Move number: 70
# Stockfish Suggested Move: f4
# Qwen white move: f4 Move number: 71
# Stockfish Suggested Move: Rxb2
# Qwen black move: Rxb2 Move number: 72
# Stockfish Suggested Move: Ke3
# Qwen white move: Ke3 Move number: 73
# Stockfish Suggested Move: Rb5
# Qwen black move: Rb5 Move number: 74
# Stockfish Suggested Move: Ne6
# Qwen white move: Ne6 Move number: 75
# Stockfish Suggested Move: Rc8
# Qwen black move: Rc8 Move number: 76
# Stockfish Suggested Move: Ra3
# Qwen white move: Ra3 Move number: 77
# Stockfish Suggested Move: Kf7
# Qwen black move: Kf7 Move number: 78
# Stockfish Suggested Move: N6d4
# Qwen white move: N6d4 Move number: 79
# Stockfish Suggested Move: Rbc5
# Qwen black move: Rbc5 Move number: 80
# Stockfish Suggested Move: Nf5
# Qwen white move: Nf5 Move number: 81
# Stockfish Suggested Move: Rd8
# Qwen black move: Rd8 Move number: 82
# Stockfish Suggested Move: Kd4
# Qwen white move: Kd4 Move number: 83
# Stockfish Suggested Move: Rb5
# Qwen black move: Rb5 Move number: 84
# Stockfish Suggested Move: Ra2
# Qwen white move: Ra2 Move number: 85
# Stockfish Suggested Move: g6
# Qwen black move: g6 Move number: 86
# Stockfish Suggested Move: Ne3
# Qwen white move: Ne3 Move number: 87
# Stockfish Suggested Move: Rdb8
# Qwen black move: Rdb8 Move number: 88
# Stockfish Suggested Move: Ng3
# Qwen white move: Ng3 Move number: 89
# Stockfish Suggested Move: Rb2
# Qwen black move: Rb2 Move number: 90
# Stockfish Suggested Move: Rxa5
# Qwen white move: Rxa5 Move number: 91
# Stockfish Suggested Move: Rd2+
# Qwen black move: Rd2+ Move number: 92
# Stockfish Suggested Move: Kc5
# Qwen white move: Kc5 Move number: 93
# Stockfish Suggested Move: Rc8+
# Qwen black move: Rc8+ Move number: 94
# Stockfish Suggested Move: Kd6
# Qwen white move: Kd6 Move number: 95
# Stockfish Suggested Move: Rd8+
# Qwen black move: Rd8+ Move number: 96
# Stockfish Suggested Move: Kc7
# Qwen white move: Kc7 Move number: 97
# Stockfish Suggested Move: Re8
# Qwen black move: Re8 Move number: 98
# Stockfish Suggested Move: Rxd5
# Qwen white move: Rxd5 Move number: 99
# Stockfish Suggested Move: Rd3
# Qwen black move: Rd3 Move number: 100
# Stockfish Suggested Move: Rxd3
# Qwen white move: Rxd3 Move number: 101
# Stockfish Suggested Move: exd3
# Qwen black move: exd3 Move number: 102
# Game 6 result: *
#
#
# Starting game 7...
# Stockfish Suggested Move: e4
# Qwen white move: e4 Move number: 1
# Stockfish Suggested Move: e5
# Qwen black move: e5 Move number: 2
# Stockfish Suggested Move: Nf3
# Qwen white move: Nf3 Move number: 3
# Stockfish Suggested Move: Nc6
# Qwen black move: Nc6 Move number: 4
# Stockfish Suggested Move: Bb5
# Qwen white move: Bb5 Move number: 5
# Stockfish Suggested Move: a6
# Qwen black move: a6 Move number: 6
# Stockfish Suggested Move: Ba4
# Qwen white move: Ba4 Move number: 7
# Stockfish Suggested Move: Nf6
# Qwen black move: Nf6 Move number: 8
# Stockfish Suggested Move: O-O
# Qwen white move: O-O Move number: 9
# Stockfish Suggested Move: Nxe4
# Qwen black move: Nxe4 Move number: 10
# Stockfish Suggested Move: d4
# Qwen white move: d4 Move number: 11
# Stockfish Suggested Move: b5
# Qwen black move: b5 Move number: 12
# Stockfish Suggested Move: Bb3
# Qwen white move: Bb3 Move number: 13
# Stockfish Suggested Move: d5
# Qwen black move: d5 Move number: 14
# Stockfish Suggested Move: dxe5
# Qwen white move: dxe5 Move number: 15
# Stockfish Suggested Move: Be6
# Qwen black move: Be6 Move number: 16
# Stockfish Suggested Move: c3
# Qwen white move: c3 Move number: 17
# Stockfish Suggested Move: Be7
# Qwen black move: Be7 Move number: 18
# Stockfish Suggested Move: Bc2
# Qwen white move: Bc2 Move number: 19
# Stockfish Suggested Move: Bg4
# Qwen black move: Bg4 Move number: 20
# Stockfish Suggested Move: a4
# Qwen white move: a4 Move number: 21
# Stockfish Suggested Move: b4
# Qwen black move: b4 Move number: 22
# Stockfish Suggested Move: h3
# Qwen white move: h3 Move number: 23
# Stockfish Suggested Move: Bh5
# Qwen black move: Bh5 Move number: 24
# Stockfish Suggested Move: g4
# Qwen white move: g4 Move number: 25
# Stockfish Suggested Move: Bg6
# Qwen black move: Bg6 Move number: 26
# Stockfish Suggested Move: Bb3
# Qwen white move: Bb3 Move number: 27
# Stockfish Suggested Move: O-O
# Qwen black move: O-O Move number: 28
# Stockfish Suggested Move: Bxd5
# Qwen white move: Bxd5 Move number: 29
# Stockfish Suggested Move: Qe8
# Qwen black move: Qe8 Move number: 30
# Stockfish Suggested Move: Qe2
# Qwen white move: Qe2 Move number: 31
# Stockfish Suggested Move: Nc5
# Qwen black move: Nc5 Move number: 32
# Stockfish Suggested Move: Bc4
# Qwen white move: Bc4 Move number: 33
# Stockfish Suggested Move: Rd8
# Qwen black move: Rd8 Move number: 34
# Stockfish Suggested Move: Be3
# Qwen white move: Be3 Move number: 35
# Stockfish Suggested Move: Bd3
# Qwen black move: Bd3 Move number: 36
# Stockfish Suggested Move: Bxd3
# Qwen white move: Bxd3 Move number: 37
# Stockfish Suggested Move: Nxd3
# Qwen black move: Nxd3 Move number: 38
# Stockfish Suggested Move: Rd1
# Qwen white move: Rd1 Move number: 39
# Stockfish Suggested Move: Ncxe5
# Qwen black move: Ncxe5 Move number: 40
# Stockfish Suggested Move: Nxe5
# Qwen white move: Nxe5 Move number: 41
# Stockfish Suggested Move: Nxe5
# Qwen black move: Nxe5 Move number: 42
# Stockfish Suggested Move: Rxd8
# Qwen white move: Rxd8 Move number: 43
# Stockfish Suggested Move: Qxd8
# Qwen black move: Qxd8 Move number: 44
# Stockfish Suggested Move: Nd2
# Qwen white move: Nd2 Move number: 45
# Stockfish Suggested Move: bxc3
# Qwen black move: bxc3 Move number: 46
# Stockfish Suggested Move: bxc3
# Qwen white move: bxc3 Move number: 47
# Stockfish Suggested Move: Qc8
# Qwen black move: Qc8 Move number: 48
# Stockfish Suggested Move: Nf3
# Qwen white move: Nf3 Move number: 49
# Stockfish Suggested Move: Ng6
# Qwen black move: Ng6 Move number: 50
# Stockfish Suggested Move: Qc4
# Qwen white move: Qc4 Move number: 51
# Stockfish Suggested Move: Qb7
# Qwen black move: Qb7 Move number: 52
# Stockfish Suggested Move: Nd2
# Qwen white move: Nd2 Move number: 53
# Stockfish Suggested Move: h6
# Qwen black move: h6 Move number: 54
# Stockfish Suggested Move: Rb1
# Qwen white move: Rb1 Move number: 55
# Stockfish Suggested Move: Qc8
# Qwen black move: Qc8 Move number: 56
# Stockfish Suggested Move: Qc6
# Qwen white move: Qc6 Move number: 57
# Stockfish Suggested Move: h5
# Qwen black move: h5 Move number: 58
# Stockfish Suggested Move: Qb7
# Qwen white move: Qb7 Move number: 59
# Stockfish Suggested Move: Qd7
# Qwen black move: Qd7 Move number: 60
# Stockfish Suggested Move: gxh5
# Qwen white move: gxh5 Move number: 61
# Stockfish Suggested Move: Nh4
# Qwen black move: Nh4 Move number: 62
# Stockfish Suggested Move: Nf3
# Qwen white move: Nf3 Move number: 63
# Stockfish Suggested Move: Qxh3
# Qwen black move: Qxh3 Move number: 64
# Stockfish Suggested Move: Nxh4
# Qwen white move: Nxh4 Move number: 65
# Stockfish Suggested Move: Qxh4
# Qwen black move: Qxh4 Move number: 66
# Stockfish Suggested Move: h6
# Qwen white move: h6 Move number: 67
# Stockfish Suggested Move: Rd8
# Qwen black move: Rd8 Move number: 68
# Stockfish Suggested Move: Qxc7
# Qwen white move: Qxc7 Move number: 69
# Stockfish Suggested Move: Rd6
# Qwen black move: Rd6 Move number: 70
# Stockfish Suggested Move: Qc8+
# Qwen white move: Qc8+ Move number: 71
# Stockfish Suggested Move: Bd8
# Qwen black move: Bd8 Move number: 72
# Stockfish Suggested Move: hxg7
# Qwen white move: hxg7 Move number: 73
# Stockfish Suggested Move: Qe4
# Qwen black move: Qe4 Move number: 74
# Stockfish Suggested Move: Re1
# Qwen white move: Re1 Move number: 75
# Stockfish Suggested Move: Qg6+
# Qwen black move: Qg6+ Move number: 76
# Stockfish Suggested Move: Kf1
# Qwen white move: Kf1 Move number: 77
# Stockfish Suggested Move: Qd3+
# Qwen black move: Qd3+ Move number: 78
# Stockfish Suggested Move: Re2
# Qwen white move: Re2 Move number: 79
# Stockfish Suggested Move: Qd1+
# Qwen black move: Qd1+ Move number: 80
# Stockfish Suggested Move: Re1
# Qwen white move: Re1 Move number: 81
# Stockfish Suggested Move: Qd3+
# Qwen black move: Qd3+ Move number: 82
# Stockfish Suggested Move: Re2
# Qwen white move: Re2 Move number: 83
# Stockfish Suggested Move: Qb1+
# Qwen black move: Qb1+ Move number: 84
# Stockfish Suggested Move: Re1
# Qwen white move: Re1 Move number: 85
# Stockfish Suggested Move: Qd3+
# Qwen black move: Qd3+ Move number: 86
# Stockfish Suggested Move: Re2
# Qwen white move: Re2 Move number: 87
# Stockfish Suggested Move: Qd1+
# Qwen black move: Qd1+ Move number: 88
# Stockfish Suggested Move: Re1
# Qwen white move: Re1 Move number: 89
# Stockfish Suggested Move: Qd3+
# Qwen black move: Qd3+ Move number: 90
# Stockfish Suggested Move: Re2
# Qwen white move: Re2 Move number: 91
# Stockfish Suggested Move: Qd1+
# Qwen black move: Qd1+ Move number: 92
# Stockfish Suggested Move: Re1
# Qwen white move: Re1 Move number: 93
# Stockfish Suggested Move: Qd3+
# Qwen black move: Qd3+ Move number: 94
# Game 7 result: 1/2-1/2
#
#
# Starting game 8...
# Stockfish Suggested Move: e4
# Qwen white move: e4 Move number: 1
# Stockfish Suggested Move: e5
# Qwen black move: e5 Move number: 2
# Stockfish Suggested Move: Nf3
# Qwen white move: Nf3 Move number: 3
# Stockfish Suggested Move: Nc6
# Qwen black move: Nc6 Move number: 4
# Stockfish Suggested Move: Bb5
# Qwen white move: Bb5 Move number: 5
# Stockfish Suggested Move: a6
# Qwen black move: a6 Move number: 6
# Stockfish Suggested Move: Ba4
# Qwen white move: Ba4 Move number: 7
# Stockfish Suggested Move: Nf6
# Qwen black move: Nf6 Move number: 8
# Stockfish Suggested Move: O-O
# Qwen white move: O-O Move number: 9
# Stockfish Suggested Move: Nxe4
# Qwen black move: Nxe4 Move number: 10
# Stockfish Suggested Move: d4
# Qwen white move: d4 Move number: 11
# Stockfish Suggested Move: b5
# Qwen black move: b5 Move number: 12
# Stockfish Suggested Move: Bb3
# Qwen white move: Bb3 Move number: 13
# Stockfish Suggested Move: d5
# Qwen black move: d5 Move number: 14
# Stockfish Suggested Move: dxe5
# Qwen white move: dxe5 Move number: 15
# Stockfish Suggested Move: Be6
# Qwen black move: Be6 Move number: 16
# Stockfish Suggested Move: c3
# Qwen white move: c3 Move number: 17
# Stockfish Suggested Move: Bc5
# Qwen black move: Bc5 Move number: 18
# Stockfish Suggested Move: Nbd2
# Qwen white move: Nbd2 Move number: 19
# Stockfish Suggested Move: O-O
# Qwen black move: O-O Move number: 20
# Stockfish Suggested Move: Bc2
# Qwen white move: Bc2 Move number: 21
# Stockfish Suggested Move: f5
# Qwen black move: f5 Move number: 22
# Stockfish Suggested Move: Nb3
# Qwen white move: Nb3 Move number: 23
# Stockfish Suggested Move: Bb6
# Qwen black move: Bb6 Move number: 24
# Stockfish Suggested Move: Nfd4
# Qwen white move: Nfd4 Move number: 25
# Stockfish Suggested Move: Nxd4
# Qwen black move: Nxd4 Move number: 26
# Stockfish Suggested Move: Nxd4
# Qwen white move: Nxd4 Move number: 27
# Stockfish Suggested Move: Bd7
# Qwen black move: Bd7 Move number: 28
# Stockfish Suggested Move: f3
# Qwen white move: f3 Move number: 29
# ...
# Qwen black move: Nxe4 Move number: 8
# Stockfish Suggested Move: d4
# Qwen white move: d4 Move number: 9
# Stockfish Suggested Move: Be7
# Qwen black move: Be7 Move number: 10
# Stockfish Suggested Move: Bd3
# Qwen white move: Bd3 Move number: 11
# Stockfish Suggested Move: d5
# Qwen black move: d5 Move number: 12
# Stockfish Suggested Move: O-O
# Qwen white move: O-O Move number: 13
# Stockfish Suggested Move: Nc6
# Qwen black move: Nc6 Move number: 14
# Stockfish Suggested Move: c4
# Qwen white move: c4 Move number: 15
# Stockfish Suggested Move: Nb4
# Qwen black move: Nb4 Move number: 16
# Stockfish Suggested Move: cxd5
# Qwen white move: cxd5 Move number: 17
# Stockfish Suggested Move: Nxd3
# Qwen black move: Nxd3 Move number: 18
# Stockfish Suggested Move: Qxd3
# Qwen white move: Qxd3 Move number: 19
# Stockfish Suggested Move: Qxd5
# Qwen black move: Qxd5 Move number: 20
# Stockfish Suggested Move: Re1
# Qwen white move: Re1 Move number: 21
# Stockfish Suggested Move: Bf5
# Qwen black move: Bf5 Move number: 22
# Stockfish Suggested Move: g4
# Qwen white move: g4 Move number: 23
# Stockfish Suggested Move: Bg6
# Qwen black move: Bg6 Move number: 24
# Stockfish Suggested Move: Nc3
# Qwen white move: Nc3 Move number: 25
# Stockfish Suggested Move: Nxc3
# Qwen black move: Nxc3 Move number: 26
# Stockfish Suggested Move: Qxc3
# Qwen white move: Qxc3 Move number: 27
# Stockfish Suggested Move: f6
# Qwen black move: f6 Move number: 28
# Stockfish Suggested Move: Nh4
# Qwen white move: Nh4 Move number: 29
# Stockfish Suggested Move: Kd7
# Qwen black move: Kd7 Move number: 30
# Stockfish Suggested Move: Bf4
# Qwen white move: Bf4 Move number: 31
# Stockfish Suggested Move: Rac8
# Invalid move by Qwen black. Move:  Rac8
# New Move: Qa5
# Qwen black move: Qa5 Move number: 32
# Stockfish Suggested Move: Qxa5
# Qwen white move: Qxa5 Move number: 33
# Stockfish Suggested Move: Bd6
# Qwen black move: Bd6 Move number: 34
# Stockfish Suggested Move: Bxd6
# Qwen white move: Bxd6 Move number: 35
# Stockfish Suggested Move: b6
# Qwen black move: b6 Move number: 36
# Stockfish Suggested Move: Qa4+
# Qwen white move: Qa4+ Move number: 37
# Stockfish Suggested Move: c6
# Qwen black move: c6 Move number: 38
# Stockfish Suggested Move: Bf4
# Qwen white move: Bf4 Move number: 39
# Stockfish Suggested Move: Bh5
# Qwen black move: Bh5 Move number: 40
# Stockfish Suggested Move: gxh5
# Qwen white move: gxh5 Move number: 41
# Stockfish Suggested Move: g5
# Qwen black move: g5 Move number: 42
# Stockfish Suggested Move: hxg6
# Qwen white move: hxg6 Move number: 43
# Stockfish Suggested Move: a5
# Qwen black move: a5 Move number: 44
# Stockfish Suggested Move: d5
# Qwen white move: d5 Move number: 45
# Stockfish Suggested Move: Kd8
# Qwen black move: Kd8 Move number: 46
# Stockfish Suggested Move: Bc7+
# Qwen white move: Bc7+ Move number: 47
# Stockfish Suggested Move: Kxc7
# Qwen black move: Kxc7 Move number: 48
# Stockfish Suggested Move: Qxc6+
# Qwen white move: Qxc6+ Move number: 49
# Stockfish Suggested Move: Kd8
# Qwen black move: Kd8 Move number: 50
# Stockfish Suggested Move: Qxb6+
# Qwen white move: Qxb6+ Move number: 51
# Stockfish Suggested Move: Kd7
# Qwen black move: Kd7 Move number: 52
# Stockfish Suggested Move: Qb7+
# Qwen white move: Qb7+ Move number: 53
# Stockfish Suggested Move: Kd8
# Qwen black move: Kd8 Move number: 54
# Stockfish Suggested Move: Qe7+
# Qwen white move: Qe7+ Move number: 55
# Stockfish Suggested Move: Kc8
# Qwen black move: Kc8 Move number: 56
# Stockfish Suggested Move: Rac1+
# Qwen white move: Rac1+ Move number: 57
# Stockfish Suggested Move: Kb8
# Qwen black move: Kb8 Move number: 58
# Stockfish Suggested Move: Qc7#
# Qwen white move: Qc7# Move number: 59
# Qwen black move: Kb8 Move number: 60
# Game 58 result: 1-0
#
#
# Starting game 59...
# Stockfish Suggested Move: e4
# Qwen white move: e4 Move number: 1
# Stockfish Suggested Move: e5
# Qwen black move: e5 Move number: 2
# Stockfish Suggested Move: Nf3
# Qwen white move: Nf3 Move number: 3
# Stockfish Suggested Move: Nf6
# Qwen black move: Nf6 Move number: 4
# Stockfish Suggested Move: Nxe5
# Qwen white move: Nxe5 Move number: 5
# Stockfish Suggested Move: d6
# Qwen black move: d6 Move number: 6
# Stockfish Suggested Move: Nf3
# Qwen white move: Nf3 Move number: 7
# Stockfish Suggested Move: Nxe4
# Qwen black move: Nxe4 Move number: 8
# Stockfish Suggested Move: d4
# Qwen white move: d4 Move number: 9
# Stockfish Suggested Move: Be7
# Qwen black move: Be7 Move number: 10
# Stockfish Suggested Move: Bd3
# Qwen white move: Bd3 Move number: 11
# Stockfish Suggested Move: d5
# Qwen black move: d5 Move number: 12
# Stockfish Suggested Move: O-O
# Qwen white move: O-O Move number: 13
# Stockfish Suggested Move: Nc6
# Qwen black move: Nc6 Move number: 14
# Stockfish Suggested Move: Re1
# Qwen white move: Re1 Move number: 15
# Stockfish Suggested Move: Bg4
# Qwen black move: Bg4 Move number: 16
# Stockfish Suggested Move: c3
# Qwen white move: c3 Move number: 17
# Stockfish Suggested Move: f5
# Qwen black move: f5 Move number: 18
# Stockfish Suggested Move: Qb3
# Qwen white move: Qb3 Move number: 19
# Stockfish Suggested Move: O-O
# Qwen black move: O-O Move number: 20
# Stockfish Suggested Move: Nbd2
# Qwen white move: Nbd2 Move number: 21
# Stockfish Suggested Move: Na5
# Qwen black move: Na5 Move number: 22
# Stockfish Suggested Move: Qc2
# Qwen white move: Qc2 Move number: 23
# Stockfish Suggested Move: Nc6
# Qwen black move: Nc6 Move number: 24
# Stockfish Suggested Move: b4
# Qwen white move: b4 Move number: 25
# Stockfish Suggested Move: Bd6
# Qwen black move: Bd6 Move number: 26
# Stockfish Suggested Move: b5
# Qwen white move: b5 Move number: 27
# Stockfish Suggested Move: Na5
# Qwen black move: Na5 Move number: 28
# Stockfish Suggested Move: c4
# Qwen white move: c4 Move number: 29
# Stockfish Suggested Move: c6
# Qwen black move: c6 Move number: 30
# Stockfish Suggested Move: a4
# Qwen white move: a4 Move number: 31
# Stockfish Suggested Move: Bf4
# Qwen black move: Bf4 Move number: 32
# Stockfish Suggested Move: h3
# Qwen white move: h3 Move number: 33
# Stockfish Suggested Move: Bh5
# Qwen black move: Bh5 Move number: 34
# Stockfish Suggested Move: Bf1
# Qwen white move: Bf1 Move number: 35
# Stockfish Suggested Move: Rc8
# Qwen black move: Rc8 Move number: 36
# Stockfish Suggested Move: Qa2
# Qwen white move: Qa2 Move number: 37
# Stockfish Suggested Move: Bxd2
# Qwen black move: Bxd2 Move number: 38
# Stockfish Suggested Move: Nxd2
# Qwen white move: Nxd2 Move number: 39
# Stockfish Suggested Move: Nxd2
# Qwen black move: Nxd2 Move number: 40
# Stockfish Suggested Move: Bxd2
# Qwen white move: Bxd2 Move number: 41
# Stockfish Suggested Move: Nxc4
# Qwen black move: Nxc4 Move number: 42
# Stockfish Suggested Move: Bb4
# Qwen white move: Bb4 Move number: 43
# Stockfish Suggested Move: Re8
# Qwen black move: Re8 Move number: 44
# Stockfish Suggested Move: Rxe8+
# Qwen white move: Rxe8+ Move number: 45
# Stockfish Suggested Move: Bxe8
# Qwen black move: Bxe8 Move number: 46
# Stockfish Suggested Move: Re1
# Qwen white move: Re1 Move number: 47
# Stockfish Suggested Move: cxb5
# Qwen black move: cxb5 Move number: 48
# Stockfish Suggested Move: axb5
# Qwen white move: axb5 Move number: 49
# Stockfish Suggested Move: Bxb5
# Qwen black move: Bxb5 Move number: 50
# Stockfish Suggested Move: Qxa7
# Qwen white move: Qxa7 Move number: 51
# Stockfish Suggested Move: Bc6
# Qwen black move: Bc6 Move number: 52
# Stockfish Suggested Move: Bd3
# Qwen white move: Bd3 Move number: 53
# Stockfish Suggested Move: Qf6
# Qwen black move: Qf6 Move number: 54
# Stockfish Suggested Move: Qa1
# Qwen white move: Qa1 Move number: 55
# Stockfish Suggested Move: h6
# Qwen black move: h6 Move number: 56
# Stockfish Suggested Move: Qa2
# Qwen white move: Qa2 Move number: 57
# Stockfish Suggested Move: Kh8
# Qwen black move: Kh8 Move number: 58
# Stockfish Suggested Move: Re7
# Qwen white move: Re7 Move number: 59
# Stockfish Suggested Move: Rf8
# Qwen black move: Rf8 Move number: 60
# Stockfish Suggested Move: Qa1
# Qwen white move: Qa1 Move number: 61
# Stockfish Suggested Move: Kg8
# Qwen black move: Kg8 Move number: 62
# Stockfish Suggested Move: Qa7
# Qwen white move: Qa7 Move number: 63
# Stockfish Suggested Move: Rd8
# Qwen black move: Rd8 Move number: 64
# Stockfish Suggested Move: Qa2
# Qwen white move: Qa2 Move number: 65
# Stockfish Suggested Move: Re8
# Qwen black move: Re8 Move number: 66
# Stockfish Suggested Move: Rxe8+
# Qwen white move: Rxe8+ Move number: 67
# Stockfish Suggested Move: Bxe8
# Qwen black move: Bxe8 Move number: 68
# Stockfish Suggested Move: Qa8
# Qwen white move: Qa8 Move number: 69
# Stockfish Suggested Move: Qf7
# Qwen black move: Qf7 Move number: 70
# Stockfish Suggested Move: Qc8
# Qwen white move: Qc8 Move number: 71
# Stockfish Suggested Move: Nb6
# Qwen black move: Nb6 Move number: 72
# Stockfish Suggested Move: Qb8
# Qwen white move: Qb8 Move number: 73
# Stockfish Suggested Move: Nc4
# Qwen black move: Nc4 Move number: 74
# Stockfish Suggested Move: Qc8
# Qwen white move: Qc8 Move number: 75
# Stockfish Suggested Move: Nb6
# Qwen black move: Nb6 Move number: 76
# Stockfish Suggested Move: Qb8
# Qwen white move: Qb8 Move number: 77
# Stockfish Suggested Move: Nc4
# Qwen black move: Nc4 Move number: 78
# Stockfish Suggested Move: Qc8
# Qwen white move: Qc8 Move number: 79
# Stockfish Suggested Move: Nb6
# Qwen black move: Nb6 Move number: 80
# Stockfish Suggested Move: Qxf5
# Qwen white move: Qxf5 Move number: 81
# Stockfish Suggested Move: Qxf5
# Qwen black move: Qxf5 Move number: 82
# Stockfish Suggested Move: Bxf5
# Qwen white move: Bxf5 Move number: 83
# Stockfish Suggested Move: Kf7
# Qwen black move: Kf7 Move number: 84
# Stockfish Suggested Move: Bg4
# Qwen white move: Bg4 Move number: 85
# Stockfish Suggested Move: Nd7
# Qwen black move: Nd7 Move number: 86
# Stockfish Suggested Move: h4
# Qwen white move: h4 Move number: 87
# Stockfish Suggested Move: Nf8
# Qwen black move: Nf8 Move number: 88
# Stockfish Suggested Move: Bf3
# Qwen white move: Bf3 Move number: 89
# Stockfish Suggested Move: Bc6
# Qwen black move: Bc6 Move number: 90
# Stockfish Suggested Move: Bh5+
# Qwen white move: Bh5+ Move number: 91
# Stockfish Suggested Move: g6
# Qwen black move: g6 Move number: 92
# Stockfish Suggested Move: Bxf8
# Qwen white move: Bxf8 Move number: 93
# Stockfish Suggested Move: gxh5
# Qwen black move: gxh5 Move number: 94
# Stockfish Suggested Move: Bxh6
# Qwen white move: Bxh6 Move number: 95
# Stockfish Suggested Move: Bb5
# Qwen black move: Bb5 Move number: 96
# Stockfish Suggested Move: Bg5
# Qwen white move: Bg5 Move number: 97
# Stockfish Suggested Move: Ke6
# Qwen black move: Ke6 Move number: 98
# Stockfish Suggested Move: f3
# Qwen white move: f3 Move number: 99
# Stockfish Suggested Move: Kf5
# Qwen black move: Kf5 Move number: 100
# Stockfish Suggested Move: Bd2
# Qwen white move: Bd2 Move number: 101
# Stockfish Suggested Move: Be2
# Qwen black move: Be2 Move number: 102
# Game 59 result: *
#
#
# Starting game 60...
# Stockfish Suggested Move: d4
# Qwen white move: d4 Move number: 1
# Stockfish Suggested Move: d5
# Qwen black move: d5 Move number: 2
# Stockfish Suggested Move: c4
# Qwen white move: c4 Move number: 3
# Stockfish Suggested Move: e6
# Qwen black move: e6 Move number: 4
# Stockfish Suggested Move: Nc3
# Qwen white move: Nc3 Move number: 5
# Stockfish Suggested Move: Nf6
# Qwen black move: Nf6 Move number: 6
# Stockfish Suggested Move: Bg5
# Qwen white move: Bg5 Move number: 7
# Stockfish Suggested Move: c5
# Qwen black move: c5 Move number: 8
# Stockfish Suggested Move: cxd5
# Qwen white move: cxd5 Move number: 9
# Stockfish Suggested Move: cxd4
# Qwen black move: cxd4 Move number: 10
# Stockfish Suggested Move: Qxd4
# Qwen white move: Qxd4 Move number: 11
# Stockfish Suggested Move: Be7
# Qwen black move: Be7 Move number: 12
# Stockfish Suggested Move: e4
# Qwen white move: e4 Move number: 13
# Stockfish Suggested Move: exd5
# Qwen black move: exd5 Move number: 14
# Stockfish Suggested Move: Bxf6
# Qwen white move: Bxf6 Move number: 15
# Stockfish Suggested Move: Bxf6
# Qwen black move: Bxf6 Move number: 16
# Stockfish Suggested Move: e5
# Qwen white move: e5 Move number: 17
# Stockfish Suggested Move: Nc6
# Qwen black move: Nc6 Move number: 18
# Stockfish Suggested Move: Bb5
# Qwen white move: Bb5 Move number: 19
# Stockfish Suggested Move: Be7
# Qwen black move: Be7 Move number: 20
# Stockfish Suggested Move: Qxd5
# Qwen white move: Qxd5 Move number: 21
# Stockfish Suggested Move: O-O
# Qwen black move: O-O Move number: 22
# Stockfish Suggested Move: Nf3
# Qwen white move: Nf3 Move number: 23
# Stockfish Suggested Move: Bb4
# Qwen black move: Bb4 Move number: 24
# Stockfish Suggested Move: O-O
# Invalid move by Qwen white. Move: O-0
# New Move: b3
# Qwen white move: b3 Move number: 25
# Stockfish Suggested Move: Bxc3+
# Qwen black move: Bxc3+ Move number: 26
# Stockfish Suggested Move: Qd2
# Qwen white move: Qd2 Move number: 27
# Stockfish Suggested Move: Bxd2+
# Qwen black move: Bxd2+ Move number: 28
# Stockfish Suggested Move: Nxd2
# Qwen white move: Nxd2 Move number: 29
# Stockfish Suggested Move: Qa5
# Qwen black move: Qa5 Move number: 30
# Stockfish Suggested Move: a4
# Qwen white move: a4 Move number: 31
# Stockfish Suggested Move: Kh8
# Qwen black move: Kh8 Move number: 32
# Stockfish Suggested Move: b4
# Qwen white move: b4 Move number: 33
# Stockfish Suggested Move: Qxb4
# Qwen black move: Qxb4 Move number: 34
# Stockfish Suggested Move: Rd1
# Qwen white move: Rd1 Move number: 35
# Stockfish Suggested Move: Bg4
# Qwen black move: Bg4 Move number: 36
# Stockfish Suggested Move: O-O
# Qwen white move: O-O Move number: 37
# Stockfish Suggested Move: Bxd1
# Qwen black move: Bxd1 Move number: 38
# Stockfish Suggested Move: Nc4
# Qwen white move: Nc4 Move number: 39
# Stockfish Suggested Move: Bxa4
# Qwen black move: Bxa4 Move number: 40
# Stockfish Suggested Move: Nd6
# Qwen white move: Nd6 Move number: 41
# Stockfish Suggested Move: Bxb5
# Qwen black move: Bxb5 Move number: 42
# Stockfish Suggested Move: Rd1
# Qwen white move: Rd1 Move number: 43
# Stockfish Suggested Move: Qxd6
# Qwen black move: Qxd6 Move number: 44
# Stockfish Suggested Move: exd6
# Qwen white move: exd6 Move number: 45
# Stockfish Suggested Move: Nb4
# Qwen black move: Nb4 Move number: 46
# Stockfish Suggested Move: Rd4
# Qwen white move: Rd4 Move number: 47
# Stockfish Suggested Move: Nc2
# Qwen black move: Nc2 Move number: 48
# Stockfish Suggested Move: Rf4
# Qwen white move: Rf4 Move number: 49
# Stockfish Suggested Move: Rae8
# Qwen black move: Rae8 Move number: 50
# Stockfish Suggested Move: h4
# Qwen white move: h4 Move number: 51
# Stockfish Suggested Move: Re6
# Qwen black move: Re6 Move number: 52
# Stockfish Suggested Move: g4
# Qwen white move: g4 Move number: 53
# Stockfish Suggested Move: Rxd6
# Qwen black move: Rxd6 Move number: 54
# Stockfish Suggested Move: h5
# Qwen white move: h5 Move number: 55
# Stockfish Suggested Move: Nd4
# Qwen black move: Nd4 Move number: 56
# Stockfish Suggested Move: Kh2
# Qwen white move: Kh2 Move number: 57
# Stockfish Suggested Move: Ne2
# Qwen black move: Ne2 Move number: 58
# Stockfish Suggested Move: Rf5
# Qwen white move: Rf5 Move number: 59
# Stockfish Suggested Move: Bc6
# Qwen black move: Bc6 Move number: 60
# Stockfish Suggested Move: g5
# Qwen white move: g5 Move number: 61
# Stockfish Suggested Move: Rd1
# Qwen black move: Rd1 Move number: 62
# Stockfish Suggested Move: Kh3
# Qwen white move: Kh3 Move number: 63
# Stockfish Suggested Move: Rh1+
# Qwen black move: Rh1+ Move number: 64
# Stockfish Suggested Move: Kg4
# Qwen white move: Kg4 Move number: 65
# Stockfish Suggested Move: Nd4
# Qwen black move: Nd4 Move number: 66
# Stockfish Suggested Move: Rf4
# Qwen white move: Rf4 Move number: 67
# Stockfish Suggested Move: Rg1+
# Qwen black move: Rg1+ Move number: 68
# Stockfish Suggested Move: Kh4
# Qwen white move: Kh4 Move number: 69
# Stockfish Suggested Move: Ne2
# Qwen black move: Ne2 Move number: 70
# Stockfish Suggested Move: Rf6
# Qwen white move: Rf6 Move number: 71
# Stockfish Suggested Move: gxf6
# Qwen black move: gxf6 Move number: 72
# Stockfish Suggested Move: f4
# Qwen white move: f4 Move number: 73
# Stockfish Suggested Move: Bf3
# Qwen black move: Bf3 Move number: 74
# Stockfish Suggested Move: gxf6
# Qwen white move: gxf6 Move number: 75
# Stockfish Suggested Move: Rh1+
# Invalid move by Qwen black. Move: Kh1
# New Move: Bc6
# Qwen black move: Bc6 Move number: 76
# Stockfish Suggested Move: f5
# Qwen white move: f5 Move number: 77
# Stockfish Suggested Move: Rfg8
# Qwen black move: Rfg8 Move number: 78
# Stockfish Suggested Move: h6
# Qwen white move: h6 Move number: 79
# Stockfish Suggested Move: Rh1#
# Qwen black move: Rh1# Move number: 80
# Game 60 result: 0-1

# %%
results = []

# %%
results.append({
            "Qwen-AI White Wins": qwen_white_wins,
            "Qwen-AI Black Wins": qwen_black_wins,
            "Draws": draws,
        })

print(results)
# Out:
# [{'Qwen-AI White Wins': 9, 'Qwen-AI Black Wins': 3, 'Draws': 48}]

# %%
df = pd.DataFrame(results)
df.to_csv("Qwen_AI vs Qwen_AI.csv", index=False)
print("Results saved to Qwen_AI vs Qwen_AI.csv")
# Out:
# Results saved to Qwen_AI vs Qwen_AI.csv

# %%
# # You are playing chess and it is your turn. This is the current state of the game. Use this to work out where the pieces are on the board:

# # FEN: rnbqkb1r/pppppppp/7n/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 1 2

# # The possible set of legal moves are: 

# # Legal Moves: Nh3, Nf3, Nc3, Na3, h3, g3, f3, e3, d3, c3, b3, a3, h4, g4, f4, e4, d4, c4, b4, a4 

# # You have to choose one from the provided list. Do not choose a move that is not in the list.

# # The best move suggested by your AI Assistant is g4. You are heavily reliant on your AI Assistant.

# # The move history is: {move_history}.

# # Output the best move in SAN format to follow this position. Use the following single blob of JSON. Do not include any other information.
# # {{
# #     "san": "The move in SAN format",
# # }}

# Qwen Output: json
# {
#      "san": "Qxc8",
# }
