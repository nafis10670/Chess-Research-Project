# %% [markdown]
# # Stockfish Highest ELO vs. Stockfish 700 ELO

# %%
import chess
from stockfish import Stockfish
from ollama import chat
from ollama import ChatResponse
import json
import random
import pandas as pd
import asyncio

# %%
HIGH_ELO = 3500
LOW_ELO = 1000
NUM_GAMES = 100
AI_USE_US = 80
AI_USE_CN = 80

# %%
stockfish_us = Stockfish()
stockfish_cn = Stockfish()

# %%
cn_wins = 0
us_wins = 0
draws = 0

# %%
async def get_move_with_timeout(stockfish, timeout=15):
    """
    Run stockfish.get_best_move() in a separate thread and wait for a maximum of `timeout` seconds.
    If the call exceeds the timeout, return None.
    """
    try:
        # Use asyncio.to_thread to run the blocking call in a separate thread.
        move = await asyncio.wait_for(asyncio.to_thread(stockfish.get_best_move), timeout)
        return move
    except asyncio.TimeoutError:
        # move = stockfish.get_best_move_time(1000)
        print(f"Timeout: stockfish.get_best_move() took more than 15 seconds.")
        return None

# %%
for game_number in range(1, NUM_GAMES + 1):
    
    move_counter = 0
    num_us = random.randint(1, 100)
    num_cn = random.randint(1, 100)

    if num_us <= AI_USE_US: stockfish_us.update_engine_parameters({"Skill Level": 20, "Threads": 3, "Hash": 2048, "Minimum Thinking Time": 50})
    else: stockfish_us.update_engine_parameters({"Skill Level": 10, "Threads": 3, "Hash": 2048, "Minimum Thinking Time": 50})

    if num_cn <= AI_USE_CN: stockfish_cn.update_engine_parameters({"Skill Level": 20, "Threads": 3, "Hash": 2048, "Minimum Thinking Time": 50})
    else: stockfish_cn.update_engine_parameters({"Skill Level": 10, "Threads": 3, "Hash": 2048, "Minimum Thinking Time": 50})

    print(stockfish_us.get_parameters())
    print(stockfish_cn.get_parameters())

    print(f"Starting game {game_number}...")

    board = chess.Board()

    while not board.is_game_over():
        # Determine which engine to use based on turn
        current_engine = stockfish_us if board.turn == chess.WHITE else stockfish_cn

        # Set the position on the board for the engine
        current_engine.set_fen_position(board.fen())

        # Get the best move from the engine
        best_move = await get_move_with_timeout(current_engine)
        if best_move is None:
            print("Engine failed to provide a move.")
            # if current_engine == stockfish_us:
            #     stockfish_us = Stockfish(parameters={})
            break

        # Apply the move to the board
        print(f"Move by {"US White" if board.turn else "CN Black"}: {best_move}   Move: {move_counter}")
        move = chess.Move.from_uci(best_move)
        board.push(move)
        move_counter += 1

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        us_wins += 1
    elif result == "0-1":
        cn_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n\n")
# Out:
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 1...
# Move by US White: e2e4   Move: 0
# Move by CN Black: c7c5   Move: 1
# Move by US White: g1f3   Move: 2
# Move by CN Black: b8c6   Move: 3
# Move by US White: f1b5   Move: 4
# Move by CN Black: g7g6   Move: 5
# Move by US White: b5c6   Move: 6
# Move by CN Black: b7c6   Move: 7
# Move by US White: e1g1   Move: 8
# Move by CN Black: f8g7   Move: 9
# Move by US White: f1e1   Move: 10
# Move by CN Black: d8c7   Move: 11
# Move by US White: c2c3   Move: 12
# Move by CN Black: d7d6   Move: 13
# Move by US White: d2d4   Move: 14
# Move by CN Black: c5d4   Move: 15
# Move by US White: c3d4   Move: 16
# Move by CN Black: g8f6   Move: 17
# Move by US White: b1c3   Move: 18
# Move by CN Black: c8g4   Move: 19
# Move by US White: c1e3   Move: 20
# Move by CN Black: c7b7   Move: 21
# Move by US White: a1b1   Move: 22
# Move by CN Black: e8g8   Move: 23
# Move by US White: h2h3   Move: 24
# Move by CN Black: g4f3   Move: 25
# Move by US White: d1f3   Move: 26
# Move by CN Black: a7a5   Move: 27
# Move by US White: b2b3   Move: 28
# Move by CN Black: f6d7   Move: 29
# Move by US White: e1c1   Move: 30
# Move by CN Black: c6c5   Move: 31
# Move by US White: d4c5   Move: 32
# Move by CN Black: d7c5   Move: 33
# Move by US White: c3d5   Move: 34
# Move by CN Black: e7e6   Move: 35
# Move by US White: b3b4   Move: 36
# Move by CN Black: c5e4   Move: 37
# Move by US White: d5b6   Move: 38
# Move by CN Black: a8b8   Move: 39
# Move by US White: b4a5   Move: 40
# Move by CN Black: d6d5   Move: 41
# Move by US White: b1b3   Move: 42
# Move by CN Black: b8d8   Move: 43
# Move by US White: b6c8   Move: 44
# Move by CN Black: b7d7   Move: 45
# Move by US White: c8b6   Move: 46
# Move by CN Black: d7b7   Move: 47
# Move by US White: b6c8   Move: 48
# Move by CN Black: b7d7   Move: 49
# Move by US White: c8b6   Move: 50
# Move by CN Black: d7b7   Move: 51
# Move by US White: b6c8   Move: 52
# Move by CN Black: b7d7   Move: 53
# Move by US White: c8b6   Move: 54
# Move by CN Black: d7b7   Move: 55
# Move by US White: a2a4   Move: 56
# Move by CN Black: b7a6   Move: 57
# Move by US White: b3b5   Move: 58
# Move by CN Black: e4c3   Move: 59
# Move by US White: c1c3   Move: 60
# Move by CN Black: g7c3   Move: 61
# Move by US White: e3c5   Move: 62
# Move by CN Black: c3a5   Move: 63
# Move by US White: f3f6   Move: 64
# Move by CN Black: f8e8   Move: 65
# Move by US White: c5d4   Move: 66
# Move by CN Black: e6e5   Move: 67
# Move by US White: d4e5   Move: 68
# Move by CN Black: e8e5   Move: 69
# Move by US White: f6d8   Move: 70
# Move by CN Black: g8g7   Move: 71
# Move by US White: d8b8   Move: 72
# Move by CN Black: e5e1   Move: 73
# Move by US White: g1h2   Move: 74
# Move by CN Black: a5b6   Move: 75
# Move by US White: b8b6   Move: 76
# Move by CN Black: a6b6   Move: 77
# Move by US White: b5b6   Move: 78
# Move by CN Black: e1a1   Move: 79
# Move by US White: b6d6   Move: 80
# Move by CN Black: a1a4   Move: 81
# Move by US White: d6d5   Move: 82
# Move by CN Black: a4b4   Move: 83
# Move by US White: g2g4   Move: 84
# Move by CN Black: b4b7   Move: 85
# Move by US White: d5d2   Move: 86
# Move by CN Black: g6g5   Move: 87
# Move by US White: d2a2   Move: 88
# Move by CN Black: b7b5   Move: 89
# Move by US White: h3h4   Move: 90
# Move by CN Black: h7h6   Move: 91
# Move by US White: a2a3   Move: 92
# Move by CN Black: g5h4   Move: 93
# Move by US White: h2h3   Move: 94
# Move by CN Black: b5b2   Move: 95
# Move by US White: f2f3   Move: 96
# Move by CN Black: b2b1   Move: 97
# Move by US White: h3h4   Move: 98
# Move by CN Black: f7f5   Move: 99
# Move by US White: a3a7   Move: 100
# Move by CN Black: g7g6   Move: 101
# Move by US White: a7a6   Move: 102
# Move by CN Black: g6g7   Move: 103
# Move by US White: g4f5   Move: 104
# Move by CN Black: b1g1   Move: 105
# Move by US White: a6d6   Move: 106
# Move by CN Black: g1g5   Move: 107
# Move by US White: d6g6   Move: 108
# Move by CN Black: g5g6   Move: 109
# Move by US White: f5g6   Move: 110
# Move by CN Black: g7g6   Move: 111
# Move by US White: f3f4   Move: 112
# Move by CN Black: h6h5   Move: 113
# Move by US White: h4g3   Move: 114
# Move by CN Black: g6f5   Move: 115
# Move by US White: g3h4   Move: 116
# Move by CN Black: f5g6   Move: 117
# Move by US White: h4g3   Move: 118
# Move by CN Black: g6f5   Move: 119
# Move by US White: g3h3   Move: 120
# Move by CN Black: f5f4   Move: 121
# Move by US White: h3h4   Move: 122
# Move by CN Black: f4e5   Move: 123
# Move by US White: h4h5   Move: 124
# Game 1 result: 1/2-1/2
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 10, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 2...
# Move by US White: e2e4   Move: 0
# Move by CN Black: e7e6   Move: 1
# Move by US White: d2d4   Move: 2
# Move by CN Black: d7d5   Move: 3
# Move by US White: e4e5   Move: 4
# Move by CN Black: g8e7   Move: 5
# Move by US White: b2b4   Move: 6
# Move by CN Black: b8d7   Move: 7
# Move by US White: c2c3   Move: 8
# Move by CN Black: e7f5   Move: 9
# Move by US White: b1d2   Move: 10
# Move by CN Black: a7a5   Move: 11
# Move by US White: b4b5   Move: 12
# Move by CN Black: c7c5   Move: 13
# Move by US White: b5c6   Move: 14
# Move by CN Black: b7c6   Move: 15
# Move by US White: f1d3   Move: 16
# Move by CN Black: c8a6   Move: 17
# Move by US White: d3f5   Move: 18
# Move by CN Black: e6f5   Move: 19
# Move by US White: g1e2   Move: 20
# Move by CN Black: f8e7   Move: 21
# Move by US White: e1g1   Move: 22
# Move by CN Black: e8g8   Move: 23
# Move by US White: f1e1   Move: 24
# Move by CN Black: f8e8   Move: 25
# Move by US White: d1c2   Move: 26
# Move by CN Black: g7g6   Move: 27
# Move by US White: e2f4   Move: 28
# Move by CN Black: a8c8   Move: 29
# Move by US White: d2f3   Move: 30
# Move by CN Black: d7f8   Move: 31
# Move by US White: a1b1   Move: 32
# Move by CN Black: a6b5   Move: 33
# Move by US White: g2g3   Move: 34
# Move by CN Black: c8b8   Move: 35
# Move by US White: e5e6   Move: 36
# Move by CN Black: f7f6   Move: 37
# Move by US White: h2h4   Move: 38
# Move by CN Black: d8c8   Move: 39
# Move by US White: h4h5   Move: 40
# Move by CN Black: b5a4   Move: 41
# Move by US White: c2d3   Move: 42
# Move by CN Black: b8b1   Move: 43
# Move by US White: d3b1   Move: 44
# Move by CN Black: c8b8   Move: 45
# Move by US White: b1d3   Move: 46
# Move by CN Black: b8b5   Move: 47
# Move by US White: d3d2   Move: 48
# Move by CN Black: g6g5   Move: 49
# Move by US White: f4d3   Move: 50
# Move by CN Black: h7h6   Move: 51
# Move by US White: d3b2   Move: 52
# Move by CN Black: e7a3   Move: 53
# Move by US White: b2a4   Move: 54
# Move by CN Black: b5a4   Move: 55
# Move by US White: c1a3   Move: 56
# Move by CN Black: a4a3   Move: 57
# Move by US White: d2d3   Move: 58
# Move by CN Black: f5f4   Move: 59
# Move by US White: g3f4   Move: 60
# Move by CN Black: e8e6   Move: 61
# Move by US White: e1e6   Move: 62
# Move by CN Black: f8e6   Move: 63
# Move by US White: d3g6   Move: 64
# Move by CN Black: e6g7   Move: 65
# Move by US White: f4g5   Move: 66
# Move by CN Black: f6g5   Move: 67
# Move by US White: g6h6   Move: 68
# Move by CN Black: a3c3   Move: 69
# Move by US White: g1g2   Move: 70
# Move by CN Black: g5g4   Move: 71
# Move by US White: f3g5   Move: 72
# Move by CN Black: c3c2   Move: 73
# Move by US White: h6f6   Move: 74
# Move by CN Black: c2f5   Move: 75
# Move by US White: f6d8   Move: 76
# Move by CN Black: f5f8   Move: 77
# Move by US White: d8c7   Move: 78
# Move by CN Black: g4g3   Move: 79
# Move by US White: f2f3   Move: 80
# Move by CN Black: f8f5   Move: 81
# Move by US White: h5h6   Move: 82
# Move by CN Black: f5g5   Move: 83
# Move by US White: c7g7   Move: 84
# Move by CN Black: g5g7   Move: 85
# Move by US White: h6g7   Move: 86
# Move by CN Black: g8g7   Move: 87
# Move by US White: g2g3   Move: 88
# Move by CN Black: g7f7   Move: 89
# Move by US White: g3g4   Move: 90
# Move by CN Black: a5a4   Move: 91
# Move by US White: g4f5   Move: 92
# Move by CN Black: a4a3   Move: 93
# Move by US White: f5e5   Move: 94
# Move by CN Black: f7e7   Move: 95
# Move by US White: f3f4   Move: 96
# Move by CN Black: e7d7   Move: 97
# Move by US White: f4f5   Move: 98
# Move by CN Black: d7d8   Move: 99
# Move by US White: e5d6   Move: 100
# Move by CN Black: d8c8   Move: 101
# Move by US White: f5f6   Move: 102
# Move by CN Black: c8b7   Move: 103
# Move by US White: f6f7   Move: 104
# Move by CN Black: b7b6   Move: 105
# Move by US White: f7f8q   Move: 106
# Move by CN Black: c6c5   Move: 107
# Move by US White: f8b8   Move: 108
# Move by CN Black: b6a5   Move: 109
# Move by US White: d6c5   Move: 110
# Move by CN Black: a5a6   Move: 111
# Move by US White: b8b6   Move: 112
# Game 2 result: 1-0
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 3...
# Move by US White: e2e4   Move: 0
# Move by CN Black: e7e5   Move: 1
# Move by US White: g1f3   Move: 2
# Move by CN Black: b8c6   Move: 3
# Move by US White: f1b5   Move: 4
# Move by CN Black: a7a6   Move: 5
# Move by US White: b5a4   Move: 6
# Move by CN Black: g8f6   Move: 7
# Move by US White: e1g1   Move: 8
# Move by CN Black: f8e7   Move: 9
# Move by US White: f1e1   Move: 10
# Move by CN Black: b7b5   Move: 11
# Move by US White: a4b3   Move: 12
# Move by CN Black: e8g8   Move: 13
# Move by US White: c2c3   Move: 14
# Move by CN Black: c6a5   Move: 15
# Move by US White: b3c2   Move: 16
# Move by CN Black: d7d5   Move: 17
# Move by US White: d2d4   Move: 18
# Move by CN Black: d5e4   Move: 19
# Move by US White: f3e5   Move: 20
# Move by CN Black: c7c5   Move: 21
# Move by US White: c1e3   Move: 22
# Move by CN Black: c8b7   Move: 23
# Move by US White: b1d2   Move: 24
# Move by CN Black: a8c8   Move: 25
# Move by US White: d1e2   Move: 26
# Move by CN Black: e7d6   Move: 27
# Move by US White: a1d1   Move: 28
# Move by CN Black: d8e7   Move: 29
# Move by US White: f2f4   Move: 30
# Move by CN Black: e4f3   Move: 31
# Move by US White: d2f3   Move: 32
# Move by CN Black: a5c4   Move: 33
# Move by US White: e5c4   Move: 34
# Move by CN Black: b5c4   Move: 35
# Move by US White: e2c4   Move: 36
# Move by CN Black: b7f3   Move: 37
# Move by US White: g2f3   Move: 38
# Move by CN Black: c5d4   Move: 39
# Move by US White: c4d4   Move: 40
# Move by CN Black: d6c5   Move: 41
# Move by US White: d4d2   Move: 42
# Move by CN Black: c8d8   Move: 43
# Move by US White: e3c5   Move: 44
# Move by CN Black: e7c5   Move: 45
# Move by US White: d2e3   Move: 46
# Move by CN Black: c5c6   Move: 47
# Move by US White: g1g2   Move: 48
# Move by CN Black: d8d1   Move: 49
# Move by US White: c2d1   Move: 50
# Move by CN Black: f8e8   Move: 51
# Move by US White: e3d2   Move: 52
# Move by CN Black: e8e1   Move: 53
# Move by US White: d2e1   Move: 54
# Move by CN Black: c6d5   Move: 55
# Move by US White: d1b3   Move: 56
# Move by CN Black: d5g5   Move: 57
# Move by US White: e1g3   Move: 58
# Move by CN Black: g5d2   Move: 59
# Move by US White: g3f2   Move: 60
# Move by CN Black: d2g5   Move: 61
# Move by US White: g2f1   Move: 62
# Move by CN Black: g5c1   Move: 63
# Move by US White: f2e1   Move: 64
# Move by CN Black: c1f4   Move: 65
# Move by US White: e1g3   Move: 66
# Move by CN Black: f4c1   Move: 67
# Move by US White: g3e1   Move: 68
# Move by CN Black: c1f4   Move: 69
# Move by US White: f1g2   Move: 70
# Move by CN Black: g7g6   Move: 71
# Move by US White: e1e2   Move: 72
# Move by CN Black: a6a5   Move: 73
# Move by US White: e2c4   Move: 74
# Move by CN Black: f4d2   Move: 75
# Move by US White: g2f1   Move: 76
# Move by CN Black: d2c1   Move: 77
# Move by US White: f1g2   Move: 78
# Move by CN Black: c1d2   Move: 79
# Move by US White: g2h3   Move: 80
# Move by CN Black: d2d7   Move: 81
# Move by US White: h3g2   Move: 82
# Move by CN Black: d7d2   Move: 83
# Move by US White: g2f1   Move: 84
# Move by CN Black: d2c1   Move: 85
# Move by US White: f1e2   Move: 86
# Move by CN Black: c1b2   Move: 87
# Move by US White: e2d3   Move: 88
# Move by CN Black: b2b1   Move: 89
# Move by US White: d3d4   Move: 90
# Move by CN Black: b1g1   Move: 91
# Move by US White: d4e5   Move: 92
# Move by CN Black: g1h2   Move: 93
# Move by US White: f3f4   Move: 94
# Move by CN Black: f6g4   Move: 95
# Move by US White: e5d6   Move: 96
# Move by CN Black: g4h6   Move: 97
# Move by US White: d6c5   Move: 98
# Move by CN Black: h2f2   Move: 99
# Move by US White: c5b5   Move: 100
# Move by CN Black: f2a7   Move: 101
# Move by US White: c4c5   Move: 102
# Move by CN Black: a7b8   Move: 103
# Move by US White: b5a5   Move: 104
# Move by CN Black: h6f5   Move: 105
# Move by US White: c5c6   Move: 106
# Move by CN Black: g8g7   Move: 107
# Move by US White: c6d7   Move: 108
# Move by CN Black: h7h5   Move: 109
# Move by US White: d7f7   Move: 110
# Move by CN Black: g7h6   Move: 111
# Move by US White: f7f6   Move: 112
# Move by CN Black: b8f4   Move: 113
# Move by US White: a2a4   Move: 114
# Move by CN Black: h5h4   Move: 115
# Move by US White: f6h8   Move: 116
# Move by CN Black: h6g5   Move: 117
# Move by US White: h8d8   Move: 118
# Move by CN Black: g5g4   Move: 119
# Move by US White: d8d1   Move: 120
# Move by CN Black: g4g5   Move: 121
# Move by US White: d1d8   Move: 122
# Move by CN Black: g5g4   Move: 123
# Move by US White: d8d1   Move: 124
# Move by CN Black: g4g5   Move: 125
# Move by US White: d1d8   Move: 126
# Move by CN Black: g5g4   Move: 127
# Move by US White: d8d1   Move: 128
# Move by CN Black: g4h3   Move: 129
# Move by US White: b3d5   Move: 130
# Move by CN Black: f4c7   Move: 131
# Move by US White: a5b4   Move: 132
# Move by CN Black: c7b6   Move: 133
# Move by US White: b4a3   Move: 134
# Move by CN Black: f5e3   Move: 135
# Move by US White: d1f3   Move: 136
# Move by CN Black: h3h2   Move: 137
# Move by US White: f3f2   Move: 138
# Move by CN Black: h2h3   Move: 139
# Move by US White: f2f3   Move: 140
# Move by CN Black: h3h2   Move: 141
# Move by US White: f3f2   Move: 142
# Move by CN Black: h2h3   Move: 143
# Move by US White: f2f3   Move: 144
# Move by CN Black: h3h2   Move: 145
# Move by US White: f3f2   Move: 146
# Move by CN Black: h2h3   Move: 147
# Move by US White: f2f3   Move: 148
# Move by CN Black: h3h2   Move: 149
# Move by US White: f3e2   Move: 150
# Move by CN Black: h2g3   Move: 151
# Move by US White: e2f3   Move: 152
# Move by CN Black: g3h2   Move: 153
# Game 3 result: 1/2-1/2
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 4...
# Move by US White: e2e4   Move: 0
# Move by CN Black: e7e5   Move: 1
# Move by US White: g1f3   Move: 2
# Move by CN Black: b8c6   Move: 3
# Move by US White: f1b5   Move: 4
# Move by CN Black: a7a6   Move: 5
# Move by US White: b5a4   Move: 6
# Move by CN Black: g8f6   Move: 7
# Move by US White: e1g1   Move: 8
# Move by CN Black: f6e4   Move: 9
# Move by US White: d2d4   Move: 10
# Move by CN Black: b7b5   Move: 11
# Move by US White: a4b3   Move: 12
# Move by CN Black: d7d5   Move: 13
# Move by US White: d4e5   Move: 14
# Move by CN Black: c8e6   Move: 15
# Move by US White: c2c3   Move: 16
# Move by CN Black: f8c5   Move: 17
# Move by US White: b1d2   Move: 18
# Move by CN Black: e8g8   Move: 19
# Move by US White: b3c2   Move: 20
# Move by CN Black: e6f5   Move: 21
# Move by US White: d2b3   Move: 22
# Move by CN Black: f5g6   Move: 23
# Move by US White: f3d4   Move: 24
# Move by CN Black: c5d4   Move: 25
# Move by US White: b3d4   Move: 26
# Move by CN Black: d8d7   Move: 27
# Move by US White: f2f4   Move: 28
# Move by CN Black: c6d4   Move: 29
# Move by US White: c3d4   Move: 30
# Move by CN Black: f7f6   Move: 31
# Move by US White: c1e3   Move: 32
# Move by CN Black: a8d8   Move: 33
# Move by US White: d1e1   Move: 34
# Move by CN Black: e4g3   Move: 35
# Move by US White: e1g3   Move: 36
# Move by CN Black: g6c2   Move: 37
# Move by US White: a1c1   Move: 38
# Move by CN Black: c2d3   Move: 39
# Move by US White: f1f2   Move: 40
# Move by CN Black: d8c8   Move: 41
# Move by US White: e3d2   Move: 42
# Move by CN Black: d3e4   Move: 43
# Move by US White: d2b4   Move: 44
# Move by CN Black: f8f7   Move: 45
# Move by US White: h2h3   Move: 46
# Move by CN Black: c8e8   Move: 47
# Move by US White: b4a5   Move: 48
# Move by CN Black: c7c6   Move: 49
# Move by US White: a5b4   Move: 50
# Move by CN Black: f6e5   Move: 51
# Move by US White: f4e5   Move: 52
# Move by CN Black: f7f2   Move: 53
# Move by US White: g3f2   Move: 54
# Move by CN Black: h7h6   Move: 55
# Move by US White: g1h2   Move: 56
# Move by CN Black: a6a5   Move: 57
# Move by US White: b4c5   Move: 58
# Move by CN Black: d7e6   Move: 59
# Move by US White: c5d6   Move: 60
# Move by CN Black: g8h7   Move: 61
# Move by US White: f2f4   Move: 62
# Move by CN Black: e6d7   Move: 63
# Move by US White: c1f1   Move: 64
# Move by CN Black: e4g6   Move: 65
# Move by US White: f1f2   Move: 66
# Move by CN Black: b5b4   Move: 67
# Move by US White: f2f1   Move: 68
# Move by CN Black: d7e6   Move: 69
# Move by US White: f4f3   Move: 70
# Move by CN Black: h7g8   Move: 71
# Move by US White: f3g3   Move: 72
# Move by CN Black: g6f5   Move: 73
# Move by US White: f1f2   Move: 74
# Move by CN Black: e8a8   Move: 75
# Move by US White: g3f4   Move: 76
# Move by CN Black: f5e4   Move: 77
# Move by US White: f4c1   Move: 78
# Move by CN Black: e6d7   Move: 79
# Move by US White: c1c5   Move: 80
# Move by CN Black: e4f5   Move: 81
# Move by US White: a2a3   Move: 82
# Move by CN Black: b4a3   Move: 83
# Move by US White: b2a3   Move: 84
# Move by CN Black: a5a4   Move: 85
# Move by US White: c5b6   Move: 86
# Move by CN Black: g8h7   Move: 87
# Move by US White: d6b4   Move: 88
# Move by CN Black: f5e4   Move: 89
# Move by US White: b4c5   Move: 90
# Move by CN Black: e4g6   Move: 91
# Move by US White: c5b4   Move: 92
# Move by CN Black: g6e4   Move: 93
# Move by US White: b6c5   Move: 94
# Move by CN Black: a8e8   Move: 95
# Move by US White: c5d6   Move: 96
# Move by CN Black: d7c8   Move: 97
# Move by US White: h2g1   Move: 98
# Move by CN Black: e4g6   Move: 99
# Move by US White: g1h2   Move: 100
# Move by CN Black: e8e6   Move: 101
# Move by US White: f2f8   Move: 102
# Move by CN Black: e6e8   Move: 103
# Move by US White: f8f3   Move: 104
# Move by CN Black: g6e4   Move: 105
# Move by US White: f3f7   Move: 106
# Move by CN Black: e8e6   Move: 107
# Move by US White: f7f8   Move: 108
# Move by CN Black: e6e8   Move: 109
# Move by US White: f8f7   Move: 110
# Move by CN Black: e8e6   Move: 111
# Move by US White: f7f8   Move: 112
# Move by CN Black: e6e8   Move: 113
# Move by US White: f8f1   Move: 114
# Move by CN Black: e8e6   Move: 115
# Move by US White: f1f8   Move: 116
# Move by CN Black: e6e8   Move: 117
# Move by US White: f8f7   Move: 118
# Move by CN Black: e8e6   Move: 119
# Move by US White: f7f8   Move: 120
# Move by CN Black: e6e8   Move: 121
# Move by US White: f8f7   Move: 122
# Move by CN Black: e8e6   Move: 123
# Move by US White: f7f8   Move: 124
# Game 4 result: 1/2-1/2
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 5...
# Move by US White: d2d4   Move: 0
# Move by CN Black: g8f6   Move: 1
# Move by US White: c2c4   Move: 2
# Move by CN Black: e7e6   Move: 3
# Move by US White: g1f3   Move: 4
# Move by CN Black: d7d5   Move: 5
# Move by US White: b1c3   Move: 6
# Move by CN Black: c7c5   Move: 7
# Move by US White: c4d5   Move: 8
# Move by CN Black: f6d5   Move: 9
# Move by US White: e2e4   Move: 10
# Move by CN Black: d5c3   Move: 11
# Move by US White: b2c3   Move: 12
# Move by CN Black: c5d4   Move: 13
# Move by US White: c3d4   Move: 14
# Move by CN Black: f8b4   Move: 15
# Move by US White: c1d2   Move: 16
# Move by CN Black: b4d2   Move: 17
# Move by US White: d1d2   Move: 18
# Move by CN Black: e8g8   Move: 19
# Move by US White: f1c4   Move: 20
# Move by CN Black: b8d7   Move: 21
# Move by US White: e1g1   Move: 22
# Move by CN Black: b7b6   Move: 23
# Move by US White: d4d5   Move: 24
# Move by CN Black: d7c5   Move: 25
# Move by US White: f1e1   Move: 26
# Move by CN Black: e6d5   Move: 27
# Move by US White: e4d5   Move: 28
# Move by CN Black: d8d6   Move: 29
# Move by US White: d2d4   Move: 30
# Move by CN Black: c5d7   Move: 31
# Move by US White: a1d1   Move: 32
# Move by CN Black: d7f6   Move: 33
# Move by US White: f3e5   Move: 34
# Move by CN Black: c8b7   Move: 35
# Move by US White: e1e3   Move: 36
# Move by CN Black: b6b5   Move: 37
# Move by US White: c4b3   Move: 38
# Move by CN Black: a7a5   Move: 39
# Move by US White: a2a4   Move: 40
# Move by CN Black: b5a4   Move: 41
# Move by US White: d4a4   Move: 42
# Move by CN Black: b7d5   Move: 43
# Move by US White: b3d5   Move: 44
# Move by CN Black: f6d5   Move: 45
# Move by US White: e5c6   Move: 46
# Move by CN Black: f8e8   Move: 47
# Move by US White: e3e8   Move: 48
# Move by CN Black: a8e8   Move: 49
# Move by US White: h2h4   Move: 50
# Move by CN Black: d6e6   Move: 51
# Move by US White: a4c4   Move: 52
# Move by CN Black: d5f4   Move: 53
# Move by US White: c4e6   Move: 54
# Move by CN Black: f4e6   Move: 55
# Move by US White: c6a5   Move: 56
# Move by CN Black: e8c8   Move: 57
# Move by US White: g2g3   Move: 58
# Move by CN Black: g8f8   Move: 59
# Move by US White: d1d5   Move: 60
# Move by CN Black: f8e7   Move: 61
# Move by US White: a5b7   Move: 62
# Move by CN Black: g7g6   Move: 63
# Move by US White: b7a5   Move: 64
# Move by CN Black: c8c5   Move: 65
# Move by US White: d5c5   Move: 66
# Move by CN Black: e6c5   Move: 67
# Move by US White: g1f1   Move: 68
# Move by CN Black: c5e6   Move: 69
# Move by US White: f1e2   Move: 70
# Move by CN Black: g6g5   Move: 71
# Move by US White: h4g5   Move: 72
# Move by CN Black: e6g5   Move: 73
# Move by US White: a5c4   Move: 74
# Move by CN Black: h7h5   Move: 75
# Move by US White: e2e3   Move: 76
# Move by CN Black: e7e6   Move: 77
# Move by US White: c4b2   Move: 78
# Move by CN Black: e6f5   Move: 79
# Move by US White: f2f3   Move: 80
# Move by CN Black: g5e6   Move: 81
# Move by US White: b2d3   Move: 82
# Move by CN Black: e6g7   Move: 83
# Move by US White: d3f4   Move: 84
# Move by CN Black: f5e5   Move: 85
# Move by US White: f4d3   Move: 86
# Move by CN Black: e5d5   Move: 87
# Move by US White: d3e1   Move: 88
# Move by CN Black: f7f6   Move: 89
# Move by US White: e3f4   Move: 90
# Move by CN Black: d5d4   Move: 91
# Move by US White: e1g2   Move: 92
# Move by CN Black: d4d3   Move: 93
# Move by US White: g3g4   Move: 94
# Move by CN Black: d3e2   Move: 95
# Move by US White: g4h5   Move: 96
# Move by CN Black: g7h5   Move: 97
# Move by US White: f4g4   Move: 98
# Move by CN Black: e2f2   Move: 99
# Move by US White: g2h4   Move: 100
# Move by CN Black: h5g7   Move: 101
# Move by US White: h4g6   Move: 102
# Move by CN Black: g7f5   Move: 103
# Move by US White: g4f4   Move: 104
# Move by CN Black: f5d4   Move: 105
# Move by US White: g6h4   Move: 106
# Move by CN Black: f2e2   Move: 107
# Move by US White: f4e4   Move: 108
# Move by CN Black: d4f3   Move: 109
# Move by US White: e4f5   Move: 110
# Move by CN Black: f3h4   Move: 111
# Move by US White: f5f6   Move: 112
# Game 5 result: 1/2-1/2
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 6...
# Move by US White: e2e4   Move: 0
# Move by CN Black: c7c5   Move: 1
# Move by US White: g1f3   Move: 2
# Move by CN Black: b8c6   Move: 3
# Move by US White: f1b5   Move: 4
# Move by CN Black: g7g6   Move: 5
# Move by US White: b5c6   Move: 6
# Move by CN Black: b7c6   Move: 7
# Move by US White: e1g1   Move: 8
# Move by CN Black: f8g7   Move: 9
# Move by US White: f1e1   Move: 10
# Move by CN Black: d7d6   Move: 11
# Move by US White: e4e5   Move: 12
# Move by CN Black: g8h6   Move: 13
# Move by US White: e5d6   Move: 14
# Move by CN Black: d8d6   Move: 15
# Move by US White: d2d3   Move: 16
# Move by CN Black: c8g4   Move: 17
# Move by US White: b1d2   Move: 18
# Move by CN Black: h6f5   Move: 19
# Move by US White: e1e4   Move: 20
# Move by CN Black: g4f3   Move: 21
# Move by US White: d2f3   Move: 22
# Move by CN Black: e8g8   Move: 23
# Move by US White: c1f4   Move: 24
# Move by CN Black: d6d7   Move: 25
# Move by US White: f4e5   Move: 26
# Move by CN Black: f7f6   Move: 27
# Move by US White: e5c3   Move: 28
# Move by CN Black: e7e5   Move: 29
# Move by US White: e4c4   Move: 30
# Move by CN Black: d7d5   Move: 31
# Move by US White: f3d2   Move: 32
# Move by CN Black: f5d6   Move: 33
# Move by US White: c4a4   Move: 34
# Move by CN Black: f6f5   Move: 35
# Move by US White: d1e2   Move: 36
# Move by CN Black: d6b5   Move: 37
# Move by US White: d2b3   Move: 38
# Move by CN Black: f8e8   Move: 39
# Move by US White: a1e1   Move: 40
# Move by CN Black: b5c3   Move: 41
# Move by US White: b2c3   Move: 42
# Move by CN Black: a7a5   Move: 43
# Move by US White: h2h4   Move: 44
# Move by CN Black: g7f8   Move: 45
# Move by US White: g2g3   Move: 46
# Move by CN Black: c5c4   Move: 47
# Move by US White: a4c4   Move: 48
# Move by CN Black: a5a4   Move: 49
# Move by US White: b3d2   Move: 50
# Move by CN Black: a4a3   Move: 51
# Move by US White: h4h5   Move: 52
# Move by CN Black: e8e6   Move: 53
# Move by US White: d2f1   Move: 54
# Move by CN Black: d5b5   Move: 55
# Move by US White: h5g6   Move: 56
# Move by CN Black: h7g6   Move: 57
# Move by US White: g3g4   Move: 58
# Move by CN Black: a8a7   Move: 59
# Move by US White: f1g3   Move: 60
# Move by CN Black: e5e4   Move: 61
# Move by US White: c4d4   Move: 62
# Move by CN Black: a7e7   Move: 63
# Move by US White: g4f5   Move: 64
# Move by CN Black: e4d3   Move: 65
# Move by US White: e2e6   Move: 66
# Move by CN Black: e7e6   Move: 67
# Move by US White: f5e6   Move: 68
# Move by CN Black: d3c2   Move: 69
# Move by US White: g1h2   Move: 70
# Move by CN Black: b5b1   Move: 71
# Move by US White: e1e3   Move: 72
# Move by CN Black: c2c1q   Move: 73
# Move by US White: e3e5   Move: 74
# Move by CN Black: c1g1   Move: 75
# Move by US White: h2h3   Move: 76
# Move by CN Black: b1b8   Move: 77
# Move by US White: e5g5   Move: 78
# Move by CN Black: b8e8   Move: 79
# Move by US White: d4e4   Move: 80
# Move by CN Black: f8e7   Move: 81
# Move by US White: g5g4   Move: 82
# Move by CN Black: g1a1   Move: 83
# Move by US White: e4e5   Move: 84
# Move by CN Black: a1c3   Move: 85
# Move by US White: e5e4   Move: 86
# Move by CN Black: c3f6   Move: 87
# Move by US White: g4f4   Move: 88
# Move by CN Black: f6b2   Move: 89
# Move by US White: e4e2   Move: 90
# Move by CN Black: b2h8   Move: 91
# Move by US White: h3g2   Move: 92
# Move by CN Black: e8a8   Move: 93
# Move by US White: e2e4   Move: 94
# Move by CN Black: c6c5   Move: 95
# Move by US White: f4g4   Move: 96
# Move by CN Black: h8f6   Move: 97
# Move by US White: g2g1   Move: 98
# Move by CN Black: a8e4   Move: 99
# Move by US White: g4e4   Move: 100
# Move by CN Black: f6a1   Move: 101
# Move by US White: g3f1   Move: 102
# Move by CN Black: a1a2   Move: 103
# Move by US White: e4a4   Move: 104
# Move by CN Black: a2b3   Move: 105
# Move by US White: a4a7   Move: 106
# Move by CN Black: a3a2   Move: 107
# Move by US White: a7e7   Move: 108
# Move by CN Black: b3a4   Move: 109
# Move by US White: e7b7   Move: 110
# Move by CN Black: g8f8   Move: 111
# Move by US White: e6e7   Move: 112
# Move by CN Black: f8e8   Move: 113
# Move by US White: b7b8   Move: 114
# Move by CN Black: e8e7   Move: 115
# Move by US White: b8b7   Move: 116
# Move by CN Black: e7e8   Move: 117
# Move by US White: b7b8   Move: 118
# Move by CN Black: e8d7   Move: 119
# Move by US White: b8g8   Move: 120
# Move by CN Black: a2a1q   Move: 121
# Move by US White: g8g7   Move: 122
# Move by CN Black: a1g7   Move: 123
# Move by US White: f1g3   Move: 124
# Move by CN Black: g7a1   Move: 125
# Move by US White: g1g2   Move: 126
# Move by CN Black: a4a8   Move: 127
# Move by US White: f2f3   Move: 128
# Move by CN Black: a8a2   Move: 129
# Move by US White: g2h3   Move: 130
# Move by CN Black: a1h8   Move: 131
# Move by US White: h3g4   Move: 132
# Move by CN Black: a2g2   Move: 133
# Move by US White: g4f4   Move: 134
# Move by CN Black: h8h4   Move: 135
# Move by US White: f4e5   Move: 136
# Move by CN Black: h4d4   Move: 137
# Game 6 result: 0-1
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 7...
# Move by US White: e2e4   Move: 0
# Move by CN Black: c7c5   Move: 1
# Move by US White: b1c3   Move: 2
# Move by CN Black: d7d6   Move: 3
# Move by US White: g1e2   Move: 4
# Move by CN Black: g8f6   Move: 5
# Move by US White: d2d4   Move: 6
# Move by CN Black: c5d4   Move: 7
# Move by US White: e2d4   Move: 8
# Move by CN Black: a7a6   Move: 9
# Move by US White: d1f3   Move: 10
# Move by CN Black: g7g6   Move: 11
# Move by US White: c1e3   Move: 12
# Move by CN Black: f8g7   Move: 13
# Move by US White: h2h3   Move: 14
# Move by CN Black: e8g8   Move: 15
# Move by US White: a1d1   Move: 16
# Move by CN Black: c8d7   Move: 17
# Move by US White: f1d3   Move: 18
# Move by CN Black: b8c6   Move: 19
# Move by US White: e1g1   Move: 20
# Move by CN Black: c6e5   Move: 21
# Move by US White: f3e2   Move: 22
# Move by CN Black: b7b5   Move: 23
# Move by US White: a2a3   Move: 24
# Move by CN Black: d8b8   Move: 25
# Move by US White: f2f4   Move: 26
# Move by CN Black: e5d3   Move: 27
# Move by US White: c2d3   Move: 28
# Move by CN Black: a6a5   Move: 29
# Move by US White: b2b4   Move: 30
# Move by CN Black: a5b4   Move: 31
# Move by US White: a3b4   Move: 32
# Move by CN Black: f6h5   Move: 33
# Move by US White: e2f3   Move: 34
# Move by CN Black: a8a3   Move: 35
# Move by US White: d1c1   Move: 36
# Move by CN Black: e7e5   Move: 37
# Move by US White: f4e5   Move: 38
# Move by CN Black: d6e5   Move: 39
# Move by US White: d4e2   Move: 40
# Move by CN Black: d7e6   Move: 41
# Move by US White: c1a1   Move: 42
# Move by CN Black: a3a1   Move: 43
# Move by US White: f1a1   Move: 44
# Move by CN Black: f8d8   Move: 45
# Move by US White: e3a7   Move: 46
# Move by CN Black: b8c7   Move: 47
# Move by US White: a7c5   Move: 48
# Move by CN Black: g7f8   Move: 49
# Move by US White: c5f8   Move: 50
# Move by CN Black: d8f8   Move: 51
# Move by US White: a1a5   Move: 52
# Move by CN Black: h5f4   Move: 53
# Move by US White: a5b5   Move: 54
# Move by CN Black: f4e2   Move: 55
# Move by US White: c3e2   Move: 56
# Move by CN Black: f8b8   Move: 57
# Move by US White: b5c5   Move: 58
# Move by CN Black: c7d6   Move: 59
# Move by US White: f3f6   Move: 60
# Move by CN Black: d6d3   Move: 61
# Move by US White: c5e5   Move: 62
# Move by CN Black: d3e2   Move: 63
# Move by US White: e5e6   Move: 64
# Move by CN Black: e2d1   Move: 65
# Move by US White: g1h2   Move: 66
# Move by CN Black: f7e6   Move: 67
# Move by US White: f6e6   Move: 68
# Move by CN Black: g8f8   Move: 69
# Move by US White: e6f6   Move: 70
# Move by CN Black: f8g8   Move: 71
# Move by US White: f6e6   Move: 72
# Move by CN Black: g8f8   Move: 73
# Move by US White: e6f6   Move: 74
# Move by CN Black: f8g8   Move: 75
# Move by US White: f6e6   Move: 76
# Move by CN Black: g8f8   Move: 77
# Move by US White: e6f6   Move: 78
# Move by CN Black: f8g8   Move: 79
# Move by US White: f6e6   Move: 80
# Move by CN Black: g8f8   Move: 81
# Move by US White: e6f6   Move: 82
# Move by CN Black: f8g8   Move: 83
# Move by US White: f6e6   Move: 84
# Game 7 result: 1/2-1/2
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 8...
# Move by US White: e2e4   Move: 0
# Move by CN Black: c7c5   Move: 1
# Move by US White: g1f3   Move: 2
# Move by CN Black: b8c6   Move: 3
# Move by US White: f1b5   Move: 4
# Move by CN Black: g7g6   Move: 5
# Move by US White: b5c6   Move: 6
# Move by CN Black: b7c6   Move: 7
# Move by US White: e1g1   Move: 8
# Move by CN Black: f8g7   Move: 9
# Move by US White: f1e1   Move: 10
# Move by CN Black: d7d6   Move: 11
# Move by US White: e4e5   Move: 12
# Move by CN Black: d6e5   Move: 13
# Move by US White: f3e5   Move: 14
# Move by CN Black: d8c7   Move: 15
# Move by US White: d2d4   Move: 16
# Move by CN Black: c5d4   Move: 17
# Move by US White: d1d4   Move: 18
# Move by CN Black: g8f6   Move: 19
# Move by US White: d4c5   Move: 20
# Move by CN Black: e8g8   Move: 21
# Move by US White: b1c3   Move: 22
# Move by CN Black: c8e6   Move: 23
# Move by US White: c1f4   Move: 24
# Move by CN Black: f8e8   Move: 25
# Move by US White: c3b5   Move: 26
# Move by CN Black: c7b7   Move: 27
# Move by US White: b5d4   Move: 28
# Move by CN Black: f6d7   Move: 29
# Move by US White: c5c6   Move: 30
# Move by CN Black: b7b2   Move: 31
# Move by US White: d4e6   Move: 32
# Move by CN Black: d7e5   Move: 33
# Move by US White: c6a6   Move: 34
# Move by CN Black: f7e6   Move: 35
# Move by US White: f4e5   Move: 36
# Move by CN Black: g7e5   Move: 37
# Move by US White: a6e6   Move: 38
# Move by CN Black: g8f8   Move: 39
# Move by US White: a1b1   Move: 40
# Move by CN Black: b2c2   Move: 41
# Move by US White: e6e5   Move: 42
# Move by CN Black: c2a2   Move: 43
# Move by US White: h2h4   Move: 44
# Move by CN Black: f8g8   Move: 45
# Move by US White: h4h5   Move: 46
# Move by CN Black: e8f8   Move: 47
# Move by US White: f2f3   Move: 48
# Move by CN Black: a2c4   Move: 49
# Move by US White: h5h6   Move: 50
# Move by CN Black: f8f7   Move: 51
# Move by US White: e1e4   Move: 52
# Move by CN Black: c4c6   Move: 53
# Move by US White: e5a5   Move: 54
# Move by CN Black: e7e6   Move: 55
# Move by US White: a5e5   Move: 56
# Move by CN Black: a7a5   Move: 57
# Move by US White: b1d1   Move: 58
# Move by CN Black: a5a4   Move: 59
# Move by US White: e4d4   Move: 60
# Move by CN Black: c6e8   Move: 61
# Move by US White: d4d6   Move: 62
# Move by CN Black: a4a3   Move: 63
# Move by US White: d6e6   Move: 64
# Move by CN Black: e8a4   Move: 65
# Move by US White: d1d4   Move: 66
# Move by CN Black: a4a7   Move: 67
# Move by US White: g1f1   Move: 68
# Move by CN Black: a3a2   Move: 69
# Move by US White: e6e8   Move: 70
# Move by CN Black: a8e8   Move: 71
# Move by US White: e5e8   Move: 72
# Move by CN Black: f7f8   Move: 73
# Move by US White: e8e6   Move: 74
# Move by CN Black: a7f7   Move: 75
# Move by US White: e6f7   Move: 76
# Move by CN Black: g8f7   Move: 77
# Move by US White: d4a4   Move: 78
# Move by CN Black: f7f6   Move: 79
# Move by US White: f1f2   Move: 80
# Move by CN Black: f6g5   Move: 81
# Move by US White: a4a2   Move: 82
# Move by CN Black: g5h6   Move: 83
# Move by US White: f2g3   Move: 84
# Move by CN Black: f8f5   Move: 85
# Move by US White: a2a3   Move: 86
# Move by CN Black: f5f7   Move: 87
# Move by US White: f3f4   Move: 88
# Move by CN Black: h6g7   Move: 89
# Move by US White: a3a2   Move: 90
# Move by CN Black: f7b7   Move: 91
# Move by US White: g3h3   Move: 92
# Move by CN Black: b7f7   Move: 93
# Move by US White: h3g4   Move: 94
# Move by CN Black: h7h6   Move: 95
# Move by US White: g2g3   Move: 96
# Move by CN Black: f7f6   Move: 97
# Move by US White: g4f3   Move: 98
# Move by CN Black: g6g5   Move: 99
# Move by US White: f3g4   Move: 100
# Move by CN Black: g7g6   Move: 101
# Move by US White: f4g5   Move: 102
# Move by CN Black: h6g5   Move: 103
# Move by US White: a2a5   Move: 104
# Move by CN Black: g6h6   Move: 105
# Move by US White: a5a2   Move: 106
# Move by CN Black: f6b6   Move: 107
# Move by US White: a2a4   Move: 108
# Move by CN Black: h6g6   Move: 109
# Move by US White: g4h3   Move: 110
# Move by CN Black: g6f5   Move: 111
# Move by US White: a4a5   Move: 112
# Move by CN Black: f5g6   Move: 113
# Move by US White: a5a8   Move: 114
# Move by CN Black: b6b3   Move: 115
# Move by US White: a8a7   Move: 116
# Move by CN Black: b3b6   Move: 117
# Move by US White: g3g4   Move: 118
# Move by CN Black: g6f6   Move: 119
# Move by US White: h3g2   Move: 120
# Move by CN Black: b6b4   Move: 121
# Move by US White: g2g3   Move: 122
# Move by CN Black: b4b3   Move: 123
# Move by US White: g3h2   Move: 124
# Move by CN Black: f6e5   Move: 125
# Move by US White: a7f7   Move: 126
# Move by CN Black: b3a3   Move: 127
# Move by US White: h2g2   Move: 128
# Move by CN Black: a3a2   Move: 129
# Move by US White: g2h3   Move: 130
# Move by CN Black: e5d4   Move: 131
# Move by US White: f7f5   Move: 132
# Move by CN Black: a2a3   Move: 133
# Move by US White: h3h2   Move: 134
# Move by CN Black: d4e4   Move: 135
# Move by US White: f5f8   Move: 136
# Move by CN Black: a3a2   Move: 137
# Move by US White: h2g3   Move: 138
# Move by CN Black: a2b2   Move: 139
# Move by US White: f8f3   Move: 140
# Move by CN Black: b2a2   Move: 141
# Move by US White: f3f5   Move: 142
# Move by CN Black: a2a3   Move: 143
# Move by US White: g3g2   Move: 144
# Move by CN Black: a3a2   Move: 145
# Move by US White: g2g3   Move: 146
# Move by CN Black: a2a3   Move: 147
# Move by US White: g3g2   Move: 148
# Move by CN Black: a3a8   Move: 149
# Move by US White: g2g3   Move: 150
# Move by CN Black: a8a3   Move: 151
# Move by US White: g3g2   Move: 152
# Move by CN Black: a3a2   Move: 153
# Move by US White: g2g3   Move: 154
# Move by CN Black: a2a3   Move: 155
# Move by US White: g3h2   Move: 156
# Move by CN Black: a3a2   Move: 157
# Move by US White: h2h3   Move: 158
# Move by CN Black: a2a3   Move: 159
# Move by US White: h3g2   Move: 160
# Move by CN Black: a3a2   Move: 161
# Move by US White: g2h3   Move: 162
# Move by CN Black: a2a3   Move: 163
# Move by US White: h3g2   Move: 164
# Game 8 result: 1/2-1/2
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 9...
# Move by US White: e2e4   Move: 0
# Move by CN Black: e7e5   Move: 1
# Move by US White: g1f3   Move: 2
# Move by CN Black: g8f6   Move: 3
# Move by US White: f3e5   Move: 4
# Move by CN Black: d7d6   Move: 5
# Move by US White: e5f3   Move: 6
# Move by CN Black: f6e4   Move: 7
# Move by US White: d2d4   Move: 8
# Move by CN Black: d6d5   Move: 9
# Move by US White: f1d3   Move: 10
# Move by CN Black: f8e7   Move: 11
# Move by US White: e1g1   Move: 12
# Move by CN Black: e4d6   Move: 13
# Move by US White: f1e1   Move: 14
# Move by CN Black: e8g8   Move: 15
# Move by US White: c1f4   Move: 16
# Move by CN Black: f8e8   Move: 17
# Move by US White: c2c3   Move: 18
# Move by CN Black: b8d7   Move: 19
# Move by US White: b1d2   Move: 20
# Move by CN Black: d7f8   Move: 21
# Move by US White: d1b3   Move: 22
# Move by CN Black: c8e6   Move: 23
# Move by US White: e1e2   Move: 24
# Move by CN Black: c7c5   Move: 25
# Move by US White: d4c5   Move: 26
# Move by CN Black: d6e4   Move: 27
# Move by US White: b3c2   Move: 28
# Move by CN Black: e4c5   Move: 29
# Move by US White: a1e1   Move: 30
# Move by CN Black: c5d3   Move: 31
# Move by US White: c2d3   Move: 32
# Move by CN Black: d8a5   Move: 33
# Move by US White: d3b1   Move: 34
# Move by CN Black: a5a6   Move: 35
# Move by US White: f4g3   Move: 36
# Move by CN Black: e7c5   Move: 37
# Move by US White: d2b3   Move: 38
# Move by CN Black: c5b6   Move: 39
# Move by US White: h2h4   Move: 40
# Move by CN Black: e6d7   Move: 41
# Move by US White: e2e5   Move: 42
# Move by CN Black: f7f6   Move: 43
# Move by US White: e5d5   Move: 44
# Move by CN Black: e8e1   Move: 45
# Move by US White: f3e1   Move: 46
# Move by CN Black: d7e8   Move: 47
# Move by US White: d5d2   Move: 48
# Move by CN Black: e8g6   Move: 49
# Move by US White: e1c2   Move: 50
# Move by CN Black: f8e6   Move: 51
# Move by US White: b1e1   Move: 52
# Move by CN Black: a8e8   Move: 53
# Move by US White: c2b4   Move: 54
# Move by CN Black: a6c4   Move: 55
# Move by US White: d2e2   Move: 56
# Move by CN Black: g6f7   Move: 57
# Move by US White: b3d2   Move: 58
# Move by CN Black: c4b5   Move: 59
# Move by US White: b2b3   Move: 60
# Move by CN Black: b6c5   Move: 61
# Move by US White: d2c4   Move: 62
# Move by CN Black: c5b4   Move: 63
# Move by US White: c3b4   Move: 64
# Move by CN Black: e6d4   Move: 65
# Move by US White: e2e8   Move: 66
# Move by CN Black: b5e8   Move: 67
# Move by US White: e1d2   Move: 68
# Move by CN Black: d4f5   Move: 69
# Move by US White: d2d3   Move: 70
# Move by CN Black: f7e6   Move: 71
# Move by US White: d3e4   Move: 72
# Move by CN Black: e8d7   Move: 73
# Move by US White: b4b5   Move: 74
# Move by CN Black: d7d5   Move: 75
# Move by US White: e4d5   Move: 76
# Move by CN Black: e6d5   Move: 77
# Move by US White: g1h2   Move: 78
# Move by CN Black: g8f7   Move: 79
# Move by US White: f2f3   Move: 80
# Move by CN Black: f5d4   Move: 81
# Move by US White: c4d6   Move: 82
# Move by CN Black: f7e7   Move: 83
# Move by US White: d6c8   Move: 84
# Move by CN Black: e7d7   Move: 85
# Move by US White: c8a7   Move: 86
# Move by CN Black: d4e2   Move: 87
# Move by US White: g3e1   Move: 88
# Move by CN Black: e2c1   Move: 89
# Move by US White: e1d2   Move: 90
# Move by CN Black: c1a2   Move: 91
# Move by US White: b3b4   Move: 92
# Move by CN Black: d7e6   Move: 93
# Move by US White: b5b6   Move: 94
# Move by CN Black: g7g6   Move: 95
# Move by US White: h2g3   Move: 96
# Move by CN Black: e6e5   Move: 97
# Move by US White: a7b5   Move: 98
# Move by CN Black: d5c6   Move: 99
# Move by US White: b5c7   Move: 100
# Move by CN Black: e5d4   Move: 101
# Move by US White: c7e6   Move: 102
# Move by CN Black: d4d3   Move: 103
# Move by US White: d2e1   Move: 104
# Move by CN Black: c6d5   Move: 105
# Move by US White: e6f8   Move: 106
# Move by CN Black: d3e2   Move: 107
# Move by US White: e1f2   Move: 108
# Move by CN Black: a2b4   Move: 109
# Move by US White: f8h7   Move: 110
# Move by CN Black: f6f5   Move: 111
# Move by US White: h7f8   Move: 112
# Move by CN Black: d5f7   Move: 113
# Move by US White: f2d4   Move: 114
# Move by CN Black: b4d3   Move: 115
# Move by US White: d4c3   Move: 116
# Move by CN Black: f5f4   Move: 117
# Move by US White: g3h2   Move: 118
# Move by CN Black: e2f2   Move: 119
# Move by US White: f8d7   Move: 120
# Move by CN Black: f7e8   Move: 121
# Move by US White: d7e5   Move: 122
# Move by CN Black: d3e5   Move: 123
# Move by US White: c3d4   Move: 124
# Move by CN Black: f2e2   Move: 125
# Move by US White: d4e5   Move: 126
# Move by CN Black: e2e3   Move: 127
# Move by US White: e5b2   Move: 128
# Move by CN Black: e3d2   Move: 129
# Move by US White: h2g1   Move: 130
# Move by CN Black: d2e3   Move: 131
# Move by US White: b2c1   Move: 132
# Move by CN Black: e3d4   Move: 133
# Move by US White: c1f4   Move: 134
# Move by CN Black: d4d5   Move: 135
# Move by US White: g1f2   Move: 136
# Move by CN Black: d5e6   Move: 137
# Move by US White: f4d2   Move: 138
# Move by CN Black: e6f5   Move: 139
# Move by US White: f2g3   Move: 140
# Move by CN Black: e8a4   Move: 141
# Move by US White: g3h2   Move: 142
# Move by CN Black: a4b5   Move: 143
# Move by US White: h2g3   Move: 144
# Move by CN Black: b5d3   Move: 145
# Move by US White: g3f2   Move: 146
# Move by CN Black: d3b5   Move: 147
# Move by US White: f2g1   Move: 148
# Move by CN Black: b5d7   Move: 149
# Move by US White: g1f2   Move: 150
# Move by CN Black: d7b5   Move: 151
# Move by US White: d2c1   Move: 152
# Move by CN Black: b5a4   Move: 153
# Move by US White: c1b2   Move: 154
# Move by CN Black: a4c2   Move: 155
# Move by US White: b2c3   Move: 156
# Move by CN Black: c2a4   Move: 157
# Move by US White: f2e3   Move: 158
# Move by CN Black: a4c2   Move: 159
# Move by US White: e3e2   Move: 160
# Move by CN Black: c2a4   Move: 161
# Move by US White: c3d2   Move: 162
# Move by CN Black: a4b3   Move: 163
# Move by US White: e2e3   Move: 164
# Move by CN Black: b3a4   Move: 165
# Move by US White: d2c3   Move: 166
# Move by CN Black: a4b3   Move: 167
# Move by US White: c3d4   Move: 168
# Move by CN Black: b3d1   Move: 169
# Move by US White: e3d2   Move: 170
# Move by CN Black: d1a4   Move: 171
# Move by US White: d2e1   Move: 172
# Move by CN Black: a4c2   Move: 173
# Move by US White: g2g4   Move: 174
# Move by CN Black: f5f4   Move: 175
# Move by US White: e1e2   Move: 176
# Move by CN Black: c2b3   Move: 177
# Move by US White: e2f2   Move: 178
# Move by CN Black: b3d1   Move: 179
# Move by US White: d4e3   Move: 180
# Move by CN Black: f4e5   Move: 181
# Move by US White: f2g2   Move: 182
# Move by CN Black: e5e6   Move: 183
# Move by US White: e3d2   Move: 184
# Move by CN Black: e6f7   Move: 185
# Move by US White: d2b4   Move: 186
# Move by CN Black: f7e6   Move: 187
# Move by US White: b4c5   Move: 188
# Move by CN Black: e6e5   Move: 189
# Move by US White: g2g3   Move: 190
# Move by CN Black: d1a4   Move: 191
# Move by US White: c5b4   Move: 192
# Move by CN Black: a4b3   Move: 193
# Move by US White: b4c3   Move: 194
# Move by CN Black: e5e6   Move: 195
# Move by US White: g3f2   Move: 196
# Move by CN Black: b3d1   Move: 197
# Move by US White: f2g3   Move: 198
# Move by CN Black: d1b3   Move: 199
# Move by US White: g3h2   Move: 200
# Move by CN Black: b3a4   Move: 201
# Move by US White: c3d4   Move: 202
# Move by CN Black: a4d1   Move: 203
# Move by US White: h2g3   Move: 204
# Move by CN Black: e6e7   Move: 205
# Move by US White: d4g7   Move: 206
# Move by CN Black: e7f7   Move: 207
# Move by US White: g7a1   Move: 208
# Move by CN Black: d1c2   Move: 209
# Move by US White: g3f2   Move: 210
# Move by CN Black: c2d1   Move: 211
# Move by US White: f2g3   Move: 212
# Move by CN Black: d1c2   Move: 213
# Move by US White: a1c3   Move: 214
# Move by CN Black: c2b3   Move: 215
# Move by US White: c3d4   Move: 216
# Move by CN Black: b3d1   Move: 217
# Move by US White: d4c3   Move: 218
# Move by CN Black: d1e2   Move: 219
# Move by US White: c3b2   Move: 220
# Move by CN Black: e2d1   Move: 221
# Move by US White: b2a1   Move: 222
# Move by CN Black: f7e6   Move: 223
# Move by US White: g3f4   Move: 224
# Move by CN Black: e6f7   Move: 225
# ...
# Move by US White: e6e7   Move: 76
# Move by CN Black: f8e7   Move: 77
# Move by US White: g6g7   Move: 78
# Move by CN Black: a3b5   Move: 79
# Move by US White: f2f4   Move: 80
# Move by CN Black: b5c3   Move: 81
# Move by US White: g4g5   Move: 82
# Move by CN Black: c3e4   Move: 83
# Move by US White: g5h6   Move: 84
# Move by CN Black: e4f6   Move: 85
# Move by US White: f4f5   Move: 86
# Move by CN Black: f6e8   Move: 87
# Move by US White: g7g6   Move: 88
# Move by CN Black: e8f6   Move: 89
# Move by US White: g6g5   Move: 90
# Move by CN Black: f6h7   Move: 91
# Move by US White: g5g6   Move: 92
# Move by CN Black: h7f6   Move: 93
# Move by US White: g6g5   Move: 94
# Move by CN Black: f6h7   Move: 95
# Move by US White: g5g6   Move: 96
# Move by CN Black: h7f6   Move: 97
# Move by US White: g6g7   Move: 98
# Move by CN Black: f6h5   Move: 99
# Move by US White: g7g6   Move: 100
# Move by CN Black: h5f6   Move: 101
# Move by US White: g6g7   Move: 102
# Move by CN Black: f6h5   Move: 103
# Move by US White: g7g8   Move: 104
# Move by CN Black: h5f6   Move: 105
# Move by US White: g8g7   Move: 106
# Move by CN Black: f6h5   Move: 107
# Move by US White: g7g6   Move: 108
# Move by CN Black: h5f6   Move: 109
# Game 97 result: 1/2-1/2
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 98...
# Move by US White: e2e4   Move: 0
# Move by CN Black: e7e5   Move: 1
# Move by US White: g1f3   Move: 2
# Move by CN Black: b8c6   Move: 3
# Move by US White: d2d4   Move: 4
# Move by CN Black: e5d4   Move: 5
# Move by US White: f3d4   Move: 6
# Move by CN Black: f8b4   Move: 7
# Move by US White: c2c3   Move: 8
# Move by CN Black: b4c5   Move: 9
# Move by US White: f1e2   Move: 10
# Move by CN Black: g8f6   Move: 11
# Move by US White: d4c6   Move: 12
# Move by CN Black: b7c6   Move: 13
# Move by US White: e4e5   Move: 14
# Move by CN Black: f6e4   Move: 15
# Move by US White: e1g1   Move: 16
# Move by CN Black: d8h4   Move: 17
# Move by US White: d1e1   Move: 18
# Move by CN Black: d7d5   Move: 19
# Move by US White: b1d2   Move: 20
# Move by CN Black: e4d2   Move: 21
# Move by US White: c1d2   Move: 22
# Move by CN Black: e8g8   Move: 23
# Move by US White: b2b4   Move: 24
# Move by CN Black: c5b6   Move: 25
# Move by US White: a2a4   Move: 26
# Move by CN Black: a7a5   Move: 27
# Move by US White: b4a5   Move: 28
# Move by CN Black: b6a5   Move: 29
# Move by US White: c3c4   Move: 30
# Move by CN Black: a5d2   Move: 31
# Move by US White: e1d2   Move: 32
# Move by CN Black: d5c4   Move: 33
# Move by US White: a4a5   Move: 34
# Move by CN Black: c8e6   Move: 35
# Move by US White: a5a6   Move: 36
# Move by CN Black: e6d5   Move: 37
# Move by US White: f2f4   Move: 38
# Move by CN Black: h4e7   Move: 39
# Move by US White: a1a5   Move: 40
# Move by CN Black: f8b8   Move: 41
# Move by US White: f1c1   Move: 42
# Move by CN Black: b8b6   Move: 43
# Move by US White: a6a7   Move: 44
# Move by CN Black: b6b7   Move: 45
# Move by US White: d2d4   Move: 46
# Move by CN Black: e7b4   Move: 47
# Move by US White: a5a6   Move: 48
# Move by CN Black: b4b5   Move: 49
# Move by US White: c1a1   Move: 50
# Move by CN Black: b5b3   Move: 51
# Move by US White: a1c1   Move: 52
# Move by CN Black: g7g6   Move: 53
# Move by US White: e2c4   Move: 54
# Move by CN Black: d5c4   Move: 55
# Move by US White: d4c4   Move: 56
# Move by CN Black: b3e3   Move: 57
# Move by US White: g1h1   Move: 58
# Move by CN Black: b7a7   Move: 59
# Move by US White: a6a7   Move: 60
# Move by CN Black: a8a7   Move: 61
# Move by US White: c4c6   Move: 62
# Move by CN Black: e3f4   Move: 63
# Move by US White: e5e6   Move: 64
# Move by CN Black: f7e6   Move: 65
# Move by US White: c6e6   Move: 66
# Move by CN Black: f4f7   Move: 67
# Move by US White: e6c6   Move: 68
# Move by CN Black: f7e7   Move: 69
# Move by US White: c6d5   Move: 70
# Move by CN Black: e7f7   Move: 71
# Move by US White: d5d8   Move: 72
# Move by CN Black: f7f8   Move: 73
# Move by US White: d8d5   Move: 74
# Move by CN Black: f8f7   Move: 75
# Move by US White: d5d8   Move: 76
# Move by CN Black: f7f8   Move: 77
# Move by US White: d8d5   Move: 78
# Move by CN Black: f8f7   Move: 79
# Move by US White: d5d8   Move: 80
# Move by CN Black: f7f8   Move: 81
# Move by US White: d8d5   Move: 82
# Move by CN Black: f8f7   Move: 83
# Move by US White: d5d8   Move: 84
# Move by CN Black: f7f8   Move: 85
# Move by US White: d8d5   Move: 86
# Move by CN Black: f8f7   Move: 87
# Game 98 result: 1/2-1/2
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 99...
# Move by US White: e2e4   Move: 0
# Move by CN Black: c7c5   Move: 1
# Move by US White: g1f3   Move: 2
# Move by CN Black: b8c6   Move: 3
# Move by US White: f1b5   Move: 4
# Move by CN Black: g7g6   Move: 5
# Move by US White: e1g1   Move: 6
# Move by CN Black: f8g7   Move: 7
# Move by US White: c2c3   Move: 8
# Move by CN Black: e7e5   Move: 9
# Move by US White: d2d4   Move: 10
# Move by CN Black: e5d4   Move: 11
# Move by US White: c3d4   Move: 12
# Move by CN Black: c5d4   Move: 13
# Move by US White: c1f4   Move: 14
# Move by CN Black: a7a6   Move: 15
# Move by US White: b5c4   Move: 16
# Move by CN Black: d7d6   Move: 17
# Move by US White: f3g5   Move: 18
# Move by CN Black: g8h6   Move: 19
# Move by US White: b1a3   Move: 20
# Move by CN Black: e8g8   Move: 21
# Move by US White: h2h3   Move: 22
# Move by CN Black: g8h8   Move: 23
# Move by US White: d1d2   Move: 24
# Move by CN Black: c6e5   Move: 25
# Move by US White: c4d5   Move: 26
# Move by CN Black: f7f6   Move: 27
# Move by US White: g5e6   Move: 28
# Move by CN Black: c8e6   Move: 29
# Move by US White: d5e6   Move: 30
# Move by CN Black: g6g5   Move: 31
# Move by US White: f4h2   Move: 32
# Move by CN Black: d8e7   Move: 33
# Move by US White: e6d5   Move: 34
# Move by CN Black: g5g4   Move: 35
# Move by US White: a3c2   Move: 36
# Move by CN Black: g4h3   Move: 37
# Move by US White: c2d4   Move: 38
# Move by CN Black: f6f5   Move: 39
# Move by US White: a1e1   Move: 40
# Move by CN Black: h3g2   Move: 41
# Move by US White: g1g2   Move: 42
# Move by CN Black: e7f6   Move: 43
# Move by US White: f2f3   Move: 44
# Move by CN Black: f6g6   Move: 45
# Move by US White: g2h1   Move: 46
# Move by CN Black: g6h5   Move: 47
# Move by US White: f1g1   Move: 48
# Move by CN Black: e5f3   Move: 49
# Move by US White: d4f3   Move: 50
# Move by CN Black: h5f3   Move: 51
# Move by US White: d2g2   Move: 52
# Move by CN Black: f3g2   Move: 53
# Move by US White: g1g2   Move: 54
# Move by CN Black: f5f4   Move: 55
# Move by US White: d5b7   Move: 56
# Move by CN Black: a8a7   Move: 57
# Move by US White: b7d5   Move: 58
# Move by CN Black: g7e5   Move: 59
# Move by US White: e1g1   Move: 60
# Move by CN Black: f4f3   Move: 61
# Move by US White: g2g5   Move: 62
# Move by CN Black: f3f2   Move: 63
# Move by US White: g1f1   Move: 64
# Move by CN Black: a7g7   Move: 65
# Move by US White: g5g7   Move: 66
# Move by CN Black: h8g7   Move: 67
# Move by US White: d5e6   Move: 68
# Move by CN Black: e5b2   Move: 69
# Move by US White: h2g3   Move: 70
# Move by CN Black: b2d4   Move: 71
# Move by US White: e6h3   Move: 72
# Move by CN Black: f8f6   Move: 73
# Move by US White: h1g2   Move: 74
# Move by CN Black: f6g6   Move: 75
# Move by US White: g2f3   Move: 76
# Move by CN Black: a6a5   Move: 77
# Move by US White: a2a4   Move: 78
# Move by CN Black: d4c5   Move: 79
# Move by US White: f1d1   Move: 80
# Move by CN Black: g7f8   Move: 81
# Move by US White: d1f1   Move: 82
# Move by CN Black: c5a7   Move: 83
# Move by US White: f1c1   Move: 84
# Move by CN Black: h6f7   Move: 85
# Move by US White: h3f5   Move: 86
# Move by CN Black: g6g8   Move: 87
# Move by US White: g3f2   Move: 88
# Move by CN Black: f7e5   Move: 89
# Move by US White: f3e2   Move: 90
# Move by CN Black: a7f2   Move: 91
# Move by US White: c1c8   Move: 92
# Move by CN Black: f8f7   Move: 93
# Move by US White: c8c7   Move: 94
# Move by CN Black: f7f6   Move: 95
# Move by US White: e2f2   Move: 96
# Move by CN Black: h7h5   Move: 97
# Move by US White: c7a7   Move: 98
# Move by CN Black: e5c4   Move: 99
# Move by US White: a7c7   Move: 100
# Move by CN Black: c4e5   Move: 101
# Move by US White: c7a7   Move: 102
# Move by CN Black: e5c4   Move: 103
# Move by US White: a7c7   Move: 104
# Move by CN Black: c4e5   Move: 105
# Move by US White: c7a7   Move: 106
# Move by CN Black: e5c4   Move: 107
# Move by US White: a7c7   Move: 108
# Move by CN Black: c4e5   Move: 109
# Move by US White: c7a7   Move: 110
# Move by CN Black: e5c4   Move: 111
# Move by US White: a7c7   Move: 112
# Move by CN Black: c4e5   Move: 113
# Game 99 result: 1/2-1/2
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 10, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 10, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 100...
# Move by US White: e2e4   Move: 0
# Move by CN Black: e7e5   Move: 1
# Move by US White: d2d4   Move: 2
# Move by CN Black: d8e7   Move: 3
# Move by US White: f1c4   Move: 4
# Move by CN Black: e5d4   Move: 5
# Move by US White: b1d2   Move: 6
# Move by CN Black: g8f6   Move: 7
# Move by US White: d1e2   Move: 8
# Move by CN Black: d7d5   Move: 9
# Move by US White: c4d5   Move: 10
# Move by CN Black: f6d5   Move: 11
# Move by US White: e4d5   Move: 12
# Move by CN Black: b7b6   Move: 13
# Move by US White: g1f3   Move: 14
# Move by CN Black: c7c5   Move: 15
# Move by US White: e2e7   Move: 16
# Move by CN Black: f8e7   Move: 17
# Move by US White: c2c4   Move: 18
# Move by CN Black: c8f5   Move: 19
# Move by US White: e1g1   Move: 20
# Move by CN Black: e8d8   Move: 21
# Move by US White: h2h3   Move: 22
# Move by CN Black: h8e8   Move: 23
# Move by US White: a2a4   Move: 24
# Move by CN Black: b8d7   Move: 25
# Move by US White: a4a5   Move: 26
# Move by CN Black: b6b5   Move: 27
# Move by US White: c4b5   Move: 28
# Move by CN Black: f5d3   Move: 29
# Move by US White: f1e1   Move: 30
# Move by CN Black: e7f6   Move: 31
# Move by US White: e1e8   Move: 32
# Move by CN Black: d8e8   Move: 33
# Move by US White: g2g4   Move: 34
# Move by CN Black: h7h6   Move: 35
# Move by US White: b2b4   Move: 36
# Move by CN Black: c5c4   Move: 37
# Move by US White: c1a3   Move: 38
# Move by CN Black: a8c8   Move: 39
# Move by US White: h3h4   Move: 40
# Move by CN Black: g7g5   Move: 41
# Move by US White: d5d6   Move: 42
# Move by CN Black: g5h4   Move: 43
# Move by US White: a1e1   Move: 44
# Move by CN Black: e8f8   Move: 45
# Move by US White: b5b6   Move: 46
# Move by CN Black: c4c3   Move: 47
# Move by US White: b6b7   Move: 48
# Move by CN Black: c8b8   Move: 49
# Move by US White: d2b3   Move: 50
# Move by CN Black: d3a6   Move: 51
# Move by US White: b4b5   Move: 52
# Move by CN Black: a6b7   Move: 53
# Move by US White: f3d4   Move: 54
# Move by CN Black: b8e8   Move: 55
# Move by US White: e1d1   Move: 56
# Move by CN Black: e8c8   Move: 57
# Move by US White: b3a1   Move: 58
# Move by CN Black: f6d4   Move: 59
# Move by US White: d1d4   Move: 60
# Move by CN Black: c3c2   Move: 61
# Move by US White: a3c1   Move: 62
# Move by CN Black: d7e5   Move: 63
# Move by US White: d4f4   Move: 64
# Move by CN Black: f8e8   Move: 65
# Move by US White: a5a6   Move: 66
# Move by CN Black: b7d5   Move: 67
# Move by US White: b5b6   Move: 68
# Move by CN Black: a7b6   Move: 69
# Move by US White: f4f5   Move: 70
# Move by CN Black: e5f3   Move: 71
# Move by US White: g1f1   Move: 72
# Move by CN Black: d5c4   Move: 73
# Move by US White: f1g2   Move: 74
# Move by CN Black: f3d4   Move: 75
# Move by US White: f5f6   Move: 76
# Move by CN Black: e8d7   Move: 77
# Move by US White: g2h2   Move: 78
# Move by CN Black: c4e6   Move: 79
# Move by US White: a1c2   Move: 80
# Move by CN Black: d4c2   Move: 81
# Move by US White: c1d2   Move: 82
# Move by CN Black: b6b5   Move: 83
# Move by US White: f6h6   Move: 84
# Move by CN Black: b5b4   Move: 85
# Move by US White: h6h5   Move: 86
# Move by CN Black: c8a8   Move: 87
# Move by US White: h5b5   Move: 88
# Move by CN Black: a8a6   Move: 89
# Move by US White: b5b8   Move: 90
# Move by CN Black: d7d6   Move: 91
# Move by US White: b8d8   Move: 92
# Move by CN Black: d6c5   Move: 93
# Move by US White: d8b8   Move: 94
# Move by CN Black: e6g4   Move: 95
# Move by US White: d2g5   Move: 96
# Move by CN Black: g4f5   Move: 97
# Move by US White: b8g8   Move: 98
# Move by CN Black: c5c4   Move: 99
# Move by US White: g5h4   Move: 100
# Move by CN Black: b4b3   Move: 101
# Move by US White: h4g5   Move: 102
# Move by CN Black: b3b2   Move: 103
# Move by US White: g8b8   Move: 104
# Move by CN Black: a6a2   Move: 105
# Move by US White: g5e7   Move: 106
# Move by CN Black: c2d4   Move: 107
# Move by US White: e7d6   Move: 108
# Move by CN Black: b2b1r   Move: 109
# Move by US White: d6e5   Move: 110
# Move by CN Black: a2f2   Move: 111
# Move by US White: h2g3   Move: 112
# Move by CN Black: f2b2   Move: 113
# Move by US White: b8b2   Move: 114
# Move by CN Black: b1b2   Move: 115
# Move by US White: e5f6   Move: 116
# Move by CN Black: f5c2   Move: 117
# Move by US White: g3h3   Move: 118
# Move by CN Black: b2b3   Move: 119
# Move by US White: h3h2   Move: 120
# Move by CN Black: b3b2   Move: 121
# Move by US White: f6h4   Move: 122
# Move by CN Black: c2e4   Move: 123
# Move by US White: h2h3   Move: 124
# Move by CN Black: b2b3   Move: 125
# Move by US White: h3g4   Move: 126
# Move by CN Black: c4d3   Move: 127
# Move by US White: h4f6   Move: 128
# Move by CN Black: d4e2   Move: 129
# Move by US White: g4h5   Move: 130
# Move by CN Black: e2f4   Move: 131
# Move by US White: h5g4   Move: 132
# Move by CN Black: f4e6   Move: 133
# Move by US White: g4g3   Move: 134
# Move by CN Black: d3e3   Move: 135
# Move by US White: g3h4   Move: 136
# Move by CN Black: e4b1   Move: 137
# Move by US White: h4g3   Move: 138
# Move by CN Black: b1e4   Move: 139
# Move by US White: g3h4   Move: 140
# Move by CN Black: b3b4   Move: 141
# Move by US White: h4g3   Move: 142
# Move by CN Black: b4b5   Move: 143
# Move by US White: g3g4   Move: 144
# Move by CN Black: e4f5   Move: 145
# Move by US White: g4h5   Move: 146
# Move by CN Black: f5d3   Move: 147
# Move by US White: h5h4   Move: 148
# Move by CN Black: b5b1   Move: 149
# Move by US White: h4h3   Move: 150
# Move by CN Black: b1f1   Move: 151
# Move by US White: f6e5   Move: 152
# Move by CN Black: f7f5   Move: 153
# Move by US White: h3g3   Move: 154
# Move by CN Black: d3e4   Move: 155
# Move by US White: e5b8   Move: 156
# Move by CN Black: e3e2   Move: 157
# Move by US White: g3h3   Move: 158
# Move by CN Black: e6g5   Move: 159
# Move by US White: h3h4   Move: 160
# Move by CN Black: f1g1   Move: 161
# Move by US White: b8a7   Move: 162
# Move by CN Black: g1g2   Move: 163
# Move by US White: h4h5   Move: 164
# Move by CN Black: e4d5   Move: 165
# Move by US White: a7b8   Move: 166
# Move by CN Black: d5f7   Move: 167
# Move by US White: h5h6   Move: 168
# Move by CN Black: g5e6   Move: 169
# Move by US White: b8c7   Move: 170
# Move by CN Black: g2g6   Move: 171
# Move by US White: h6h7   Move: 172
# Move by CN Black: e6f8   Move: 173
# Move by US White: h7h8   Move: 174
# Move by CN Black: f7d5   Move: 175
# Move by US White: c7h2   Move: 176
# Move by CN Black: g6g8   Move: 177
# Game 100 result: 0-1

# %%
results = []

# %%
results.append({
            "US Wins": us_wins,
            "CN Wins": cn_wins,
            "Draws": draws,
        })

print(results)
# Out:
# [{'US Wins': 25, 'CN Wins': 16, 'Draws': 59}]

# %% [markdown]
# ## Swapping sides

# %%
stockfish_us = Stockfish()
stockfish_cn = Stockfish()

# %%
us_wins = 25
cn_wins = 16
draws = 59

# %%
for game_number in range(1, NUM_GAMES + 1):
    
    move_counter = 0
    num_us = random.randint(1, 100)
    num_cn = random.randint(1, 100)

    if num_us <= AI_USE_US: stockfish_us.update_engine_parameters({"Skill Level": 20, "Threads": 3, "Hash": 2048, "Minimum Thinking Time": 50})
    else: stockfish_us.update_engine_parameters({"Skill Level": 10, "Threads": 3, "Hash": 2048, "Minimum Thinking Time": 50})

    if num_cn <= AI_USE_CN: stockfish_cn.update_engine_parameters({"Skill Level": 20, "Threads": 3, "Hash": 2048, "Minimum Thinking Time": 50})
    else: stockfish_cn.update_engine_parameters({"Skill Level": 10, "Threads": 3, "Hash": 2048, "Minimum Thinking Time": 50})

    print(stockfish_us.get_parameters())
    print(stockfish_cn.get_parameters())

    print(f"Starting game {game_number}...")

    board = chess.Board()

    while not board.is_game_over():
        # Determine which engine to use based on turn
        current_engine = stockfish_cn if board.turn == chess.WHITE else stockfish_us

        # Set the position on the board for the engine
        current_engine.set_fen_position(board.fen())

        # Get the best move from the engine
        best_move = await get_move_with_timeout(current_engine)
        if best_move is None:
            print("Engine failed to provide a move.")
            # if current_engine == stockfish_us:
            #     stockfish_us = Stockfish(parameters={})
            break

        # Apply the move to the board
        print(f"Move by {"CN White" if board.turn else "US Black"}: {best_move}   Move: {move_counter}")
        move = chess.Move.from_uci(best_move)
        board.push(move)
        move_counter += 1

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        cn_wins += 1
    elif result == "0-1":
        us_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n\n")
# Out:
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 1...
# Move by CN White: e2e4   Move: 0
# Move by US Black: e7e5   Move: 1
# Move by CN White: g1f3   Move: 2
# Move by US Black: b8c6   Move: 3
# Move by CN White: f1b5   Move: 4
# Move by US Black: a7a6   Move: 5
# Move by CN White: b5a4   Move: 6
# Move by US Black: g8f6   Move: 7
# Move by CN White: e1g1   Move: 8
# Move by US Black: f8e7   Move: 9
# Move by CN White: f1e1   Move: 10
# Move by US Black: b7b5   Move: 11
# Move by CN White: a4b3   Move: 12
# Move by US Black: d7d6   Move: 13
# Move by CN White: c2c3   Move: 14
# Move by US Black: e8g8   Move: 15
# Move by CN White: h2h3   Move: 16
# Move by US Black: c8e6   Move: 17
# Move by CN White: d2d4   Move: 18
# Move by US Black: e6b3   Move: 19
# Move by CN White: a2b3   Move: 20
# Move by US Black: e5d4   Move: 21
# Move by CN White: c3d4   Move: 22
# Move by US Black: c6b4   Move: 23
# Move by CN White: d4d5   Move: 24
# Move by US Black: c7c5   Move: 25
# Move by CN White: d5c6   Move: 26
# Move by US Black: b4c6   Move: 27
# Move by CN White: b1c3   Move: 28
# Move by US Black: f8e8   Move: 29
# Move by CN White: c1f4   Move: 30
# Move by US Black: h7h6   Move: 31
# Move by CN White: f4g3   Move: 32
# Move by US Black: d8d7   Move: 33
# Move by CN White: f3h4   Move: 34
# Move by US Black: e7f8   Move: 35
# Move by CN White: h4f5   Move: 36
# Move by US Black: a8d8   Move: 37
# Move by CN White: a1a6   Move: 38
# Move by US Black: d7c8   Move: 39
# Move by CN White: a6b6   Move: 40
# Move by US Black: d6d5   Move: 41
# Move by CN White: e4e5   Move: 42
# Move by US Black: f6d7   Move: 43
# Move by CN White: b6b5   Move: 44
# Move by US Black: d7e5   Move: 45
# Move by CN White: g3e5   Move: 46
# Move by US Black: c8f5   Move: 47
# Move by CN White: e5c7   Move: 48
# Move by US Black: e8e1   Move: 49
# Move by CN White: d1e1   Move: 50
# Move by US Black: d8d7   Move: 51
# Move by CN White: c7b6   Move: 52
# Move by US Black: f5e6   Move: 53
# Move by CN White: e1e6   Move: 54
# Move by US Black: f7e6   Move: 55
# Move by CN White: g1f1   Move: 56
# Move by US Black: g8f7   Move: 57
# Move by CN White: f1e2   Move: 58
# Move by US Black: f8e7   Move: 59
# Move by CN White: f2f3   Move: 60
# Move by US Black: c6a7   Move: 61
# Move by CN White: b5a5   Move: 62
# Move by US Black: a7c6   Move: 63
# Move by CN White: a5b5   Move: 64
# Move by US Black: c6a7   Move: 65
# Move by CN White: b5a5   Move: 66
# Move by US Black: a7c6   Move: 67
# Move by CN White: a5b5   Move: 68
# Move by US Black: c6a7   Move: 69
# Move by CN White: b5a5   Move: 70
# Move by US Black: a7c6   Move: 71
# Move by CN White: a5a6   Move: 72
# Move by US Black: c6b4   Move: 73
# Move by CN White: a6a8   Move: 74
# Move by US Black: d7b7   Move: 75
# Move by CN White: c3a4   Move: 76
# Move by US Black: e6e5   Move: 77
# Move by CN White: a8a7   Move: 78
# Move by US Black: b7a7   Move: 79
# Move by CN White: b6a7   Move: 80
# Move by US Black: f7e6   Move: 81
# Move by CN White: a4c5   Move: 82
# Move by US Black: e6f6   Move: 83
# Move by CN White: c5d3   Move: 84
# Move by US Black: h6h5   Move: 85
# Move by CN White: a7e3   Move: 86
# Move by US Black: b4c2   Move: 87
# Move by CN White: e2f2   Move: 88
# Move by US Black: f6f5   Move: 89
# Move by CN White: g2g4   Move: 90
# Move by US Black: h5g4   Move: 91
# Move by CN White: h3g4   Move: 92
# Move by US Black: f5f6   Move: 93
# Move by CN White: e3d2   Move: 94
# Move by US Black: e5e4   Move: 95
# Move by CN White: f3e4   Move: 96
# Move by US Black: d5e4   Move: 97
# Move by CN White: d2c3   Move: 98
# Move by US Black: f6g5   Move: 99
# Move by CN White: d3e5   Move: 100
# Move by US Black: e7c5   Move: 101
# Move by CN White: f2e2   Move: 102
# Move by US Black: g5f4   Move: 103
# Move by CN White: e5c6   Move: 104
# Move by US Black: f4g4   Move: 105
# Move by CN White: b3b4   Move: 106
# Move by US Black: c5b6   Move: 107
# Move by CN White: c6e7   Move: 108
# Move by US Black: c2d4   Move: 109
# Move by CN White: e2e3   Move: 110
# Move by US Black: d4f5   Move: 111
# Move by CN White: e3e4   Move: 112
# Move by US Black: f5e7   Move: 113
# Move by CN White: c3g7   Move: 114
# Move by US Black: e7f5   Move: 115
# Move by CN White: g7e5   Move: 116
# Move by US Black: g4g5   Move: 117
# Move by CN White: b4b5   Move: 118
# Move by US Black: b6g1   Move: 119
# Move by CN White: b2b3   Move: 120
# Move by US Black: g1b6   Move: 121
# Move by CN White: e4d5   Move: 122
# Move by US Black: g5g6   Move: 123
# Move by CN White: d5c6   Move: 124
# Move by US Black: b6e3   Move: 125
# Move by CN White: c6d7   Move: 126
# Move by US Black: f5h6   Move: 127
# Move by CN White: d7e6   Move: 128
# Move by US Black: h6f5   Move: 129
# Move by CN White: b3b4   Move: 130
# Move by US Black: e3a7   Move: 131
# Move by CN White: e6d7   Move: 132
# Move by US Black: g6f7   Move: 133
# Move by CN White: e5f4   Move: 134
# Move by US Black: f7g8   Move: 135
# Move by CN White: f4d6   Move: 136
# Move by US Black: f5d6   Move: 137
# Move by CN White: d7d6   Move: 138
# Move by US Black: g8f7   Move: 139
# Move by CN White: d6c7   Move: 140
# Move by US Black: a7g1   Move: 141
# Move by CN White: c7d7   Move: 142
# Move by US Black: g1f2   Move: 143
# Move by CN White: b5b6   Move: 144
# Move by US Black: f2b6   Move: 145
# Move by CN White: d7d6   Move: 146
# Move by US Black: f7f6   Move: 147
# Move by CN White: d6d5   Move: 148
# Move by US Black: f6e7   Move: 149
# Move by CN White: d5e5   Move: 150
# Move by US Black: b6d4   Move: 151
# Move by CN White: e5d4   Move: 152
# Move by US Black: e7d6   Move: 153
# Move by CN White: d4c4   Move: 154
# Move by US Black: d6c6   Move: 155
# Move by CN White: b4b5   Move: 156
# Move by US Black: c6c7   Move: 157
# Move by CN White: c4c5   Move: 158
# Move by US Black: c7b7   Move: 159
# Move by CN White: c5b4   Move: 160
# Move by US Black: b7b8   Move: 161
# Move by CN White: b4a5   Move: 162
# Move by US Black: b8b7   Move: 163
# Move by CN White: a5b4   Move: 164
# Move by US Black: b7a8   Move: 165
# Move by CN White: b4c5   Move: 166
# Move by US Black: a8b7   Move: 167
# Move by CN White: c5d5   Move: 168
# Move by US Black: b7b6   Move: 169
# Move by CN White: d5c4   Move: 170
# Move by US Black: b6c7   Move: 171
# Move by CN White: c4c5   Move: 172
# Move by US Black: c7b7   Move: 173
# Move by CN White: c5d4   Move: 174
# Move by US Black: b7b6   Move: 175
# Move by CN White: d4c4   Move: 176
# Move by US Black: b6b7   Move: 177
# Move by CN White: c4c5   Move: 178
# Move by US Black: b7c7   Move: 179
# Move by CN White: b5b6   Move: 180
# Move by US Black: c7b8   Move: 181
# Move by CN White: c5c6   Move: 182
# Move by US Black: b8a8   Move: 183
# Move by CN White: c6d5   Move: 184
# Move by US Black: a8b8   Move: 185
# Move by CN White: d5c5   Move: 186
# Move by US Black: b8b7   Move: 187
# Move by CN White: c5b5   Move: 188
# Move by US Black: b7b8   Move: 189
# Move by CN White: b5a5   Move: 190
# Move by US Black: b8b7   Move: 191
# Move by CN White: a5b5   Move: 192
# Move by US Black: b7b8   Move: 193
# Move by CN White: b5c6   Move: 194
# Move by US Black: b8c8   Move: 195
# Move by CN White: c6b5   Move: 196
# Move by US Black: c8b8   Move: 197
# Move by CN White: b5a6   Move: 198
# Move by US Black: b8a8   Move: 199
# Move by CN White: a6b5   Move: 200
# Move by US Black: a8b7   Move: 201
# Move by CN White: b5c5   Move: 202
# Move by US Black: b7b8   Move: 203
# Move by CN White: c5b5   Move: 204
# Move by US Black: b8b7   Move: 205
# Move by CN White: b5a5   Move: 206
# Move by US Black: b7b8   Move: 207
# Move by CN White: a5b5   Move: 208
# Move by US Black: b8b7   Move: 209
# Move by CN White: b5a5   Move: 210
# Move by US Black: b7b8   Move: 211
# Move by CN White: a5b5   Move: 212
# Move by US Black: b8b7   Move: 213
# Move by CN White: b5c5   Move: 214
# Move by US Black: b7b8   Move: 215
# Move by CN White: c5d6   Move: 216
# Move by US Black: b8b7   Move: 217
# Move by CN White: d6c5   Move: 218
# Move by US Black: b7b8   Move: 219
# Move by CN White: c5c6   Move: 220
# Move by US Black: b8a8   Move: 221
# Move by CN White: c6b5   Move: 222
# Move by US Black: a8b7   Move: 223
# Game 1 result: 1/2-1/2
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 2...
# Move by CN White: e2e4   Move: 0
# Move by US Black: e7e5   Move: 1
# Move by CN White: g1f3   Move: 2
# Move by US Black: g8f6   Move: 3
# Move by CN White: f3e5   Move: 4
# Move by US Black: d7d6   Move: 5
# Move by CN White: e5f3   Move: 6
# Move by US Black: f6e4   Move: 7
# Move by CN White: d2d4   Move: 8
# Move by US Black: d6d5   Move: 9
# Move by CN White: f1d3   Move: 10
# Move by US Black: f8d6   Move: 11
# Move by CN White: e1g1   Move: 12
# Move by US Black: e8g8   Move: 13
# Move by CN White: c2c4   Move: 14
# Move by US Black: c7c6   Move: 15
# Move by CN White: f1e1   Move: 16
# Move by US Black: e4f6   Move: 17
# Move by CN White: b1c3   Move: 18
# Move by US Black: d5c4   Move: 19
# Move by CN White: d3c4   Move: 20
# Move by US Black: c8g4   Move: 21
# Move by CN White: h2h3   Move: 22
# Move by US Black: g4f3   Move: 23
# Move by CN White: d1f3   Move: 24
# Move by US Black: b8d7   Move: 25
# Move by CN White: c4b3   Move: 26
# Move by US Black: f8e8   Move: 27
# Move by CN White: e1e8   Move: 28
# Move by US Black: d8e8   Move: 29
# Move by CN White: c1d2   Move: 30
# Move by US Black: d7b6   Move: 31
# Move by CN White: g2g4   Move: 32
# Move by US Black: e8d7   Move: 33
# Move by CN White: g4g5   Move: 34
# Move by US Black: f6d5   Move: 35
# Move by CN White: h3h4   Move: 36
# Move by US Black: a7a5   Move: 37
# Move by CN White: a2a4   Move: 38
# Move by US Black: a8e8   Move: 39
# Move by CN White: h4h5   Move: 40
# Move by US Black: d6b4   Move: 41
# Move by CN White: g1g2   Move: 42
# Move by US Black: b6c8   Move: 43
# Move by CN White: c3d5   Move: 44
# Move by US Black: b4d2   Move: 45
# Move by CN White: g5g6   Move: 46
# Move by US Black: h7g6   Move: 47
# Move by CN White: h5g6   Move: 48
# Move by US Black: e8e6   Move: 49
# Move by CN White: d5f4   Move: 50
# Move by US Black: d2f4   Move: 51
# Move by CN White: g6f7   Move: 52
# Move by US Black: g8f8   Move: 53
# Move by CN White: b3e6   Move: 54
# Move by US Black: d7e6   Move: 55
# Move by CN White: f3f4   Move: 56
# Move by US Black: e6g6   Move: 57
# Move by CN White: f4g3   Move: 58
# Move by US Black: g6e4   Move: 59
# Move by CN White: g3f3   Move: 60
# Move by US Black: e4g6   Move: 61
# Move by CN White: g2f1   Move: 62
# Move by US Black: c8d6   Move: 63
# Move by CN White: a1e1   Move: 64
# Move by US Black: g6h7   Move: 65
# Move by CN White: e1e5   Move: 66
# Move by US Black: h7b1   Move: 67
# Move by CN White: f1g2   Move: 68
# Move by US Black: b1g6   Move: 69
# Move by CN White: f3g3   Move: 70
# Move by US Black: g6f6   Move: 71
# Move by CN White: g3g4   Move: 72
# Move by US Black: f6f7   Move: 73
# Move by CN White: g4g5   Move: 74
# Move by US Black: f7d7   Move: 75
# Move by CN White: e5a5   Move: 76
# Move by US Black: f8f7   Move: 77
# Move by CN White: g5h5   Move: 78
# Move by US Black: f7f8   Move: 79
# Move by CN White: h5f3   Move: 80
# Move by US Black: d6f7   Move: 81
# Move by CN White: a5a8   Move: 82
# Move by US Black: f8e7   Move: 83
# Move by CN White: f3e3   Move: 84
# Move by US Black: e7f6   Move: 85
# Move by CN White: e3f4   Move: 86
# Move by US Black: f6g6   Move: 87
# Move by CN White: f4e4   Move: 88
# Move by US Black: g6h6   Move: 89
# Move by CN White: a8e8   Move: 90
# Move by US Black: h6h5   Move: 91
# Move by CN White: e8e7   Move: 92
# Move by US Black: f7g5   Move: 93
# Move by CN White: e4e2   Move: 94
# Move by US Black: d7g4   Move: 95
# Move by CN White: e2g4   Move: 96
# Move by US Black: h5g4   Move: 97
# Move by CN White: a4a5   Move: 98
# Move by US Black: g7g6   Move: 99
# Move by CN White: e7b7   Move: 100
# Move by US Black: g5f3   Move: 101
# Move by CN White: a5a6   Move: 102
# Move by US Black: f3d4   Move: 103
# Move by CN White: a6a7   Move: 104
# Move by US Black: c6c5   Move: 105
# Move by CN White: b7f7   Move: 106
# Move by US Black: g4g5   Move: 107
# Move by CN White: a7a8q   Move: 108
# Move by US Black: d4f5   Move: 109
# Move by CN White: a8d8   Move: 110
# Move by US Black: g5g4   Move: 111
# Move by CN White: f2f3   Move: 112
# Move by US Black: g4f4   Move: 113
# Move by CN White: d8d6   Move: 114
# Move by US Black: f4e3   Move: 115
# Move by CN White: d6c5   Move: 116
# Move by US Black: e3e2   Move: 117
# Move by CN White: c5c2   Move: 118
# Move by US Black: e2e1   Move: 119
# Move by CN White: c2e4   Move: 120
# Move by US Black: e1d1   Move: 121
# Move by CN White: f7d7   Move: 122
# Move by US Black: f5d4   Move: 123
# Move by CN White: e4d4   Move: 124
# Move by US Black: d1c2   Move: 125
# Move by CN White: d4c3   Move: 126
# Move by US Black: c2b1   Move: 127
# Move by CN White: d7d1   Move: 128
# Move by US Black: b1a2   Move: 129
# Move by CN White: c3a3   Move: 130
# Game 2 result: 1-0
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 3...
# Move by CN White: e2e4   Move: 0
# Move by US Black: e7e5   Move: 1
# Move by CN White: g1f3   Move: 2
# Move by US Black: b8c6   Move: 3
# Move by CN White: f1c4   Move: 4
# Move by US Black: f8c5   Move: 5
# Move by CN White: d2d3   Move: 6
# Move by US Black: g8f6   Move: 7
# Move by CN White: c2c3   Move: 8
# Move by US Black: d7d6   Move: 9
# Move by CN White: b2b4   Move: 10
# Move by US Black: c5b6   Move: 11
# Move by CN White: a2a4   Move: 12
# Move by US Black: a7a5   Move: 13
# Move by CN White: b4b5   Move: 14
# Move by US Black: c6e7   Move: 15
# Move by CN White: e1g1   Move: 16
# Move by US Black: e8g8   Move: 17
# Move by CN White: b1d2   Move: 18
# Move by US Black: c7c6   Move: 19
# Move by CN White: b5c6   Move: 20
# Move by US Black: b7c6   Move: 21
# Move by CN White: d3d4   Move: 22
# Move by US Black: e5d4   Move: 23
# Move by CN White: c3d4   Move: 24
# Move by US Black: d6d5   Move: 25
# Move by CN White: e4e5   Move: 26
# Move by US Black: f6h5   Move: 27
# Move by CN White: c4d3   Move: 28
# Move by US Black: h5f4   Move: 29
# Move by CN White: d3c2   Move: 30
# Move by US Black: e7g6   Move: 31
# Move by CN White: c1a3   Move: 32
# Move by US Black: f8e8   Move: 33
# Move by CN White: g2g3   Move: 34
# Move by US Black: f4h3   Move: 35
# Move by CN White: g1g2   Move: 36
# Move by US Black: d8d7   Move: 37
# Move by CN White: c2g6   Move: 38
# Move by US Black: h7g6   Move: 39
# Move by CN White: a1c1   Move: 40
# Move by US Black: g6g5   Move: 41
# Move by CN White: d2b3   Move: 42
# Move by US Black: g5g4   Move: 43
# Move by CN White: f3h4   Move: 44
# Move by US Black: h3g5   Move: 45
# Move by CN White: a3c5   Move: 46
# Move by US Black: b6d8   Move: 47
# Move by CN White: c5d6   Move: 48
# Move by US Black: g5e4   Move: 49
# Move by CN White: b3c5   Move: 50
# Move by US Black: e4c5   Move: 51
# Move by CN White: d6c5   Move: 52
# Move by US Black: a8b8   Move: 53
# Move by CN White: g2g1   Move: 54
# Move by US Black: d8h4   Move: 55
# Move by CN White: g3h4   Move: 56
# Move by US Black: d7f5   Move: 57
# Move by CN White: d1c2   Move: 58
# Move by US Black: f5f3   Move: 59
# Move by CN White: c2c3   Move: 60
# Move by US Black: c8f5   Move: 61
# Move by CN White: c3f3   Move: 62
# Move by US Black: g4f3   Move: 63
# Move by CN White: c1c3   Move: 64
# Move by US Black: f5e4   Move: 65
# Move by CN White: h2h3   Move: 66
# Move by US Black: e8e6   Move: 67
# Move by CN White: g1h2   Move: 68
# Move by US Black: b8b2   Move: 69
# Move by CN White: h4h5   Move: 70
# Move by US Black: e6h6   Move: 71
# Move by CN White: c5a3   Move: 72
# Move by US Black: b2a2   Move: 73
# Move by CN White: a3c1   Move: 74
# Move by US Black: h6h5   Move: 75
# Move by CN White: h2g3   Move: 76
# Move by US Black: a2a4   Move: 77
# Move by CN White: c1e3   Move: 78
# Move by US Black: e4f5   Move: 79
# Move by CN White: h3h4   Move: 80
# Move by US Black: a4c4   Move: 81
# Move by CN White: c3c4   Move: 82
# Move by US Black: d5c4   Move: 83
# Move by CN White: f1a1   Move: 84
# Move by US Black: g8h7   Move: 85
# Move by CN White: a1a5   Move: 86
# Move by US Black: f5e6   Move: 87
# Move by CN White: a5a1   Move: 88
# Move by US Black: e6d5   Move: 89
# Move by CN White: a1g1   Move: 90
# Move by US Black: f7f6   Move: 91
# Move by CN White: e3d2   Move: 92
# Move by US Black: h7g6   Move: 93
# Move by CN White: e5f6   Move: 94
# Move by US Black: g6f6   Move: 95
# Move by CN White: g1e1   Move: 96
# Move by US Black: h5h8   Move: 97
# Move by CN White: d2g5   Move: 98
# Move by US Black: f6f5   Move: 99
# Move by CN White: e1e5   Move: 100
# Move by US Black: f5g6   Move: 101
# Move by CN White: e5e7   Move: 102
# Move by US Black: g6f5   Move: 103
# Move by CN White: e7e5   Move: 104
# Move by US Black: f5g6   Move: 105
# Move by CN White: g3g4   Move: 106
# Move by US Black: h8a8   Move: 107
# Move by CN White: e5e7   Move: 108
# Move by US Black: g6h7   Move: 109
# Move by CN White: g5f6   Move: 110
# Move by US Black: a8g8   Move: 111
# Move by CN White: f6g5   Move: 112
# Move by US Black: h7h8   Move: 113
# Move by CN White: h4h5   Move: 114
# Move by US Black: g8b8   Move: 115
# Move by CN White: g4f5   Move: 116
# Move by US Black: c4c3   Move: 117
# Move by CN White: f5g6   Move: 118
# Move by US Black: c3c2   Move: 119
# Move by CN White: h5h6   Move: 120
# Move by US Black: g7h6   Move: 121
# Move by CN White: g6h6   Move: 122
# Move by US Black: h8g8   Move: 123
# Move by CN White: h6g6   Move: 124
# Move by US Black: g8h8   Move: 125
# Move by CN White: g5f6   Move: 126
# Move by US Black: h8g8   Move: 127
# Move by CN White: f6g5   Move: 128
# Move by US Black: b8d8   Move: 129
# Move by CN White: g5c1   Move: 130
# Move by US Black: d8d6   Move: 131
# Move by CN White: g6g5   Move: 132
# Move by US Black: d5e6   Move: 133
# Move by CN White: c1a3   Move: 134
# Move by US Black: e6f7   Move: 135
# Move by CN White: e7e3   Move: 136
# Move by US Black: d6d4   Move: 137
# Move by CN White: e3c3   Move: 138
# Move by US Black: d4d2   Move: 139
# Move by CN White: c3f3   Move: 140
# Move by US Black: f7d5   Move: 141
# Move by CN White: f3e3   Move: 142
# Move by US Black: c6c5   Move: 143
# Move by CN White: e3c3   Move: 144
# Move by US Black: c5c4   Move: 145
# Move by CN White: f2f3   Move: 146
# Move by US Black: g8f7   Move: 147
# Move by CN White: g5f4   Move: 148
# Move by US Black: f7e6   Move: 149
# Move by CN White: f4e3   Move: 150
# Move by US Black: d2d1   Move: 151
# Move by CN White: a3b2   Move: 152
# Move by US Black: e6f5   Move: 153
# Move by CN White: e3f2   Move: 154
# Move by US Black: d1d2   Move: 155
# Move by CN White: f2e3   Move: 156
# Move by US Black: d2d1   Move: 157
# Move by CN White: b2a3   Move: 158
# Move by US Black: f5e5   Move: 159
# Move by CN White: e3e2   Move: 160
# Move by US Black: e5d4   Move: 161
# Move by CN White: a3b2   Move: 162
# Move by US Black: d4c5   Move: 163
# Move by CN White: c3c2   Move: 164
# Move by US Black: d1d3   Move: 165
# Move by CN White: f3f4   Move: 166
# Move by US Black: d5f3   Move: 167
# Move by CN White: e2f1   Move: 168
# Move by US Black: f3e4   Move: 169
# Move by CN White: c2c1   Move: 170
# Move by US Black: d3f3   Move: 171
# Move by CN White: f1e2   Move: 172
# Move by US Black: f3f4   Move: 173
# Move by CN White: e2e3   Move: 174
# Move by US Black: f4h4   Move: 175
# Move by CN White: b2d4   Move: 176
# Move by US Black: c5d5   Move: 177
# Move by CN White: d4c3   Move: 178
# Move by US Black: h4h7   Move: 179
# Move by CN White: c1d1   Move: 180
# Move by US Black: e4d3   Move: 181
# Move by CN White: d1g1   Move: 182
# Move by US Black: d5c6   Move: 183
# Move by CN White: e3f4   Move: 184
# Move by US Black: d3f1   Move: 185
# Move by CN White: f4e3   Move: 186
# Move by US Black: f1d3   Move: 187
# Move by CN White: g1c1   Move: 188
# Move by US Black: h7b7   Move: 189
# Move by CN White: c1h1   Move: 190
# Move by US Black: d3f5   Move: 191
# Move by CN White: h1e1   Move: 192
# Move by US Black: b7a7   Move: 193
# Move by CN White: e3d4   Move: 194
# Move by US Black: f5d3   Move: 195
# Move by CN White: e1e6   Move: 196
# Move by US Black: c6b5   Move: 197
# Move by CN White: e6e5   Move: 198
# Move by US Black: b5a4   Move: 199
# Move by CN White: e5e8   Move: 200
# Move by US Black: a4b3   Move: 201
# Move by CN White: e8b8   Move: 202
# Move by US Black: b3c2   Move: 203
# Move by CN White: b8b2   Move: 204
# Move by US Black: c2c1   Move: 205
# Move by CN White: b2f2   Move: 206
# Move by US Black: a7e7   Move: 207
# Move by CN White: f2h2   Move: 208
# Move by US Black: e7e4   Move: 209
# Move by CN White: d4d5   Move: 210
# Move by US Black: e4e2   Move: 211
# Move by CN White: h2e2   Move: 212
# Move by US Black: d3e2   Move: 213
# Move by CN White: c3e1   Move: 214
# Move by US Black: c1b2   Move: 215
# Move by CN White: e1h4   Move: 216
# Move by US Black: b2c3   Move: 217
# Move by CN White: h4f6   Move: 218
# Move by US Black: c3b3   Move: 219
# Move by CN White: f6a1   Move: 220
# Move by US Black: e2g4   Move: 221
# Move by CN White: d5d4   Move: 222
# Move by US Black: g4c8   Move: 223
# Move by CN White: a1c3   Move: 224
# Move by US Black: c8e6   Move: 225
# Move by CN White: c3e1   Move: 226
# Move by US Black: e6g4   Move: 227
# Move by CN White: e1a5   Move: 228
# Move by US Black: g4e6   Move: 229
# Move by CN White: a5e1   Move: 230
# Move by US Black: e6f5   Move: 231
# Move by CN White: e1d2   Move: 232
# Move by US Black: f5c8   Move: 233
# Move by CN White: d2a5   Move: 234
# Move by US Black: c8h3   Move: 235
# Move by CN White: a5d2   Move: 236
# Move by US Black: h3e6   Move: 237
# Move by CN White: d2a5   Move: 238
# Move by US Black: e6f5   Move: 239
# Move by CN White: a5e1   Move: 240
# Move by US Black: f5e4   Move: 241
# Move by CN White: d4e4   Move: 242
# Move by US Black: c4c3   Move: 243
# Move by CN White: e1c3   Move: 244
# Game 3 result: 1/2-1/2
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 10, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 10, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 4...
# Move by CN White: e2e4   Move: 0
# Move by US Black: d7d6   Move: 1
# Move by CN White: d2d4   Move: 2
# Move by US Black: g8f6   Move: 3
# Move by CN White: f2f3   Move: 4
# Move by US Black: b8d7   Move: 5
# Move by CN White: g1e2   Move: 6
# Move by US Black: c7c6   Move: 7
# Move by CN White: c1e3   Move: 8
# Move by US Black: b7b5   Move: 9
# Move by CN White: a2a4   Move: 10
# Move by US Black: b5a4   Move: 11
# Move by CN White: e2c3   Move: 12
# Move by US Black: e7e5   Move: 13
# Move by CN White: d4e5   Move: 14
# Move by US Black: d6e5   Move: 15
# Move by CN White: c3a4   Move: 16
# Move by US Black: d8c7   Move: 17
# Move by CN White: f1d3   Move: 18
# Move by US Black: f6h5   Move: 19
# Move by CN White: e1f2   Move: 20
# Move by US Black: g7g6   Move: 21
# Move by CN White: d1d2   Move: 22
# Move by US Black: h5f4   Move: 23
# Move by CN White: h1d1   Move: 24
# Move by US Black: f8e7   Move: 25
# Move by CN White: d3c4   Move: 26
# Move by US Black: h7h5   Move: 27
# Move by CN White: g2g3   Move: 28
# Move by US Black: g6g5   Move: 29
# Move by CN White: b1c3   Move: 30
# Move by US Black: h8h6   Move: 31
# Move by CN White: b2b3   Move: 32
# Move by US Black: h6d6   Move: 33
# Move by CN White: d2c1   Move: 34
# Move by US Black: a7a5   Move: 35
# Move by CN White: h2h4   Move: 36
# Move by US Black: f4h3   Move: 37
# Move by CN White: f2g2   Move: 38
# Move by US Black: h3f4   Move: 39
# Move by CN White: g2h1   Move: 40
# Move by US Black: d6g6   Move: 41
# Move by CN White: c1d2   Move: 42
# Move by US Black: c7b8   Move: 43
# Move by CN White: d2h2   Move: 44
# Move by US Black: d7f6   Move: 45
# Move by CN White: h4g5   Move: 46
# Move by US Black: h5h4   Move: 47
# Move by CN White: g3f4   Move: 48
# Move by US Black: f6h5   Move: 49
# Move by CN White: h2h4   Move: 50
# Move by US Black: e5f4   Move: 51
# Move by CN White: h4h5   Move: 52
# Move by US Black: e7f8   Move: 53
# Move by CN White: e3g1   Move: 54
# Move by US Black: f8g7   Move: 55
# Move by CN White: c3e2   Move: 56
# Move by US Black: c8a6   Move: 57
# Move by CN White: c4f7   Move: 58
# Move by US Black: e8f7   Move: 59
# Move by CN White: d1d7   Move: 60
# Move by US Black: f7g8   Move: 61
# Move by CN White: h5g6   Move: 62
# Move by US Black: b8f8   Move: 63
# Move by CN White: d7g7   Move: 64
# Move by US Black: f8g7   Move: 65
# Move by CN White: e2f4   Move: 66
# Move by US Black: g7g6   Move: 67
# Move by CN White: f4g6   Move: 68
# Move by US Black: a8d8   Move: 69
# Move by CN White: g6e7   Move: 70
# Move by US Black: g8f7   Move: 71
# Move by CN White: e7f5   Move: 72
# Move by US Black: a6b5   Move: 73
# Move by CN White: h1g2   Move: 74
# Move by US Black: f7g6   Move: 75
# Move by CN White: f5d4   Move: 76
# Move by US Black: d8h8   Move: 77
# Move by CN White: a4c3   Move: 78
# Move by US Black: h8h5   Move: 79
# Move by CN White: f3f4   Move: 80
# Move by US Black: h5h4   Move: 81
# Move by CN White: f4f5   Move: 82
# Move by US Black: g6f7   Move: 83
# Move by CN White: g1f2   Move: 84
# Move by US Black: h4g4   Move: 85
# Move by CN White: f2g3   Move: 86
# Move by US Black: c6c5   Move: 87
# Move by CN White: g5g6   Move: 88
# Move by US Black: f7g8   Move: 89
# Move by CN White: d4e6   Move: 90
# Move by US Black: b5d7   Move: 91
# Move by CN White: g2f3   Move: 92
# Move by US Black: c5c4   Move: 93
# Move by CN White: g3e5   Move: 94
# Move by US Black: g4g6   Move: 95
# Move by CN White: f5g6   Move: 96
# Move by US Black: d7e8   Move: 97
# Move by CN White: a1h1   Move: 98
# Move by US Black: e8g6   Move: 99
# Move by CN White: h1h8   Move: 100
# Move by US Black: g8f7   Move: 101
# Move by CN White: e6d4   Move: 102
# Move by US Black: c4b3   Move: 103
# Move by CN White: c2b3   Move: 104
# Move by US Black: g6e4   Move: 105
# Move by CN White: f3e4   Move: 106
# Move by US Black: f7g6   Move: 107
# Move by CN White: e4d5   Move: 108
# Move by US Black: g6g5   Move: 109
# Move by CN White: c3e4   Move: 110
# Move by US Black: g5g4   Move: 111
# Move by CN White: e5g3   Move: 112
# Move by US Black: a5a4   Move: 113
# Move by CN White: d5c6   Move: 114
# Move by US Black: a4a3   Move: 115
# Move by CN White: c6b5   Move: 116
# Move by US Black: a3a2   Move: 117
# Move by CN White: h8h4   Move: 118
# Game 4 result: 1-0
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 5...
# Move by CN White: e2e4   Move: 0
# Move by US Black: e7e5   Move: 1
# Move by CN White: g1f3   Move: 2
# Move by US Black: g8f6   Move: 3
# Move by CN White: f3e5   Move: 4
# Move by US Black: f6e4   Move: 5
# Move by CN White: d1e2   Move: 6
# Move by US Black: d7d5   Move: 7
# Move by CN White: d2d3   Move: 8
# Move by US Black: d8e7   Move: 9
# Move by CN White: d3e4   Move: 10
# Move by US Black: e7e5   Move: 11
# Move by CN White: e4d5   Move: 12
# Move by US Black: f8d6   Move: 13
# Move by CN White: b1c3   Move: 14
# Move by US Black: b8d7   Move: 15
# Move by CN White: c1e3   Move: 16
# Move by US Black: e8g8   Move: 17
# Move by CN White: e2d2   Move: 18
# Move by US Black: f8e8   Move: 19
# Move by CN White: e1c1   Move: 20
# Move by US Black: d7f6   Move: 21
# Move by CN White: f1b5   Move: 22
# Move by US Black: c8d7   Move: 23
# Move by CN White: b5d7   Move: 24
# Move by US Black: f6d7   Move: 25
# Move by CN White: e3d4   Move: 26
# Move by US Black: e5f5   Move: 27
# Move by CN White: c1b1   Move: 28
# Move by US Black: d6f4   Move: 29
# Move by CN White: d2d3   Move: 30
# Move by US Black: f5d3   Move: 31
# Move by CN White: d1d3   Move: 32
# Move by US Black: a7a6   Move: 33
# Move by CN White: a2a3   Move: 34
# Move by US Black: f4d6   Move: 35
# Move by CN White: d3d1   Move: 36
# Move by US Black: f7f5   Move: 37
# Move by CN White: b2b4   Move: 38
# Move by US Black: g7g5   Move: 39
# Move by CN White: b1a2   Move: 40
# Move by US Black: g8f7   Move: 41
# Move by CN White: a2b3   Move: 42
# Move by US Black: d7f6   Move: 43
# Move by CN White: h2h3   Move: 44
# Move by US Black: h7h5   Move: 45
# Move by CN White: h1e1   Move: 46
# Move by US Black: a8d8   Move: 47
# Move by CN White: d4f6   Move: 48
# Move by US Black: f7f6   Move: 49
# Move by CN White: c3a2   Move: 50
# Move by US Black: g5g4   Move: 51
# Move by CN White: c2c4   Move: 52
# Move by US Black: b7b6   Move: 53
# Move by CN White: h3h4   Move: 54
# Move by US Black: d8c8   Move: 55
# Move by CN White: a2c3   Move: 56
# Move by US Black: g4g3   Move: 57
# Move by CN White: f2f3   Move: 58
# Move by US Black: f6f7   Move: 59
# Move by CN White: b3c2   Move: 60
# Move by US Black: d6e7   Move: 61
# Move by CN White: e1e6   Move: 62
# Move by US Black: e7h4   Move: 63
# Move by CN White: d1h1   Move: 64
# Move by US Black: h4f6   Move: 65
# Move by CN White: h1h5   Move: 66
# Move by US Black: e8e6   Move: 67
# Move by CN White: d5e6   Move: 68
# Move by US Black: f7e6   Move: 69
# Move by CN White: c3d5   Move: 70
# Move by US Black: c7c6   Move: 71
# Move by CN White: d5b6   Move: 72
# Move by US Black: c8e8   Move: 73
# Move by CN White: c4c5   Move: 74
# Move by US Black: e6f7   Move: 75
# Move by CN White: h5f5   Move: 76
# Move by US Black: f7g6   Move: 77
# Move by CN White: f5f4   Move: 78
# Move by US Black: e8e2   Move: 79
# Move by CN White: c2b3   Move: 80
# Move by US Black: e2g2   Move: 81
# Move by CN White: b6c4   Move: 82
# Move by US Black: g6f7   Move: 83
# Move by CN White: f4g4   Move: 84
# Move by US Black: f7e6   Move: 85
# Move by CN White: g4e4   Move: 86
# Move by US Black: e6d7   Move: 87
# Move by CN White: e4f4   Move: 88
# Move by US Black: d7e7   Move: 89
# Move by CN White: f4g4   Move: 90
# Move by US Black: e7e6   Move: 91
# Move by CN White: g4e4   Move: 92
# Move by US Black: e6d7   Move: 93
# Move by CN White: e4g4   Move: 94
# Move by US Black: d7e6   Move: 95
# Move by CN White: b3a4   Move: 96
# Move by US Black: g2c2   Move: 97
# Move by CN White: a4a5   Move: 98
# Move by US Black: g3g2   Move: 99
# Move by CN White: c4e3   Move: 100
# Move by US Black: c2c3   Move: 101
# Move by CN White: e3g2   Move: 102
# Move by US Black: c3a3   Move: 103
# Move by CN White: a5b6   Move: 104
# Move by US Black: e6d7   Move: 105
# Move by CN White: g4f4   Move: 106
# Move by US Black: f6c3   Move: 107
# Move by CN White: f4f7   Move: 108
# Move by US Black: d7e8   Move: 109
# Move by CN White: f7f4   Move: 110
# Move by US Black: e8d7   Move: 111
# Move by CN White: f4f7   Move: 112
# Move by US Black: d7e6   Move: 113
# Move by CN White: f7f4   Move: 114
# Move by US Black: e6d7   Move: 115
# Move by CN White: g2h4   Move: 116
# Move by US Black: a6a5   Move: 117
# Move by CN White: b4b5   Move: 118
# Move by US Black: a3b3   Move: 119
# Move by CN White: f4f7   Move: 120
# Move by US Black: d7e6   Move: 121
# Move by CN White: f7h7   Move: 122
# Move by US Black: b3b5   Move: 123
# Move by CN White: b6c6   Move: 124
# Move by US Black: b5b3   Move: 125
# Move by CN White: h4g6   Move: 126
# Move by US Black: c3b2   Move: 127
# Move by CN White: g6f8   Move: 128
# Move by US Black: e6f6   Move: 129
# Move by CN White: f8d7   Move: 130
# Move by US Black: f6g6   Move: 131
# Move by CN White: h7h4   Move: 132
# Move by US Black: b3f3   Move: 133
# Move by CN White: c6c7   Move: 134
# Move by US Black: g6g5   Move: 135
# Move by CN White: h4a4   Move: 136
# Move by US Black: f3a3   Move: 137
# Move by CN White: a4a3   Move: 138
# Move by US Black: b2a3   Move: 139
# Move by CN White: c5c6   Move: 140
# Move by US Black: a5a4   Move: 141
# Move by CN White: d7e5   Move: 142
# Move by US Black: a3b2   Move: 143
# Move by CN White: e5c4   Move: 144
# Move by US Black: b2c1   Move: 145
# Move by CN White: c7b6   Move: 146
# Move by US Black: c1f4   Move: 147
# Move by CN White: b6a5   Move: 148
# Move by US Black: f4c7   Move: 149
# Move by CN White: a5a4   Move: 150
# Move by US Black: g5f5   Move: 151
# Move by CN White: a4b5   Move: 152
# Move by US Black: f5e6   Move: 153
# Move by CN White: b5c5   Move: 154
# Move by US Black: c7d8   Move: 155
# Move by CN White: c4e3   Move: 156
# Move by US Black: d8c7   Move: 157
# Move by CN White: e3c4   Move: 158
# Move by US Black: e6e7   Move: 159
# Move by CN White: c5b5   Move: 160
# Move by US Black: e7e6   Move: 161
# Move by CN White: b5c5   Move: 162
# Move by US Black: c7d8   Move: 163
# Move by CN White: c4b6   Move: 164
# Move by US Black: d8e7   Move: 165
# Move by CN White: c5b5   Move: 166
# Move by US Black: e7d8   Move: 167
# Move by CN White: b5c5   Move: 168
# Move by US Black: d8e7   Move: 169
# Move by CN White: c5b5   Move: 170
# Move by US Black: e7d8   Move: 171
# Move by CN White: b5c5   Move: 172
# Move by US Black: e6e5   Move: 173
# Move by CN White: b6c4   Move: 174
# Move by US Black: e5e6   Move: 175
# Move by CN White: c4e3   Move: 176
# Move by US Black: d8e7   Move: 177
# Move by CN White: c5b5   Move: 178
# Move by US Black: e7d8   Move: 179
# Move by CN White: b5a6   Move: 180
# Move by US Black: e6d6   Move: 181
# Move by CN White: a6b7   Move: 182
# Move by US Black: d6e6   Move: 183
# Move by CN White: e3f5   Move: 184
# Move by US Black: e6d5   Move: 185
# Move by CN White: f5e7   Move: 186
# Move by US Black: d5d6   Move: 187
# Move by CN White: e7g8   Move: 188
# Move by US Black: d6e5   Move: 189
# Move by CN White: g8h6   Move: 190
# Move by US Black: e5d5   Move: 191
# Move by CN White: h6f5   Move: 192
# Move by US Black: d8a5   Move: 193
# Move by CN White: f5e3   Move: 194
# Move by US Black: d5e6   Move: 195
# Move by CN White: e3c4   Move: 196
# Move by US Black: a5d8   Move: 197
# Move by CN White: b7c8   Move: 198
# Move by US Black: e6d5   Move: 199
# Move by CN White: c8d7   Move: 200
# Move by US Black: d5c5   Move: 201
# Move by CN White: c4d2   Move: 202
# Move by US Black: d8b6   Move: 203
# Move by CN White: d2e4   Move: 204
# Move by US Black: c5d5   Move: 205
# Move by CN White: e4c3   Move: 206
# Move by US Black: d5c4   Move: 207
# Move by CN White: c3a4   Move: 208
# Move by US Black: b6a5   Move: 209
# Move by CN White: d7d6   Move: 210
# Move by US Black: a5e1   Move: 211
# Move by CN White: d6c7   Move: 212
# Move by US Black: c4b5   Move: 213
# Move by CN White: a4b2   Move: 214
# Move by US Black: e1g3   Move: 215
# Move by CN White: c7b7   Move: 216
# Move by US Black: g3h2   Move: 217
# Move by CN White: b2d1   Move: 218
# Move by US Black: h2b8   Move: 219
# Move by CN White: d1c3   Move: 220
# Move by US Black: b5c5   Move: 221
# Move by CN White: c3e4   Move: 222
# Move by US Black: c5b5   Move: 223
# Move by CN White: e4c3   Move: 224
# Move by US Black: b5c5   Move: 225
# Move by CN White: c3a4   Move: 226
# Move by US Black: c5b5   Move: 227
# Move by CN White: a4c3   Move: 228
# Move by US Black: b5c5   Move: 229
# Move by CN White: c3e4   Move: 230
# Move by US Black: c5b5   Move: 231
# Move by CN White: e4c3   Move: 232
# Move by US Black: b5c5   Move: 233
# Move by CN White: c3a4   Move: 234
# Move by US Black: c5b5   Move: 235
# Move by CN White: a4c3   Move: 236
# Game 5 result: 1/2-1/2
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 6...
# Move by CN White: e2e4   Move: 0
# Move by US Black: c7c5   Move: 1
# Move by CN White: g1f3   Move: 2
# Move by US Black: d7d6   Move: 3
# Move by CN White: d2d4   Move: 4
# Move by US Black: c5d4   Move: 5
# Move by CN White: f3d4   Move: 6
# Move by US Black: g8f6   Move: 7
# Move by CN White: b1c3   Move: 8
# Move by US Black: a7a6   Move: 9
# Move by CN White: c1g5   Move: 10
# Move by US Black: e7e6   Move: 11
# Move by CN White: f2f4   Move: 12
# Move by US Black: f8e7   Move: 13
# Move by CN White: d1f3   Move: 14
# Move by US Black: d8c7   Move: 15
# Move by CN White: e1c1   Move: 16
# Move by US Black: b8d7   Move: 17
# Move by CN White: g2g4   Move: 18
# Move by US Black: b7b5   Move: 19
# Move by CN White: g5f6   Move: 20
# Move by US Black: e7f6   Move: 21
# Move by CN White: f1b5   Move: 22
# Move by US Black: a8b8   Move: 23
# Move by CN White: b5d7   Move: 24
# Move by US Black: c8d7   Move: 25
# Move by CN White: f3e3   Move: 26
# Move by US Black: c7b6   Move: 27
# Move by CN White: b2b3   Move: 28
# Move by US Black: h7h6   Move: 29
# Move by CN White: h2h4   Move: 30
# Move by US Black: b6c5   Move: 31
# Move by CN White: e3d3   Move: 32
# Move by US Black: b8c8   Move: 33
# Move by CN White: c1b2   Move: 34
# Move by US Black: e6e5   Move: 35
# Move by CN White: d4f5   Move: 36
# Move by US Black: d7f5   Move: 37
# Move by CN White: g4g5   Move: 38
# Move by US Black: c5c3   Move: 39
# Move by CN White: d3c3   Move: 40
# Move by US Black: c8c3   Move: 41
# Move by CN White: b2c3   Move: 42
# Move by US Black: f5e4   Move: 43
# Move by CN White: h1e1   Move: 44
# Move by US Black: h6g5   Move: 45
# Move by CN White: h4g5   Move: 46
# Move by US Black: f6g5   Move: 47
# Move by CN White: e1e4   Move: 48
# Move by US Black: g5f4   Move: 49
# Move by CN White: d1d6   Move: 50
# Move by US Black: e8g8   Move: 51
# Move by CN White: b3b4   Move: 52
# Move by US Black: g7g5   Move: 53
# Move by CN White: d6a6   Move: 54
# Move by US Black: g5g4   Move: 55
# Move by CN White: b4b5   Move: 56
# Move by US Black: f7f5   Move: 57
# Move by CN White: e4e1   Move: 58
# Move by US Black: g4g3   Move: 59
# Move by CN White: b5b6   Move: 60
# Move by US Black: f8c8   Move: 61
# Move by CN White: c3b3   Move: 62
# Move by US Black: g8f7   Move: 63
# Move by CN White: a2a4   Move: 64
# Move by US Black: e5e4   Move: 65
# Move by CN White: a4a5   Move: 66
# Move by US Black: f4e5   Move: 67
# Move by CN White: a6a7   Move: 68
# Move by US Black: f7f6   Move: 69
# Move by CN White: a5a6   Move: 70
# Move by US Black: c8b8   Move: 71
# Move by CN White: a7b7   Move: 72
# Move by US Black: b8a8   Move: 73
# Move by CN White: b7a7   Move: 74
# Move by US Black: a8b8   Move: 75
# Move by CN White: a7b7   Move: 76
# Move by US Black: b8a8   Move: 77
# Move by CN White: a6a7   Move: 78
# Move by US Black: f5f4   Move: 79
# Move by CN White: b7h7   Move: 80
# Move by US Black: f4f3   Move: 81
# Move by CN White: h7h6   Move: 82
# Move by US Black: f6f7   Move: 83
# Move by CN White: e1d1   Move: 84
# Move by US Black: g3g2   Move: 85
# Move by CN White: d1d7   Move: 86
# Move by US Black: f7e8   Move: 87
# Move by CN White: d7g7   Move: 88
# Move by US Black: e8f8   Move: 89
# Move by CN White: g7g2   Move: 90
# Move by US Black: f3g2   Move: 91
# Move by CN White: h6g6   Move: 92
# Move by US Black: e5b8   Move: 93
# Move by CN White: g6g2   Move: 94
# Move by US Black: b8a7   Move: 95
# Move by CN White: b6a7   Move: 96
# Move by US Black: a8a7   Move: 97
# Move by CN White: g2e2   Move: 98
# Move by US Black: f8e7   Move: 99
# Move by CN White: e2e4   Move: 100
# Move by US Black: e7d6   Move: 101
# Move by CN White: e4h4   Move: 102
# Move by US Black: d6c5   Move: 103
# Move by CN White: h4h5   Move: 104
# Move by US Black: c5c6   Move: 105
# Move by CN White: h5h3   Move: 106
# Move by US Black: c6d5   Move: 107
# Move by CN White: h3d3   Move: 108
# Move by US Black: d5c6   Move: 109
# Move by CN White: d3h3   Move: 110
# Move by US Black: a7f7   Move: 111
# Move by CN White: c2c4   Move: 112
# Move by US Black: f7f1   Move: 113
# Move by CN White: b3b4   Move: 114
# Move by US Black: f1b1   Move: 115
# Move by CN White: b4c3   Move: 116
# Move by US Black: b1c1   Move: 117
# Move by CN White: c3d3   Move: 118
# Move by US Black: c1d1   Move: 119
# Move by CN White: d3c3   Move: 120
# Move by US Black: d1c1   Move: 121
# Move by CN White: c3d3   Move: 122
# Move by US Black: c1g1   Move: 123
# Move by CN White: d3d4   Move: 124
# Move by US Black: g1g4   Move: 125
# Move by CN White: d4d3   Move: 126
# Move by US Black: c6c7   Move: 127
# Move by CN White: d3c2   Move: 128
# Move by US Black: g4c4   Move: 129
# Move by CN White: h3c3   Move: 130
# Move by US Black: c4c3   Move: 131
# Move by CN White: c2c3   Move: 132
# Game 6 result: 1/2-1/2
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 10, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 7...
# Move by CN White: e2e4   Move: 0
# Move by US Black: c7c5   Move: 1
# Move by CN White: g1f3   Move: 2
# Move by US Black: b8c6   Move: 3
# Move by CN White: f1b5   Move: 4
# Move by US Black: d7d6   Move: 5
# Move by CN White: e1g1   Move: 6
# Move by US Black: g8f6   Move: 7
# Move by CN White: e4e5   Move: 8
# Move by US Black: f6g4   Move: 9
# Move by CN White: e5d6   Move: 10
# Move by US Black: g4f6   Move: 11
# Move by CN White: b5c6   Move: 12
# Move by US Black: b7c6   Move: 13
# Move by CN White: d6e7   Move: 14
# Move by US Black: f8e7   Move: 15
# Move by CN White: d2d3   Move: 16
# Move by US Black: c8e6   Move: 17
# Move by CN White: b2b3   Move: 18
# Move by US Black: f6d5   Move: 19
# Move by CN White: f3e5   Move: 20
# Move by US Black: d8c7   Move: 21
# Move by CN White: f1e1   Move: 22
# Move by US Black: e8g8   Move: 23
# Move by CN White: b1d2   Move: 24
# Move by US Black: e7f6   Move: 25
# Move by CN White: c1b2   Move: 26
# Move by US Black: a7a5   Move: 27
# Move by CN White: c2c4   Move: 28
# Move by US Black: d5b4   Move: 29
# Move by CN White: a2a3   Move: 30
# Move by US Black: a5a4   Move: 31
# Move by CN White: b3a4   Move: 32
# Move by US Black: b4a6   Move: 33
# Move by CN White: d1f3   Move: 34
# Move by US Black: a6b8   Move: 35
# Move by CN White: f3g3   Move: 36
# Move by US Black: f8c8   Move: 37
# Move by CN White: a1b1   Move: 38
# Move by US Black: f6d8   Move: 39
# Move by CN White: d2e4   Move: 40
# Move by US Black: d8e7   Move: 41
# Move by CN White: h2h4   Move: 42
# Move by US Black: e7f8   Move: 43
# Move by CN White: e1e3   Move: 44
# Move by US Black: a8a7   Move: 45
# Move by CN White: b1e1   Move: 46
# Move by US Black: b8d7   Move: 47
# Move by CN White: e5d7   Move: 48
# Move by US Black: e6d7   Move: 49
# Move by CN White: e4f6   Move: 50
# Move by US Black: g8h8   Move: 51
# Move by CN White: b2e5   Move: 52
# Move by US Black: c7d8   Move: 53
# Move by CN White: g3f4   Move: 54
# Move by US Black: c8a8   Move: 55
# Move by CN White: f6h5   Move: 56
# Move by US Black: f7f6   Move: 57
# Move by CN White: h5f6   Move: 58
# Move by US Black: d7e6   Move: 59
# Move by CN White: e5c3   Move: 60
# Move by US Black: e6f7   Move: 61
# Move by CN White: f6g4   Move: 62
# Move by US Black: f7h5   Move: 63
# Move by CN White: g4e5   Move: 64
# Move by US Black: f8d6   Move: 65
# Move by CN White: a4a5   Move: 66
# Move by US Black: h7h6   Move: 67
# Move by CN White: f4f5   Move: 68
# Move by US Black: d6e5   Move: 69
# Move by CN White: f5e5   Move: 70
# Move by US Black: h5g4   Move: 71
# Move by CN White: e5f4   Move: 72
# Move by US Black: d8f8   Move: 73
# Move by CN White: f4g4   Move: 74
# Move by US Black: a7f7   Move: 75
# Move by CN White: g4e2   Move: 76
# Move by US Black: h8g8   Move: 77
# Move by CN White: e3g3   Move: 78
# Move by US Black: f8d6   Move: 79
# Move by CN White: e2e3   Move: 80
# Move by US Black: a8d8   Move: 81
# Move by CN White: a5a6   Move: 82
# Move by US Black: f7d7   Move: 83
# Move by CN White: h4h5   Move: 84
# Move by US Black: d7a7   Move: 85
# Move by CN White: a3a4   Move: 86
# Move by US Black: a7f7   Move: 87
# Move by CN White: e3e6   Move: 88
# Move by US Black: d6e6   Move: 89
# Move by CN White: e1e6   Move: 90
# Move by US Black: g8h7   Move: 91
# Move by CN White: e6c6   Move: 92
# Move by US Black: d8b8   Move: 93
# Move by CN White: c6g6   Move: 94
# Move by US Black: h7h8   Move: 95
# Move by CN White: g1h2   Move: 96
# Move by US Black: b8b1   Move: 97
# Move by CN White: g6h6   Move: 98
# Move by US Black: h8g8   Move: 99
# Move by CN White: h6g6   Move: 100
# Move by US Black: g8h8   Move: 101
# Move by CN White: g6g7   Move: 102
# Move by US Black: f7g7   Move: 103
# Move by CN White: a6a7   Move: 104
# Move by US Black: b1b7   Move: 105
# Move by CN White: a7a8q   Move: 106
# Move by US Black: h8h7   Move: 107
# Move by CN White: a8f8   Move: 108
# Move by US Black: b7a7   Move: 109
# Move by CN White: g3g7   Move: 110
# Move by US Black: a7g7   Move: 111
# Move by CN White: f8g7   Move: 112
# Game 7 result: 1-0
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 8...
# Move by CN White: e2e4   Move: 0
# Move by US Black: c7c5   Move: 1
# Move by CN White: g1f3   Move: 2
# Move by US Black: b8c6   Move: 3
# Move by CN White: f1b5   Move: 4
# Move by US Black: g7g6   Move: 5
# Move by CN White: e1g1   Move: 6
# Move by US Black: f8g7   Move: 7
# Move by CN White: b5c6   Move: 8
# Move by US Black: b7c6   Move: 9
# Move by CN White: f1e1   Move: 10
# Move by US Black: d8c7   Move: 11
# Move by CN White: c2c3   Move: 12
# Move by US Black: d7d6   Move: 13
# Move by CN White: d2d4   Move: 14
# Move by US Black: c5d4   Move: 15
# Move by CN White: c3d4   Move: 16
# Move by US Black: c8g4   Move: 17
# Move by CN White: b1d2   Move: 18
# Move by US Black: g8f6   Move: 19
# Move by CN White: h2h3   Move: 20
# Move by US Black: g4f3   Move: 21
# Move by CN White: d2f3   Move: 22
# Move by US Black: e8g8   Move: 23
# Move by CN White: c1d2   Move: 24
# Move by US Black: a7a5   Move: 25
# Move by CN White: a1c1   Move: 26
# Move by US Black: f8c8   Move: 27
# Move by CN White: e4e5   Move: 28
# Move by US Black: f6d5   Move: 29
# Move by CN White: h3h4   Move: 30
# Move by US Black: d6e5   Move: 31
# Move by CN White: d4e5   Move: 32
# Move by US Black: e7e6   Move: 33
# Move by CN White: c1c4   Move: 34
# Move by US Black: c7b7   Move: 35
# Move by CN White: b2b3   Move: 36
# Move by US Black: d5b6   Move: 37
# Move by CN White: c4c3   Move: 38
# Move by US Black: b6d5   Move: 39
# Move by CN White: c3c4   Move: 40
# Move by US Black: c8d8   Move: 41
# Move by CN White: d1e2   Move: 42
# Move by US Black: d5b4   Move: 43
# Move by CN White: d2g5   Move: 44
# Move by US Black: d8d5   Move: 45
# Move by CN White: g5f6   Move: 46
# Move by US Black: b4d3   Move: 47
# Move by CN White: e1d1   Move: 48
# Move by US Black: b7d7   Move: 49
# Move by CN White: c4d4   Move: 50
# Move by US Black: g7f6   Move: 51
# Move by CN White: d4d5   Move: 52
# Move by US Black: e6d5   Move: 53
# Move by CN White: e5f6   Move: 54
# ...
# Move by CN White: h2h3   Move: 130
# Move by US Black: g8g7   Move: 131
# Move by CN White: g3f4   Move: 132
# Move by US Black: f5d4   Move: 133
# Move by CN White: c6c8   Move: 134
# Move by US Black: d4f5   Move: 135
# Move by CN White: c8c6   Move: 136
# Move by US Black: f5d4   Move: 137
# Move by CN White: c6e4   Move: 138
# Move by US Black: d4f5   Move: 139
# Move by CN White: e4c6   Move: 140
# Move by US Black: f5d4   Move: 141
# Move by CN White: c6e4   Move: 142
# Move by US Black: d4f5   Move: 143
# Move by CN White: e1d1   Move: 144
# Move by US Black: g7g8   Move: 145
# Move by CN White: e4a8   Move: 146
# Move by US Black: g8h7   Move: 147
# Move by CN White: a8e4   Move: 148
# Move by US Black: a7a5   Move: 149
# Move by CN White: g2g4   Move: 150
# Move by US Black: h5g4   Move: 151
# Move by CN White: f3g4   Move: 152
# Move by US Black: f5g7   Move: 153
# Move by CN White: h3g3   Move: 154
# Move by US Black: a5a4   Move: 155
# Move by CN White: h4h5   Move: 156
# Move by US Black: f6f5   Move: 157
# Move by CN White: h5g6   Move: 158
# Move by US Black: f7g6   Move: 159
# Move by CN White: e4h1   Move: 160
# Move by US Black: h7g8   Move: 161
# Move by CN White: h1d5   Move: 162
# Move by US Black: g8f8   Move: 163
# Move by CN White: g4g5   Move: 164
# Move by US Black: g7h5   Move: 165
# Move by CN White: g3f3   Move: 166
# Move by US Black: h5f4   Move: 167
# Move by CN White: f3f4   Move: 168
# Move by US Black: a4a3   Move: 169
# Move by CN White: d5a8   Move: 170
# Move by US Black: f8g7   Move: 171
# Move by CN White: a8a3   Move: 172
# Move by US Black: g6h5   Move: 173
# Move by CN White: a3a1   Move: 174
# Move by US Black: g7g8   Move: 175
# Move by CN White: a1a8   Move: 176
# Move by US Black: g8g7   Move: 177
# Move by CN White: a8f3   Move: 178
# Move by US Black: h5h2   Move: 179
# Move by CN White: f3g3   Move: 180
# Move by US Black: h2e2   Move: 181
# Move by CN White: g3c3   Move: 182
# Move by US Black: g7g8   Move: 183
# Move by CN White: c3d3   Move: 184
# Move by US Black: e2h2   Move: 185
# Move by CN White: d3g3   Move: 186
# Move by US Black: h2e2   Move: 187
# Move by CN White: g3f3   Move: 188
# Move by US Black: e2h2   Move: 189
# Move by CN White: f3g3   Move: 190
# Move by US Black: h2e2   Move: 191
# Move by CN White: g3f3   Move: 192
# Move by US Black: e2h2   Move: 193
# Move by CN White: f3g3   Move: 194
# Move by US Black: h2e2   Move: 195
# Move by CN White: g3d3   Move: 196
# Move by US Black: e2h2   Move: 197
# Move by CN White: d3g3   Move: 198
# Move by US Black: h2e2   Move: 199
# Move by CN White: g3d3   Move: 200
# Move by US Black: e2h2   Move: 201
# Move by CN White: d3g3   Move: 202
# Game 97 result: 1/2-1/2
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 10, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 98...
# Move by CN White: d2d4   Move: 0
# Move by US Black: d7d5   Move: 1
# Move by CN White: e2e3   Move: 2
# Move by US Black: g8f6   Move: 3
# Move by CN White: g1f3   Move: 4
# Move by US Black: e7e6   Move: 5
# Move by CN White: f1d3   Move: 6
# Move by US Black: c7c5   Move: 7
# Move by CN White: c2c3   Move: 8
# Move by US Black: b7b6   Move: 9
# Move by CN White: e1g1   Move: 10
# Move by US Black: c8b7   Move: 11
# Move by CN White: f1e1   Move: 12
# Move by US Black: b8d7   Move: 13
# Move by CN White: b1d2   Move: 14
# Move by US Black: f8e7   Move: 15
# Move by CN White: b2b3   Move: 16
# Move by US Black: e8g8   Move: 17
# Move by CN White: c3c4   Move: 18
# Move by US Black: a8c8   Move: 19
# Move by CN White: c1a3   Move: 20
# Move by US Black: c5d4   Move: 21
# Move by CN White: a3e7   Move: 22
# Move by US Black: d8e7   Move: 23
# Move by CN White: e3d4   Move: 24
# Move by US Black: d7b8   Move: 25
# Move by CN White: d1b1   Move: 26
# Move by US Black: f8d8   Move: 27
# Move by CN White: d3e2   Move: 28
# Move by US Black: f6e4   Move: 29
# Move by CN White: b1b2   Move: 30
# Move by US Black: d5c4   Move: 31
# Move by CN White: b3c4   Move: 32
# Move by US Black: e4d2   Move: 33
# Move by CN White: b2d2   Move: 34
# Move by US Black: b7f3   Move: 35
# Move by CN White: e2f3   Move: 36
# Move by US Black: c8c4   Move: 37
# Move by CN White: a1d1   Move: 38
# Move by US Black: d8d4   Move: 39
# Move by CN White: d2d4   Move: 40
# Move by US Black: c4d4   Move: 41
# Move by CN White: d1d4   Move: 42
# Move by US Black: b8d7   Move: 43
# Move by CN White: d4c4   Move: 44
# Move by US Black: d7c5   Move: 45
# Move by CN White: g2g3   Move: 46
# Move by US Black: e7f6   Move: 47
# Move by CN White: f3e2   Move: 48
# Move by US Black: f6b2   Move: 49
# Move by CN White: e2f1   Move: 50
# Move by US Black: g7g6   Move: 51
# Move by CN White: a2a4   Move: 52
# Move by US Black: a7a5   Move: 53
# Move by CN White: e1e2   Move: 54
# Move by US Black: b2b1   Move: 55
# Move by CN White: h2h3   Move: 56
# Move by US Black: g8g7   Move: 57
# Move by CN White: h3h4   Move: 58
# Move by US Black: b1a1   Move: 59
# Move by CN White: h4h5   Move: 60
# Move by US Black: a1d1   Move: 61
# Move by CN White: c4h4   Move: 62
# Move by US Black: g6g5   Move: 63
# Move by CN White: h5h6   Move: 64
# Move by US Black: g7g6   Move: 65
# Move by CN White: h4h1   Move: 66
# Move by US Black: d1a4   Move: 67
# Move by CN White: e2d2   Move: 68
# Move by US Black: c5e4   Move: 69
# Move by CN White: d2d8   Move: 70
# Move by US Black: a4c2   Move: 71
# Move by CN White: h1h2   Move: 72
# Move by US Black: c2c1   Move: 73
# Move by CN White: f2f3   Move: 74
# Move by US Black: c1e3   Move: 75
# Move by CN White: g1h1   Move: 76
# Move by US Black: e3f3   Move: 77
# Move by CN White: h1g1   Move: 78
# Move by US Black: f3e3   Move: 79
# Move by CN White: g1h1   Move: 80
# Move by US Black: e4f2   Move: 81
# Move by CN White: h1g2   Move: 82
# Move by US Black: g6f6   Move: 83
# Move by CN White: f1a6   Move: 84
# Move by US Black: f2g4   Move: 85
# Move by CN White: g2h3   Move: 86
# Move by US Black: g4h2   Move: 87
# Move by CN White: a6d3   Move: 88
# Move by US Black: h2f3   Move: 89
# Move by CN White: d3c4   Move: 90
# Move by US Black: g5g4   Move: 91
# Move by CN White: h3g4   Move: 92
# Move by US Black: e3e4   Move: 93
# Move by CN White: g4h3   Move: 94
# Move by US Black: f3g5   Move: 95
# Move by CN White: h3h2   Move: 96
# Move by US Black: e4c4   Move: 97
# Move by CN White: g3g4   Move: 98
# Move by US Black: c4g4   Move: 99
# Move by CN White: h2h1   Move: 100
# Move by US Black: g5f3   Move: 101
# Move by CN White: d8d6   Move: 102
# Move by US Black: g4g1   Move: 103
# Game 98 result: 0-1
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 99...
# Move by CN White: e2e4   Move: 0
# Move by US Black: e7e5   Move: 1
# Move by CN White: g1f3   Move: 2
# Move by US Black: b8c6   Move: 3
# Move by CN White: f1b5   Move: 4
# Move by US Black: a7a6   Move: 5
# Move by CN White: b5a4   Move: 6
# Move by US Black: g8f6   Move: 7
# Move by CN White: e1g1   Move: 8
# Move by US Black: b7b5   Move: 9
# Move by CN White: a4b3   Move: 10
# Move by US Black: f8e7   Move: 11
# Move by CN White: d2d4   Move: 12
# Move by US Black: d7d6   Move: 13
# Move by CN White: d4e5   Move: 14
# Move by US Black: d6e5   Move: 15
# Move by CN White: d1d8   Move: 16
# Move by US Black: e7d8   Move: 17
# Move by CN White: a2a4   Move: 18
# Move by US Black: c8b7   Move: 19
# Move by CN White: a4b5   Move: 20
# Move by US Black: a6b5   Move: 21
# Move by CN White: a1a8   Move: 22
# Move by US Black: b7a8   Move: 23
# Move by CN White: b1a3   Move: 24
# Move by US Black: c6a5   Move: 25
# Move by CN White: b3a2   Move: 26
# Move by US Black: b5b4   Move: 27
# Move by CN White: a3c4   Move: 28
# Move by US Black: a5c4   Move: 29
# Move by CN White: a2c4   Move: 30
# Move by US Black: a8e4   Move: 31
# Move by CN White: f3e5   Move: 32
# Move by US Black: e8g8   Move: 33
# Move by CN White: f1d1   Move: 34
# Move by US Black: d8e7   Move: 35
# Move by CN White: c4b3   Move: 36
# Move by US Black: e7d6   Move: 37
# Move by CN White: c1f4   Move: 38
# Move by US Black: e4f5   Move: 39
# Move by CN White: e5f7   Move: 40
# Move by US Black: d6f4   Move: 41
# Move by CN White: f7h6   Move: 42
# Move by US Black: g8h8   Move: 43
# Move by CN White: h6f7   Move: 44
# Move by US Black: h8g8   Move: 45
# Move by CN White: f7e5   Move: 46
# Move by US Black: g8h8   Move: 47
# Move by CN White: e5f7   Move: 48
# Move by US Black: h8g8   Move: 49
# Move by CN White: f7d6   Move: 50
# Move by US Black: g8h8   Move: 51
# Move by CN White: d6f5   Move: 52
# Move by US Black: f4e5   Move: 53
# Move by CN White: f2f3   Move: 54
# Move by US Black: g7g6   Move: 55
# Move by CN White: f5e7   Move: 56
# Move by US Black: c7c5   Move: 57
# Move by CN White: g2g4   Move: 58
# Move by US Black: e5b2   Move: 59
# Move by CN White: g1g2   Move: 60
# Move by US Black: f8e8   Move: 61
# Move by CN White: e7c6   Move: 62
# Move by US Black: e8c8   Move: 63
# Move by CN White: c6a5   Move: 64
# Move by US Black: b2d4   Move: 65
# Move by CN White: h2h4   Move: 66
# Move by US Black: h8g7   Move: 67
# Move by CN White: b3c4   Move: 68
# Move by US Black: f6d7   Move: 69
# Move by CN White: c4e6   Move: 70
# Move by US Black: c8c7   Move: 71
# Move by CN White: a5b3   Move: 72
# Move by US Black: d7e5   Move: 73
# Move by CN White: g2g3   Move: 74
# Move by US Black: d4c3   Move: 75
# Move by CN White: f3f4   Move: 76
# Move by US Black: e5c6   Move: 77
# Move by CN White: g4g5   Move: 78
# Move by US Black: c6d4   Move: 79
# Move by CN White: b3d4   Move: 80
# Move by US Black: c3d4   Move: 81
# Move by CN White: h4h5   Move: 82
# Move by US Black: h7h6   Move: 83
# Move by CN White: h5g6   Move: 84
# Move by US Black: g7g6   Move: 85
# Move by CN White: g5h6   Move: 86
# Move by US Black: c7h7   Move: 87
# Move by CN White: d1e1   Move: 88
# Move by US Black: h7h6   Move: 89
# Move by CN White: e6c4   Move: 90
# Move by US Black: g6f5   Move: 91
# Move by CN White: e1e8   Move: 92
# Move by US Black: h6d6   Move: 93
# Move by CN White: e8f8   Move: 94
# Move by US Black: f5e4   Move: 95
# Move by CN White: f8e8   Move: 96
# Move by US Black: e4f5   Move: 97
# Move by CN White: e8f8   Move: 98
# Move by US Black: f5e4   Move: 99
# Move by CN White: f8e8   Move: 100
# Move by US Black: e4f5   Move: 101
# Move by CN White: c4d3   Move: 102
# Move by US Black: f5f6   Move: 103
# Move by CN White: d3c4   Move: 104
# Move by US Black: d4b2   Move: 105
# Move by CN White: e8c8   Move: 106
# Move by US Black: d6d2   Move: 107
# Move by CN White: c8c6   Move: 108
# Move by US Black: f6e7   Move: 109
# Move by CN White: c4b3   Move: 110
# Move by US Black: b2d4   Move: 111
# Move by CN White: g3f3   Move: 112
# Move by US Black: e7d7   Move: 113
# Move by CN White: b3a4   Move: 114
# Move by US Black: d2f2   Move: 115
# Move by CN White: f3g3   Move: 116
# Move by US Black: d7e7   Move: 117
# Move by CN White: g3g4   Move: 118
# Move by US Black: d4e3   Move: 119
# Move by CN White: f4f5   Move: 120
# Move by US Black: f2f4   Move: 121
# Move by CN White: g4g5   Move: 122
# Move by US Black: e3c1   Move: 123
# Move by CN White: c6c7   Move: 124
# Move by US Black: e7d6   Move: 125
# Move by CN White: c7c8   Move: 126
# Move by US Black: f4f2   Move: 127
# Move by CN White: g5g6   Move: 128
# Move by US Black: c1b2   Move: 129
# Move by CN White: c8c6   Move: 130
# Move by US Black: d6d5   Move: 131
# Move by CN White: f5f6   Move: 132
# Move by US Black: f2g2   Move: 133
# Move by CN White: g6h6   Move: 134
# Move by US Black: c5c4   Move: 135
# Move by CN White: c6a6   Move: 136
# Move by US Black: g2f2   Move: 137
# Move by CN White: h6g7   Move: 138
# Move by US Black: d5c5   Move: 139
# Move by CN White: a6a5   Move: 140
# Move by US Black: c5d6   Move: 141
# Move by CN White: a5a6   Move: 142
# Move by US Black: d6d5   Move: 143
# Move by CN White: g7g6   Move: 144
# Move by US Black: f2f6   Move: 145
# Move by CN White: a6f6   Move: 146
# Move by US Black: b2f6   Move: 147
# Move by CN White: g6f6   Move: 148
# Move by US Black: d5d4   Move: 149
# Move by CN White: f6e6   Move: 150
# Move by US Black: d4c3   Move: 151
# Move by CN White: e6d5   Move: 152
# Move by US Black: b4b3   Move: 153
# Move by CN White: a4b3   Move: 154
# Move by US Black: c4b3   Move: 155
# Move by CN White: c2b3   Move: 156
# Move by US Black: c3b3   Move: 157
# Game 99 result: 1/2-1/2
#
#
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 20, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# {'Debug Log File': '', 'Contempt': 0, 'Min Split Depth': 0, 'Ponder': 'false', 'MultiPV': 1, 'Skill Level': 10, 'Move Overhead': 10, 'Minimum Thinking Time': 50, 'Slow Mover': 100, 'UCI_Chess960': 'false', 'UCI_LimitStrength': 'false', 'UCI_Elo': 1350, 'Threads': 3, 'Hash': 2048}
# Starting game 100...
# Move by CN White: e2e4   Move: 0
# Move by US Black: e7e5   Move: 1
# Move by CN White: d2d4   Move: 2
# Move by US Black: e5d4   Move: 3
# Move by CN White: d1d4   Move: 4
# Move by US Black: b8c6   Move: 5
# Move by CN White: d4a4   Move: 6
# Move by US Black: g8f6   Move: 7
# Move by CN White: f1b5   Move: 8
# Move by US Black: f8c5   Move: 9
# Move by CN White: b1d2   Move: 10
# Move by US Black: f6g4   Move: 11
# Move by CN White: b5c6   Move: 12
# Move by US Black: d7c6   Move: 13
# Move by CN White: g1h3   Move: 14
# Move by US Black: d8d6   Move: 15
# Move by CN White: d2f3   Move: 16
# Move by US Black: b7b5   Move: 17
# Move by CN White: a4b3   Move: 18
# Move by US Black: c8e6   Move: 19
# Move by CN White: b3d3   Move: 20
# Move by US Black: e8c8   Move: 21
# Move by CN White: d3d6   Move: 22
# Move by US Black: d8d6   Move: 23
# Move by CN White: e1g1   Move: 24
# Move by US Black: h7h6   Move: 25
# Move by CN White: b2b3   Move: 26
# Move by US Black: g7g5   Move: 27
# Move by CN White: g2g3   Move: 28
# Move by US Black: h8e8   Move: 29
# Move by CN White: c1b2   Move: 30
# Move by US Black: g4e3   Move: 31
# Move by CN White: h3g5   Move: 32
# Move by US Black: e3f1   Move: 33
# Move by CN White: g5e6   Move: 34
# Move by US Black: e8e6   Move: 35
# Move by CN White: b3b4   Move: 36
# Move by US Black: f1h2   Move: 37
# Move by CN White: g1h2   Move: 38
# Move by US Black: c5f2   Move: 39
# Move by CN White: a1f1   Move: 40
# Move by US Black: f2b6   Move: 41
# Move by CN White: f3e5   Move: 42
# Move by US Black: d6d2   Move: 43
# Move by CN White: h2h3   Move: 44
# Move by US Black: d2c2   Move: 45
# Move by CN White: b2a1   Move: 46
# Move by US Black: c2a2   Move: 47
# Move by CN White: e5f7   Move: 48
# Move by US Black: e6e4   Move: 49
# Move by CN White: a1h8   Move: 50
# Move by US Black: h6h5   Move: 51
# Move by CN White: f1f4   Move: 52
# Move by US Black: b6g1   Move: 53
# Move by CN White: h3h4   Move: 54
# Move by US Black: g1e3   Move: 55
# Move by CN White: h4g5   Move: 56
# Move by US Black: e3f4   Move: 57
# Move by CN White: g3f4   Move: 58
# Move by US Black: h5h4   Move: 59
# Move by CN White: h8c3   Move: 60
# Move by US Black: h4h3   Move: 61
# Move by CN White: c3e5   Move: 62
# Move by US Black: h3h2   Move: 63
# Move by CN White: f7h8   Move: 64
# Move by US Black: h2h1q   Move: 65
# Move by CN White: h8g6   Move: 66
# Move by US Black: c8b7   Move: 67
# Move by CN White: g6e7   Move: 68
# Move by US Black: e4e5   Move: 69
# Move by CN White: f4e5   Move: 70
# Move by US Black: h1g1   Move: 71
# Move by CN White: g5f4   Move: 72
# Move by US Black: a2f2   Move: 73
# Move by CN White: f4e3   Move: 74
# Move by US Black: g1g3   Move: 75
# Move by CN White: e3e4   Move: 76
# Move by US Black: f2f4   Move: 77
# Game 100 result: 0-1

# %%
results = []

# %%
results.append({
            "US Wins": us_wins,
            "CN Wins": cn_wins,
            "Draws": draws,
        })

print(results)
# Out:
# [{'US Wins': 40, 'CN Wins': 46, 'Draws': 114}]

# %%
df = pd.DataFrame(results)
csv_path = f"Results/STKFISH_{AI_USE_US}_vs_STKFISH_{AI_USE_CN}.csv"
df.to_csv(csv_path, index=False)
print(f"Results saved to {csv_path}")
# Out:
# Results saved to Results/STKFISH_80_vs_STKFISH_80.csv
