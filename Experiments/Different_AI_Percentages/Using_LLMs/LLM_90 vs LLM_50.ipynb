# %% [markdown]
# # LLM_1 - **20%** vs. LLM_2 - **20%**

# %%
import chess
from stockfish import Stockfish
from ollama import chat
from ollama import ChatResponse
import json
import random
import pandas as pd
import asyncio

# %%
# STOCKFISH_PATH = r"C:\Users\nafis\Downloads\stockfish-windows-x86-64-avx2\stockfish\stockfish-windows-x86-64-avx2.exe"

STOCKFISH_ELO = 3500
NUM_GAMES = 100
MOVE_LIMIT = 300
RANDOM_START = 0
QWEN_US_AI = 90
QWEN_CN_AI = 50

# %%
stockfish = Stockfish()
stockfish.update_engine_parameters({"Threads": 4, "Hash": 4096})

# %%
qwen_cn_wins = 0
qwen_us_wins = 0
draws = 0

# %%
def valid_move_to_string(board):
    legal_moves = [
        board.san(move) for move in board.legal_moves]
    
    if not legal_moves:
        return "No legal moves."
    else:
        return ", ".join(legal_moves)

# %%
def get_move_history(board: chess.Board) -> str:
    """Return a formatted move history string like '1. e4 e5 2. Nf3 d5'."""
    temp_board = chess.Board()  # Start from the initial position.
    move_history = []
    
    # Iterate over the moves in the board's move stack.
    for i, move in enumerate(board.move_stack):
        # Get the SAN for the move in the current temporary board.
        move_san = temp_board.san(move)
        # Push the move so that the board state is updated.
        temp_board.push(move)
        
        # For white moves (even index), start a new entry with move number.
        if i % 2 == 0:
            move_history.append(f"{i//2 + 1}. {move_san}")
        # For black moves, append to the last white move entry.
        else:
            move_history[-1] += f" {move_san}"
    
    # Join all entries with a space.
    return " ".join(move_history)

# %%
async def get_move_with_timeout(stockfish, timeout=15):
    """
    Run stockfish.get_best_move() in a separate thread and wait for a maximum of `timeout` seconds.
    If the call exceeds the timeout, return None.
    """
    try:
        # Use asyncio.to_thread to run the blocking call in a separate thread.
        move = await asyncio.wait_for(asyncio.to_thread(stockfish.get_best_move), timeout)
        return move
    except asyncio.TimeoutError:
        # move = stockfish.get_best_move_time(1000)
        print(f"Timeout: stockfish.get_best_move() took more than 15 seconds.")
        return None

# %%
def get_qwen_move(board:chess.Board, fen:str, temp=0.0):
    qwen_move = None

    valid_moves = valid_move_to_string(board)

    move_history = get_move_history(board)
    
    response: ChatResponse = chat(model='qwen:32b', messages=[
        {
            'role': 'system',
            'content': 'You are a grand master chess player.'
        },
        {
            'role': 'user',
            'content': f"""You are playing chess and it is your turn. This is the current state of the game. Use this to work out where the pieces are on the board:

FEN: {fen}

The possible set of legal moves are: 

Legal Moves: {valid_moves}

+(You have to choose one from the provided list. Do not choose a move that is not in the list.)

The move history is: {move_history}.

Output the best move in SAN format to follow this position. Use the following single blob of JSON. Do not include any other information.
{{
    "san": "The move in SAN format",
}}"""}], options={"temperature": temp})
    
    try:
        parsed_json = json.loads(response.message.content)
        qwen_move = parsed_json["san"]
    except Exception as e:
        print(f"Wrong format given by Qwen. \nQwen Output: {response.message.content}")

    

    return qwen_move

# %%
def get_random_move(board:chess.Board, fen:str, seed: int = 101):
    legal_moves = [
        board.san(move)
        for move in board.legal_moves
    ]

    random.seed(seed)

    # print(random.choice(legal_moves))
    return random.choice(legal_moves)

    # print(legal_moves[0])

# %%
for game_number in range(1, NUM_GAMES + 1):
    
    move_counter = 0

    print(f"Starting game {game_number}...")

    board = chess.Board()

    while not board.is_game_over() and move_counter <= MOVE_LIMIT:
        if board.turn == chess.WHITE and not board.is_game_over():
            num = random.randint(1,100)
            
            if num <= QWEN_US_AI:
                stockfish.set_fen_position(board.fen())
                qwen_us_move = await get_move_with_timeout(stockfish)

                if qwen_us_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break
            
            else:
                qwen_us_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_us_move)
            except Exception as e:
                print(f"Invalid move by Qwen white. Move: {qwen_us_move}")
                qwen_us_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_us_move)
                print(f"New Move: {qwen_us_move}")
                # continue
            
            move_counter += 1        
            print(f"Qwen US move: {qwen_us_move} Move number: {move_counter}")

        elif board.turn == chess.BLACK and not board.is_game_over():
            num = random.randint(1, 100)

            if num <= QWEN_CN_AI:
                stockfish.set_fen_position(board.fen())
                qwen_cn_move = await get_move_with_timeout(stockfish)

                if qwen_cn_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break

            else:
                qwen_cn_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_cn_move)
            except Exception as e:
                print(f"Invalid move by Qwen black. Move: {qwen_cn_move}")
                qwen_cn_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_cn_move)
                print(f"New Move: {qwen_cn_move}")
                # continue
            move_counter += 1
            print(f"Qwen CN move: {qwen_cn_move} Move number: {move_counter}")   

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        qwen_us_wins += 1
    elif result == "0-1":
        qwen_cn_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n\n")
# Out:
# Starting game 1...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: Nf3+ Move number: 8
# Qwen US move: d1f3 Move number: 9
# Qwen CN move: Nxe7 Move number: 10
# Qwen US move: b1c3 Move number: 11
# Qwen CN move: d7d5 Move number: 12
# Qwen US move: e4d5 Move number: 13
# Qwen CN move: e7g6 Move number: 14
# Qwen US move: c1d2 Move number: 15
# Qwen CN move: f8b4 Move number: 16
# Qwen US move: f3e2 Move number: 17
# Qwen CN move: b4e7 Move number: 18
# Invalid move by Qwen white. Move: Nbd2
# New Move: Qa6
# Qwen US move: Qa6 Move number: 19
# Qwen CN move: b7a6 Move number: 20
# Invalid move by Qwen white. Move: Nxe7+
# New Move: Bg5
# Qwen US move: Bg5 Move number: 21
# Qwen CN move: e7g5 Move number: 22
# Qwen US move: Nb5 Move number: 23
# Qwen CN move: e8g8 Move number: 24
# Qwen US move: b5c3 Move number: 25
# Qwen CN move: g8h8 Move number: 26
# Qwen US move: f1d3 Move number: 27
# Invalid move by Qwen black. Move: Rd1
# New Move: Qd6
# Qwen CN move: Qd6 Move number: 28
# Qwen US move: c3e4 Move number: 29
# Qwen CN move: Bf4 Move number: 30
# Qwen US move: e4d6 Move number: 31
# Qwen CN move: f4d6 Move number: 32
# Qwen US move: d3g6 Move number: 33
# Qwen CN move: f8e8 Move number: 34
# Qwen US move: Kd2 Move number: 35
# Qwen CN move: d6f4 Move number: 36
# Qwen US move: d2c3 Move number: 37
# Qwen CN move: Re5 Move number: 38
# Qwen US move: d4e5 Move number: 39
# Qwen CN move: f4e5 Move number: 40
# Qwen US move: c3c4 Move number: 41
# Qwen CN move: Bd6 Move number: 42
# Qwen US move: g6f7 Move number: 43
# Qwen CN move: c8d7 Move number: 44
# Qwen US move: f7e6 Move number: 45
# Qwen CN move: d7b5 Move number: 46
# Qwen US move: c4d4 Move number: 47
# Qwen CN move: Rg8 Move number: 48
# Qwen US move: a2a4 Move number: 49
# Qwen CN move: c7c5 Move number: 50
# Qwen US move: d4e3 Move number: 51
# Qwen CN move: b5e8 Move number: 52
# Qwen US move: Bf7 Move number: 53
# Qwen CN move: Bxf4+ Move number: 54
# Qwen US move: e3f4 Move number: 55
# Qwen CN move: Rf8 Move number: 56
# Qwen US move: f4g3 Move number: 57
# Qwen CN move: e8f7 Move number: 58
# Qwen US move: h1d1 Move number: 59
# Qwen CN move: Rd8 Move number: 60
# Qwen US move: c2c4 Move number: 61
# Qwen CN move: h8g8 Move number: 62
# Qwen US move: Kf4 Move number: 63
# Qwen CN move: d8b8 Move number: 64
# Qwen US move: b2b3 Move number: 65
# Qwen CN move: Rb7 Move number: 66
# Qwen US move: d5d6 Move number: 67
# Qwen CN move: b7d7 Move number: 68
# Qwen US move: h2h4 Move number: 69
# Qwen CN move: f7e6 Move number: 70
# Qwen US move: Rh1 Move number: 71
# Qwen CN move: d7d6 Move number: 72
# Qwen US move: a1d1 Move number: 73
# Qwen CN move: d6b6 Move number: 74
# Qwen US move: d1d3 Move number: 75
# Qwen CN move: b6b7 Move number: 76
# Qwen US move: d3e3 Move number: 77
# Qwen CN move: b7e7 Move number: 78
# Qwen US move: f4g3 Move number: 79
# Qwen CN move: g8f7 Move number: 80
# Qwen US move: h1e1 Move number: 81
# Invalid move by Qwen black. Move: Rhe3
# New Move: g5
# Qwen CN move: g5 Move number: 82
# Qwen US move: h4g5 Move number: 83
# Qwen CN move: e7e8 Move number: 84
# Qwen US move: Rxe6 Move number: 85
# Qwen CN move: e8e6 Move number: 86
# Qwen US move: e1e6 Move number: 87
# Qwen CN move: f7e6 Move number: 88
# Qwen US move: a4a5 Move number: 89
# Qwen CN move: Kf7 Move number: 90
# Qwen US move: g3f3 Move number: 91
# Qwen CN move: Kg7 Move number: 92
# Qwen US move: Kg4 Move number: 93
# Qwen CN move: h5+ Move number: 94
# Qwen US move: g4h5 Move number: 95
# Invalid move by Qwen black. Move: Kg4
# New Move: Kh8
# Qwen CN move: Kh8 Move number: 96
# Qwen US move: h5g6 Move number: 97
# Invalid move by Qwen black. Move: Kg7
# New Move: Kg8
# Qwen CN move: Kg8 Move number: 98
# Qwen US move: f2f4 Move number: 99
# Qwen CN move: Kf8 Move number: 100
# Qwen US move: f4f5 Move number: 101
# Qwen CN move: f8e7 Move number: 102
# Qwen US move: f5f6 Move number: 103
# Qwen CN move: e7d6 Move number: 104
# Qwen US move: Kf7 Move number: 105
# Qwen CN move: d6e5 Move number: 106
# Qwen US move: f7g7 Move number: 107
# Qwen CN move: Kf4 Move number: 108
# Qwen US move: f6f7 Move number: 109
# Qwen CN move: f4e3 Move number: 110
# Qwen US move: f7f8q Move number: 111
# Qwen CN move: Ke4 Move number: 112
# Qwen US move: f8f3 Move number: 113
# Qwen CN move: e4e5 Move number: 114
# Qwen US move: g2g3 Move number: 115
# Qwen CN move: e5d6 Move number: 116
# Qwen US move: f3d5 Move number: 117
# Qwen CN move: Kc7 Move number: 118
# Qwen US move: g7g8 Move number: 119
# Qwen CN move: c7c8 Move number: 120
# Qwen US move: d5d6 Move number: 121
# Qwen CN move: c8b7 Move number: 122
# Qwen US move: Qf8 Move number: 123
# Qwen CN move: Kc7 Move number: 124
# Qwen US move: f8c5 Move number: 125
# Qwen CN move: Kd7 Move number: 126
# Qwen US move: g8f7 Move number: 127
# Qwen CN move: d7d8 Move number: 128
# Qwen US move: f7e6 Move number: 129
# Invalid move by Qwen black. Move: Kf7
# New Move: Ke8
# Qwen CN move: Ke8 Move number: 130
# Qwen US move: c5e7 Move number: 131
# Game 1 result: 1-0
#
#
# Starting game 2...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1c4 Move number: 5
# Qwen CN move: Nf6 Move number: 6
# Qwen US move: f3g5 Move number: 7
# Qwen CN move: Nxe4 Move number: 8
# Qwen US move: Nxe4 Move number: 9
# Invalid move by Qwen black. Move: Bc4
# New Move: d6
# Qwen CN move: d6 Move number: 10
# Qwen US move: c4d5 Move number: 11
# Qwen CN move: c6b4 Move number: 12
# Qwen US move: Bxf7+ Move number: 13
# Qwen CN move: e8f7 Move number: 14
# Qwen US move: a2a3 Move number: 15
# Qwen CN move: b4c6 Move number: 16
# Qwen US move: c2c4 Move number: 17
# Qwen CN move: Be7 Move number: 18
# Qwen US move: d2d3 Move number: 19
# Invalid move by Qwen black. Move: Bh6
# New Move: Bd7
# Qwen CN move: Bd7 Move number: 20
# Qwen US move: d1h5 Move number: 21
# Qwen CN move: Kf8 Move number: 22
# Qwen US move: e1g1 Move number: 23
# Qwen CN move: d8e8 Move number: 24
# Qwen US move: h5d1 Move number: 25
# Qwen CN move: f8f7 Move number: 26
# Qwen US move: Nxf6 Move number: 27
# Qwen CN move: e7f6 Move number: 28
# Qwen US move: f2f4 Move number: 29
# Qwen CN move: Qe6 Move number: 30
# Qwen US move: f4f5 Move number: 31
# Qwen CN move: e6e7 Move number: 32
# Qwen US move: b1c3 Move number: 33
# Invalid move by Qwen black. Move: Nh4
# New Move: Raf8
# Qwen CN move: Raf8 Move number: 34
# Qwen US move: c3d5 Move number: 35
# Invalid move by Qwen black. Move: Nxe7+
# New Move: Kg8
# Qwen CN move: Kg8 Move number: 36
# Qwen US move: d5e7 Move number: 37
# Qwen CN move: Nxe7 Move number: 38
# Qwen US move: c4c5 Move number: 39
# Qwen CN move: h7h6 Move number: 40
# Qwen US move: c5d6 Move number: 41
# Qwen CN move: c7d6 Move number: 42
# Qwen US move: Rf4 Move number: 43
# Qwen CN move: e5f4 Move number: 44
# Qwen US move: c1f4 Move number: 45
# Invalid move by Qwen black. Move: Rf1
# New Move: Ra8
# Qwen CN move: Ra8 Move number: 46
# Qwen US move: d3d4 Move number: 47
# Qwen CN move: Bxd4+ Move number: 48
# Qwen US move: d1d4 Move number: 49
# Qwen CN move: e7f5 Move number: 50
# Qwen US move: d4e4 Move number: 51
# Qwen CN move: g8h7 Move number: 52
# Qwen US move: Qxf5+ Move number: 53
# Qwen CN move: d7f5 Move number: 54
# Qwen US move: f4d6 Move number: 55
# Invalid move by Qwen black. Move: Bxd6
# New Move: Bh3
# Qwen CN move: Bh3 Move number: 56
# Qwen US move: g2h3 Move number: 57
# Qwen CN move: a8d8 Move number: 58
# Invalid move by Qwen white. Move: Bxd6
# New Move: a4
# Qwen US move: a4 Move number: 59
# Qwen CN move: d8d6 Move number: 60
# Qwen US move: a1e1 Move number: 61
# Qwen CN move: Rd2 Move number: 62
# Qwen US move: b2b3 Move number: 63
# Qwen CN move: h8c8 Move number: 64
# Qwen US move: h3h4 Move number: 65
# Qwen CN move: c8c2 Move number: 66
# Invalid move by Qwen white. Move: Re1
# New Move: Re7
# Qwen US move: Re7 Move number: 67
# Qwen CN move: c2c1 Move number: 68
# Qwen US move: Re1 Move number: 69
# Qwen CN move: c1e1 Move number: 70
# Game 2 result: 0-1
#
#
# Starting game 3...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: f1c4 Move number: 5
# Qwen CN move: Nf6 Move number: 6
# Qwen US move: Bxf7+ Move number: 7
# Invalid move by Qwen black. Move: Bxf7+
# New Move: Kxf7
# Qwen CN move: Kxf7 Move number: 8
# Qwen US move: d2d4 Move number: 9
# Qwen CN move: Be7 Move number: 10
# Qwen US move: d4d5 Move number: 11
# Qwen CN move: c6b8 Move number: 12
# Qwen US move: f3e5 Move number: 13
# Qwen CN move: f7g8 Move number: 14
# Invalid move by Qwen white. Move: Nxe5
# New Move: b4
# Qwen US move: b4 Move number: 15
# Qwen CN move: d7d6 Move number: 16
# Qwen US move: e5d3 Move number: 17
# Qwen CN move: Nxd5 Move number: 18
# Qwen US move: e4d5 Move number: 19
# Qwen CN move: e7f6 Move number: 20
# Qwen US move: c1b2 Move number: 21
# Qwen CN move: f6b2 Move number: 22
# Qwen US move: Nxe5 Move number: 23
# Qwen CN move: b2a1 Move number: 24
# Qwen US move: e5c4 Move number: 25
# Qwen CN move: Qe7+ Move number: 26
# Qwen US move: c4e3 Move number: 27
# Qwen CN move: a1f6 Move number: 28
# Qwen US move: e1g1 Move number: 29
# Qwen CN move: Qe4 Move number: 30
# Qwen US move: b1d2 Move number: 31
# Qwen CN move: e4g6 Move number: 32
# Qwen US move: f2f4 Move number: 33
# Qwen CN move: b8d7 Move number: 34
# Qwen US move: g1h1 Move number: 35
# Qwen CN move: Nc5 Move number: 36
# Qwen US move: b4c5 Move number: 37
# Qwen CN move: h7h5 Move number: 38
# Qwen US move: f4f5 Move number: 39
# Qwen CN move: g6e8 Move number: 40
# Qwen US move: Ng4 Move number: 41
# Qwen CN move: Qe2 Move number: 42
# Qwen US move: g4f6 Move number: 43
# Invalid move by Qwen black. Move: Nxf6+
# New Move: gxf6
# Qwen CN move: gxf6 Move number: 44
# Qwen US move: d1e2 Move number: 45
# Qwen CN move: c8d7 Move number: 46
# Qwen US move: Qe8+ Move number: 47
# Qwen CN move: a8e8 Move number: 48
# Qwen US move: c5d6 Move number: 49
# Qwen CN move: c7d6 Move number: 50
# Qwen US move: d2c4 Move number: 51
# Qwen CN move: Re1 Move number: 52
# Qwen US move: f1e1 Move number: 53
# Qwen CN move: Rh6 Move number: 54
# Qwen US move: Nxd6 Move number: 55
# Invalid move by Qwen black. Move: Nxe7+
# New Move: Kg7
# Qwen CN move: Kg7 Move number: 56
# Qwen US move: e1e7 Move number: 57
# Invalid move by Qwen black. Move: Rxe8+ Kf8
# New Move: Kf8
# Qwen CN move: Kf8 Move number: 58
# Qwen US move: e7d7 Move number: 59
# Qwen CN move: h5h4 Move number: 60
# Qwen US move: Rd8+ Move number: 61
# Qwen CN move: f8g7 Move number: 62
# Qwen US move: h2h3 Move number: 63
# Qwen CN move: h6h5 Move number: 64
# Qwen US move: d8d7 Move number: 65
# Qwen CN move: Kh6 Move number: 66
# Qwen US move: d7b7 Move number: 67
# Invalid move by Qwen black. Move: Rxb7
# New Move: Kg5
# Qwen CN move: Kg5 Move number: 68
# Qwen US move: h1h2 Move number: 69
# Qwen CN move: Rh8 Move number: 70
# Qwen US move: d6f7 Move number: 71
# Qwen CN move: g5f5 Move number: 72
# Qwen US move: f7h8 Move number: 73
# Qwen CN move: f5e5 Move number: 74
# Qwen US move: Nf7+ Move number: 75
# Qwen CN move: e5d5 Move number: 76
# Qwen US move: b7a7 Move number: 77
# Invalid move by Qwen black. Move: Rxb8
# New Move: Kc4
# Qwen CN move: Kc4 Move number: 78
# Qwen US move: a7a4 Move number: 79
# Qwen CN move: c4c3 Move number: 80
# Qwen US move: Rxh4 Move number: 81
# Qwen CN move: c3c2 Move number: 82
# Qwen US move: h2g3 Move number: 83
# Qwen CN move: c2b1 Move number: 84
# Qwen US move: g3g4 Move number: 85
# Qwen CN move: Kc2 Move number: 86
# Qwen US move: a2a4 Move number: 87
# Qwen CN move: Kd3 Move number: 88
# Qwen US move: Nh8 Move number: 89
# Invalid move by Qwen black. Move: Kf2
# New Move: Kd4
# Qwen CN move: Kd4 Move number: 90
# Qwen US move: g4f5 Move number: 91
# Qwen CN move: Kd3 Move number: 92
# Qwen US move: h4e4 Move number: 93
# Qwen CN move: d3c2 Move number: 94
# Qwen US move: h3h4 Move number: 95
# Qwen CN move: c2c1 Move number: 96
# Qwen US move: Re3 Move number: 97
# Qwen CN move: c1b2 Move number: 98
# Qwen US move: a4a5 Move number: 99
# Invalid move by Qwen black. Move: Rf3
# New Move: Kc2
# Qwen CN move: Kc2 Move number: 100
# Qwen US move: a5a6 Move number: 101
# Qwen CN move: Kd2 Move number: 102
# Qwen US move: e3h3 Move number: 103
# Qwen CN move: d2e2 Move number: 104
# Qwen US move: f5f6 Move number: 105
# Qwen CN move: e2f1 Move number: 106
# Invalid move by Qwen white. Move: Rh3
# New Move: h5
# Qwen US move: h5 Move number: 107
# Qwen CN move: f1e1 Move number: 108
# Qwen US move: a6a7 Move number: 109
# Invalid move by Qwen black. Move: Nh8
# New Move: Kf2
# Qwen CN move: Kf2 Move number: 110
# Qwen US move: a7a8q Move number: 111
# Invalid move by Qwen black. Move: Rd6
# New Move: Ke2
# Qwen CN move: Ke2 Move number: 112
# Qwen US move: a8a2 Move number: 113
# Qwen CN move: Kf1 Move number: 114
# Qwen US move: h3h1 Move number: 115
# Game 3 result: 1-0
#
#
# Starting game 4...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: Bb4 Move number: 6
# Qwen US move: Bxc6 Move number: 7
# Qwen CN move: Bxc3 Move number: 8
# Qwen US move: b1c3 Move number: 9
# Qwen CN move: Nf6 Move number: 10
# Qwen US move: c6b5 Move number: 11
# Qwen CN move: e8g8 Move number: 12
# Qwen US move: d2d4 Move number: 13
# Qwen CN move: e5d4 Move number: 14
# Qwen US move: d1d4 Move number: 15
# Qwen CN move: c7c5 Move number: 16
# Qwen US move: d4c5 Move number: 17
# Qwen CN move: Nxe4 Move number: 18
# Qwen US move: c3e4 Move number: 19
# Invalid move by Qwen black. Move: Nxd6
# New Move: d5
# Qwen CN move: d5 Move number: 20
# Qwen US move: e4c3 Move number: 21
# Qwen CN move: a7a6 Move number: 22
# Qwen US move: Qxc8 Move number: 23
# Qwen CN move: a8c8 Move number: 24
# Qwen US move: b5d3 Move number: 25
# Qwen CN move: f8e8 Move number: 26
# Qwen US move: c3e2 Move number: 27
# Qwen CN move: Re3 Move number: 28
# Qwen US move: c1e3 Move number: 29
# Qwen CN move: Qa5+ Move number: 30
# Qwen US move: Nd2 Move number: 31
# Invalid move by Qwen black. Move: Re1
# New Move: Rc7
# Qwen CN move: Rc7 Move number: 32
# Qwen US move: e3d4 Move number: 33
# Qwen CN move: Rc8 Move number: 34
# Qwen US move: e1d1 Move number: 35
# Qwen CN move: g8f8 Move number: 36
# Qwen US move: h1e1 Move number: 37
# Qwen CN move: c8c4 Move number: 38
# Qwen US move: Bxc4 Move number: 39
# Qwen CN move: d5c4 Move number: 40
# Qwen US move: d4c3 Move number: 41
# Qwen CN move: Qd5 Move number: 42
# Qwen US move: f2f3 Move number: 43
# Qwen CN move: d5c5 Move number: 44
# Qwen US move: e2g3 Move number: 45
# Invalid move by Qwen black. Move: Ng1
# New Move: Qg1
# Qwen CN move: Qg1 Move number: 46
# Qwen US move: e1g1 Move number: 47
# Qwen CN move: h7h6 Move number: 48
# Qwen US move: Nh5 Move number: 49
# Qwen CN move: b7b5 Move number: 50
# Qwen US move: g1e1 Move number: 51
# Qwen CN move: f7f5 Move number: 52
# Qwen US move: c3g7 Move number: 53
# Invalid move by Qwen black. Move: Bxd5
# New Move: Kg8
# Qwen CN move: Kg8 Move number: 54
# Qwen US move: a2a3 Move number: 55
# Invalid move by Qwen black. Move: a4
# New Move: c3
# Qwen CN move: c3 Move number: 56
# Qwen US move: b2c3 Move number: 57
# Qwen CN move: g8f7 Move number: 58
# Qwen US move: Bd4 Move number: 59
# Qwen CN move: a6a5 Move number: 60
# Qwen US move: a1b1 Move number: 61
# Qwen CN move: b5b4 Move number: 62
# Qwen US move: h5f4 Move number: 63
# Qwen CN move: bxc3 Move number: 64
# Qwen US move: b1b7 Move number: 65
# Invalid move by Qwen black. Move: Rxb8
# New Move: Kg8
# Qwen CN move: Kg8 Move number: 66
# Qwen US move: e1e8 Move number: 67
# Game 4 result: 1-0
#
#
# Starting game 5...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: d7d6 Move number: 4
# Qwen US move: b1c3 Move number: 5
# Qwen CN move: Nf6 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: Nbd7 Move number: 8
# Qwen US move: Nh4 Move number: 9
# Qwen CN move: Nxe4 Move number: 10
# Qwen US move: c3e4 Move number: 11
# Invalid move by Qwen black. Move: Nf3
# New Move: f5
# Qwen CN move: f5 Move number: 12
# Qwen US move: d1h5 Move number: 13
# Qwen CN move: g7g6 Move number: 14
# Qwen US move: Nf3 Move number: 15
# Qwen CN move: g6h5 Move number: 16
# Qwen US move: e4g5 Move number: 17
# Qwen CN move: f8h6 Move number: 18
# Qwen US move: g5e6 Move number: 19
# Invalid move by Qwen black. Move: Ne4
# New Move: b6
# Qwen CN move: b6 Move number: 20
# Qwen US move: c1h6 Move number: 21
# Qwen CN move: d7e5 Move number: 22
# Invalid move by Qwen white. Move: Bxf7+ Kxf7
# New Move: h4
# Qwen US move: h4 Move number: 23
# Qwen CN move: e5f3 Move number: 24
# Qwen US move: g2f3 Move number: 25
# Qwen CN move: Bxe6 Move number: 26
# Qwen US move: e1c1 Move number: 27
# Qwen CN move: c5d4 Move number: 28
# Qwen US move: h1g1 Move number: 29
# Qwen CN move: a7a6 Move number: 30
# Qwen US move: Bg2 Move number: 31
# Qwen CN move: e8d7 Move number: 32
# Qwen US move: g1e1 Move number: 33
# Qwen CN move: Rg8 Move number: 34
# Qwen US move: g2h3 Move number: 35
# Qwen CN move: a8c8 Move number: 36
# Qwen US move: e1e6 Move number: 37
# Invalid move by Qwen black. Move: Rxe7
# New Move: Rxc2+
# Qwen CN move: Rxc2+ Move number: 38
# Qwen US move: c1c2 Move number: 39
# Qwen CN move: d7e6 Move number: 40
# Qwen US move: Bf1 Move number: 41
# Qwen CN move: d8a8 Move number: 42
# Qwen US move: d1e1 Move number: 43
# Qwen CN move: e6d7 Move number: 44
# Qwen US move: h6g5 Move number: 45
# Invalid move by Qwen black. Move: Bh6
# New Move: Rg6
# Qwen CN move: Rg6 Move number: 46
# Qwen US move: e1e7 Move number: 47
# Invalid move by Qwen black. Move: Rxf7+ Kc8
# New Move: Kc6
# Qwen CN move: Kc6 Move number: 48
# Qwen US move: f1d3 Move number: 49
# Qwen CN move: a8g8 Move number: 50
# Qwen US move: Re8 Move number: 51
# Qwen CN move: g8e8 Move number: 52
# Qwen US move: d3a6 Move number: 53
# Qwen CN move: c6c7 Move number: 54
# Qwen US move: c2d2 Move number: 55
# Qwen CN move: Qe4 Move number: 56
# Qwen US move: f3e4 Move number: 57
# Qwen CN move: Rg7 Move number: 58
# Qwen US move: Bf1 Move number: 59
# Qwen CN move: Rg8 Move number: 60
# Qwen US move: e4f5 Move number: 61
# Invalid move by Qwen black. Move: Rg8
# New Move: Rd8
# Qwen CN move: Rd8 Move number: 62
# Qwen US move: g5d8 Move number: 63
# Qwen CN move: Kc6 Move number: 64
# Qwen US move: f5f6 Move number: 65
# Qwen CN move: c6d7 Move number: 66
# Qwen US move: d8b6 Move number: 67
# Qwen CN move: d7e6 Move number: 68
# Qwen US move: Bc4+ Move number: 69
# Qwen CN move: e6f6 Move number: 70
# Qwen US move: b6d4 Move number: 71
# Qwen CN move: Ke7 Move number: 72
# Qwen US move: d2e3 Move number: 73
# Qwen CN move: e7d8 Move number: 74
# Qwen US move: c4g8 Move number: 75
# Invalid move by Qwen black. Move: Bf1
# New Move: h6
# Qwen CN move: h6 Move number: 76
# Qwen US move: g8h7 Move number: 77
# Qwen CN move: d8d7 Move number: 78
# Qwen US move: Bg8 Move number: 79
# Qwen CN move: d7c6 Move number: 80
# Qwen US move: g8e6 Move number: 81
# Qwen CN move: c6b5 Move number: 82
# Qwen US move: e6d7 Move number: 83
# Invalid move by Qwen black. Move: Bf1
# New Move: Ka6
# Qwen CN move: Ka6 Move number: 84
# Qwen US move: d7f5 Move number: 85
# Invalid move by Qwen black. Move: Bxf7+ Kxf7
# New Move: Kb7
# Qwen CN move: Kb7 Move number: 86
# Qwen US move: f5d7 Move number: 87
# Invalid move by Qwen black. Move: Bxd6
# New Move: Kb8
# Qwen CN move: Kb8 Move number: 88
# Qwen US move: d7f5 Move number: 89
# Invalid move by Qwen black. Move: Bf5
# New Move: Ka8
# Qwen CN move: Ka8 Move number: 90
# Qwen US move: f5g6 Move number: 91
# Invalid move by Qwen black. Move: Bf5
# New Move: d5
# Qwen CN move: d5 Move number: 92
# Qwen US move: g6f7 Move number: 93
# Qwen CN move: a8b7 Move number: 94
# Qwen US move: Bg6 Move number: 95
# Qwen CN move: b7c7 Move number: 96
# Qwen US move: f2f4 Move number: 97
# Qwen CN move: c7d6 Move number: 98
# Qwen US move: f4f5 Move number: 99
# Invalid move by Qwen black. Move: Bf7
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 100
# Qwen US move: f5f6 Move number: 101
# Invalid move by Qwen black. Move: f7+f8=Q
# New Move: Kf8
# Qwen CN move: Kf8 Move number: 102
# Qwen US move: e3d3 Move number: 103
# Invalid move by Qwen black. Move: Bf7
# New Move: Kg8
# Qwen CN move: Kg8 Move number: 104
# Qwen US move: f6f7 Move number: 105
# Invalid move by Qwen black. Move: Bf7
# New Move: Kf8
# Qwen CN move: Kf8 Move number: 106
# Qwen US move: d4c5 Move number: 107
# Invalid move by Qwen black. Move: Bf7
# New Move: Kg7
# Qwen CN move: Kg7 Move number: 108
# Qwen US move: g6h5 Move number: 109
# Invalid move by Qwen black. Move: Bf7
# New Move: Kh8
# Qwen CN move: Kh8 Move number: 110
# Qwen US move: f7f8q Move number: 111
# Invalid move by Qwen black. Move: Bh5
# New Move: Kh7
# Qwen CN move: Kh7 Move number: 112
# Qwen US move: f8f7 Move number: 113
# Invalid move by Qwen black. Move: Qf5+
# New Move: Kh8
# Qwen CN move: Kh8 Move number: 114
# Qwen US move: c5d4 Move number: 115
# Game 5 result: 1-0
#
#
# Starting game 6...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: c2c3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: e4e5 Move number: 5
# Invalid move by Qwen black. Move: exf6
# New Move: d5
# Qwen CN move: d5 Move number: 6
# Qwen US move: e5f6 Move number: 7
# Qwen CN move: g7f6 Move number: 8
# Qwen US move: Nh3 Move number: 9
# Qwen CN move: b8c6 Move number: 10
# Qwen US move: d2d3 Move number: 11
# Qwen CN move: e7e5 Move number: 12
# Qwen US move: f2f4 Move number: 13
# Invalid move by Qwen black. Move: fxe5
# New Move: Qe7
# Qwen CN move: Qe7 Move number: 14
# Qwen US move: h3f2 Move number: 15
# Qwen CN move: Bh6 Move number: 16
# Qwen US move: f1e2 Move number: 17
# Qwen CN move: c8e6 Move number: 18
# Qwen US move: b1a3 Move number: 19
# Qwen CN move: h8g8 Move number: 20
# Qwen US move: Nh3 Move number: 21
# Qwen CN move: g8g2 Move number: 22
# Qwen US move: h3f2 Move number: 23
# Qwen CN move: Nd4 Move number: 24
# Qwen US move: c3d4 Move number: 25
# Qwen CN move: f6f5 Move number: 26
# Qwen US move: e2f3 Move number: 27
# Invalid move by Qwen black. Move: Be2
# New Move: Qd8
# Qwen CN move: Qd8 Move number: 28
# Qwen US move: f3g2 Move number: 29
# Invalid move by Qwen black. Move: Be2
# New Move: Qc7
# Qwen CN move: Qc7 Move number: 30
# Qwen US move: f4e5 Move number: 31
# Qwen CN move: Qd6 Move number: 32
# Qwen US move: c1h6 Move number: 33
# Qwen CN move: d6b6 Move number: 34
# Qwen US move: e1f1 Move number: 35
# Qwen CN move: c5c4 Move number: 36
# Invalid move by Qwen white. Move: Bh6
# New Move: Nb5
# Qwen US move: Nb5 Move number: 37
# Qwen CN move: b6b5 Move number: 38
# Qwen US move: Bxd5 Move number: 39
# Qwen CN move: e6d5 Move number: 40
# Qwen US move: e5e6 Move number: 41
# Qwen CN move: f7e6 Move number: 42
# Qwen US move: d1h5 Move number: 43
# Qwen CN move: Kd7 Move number: 44
# Qwen US move: h5f7 Move number: 45
# Qwen CN move: Kd8 Move number: 46
# Qwen US move: Qg8+ Move number: 47
# Qwen CN move: Ke7 Move number: 48
# Qwen US move: g8h7 Move number: 49
# Qwen CN move: Kd6 Move number: 50
# Qwen US move: h6f4 Move number: 51
# Qwen CN move: e6e5 Move number: 52
# Qwen US move: f4e5 Move number: 53
# Qwen CN move: d6e6 Move number: 54
# Qwen US move: h7h6 Move number: 55
# Qwen CN move: e6e7 Move number: 56
# Qwen US move: h1g1 Move number: 57
# Qwen CN move: Rh8 Move number: 58
# Qwen US move: g1g7 Move number: 59
# Qwen CN move: Bf7 Move number: 60
# Qwen US move: h6f6 Move number: 61
# Qwen CN move: Kf8 Move number: 62
# Qwen US move: f6f7 Move number: 63
# Game 6 result: 1-0
#
#
# Starting game 7...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: f3e5 Move number: 5
# Qwen CN move: Nxe4 Move number: 6
# Qwen US move: d1e2 Move number: 7
# Qwen CN move: d8e7 Move number: 8
# Invalid move by Qwen white. Move: Nxe4
# New Move: Nd3
# Qwen US move: Nd3 Move number: 9
# Qwen CN move: b8c6 Move number: 10
# Invalid move by Qwen white. Move: Nxe4
# New Move: h4
# Qwen US move: h4 Move number: 11
# Qwen CN move: c6d4 Move number: 12
# Qwen US move: b1c3 Move number: 13
# Invalid move by Qwen black. Move: Nxe4
# New Move: c5
# Qwen CN move: c5 Move number: 14
# Qwen US move: e2e4 Move number: 15
# Qwen CN move: e7e4 Move number: 16
# Qwen US move: Nxe4 Move number: 17
# Qwen CN move: d7d5 Move number: 18
# Qwen US move: c2c3 Move number: 19
# Qwen CN move: d5e4 Move number: 20
# Qwen US move: c3d4 Move number: 21
# Qwen CN move: Rg8 Move number: 22
# Qwen US move: d3c5 Move number: 23
# Qwen CN move: Bxc5 Move number: 24
# Qwen US move: dxc5 Move number: 25
# Qwen CN move: Bh3 Move number: 26
# Qwen US move: h1h3 Move number: 27
# Qwen CN move: Rd8 Move number: 28
# Qwen US move: d2d3 Move number: 29
# Qwen CN move: e4d3 Move number: 30
# Qwen US move: h3d3 Move number: 31
# Qwen CN move: d8d3 Move number: 32
# Qwen US move: f1d3 Move number: 33
# Qwen CN move: e8e7 Move number: 34
# Qwen US move: c1g5 Move number: 35
# Qwen CN move: Kf8 Move number: 36
# Qwen US move: e1c1 Move number: 37
# Qwen CN move: Rh8 Move number: 38
# Qwen US move: d1e1 Move number: 39
# Qwen CN move: Rg8 Move number: 40
# Qwen US move: g5e7 Move number: 41
# Invalid move by Qwen black. Move: Bf6
# New Move: Ke8
# Qwen CN move: Ke8 Move number: 42
# Qwen US move: d3b5 Move number: 43
# Game 7 result: 1-0
#
#
# Starting game 8...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: d7d6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Qwen CN move: d5 Move number: 6
# Qwen US move: d4c5 Move number: 7
# Qwen CN move: Nxc6 Move number: 8
# Qwen US move: Nfd2 Move number: 9
# Qwen CN move: Nf6 Move number: 10
# Qwen US move: f1d3 Move number: 11
# Qwen CN move: Be6 Move number: 12
# Qwen US move: e1g1 Move number: 13
# Qwen CN move: g7g6 Move number: 14
# Qwen US move: e4d5 Move number: 15
# Qwen CN move: f6d5 Move number: 16
# Qwen US move: d2f3 Move number: 17
# Qwen CN move: f8g7 Move number: 18
# Qwen US move: f3g5 Move number: 19
# Qwen CN move: Bh6 Move number: 20
# Qwen US move: g5e6 Move number: 21
# Qwen CN move: Nf4 Move number: 22
# Qwen US move: c1f4 Move number: 23
# Qwen CN move: Rg8 Move number: 24
# Qwen US move: e6c7 Move number: 25
# Qwen CN move: Qxc7 Move number: 26
# Qwen US move: f4c7 Move number: 27
# Invalid move by Qwen black. Move: Rg8
# New Move: Nb4
# Qwen CN move: Nb4 Move number: 28
# Qwen US move: d3b5 Move number: 29
# Qwen CN move: b4c6 Move number: 30
# Qwen US move: Bxc6+ Move number: 31
# Qwen CN move: b7c6 Move number: 32
# Qwen US move: g1h1 Move number: 33
# Qwen CN move: h6f4 Move number: 34
# Qwen US move: d1f3 Move number: 35
# Qwen CN move: Rd8 Move number: 36
# Qwen US move: f3c6 Move number: 37
# Qwen CN move: Rd7 Move number: 38
# Invalid move by Qwen white. Move: Qxc6
# New Move: Qa8+
# Qwen US move: Qa8+ Move number: 39
# Qwen CN move: d7d8 Move number: 40
# Qwen US move: Qxd8# Move number: 41
# Game 8 result: 1-0
#
#
# Starting game 9...
# Qwen US move: d2d4 Move number: 1
# Qwen CN move: g8f6 Move number: 2
# Qwen US move: c2c4 Move number: 3
# Qwen CN move: e7e6 Move number: 4
# Qwen US move: Nf3 Move number: 5
# Qwen CN move: d7d5 Move number: 6
# Qwen US move: g2g3 Move number: 7
# Invalid move by Qwen black. Move: Bg5
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 8
# Qwen US move: f1g2 Move number: 9
# Qwen CN move: Nc6 Move number: 10
# Qwen US move: e1g1 Move number: 11
# Qwen CN move: d7e8 Move number: 12
# Qwen US move: b1c3 Move number: 13
# Qwen CN move: a7a5 Move number: 14
# Qwen US move: Nd2 Move number: 15
# Qwen CN move: c6d4 Move number: 16
# Qwen US move: c4d5 Move number: 17
# Invalid move by Qwen black. Move: Bg2
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 18
# Qwen US move: d2c4 Move number: 19
# Qwen CN move: Nxe2+ Move number: 20
# Qwen US move: d1e2 Move number: 21
# Qwen CN move: f8b4 Move number: 22
# Qwen US move: c1f4 Move number: 23
# Qwen CN move: d7e8 Move number: 24
# Qwen US move: Bxc7 Move number: 25
# Qwen CN move: d8c7 Move number: 26
# Qwen US move: c3b5 Move number: 27
# Invalid move by Qwen black. Move: Nxb7
# New Move: a4
# Qwen CN move: a4 Move number: 28
# Qwen US move: b5c7 Move number: 29
# Qwen CN move: e8f8 Move number: 30
# Qwen US move: Ne5 Move number: 31
# Qwen CN move: e6d5 Move number: 32
# Qwen US move: c7a8 Move number: 33
# Qwen CN move: g7g6 Move number: 34
# Qwen US move: e5f7 Move number: 35
# Qwen CN move: Rg8 Move number: 36
# Qwen US move: f7g5 Move number: 37
# Qwen CN move: Nh5 Move number: 38
# Qwen US move: Nh3 Move number: 39
# Qwen CN move: Nf4 Move number: 40
# Qwen US move: h3f4 Move number: 41
# Qwen CN move: Bf5 Move number: 42
# Qwen US move: g2d5 Move number: 43
# Qwen CN move: a4a3 Move number: 44
# Qwen US move: f4e6 Move number: 45
# Qwen CN move: f8e7 Move number: 46
# Qwen US move: e6g5 Move number: 47
# Qwen CN move: e7f6 Move number: 48
# Qwen US move: e2c4 Move number: 49
# Invalid move by Qwen black. Move: Rg8
# New Move: Rg7
# Qwen CN move: Rg7 Move number: 50
# Qwen US move: c4d4 Move number: 51
# Qwen CN move: Ke7 Move number: 52
# Qwen US move: d4g7 Move number: 53
# Qwen CN move: e7e8 Move number: 54
# Qwen US move: g7f7 Move number: 55
# Qwen CN move: e8d8 Move number: 56
# Qwen US move: Qxf6+ Move number: 57
# Qwen CN move: b4e7 Move number: 58
# Qwen US move: g5f7 Move number: 59
# Invalid move by Qwen black. Move: Nf7+ Ke7
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 60
# Qwen US move: a8b6 Move number: 61
# Qwen CN move: d7c7 Move number: 62
# Qwen US move: Qg5+ Move number: 63
# Qwen CN move: e7g5 Move number: 64
# Qwen US move: b2a3 Move number: 65
# Qwen CN move: g5f6 Move number: 66
# Qwen US move: a1b1 Move number: 67
# Qwen CN move: Bd3 Move number: 68
# Qwen US move: f1c1 Move number: 69
# Qwen CN move: Bc3 Move number: 70
# Qwen US move: Rxc3+ Move number: 71
# Qwen CN move: Kb8 Move number: 72
# Qwen US move: c3c8 Move number: 73
# Invalid move by Qwen black. Move: Rc8#
# New Move: Ka7
# Qwen CN move: Ka7 Move number: 74
# Qwen US move: c8a8 Move number: 75
# Game 9 result: 1-0
#
#
# Starting game 10...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: Be7 Move number: 6
# Qwen US move: e1g1 Move number: 7
# Invalid move by Qwen black. Move: Bf4
# New Move: b6
# Qwen CN move: b6 Move number: 8
# Qwen US move: b1c3 Move number: 9
# Qwen CN move: e7f6 Move number: 10
# Qwen US move: Bxc6 Move number: 11
# Qwen CN move: d7c6 Move number: 12
# Qwen US move: d2d4 Move number: 13
# Qwen CN move: e5d4 Move number: 14
# Qwen US move: c3e2 Move number: 15
# Invalid move by Qwen black. Move: Nbd2
# New Move: Bh4
# Qwen CN move: Bh4 Move number: 16
# Qwen US move: f3h4 Move number: 17
# Qwen CN move: d8h4 Move number: 18
# Qwen US move: Nf4 Move number: 19
# Qwen CN move: c8a6 Move number: 20
# Qwen US move: f1e1 Move number: 21
# Qwen CN move: e8c8 Move number: 22
# Qwen US move: g2g3 Move number: 23
# Qwen CN move: Nh6 Move number: 24
# Qwen US move: g3h4 Move number: 25
# Qwen CN move: Ng4 Move number: 26
# Qwen US move: Ng2 Move number: 27
# Qwen CN move: Rdf8 Move number: 28
# Qwen US move: d1g4 Move number: 29
# Qwen CN move: f5 Move number: 30
# Qwen US move: g4h3 Move number: 31
# Qwen CN move: f8d8 Move number: 32
# Qwen US move: c1g5 Move number: 33
# Qwen CN move: d4d3 Move number: 34
# Qwen US move: g5d8 Move number: 35
# Qwen CN move: h8d8 Move number: 36
# Qwen US move: c2d3 Move number: 37
# Qwen CN move: Rd5 Move number: 38
# Qwen US move: e4d5 Move number: 39
# Qwen CN move: Bxd3 Move number: 40
# Qwen US move: h3d3 Move number: 41
# Qwen CN move: cxd5 Move number: 42
# Qwen US move: d3f5 Move number: 43
# Qwen CN move: Kb7 Move number: 44
# Qwen US move: f5d5 Move number: 45
# Qwen CN move: Kb8 Move number: 46
# Qwen US move: e1e8 Move number: 47
# Game 10 result: 1-0
#
#
# Starting game 11...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: Nc3 Move number: 5
# Qwen CN move: b8c6 Move number: 6
# Qwen US move: f1b5 Move number: 7
# Invalid move by Qwen black. Move: Bc4
# New Move: g6
# Qwen CN move: g6 Move number: 8
# Qwen US move: b5c6 Move number: 9
# Qwen CN move: d7c6 Move number: 10
# Qwen US move: Nh4 Move number: 11
# Qwen CN move: f6e4 Move number: 12
# Qwen US move: c3e4 Move number: 13
# Qwen CN move: d8h4 Move number: 14
# Qwen US move: d2d3 Move number: 15
# Qwen CN move: Be7 Move number: 16
# Qwen US move: e1g1 Move number: 17
# Qwen CN move: Be6 Move number: 18
# Qwen US move: Ng3 Move number: 19
# Qwen CN move: Rg8 Move number: 20
# Qwen US move: f1e1 Move number: 21
# Invalid move by Qwen black. Move: Rg8
# New Move: O-O-O
# Qwen CN move: O-O-O Move number: 22
# Qwen US move: e1e5 Move number: 23
# Qwen CN move: h4d4 Move number: 24
# Qwen US move: Re1 Move number: 25
# Qwen CN move: g8e8 Move number: 26
# Qwen US move: g3e4 Move number: 27
# Qwen CN move: c6c5 Move number: 28
# Qwen US move: a1b1 Move number: 29
# Qwen CN move: Rd5 Move number: 30
# Qwen US move: c1e3 Move number: 31
# Invalid move by Qwen black. Move: Bf4
# New Move: a6
# Qwen CN move: a6 Move number: 32
# Qwen US move: e3d4 Move number: 33
# Qwen CN move: d5d4 Move number: 34
# Qwen US move: Nf6 Move number: 35
# Qwen CN move: e7f6 Move number: 36
# Qwen US move: d1f3 Move number: 37
# Qwen CN move: f6h8 Move number: 38
# Qwen US move: e1e6 Move number: 39
# Qwen CN move: Rxe6 Move number: 40
# Qwen US move: f3f7 Move number: 41
# Qwen CN move: Re8 Move number: 42
# Qwen US move: Qf6 Move number: 43
# Qwen CN move: Re1+ Move number: 44
# Qwen US move: b1e1 Move number: 45
# Qwen CN move: Rd6 Move number: 46
# Qwen US move: f6h8 Move number: 47
# Qwen CN move: d6d8 Move number: 48
# Qwen US move: e1e8 Move number: 49
# Qwen CN move: c8d7 Move number: 50
# Qwen US move: e8d8 Move number: 51
# Qwen CN move: d7c6 Move number: 52
# Qwen US move: g1f1 Move number: 53
# Invalid move by Qwen black. Move:  Kb5
# New Move: Kb5
# Qwen CN move: Kb5 Move number: 54
# Qwen US move: h8h7 Move number: 55
# Invalid move by Qwen black. Move: Qg6
# New Move: Kb6
# Qwen CN move: Kb6 Move number: 56
# Qwen US move: d8c8 Move number: 57
# Invalid move by Qwen black. Move: Rc7
# New Move: Kc6
# Qwen CN move: Kc6 Move number: 58
# Qwen US move: h7c7 Move number: 59
# Invalid move by Qwen black. Move: Qxc5
# New Move: Kd5
# Qwen CN move: Kd5 Move number: 60
# Qwen US move: c7d7 Move number: 61
# Qwen CN move: Ke5 Move number: 62
# Qwen US move: c8f8 Move number: 63
# Qwen CN move: b7b5 Move number: 64
# Qwen US move: f2f4 Move number: 65
# Game 11 result: 1-0
#
#
# Starting game 12...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: Nxe5 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: Nf3+ Move number: 8
# Qwen US move: d1f3 Move number: 9
# Qwen CN move: d8f6 Move number: 10
# Qwen US move: f3e3 Move number: 11
# Qwen CN move: d7d5 Move number: 12
# Qwen US move: e4d5 Move number: 13
# Qwen CN move: g8e7 Move number: 14
# Qwen US move: f1b5 Move number: 15
# Qwen CN move: Bd7 Move number: 16
# Qwen US move: b5d7 Move number: 17
# Qwen CN move: Kd8 Move number: 18
# Qwen US move: d7a4 Move number: 19
# Qwen CN move: Nxd5 Move number: 20
# Qwen US move: e3e8 Move number: 21
# Game 12 result: 1-0
#
#
# Starting game 13...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Invalid move by Qwen black. Move: dxe5
# New Move: b6
# Qwen CN move: b6 Move number: 6
# Qwen US move: d4e5 Move number: 7
# Qwen CN move: f6e4 Move number: 8
# Qwen US move: Nbd2 Move number: 9
# Qwen CN move: e4c5 Move number: 10
# Qwen US move: d2b3 Move number: 11
# Qwen CN move: c5e6 Move number: 12
# Qwen US move: f1c4 Move number: 13
# Invalid move by Qwen black. Move: Bb5
# New Move: Qe7
# Qwen CN move: Qe7 Move number: 14
# Qwen US move: c2c3 Move number: 15
# Invalid move by Qwen black. Move: Be3
# New Move: Qf6
# Qwen CN move: Qf6 Move number: 16
# Qwen US move: e5f6 Move number: 17
# Invalid move by Qwen black. Move: fxg7
# New Move: c6
# Qwen CN move: c6 Move number: 18
# Qwen US move: f6g7 Move number: 19
# Qwen CN move: f8g7 Move number: 20
# Qwen US move: Nbd4 Move number: 21
# Qwen CN move: d7d5 Move number: 22
# Qwen US move: c4d3 Move number: 23
# Qwen CN move: h8g8 Move number: 24
# Qwen US move: d4e6 Move number: 25
# Qwen CN move: Bxc3+ Move number: 26
# Qwen US move: b2c3 Move number: 27
# Qwen CN move: Rh8 Move number: 28
# Qwen US move: Nh4 Move number: 29
# Qwen CN move: Rg8 Move number: 30
# Qwen US move: e6c7 Move number: 31
# Invalid move by Qwen black. Move: Nf4
# New Move: Kf8
# Qwen CN move: Kf8 Move number: 32
# Qwen US move: c1a3 Move number: 33
# Qwen CN move: Kg7 Move number: 34
# Qwen US move: d1h5 Move number: 35
# Qwen CN move: c6c5 Move number: 36
# Qwen US move: h5h7 Move number: 37
# Qwen CN move: g7f6 Move number: 38
# Qwen US move: Qh8+ Move number: 39
# Qwen CN move: g8h8 Move number: 40
# Qwen US move: h4f3 Move number: 41
# Qwen CN move: Rh7 Move number: 42
# Qwen US move: d3h7 Move number: 43
# Qwen CN move: b8c6 Move number: 44
# Qwen US move: e1c1 Move number: 45
# Qwen CN move: Bd7 Move number: 46
# Qwen US move: d1d5 Move number: 47
# Qwen CN move: d7e6 Move number: 48
# Qwen US move: d5d6 Move number: 49
# Qwen CN move: c6e5 Move number: 50
# Qwen US move: f3e5 Move number: 51
# Qwen CN move: Rd8 Move number: 52
# Qwen US move: d6d8 Move number: 53
# Qwen CN move: f6e5 Move number: 54
# Qwen US move: h1e1 Move number: 55
# Qwen CN move: e5f6 Move number: 56
# Qwen US move: Rd2 Move number: 57
# Qwen CN move: Bd5 Move number: 58
# Qwen US move: c7d5 Move number: 59
# Invalid move by Qwen black. Move: Nxf7+
# New Move: Kg7
# Qwen CN move: Kg7 Move number: 60
# Qwen US move: h7f5 Move number: 61
# Invalid move by Qwen black. Move: Bf4
# New Move: Kg8
# Qwen CN move: Kg8 Move number: 62
# Qwen US move: d2d3 Move number: 63
# Qwen CN move: Kg7 Move number: 64
# Qwen US move: d3g3 Move number: 65
# Qwen CN move: g7f8 Move number: 66
# Qwen US move: e1e8 Move number: 67
# Qwen CN move: f8e8 Move number: 68
# Qwen US move: Bh3 Move number: 69
# Qwen CN move: f7f5 Move number: 70
# Qwen US move: h3f5 Move number: 71
# Invalid move by Qwen black. Move: Bf4
# New Move: c4
# Qwen CN move: c4 Move number: 72
# Qwen US move: f5e6 Move number: 73
# Qwen CN move: e8d8 Move number: 74
# Qwen US move: Bh3 Move number: 75
# Qwen CN move: d8e8 Move number: 76
# Qwen US move: g3f3 Move number: 77
# Qwen CN move: a7a6 Move number: 78
# Qwen US move: f3f8 Move number: 79
# Game 13 result: 1-0
#
#
# Starting game 14...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Invalid move by Qwen black. Move: d4
# New Move: b5
# Qwen CN move: b5 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: c8b7 Move number: 6
# Qwen US move: Bxc6 Move number: 7
# Qwen CN move: b8c6 Move number: 8
# Qwen US move: e1g1 Move number: 9
# Qwen CN move: e7e6 Move number: 10
# Qwen US move: b1c3 Move number: 11
# Qwen CN move: Nge7 Move number: 12
# Qwen US move: d2d3 Move number: 13
# Qwen CN move: Nd5 Move number: 14
# Qwen US move: Nd2 Move number: 15
# Invalid move by Qwen black. Move: Nd2
# New Move: f5
# Qwen CN move: f5 Move number: 16
# Qwen US move: e4d5 Move number: 17
# Qwen CN move: c6d4 Move number: 18
# Qwen US move: Ncb1 Move number: 19
# Qwen CN move: e6d5 Move number: 20
# Qwen US move: d2f3 Move number: 21
# Qwen CN move: d4e6 Move number: 22
# Qwen US move: d3d4 Move number: 23
# Invalid move by Qwen black. Move: dxe6
# New Move: Qe7
# Qwen CN move: Qe7 Move number: 24
# Qwen US move: f1e1 Move number: 25
# Qwen CN move: Nxd4 Move number: 26
# Qwen US move: f3d4 Move number: 27
# Qwen CN move: c5d4 Move number: 28
# Qwen US move: b1a3 Move number: 29
# Qwen CN move: e7e4 Move number: 30
# Qwen US move: Re2 Move number: 31
# Qwen CN move: f8c5 Move number: 32
# Qwen US move: b2b4 Move number: 33
# Qwen CN move: Rb8 Move number: 34
# Qwen US move: e2e4 Move number: 35
# Qwen CN move: d5e4 Move number: 36
# Qwen US move: b4c5 Move number: 37
# Qwen CN move: Rg8 Move number: 38
# Qwen US move: c1f4 Move number: 39
# Qwen CN move: e8f7 Move number: 40
# Qwen US move: d1d4 Move number: 41
# Qwen CN move: b7c6 Move number: 42
# Qwen US move: h2h4 Move number: 43
# Qwen CN move: Rh8 Move number: 44
# Qwen US move: a3c4 Move number: 45
# Qwen CN move: h7h6 Move number: 46
# Qwen US move: c4e5 Move number: 47
# Qwen CN move: f7g8 Move number: 48
# Invalid move by Qwen white. Move: Nh3
# New Move: a3
# Qwen US move: a3 Move number: 49
# Qwen CN move: g8h7 Move number: 50
# Qwen US move: e5c6 Move number: 51
# Qwen CN move: Rb1+ Move number: 52
# Qwen US move: a1b1 Move number: 53
# Qwen CN move: d7c6 Move number: 54
# Qwen US move: d4d6 Move number: 55
# Qwen CN move: h8c8 Move number: 56
# Invalid move by Qwen white. Move: Qe2
# New Move: h5
# Qwen US move: h5 Move number: 57
# Qwen CN move: e4e3 Move number: 58
# Qwen US move: f4e3 Move number: 59
# Qwen CN move: Rc7 Move number: 60
# Qwen US move: d6g6 Move number: 61
# Qwen CN move: h7g8 Move number: 62
# Qwen US move: b1b8 Move number: 63
# Qwen CN move: c7c8 Move number: 64
# Qwen US move: Rxc8# Move number: 65
# Game 14 result: 1-0
#
#
# Starting game 15...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Invalid move by Qwen black. Move: Bc4
# New Move: g6
# Qwen CN move: g6 Move number: 6
# Qwen US move: c2c3 Move number: 7
# Qwen CN move: a7a6 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Qwen CN move: d7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: c8g4 Move number: 12
# Qwen US move: b1d2 Move number: 13
# Qwen CN move: Be7 Move number: 14
# Qwen US move: d1b3 Move number: 15
# Qwen CN move: Qd6 Move number: 16
# Qwen US move: Qxf7+ Move number: 17
# Qwen CN move: Kd8 Move number: 18
# Qwen US move: f3e5 Move number: 19
# Invalid move by Qwen black. Move: Nxe5
# New Move: Bf6
# Qwen CN move: Bf6 Move number: 20
# Qwen US move: e5g4 Move number: 21
# Qwen CN move: Nh6 Move number: 22
# Qwen US move: f7f6 Move number: 23
# Qwen CN move: d6f6 Move number: 24
# Qwen US move: g4f6 Move number: 25
# Qwen CN move: h8f8 Move number: 26
# Qwen US move: Nh5 Move number: 27
# Qwen CN move: g6h5 Move number: 28
# Qwen US move: d2f3 Move number: 29
# Qwen CN move: Rxf3 Move number: 30
# Qwen US move: g2f3 Move number: 31
# Qwen CN move: h6g8 Move number: 32
# Qwen US move: h1g1 Move number: 33
# Qwen CN move: Ne7 Move number: 34
# Qwen US move: g1g7 Move number: 35
# Qwen CN move: d8d7 Move number: 36
# Qwen US move: c1g5 Move number: 37
# Qwen CN move: a8g8 Move number: 38
# Qwen US move: g7e7 Move number: 39
# Invalid move by Qwen black. Move: Bh6
# New Move: Kd6
# Qwen CN move: Kd6 Move number: 40
# Qwen US move: e4e5 Move number: 41
# Qwen CN move: d6d5 Move number: 42
# Qwen US move: Rxd7+ Move number: 43
# Qwen CN move: d5e6 Move number: 44
# Qwen US move: d7e7 Move number: 45
# Qwen CN move: e6d5 Move number: 46
# Qwen US move: c3c4 Move number: 47
# Qwen CN move: Kxd4 Move number: 48
# Qwen US move: g5e3 Move number: 49
# Qwen CN move: Kd3 Move number: 50
# Qwen US move: Rd1+ Move number: 51
# Qwen CN move: Kxc4 Move number: 52
# Qwen US move: e1e2 Move number: 53
# Invalid move by Qwen black. Move: Rg8
# New Move: h4
# Qwen CN move: h4 Move number: 54
# Qwen US move: e7c7 Move number: 55
# Qwen CN move: g8b8 Move number: 56
# Qwen US move: Rc8 Move number: 57
# Qwen CN move: b8c8 Move number: 58
# Qwen US move: f3f4 Move number: 59
# Qwen CN move: c6c5 Move number: 60
# Qwen US move: f4f5 Move number: 61
# Qwen CN move: Rc6 Move number: 62
# Qwen US move: e5e6 Move number: 63
# Qwen CN move: Rc8 Move number: 64
# Qwen US move: Bxc5 Move number: 65
# Qwen CN move: Rc6 Move number: 66
# Qwen US move: c5e3 Move number: 67
# Qwen CN move: Rc8 Move number: 68
# Qwen US move: d1c1 Move number: 69
# Qwen CN move: c4d5 Move number: 70
# Qwen US move: c1c8 Move number: 71
# Qwen CN move: d5d6 Move number: 72
# Qwen US move: c8d8 Move number: 73
# Qwen CN move: d6c6 Move number: 74
# Qwen US move: e6e7 Move number: 75
# Invalid move by Qwen black. Move: Bxc5
# New Move: Kb5
# Qwen CN move: Kb5 Move number: 76
# Qwen US move: e7e8q Move number: 77
# Qwen CN move: Kb4 Move number: 78
# Qwen US move: e3b6 Move number: 79
# Qwen CN move: h7h5 Move number: 80
# Qwen US move: d8d4 Move number: 81
# Game 15 result: 1-0
#
#
# Starting game 16...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Invalid move by Qwen black. Move: Nc6
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 6
# Qwen US move: e5c6 Move number: 7
# Invalid move by Qwen black. Move: Nxe5
# New Move: d6
# Qwen CN move: d6 Move number: 8
# Qwen US move: c6d8 Move number: 9
# Qwen CN move: g8f6 Move number: 10
# Qwen US move: Nxb7 Move number: 11
# Qwen CN move: f6e4 Move number: 12
# Qwen US move: f1b5 Move number: 13
# Qwen CN move: e8f8 Move number: 14
# Qwen US move: f2f3 Move number: 15
# Qwen CN move: Bxb2 Move number: 16
# Qwen US move: c1b2 Move number: 17
# Qwen CN move: Bg4 Move number: 18
# Qwen US move: Bxf6 Move number: 19
# Qwen CN move: Bh5 Move number: 20
# Qwen US move: f6e7 Move number: 21
# Qwen CN move: Kg8 Move number: 22
# Qwen US move: d2d3 Move number: 23
# Qwen CN move: a7a6 Move number: 24
# Qwen US move: d3e4 Move number: 25
# Qwen CN move: a6b5 Move number: 26
# Qwen US move: e1e2 Move number: 27
# Qwen CN move: h5g6 Move number: 28
# Qwen US move: b1d2 Move number: 29
# Qwen CN move: Rxa2 Move number: 30
# Qwen US move: d1c1 Move number: 31
# Qwen CN move: Bh5 Move number: 32
# Qwen US move: a1a2 Move number: 33
# Qwen CN move: Bg6 Move number: 34
# Qwen US move: a2a8 Move number: 35
# Game 16 result: 1-0
#
#
# Starting game 17...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Qwen CN move: d5 Move number: 6
# Qwen US move: f3e5 Move number: 7
# Qwen CN move: d5e4 Move number: 8
# Qwen US move: Nxc6 Move number: 9
# Qwen CN move: b7c6 Move number: 10
# Qwen US move: f1e2 Move number: 11
# Qwen CN move: Nxe7 Move number: 12
# Qwen US move: e1g1 Move number: 13
# Qwen CN move: g7g6 Move number: 14
# Qwen US move: f1e1 Move number: 15
# Qwen CN move: f8g7 Move number: 16
# Qwen US move: Bd3 Move number: 17
# Qwen CN move: e4d3 Move number: 18
# Qwen US move: c1g5 Move number: 19
# Qwen CN move: f7f6 Move number: 20
# Qwen US move: g5d2 Move number: 21
# Qwen CN move: e8g8 Move number: 22
# Qwen US move: d2b4 Move number: 23
# Qwen CN move: f8e8 Move number: 24
# Qwen US move: d1d3 Move number: 25
# Qwen CN move: e7d5 Move number: 26
# Qwen US move: d3c4 Move number: 27
# Qwen CN move: Re3 Move number: 28
# Qwen US move: e1e3 Move number: 29
# Qwen CN move: Bh6 Move number: 30
# Qwen US move: e3e1 Move number: 31
# Qwen CN move: g8g7 Move number: 32
# Qwen US move: b1c3 Move number: 33
# Qwen CN move: Bd2 Move number: 34
# Qwen US move: c4c6 Move number: 35
# Invalid move by Qwen black. Move: Qxc6
# New Move: Bd7
# Qwen CN move: Bd7 Move number: 36
# Qwen US move: c6d5 Move number: 37
# Qwen CN move: Bxc3 Move number: 38
# Qwen US move: b4c3 Move number: 39
# Qwen CN move: d7f5 Move number: 40
# Qwen US move: d5f3 Move number: 41
# Qwen CN move: f5c2 Move number: 42
# Qwen US move: Qxa8 Move number: 43
# Qwen CN move: d8a8 Move number: 44
# Qwen US move: e1e7 Move number: 45
# Qwen CN move: Kf8 Move number: 46
# Qwen US move: a1e1 Move number: 47
# Qwen CN move: a7a5 Move number: 48
# Qwen US move: d4d5 Move number: 49
# Invalid move by Qwen black. Move: Qd6
# New Move: f5
# Qwen CN move: f5 Move number: 50
# Qwen US move: c3g7 Move number: 51
# Qwen CN move: f8g8 Move number: 52
# Invalid move by Qwen white. Move: Bxc7
# New Move: Re8+
# Qwen US move: Re8+ Move number: 53
# Qwen CN move: a8e8 Move number: 54
# Qwen US move: Re2 Move number: 55
# Qwen CN move: e8e2 Move number: 56
# Qwen US move: h2h3 Move number: 57
# Qwen CN move: g8g7 Move number: 58
# Qwen US move: f2f3 Move number: 59
# Qwen CN move: Qe4 Move number: 60
# Qwen US move: f3e4 Move number: 61
# Qwen CN move: fxe4 Move number: 62
# Qwen US move: Kh2 Move number: 63
# Invalid move by Qwen black. Move: Bc4
# New Move: Kf7
# Qwen CN move: Kf7 Move number: 64
# Qwen US move: h2g1 Move number: 65
# Invalid move by Qwen black. Move: Kf2
# New Move: Kg7
# Qwen CN move: Kg7 Move number: 66
# Qwen US move: g1f2 Move number: 67
# Invalid move by Qwen black. Move: Kf1
# New Move: Kf7
# Qwen CN move: Kf7 Move number: 68
# Qwen US move: f2e3 Move number: 69
# Invalid move by Qwen black. Move: Ke4
# New Move: Kg7
# Qwen CN move: Kg7 Move number: 70
# Qwen US move: e3d2 Move number: 71
# Qwen CN move: Kf7 Move number: 72
# Qwen US move: d2c2 Move number: 73
# Qwen CN move: f7f6 Move number: 74
# Qwen US move: c2b3 Move number: 75
# Qwen CN move: f6e5 Move number: 76
# Qwen US move: Kc4 Move number: 77
# Qwen CN move: e5f4 Move number: 78
# Qwen US move: c4d4 Move number: 79
# Qwen CN move: Kf5 Move number: 80
# Qwen US move: b2b3 Move number: 81
# Qwen CN move: f5f4 Move number: 82
# Qwen US move: h3h4 Move number: 83
# Qwen CN move: Kf5 Move number: 84
# Qwen US move: g2g3 Move number: 85
# Qwen CN move: h7h5 Move number: 86
# Qwen US move: a2a3 Move number: 87
# Qwen CN move: g6g5 Move number: 88
# Qwen US move: h4g5 Move number: 89
# Qwen CN move: Kg4 Move number: 90
# ...
# Qwen CN move: g7g6 Move number: 92
# Invalid move by Qwen white. Move: Rf4+
# New Move: a5
# Qwen US move: a5 Move number: 93
# Qwen CN move: g6g7 Move number: 94
# Qwen US move: a5a6 Move number: 95
# Invalid move by Qwen black. Move: Rf7+
# New Move: Kh8
# Qwen CN move: Kh8 Move number: 96
# Qwen US move: a6a7 Move number: 97
# Invalid move by Qwen black. Move: Rf1
# New Move: Kg7
# Qwen CN move: Kg7 Move number: 98
# Qwen US move: f4g4 Move number: 99
# Qwen CN move: g7h6 Move number: 100
# Qwen US move: Rg8 Move number: 101
# Qwen CN move: h6h7 Move number: 102
# Qwen US move: a7a8q Move number: 103
# Qwen CN move: h7h6 Move number: 104
# Qwen US move: a8h1 Move number: 105
# Game 94 result: 1-0
#
#
# Starting game 95...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Qwen CN move: e5d4 Move number: 6
# Qwen US move: f3d4 Move number: 7
# Invalid move by Qwen black. Move: Nf3
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 8
# Qwen US move: b1a3 Move number: 9
# Qwen CN move: Nxe5 Move number: 10
# Qwen US move: a3c4 Move number: 11
# Qwen CN move: d7d6 Move number: 12
# Qwen US move: c4e5 Move number: 13
# Qwen CN move: d6e5 Move number: 14
# Qwen US move: Nf3 Move number: 15
# Qwen CN move: d8d1 Move number: 16
# Qwen US move: e1d1 Move number: 17
# Qwen CN move: Nf6 Move number: 18
# Qwen US move: f3d2 Move number: 19
# Qwen CN move: c8e6 Move number: 20
# Qwen US move: f1b5 Move number: 21
# Qwen CN move: Bd7 Move number: 22
# Qwen US move: b5c4 Move number: 23
# Qwen CN move: e8c8 Move number: 24
# Qwen US move: d1e1 Move number: 25
# Qwen CN move: d7c6 Move number: 26
# Qwen US move: f2f3 Move number: 27
# Invalid move by Qwen black. Move: Nf5
# New Move: Rd6
# Qwen CN move: Rd6 Move number: 28
# Qwen US move: c4e2 Move number: 29
# Invalid move by Qwen black. Move: Nxe5
# New Move: Ng8
# Qwen CN move: Ng8 Move number: 30
# Qwen US move: d2c4 Move number: 31
# Invalid move by Qwen black. Move: Ncxe5
# New Move: Rd7
# Qwen CN move: Rd7 Move number: 32
# Qwen US move: c4e5 Move number: 33
# Invalid move by Qwen black. Move: Nxe5
# New Move: b6
# Qwen CN move: b6 Move number: 34
# Qwen US move: e5c6 Move number: 35
# Qwen CN move: d7d6 Move number: 36
# Qwen US move: Nxe5 Move number: 37
# Qwen CN move: f7f5 Move number: 38
# Qwen US move: e5f7 Move number: 39
# Qwen CN move: f5e4 Move number: 40
# Qwen US move: f7h8 Move number: 41
# Qwen CN move: Ne7 Move number: 42
# Qwen US move: h8f7 Move number: 43
# Qwen CN move: Rd1+ Move number: 44
# Qwen US move: Kf2 Move number: 45
# Qwen CN move: Re1 Move number: 46
# Qwen US move: e2a6 Move number: 47
# Invalid move by Qwen black. Move: Be3
# New Move: Kb8
# Qwen CN move: Kb8 Move number: 48
# Qwen US move: f2e1 Move number: 49
# Invalid move by Qwen black. Move: Bxc8
# New Move: Ng6
# Qwen CN move: Ng6 Move number: 50
# Qwen US move: c1g5 Move number: 51
# Qwen CN move: Nxe5 Move number: 52
# Qwen US move: f7e5 Move number: 53
# Qwen CN move: c7c5 Move number: 54
# Qwen US move: a1d1 Move number: 55
# Qwen CN move: e4f3 Move number: 56
# Qwen US move: Bd8 Move number: 57
# Qwen CN move: f3f2 Move number: 58
# Qwen US move: e1f1 Move number: 59
# Invalid move by Qwen black. Move: Be2
# New Move: h5
# Qwen CN move: h5 Move number: 60
# Qwen US move: e5c6 Move number: 61
# Qwen CN move: b8a8 Move number: 62
# Qwen US move: Bd3 Move number: 63
# Qwen CN move: h5h4 Move number: 64
# Qwen US move: d8h4 Move number: 65
# Qwen CN move: a8b7 Move number: 66
# Qwen US move: c6d8 Move number: 67
# Invalid move by Qwen black. Move: Nc6+
# New Move: Kc8
# Qwen CN move: Kc8 Move number: 68
# Qwen US move: d3f5 Move number: 69
# Invalid move by Qwen black. Move: Nc6
# New Move: Kb8
# Qwen CN move: Kb8 Move number: 70
# Qwen US move: h4g3 Move number: 71
# Invalid move by Qwen black. Move: Ke2
# New Move: Ka8
# Qwen CN move: Ka8 Move number: 72
# Qwen US move: f5e4 Move number: 73
# Game 95 result: 1-0
#
#
# Starting game 96...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1c4 Move number: 5
# Qwen CN move: Nf6 Move number: 6
# Qwen US move: f3g5 Move number: 7
# Invalid move by Qwen black. Move: Bc4
# New Move: g6
# Qwen CN move: g6 Move number: 8
# Qwen US move: g5f7 Move number: 9
# Qwen CN move: d8e7 Move number: 10
# Qwen US move: Nxe5 Move number: 11
# Qwen CN move: e7e5 Move number: 12
# Qwen US move: e1g1 Move number: 13
# Qwen CN move: f8d6 Move number: 14
# Qwen US move: g2g3 Move number: 15
# Qwen CN move: Nh5 Move number: 16
# Qwen US move: c2c3 Move number: 17
# Qwen CN move: Bc5 Move number: 18
# Qwen US move: Bd3 Move number: 19
# Qwen CN move: Bd4 Move number: 20
# Qwen US move: c3d4 Move number: 21
# Qwen CN move: Nd8 Move number: 22
# Qwen US move: d4e5 Move number: 23
# Qwen CN move: d8e6 Move number: 24
# Qwen US move: d3e2 Move number: 25
# Qwen CN move: e6d4 Move number: 26
# Qwen US move: b1c3 Move number: 27
# Qwen CN move: d4e2 Move number: 28
# Qwen US move: c3e2 Move number: 29
# Qwen CN move: Ng7 Move number: 30
# Qwen US move: f2f3 Move number: 31
# Qwen CN move: Rg8 Move number: 32
# Qwen US move: d2d4 Move number: 33
# Qwen CN move: Nh5 Move number: 34
# Qwen US move: g1f2 Move number: 35
# Invalid move by Qwen black. Move: Nh4
# New Move: b5
# Qwen CN move: b5 Move number: 36
# Qwen US move: d1b3 Move number: 37
# Qwen CN move: g8h8 Move number: 38
# Qwen US move: Qg8+ Move number: 39
# Qwen CN move: h8g8 Move number: 40
# Qwen US move: c1d2 Move number: 41
# Qwen CN move: d7d5 Move number: 42
# Qwen US move: e4d5 Move number: 43
# Qwen CN move: Rg7 Move number: 44
# Qwen US move: g3g4 Move number: 45
# Invalid move by Qwen black. Move: Bg5
# New Move: c6
# Qwen CN move: c6 Move number: 46
# Qwen US move: d5d6 Move number: 47
# Qwen CN move: c8e6 Move number: 48
# Invalid move by Qwen white. Move: Nh4
# New Move: Ng1
# Qwen US move: Ng1 Move number: 49
# Qwen CN move: e8c8 Move number: 50
# Qwen US move: Nh3 Move number: 51
# Qwen CN move: d8f8 Move number: 52
# Qwen US move: f2g1 Move number: 53
# Qwen CN move: c8d7 Move number: 54
# Qwen US move: d2h6 Move number: 55
# Qwen CN move: Rxf3 Move number: 56
# Qwen US move: f1f3 Move number: 57
# Qwen CN move: Bg8 Move number: 58
# Qwen US move: Rf2 Move number: 59
# Invalid move by Qwen black. Move: Bxd4
# New Move: Bc4
# Qwen CN move: Bc4 Move number: 60
# Qwen US move: h3g5 Move number: 61
# Invalid move by Qwen black. Move: Nxf3
# New Move: b4
# Qwen CN move: b4 Move number: 62
# Qwen US move: a1c1 Move number: 63
# Qwen CN move: c4d5 Move number: 64
# Qwen US move: Rf3 Move number: 65
# Qwen CN move: g7g8 Move number: 66
# Qwen US move: f3f2 Move number: 67
# Qwen CN move: a7a5 Move number: 68
# Qwen US move: c1e1 Move number: 69
# Qwen CN move: Ng7 Move number: 70
# Qwen US move: g5h7 Move number: 71
# Invalid move by Qwen black. Move: Ng5
# New Move: Bb3
# Qwen CN move: Bb3 Move number: 72
# Qwen US move: h7f6 Move number: 73
# Qwen CN move: d7c8 Move number: 74
# Qwen US move: Bxg7 Move number: 75
# Qwen CN move: b3a2 Move number: 76
# Qwen US move: f6g8 Move number: 77
# Qwen CN move: a2g8 Move number: 78
# Qwen US move: f2f8 Move number: 79
# Invalid move by Qwen black. Move: Rxf3
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 80
# Qwen US move: f8g8 Move number: 81
# Qwen CN move: Ke6 Move number: 82
# Qwen US move: d6d7 Move number: 83
# Qwen CN move: e6d5 Move number: 84
# Qwen US move: b2b3 Move number: 85
# Qwen CN move: d5d4 Move number: 86
# Qwen US move: Rd8 Move number: 87
# Qwen CN move: d4c3 Move number: 88
# Qwen US move: d8e8 Move number: 89
# Invalid move by Qwen black. Move: Rf2
# New Move: Kd3
# Qwen CN move: Kd3 Move number: 90
# Qwen US move: d7d8q Move number: 91
# Qwen CN move: Kc2 Move number: 92
# Qwen US move: e1e2 Move number: 93
# Qwen CN move: c2c3 Move number: 94
# Qwen US move: d8d2 Move number: 95
# Qwen CN move: c3b3 Move number: 96
# Qwen US move: Qd1+ Move number: 97
# Qwen CN move: b3c4 Move number: 98
# Qwen US move: d1c2 Move number: 99
# Invalid move by Qwen black. Move: Qc4
# New Move: Kd4
# Qwen CN move: Kd4 Move number: 100
# Qwen US move: e8d8 Move number: 101
# Game 96 result: 1-0
#
#
# Starting game 97...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen US move: Bxc6 Move number: 7
# Qwen CN move: d7c6 Move number: 8
# Qwen US move: e1g1 Move number: 9
# Qwen CN move: Nf6 Move number: 10
# Qwen US move: f3e5 Move number: 11
# Qwen CN move: f8c5 Move number: 12
# Qwen US move: b1c3 Move number: 13
# Qwen CN move: Nxd5 Move number: 14
# Qwen US move: e4d5 Move number: 15
# Qwen CN move: c6d5 Move number: 16
# Qwen US move: d2d4 Move number: 17
# Qwen CN move: c5a7 Move number: 18
# Qwen US move: c3e2 Move number: 19
# Qwen CN move: Qg5 Move number: 20
# Qwen US move: c1g5 Move number: 21
# Qwen CN move: f7f6 Move number: 22
# Qwen US move: g1h1 Move number: 23
# Qwen CN move: f6e5 Move number: 24
# Qwen US move: Bd2 Move number: 25
# Qwen CN move: Bxd4 Move number: 26
# Qwen US move: d1e1 Move number: 27
# Qwen CN move: Rg8 Move number: 28
# Qwen US move: e2d4 Move number: 29
# Qwen CN move: e5e4 Move number: 30
# Qwen US move: f2f4 Move number: 31
# Qwen CN move: Rf8 Move number: 32
# Qwen US move: d2a5 Move number: 33
# Qwen CN move: c7c5 Move number: 34
# Qwen US move: Bd2 Move number: 35
# Qwen CN move: c5d4 Move number: 36
# Qwen US move: h2h4 Move number: 37
# Qwen CN move: Rh8 Move number: 38
# Qwen US move: f4f5 Move number: 39
# Qwen CN move: c8f5 Move number: 40
# Qwen US move: f1f5 Move number: 41
# Qwen CN move: e8c8 Move number: 42
# Qwen US move: Rf8 Move number: 43
# Qwen CN move: h8f8 Move number: 44
# Qwen US move: d2a5 Move number: 45
# Qwen CN move: d8e8 Move number: 46
# Qwen US move: e1b4 Move number: 47
# Qwen CN move: c8b8 Move number: 48
# Qwen US move: a1e1 Move number: 49
# Qwen CN move: e4e3 Move number: 50
# Qwen US move: b4d4 Move number: 51
# Qwen CN move: e3e2 Move number: 52
# Qwen US move: d4d5 Move number: 53
# Qwen CN move: Rf1+ Move number: 54
# Qwen US move: h1h2 Move number: 55
# Qwen CN move: Re1 Move number: 56
# Qwen US move: a5e1 Move number: 57
# Qwen CN move: b8a8 Move number: 58
# Qwen US move: d5f7 Move number: 59
# Qwen CN move: Re3 Move number: 60
# Qwen US move: f7f8 Move number: 61
# Qwen CN move: Re8 Move number: 62
# Qwen US move: f8e8 Move number: 63
# Qwen CN move: a8a7 Move number: 64
# Qwen US move: e8e7 Move number: 65
# Qwen CN move: a7b6 Move number: 66
# Qwen US move: Qe8 Move number: 67
# Qwen CN move: b6c7 Move number: 68
# Qwen US move: e1g3 Move number: 69
# Invalid move by Qwen black. Move: Bf4
# New Move: Kb6
# Qwen CN move: Kb6 Move number: 70
# Qwen US move: e8e3 Move number: 71
# Qwen CN move: Kb5 Move number: 72
# Qwen US move: e3e2 Move number: 73
# Qwen CN move: b5b6 Move number: 74
# Qwen US move: e2e3 Move number: 75
# Qwen CN move: b6b5 Move number: 76
# Qwen US move: Qe4 Move number: 77
# Qwen CN move: b5b6 Move number: 78
# Qwen US move: e4e6 Move number: 79
# Invalid move by Qwen black. Move: Qe5+
# New Move: Ka7
# Qwen CN move: Ka7 Move number: 80
# Qwen US move: g3c7 Move number: 81
# Invalid move by Qwen black. Move: Bc7
# New Move: h6
# Qwen CN move: h6 Move number: 82
# Qwen US move: c7b6 Move number: 83
# Invalid move by Qwen black. Move: Bb4
# New Move: Kb8
# Qwen CN move: Kb8 Move number: 84
# Qwen US move: e6e8 Move number: 85
# Game 97 result: 1-0
#
#
# Starting game 98...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: Nf6 Move number: 6
# Qwen US move: e1g1 Move number: 7
# Qwen CN move: Bc5 Move number: 8
# Qwen US move: Be2 Move number: 9
# Qwen CN move: Nd4 Move number: 10
# Qwen US move: f3e5 Move number: 11
# Qwen CN move: Nh5 Move number: 12
# Qwen US move: e2h5 Move number: 13
# Qwen CN move: d8f6 Move number: 14
# Qwen US move: c2c3 Move number: 15
# Qwen CN move: f6e5 Move number: 16
# Qwen US move: c3d4 Move number: 17
# Qwen CN move: c5d4 Move number: 18
# Qwen US move: b1c3 Move number: 19
# Qwen CN move: Qg3 Move number: 20
# Qwen US move: h2g3 Move number: 21
# Qwen CN move: Rg8 Move number: 22
# Qwen US move: c3e2 Move number: 23
# Qwen CN move: Bf6 Move number: 24
# Qwen US move: d2d4 Move number: 25
# Qwen CN move: Bg5 Move number: 26
# Qwen US move: c1g5 Move number: 27
# Qwen CN move: Rh8 Move number: 28
# Qwen US move: d1b3 Move number: 29
# Qwen CN move: Rg8 Move number: 30
# Qwen US move: b3f7 Move number: 31
# Game 98 result: 1-0
#
#
# Starting game 99...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Invalid move by Qwen black. Move: dxe5
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 6
# Qwen US move: b1a3 Move number: 7
# Qwen CN move: Nge7 Move number: 8
# Qwen US move: d4d5 Move number: 9
# Qwen CN move: c6d4 Move number: 10
# Qwen US move: f3d4 Move number: 11
# Qwen CN move: e5d4 Move number: 12
# Invalid move by Qwen white. Move: Nbd2
# New Move: Bd3
# Qwen US move: Bd3 Move number: 13
# Qwen CN move: d7d6 Move number: 14
# Qwen US move: Be2 Move number: 15
# Qwen CN move: e8g8 Move number: 16
# Qwen US move: d1d4 Move number: 17
# Qwen CN move: e7g6 Move number: 18
# Qwen US move: h2h4 Move number: 19
# Qwen CN move: Qg5 Move number: 20
# Qwen US move: c1g5 Move number: 21
# Invalid move by Qwen black. Move: Nf3
# New Move: f5
# Qwen CN move: f5 Move number: 22
# Qwen US move: h4h5 Move number: 23
# Qwen CN move: g6e5 Move number: 24
# Qwen US move: Bd2 Move number: 25
# Qwen CN move: f5e4 Move number: 26
# Qwen US move: d2b4 Move number: 27
# Qwen CN move: a7a5 Move number: 28
# Qwen US move: b4d6 Move number: 29
# Invalid move by Qwen black. Move: Rf1
# New Move: Rf4
# Qwen CN move: Rf4 Move number: 30
# Qwen US move: d6e5 Move number: 31
# Qwen CN move: Rxf2 Move number: 32
# Qwen US move: e1d2 Move number: 33
# Qwen CN move: f2e2 Move number: 34
# Qwen US move: d2e2 Move number: 35
# Qwen CN move: c8g4 Move number: 36
# Qwen US move: Ke3 Move number: 37
# Qwen CN move: a8f8 Move number: 38
# Qwen US move: b2b3 Move number: 39
# Qwen CN move: Rf1 Move number: 40
# Qwen US move: a1f1 Move number: 41
# Qwen CN move: h7h6 Move number: 42
# Qwen US move: f1f8 Move number: 43
# Qwen CN move: Kxf8 Move number: 44
# Qwen US move: d4c5 Move number: 45
# Qwen CN move: f8e8 Move number: 46
# Qwen US move: e5c7 Move number: 47
# Qwen CN move: g4f3 Move number: 48
# Qwen US move: g2f3 Move number: 49
# Qwen CN move: exf3 Move number: 50
# Qwen US move: e3f3 Move number: 51
# Qwen CN move: e8f7 Move number: 52
# Qwen US move: h1f1 Move number: 53
# Qwen CN move: f7g8 Move number: 54
# Qwen US move: Bd6 Move number: 55
# Invalid move by Qwen black. Move: Bc5
# New Move: Kh7
# Qwen CN move: Kh7 Move number: 56
# Qwen US move: c5d4 Move number: 57
# Invalid move by Qwen black. Move: Bxd7+
# New Move: g5
# Qwen CN move: g5 Move number: 58
# Qwen US move: d4d3 Move number: 59
# Qwen CN move: h7h8 Move number: 60
# Qwen US move: Bc5 Move number: 61
# Qwen CN move: b7b6 Move number: 62
# Qwen US move: c5d4 Move number: 63
# Qwen CN move: h8g8 Move number: 64
# Qwen US move: f3e2 Move number: 65
# Qwen CN move: g4 Move number: 66
# Qwen US move: d3g6 Move number: 67
# Game 99 result: 1-0
#
#
# Starting game 100...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Invalid move by Qwen black. Move: Bc4
# New Move: g6
# Qwen CN move: g6 Move number: 6
# Qwen US move: c2c3 Move number: 7
# Qwen CN move: g8e7 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Qwen CN move: e7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: d7d6 Move number: 12
# Qwen US move: d4d5 Move number: 13
# Invalid move by Qwen black. Move: dxe5
# New Move: Nd4
# Qwen CN move: Nd4 Move number: 14
# Qwen US move: c3d4 Move number: 15
# Qwen CN move: f8g7 Move number: 16
# Qwen US move: Nfd2 Move number: 17
# Qwen CN move: e5d4 Move number: 18
# Qwen US move: d2f3 Move number: 19
# Qwen CN move: c7c5 Move number: 20
# Qwen US move: d5c6 Move number: 21
# Qwen CN move: Qd7 Move number: 22
# Qwen US move: c6d7 Move number: 23
# Qwen CN move: Kf8 Move number: 24
# Qwen US move: Ng5 Move number: 25
# Qwen CN move: Bxd7 Move number: 26
# Qwen US move: d1b3 Move number: 27
# Qwen CN move: Rg8 Move number: 28
# Qwen US move: b3f7 Move number: 29
# Game 100 result: 1-0

# %%
results = []

# %%
results.append({
            "Qwen US Wins": qwen_us_wins,
            "Qwen CN Wins": qwen_cn_wins,
            "Draws": draws,
        })

print(results)
# Out:
# [{'Qwen US Wins': 95, 'Qwen CN Wins': 4, 'Draws': 1}]

# %% [markdown]
# ## Swapping sides

# %%
stockfish = Stockfish()
stockfish.update_engine_parameters({"Threads": 4, "Hash": 4096})

# %%
for game_number in range(1, NUM_GAMES + 1):
    
    move_counter = 0

    print(f"Starting game {game_number}...")

    board = chess.Board()

    while not board.is_game_over() and move_counter <= MOVE_LIMIT:
        if board.turn == chess.WHITE and not board.is_game_over():
            num = random.randint(1,100)
            
            if num <= QWEN_US_AI:
                stockfish.set_fen_position(board.fen())
                qwen_us_move = await get_move_with_timeout(stockfish)

                if qwen_us_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break
            
            else:
                qwen_us_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_us_move)
            except Exception as e:
                print(f"Invalid move by Qwen white. Move: {qwen_us_move}")
                qwen_us_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_us_move)
                print(f"New Move: {qwen_us_move}")
                # continue
            
            move_counter += 1        
            print(f"Qwen US move: {qwen_us_move} Move number: {move_counter}")

        elif board.turn == chess.BLACK and not board.is_game_over():
            num = random.randint(1, 100)

            if num <= QWEN_CN_AI:
                stockfish.set_fen_position(board.fen())
                qwen_cn_move = await get_move_with_timeout(stockfish)

                if qwen_cn_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break

            else:
                qwen_cn_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_cn_move)
            except Exception as e:
                print(f"Invalid move by Qwen black. Move: {qwen_cn_move}")
                qwen_cn_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_cn_move)
                print(f"New Move: {qwen_cn_move}")
                # continue
            move_counter += 1
            print(f"Qwen CN move: {qwen_cn_move} Move number: {move_counter}")   

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        qwen_cn_wins += 1
    elif result == "0-1":
        qwen_us_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n\n")

# %%
results = []

# %%
results.append({
            "Qwen US Wins": qwen_us_wins,
            "Qwen CN Wins": qwen_cn_wins,
            "Draws": draws,
        })

print(results)

# %%
df = pd.DataFrame(results)
df.to_csv(f"LLM_{QWEN_US_AI}_vs_LLM_{QWEN_CN_AI}.csv", index=False)
print(f"Results saved to LLM_{QWEN_US_AI}_vs_LLM_{QWEN_CN_AI}.csv")
