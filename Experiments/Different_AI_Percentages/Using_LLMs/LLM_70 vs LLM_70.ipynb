# %% [markdown]
# # LLM_1 - **70%** vs. LLM_2 - **70%**

# %%
import chess
from stockfish import Stockfish
from ollama import chat
from ollama import ChatResponse
import json
import random
import pandas as pd
import asyncio

# %%
# STOCKFISH_PATH = r"C:\Users\nafis\Downloads\stockfish-windows-x86-64-avx2\stockfish\stockfish-windows-x86-64-avx2.exe"

STOCKFISH_ELO = 3500
NUM_GAMES = 100
MOVE_LIMIT = 300
RANDOM_START = 0
QWEN_US_AI = 70
QWEN_CN_AI = 70

# %%
stockfish = Stockfish()
stockfish.update_engine_parameters({"Threads": 4, "Hash": 4096})

# %%
qwen_cn_wins = 0
qwen_us_wins = 0
draws = 0

# %%
# def generate_random_number(seed:int) -> int:
#     # random.seed(seed)
#     return random.randint(1, 100)

# %%
def valid_move_to_string(board):
    legal_moves = [
        board.san(move) for move in board.legal_moves]
    
    if not legal_moves:
        return "No legal moves."
    else:
        return ", ".join(legal_moves)

# %%
def get_move_history(board: chess.Board) -> str:
    """Return a formatted move history string like '1. e4 e5 2. Nf3 d5'."""
    temp_board = chess.Board()  # Start from the initial position.
    move_history = []
    
    # Iterate over the moves in the board's move stack.
    for i, move in enumerate(board.move_stack):
        # Get the SAN for the move in the current temporary board.
        move_san = temp_board.san(move)
        # Push the move so that the board state is updated.
        temp_board.push(move)
        
        # For white moves (even index), start a new entry with move number.
        if i % 2 == 0:
            move_history.append(f"{i//2 + 1}. {move_san}")
        # For black moves, append to the last white move entry.
        else:
            move_history[-1] += f" {move_san}"
    
    # Join all entries with a space.
    return " ".join(move_history)

# %%
async def get_move_with_timeout(stockfish, timeout=15):
    """
    Run stockfish.get_best_move() in a separate thread and wait for a maximum of `timeout` seconds.
    If the call exceeds the timeout, return None.
    """
    try:
        # Use asyncio.to_thread to run the blocking call in a separate thread.
        move = await asyncio.wait_for(asyncio.to_thread(stockfish.get_best_move), timeout)
        return move
    except asyncio.TimeoutError:
        # move = stockfish.get_best_move_time(1000)
        print(f"Timeout: stockfish.get_best_move() took more than 15 seconds.")
        return None

# %%
def get_qwen_move(board:chess.Board, fen:str, temp=0.0):
    qwen_move = None

    valid_moves = valid_move_to_string(board)

    move_history = get_move_history(board)
    
    response: ChatResponse = chat(model='qwen:32b', messages=[
        {
            'role': 'system',
            'content': 'You are a grand master chess player.'
        },
        {
            'role': 'user',
            'content': f"""You are playing chess and it is your turn. This is the current state of the game. Use this to work out where the pieces are on the board:

FEN: {fen}

The possible set of legal moves are: 

Legal Moves: {valid_moves}

+(You have to choose one from the provided list. Do not choose a move that is not in the list.)

The move history is: {move_history}.

Output the best move in SAN format to follow this position. Use the following single blob of JSON. Do not include any other information.
{{
    "san": "The move in SAN format",
}}"""}], options={"temperature": temp})
    
    try:
        parsed_json = json.loads(response.message.content)
        qwen_move = parsed_json["san"]
    except Exception as e:
        print(f"Wrong format given by Qwen. \nQwen Output: {response.message.content}")

    

    return qwen_move

# %%
def get_random_move(board:chess.Board, fen:str, seed: int = 101):
    legal_moves = [
        board.san(move)
        for move in board.legal_moves
    ]

    random.seed(seed)

    # print(random.choice(legal_moves))
    return random.choice(legal_moves)

    # print(legal_moves[0])

# %%
for game_number in range(1, NUM_GAMES + 1):
    
    move_counter = 0

    print(f"Starting game {game_number}...")

    board = chess.Board()

    while not board.is_game_over() and move_counter <= MOVE_LIMIT:
        if board.turn == chess.WHITE and not board.is_game_over():
            num = random.randint(1,100)
            
            if num <= QWEN_US_AI:
                stockfish.set_fen_position(board.fen())
                qwen_us_move = await get_move_with_timeout(stockfish)

                if qwen_us_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break
            
            else:
                qwen_us_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_us_move)
            except Exception as e:
                print(f"Invalid move by Qwen white. Move: {qwen_us_move}")
                qwen_us_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_us_move)
                print(f"New Move: {qwen_us_move}")
                # continue
            
            move_counter += 1        
            print(f"Qwen US move: {qwen_us_move} Move number: {move_counter}")

        elif board.turn == chess.BLACK and not board.is_game_over():
            num = random.randint(1, 100)

            if num <= QWEN_CN_AI:
                stockfish.set_fen_position(board.fen())
                qwen_cn_move = await get_move_with_timeout(stockfish)

                if qwen_cn_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break

            else:
                qwen_cn_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_cn_move)
            except Exception as e:
                print(f"Invalid move by Qwen black. Move: {qwen_cn_move}")
                qwen_cn_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_cn_move)
                print(f"New Move: {qwen_cn_move}")
                # continue
            move_counter += 1
            print(f"Qwen CN move: {qwen_cn_move} Move number: {move_counter}")   

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        qwen_us_wins += 1
    elif result == "0-1":
        qwen_cn_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n\n")
# Out:
# Starting game 1...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Ng5 Move number: 5
# Qwen CN move: d8g5 Move number: 6
# Qwen US move: b1c3 Move number: 7
# Qwen CN move: g5g6 Move number: 8
# Qwen US move: f2f4 Move number: 9
# Qwen CN move: d7d5 Move number: 10
# Qwen US move: f4f5 Move number: 11
# Qwen CN move: g6f6 Move number: 12
# Qwen US move: f1d3 Move number: 13
# Qwen CN move: d5e4 Move number: 14
# Qwen US move: d3c4 Move number: 15
# Qwen CN move: Bxf5 Move number: 16
# Qwen US move: e1g1 Move number: 17
# Qwen CN move: Nge7 Move number: 18
# Qwen US move: Bxf7+ Move number: 19
# Qwen CN move: f6f7 Move number: 20
# Qwen US move: Rf4 Move number: 21
# Qwen CN move: e5f4 Move number: 22
# Qwen US move: Nxe4 Move number: 23
# Qwen CN move: f5e4 Move number: 24
# Qwen US move: d2d3 Move number: 25
# Qwen CN move: e4d5 Move number: 26
# Qwen US move: c2c4 Move number: 27
# Invalid move by Qwen black. Move: Nxd5
# New Move: Qg6
# Qwen CN move: Qg6 Move number: 28
# Qwen US move: c4d5 Move number: 29
# Qwen CN move: Nf5 Move number: 30
# Qwen US move: c1f4 Move number: 31
# Qwen CN move: f8c5 Move number: 32
# Qwen US move: g1h1 Move number: 33
# Qwen CN move: e8g8 Move number: 34
# Qwen US move: Bxc7 Move number: 35
# Qwen CN move: f5e3 Move number: 36
# Qwen US move: Qe2 Move number: 37
# Qwen CN move: Qf5 Move number: 38
# Qwen US move: d5c6 Move number: 39
# Qwen CN move: b7c6 Move number: 40
# Qwen US move: Bd8 Move number: 41
# Qwen CN move: a8d8 Move number: 42
# Qwen US move: a1e1 Move number: 43
# Qwen CN move: f5g6 Move number: 44
# Qwen US move: h2h3 Move number: 45
# Qwen CN move: d8e8 Move number: 46
# Qwen US move: b2b4 Move number: 47
# Qwen CN move: c5d6 Move number: 48
# Qwen US move: Qf1 Move number: 49
# Qwen CN move: f8f1 Move number: 50
# Qwen US move: Rxf1 Move number: 51
# Qwen CN move: g6g2 Move number: 52
# Game 1 result: 0-1
#
#
# Starting game 2...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Qwen CN move: e5d4 Move number: 6
# Qwen US move: f3d4 Move number: 7
# Invalid move by Qwen black. Move: Nc3
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 8
# Qwen US move: b1a3 Move number: 9
# Qwen CN move: Nxe5 Move number: 10
# Qwen US move: a3c4 Move number: 11
# Qwen CN move: e5c4 Move number: 12
# Qwen US move: f1c4 Move number: 13
# Qwen CN move: d7d5 Move number: 14
# Qwen US move: Nf3 Move number: 15
# Qwen CN move: d5c4 Move number: 16
# Qwen US move: Nh4 Move number: 17
# Qwen CN move: Qd2+ Move number: 18
# Qwen US move: c1d2 Move number: 19
# Qwen CN move: g8f6 Move number: 20
# Invalid move by Qwen white. Move: Nh4
# New Move: Bb4
# Qwen US move: Bb4 Move number: 21
# Qwen CN move: c4c3 Move number: 22
# Qwen US move: Bxc3 Move number: 23
# Qwen CN move: f6e4 Move number: 24
# Qwen US move: d1e2 Move number: 25
# Qwen CN move: c8e6 Move number: 26
# Qwen US move: e2e4 Move number: 27
# Qwen CN move: Rg8 Move number: 28
# Qwen US move: e4b7 Move number: 29
# Qwen CN move: Rd8 Move number: 30
# Invalid move by Qwen white. Move: Qxe5
# New Move: a4
# Qwen US move: a4 Move number: 31
# Qwen CN move: d8d2 Move number: 32
# Qwen US move: b7c6 Move number: 33
# Qwen CN move: Ke7 Move number: 34
# Qwen US move: c3d2 Move number: 35
# Qwen CN move: g8b8 Move number: 36
# Qwen US move: c6c7 Move number: 37
# Qwen CN move: e6d7 Move number: 38
# Qwen US move: Qd8+ Move number: 39
# Qwen CN move: e7d8 Move number: 40
# Qwen US move: Bh6 Move number: 41
# Qwen CN move: Rxb2 Move number: 42
# Qwen US move: h6e3 Move number: 43
# Qwen CN move: d8c8 Move number: 44
# Qwen US move: Bh6 Move number: 45
# Qwen CN move: g7h6 Move number: 46
# Qwen US move: e1g1 Move number: 47
# Qwen CN move: a7a5 Move number: 48
# Qwen US move: h4f3 Move number: 49
# Qwen CN move: c8c7 Move number: 50
# Qwen US move: f3e5 Move number: 51
# Qwen CN move: d7e6 Move number: 52
# Qwen US move: Nxf7 Move number: 53
# Qwen CN move: e6f7 Move number: 54
# Qwen US move: Rfd1 Move number: 55
# Qwen CN move: b2c2 Move number: 56
# Qwen US move: Rd3 Move number: 57
# Qwen CN move: Rc1+ Move number: 58
# Qwen US move: Rd1 Move number: 59
# Qwen CN move: c1a1 Move number: 60
# Qwen US move: d1a1 Move number: 61
# Qwen CN move: c7d6 Move number: 62
# Qwen US move: f2f4 Move number: 63
# Invalid move by Qwen black. Move: Bh6
# New Move: Be6
# Qwen CN move: Be6 Move number: 64
# Qwen US move: a1b1 Move number: 65
# Invalid move by Qwen black. Move: Bh6
# New Move: Bd7
# Qwen CN move: Bd7 Move number: 66
# Qwen US move: b1d1 Move number: 67
# Qwen CN move: Kc5 Move number: 68
# Qwen US move: d1d7 Move number: 69
# Qwen CN move: c5b4 Move number: 70
# Qwen US move: f4f5 Move number: 71
# Qwen CN move: b4a4 Move number: 72
# Qwen US move: Rd2 Move number: 73
# Qwen CN move: h6h5 Move number: 74
# Qwen US move: Rd8 Move number: 75
# Invalid move by Qwen black. Move: Rd7
# New Move: h4
# Qwen CN move: h4 Move number: 76
# Qwen US move: f5f6 Move number: 77
# Qwen CN move: h7h5 Move number: 78
# Qwen US move: Rd4+ Move number: 79
# Qwen CN move: a4b5 Move number: 80
# Qwen US move: f6f7 Move number: 81
# Qwen CN move: h4h3 Move number: 82
# Qwen US move: f7f8q Move number: 83
# Invalid move by Qwen black. Move: f8=Q#
# New Move: a4
# Qwen CN move: a4 Move number: 84
# Qwen US move: f8b4 Move number: 85
# Qwen CN move: b5c6 Move number: 86
# Qwen US move: Qb5+ Move number: 87
# Qwen CN move: c6b5 Move number: 88
# Qwen US move: g2h3 Move number: 89
# Qwen CN move: b5a5 Move number: 90
# Qwen US move: g1f2 Move number: 91
# Qwen CN move: Kb5 Move number: 92
# Qwen US move: f2e3 Move number: 93
# Invalid move by Qwen black. Move: Qc5+
# New Move: h4
# Qwen CN move: h4 Move number: 94
# Qwen US move: e3d3 Move number: 95
# Qwen CN move: b5a5 Move number: 96
# Qwen US move: Rd8 Move number: 97
# Qwen CN move: a5b4 Move number: 98
# Qwen US move: d8c8 Move number: 99
# Qwen CN move: b4a5 Move number: 100
# Qwen US move: d3c4 Move number: 101
# Qwen CN move: Kb6 Move number: 102
# Qwen US move: c4b4 Move number: 103
# Qwen CN move: Kb7 Move number: 104
# Qwen US move: Rc7+ Move number: 105
# Qwen CN move: b7c7 Move number: 106
# Qwen US move: b4a4 Move number: 107
# Qwen CN move: Kd6 Move number: 108
# Qwen US move: a4b4 Move number: 109
# Qwen CN move: d6d5 Move number: 110
# Qwen US move: b4c3 Move number: 111
# Qwen CN move: d5e4 Move number: 112
# Qwen US move: c3c4 Move number: 113
# Qwen CN move: e4f3 Move number: 114
# Qwen US move: c4d4 Move number: 115
# Qwen CN move: Kf4 Move number: 116
# Qwen US move: d4d5 Move number: 117
# Qwen CN move: Kf5 Move number: 118
# Qwen US move: d5d6 Move number: 119
# Qwen CN move: Kf4 Move number: 120
# Qwen US move: Kd5 Move number: 121
# Qwen CN move: Kf3 Move number: 122
# Qwen US move: d5e6 Move number: 123
# Qwen CN move: f3g2 Move number: 124
# Qwen US move: e6f5 Move number: 125
# Qwen CN move: g2h3 Move number: 126
# Qwen US move: Kg6 Move number: 127
# Qwen CN move: h3h2 Move number: 128
# Qwen US move: g6f5 Move number: 129
# Invalid move by Qwen black. Move: Kg6
# New Move: h3
# Qwen CN move: h3 Move number: 130
# Qwen US move: f5f4 Move number: 131
# Qwen CN move: h2g2 Move number: 132
# Qwen US move: Kg5 Move number: 133
# Qwen CN move: g2g3 Move number: 134
# Qwen US move: g5f5 Move number: 135
# Qwen CN move: g3f3 Move number: 136
# Qwen US move: f5f6 Move number: 137
# Qwen CN move: Kg4 Move number: 138
# Qwen US move: f6f7 Move number: 139
# Qwen CN move: Kg5 Move number: 140
# Qwen US move: Kg8 Move number: 141
# Qwen CN move: g5f4 Move number: 142
# Qwen US move: g8f8 Move number: 143
# Qwen CN move: Kg5 Move number: 144
# Qwen US move: f8e7 Move number: 145
# Qwen CN move: h3h2 Move number: 146
# Qwen US move: e7d6 Move number: 147
# Qwen CN move: g5g4 Move number: 148
# Qwen US move: d6c7 Move number: 149
# Qwen CN move: g4f3 Move number: 150
# Qwen US move: c7d8 Move number: 151
# Invalid move by Qwen black. Move: Kf7
# New Move: h1=B
# Qwen CN move: h1=B Move number: 152
# Game 2 result: 1/2-1/2
#
#
# Starting game 3...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen US move: b5a4 Move number: 7
# Qwen CN move: Nge7 Move number: 8
# Qwen US move: c2c3 Move number: 9
# Qwen CN move: Na5 Move number: 10
# Qwen US move: Bxd7+ Move number: 11
# Qwen CN move: d8d7 Move number: 12
# Qwen US move: f3e5 Move number: 13
# Invalid move by Qwen black. Move: Nxe5
# New Move: Nf5
# Qwen CN move: Nf5 Move number: 14
# Qwen US move: e5d7 Move number: 15
# Qwen CN move: Nc4 Move number: 16
# Qwen US move: e4f5 Move number: 17
# Qwen CN move: c8d7 Move number: 18
# Qwen US move: d1e2 Move number: 19
# Qwen CN move: f8e7 Move number: 20
# Qwen US move: Qxe7+ Move number: 21
# Qwen CN move: e8e7 Move number: 22
# Qwen US move: Rg1 Move number: 23
# Qwen CN move: Rhg8 Move number: 24
# Qwen US move: b2b3 Move number: 25
# Qwen CN move: c4d6 Move number: 26
# Qwen US move: Rh1 Move number: 27
# Qwen CN move: d7f5 Move number: 28
# Qwen US move: e1e2 Move number: 29
# Qwen CN move: g8e8 Move number: 30
# Qwen US move: d2d3 Move number: 31
# Qwen CN move: a8d8 Move number: 32
# Qwen US move: c1e3 Move number: 33
# Qwen CN move: e7f8 Move number: 34
# Qwen US move: Ke1 Move number: 35
# Qwen CN move: f5d3 Move number: 36
# Qwen US move: Rg1 Move number: 37
# Qwen CN move: d6f5 Move number: 38
# Qwen US move: Nd2 Move number: 39
# Qwen CN move: Re4 Move number: 40
# Qwen US move: Nc4 Move number: 41
# Qwen CN move: d3c4 Move number: 42
# Qwen US move: b3c4 Move number: 43
# Qwen CN move: f5e3 Move number: 44
# Qwen US move: f2e3 Move number: 45
# Qwen CN move: Rde8 Move number: 46
# Qwen US move: e1d2 Move number: 47
# Qwen CN move: e4e3 Move number: 48
# Qwen US move: Kc2 Move number: 49
# Qwen CN move: e3e2 Move number: 50
# Qwen US move: Kd3 Move number: 51
# Qwen CN move: c7c5 Move number: 52
# Qwen US move: a1b1 Move number: 53
# Qwen CN move: e8e3 Move number: 54
# Game 3 result: 0-1
#
#
# Starting game 4...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: e5 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: g1f3 Move number: 5
# Qwen CN move: d8c7 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: c5d4 Move number: 8
# Qwen US move: c1f4 Move number: 9
# Qwen CN move: g8f6 Move number: 10
# Qwen US move: Bh6 Move number: 11
# Qwen CN move: c6e5 Move number: 12
# Qwen US move: h6d2 Move number: 13
# Qwen CN move: Ng8 Move number: 14
# Qwen US move: f3d4 Move number: 15
# Qwen CN move: e7e6 Move number: 16
# Qwen US move: b1c3 Move number: 17
# Qwen CN move: a7a6 Move number: 18
# Qwen US move: f2f4 Move number: 19
# Qwen CN move: Nf3+ Move number: 20
# Qwen US move: d1f3 Move number: 21
# Qwen CN move: Be7 Move number: 22
# Qwen US move: Nxe6 Move number: 23
# Qwen CN move: d7e6 Move number: 24
# Qwen US move: Qxb7 Move number: 25
# Qwen CN move: c8b7 Move number: 26
# Qwen US move: Rg1 Move number: 27
# Qwen CN move: h7h5 Move number: 28
# Qwen US move: e1c1 Move number: 29
# Qwen CN move: Rh7 Move number: 30
# Qwen US move: g2g4 Move number: 31
# Qwen CN move: Rh6 Move number: 32
# Qwen US move: g4h5 Move number: 33
# Qwen CN move: e7f8 Move number: 34
# Qwen US move: f4f5 Move number: 35
# Qwen CN move: a8d8 Move number: 36
# Qwen US move: f1h3 Move number: 37
# Qwen CN move: b7c8 Move number: 38
# Qwen US move: g1e1 Move number: 39
# Qwen CN move: Ne7 Move number: 40
# Qwen US move: f5e6 Move number: 41
# Qwen CN move: c8e6 Move number: 42
# Qwen US move: h3f1 Move number: 43
# Qwen CN move: e7c6 Move number: 44
# Qwen US move: f1a6 Move number: 45
# Qwen CN move: Rd2 Move number: 46
# Qwen US move: d1d2 Move number: 47
# Invalid move by Qwen black. Move: Bxa8
# New Move: Qc8
# Qwen CN move: Qc8 Move number: 48
# Qwen US move: a6c8 Move number: 49
# Qwen CN move: Rg6 Move number: 50
# Qwen US move: h5g6 Move number: 51
# Qwen CN move: f8e7 Move number: 52
# Qwen US move: c8e6 Move number: 53
# Qwen CN move: f7e6 Move number: 54
# Qwen US move: Nd5 Move number: 55
# Qwen CN move: e6d5 Move number: 56
# Qwen US move: Rxd5 Move number: 57
# Qwen CN move: Nd4 Move number: 58
# Qwen US move: d5d4 Move number: 59
# Qwen CN move: e8f8 Move number: 60
# Qwen US move: Rd8+ Move number: 61
# Qwen CN move: e7d8 Move number: 62
# Qwen US move: c1b1 Move number: 63
# Qwen CN move: d8e7 Move number: 64
# Qwen US move: c2c3 Move number: 65
# Qwen CN move: f8e8 Move number: 66
# Qwen US move: e1d1 Move number: 67
# Qwen CN move: e7g5 Move number: 68
# Qwen US move: Rd8+ Move number: 69
# Qwen CN move: g5d8 Move number: 70
# Qwen US move: Kc2 Move number: 71
# Qwen CN move: d8c7 Move number: 72
# Invalid move by Qwen white. Move:  Kb3
# New Move: h4
# Qwen US move: h4 Move number: 73
# Qwen CN move: e8e7 Move number: 74
# Qwen US move: a2a4 Move number: 75
# Invalid move by Qwen black. Move: Bf1
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 76
# Qwen US move: h4h5 Move number: 77
# Qwen CN move: Kd8 Move number: 78
# Qwen US move: h5h6 Move number: 79
# Qwen CN move: g7h6 Move number: 80
# Qwen US move: g6g7 Move number: 81
# Qwen CN move: c7b6 Move number: 82
# Qwen US move: g8=Q+ Move number: 83
# Qwen CN move: d8c7 Move number: 84
# Qwen US move: Qg6 Move number: 85
# Qwen CN move: Bd4 Move number: 86
# Qwen US move: c3d4 Move number: 87
# Qwen CN move: h6h5 Move number: 88
# Qwen US move: Qg8 Move number: 89
# Qwen CN move: h5h4 Move number: 90
# Qwen US move: c2c3 Move number: 91
# Qwen CN move: h4h3 Move number: 92
# Qwen US move: c3c4 Move number: 93
# Qwen CN move: c7d6 Move number: 94
# Qwen US move: g8h7 Move number: 95
# Qwen CN move: d6e6 Move number: 96
# Qwen US move: Qg8+ Move number: 97
# Qwen CN move: e6d7 Move number: 98
# Qwen US move: Qg1 Move number: 99
# Qwen CN move: d7c6 Move number: 100
# Qwen US move: Qg8+ Move number: 101
# Qwen CN move: Kd6 Move number: 102
# Qwen US move: Qg1 Move number: 103
# Qwen CN move: d6c6 Move number: 104
# Qwen US move: g1h1 Move number: 105
# Qwen CN move: c6c7 Move number: 106
# Qwen US move: h1h3 Move number: 107
# Qwen CN move: Kb6 Move number: 108
# Qwen US move: h3d7 Move number: 109
# Qwen CN move: b6a6 Move number: 110
# Invalid move by Qwen white. Move: Qg8+
# New Move: Kb4
# Qwen US move: Kb4 Move number: 111
# Qwen CN move: a6b6 Move number: 112
# Qwen US move: a4a5 Move number: 113
# Invalid move by Qwen black. Move:  Kb7
# New Move: Ka6
# Qwen CN move: Ka6 Move number: 114
# Qwen US move: b4c5 Move number: 115
# Qwen CN move: Kxa5 Move number: 116
# Qwen US move: d7b5 Move number: 117
# Game 4 result: 1-0
#
#
# Starting game 5...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: Be7 Move number: 6
# Qwen US move: Bxc6 Move number: 7
# Qwen CN move: d7c6 Move number: 8
# Qwen US move: e1g1 Move number: 9
# Qwen CN move: Nh6 Move number: 10
# Qwen US move: d2d3 Move number: 11
# Qwen CN move: d8d6 Move number: 12
# Qwen US move: c1h6 Move number: 13
# Qwen CN move: d6h6 Move number: 14
# Qwen US move: f3e5 Move number: 15
# Qwen CN move: e7d6 Move number: 16
# Qwen US move: d3d4 Move number: 17
# Invalid move by Qwen black. Move: Nc3
# New Move: Bf5
# Qwen CN move: Bf5 Move number: 18
# Qwen US move: e4f5 Move number: 19
# Invalid move by Qwen black. Move: Nc3
# New Move: Rb8
# Qwen CN move: Rb8 Move number: 20
# Qwen US move: e5f3 Move number: 21
# Invalid move by Qwen black. Move: Re1
# New Move: Rc8
# Qwen CN move: Rc8 Move number: 22
# Qwen US move: f1e1 Move number: 23
# Invalid move by Qwen black. Move: Nh7
# New Move: Be7
# Qwen CN move: Be7 Move number: 24
# Qwen US move: d1e2 Move number: 25
# Qwen CN move: h6d6 Move number: 26
# Qwen US move: Nh4 Move number: 27
# Qwen CN move: e8d7 Move number: 28
# Qwen US move: h4f3 Move number: 29
# Qwen CN move: c8e8 Move number: 30
# Qwen US move: f3e5 Move number: 31
# Qwen CN move: Kd8 Move number: 32
# Qwen US move: e5f7 Move number: 33
# Qwen CN move: Kd7 Move number: 34
# Qwen US move: Qe5 Move number: 35
# Qwen CN move: d6e5 Move number: 36
# Qwen US move: f7e5 Move number: 37
# Invalid move by Qwen black. Move: Nxd6
# New Move: Kd6
# Qwen CN move: Kd6 Move number: 38
# Qwen US move: b1d2 Move number: 39
# Qwen CN move: e7f6 Move number: 40
# Qwen US move: Nf7+ Move number: 41
# Qwen CN move: d6d7 Move number: 42
# Qwen US move: f7h8 Move number: 43
# Qwen CN move: e8h8 Move number: 44
# Qwen US move: d2e4 Move number: 45
# Qwen CN move: Bxd4 Move number: 46
# Qwen US move: a1d1 Move number: 47
# Invalid move by Qwen black. Move: Re1
# New Move: Rd8
# Qwen CN move: Rd8 Move number: 48
# Qwen US move: d1d4 Move number: 49
# Invalid move by Qwen black. Move: Rd1
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 50
# Qwen US move: e4c5 Move number: 51
# Qwen CN move: e7f6 Move number: 52
# Qwen US move: Rxd8 Move number: 53
# Qwen CN move: b7b5 Move number: 54
# Qwen US move: d8f8 Move number: 55
# Qwen CN move: f6g5 Move number: 56
# Qwen US move: f8f7 Move number: 57
# Qwen CN move: Kh4 Move number: 58
# Qwen US move: f7g7 Move number: 59
# Qwen CN move: a6 Move number: 60
# Qwen US move: Rg8 Move number: 61
# Qwen CN move: b5b4 Move number: 62
# Qwen US move: e1e3 Move number: 63
# Invalid move by Qwen black. Move: Re1
# New Move: Kh5
# Qwen CN move: Kh5 Move number: 64
# Qwen US move: e3h3 Move number: 65
# Game 5 result: 1-0
#
#
# Starting game 6...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: f3e5 Move number: 5
# Invalid move by Qwen black. Move: Nxd6
# New Move: a6
# Qwen CN move: a6 Move number: 6
# Qwen US move: f1c4 Move number: 7
# Qwen CN move: d7d5 Move number: 8
# Qwen US move: Nxf7 Move number: 9
# Qwen CN move: e8f7 Move number: 10
# Qwen US move: c4b3 Move number: 11
# Qwen CN move: f7e8 Move number: 12
# Qwen US move: e4e5 Move number: 13
# Qwen CN move: Bc5 Move number: 14
# Qwen US move: d2d4 Move number: 15
# Qwen CN move: Bxd4 Move number: 16
# Qwen US move: Bxd5 Move number: 17
# Qwen CN move: d4e5 Move number: 18
# Qwen US move: d1e2 Move number: 19
# Qwen CN move: Nfd7 Move number: 20
# Qwen US move: f2f4 Move number: 21
# Qwen CN move: d8h4 Move number: 22
# Qwen US move: g2g3 Move number: 23
# Qwen CN move: h4e7 Move number: 24
# Qwen US move: f4e5 Move number: 25
# Qwen CN move: d7e5 Move number: 26
# Qwen US move: c1f4 Move number: 27
# Qwen CN move: Bg4 Move number: 28
# Qwen US move: e2e5 Move number: 29
# Invalid move by Qwen black. Move: Qe4
# New Move: g6
# Qwen CN move: g6 Move number: 30
# Qwen US move: e5e7 Move number: 31
# Qwen CN move: e8e7 Move number: 32
# Qwen US move: Bg5+ Move number: 33
# Qwen CN move: e7d7 Move number: 34
# Qwen US move: e1g1 Move number: 35
# Qwen CN move: b8c6 Move number: 36
# Qwen US move: f1f7 Move number: 37
# Invalid move by Qwen black. Move: Rf8
# New Move: Ke8
# Qwen CN move: Ke8 Move number: 38
# Qwen US move: b1c3 Move number: 39
# Qwen CN move: Rg8 Move number: 40
# Qwen US move: a1e1 Move number: 41
# Qwen CN move: g4e6 Move number: 42
# Qwen US move: d5e6 Move number: 43
# Qwen CN move: h7h6 Move number: 44
# Qwen US move: Rf8+ Move number: 45
# Qwen CN move: g8f8 Move number: 46
# Qwen US move: Bg4+ Move number: 47
# Invalid move by Qwen black. Move: Bf1
# New Move: Ne5
# Qwen CN move: Ne5 Move number: 48
# Qwen US move: e1e5 Move number: 49
# Qwen CN move: e8f7 Move number: 50
# Qwen US move: Bd2 Move number: 51
# Qwen CN move: g6g5 Move number: 52
# Qwen US move: c3e4 Move number: 53
# Qwen CN move: a6a5 Move number: 54
# Qwen US move: d2a5 Move number: 55
# Qwen CN move: Rfd8 Move number: 56
# Qwen US move: g1g2 Move number: 57
# Qwen CN move: Rd1 Move number: 58
# Qwen US move: Rf5+ Move number: 59
# Qwen CN move: f7g6 Move number: 60
# Qwen US move: f5f6 Move number: 61
# Invalid move by Qwen black. Move: Rf5+ Kxf5
# New Move: Kh7
# Qwen CN move: Kh7 Move number: 62
# Qwen US move: g4d1 Move number: 63
# Qwen CN move: Rxa5 Move number: 64
# Qwen US move: d1h5 Move number: 65
# Qwen CN move: a5a6 Move number: 66
# Qwen US move: f6f7 Move number: 67
# Qwen CN move: h7h8 Move number: 68
# Qwen US move: Rf8+ Move number: 69
# Qwen CN move: h8g7 Move number: 70
# Qwen US move: Rf5 Move number: 71
# Invalid move by Qwen black. Move: Rf7+
# New Move: Ra8
# Qwen CN move: Ra8 Move number: 72
# Qwen US move: f5f7 Move number: 73
# Invalid move by Qwen black. Move: Rf8+
# New Move: Kh8
# Qwen CN move: Kh8 Move number: 74
# Qwen US move: e4f6 Move number: 75
# Invalid move by Qwen black. Move: Nxf7
# New Move: Rd8
# Qwen CN move: Rd8 Move number: 76
# Qwen US move: f7h7 Move number: 77
# Game 6 result: 1-0
#
#
# Starting game 7...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Invalid move by Qwen black. Move: Nc3
# New Move: g5
# Qwen CN move: g5 Move number: 6
# Qwen US move: f3g5 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: Nxf7 Move number: 9
# Qwen CN move: e8f7 Move number: 10
# Qwen US move: e1g1 Move number: 11
# Qwen CN move: h8g8 Move number: 12
# Qwen US move: d2d3 Move number: 13
# Qwen CN move: Nxe4 Move number: 14
# Qwen US move: d3e4 Move number: 15
# Qwen CN move: Rg5 Move number: 16
# Qwen US move: Bxc6 Move number: 17
# Qwen CN move: g5g6 Move number: 18
# Qwen US move: c6b5 Move number: 19
# Qwen CN move: Bg7 Move number: 20
# Qwen US move: a2a4 Move number: 21
# Qwen CN move: b7b6 Move number: 22
# Qwen US move: a1a3 Move number: 23
# Qwen CN move: c8b7 Move number: 24
# Qwen US move: a3g3 Move number: 25
# Qwen CN move: d8c7 Move number: 26
# Qwen US move: b1c3 Move number: 27
# Qwen CN move: Bd5 Move number: 28
# Qwen US move: c3d5 Move number: 29
# Qwen CN move: Re8 Move number: 30
# Qwen US move: d5c7 Move number: 31
# Qwen CN move: Rf6 Move number: 32
# Qwen US move: Nxe8 Move number: 33
# Qwen CN move: Rf5 Move number: 34
# Qwen US move: e4f5 Move number: 35
# Qwen CN move: f7f8 Move number: 36
# Qwen US move: e8g7 Move number: 37
# Qwen CN move: f8f7 Move number: 38
# Qwen US move: Nh5 Move number: 39
# Qwen CN move: a7a6 Move number: 40
# Qwen US move: d1d5 Move number: 41
# Qwen CN move: Ke8 Move number: 42
# Qwen US move: g3g8 Move number: 43
# Game 7 result: 1-0
#
#
# Starting game 8...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen US move: Bxc6 Move number: 7
# Qwen CN move: d7c6 Move number: 8
# Qwen US move: e1g1 Move number: 9
# Qwen CN move: d8f6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: e5d4 Move number: 12
# Qwen US move: c1g5 Move number: 13
# Qwen CN move: f6d6 Move number: 14
# Qwen US move: Nh4 Move number: 15
# Qwen CN move: h7h6 Move number: 16
# Qwen US move: g5c1 Move number: 17
# Qwen CN move: Nf6 Move number: 18
# Qwen US move: e4e5 Move number: 19
# Qwen CN move: d6e6 Move number: 20
# Qwen US move: e5f6 Move number: 21
# Qwen CN move: e6f6 Move number: 22
# Qwen US move: h4f3 Move number: 23
# Qwen CN move: Bd6 Move number: 24
# Qwen US move: d1d4 Move number: 25
# Invalid move by Qwen black. Move: Qe2
# New Move: g5
# Qwen CN move: g5 Move number: 26
# Qwen US move: d4f6 Move number: 27
# Qwen CN move: h8f8 Move number: 28
# Qwen US move: Qh8 Move number: 29
# Qwen CN move: f8h8 Move number: 30
# Qwen US move: f1e1 Move number: 31
# Qwen CN move: e8f8 Move number: 32
# Qwen US move: c1d2 Move number: 33
# Qwen CN move: Bg3 Move number: 34
# Qwen US move: d2c3 Move number: 35
# Qwen CN move: Bg4 Move number: 36
# Qwen US move: Nxg5 Move number: 37
# Qwen CN move: h6g5 Move number: 38
# Qwen US move: c3h8 Move number: 39
# Qwen CN move: Bf5 Move number: 40
# Qwen US move: h2g3 Move number: 41
# Qwen CN move: f5c2 Move number: 42
# Qwen US move: b1a3 Move number: 43
# Qwen CN move: c2d3 Move number: 44
# Qwen US move: a1d1 Move number: 45
# Qwen CN move: f8g8 Move number: 46
# Qwen US move: h8c3 Move number: 47
# Invalid move by Qwen black. Move: Bd4
# New Move: c5
# Qwen CN move: c5 Move number: 48
# Qwen US move: d1d3 Move number: 49
# Qwen CN move: b7b5 Move number: 50
# Qwen US move: Rd8+ Move number: 51
# Qwen CN move: a8d8 Move number: 52
# Qwen US move: a3c2 Move number: 53
# Qwen CN move: b5b4 Move number: 54
# Qwen US move: c3e5 Move number: 55
# Invalid move by Qwen black. Move: Re1
# New Move: f5
# Qwen CN move: f5 Move number: 56
# Qwen US move: c2e3 Move number: 57
# Qwen CN move: a6a5 Move number: 58
# Invalid move by Qwen white. Move: Nh4
# New Move: Rd1
# Qwen US move: Rd1 Move number: 59
# Qwen CN move: d8d1 Move number: 60
# Qwen US move: e3d1 Move number: 61
# Qwen CN move: Kh7 Move number: 62
# Qwen US move: e5c7 Move number: 63
# Qwen CN move: h7g6 Move number: 64
# Qwen US move: c7a5 Move number: 65
# Qwen CN move: g6f7 Move number: 66
# Qwen US move: Bd8 Move number: 67
# Qwen CN move: g5g4 Move number: 68
# Qwen US move: Be7 Move number: 69
# Qwen CN move: f4 Move number: 70
# Qwen US move: e7c5 Move number: 71
# Qwen CN move: b4b3 Move number: 72
# Invalid move by Qwen white. Move: Bxc2
# New Move: Bd6
# Qwen US move: Bd6 Move number: 73
# Qwen CN move: b3a2 Move number: 74
# Qwen US move: Bxc5 Move number: 75
# Qwen CN move: a2a1q Move number: 76
# Qwen US move: g1h2 Move number: 77
# Qwen CN move: f4g3 Move number: 78
# Qwen US move: h2g3 Move number: 79
# Qwen CN move: Qa3+ Move number: 80
# Qwen US move: c5a3 Move number: 81
# Invalid move by Qwen black. Move: Bf5
# New Move: Ke6
# Qwen CN move: Ke6 Move number: 82
# Qwen US move: g3g4 Move number: 83
# Qwen CN move: e6d5 Move number: 84
# Invalid move by Qwen white. Move: Nh4
# New Move: Kh4
# Qwen US move: Kh4 Move number: 85
# Qwen CN move: d5c4 Move number: 86
# Qwen US move: g3 Move number: 87
# Qwen CN move: c4d4 Move number: 88
# Qwen US move: b2b4 Move number: 89
# Qwen CN move: d4d3 Move number: 90
# Qwen US move: b4b5 Move number: 91
# Invalid move by Qwen black. Move: Bf7
# New Move: Kc2
# Qwen CN move: Kc2 Move number: 92
# Qwen US move: b5b6 Move number: 93
# Qwen CN move: c2d1 Move number: 94
# Qwen US move: Bf8 Move number: 95
# Qwen CN move: d1e2 Move number: 96
# Qwen US move: f2f4 Move number: 97
# Qwen CN move: e2e3 Move number: 98
# Qwen US move: b6b7 Move number: 99
# Invalid move by Qwen black. Move: Bf8
# New Move: Ke2
# Qwen CN move: Ke2 Move number: 100
# Qwen US move: h4g5 Move number: 101
# Qwen CN move: e2f3 Move number: 102
# Qwen US move: Bxd6 Move number: 103
# Qwen CN move: f3g3 Move number: 104
# Qwen US move: f4f5 Move number: 105
# Qwen CN move: g3f3 Move number: 106
# Qwen US move: b7b8q Move number: 107
# Qwen CN move: Kf2 Move number: 108
# Qwen US move: b8b2 Move number: 109
# Qwen CN move: Kf3 Move number: 110
# Invalid move by Qwen white. Move: Bd6
# New Move: Bb4
# Qwen US move: Bb4 Move number: 111
# Qwen CN move: f3g3 Move number: 112
# Qwen US move: Bd6+ Move number: 113
# Qwen CN move: g3f3 Move number: 114
# Qwen US move: f5f6 Move number: 115
# Qwen CN move: f3e3 Move number: 116
# Qwen US move: d6c5 Move number: 117
# Invalid move by Qwen black. Move: Bd6+
# New Move: Kd3
# Qwen CN move: Kd3 Move number: 118
# Qwen US move: f6f7 Move number: 119
# Qwen CN move: d3c4 Move number: 120
# Qwen US move: Qb5+ Move number: 121
# Qwen CN move: c4b5 Move number: 122
# Qwen US move: f7f8q Move number: 123
# Qwen CN move: b5c4 Move number: 124
# Qwen US move: f8f5 Move number: 125
# Invalid move by Qwen black. Move: Bd6+
# New Move: Kb3
# Qwen CN move: Kb3 Move number: 126
# Qwen US move: f5d3 Move number: 127
# Qwen CN move: b3a4 Move number: 128
# Qwen US move: Qf5 Move number: 129
# Qwen CN move: a4b5 Move number: 130
# Qwen US move: f5d5 Move number: 131
# Qwen CN move: b5a6 Move number: 132
# Qwen US move: d5c6 Move number: 133
# Invalid move by Qwen black. Move: Kb5
# New Move: Ka5
# Qwen CN move: Ka5 Move number: 134
# Qwen US move: c6b6 Move number: 135
# Invalid move by Qwen black. Move: Bd6
# New Move: Ka4
# Qwen CN move: Ka4 Move number: 136
# Qwen US move: b6b4 Move number: 137
# Game 8 result: 1-0
#
#
# Starting game 9...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: e7e6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Invalid move by Qwen black. Move: dxe6
# New Move: b6
# Qwen CN move: b6 Move number: 6
# Qwen US move: d4d5 Move number: 7
# Qwen CN move: a7a6 Move number: 8
# Qwen US move: Nfd2 Move number: 9
# Qwen CN move: d7d6 Move number: 10
# Qwen US move: a2a4 Move number: 11
# Qwen CN move: g8f6 Move number: 12
# Qwen US move: f1e2 Move number: 13
# Qwen CN move: Nbd7 Move number: 14
# Qwen US move: d5e6 Move number: 15
# Qwen CN move: Nxe4 Move number: 16
# Qwen US move: Nxe4 Move number: 17
# Qwen CN move: d7e5 Move number: 18
# Qwen US move: e6f7 Move number: 19
# Qwen CN move: Nxf7 Move number: 20
# Qwen US move: b1c3 Move number: 21
# Qwen CN move: c8b7 Move number: 22
# Qwen US move: c3d5 Move number: 23
# Qwen CN move: d8h4 Move number: 24
# Qwen US move: c1f4 Move number: 25
# Qwen CN move: f8e7 Move number: 26
# Qwen US move: e4g3 Move number: 27
# Qwen CN move: Nh6 Move number: 28
# Qwen US move: f4h6 Move number: 29
# Qwen CN move: Rg8 Move number: 30
# Qwen US move: d5e7 Move number: 31
# Qwen CN move: Rd8 Move number: 32
# Qwen US move: Nexg8 Move number: 33
# Qwen CN move: Bd5 Move number: 34
# Qwen US move: d1d5 Move number: 35
# Qwen CN move: g7h6 Move number: 36
# Qwen US move: e2h5 Move number: 37
# Qwen CN move: h4h5 Move number: 38
# Qwen US move: Qxd6 Move number: 39
# Qwen CN move: d8d6 Move number: 40
# Qwen US move: g3h5 Move number: 41
# Qwen CN move: Rd2 Move number: 42
# Qwen US move: g8f6 Move number: 43
# Qwen CN move: Kf8 Move number: 44
# Qwen US move: e1d2 Move number: 45
# Qwen CN move: f8e7 Move number: 46
# Qwen US move: a1e1 Move number: 47
# Qwen CN move: e7f7 Move number: 48
# Qwen US move: f6d5 Move number: 49
# Invalid move by Qwen black. Move: Nd7
# New Move: c4
# Qwen CN move: c4 Move number: 50
# Qwen US move: e1e7 Move number: 51
# Qwen CN move: f7f8 Move number: 52
# Qwen US move: Re8+ Move number: 53
# Qwen CN move: f8e8 Move number: 54
# Qwen US move: h1e1 Move number: 55
# Qwen CN move: e8d8 Move number: 56
# Qwen US move: h5f6 Move number: 57
# Invalid move by Qwen black. Move: Nh5
# New Move: Kc8
# Qwen CN move: Kc8 Move number: 58
# Qwen US move: e1e7 Move number: 59
# Qwen CN move: c3+ Move number: 60
# Qwen US move: d2c3 Move number: 61
# Qwen CN move: b6b5 Move number: 62
# Qwen US move: a4b5 Move number: 63
# Qwen CN move: a6b5 Move number: 64
# Qwen US move: Re8+ Move number: 65
# Qwen CN move: c8b7 Move number: 66
# Qwen US move: Re1 Move number: 67
# Invalid move by Qwen black. Move: Nf6+
# New Move: Kb8
# Qwen CN move: Kb8 Move number: 68
# Qwen US move: c3d4 Move number: 69
# Invalid move by Qwen black. Move: Nh5
# New Move: b4
# Qwen CN move: b4 Move number: 70
# Qwen US move: f6d7 Move number: 71
# Qwen CN move: b8c8 Move number: 72
# Qwen US move: Nf4 Move number: 73
# Qwen CN move: c8d7 Move number: 74
# Qwen US move: d4d5 Move number: 75
# Qwen CN move: h6h5 Move number: 76
# Qwen US move: f4h5 Move number: 77
# Invalid move by Qwen black. Move: Nh7
# New Move: Kd8
# Qwen CN move: Kd8 Move number: 78
# Qwen US move: h5f6 Move number: 79
# Invalid move by Qwen black. Move: Nh5
# New Move: Kc8
# Qwen CN move: Kc8 Move number: 80
# Qwen US move: d5c6 Move number: 81
# Invalid move by Qwen black. Move: Nf4
# New Move: Kd8
# Qwen CN move: Kd8 Move number: 82
# Qwen US move: e1e8 Move number: 83
# Game 9 result: 1-0
#
#
# Starting game 10...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: Be7 Move number: 6
# Qwen US move: e1g1 Move number: 7
# Qwen CN move: Nh6 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Qwen CN move: d7c6 Move number: 10
# Qwen US move: d2d3 Move number: 11
# Qwen CN move: Bg5 Move number: 12
# Qwen US move: c1g5 Move number: 13
# Qwen CN move: d8d6 Move number: 14
# Qwen US move: g5h6 Move number: 15
# Qwen CN move: g7h6 Move number: 16
# Qwen US move: g1h1 Move number: 17
# Qwen CN move: h8g8 Move number: 18
# Qwen US move: f1g1 Move number: 19
# Qwen CN move: Rg3 Move number: 20
# Qwen US move: f2g3 Move number: 21
# Qwen CN move: Qxd3 Move number: 22
# Qwen US move: d1d3 Move number: 23
# Qwen CN move: Ke7 Move number: 24
# Qwen US move: Ng5 Move number: 25
# Qwen CN move: Bd7 Move number: 26
# Qwen US move: d3a3 Move number: 27
# Qwen CN move: e7f6 Move number: 28
# Qwen US move: a3f3 Move number: 29
# Qwen CN move: f6g5 Move number: 30
# Qwen US move: Qxf7 Move number: 31
# Qwen CN move: a8f8 Move number: 32
# Qwen US move: h2h4 Move number: 33
# Qwen CN move: Kg4 Move number: 34
# Qwen US move: f7d7 Move number: 35
# Qwen CN move: Kh5 Move number: 36
# Qwen US move: g3g4 Move number: 37
# Qwen CN move: h5g6 Move number: 38
# Qwen US move: h4h5 Move number: 39
# Qwen CN move: g6g5 Move number: 40
# Qwen US move: d7g7 Move number: 41
# Qwen CN move: Kh4 Move number: 42
# Qwen US move: g2g3 Move number: 43
# Qwen CN move: h4h3 Move number: 44
# Qwen US move: g7f8 Move number: 45
# Qwen CN move: b7b5 Move number: 46
# Qwen US move: f8f1 Move number: 47
# Qwen CN move: h3g4 Move number: 48
# Qwen US move: f1f5 Move number: 49
# Game 10 result: 1-0
#
#
# Starting game 11...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Qwen CN move: c5d4 Move number: 6
# Qwen US move: f3d4 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: b1c3 Move number: 9
# Invalid move by Qwen black. Move: Nxc6
# New Move: a6
# Qwen CN move: a6 Move number: 10
# Qwen US move: c1f4 Move number: 11
# Qwen CN move: d8b6 Move number: 12
# Qwen US move: Bd3 Move number: 13
# Qwen CN move: b6d4 Move number: 14
# Qwen US move: f4e3 Move number: 15
# Qwen CN move: d4b4 Move number: 16
# Qwen US move: a2a3 Move number: 17
# Qwen CN move: Na5 Move number: 18
# Qwen US move: a3b4 Move number: 19
# Qwen CN move: Nxe4 Move number: 20
# Qwen US move: Bd2 Move number: 21
# Qwen CN move: e4d2 Move number: 22
# Qwen US move: b4a5 Move number: 23
# Qwen CN move: Nf1 Move number: 24
# Qwen US move: d3f1 Move number: 25
# Qwen CN move: e7e6 Move number: 26
# Qwen US move: f1d3 Move number: 27
# Qwen CN move: b7b5 Move number: 28
# Qwen US move: d1f3 Move number: 29
# Qwen CN move: a8a7 Move number: 30
# Qwen US move: f3g3 Move number: 31
# Qwen CN move: Rg8 Move number: 32
# Qwen US move: g3b8 Move number: 33
# Qwen CN move: Rh8 Move number: 34
# Qwen US move: b8c8 Move number: 35
# Invalid move by Qwen black. Move: Kf8
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 36
# Qwen US move: c8c5 Move number: 37
# Qwen CN move: Kf6 Move number: 38
# Qwen US move: c3e4 Move number: 39
# Qwen CN move: f6g6 Move number: 40
# Qwen US move: c5g5 Move number: 41
# Game 11 result: 1-0
#
#
# Starting game 12...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Ng5 Move number: 5
# Qwen CN move: d8g5 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: Nxd4 Move number: 8
# Qwen US move: c1g5 Move number: 9
# Qwen CN move: g8f6 Move number: 10
# Qwen US move: f1d3 Move number: 11
# Qwen CN move: b7b6 Move number: 12
# Qwen US move: c2c3 Move number: 13
# Qwen CN move: d4e6 Move number: 14
# Qwen US move: g5f6 Move number: 15
# Qwen CN move: Bxd6 Move number: 16
# Qwen US move: f6h4 Move number: 17
# Invalid move by Qwen black. Move: Bxd6
# New Move: f6
# Qwen CN move: f6 Move number: 18
# Qwen US move: d3c4 Move number: 19
# Qwen CN move: c8b7 Move number: 20
# Qwen US move: Bxf6 Move number: 21
# Qwen CN move: g7f6 Move number: 22
# Qwen US move: c4d5 Move number: 23
# Qwen CN move: e8c8 Move number: 24
# Qwen US move: d5b7 Move number: 25
# Qwen CN move: Kxb7 Move number: 26
# Qwen US move: b1d2 Move number: 27
# Qwen CN move: Rhe8 Move number: 28
# Qwen US move: Nc4 Move number: 29
# Qwen CN move: d6e7 Move number: 30
# Qwen US move: c4e3 Move number: 31
# Qwen CN move: Nd4 Move number: 32
# Qwen US move: e1g1 Move number: 33
# Qwen CN move: d4e6 Move number: 34
# Qwen US move: g1h1 Move number: 35
# Qwen CN move: c7c6 Move number: 36
# Qwen US move: b2b4 Move number: 37
# Qwen CN move: e6f4 Move number: 38
# Qwen US move: g2g3 Move number: 39
# Qwen CN move: Nh3 Move number: 40
# Qwen US move: d1g4 Move number: 41
# Qwen CN move: Rf8 Move number: 42
# Qwen US move: g4h3 Move number: 43
# Invalid move by Qwen black. Move: Rf8
# New Move: c5
# Qwen CN move: c5 Move number: 44
# Qwen US move: a2a3 Move number: 45
# Qwen CN move: c5b4 Move number: 46
# Qwen US move: Qxh7 Move number: 47
# Qwen CN move: e7c5 Move number: 48
# Qwen US move: a3b4 Move number: 49
# Qwen CN move: c5e3 Move number: 50
# Qwen US move: f2e3 Move number: 51
# Qwen CN move: Rfe8 Move number: 52
# Qwen US move: f1f6 Move number: 53
# Invalid move by Qwen black. Move: Rf1
# New Move: Ka8
# Qwen CN move: Ka8 Move number: 54
# Qwen US move: h7f7 Move number: 55
# Qwen CN move: a7a5 Move number: 56
# Qwen US move: Qxe8 Move number: 57
# Qwen CN move: d8e8 Move number: 58
# Qwen US move: f6b6 Move number: 59
# Qwen CN move: a8a7 Move number: 60
# Qwen US move: b6b5 Move number: 61
# Qwen CN move: Rxb8 Move number: 62
# Qwen US move: a1a5 Move number: 63
# Game 12 result: 1-0
#
#
# Starting game 13...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Qwen US move: c2c4 Move number: 9
# Qwen CN move: c7c5 Move number: 10
# Qwen US move: b1c3 Move number: 11
# Qwen CN move: c5d4 Move number: 12
# Invalid move by Qwen white. Move: Nbd2
# New Move: Be2
# Qwen US move: Be2 Move number: 13
# Qwen CN move: d4c3 Move number: 14
# Qwen US move: Qd2 Move number: 15
# Qwen CN move: c3d2 Move number: 16
# Qwen US move: c1d2 Move number: 17
# Qwen CN move: d8c7 Move number: 18
# Qwen US move: c4c5 Move number: 19
# Qwen CN move: N8e7 Move number: 20
# Qwen US move: f2f4 Move number: 21
# Qwen CN move: Nh4 Move number: 22
# Qwen US move: Bd3 Move number: 23
# Qwen CN move: h4g2 Move number: 24
# Qwen US move: e1d1 Move number: 25
# Qwen CN move: Nf5 Move number: 26
# Qwen US move: e4f5 Move number: 27
# Qwen CN move: f8e7 Move number: 28
# Qwen US move: a1c1 Move number: 29
# Qwen CN move: c7c6 Move number: 30
# Qwen US move: h1g1 Move number: 31
# Qwen CN move: c6f3 Move number: 32
# Qwen US move: d1c2 Move number: 33
# Qwen CN move: Qf1 Move number: 34
# Qwen US move: c1f1 Move number: 35
# Qwen CN move: Bxc5 Move number: 36
# Qwen US move: g1g2 Move number: 37
# Qwen CN move: Rg8 Move number: 38
# Invalid move by Qwen white. Move: Rxf7
# New Move: Rg5
# Qwen US move: Rg5 Move number: 39
# Qwen CN move: f7f6 Move number: 40
# Qwen US move: Rg7 Move number: 41
# Qwen CN move: g8g7 Move number: 42
# Qwen US move: d2c3 Move number: 43
# Qwen CN move: c5e7 Move number: 44
# Qwen US move: f1e1 Move number: 45
# Qwen CN move: Rg8 Move number: 46
# Qwen US move: c3f6 Move number: 47
# Qwen CN move: Rh8 Move number: 48
# Qwen US move: Bxh8 Move number: 49
# Qwen CN move: e8f8 Move number: 50
# Qwen US move: h8g7 Move number: 51
# Qwen CN move: Kf7 Move number: 52
# Qwen US move: d3c4 Move number: 53
# Qwen CN move: f7g7 Move number: 54
# Qwen US move: e1e7 Move number: 55
# Qwen CN move: g7f8 Move number: 56
# Qwen US move: e7f7 Move number: 57
# Qwen CN move: f8g8 Move number: 58
# Qwen US move: c4d5 Move number: 59
# Invalid move by Qwen black. Move: Bc6
# New Move: Rb8
# Qwen CN move: Rb8 Move number: 60
# Qwen US move: f7e7 Move number: 61
# Invalid move by Qwen black. Move: Rf8
# New Move: Kh8
# Qwen CN move: Kh8 Move number: 62
# Qwen US move: f5f6 Move number: 63
# Invalid move by Qwen black. Move: Rf7+ Kh8
# New Move: h6
# Qwen CN move: h6 Move number: 64
# Qwen US move: e7e8 Move number: 65
# Qwen CN move: Kh7 Move number: 66
# Qwen US move: d5e4 Move number: 67
# Game 13 result: 1-0
#
#
# Starting game 14...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: b1c3 Move number: 3
# Qwen CN move: Nf6 Move number: 4
# Qwen US move: e4e5 Move number: 5
# Invalid move by Qwen black. Move: Nf3
# New Move: d5
# Qwen CN move: d5 Move number: 6
# Qwen US move: e5f6 Move number: 7
# Qwen CN move: b8c6 Move number: 8
# Qwen US move: Nxe4 Move number: 9
# Qwen CN move: d5e4 Move number: 10
# Qwen US move: d2d3 Move number: 11
# Qwen CN move: c8f5 Move number: 12
# Qwen US move: d3e4 Move number: 13
# Qwen CN move: Nxe5 Move number: 14
# Qwen US move: d1d8 Move number: 15
# Qwen CN move: Rxd8 Move number: 16
# Qwen US move: Nf3 Move number: 17
# Qwen CN move: e5f3 Move number: 18
# Qwen US move: g2f3 Move number: 19
# Qwen CN move: Rd1+ Move number: 20
# Qwen US move: e1d1 Move number: 21
# Qwen CN move: f5e6 Move number: 22
# Qwen US move: c2c4 Move number: 23
# Qwen CN move: g7f6 Move number: 24
# Qwen US move: h1g1 Move number: 25
# Qwen CN move: f6f5 Move number: 26
# Qwen US move: d1c2 Move number: 27
# Qwen CN move: Bd5 Move number: 28
# Qwen US move: c4d5 Move number: 29
# Qwen CN move: fxe4 Move number: 30
# Qwen US move: f3e4 Move number: 31
# Qwen CN move: Rg8 Move number: 32
# Qwen US move: Rb1 Move number: 33
# Qwen CN move: Rh8 Move number: 34
# Qwen US move: f1b5 Move number: 35
# Qwen CN move: e8d8 Move number: 36
# Qwen US move: c1d2 Move number: 37
# Qwen CN move: a7a6 Move number: 38
# Qwen US move: Be8 Move number: 39
# Qwen CN move: d8e8 Move number: 40
# Qwen US move: b1e1 Move number: 41
# Qwen CN move: Rg8 Move number: 42
# Qwen US move: g1g8 Move number: 43
# Invalid move by Qwen black. Move:  Kb1
# New Move: e5
# Qwen CN move: e5 Move number: 44
# Qwen US move: d2h6 Move number: 45
# Qwen CN move: b7b5 Move number: 46
# Qwen US move: Rxf8+ Move number: 47
# Qwen CN move: e8e7 Move number: 48
# Qwen US move: e1d1 Move number: 49
# Qwen CN move: e7f6 Move number: 50
# Qwen US move: d1g1 Move number: 51
# Invalid move by Qwen black. Move: Rd2
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 52
# Qwen US move: f8b8 Move number: 53
# Invalid move by Qwen black. Move: Rb7
# New Move: Kf6
# Qwen CN move: Kf6 Move number: 54
# Qwen US move: b8b7 Move number: 55
# Qwen CN move: a5 Move number: 56
# Qwen US move: h6g7 Move number: 57
# Game 14 result: 1-0
#
#
# Starting game 15...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Invalid move by Qwen black. Move: Bc4
# New Move: g6
# Qwen CN move: g6 Move number: 6
# Qwen US move: c2c3 Move number: 7
# Qwen CN move: a7a6 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Qwen CN move: d7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: e5d4 Move number: 12
# Qwen US move: c3d4 Move number: 13
# Qwen CN move: Nf6 Move number: 14
# Qwen US move: b1c3 Move number: 15
# Qwen CN move: Be7 Move number: 16
# Qwen US move: Nh4 Move number: 17
# Qwen CN move: f6e4 Move number: 18
# Qwen US move: c3e4 Move number: 19
# Qwen CN move: Qd5 Move number: 20
# Qwen US move: d1e2 Move number: 21
# Qwen CN move: d5b5 Move number: 22
# Qwen US move: h4f3 Move number: 23
# Qwen CN move: b5e2 Move number: 24
# Qwen US move: e1e2 Move number: 25
# Qwen CN move: c8f5 Move number: 26
# Qwen US move: e4g3 Move number: 27
# Invalid move by Qwen black. Move: Nh4
# New Move: Rb8
# Qwen CN move: Rb8 Move number: 28
# Qwen US move: g3f5 Move number: 29
# Qwen CN move: Rg8 Move number: 30
# Qwen US move: f5e3 Move number: 31
# Qwen CN move: f7f6 Move number: 32
# Qwen US move: h2h4 Move number: 33
# Qwen CN move: e7d6 Move number: 34
# Qwen US move: Nh2 Move number: 35
# Qwen CN move: d6h2 Move number: 36
# Qwen US move: Nf5 Move number: 37
# Qwen CN move: Rd8 Move number: 38
# Qwen US move: f5h6 Move number: 39
# Qwen CN move: g8g7 Move number: 40
# Qwen US move: Nf5 Move number: 41
# Qwen CN move: g6f5 Move number: 42
# Qwen US move: h1h2 Move number: 43
# Qwen CN move: c6c5 Move number: 44
# Qwen US move: d4d5 Move number: 45
# Qwen CN move: g7e7 Move number: 46
# Qwen US move: e2f1 Move number: 47
# Qwen CN move: d8d5 Move number: 48
# Qwen US move: Rh3 Move number: 49
# Qwen CN move: d5d1 Move number: 50
# Game 15 result: 0-1
#
#
# Starting game 16...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Invalid move by Qwen white. Move: Nge2
# New Move: b3
# Qwen US move: b3 Move number: 5
# Qwen CN move: d7d6 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: d5 Move number: 8
# Qwen US move: e4d5 Move number: 9
# Qwen CN move: c6d4 Move number: 10
# Qwen US move: f3d4 Move number: 11
# Qwen CN move: c5d4 Move number: 12
# Qwen US move: Nbd2 Move number: 13
# Qwen CN move: d8d5 Move number: 14
# Qwen US move: Nf3 Move number: 15
# Invalid move by Qwen black. Move: Nc3
# New Move: Bg4
# Qwen CN move: Bg4 Move number: 16
# Qwen US move: d1d4 Move number: 17
# Qwen CN move: Nf6 Move number: 18
# Qwen US move: d4d5 Move number: 19
# Qwen CN move: f6d5 Move number: 20
# Qwen US move: f3e5 Move number: 21
# Qwen CN move: g4e6 Move number: 22
# Qwen US move: Nxf7 Move number: 23
# Qwen CN move: e8f7 Move number: 24
# Qwen US move: Rg1 Move number: 25
# Qwen CN move: Rg8 Move number: 26
# Qwen US move: c1b2 Move number: 27
# Qwen CN move: g7g6 Move number: 28
# Qwen US move: Bd3 Move number: 29
# Qwen CN move: f8h6 Move number: 30
# Qwen US move: d3e4 Move number: 31
# Qwen CN move: a8d8 Move number: 32
# Qwen US move: a1d1 Move number: 33
# Qwen CN move: b7b5 Move number: 34
# Qwen US move: d1d3 Move number: 35
# Qwen CN move: d5f6 Move number: 36
# Qwen US move: Bd4 Move number: 37
# Qwen CN move: f6e4 Move number: 38
# Invalid move by Qwen white. Move: Bxe4
# New Move: Be3
# Qwen US move: Be3 Move number: 39
# Qwen CN move: h6g7 Move number: 40
# Qwen US move: Bd2 Move number: 41
# Qwen CN move: e4d2 Move number: 42
# Qwen US move: e1d2 Move number: 43
# Qwen CN move: d8c8 Move number: 44
# Qwen US move: g2g4 Move number: 45
# Qwen CN move: Rxc2+ Move number: 46
# Qwen US move: d2c2 Move number: 47
# Qwen CN move: Bd5 Move number: 48
# Qwen US move: Rxd5 Move number: 49
# Qwen CN move: g8f8 Move number: 50
# Qwen US move: g1e1 Move number: 51
# Qwen CN move: Rd8 Move number: 52
# Qwen US move: d5d8 Move number: 53
# Qwen CN move: g7f6 Move number: 54
# Qwen US move: c2d3 Move number: 55
# Qwen CN move: h7h5 Move number: 56
# Qwen US move: g4h5 Move number: 57
# Qwen CN move: g6h5 Move number: 58
# Qwen US move: d8a8 Move number: 59
# Qwen CN move: Be5 Move number: 60
# Qwen US move: e1e5 Move number: 61
# Qwen CN move: Kf6 Move number: 62
# Qwen US move: e5b5 Move number: 63
# Invalid move by Qwen black. Move: Rxb7
# New Move: Kf7
# Qwen CN move: Kf7 Move number: 64
# Qwen US move: a8a7 Move number: 65
# Qwen CN move: Kf6 Move number: 66
# Qwen US move: b5c5 Move number: 67
# Qwen CN move: e7e5 Move number: 68
# Qwen US move: c5c6 Move number: 69
# Qwen CN move: f6f5 Move number: 70
# Qwen US move: Rb7 Move number: 71
# Qwen CN move: f5f4 Move number: 72
# Qwen US move: Rb8 Move number: 73
# Qwen CN move: Kf3 Move number: 74
# Qwen US move: b8f8 Move number: 75
# Qwen CN move: f3g4 Move number: 76
# Qwen US move: Rxf3+ Move number: 77
# Qwen CN move: g4f3 Move number: 78
# Qwen US move: h2h4 Move number: 79
# Qwen CN move: f3f2 Move number: 80
# Qwen US move: d3e4 Move number: 81
# Qwen CN move: f2g3 Move number: 82
# Qwen US move: a2a4 Move number: 83
# Qwen CN move: g3h4 Move number: 84
# Qwen US move: Rc1 Move number: 85
# Qwen CN move: h4g4 Move number: 86
# Qwen US move: Rc3 Move number: 87
# Qwen CN move: h5h4 Move number: 88
# Qwen US move: Rc1 Move number: 89
# Invalid move by Qwen black. Move: Rc3
# New Move: Kh5
# Qwen CN move: Kh5 Move number: 90
# Qwen US move: a4a5 Move number: 91
# Qwen CN move: Kg4 Move number: 92
# Qwen US move: a5a6 Move number: 93
# Qwen CN move: h4h3 Move number: 94
# Qwen US move: a6a7 Move number: 95
# Qwen CN move: g4g3 Move number: 96
# Invalid move by Qwen white. Move: Rc1
# New Move: a8=R
# Qwen US move: a8=R Move number: 97
# Qwen CN move: h3h2 Move number: 98
# Qwen US move: a8g8 Move number: 99
# Invalid move by Qwen black. Move: Rg8+
# New Move: Kf2
# Qwen CN move: Kf2 Move number: 100
# Qwen US move: c1h1 Move number: 101
# Qwen CN move: f2e2 Move number: 102
# Qwen US move: Rh8 Move number: 103
# Qwen CN move: e2d2 Move number: 104
# Qwen US move: h8c8 Move number: 105
# Qwen CN move: d2e2 Move number: 106
# Qwen US move: c8c2 Move number: 107
# Game 16 result: 1-0
#
#
# Starting game 17...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen US move: Bxc6 Move number: 7
# Qwen CN move: d7c6 Move number: 8
# Qwen US move: e1g1 Move number: 9
# Qwen CN move: f7f6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: e5d4 Move number: 12
# Qwen US move: f3d4 Move number: 13
# Qwen CN move: c6c5 Move number: 14
# Qwen US move: Nc3 Move number: 15
# Qwen CN move: c5d4 Move number: 16
# Qwen US move: Nxd5 Move number: 17
# Qwen CN move: c7c6 Move number: 18
# Qwen US move: Nf4 Move number: 19
# Invalid move by Qwen black. Move: Nxd6
# New Move: Kf7
# Qwen CN move: Kf7 Move number: 20
# Qwen US move: d1h5 Move number: 21
# Invalid move by Qwen black. Move: Nh3
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 22
# Qwen US move: f1e1 Move number: 23
# Invalid move by Qwen black. Move: Nf4
# New Move: f5
# Qwen CN move: f5 Move number: 24
# Qwen US move: e4f5 Move number: 25
# ...
# Qwen CN move: b8e8 Move number: 38
# Qwen US move: b5e8 Move number: 39
# Qwen CN move: Bd4 Move number: 40
# Qwen US move: c2c3 Move number: 41
# Qwen CN move: d4e5 Move number: 42
# Qwen US move: e8f7 Move number: 43
# Qwen CN move: g8g7 Move number: 44
# Qwen US move: f3f4 Move number: 45
# Qwen CN move: e5f6 Move number: 46
# Qwen US move: a3c2 Move number: 47
# Qwen CN move: Rb8 Move number: 48
# Qwen US move: f7h5 Move number: 49
# Invalid move by Qwen black. Move: Bh5
# New Move: b5
# Qwen CN move: b5 Move number: 50
# Qwen US move: c2e3 Move number: 51
# Qwen CN move: b5b4 Move number: 52
# Qwen US move: Bd2 Move number: 53
# Qwen CN move: b4c3 Move number: 54
# Qwen US move: b2c3 Move number: 55
# Qwen CN move: g7f8 Move number: 56
# Qwen US move: e3f5 Move number: 57
# Qwen CN move: Rb1+ Move number: 58
# Qwen US move: a1b1 Move number: 59
# Qwen CN move: Bxc3 Move number: 60
# Qwen US move: Be8 Move number: 61
# Qwen CN move: c3b4 Move number: 62
# Qwen US move: d2b4 Move number: 63
# Invalid move by Qwen black. Move: Bxc3
# New Move: Kxe8
# Qwen CN move: Kxe8 Move number: 64
# Qwen US move: b4a5 Move number: 65
# Qwen CN move: Kf8 Move number: 66
# Qwen US move: b1b8 Move number: 67
# Game 95 result: 1-0
#
#
# Starting game 96...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: Nge7 Move number: 6
# Qwen US move: Bxc6 Move number: 7
# Qwen CN move: d7c6 Move number: 8
# Qwen US move: e1g1 Move number: 9
# Qwen CN move: Ng6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: c8g4 Move number: 12
# Qwen US move: d4e5 Move number: 13
# Qwen CN move: d8d1 Move number: 14
# Qwen US move: f1d1 Move number: 15
# Qwen CN move: g6e5 Move number: 16
# Qwen US move: b1d2 Move number: 17
# Qwen CN move: Rg8 Move number: 18
# Qwen US move: h2h3 Move number: 19
# Qwen CN move: Be6 Move number: 20
# Qwen US move: f3e5 Move number: 21
# Qwen CN move: Bd6 Move number: 22
# Qwen US move: Nxf7 Move number: 23
# Qwen CN move: Bxf7 Move number: 24
# Qwen US move: d2f1 Move number: 25
# Qwen CN move: a7a5 Move number: 26
# Qwen US move: f2f3 Move number: 27
# Qwen CN move: a5a4 Move number: 28
# Qwen US move: Ng3 Move number: 29
# Qwen CN move: d6g3 Move number: 30
# Qwen US move: f3f4 Move number: 31
# Qwen CN move: Rf8 Move number: 32
# Qwen US move: d1d3 Move number: 33
# Qwen CN move: Rh8 Move number: 34
# Qwen US move: d3g3 Move number: 35
# Qwen CN move: g7g6 Move number: 36
# Qwen US move: g3d3 Move number: 37
# Qwen CN move: f7c4 Move number: 38
# Qwen US move: d3d4 Move number: 39
# Invalid move by Qwen black. Move: Rd7
# New Move: Bxa2
# Qwen CN move: Bxa2 Move number: 40
# Qwen US move: a1a2 Move number: 41
# Qwen CN move: b7b5 Move number: 42
# Qwen US move: Rd8+ Move number: 43
# Qwen CN move: a8d8 Move number: 44
# Qwen US move: c1e3 Move number: 45
# Qwen CN move: e8f7 Move number: 46
# Qwen US move: g1f2 Move number: 47
# Qwen CN move: Rd7 Move number: 48
# Qwen US move: a2a1 Move number: 49
# Qwen CN move: Rd2+ Move number: 50
# Qwen US move: Kg3 Move number: 51
# Qwen CN move: d2c2 Move number: 52
# Qwen US move: a1d1 Move number: 53
# Invalid move by Qwen black. Move: Rd2+
# New Move: Rd2
# Qwen CN move: Rd2 Move number: 54
# Qwen US move: d1d2 Move number: 55
# Qwen CN move: h8e8 Move number: 56
# Qwen US move: Rd1 Move number: 57
# Qwen CN move: e8e4 Move number: 58
# Qwen US move: g3f3 Move number: 59
# Qwen CN move: e4b4 Move number: 60
# Qwen US move: d1d2 Move number: 61
# Qwen CN move: Rxf4+ Move number: 62
# Qwen US move: e3f4 Move number: 63
# Qwen CN move: Kf6 Move number: 64
# Qwen US move: Bxc7 Move number: 65
# Qwen CN move: f6f5 Move number: 66
# Qwen US move: c7d6 Move number: 67
# Qwen CN move: Kg5 Move number: 68
# Qwen US move: f3e3 Move number: 69
# Qwen CN move: g5f5 Move number: 70
# Qwen US move: g2g4 Move number: 71
# Qwen CN move: f5e6 Move number: 72
# Qwen US move: e3e4 Move number: 73
# Qwen CN move: h7h5 Move number: 74
# Qwen US move: g4g5 Move number: 75
# Invalid move by Qwen black. Move: Ke4
# New Move: a3
# Qwen CN move: a3 Move number: 76
# Qwen US move: d6a3 Move number: 77
# Qwen CN move: e6f7 Move number: 78
# Qwen US move: Ke5 Move number: 79
# Qwen CN move: f7g7 Move number: 80
# Qwen US move: e5e6 Move number: 81
# Qwen CN move: g7h7 Move number: 82
# Qwen US move: e6f7 Move number: 83
# Qwen CN move: Kh8 Move number: 84
# Qwen US move: f7g6 Move number: 85
# Qwen CN move: Kg8 Move number: 86
# Qwen US move: Rd1 Move number: 87
# Qwen CN move: h5h4 Move number: 88
# Qwen US move: d1d8 Move number: 89
# Game 96 result: 1-0
#
#
# Starting game 97...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen US move: b5a4 Move number: 7
# Qwen CN move: f8e7 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Qwen CN move: d7c6 Move number: 10
# Qwen US move: Ng5 Move number: 11
# Qwen CN move: e7g5 Move number: 12
# Qwen US move: Qe2 Move number: 13
# Qwen CN move: Nf6 Move number: 14
# Qwen US move: Qd1 Move number: 15
# Qwen CN move: c8g4 Move number: 16
# Qwen US move: f2f3 Move number: 17
# Qwen CN move: g4e6 Move number: 18
# Qwen US move: b1c3 Move number: 19
# Qwen CN move: Nxd5 Move number: 20
# Qwen US move: e4d5 Move number: 21
# Qwen CN move: c6d5 Move number: 22
# Qwen US move: Nxd5 Move number: 23
# Qwen CN move: d8d5 Move number: 24
# Qwen US move: d4 Move number: 25
# Qwen CN move: g5c1 Move number: 26
# Qwen US move: a1c1 Move number: 27
# Qwen CN move: e8c8 Move number: 28
# Qwen US move: c2c3 Move number: 29
# Qwen CN move: d5b5 Move number: 30
# Qwen US move: Qd2 Move number: 31
# Qwen CN move: e5d4 Move number: 32
# Qwen US move: c3d4 Move number: 33
# Qwen CN move: d8d5 Move number: 34
# Qwen US move: c1c2 Move number: 35
# Qwen CN move: e6f5 Move number: 36
# Qwen US move: c2c1 Move number: 37
# Qwen CN move: c8b8 Move number: 38
# Qwen US move: Qh6 Move number: 39
# Qwen CN move: h8e8 Move number: 40
# Qwen US move: h6e3 Move number: 41
# Qwen CN move: Rxe6 Move number: 42
# Qwen US move: e3e6 Move number: 43
# Qwen CN move: f5e6 Move number: 44
# Qwen US move: c1c2 Move number: 45
# Qwen CN move: d5d4 Move number: 46
# Qwen US move: g2g4 Move number: 47
# Invalid move by Qwen black. Move: Bg5
# New Move: Rd3
# Qwen CN move: Rd3 Move number: 48
# Qwen US move: e1g1 Move number: 49
# Qwen CN move: b5b6 Move number: 50
# Qwen US move: Kg2 Move number: 51
# Qwen CN move: c7c5 Move number: 52
# Qwen US move: f1e1 Move number: 53
# Qwen CN move: e6d5 Move number: 54
# Qwen US move: c2f2 Move number: 55
# Qwen CN move: Rd1 Move number: 56
# Qwen US move: e1d1 Move number: 57
# Qwen CN move: Bxf3+ Move number: 58
# Qwen US move: Kg1 Move number: 59
# Qwen CN move: f3d1 Move number: 60
# Qwen US move: g4g5 Move number: 61
# Invalid move by Qwen black. Move: gxf3
# New Move: Qh6
# Qwen CN move: Qh6 Move number: 62
# Qwen US move: g5h6 Move number: 63
# Qwen CN move: Bf3 Move number: 64
# Qwen US move: h6g7 Move number: 65
# Qwen CN move: f3d5 Move number: 66
# Qwen US move: g7g8q Move number: 67
# Qwen CN move: b8a7 Move number: 68
# Qwen US move: Qxf7 Move number: 69
# Qwen CN move: d5f7 Move number: 70
# Qwen US move: Rxf7 Move number: 71
# Invalid move by Qwen black. Move: Rf1
# New Move: c4
# Qwen CN move: c4 Move number: 72
# Qwen US move: g1f2 Move number: 73
# Qwen CN move: a7b6 Move number: 74
# Qwen US move: Rxf3 Move number: 75
# Qwen CN move: b6a5 Move number: 76
# Qwen US move: f3f7 Move number: 77
# Qwen CN move: b7b5 Move number: 78
# Qwen US move: f2e3 Move number: 79
# Qwen CN move: Kb4 Move number: 80
# Qwen US move: e3d2 Move number: 81
# Qwen CN move: Kc5 Move number: 82
# Qwen US move: Rf8 Move number: 83
# Qwen CN move: a6a5 Move number: 84
# Qwen US move: f8f5 Move number: 85
# Qwen CN move: Kd4 Move number: 86
# Qwen US move: f5b5 Move number: 87
# Qwen CN move: a5a4 Move number: 88
# Qwen US move: b5h5 Move number: 89
# Qwen CN move: c4c3 Move number: 90
# Qwen US move: b2c3 Move number: 91
# Qwen CN move: d4e4 Move number: 92
# Qwen US move: c3c4 Move number: 93
# Qwen CN move: Kf3 Move number: 94
# Qwen US move: d2c3 Move number: 95
# Qwen CN move: Kf4 Move number: 96
# Qwen US move: h5h4 Move number: 97
# Qwen CN move: Kf3 Move number: 98
# Qwen US move: Rxh7 Move number: 99
# Qwen CN move: Kf4 Move number: 100
# Qwen US move: c3b4 Move number: 101
# Qwen CN move: f4f3 Move number: 102
# Qwen US move: b4a4 Move number: 103
# Qwen CN move: f3g4 Move number: 104
# Qwen US move: Rh8 Move number: 105
# Qwen CN move: g4f5 Move number: 106
# Qwen US move: a4b4 Move number: 107
# Invalid move by Qwen black. Move: Rf8
# New Move: Kf6
# Qwen CN move: Kf6 Move number: 108
# Qwen US move: h8b8 Move number: 109
# Qwen CN move: Kf7 Move number: 110
# Qwen US move: a2a4 Move number: 111
# Qwen CN move: f7g7 Move number: 112
# Qwen US move: a4a5 Move number: 113
# Qwen CN move: g7f6 Move number: 114
# Qwen US move: Rh8 Move number: 115
# Qwen CN move: f6e6 Move number: 116
# Qwen US move: Rf8 Move number: 117
# Invalid move by Qwen black. Move: Rf5+ Kf4
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 118
# Qwen US move: f8b8 Move number: 119
# Invalid move by Qwen black. Move: Rb7
# New Move: Kf7
# Qwen CN move: Kf7 Move number: 120
# Qwen US move: a5a6 Move number: 121
# Invalid move by Qwen black. Move: a7
# New Move: Kg7
# Qwen CN move: Kg7 Move number: 122
# Qwen US move: a6a7 Move number: 123
# Invalid move by Qwen black. Move: Rb8
# New Move: Kh7
# Qwen CN move: Kh7 Move number: 124
# Qwen US move: a7a8q Move number: 125
# Invalid move by Qwen black. Move: Rh8
# New Move: Kg6
# Qwen CN move: Kg6 Move number: 126
# Qwen US move: a8c6 Move number: 127
# Qwen CN move: g6g5 Move number: 128
# Invalid move by Qwen white. Move: Qc6
# New Move: h4+
# Qwen US move: h4+ Move number: 129
# Qwen CN move: g5g4 Move number: 130
# Qwen US move: c6f6 Move number: 131
# Qwen CN move: Kh3 Move number: 132
# Qwen US move: b8g8 Move number: 133
# Qwen CN move: h3h2 Move number: 134
# Qwen US move: f6f2 Move number: 135
# Qwen CN move: h2h3 Move number: 136
# Qwen US move: Qg1 Move number: 137
# Qwen CN move: h3h4 Move number: 138
# Qwen US move: Qg2 Move number: 139
# Qwen CN move: Kh5 Move number: 140
# Qwen US move: g8h8 Move number: 141
# Game 97 result: 1-0
#
#
# Starting game 98...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen US move: b5a4 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: e1g1 Move number: 9
# Qwen CN move: Nxe4 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: Nd2 Move number: 12
# Qwen US move: c1d2 Move number: 13
# Qwen CN move: Bd6 Move number: 14
# Qwen US move: Bxc6 Move number: 15
# Qwen CN move: Rg8 Move number: 16
# Qwen US move: c6d5 Move number: 17
# Qwen CN move: e5d4 Move number: 18
# Qwen US move: f1e1 Move number: 19
# Qwen CN move: e8f8 Move number: 20
# Qwen US move: Bxf7 Move number: 21
# Qwen CN move: d8f6 Move number: 22
# Qwen US move: f7g8 Move number: 23
# Qwen CN move: Qxf3 Move number: 24
# Qwen US move: d1f3 Move number: 25
# Qwen CN move: Bf4 Move number: 26
# Qwen US move: f3f4 Move number: 27
# Qwen CN move: f8g8 Move number: 28
# Qwen US move: e1e8 Move number: 29
# Game 98 result: 1-0
#
#
# Starting game 99...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: e7e6 Move number: 6
# Qwen US move: e1g1 Move number: 7
# Qwen CN move: g8e7 Move number: 8
# Qwen US move: d2d4 Move number: 9
# Qwen CN move: c5d4 Move number: 10
# Qwen US move: Bxc6 Move number: 11
# Qwen CN move: d7c6 Move number: 12
# Qwen US move: d1d4 Move number: 13
# Qwen CN move: Qd5 Move number: 14
# Qwen US move: e4d5 Move number: 15
# Qwen CN move: c6d5 Move number: 16
# Qwen US move: f1e1 Move number: 17
# Qwen CN move: e7f5 Move number: 18
# Qwen US move: d4d3 Move number: 19
# Qwen CN move: Nh4 Move number: 20
# Qwen US move: f3h4 Move number: 21
# Qwen CN move: Bd6 Move number: 22
# Qwen US move: Qf3 Move number: 23
# Qwen CN move: d6e7 Move number: 24
# Qwen US move: Qxf7+ Move number: 25
# Qwen CN move: e8f7 Move number: 26
# Qwen US move: Ng6 Move number: 27
# Qwen CN move: f7g6 Move number: 28
# Qwen US move: c1f4 Move number: 29
# Invalid move by Qwen black. Move: Bxc6
# New Move: b6
# Qwen CN move: b6 Move number: 30
# Qwen US move: b1d2 Move number: 31
# Qwen CN move: e7f6 Move number: 32
# Qwen US move: Re3 Move number: 33
# Qwen CN move: f6b2 Move number: 34
# Qwen US move: a1e1 Move number: 35
# Qwen CN move: b2f6 Move number: 36
# Qwen US move: d2f3 Move number: 37
# Invalid move by Qwen black. Move: Re3
# New Move: h6
# Qwen CN move: h6 Move number: 38
# Qwen US move: f4e5 Move number: 39
# Qwen CN move: c8d7 Move number: 40
# Invalid move by Qwen white. Move: Bxd7
# New Move: Bc3
# Qwen US move: Bc3 Move number: 41
# Qwen CN move: h8c8 Move number: 42
# Qwen US move: Nh4+ Move number: 43
# Qwen CN move: f6h4 Move number: 44
# Qwen US move: a2a4 Move number: 45
# Qwen CN move: c8f8 Move number: 46
# Qwen US move: e1f1 Move number: 47
# Invalid move by Qwen black. Move: Rxf2+
# New Move: Rf6
# Qwen CN move: Rf6 Move number: 48
# Qwen US move: g2g3 Move number: 49
# Invalid move by Qwen black. Move: Rxf6
# New Move: Rf4
# Qwen CN move: Rf4 Move number: 50
# Qwen US move: g3f4 Move number: 51
# Qwen CN move: a8c8 Move number: 52
# Qwen US move: Rxe6+ Move number: 53
# Qwen CN move: d7e6 Move number: 54
# Qwen US move: f1e1 Move number: 55
# Qwen CN move: e6f5 Move number: 56
# Qwen US move: e1e3 Move number: 57
# Qwen CN move: Rc4 Move number: 58
# Qwen US move: e3f3 Move number: 59
# Qwen CN move: Rxf4 Move number: 60
# Qwen US move: Rxf4 Move number: 61
# Qwen CN move: h4g5 Move number: 62
# Qwen US move: f4b4 Move number: 63
# Invalid move by Qwen black. Move: Rb5
# New Move: h5
# Qwen CN move: h5 Move number: 64
# Qwen US move: b4b2 Move number: 65
# Qwen CN move: g6f7 Move number: 66
# Qwen US move: Bd2 Move number: 67
# Qwen CN move: g5d2 Move number: 68
# Qwen US move: c2c4 Move number: 69
# Qwen CN move: d2c3 Move number: 70
# Qwen US move: b2b5 Move number: 71
# Invalid move by Qwen black. Move: Rxb7
# New Move: Bc8
# Qwen CN move: Bc8 Move number: 72
# Qwen US move: b5d5 Move number: 73
# Qwen CN move: Bf6 Move number: 74
# Qwen US move: c4c5 Move number: 75
# Qwen CN move: c8e6 Move number: 76
# Qwen US move: d5h5 Move number: 77
# Qwen CN move: f7g6 Move number: 78
# Qwen US move: Rh8 Move number: 79
# Qwen CN move: b6c5 Move number: 80
# Qwen US move: Rh7 Move number: 81
# Qwen CN move: Bf5 Move number: 82
# Qwen US move: h7h8 Move number: 83
# Qwen CN move: c5c4 Move number: 84
# Qwen US move: Rg8 Move number: 85
# Qwen CN move: c4c3 Move number: 86
# Qwen US move: g8e8 Move number: 87
# Qwen CN move: c3c2 Move number: 88
# Qwen US move: e8e1 Move number: 89
# Qwen CN move: f6b2 Move number: 90
# Qwen US move: h2h4 Move number: 91
# Qwen CN move: c2c1q Move number: 92
# Invalid move by Qwen white. Move: Rxc2
# New Move: f4
# Qwen US move: f4 Move number: 93
# Qwen CN move: c1e1 Move number: 94
# Qwen US move: g1g2 Move number: 95
# Qwen CN move: Bh3+ Move number: 96
# Qwen US move: g2f3 Move number: 97
# Qwen CN move: e1f1 Move number: 98
# Qwen US move: f3e4 Move number: 99
# Qwen CN move: h3g2 Move number: 100
# Invalid move by Qwen white. Move: Kf3
# New Move: Ke3
# Qwen US move: Ke3 Move number: 101
# Qwen CN move: f1e1 Move number: 102
# Qwen US move: Kd3 Move number: 103
# Qwen CN move: g2e4 Move number: 104
# Qwen US move: d3c4 Move number: 105
# Qwen CN move: e1c3 Move number: 106
# Qwen US move: c4b5 Move number: 107
# Qwen CN move: Bd3 Move number: 108
# Game 99 result: 0-1
#
#
# Starting game 100...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Invalid move by Qwen black. Move: Nf3
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 6
# Qwen US move: b1a3 Move number: 7
# Qwen CN move: Nge7 Move number: 8
# Qwen US move: d4d5 Move number: 9
# Qwen CN move: c6b8 Move number: 10
# Qwen US move: d5d6 Move number: 11
# Qwen CN move: c7d6 Move number: 12
# Qwen US move: Nxe5 Move number: 13
# Qwen CN move: d6e5 Move number: 14
# Qwen US move: Qxd7+ Move number: 15
# Invalid move by Qwen black. Move: Qxd7+
# New Move: Kf8
# Qwen CN move: Kf8 Move number: 16
# Qwen US move: d7d8 Move number: 17
# Game 100 result: 1-0

# %%
results = []

# %%
results.append({
            "Qwen US Wins": qwen_us_wins,
            "Qwen CN Wins": qwen_cn_wins,
            "Draws": draws,
        })

print(results)
# Out:
# [{'Qwen US Wins': 60, 'Qwen CN Wins': 33, 'Draws': 7}]

# %% [markdown]
# ## Swapping sides

# %%
stockfish = Stockfish()
stockfish.update_engine_parameters({"Threads": 4, "Hash": 4096})

# %%
for game_number in range(1, NUM_GAMES + 1):
    
    move_counter = 0

    print(f"Starting game {game_number}...")

    board = chess.Board()

    while not board.is_game_over() and move_counter <= MOVE_LIMIT:
        if board.turn == chess.WHITE and not board.is_game_over():
            num = random.randint(1,100)
            
            if num <= QWEN_US_AI:
                stockfish.set_fen_position(board.fen())
                qwen_us_move = await get_move_with_timeout(stockfish)

                if qwen_us_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break
            
            else:
                qwen_us_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_us_move)
            except Exception as e:
                print(f"Invalid move by Qwen white. Move: {qwen_us_move}")
                qwen_us_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_us_move)
                print(f"New Move: {qwen_us_move}")
                # continue
            
            move_counter += 1        
            print(f"Qwen US move: {qwen_us_move} Move number: {move_counter}")

        elif board.turn == chess.BLACK and not board.is_game_over():
            num = random.randint(1, 100)

            if num <= QWEN_CN_AI:
                stockfish.set_fen_position(board.fen())
                qwen_cn_move = await get_move_with_timeout(stockfish)

                if qwen_cn_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break

            else:
                qwen_cn_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_cn_move)
            except Exception as e:
                print(f"Invalid move by Qwen black. Move: {qwen_cn_move}")
                qwen_cn_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_cn_move)
                print(f"New Move: {qwen_cn_move}")
                # continue
            move_counter += 1
            print(f"Qwen CN move: {qwen_cn_move} Move number: {move_counter}")   

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        qwen_cn_wins += 1
    elif result == "0-1":
        qwen_us_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n\n")
# Out:
# Starting game 1...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Invalid move by Qwen black. Move: Bc4
# New Move: g6
# Qwen CN move: g6 Move number: 6
# Qwen US move: c2c3 Move number: 7
# Qwen CN move: g8e7 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Qwen CN move: e7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: d7d6 Move number: 12
# Qwen US move: d4d5 Move number: 13
# Invalid move by Qwen black. Move: Nbd2
# New Move: Nd4
# Qwen CN move: Nd4 Move number: 14
# Qwen US move: c3d4 Move number: 15
# Qwen CN move: f7f5 Move number: 16
# Qwen US move: Ng5 Move number: 17
# Qwen CN move: f8g7 Move number: 18
# Qwen US move: d4e5 Move number: 19
# Qwen CN move: h7h6 Move number: 20
# Qwen US move: g5e6 Move number: 21
# Invalid move by Qwen black. Move: Nxf8
# New Move: b6
# Qwen CN move: b6 Move number: 22
# Qwen US move: e6d8 Move number: 23
# Qwen CN move: e8d8 Move number: 24
# Qwen US move: Rg1 Move number: 25
# Qwen CN move: g7e5 Move number: 26
# Qwen US move: b1c3 Move number: 27
# Qwen CN move: c8a6 Move number: 28
# Qwen US move: c1e3 Move number: 29
# Qwen CN move: Bxd4 Move number: 30
# Qwen US move: d1d4 Move number: 31
# Qwen CN move: Rg8 Move number: 32
# Qwen US move: Qd1 Move number: 33
# Qwen CN move: f5e4 Move number: 34
# Qwen US move: a2a4 Move number: 35
# Qwen CN move: Rg7 Move number: 36
# Qwen US move: d1d4 Move number: 37
# Qwen CN move: g7f7 Move number: 38
# Qwen US move: d4h8 Move number: 39
# Qwen CN move: d8d7 Move number: 40
# Qwen US move: h8h6 Move number: 41
# Qwen CN move: a8f8 Move number: 42
# Qwen US move: h6h4 Move number: 43
# Qwen CN move: Rxf2 Move number: 44
# Qwen US move: h4f2 Move number: 45
# Qwen CN move: Rxf2 Move number: 46
# Qwen US move: e1f2 Move number: 47
# Qwen CN move: Ke7 Move number: 48
# Qwen US move: Bh6 Move number: 49
# Invalid move by Qwen black. Move: Bh6
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 50
# Qwen US move: f2e1 Move number: 51
# Qwen CN move: Bf1 Move number: 52
# Qwen US move: g1f1 Move number: 53
# Qwen CN move: d7c8 Move number: 54
# Qwen US move: f1f8 Move number: 55
# Qwen CN move: c8b7 Move number: 56
# Qwen US move: Rd1 Move number: 57
# Qwen CN move: g6g5 Move number: 58
# Qwen US move: Rf1 Move number: 59
# Invalid move by Qwen black. Move: Rd8
# New Move: a5
# Qwen CN move: a5 Move number: 60
# Qwen US move: h6g5 Move number: 61
# Qwen CN move: c7c5 Move number: 62
# Qwen US move: Bh4 Move number: 63
# Qwen CN move: b7c8 Move number: 64
# Qwen US move: f1f4 Move number: 65
# Qwen CN move: b6b5 Move number: 66
# Qwen US move: a4b5 Move number: 67
# Invalid move by Qwen black. Move:  Kb7
# New Move: a4
# Qwen CN move: a4 Move number: 68
# Qwen US move: f4e4 Move number: 69
# Qwen CN move: c8c7 Move number: 70
# Invalid move by Qwen white. Move: Rf5
# New Move: Re7+
# Qwen US move: Re7+ Move number: 71
# Qwen CN move: c7c8 Move number: 72
# Qwen US move: Re8+ Move number: 73
# Qwen CN move: c8c7 Move number: 74
# Qwen US move: e8e3 Move number: 75
# Qwen CN move: c7b6 Move number: 76
# Qwen US move: e1d2 Move number: 77
# Qwen CN move: Kc7 Move number: 78
# Qwen US move: h2h3 Move number: 79
# Invalid move by Qwen black. Move:  Kb6
# New Move: c4
# Qwen CN move: c4 Move number: 80
# Qwen US move: h4e1 Move number: 81
# Qwen CN move: c7b7 Move number: 82
# Qwen US move: Re2 Move number: 83
# Qwen CN move: b7c7 Move number: 84
# Qwen US move: d1a1 Move number: 85
# Qwen CN move: c7c8 Move number: 86
# Qwen US move: a1a4 Move number: 87
# Qwen CN move: Kd7 Move number: 88
# Qwen US move: a4a7 Move number: 89
# Invalid move by Qwen black. Move: Rxa8
# New Move: Kd8
# Qwen CN move: Kd8 Move number: 90
# Qwen US move: e2e3 Move number: 91
# Invalid move by Qwen black. Move: Rf8
# New Move: Kc8
# Qwen CN move: Kc8 Move number: 92
# Qwen US move: e3e8 Move number: 93
# Game 1 result: 1-0
#
#
# Starting game 2...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: Bb4 Move number: 6
# Qwen US move: c2c3 Move number: 7
# Qwen CN move: Nge7 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Qwen CN move: e7c6 Move number: 10
# Qwen US move: c3b4 Move number: 11
# Qwen CN move: Nxb4 Move number: 12
# Qwen US move: d2d4 Move number: 13
# Qwen CN move: e5d4 Move number: 14
# Qwen US move: a2a3 Move number: 15
# Qwen CN move: b4c6 Move number: 16
# Qwen US move: f3d4 Move number: 17
# Qwen CN move: c6d4 Move number: 18
# Qwen US move: d1d4 Move number: 19
# Qwen CN move: Qe7 Move number: 20
# Qwen US move: d4g7 Move number: 21
# Qwen CN move: Qxe4+ Move number: 22
# Qwen US move: c1e3 Move number: 23
# Qwen CN move: Qf3 Move number: 24
# Qwen US move: Qxh8+ Move number: 25
# Qwen CN move: Ke7 Move number: 26
# Qwen US move: g2f3 Move number: 27
# Qwen CN move: d7d5 Move number: 28
# Qwen US move: e3g5 Move number: 29
# Qwen CN move: e7d6 Move number: 30
# Qwen US move: Qg8 Move number: 31
# Qwen CN move: h7h6 Move number: 32
# Qwen US move: g8d8 Move number: 33
# Qwen CN move: Bd7 Move number: 34
# Qwen US move: g5f4 Move number: 35
# Invalid move by Qwen black. Move: Be3
# New Move: Kc5
# Qwen CN move: Kc5 Move number: 36
# Qwen US move: d8d7 Move number: 37
# Qwen CN move: c5b6 Move number: 38
# Qwen US move: Qxf7 Move number: 39
# Qwen CN move: b6a6 Move number: 40
# Qwen US move: f7d7 Move number: 41
# Qwen CN move: c7c6 Move number: 42
# Qwen US move: e1e2 Move number: 43
# Qwen CN move: Rd8 Move number: 44
# Qwen US move: d7d8 Move number: 45
# Qwen CN move: Kb5 Move number: 46
# Qwen US move: Qxa5+ Move number: 47
# Qwen CN move: b5a5 Move number: 48
# Qwen US move: b1d2 Move number: 49
# Invalid move by Qwen black. Move: Bf4
# New Move: Ka6
# Qwen CN move: Ka6 Move number: 50
# Qwen US move: e2d1 Move number: 51
# Qwen CN move: b5 Move number: 52
# Qwen US move: a1c1 Move number: 53
# Qwen CN move: a6b6 Move number: 54
# Qwen US move: f4e3 Move number: 55
# Qwen CN move: b6c7 Move number: 56
# Invalid move by Qwen white. Move: Bxc6+
# New Move: Rc4
# Qwen US move: Rc4 Move number: 57
# Qwen CN move: b5c4 Move number: 58
# Qwen US move: e3h6 Move number: 59
# Invalid move by Qwen black. Move: Bxc4
# New Move: c3
# Qwen CN move: c3 Move number: 60
# Qwen US move: b2c3 Move number: 61
# Qwen CN move: c6c5 Move number: 62
# Qwen US move: Bf4+ Move number: 63
# Qwen CN move: c7c6 Move number: 64
# Qwen US move: h1e1 Move number: 65
# Qwen CN move: c6b6 Move number: 66
# Qwen US move: f4e5 Move number: 67
# Invalid move by Qwen black. Move: Bxc7
# New Move: Kc6
# Qwen CN move: Kc6 Move number: 68
# Qwen US move: e5h8 Move number: 69
# Invalid move by Qwen black. Move: Bh6
# New Move: Kc7
# Qwen CN move: Kc7 Move number: 70
# Qwen US move: h2h4 Move number: 71
# Invalid move by Qwen black. Move:  Kb7
# New Move: c4
# Qwen CN move: c4 Move number: 72
# Qwen US move: h4h5 Move number: 73
# Qwen CN move: d5d4 Move number: 74
# Qwen US move: Re2 Move number: 75
# Qwen CN move: c7c6 Move number: 76
# Qwen US move: h8d4 Move number: 77
# Qwen CN move: a7a5 Move number: 78
# Qwen US move: h5h6 Move number: 79
# Invalid move by Qwen black. Move: Bxc5
# New Move: Kb5
# Qwen CN move: Kb5 Move number: 80
# Qwen US move: h6h7 Move number: 81
# Qwen CN move: b5a4 Move number: 82
# Qwen US move: Bh8 Move number: 83
# Qwen CN move: a4a3 Move number: 84
# Qwen US move: h8d4 Move number: 85
# Qwen CN move: a3b2 Move number: 86
# Qwen US move: f3f4 Move number: 87
# Invalid move by Qwen black. Move: Bf5
# New Move: Ka3
# Qwen CN move: Ka3 Move number: 88
# Qwen US move: h7h8q Move number: 89
# Invalid move by Qwen black. Move: Bxd5
# New Move: Ka4
# Qwen CN move: Ka4 Move number: 90
# Qwen US move: h8e8 Move number: 91
# Invalid move by Qwen black. Move: Bxc5
# New Move: Ka3
# Qwen CN move: Ka3 Move number: 92
# Qwen US move: d2c4 Move number: 93
# Qwen CN move: Kb3 Move number: 94
# Qwen US move: e8b5 Move number: 95
# Game 2 result: 1-0
#
#
# Starting game 3...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: Nge7 Move number: 6
# Qwen US move: Bxc6 Move number: 7
# Qwen CN move: d7c6 Move number: 8
# Qwen US move: b1c3 Move number: 9
# Qwen CN move: Nxd5 Move number: 10
# Qwen US move: e4d5 Move number: 11
# Qwen CN move: c6d5 Move number: 12
# Qwen US move: f3e5 Move number: 13
# Qwen CN move: d5d4 Move number: 14
# Qwen US move: d1h5 Move number: 15
# Qwen CN move: c8e6 Move number: 16
# Qwen US move: c3e2 Move number: 17
# Qwen CN move: Bxc8 Move number: 18
# Qwen US move: h5f7 Move number: 19
# Game 3 result: 1-0
#
#
# Starting game 4...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Qwen US move: c2c4 Move number: 9
# Invalid move by Qwen black. Move: Nc3
# New Move: d6
# Qwen CN move: d6 Move number: 10
# Qwen US move: b1c3 Move number: 11
# Qwen CN move: f8e7 Move number: 12
# Qwen US move: Nd5 Move number: 13
# Qwen CN move: c7c6 Move number: 14
# Qwen US move: d5c3 Move number: 15
# Qwen CN move: g8f6 Move number: 16
# Qwen US move: f2f4 Move number: 17
# Qwen CN move: Nxe4 Move number: 18
# Qwen US move: c3e4 Move number: 19
# Invalid move by Qwen black. Move: Nf3
# New Move: Qa5+
# Qwen CN move: Qa5+ Move number: 20
# Qwen US move: d1d2 Move number: 21
# Qwen CN move: Qe5 Move number: 22
# Qwen US move: f4e5 Move number: 23
# Qwen CN move: d6e5 Move number: 24
# Qwen US move: c4c5 Move number: 25
# Qwen CN move: e8g8 Move number: 26
# Qwen US move: Nf6+ Move number: 27
# Qwen CN move: e7f6 Move number: 28
# Qwen US move: Qh6 Move number: 29
# Qwen CN move: Bh4+ Move number: 30
# Qwen US move: g2g3 Move number: 31
# Qwen CN move: h4g3 Move number: 32
# Qwen US move: Ke2 Move number: 33
# Qwen CN move: c8g4 Move number: 34
# Qwen US move: e2d2 Move number: 35
# Qwen CN move: g7h6 Move number: 36
# Qwen US move: h2g3 Move number: 37
# Qwen CN move: e5d4 Move number: 38
# Qwen US move: h1h6 Move number: 39
# Qwen CN move: a8e8 Move number: 40
# Qwen US move: Rxh7 Move number: 41
# Qwen CN move: g8h7 Move number: 42
# Qwen US move: Bd3 Move number: 43
# Qwen CN move: f8h8 Move number: 44
# Qwen US move: Bxg6+ Move number: 45
# Invalid move by Qwen black. Move: Bg5
# New Move: Kg8
# Qwen CN move: Kg8 Move number: 46
# Qwen US move: d2d3 Move number: 47
# Qwen CN move: Re1 Move number: 48
# Qwen US move: g6e4 Move number: 49
# Qwen CN move: f7f5 Move number: 50
# Qwen US move: e4c6 Move number: 51
# Qwen CN move: b7c6 Move number: 52
# Qwen US move: Kc2 Move number: 53
# Qwen CN move: h8h2 Move number: 54
# Qwen US move: Kd3 Move number: 55
# Qwen CN move: Rhe2 Move number: 56
# Qwen US move: d3d4 Move number: 57
# Qwen CN move: e2g2 Move number: 58
# Qwen US move: Bd2 Move number: 59
# Qwen CN move: e1a1 Move number: 60
# Qwen US move: d2c3 Move number: 61
# Qwen CN move: g8f7 Move number: 62
# Qwen US move: d4c4 Move number: 63
# Qwen CN move: g2e2 Move number: 64
# Qwen US move: b2b4 Move number: 65
# Qwen CN move: a1c1 Move number: 66
# Qwen US move: Kd4 Move number: 67
# Qwen CN move: c1d1 Move number: 68
# Qwen US move: Bd2 Move number: 69
# Qwen CN move: d1d2 Move number: 70
# Qwen US move: Kc4 Move number: 71
# Qwen CN move: Re1 Move number: 72
# Invalid move by Qwen white. Move:  Kb3
# New Move: Kc3
# Qwen US move: Kc3 Move number: 73
# Qwen CN move: d2g2 Move number: 74
# Qwen US move: Kd4 Move number: 75
# Qwen CN move: g2g3 Move number: 76
# Qwen US move: b4b5 Move number: 77
# Qwen CN move: e1e4 Move number: 78
# Game 4 result: 0-1
#
#
# Starting game 5...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: Nf3+ Move number: 8
# Qwen US move: d1f3 Move number: 9
# Qwen CN move: d8f6 Move number: 10
# Qwen US move: f3e3 Move number: 11
# Qwen CN move: g7g6 Move number: 12
# Qwen US move: b1c3 Move number: 13
# Qwen CN move: f8h6 Move number: 14
# Qwen US move: e3g3 Move number: 15
# Qwen CN move: Nxe7 Move number: 16
# Qwen US move: c1h6 Move number: 17
# Qwen CN move: Qg5 Move number: 18
# Qwen US move: h6g5 Move number: 19
# Qwen CN move: Nxd5 Move number: 20
# Qwen US move: Nxd5 Move number: 21
# Qwen CN move: Rg8 Move number: 22
# Qwen US move: g3e5 Move number: 23
# Qwen CN move: e8f8 Move number: 24
# Qwen US move: g5e7 Move number: 25
# Qwen CN move: f8e8 Move number: 26
# Invalid move by Qwen white. Move: Bxc6
# New Move: h3
# Qwen US move: h3 Move number: 27
# Qwen CN move: f7f5 Move number: 28
# Qwen US move: e7a3 Move number: 29
# Qwen CN move: Kf7 Move number: 30
# Qwen US move: e5e7 Move number: 31
# Game 5 result: 1-0
#
#
# Starting game 6...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: Be7 Move number: 6
# Qwen US move: Bxc6 Move number: 7
# Qwen CN move: d7c6 Move number: 8
# Qwen US move: e1g1 Move number: 9
# Qwen CN move: Nf6 Move number: 10
# Qwen US move: f1e1 Move number: 11
# Qwen CN move: c8g4 Move number: 12
# Qwen US move: h2h3 Move number: 13
# Qwen CN move: g4h5 Move number: 14
# Qwen US move: g2g4 Move number: 15
# Qwen CN move: h5g6 Move number: 16
# Qwen US move: f3e5 Move number: 17
# Qwen CN move: Nxd5 Move number: 18
# Qwen US move: e4d5 Move number: 19
# Qwen CN move: Rg8 Move number: 20
# Qwen US move: d2d4 Move number: 21
# Qwen CN move: Bg5 Move number: 22
# Qwen US move: Nxf7+ Move number: 23
# Qwen CN move: Kf8 Move number: 24
# Qwen US move: f7d8 Move number: 25
# Qwen CN move: g5d8 Move number: 26
# Qwen US move: d5c6 Move number: 27
# Qwen CN move: d8f6 Move number: 28
# Qwen US move: Re8+ Move number: 29
# Qwen CN move: a8e8 Move number: 30
# Qwen US move: c6b7 Move number: 31
# Qwen CN move: Re1+ Move number: 32
# Qwen US move: d1e1 Move number: 33
# Qwen CN move: Bh5 Move number: 34
# Qwen US move: b7b8q Move number: 35
# Qwen CN move: f8f7 Move number: 36
# Qwen US move: b8c7 Move number: 37
# Qwen CN move: f7f8 Move number: 38
# Qwen US move: e1b4 Move number: 39
# Qwen CN move: Ke8 Move number: 40
# Qwen US move: b4b8 Move number: 41
# Qwen CN move: f6d8 Move number: 42
# Qwen US move: b8d8 Move number: 43
# Game 6 result: 1-0
#
#
# Starting game 7...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: d7d6 Move number: 4
# Qwen US move: Ng5 Move number: 5
# Qwen CN move: g8f6 Move number: 6
# Qwen US move: b1c3 Move number: 7
# Qwen CN move: Nxe4 Move number: 8
# Qwen US move: g5e4 Move number: 9
# Qwen CN move: e7e6 Move number: 10
# Qwen US move: f1b5 Move number: 11
# Qwen CN move: c8d7 Move number: 12
# Qwen US move: b5d7 Move number: 13
# Qwen CN move: Nxd7 Move number: 14
# Qwen US move: d2d3 Move number: 15
# Invalid move by Qwen black. Move: Nf3
# New Move: f6
# Qwen CN move: f6 Move number: 16
# Qwen US move: e1g1 Move number: 17
# Qwen CN move: d6d5 Move number: 18
# Qwen US move: Nxf6+ Move number: 19
# Qwen CN move: d7f6 Move number: 20
# Qwen US move: f1e1 Move number: 21
# Qwen CN move: d8d7 Move number: 22
# Qwen US move: c1g5 Move number: 23
# Invalid move by Qwen black. Move: Bg5
# New Move: Rc8
# Qwen CN move: Rc8 Move number: 24
# Qwen US move: d1f3 Move number: 25
# Qwen CN move: Rg8 Move number: 26
# Qwen US move: g5f6 Move number: 27
# Qwen CN move: g7f6 Move number: 28
# Qwen US move: c3d5 Move number: 29
# Qwen CN move: f8e7 Move number: 30
# Qwen US move: Nxe7 Move number: 31
# Qwen CN move: e8e7 Move number: 32
# Qwen US move: Qxb7 Move number: 33
# Invalid move by Qwen black. Move: Rg8
# New Move: Kf7
# Qwen CN move: Kf7 Move number: 34
# Qwen US move: b7d7 Move number: 35
# Qwen CN move: f7g6 Move number: 36
# Qwen US move: Qe8+ Move number: 37
# Qwen CN move: g8e8 Move number: 38
# Qwen US move: e1e4 Move number: 39
# Qwen CN move: e6e5 Move number: 40
# Qwen US move: g1f1 Move number: 41
# Qwen CN move: Rh8 Move number: 42
# Qwen US move: b2b3 Move number: 43
# Qwen CN move: Rhe8 Move number: 44
# Qwen US move: Rxe5 Move number: 45
# Qwen CN move: e8e5 Move number: 46
# Qwen US move: a1e1 Move number: 47
# Qwen CN move: Re2 Move number: 48
# Qwen US move: e1e2 Move number: 49
# Qwen CN move: f6f5 Move number: 50
# Qwen US move: e2e6 Move number: 51
# Qwen CN move: g6g5 Move number: 52
# Qwen US move: e6a6 Move number: 53
# Qwen CN move: h7h5 Move number: 54
# Qwen US move: a6a7 Move number: 55
# Invalid move by Qwen black. Move: Rb1
# New Move: Re8
# Qwen CN move: Re8 Move number: 56
# Qwen US move: a7a4 Move number: 57
# Invalid move by Qwen black. Move: Rxe8+ Kf7
# New Move: Rd8
# Qwen CN move: Rd8 Move number: 58
# Qwen US move: h2h4 Move number: 59
# Qwen CN move: Kf6 Move number: 60
# Qwen US move: a4c4 Move number: 61
# Qwen CN move: d8a8 Move number: 62
# Qwen US move: a2a4 Move number: 63
# Qwen CN move: f6e5 Move number: 64
# Qwen US move: Rxc5+ Move number: 65
# Qwen CN move: e5d4 Move number: 66
# Qwen US move: Rc8 Move number: 67
# Qwen CN move: Rxc8 Move number: 68
# Qwen US move: c2c4 Move number: 69
# Qwen CN move: d4d3 Move number: 70
# Qwen US move: Kg1 Move number: 71
# Qwen CN move: d3d4 Move number: 72
# Qwen US move: a4a5 Move number: 73
# Qwen CN move: c8b8 Move number: 74
# Qwen US move: c4c5 Move number: 75
# Qwen CN move: d4c5 Move number: 76
# Qwen US move: f2f3 Move number: 77
# Qwen CN move: b8b3 Move number: 78
# Qwen US move: Kh1 Move number: 79
# Qwen CN move: c5d4 Move number: 80
# Qwen US move: Kh2 Move number: 81
# Qwen CN move: b3a3 Move number: 82
# Qwen US move: Kh3 Move number: 83
# Qwen CN move: Rxa5 Move number: 84
# Qwen US move: Kg3 Move number: 85
# Qwen CN move: d4e3 Move number: 86
# Qwen US move: g3h3 Move number: 87
# Qwen CN move: e3f2 Move number: 88
# Qwen US move: h3h2 Move number: 89
# Invalid move by Qwen black. Move: Re8
# New Move: Re5
# Qwen CN move: Re5 Move number: 90
# Qwen US move: g2g3 Move number: 91
# Qwen CN move: Re8 Move number: 92
# Qwen US move: h2h3 Move number: 93
# Qwen CN move: e8g8 Move number: 94
# Qwen US move: g3g4 Move number: 95
# Qwen CN move: f5g4 Move number: 96
# Qwen US move: fxg4 Move number: 97
# Qwen CN move: g8g4 Move number: 98
# Invalid move by Qwen white. Move: Kh3
# New Move: Kh2
# Qwen US move: Kh2 Move number: 99
# Qwen CN move: g4h4 Move number: 100
# Game 7 result: 0-1
#
#
# Starting game 8...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: b1c3 Move number: 3
# Qwen CN move: a7a6 Move number: 4
# Qwen US move: g1f3 Move number: 5
# Qwen CN move: Nf6 Move number: 6
# Qwen US move: e4e5 Move number: 7
# Invalid move by Qwen black. Move: Nxe5
# New Move: d5
# Qwen CN move: d5 Move number: 8
# Qwen US move: e5f6 Move number: 9
# Qwen CN move: b8c6 Move number: 10
# Qwen US move: Nxd5 Move number: 11
# Qwen CN move: d8d5 Move number: 12
# Qwen US move: f6g7 Move number: 13
# Qwen CN move: f8g7 Move number: 14
# Qwen US move: c2c3 Move number: 15
# Qwen CN move: Bd4 Move number: 16
# Qwen US move: c3d4 Move number: 17
# Qwen CN move: Nxd4 Move number: 18
# Qwen US move: Ng5 Move number: 19
# Qwen CN move: d5e5 Move number: 20
# Qwen US move: f1e2 Move number: 21
# Invalid move by Qwen black. Move: Nh3
# New Move: a5
# Qwen CN move: a5 Move number: 22
# Qwen US move: g5f3 Move number: 23
# Qwen CN move: d4f3 Move number: 24
# Qwen US move: Kf1 Move number: 25
# Qwen CN move: f3d4 Move number: 26
# Qwen US move: d2d3 Move number: 27
# Qwen CN move: b7b6 Move number: 28
# Qwen US move: e2f3 Move number: 29
# Qwen CN move: Rg8 Move number: 30
# Qwen US move: f3a8 Move number: 31
# Qwen CN move: Rh8 Move number: 32
# Qwen US move: Bd5 Move number: 33
# Qwen CN move: e5d5 Move number: 34
# Qwen US move: c1e3 Move number: 35
# Qwen CN move: Rg8 Move number: 36
# Qwen US move: f2f3 Move number: 37
# Qwen CN move: c8a6 Move number: 38
# Qwen US move: f1f2 Move number: 39
# Qwen CN move: a6d3 Move number: 40
# Qwen US move: h1g1 Move number: 41
# Qwen CN move: d4c2 Move number: 42
# Qwen US move: d1d2 Move number: 43
# Qwen CN move: Qf3+ Move number: 44
# Qwen US move: g2f3 Move number: 45
# Qwen CN move: Rg2+ Move number: 46
# Qwen US move: g1g2 Move number: 47
# Qwen CN move: Kd7 Move number: 48
# Qwen US move: Bh6 Move number: 49
# Invalid move by Qwen black. Move: Be3
# New Move: Kc7
# Qwen CN move: Kc7 Move number: 50
# Qwen US move: h6f4 Move number: 51
# Qwen CN move: Kd8 Move number: 52
# Qwen US move: g2g8 Move number: 53
# Qwen CN move: d8d7 Move number: 54
# Qwen US move: d2d3 Move number: 55
# Qwen CN move: c2d4 Move number: 56
# Qwen US move: Qe2 Move number: 57
# Qwen CN move: d4e2 Move number: 58
# Qwen US move: Rh8 Move number: 59
# Invalid move by Qwen black. Move: Nh5
# New Move: Nd4
# Qwen CN move: Nd4 Move number: 60
# Qwen US move: h8h7 Move number: 61
# Qwen CN move: Ke8 Move number: 62
# Qwen US move: a1e1 Move number: 63
# Qwen CN move: e7e6 Move number: 64
# Qwen US move: h7h8 Move number: 65
# Qwen CN move: e8d7 Move number: 66
# Qwen US move: Rg8 Move number: 67
# Qwen CN move: a5a4 Move number: 68
# Qwen US move: Rg3 Move number: 69
# Qwen CN move: Nc2 Move number: 70
# Qwen US move: e1d1 Move number: 71
# Qwen CN move: d7e7 Move number: 72
# Qwen US move: Bd2 Move number: 73
# Qwen CN move: e6e5 Move number: 74
# Qwen US move: d2c3 Move number: 75
# Qwen CN move: a4a3 Move number: 76
# Qwen US move: c3e5 Move number: 77
# Qwen CN move: f7f6 Move number: 78
# Qwen US move: d1d2 Move number: 79
# Qwen CN move: a3b2 Move number: 80
# Qwen US move: Bf4 Move number: 81
# Qwen CN move: b2b1q Move number: 82
# Qwen US move: Bh6 Move number: 83
# Qwen CN move: c2b4 Move number: 84
# Invalid move by Qwen white. Move: Bh6
# New Move: Rd4
# Qwen US move: Rd4 Move number: 85
# Qwen CN move: c5d4 Move number: 86
# Qwen US move: a2a3 Move number: 87
# Qwen CN move: Qc1 Move number: 88
# Qwen US move: h6c1 Move number: 89
# Qwen CN move: b4d3 Move number: 90
# Qwen US move: f2e2 Move number: 91
# Qwen CN move: d3c1 Move number: 92
# Qwen US move: Kf1 Move number: 93
# Qwen CN move: d4d3 Move number: 94
# Invalid move by Qwen white. Move: Rh8
# New Move: Rg5
# Qwen US move: Rg5 Move number: 95
# Qwen CN move: f6g5 Move number: 96
# Qwen US move: Kf2 Move number: 97
# Qwen CN move: d3d2 Move number: 98
# Qwen US move: f3f4 Move number: 99
# Qwen CN move: g5f4 Move number: 100
# Qwen US move: f2f3 Move number: 101
# Qwen CN move: Ke6 Move number: 102
# Qwen US move: f3f4 Move number: 103
# Qwen CN move: Kf7 Move number: 104
# Qwen US move: Kg5 Move number: 105
# Qwen CN move: d2d1q Move number: 106
# Qwen US move: g5f4 Move number: 107
# Qwen CN move: Qe1 Move number: 108
# Qwen US move: h2h4 Move number: 109
# Qwen CN move: e1f1 Move number: 110
# Qwen US move: f4e3 Move number: 111
# Qwen CN move: f1e2 Move number: 112
# Qwen US move: e3f4 Move number: 113
# Qwen CN move: c1d3 Move number: 114
# Qwen US move: f4g3 Move number: 115
# Qwen CN move: Kg6 Move number: 116
# Qwen US move: g3h3 Move number: 117
# Qwen CN move: Nf4+ Move number: 118
# Qwen US move: h3g3 Move number: 119
# Qwen CN move: Kg7 Move number: 120
# Qwen US move: Kxf4 Move number: 121
# Invalid move by Qwen black. Move: Kf5
# New Move: Kf6
# Qwen CN move: Kf6 Move number: 122
# Qwen US move: h4h5 Move number: 123
# Qwen CN move: Qe1 Move number: 124
# Qwen US move: h5h6 Move number: 125
# Qwen CN move: e1d2 Move number: 126
# Qwen US move: f4e4 Move number: 127
# Qwen CN move: d2h6 Move number: 128
# Qwen US move: Kd5 Move number: 129
# Qwen CN move: h6d2 Move number: 130
# Qwen US move: Kc6 Move number: 131
# Qwen CN move: Kf7 Move number: 132
# Qwen US move: c6b6 Move number: 133
# Qwen CN move: f7e8 Move number: 134
# Qwen US move: Kc7 Move number: 135
# Qwen CN move: d2d7 Move number: 136
# Qwen US move: c7b6 Move number: 137
# Qwen CN move: e8d8 Move number: 138
# Qwen US move: b6c5 Move number: 139
# Qwen CN move: d7g4 Move number: 140
# Qwen US move: a3a4 Move number: 141
# Qwen CN move: g4f5 Move number: 142
# Qwen US move: Kc6 Move number: 143
# Qwen CN move: f5d7 Move number: 144
# Qwen US move: Kb6 Move number: 145
# Qwen CN move: d7d5 Move number: 146
# Invalid move by Qwen white. Move: Kb7
# New Move: a5
# Qwen US move: a5 Move number: 147
# Qwen CN move: d8c8 Move number: 148
# Qwen US move: a5a6 Move number: 149
# Qwen CN move: Qd1 Move number: 150
# Qwen US move: a6a7 Move number: 151
# Qwen CN move: d1g1 Move number: 152
# Qwen US move: b6c6 Move number: 153
# Qwen CN move: g1a7 Move number: 154
# Qwen US move: Kd6 Move number: 155
# Qwen CN move: a7e3 Move number: 156
# Qwen US move: Kc6 Move number: 157
# Qwen CN move: Qe1+ Move number: 158
# Qwen US move: c6d5 Move number: 159
# Qwen CN move: c8d7 Move number: 160
# Qwen US move: Kc5 Move number: 161
# Qwen CN move: e1e4 Move number: 162
# Qwen US move: c5b5 Move number: 163
# Qwen CN move: e4d4 Move number: 164
# Qwen US move: b5a6 Move number: 165
# Qwen CN move: d4b4 Move number: 166
# Qwen US move: a6a7 Move number: 167
# Qwen CN move: d7c7 Move number: 168
# Invalid move by Qwen white. Move:  Kb5
# New Move: Ka8
# Qwen US move: Ka8 Move number: 169
# Qwen CN move: b4a3 Move number: 170
# Game 8 result: 0-1
#
#
# Starting game 9...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Invalid move by Qwen black. Move: Nc6
# New Move: g5
# Qwen CN move: g5 Move number: 6
# Qwen US move: f3g5 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: Nxe6 Move number: 9
# Qwen CN move: d7e6 Move number: 10
# Qwen US move: b5c6 Move number: 11
# Qwen CN move: b7c6 Move number: 12
# Qwen US move: d1e2 Move number: 13
# Qwen CN move: Qd4 Move number: 14
# Qwen US move: b1c3 Move number: 15
# Qwen CN move: Qd5 Move number: 16
# Qwen US move: Nxd5 Move number: 17
# Qwen CN move: c6d5 Move number: 18
# Qwen US move: d2d4 Move number: 19
# Invalid move by Qwen black. Move: d5
# New Move: h5
# Qwen CN move: h5 Move number: 20
# Qwen US move: d4c5 Move number: 21
# Qwen CN move: f8g7 Move number: 22
# Qwen US move: Qd2 Move number: 23
# Qwen CN move: d5e4 Move number: 24
# Qwen US move: d2a5 Move number: 25
# Qwen CN move: c8d7 Move number: 26
# Qwen US move: c1g5 Move number: 27
# Qwen CN move: Bh6 Move number: 28
# Qwen US move: g5h6 Move number: 29
# Qwen CN move: Rg8 Move number: 30
# Qwen US move: Bg5 Move number: 31
# Qwen CN move: g8g5 Move number: 32
# Qwen US move: e1c1 Move number: 33
# Qwen CN move: Rd5 Move number: 34
# Qwen US move: a5c3 Move number: 35
# Qwen CN move: e8f8 Move number: 36
# Qwen US move: c5c6 Move number: 37
# Qwen CN move: d7e8 Move number: 38
# Qwen US move: c6c7 Move number: 39
# Qwen CN move: e8d7 Move number: 40
# Qwen US move: d1d5 Move number: 41
# Qwen CN move: Rd8 Move number: 42
# Qwen US move: c7d8q Move number: 43
# Qwen CN move: Kg7 Move number: 44
# Qwen US move: d5g5 Move number: 45
# Qwen CN move: Kh7 Move number: 46
# Qwen US move: Qxe7 Move number: 47
# Invalid move by Qwen black. Move: Qxe7
# New Move: Bc8
# Qwen CN move: Bc8 Move number: 48
# Qwen US move: e7f7 Move number: 49
# Invalid move by Qwen black. Move: Qxf8+
# New Move: Kh8
# Qwen CN move: Kh8 Move number: 50
# Qwen US move: c3f6 Move number: 51
# Game 9 result: 1-0
#
#
# Starting game 10...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: d7d6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Qwen CN move: Nc6 Move number: 6
# Qwen US move: d4d5 Move number: 7
# Qwen CN move: Nf6 Move number: 8
# Qwen US move: Nh4 Move number: 9
# Qwen CN move: c6b8 Move number: 10
# Qwen US move: b1c3 Move number: 11
# Qwen CN move: Nxd5 Move number: 12
# Qwen US move: f1b5 Move number: 13
# Qwen CN move: b8d7 Move number: 14
# Qwen US move: e4d5 Move number: 15
# Qwen CN move: a7a6 Move number: 16
# Qwen US move: b5d7 Move number: 17
# Qwen CN move: c8d7 Move number: 18
# Qwen US move: e1g1 Move number: 19
# Invalid move by Qwen black. Move: Nxe6
# New Move: e6
# Qwen CN move: e6 Move number: 20
# Qwen US move: d5e6 Move number: 21
# Qwen CN move: d7e6 Move number: 22
# Qwen US move: Nf3 Move number: 23
# Qwen CN move: h7h6 Move number: 24
# Qwen US move: c3d5 Move number: 25
# Qwen CN move: g7g5 Move number: 26
# Qwen US move: a2a4 Move number: 27
# Qwen CN move: Bxd5 Move number: 28
# Qwen US move: d1d5 Move number: 29
# Qwen CN move: Qf6 Move number: 30
# Qwen US move: Qxf7+ Move number: 31
# Qwen CN move: e8f7 Move number: 32
# Qwen US move: a1a3 Move number: 33
# Qwen CN move: Rg8 Move number: 34
# Qwen US move: a3b3 Move number: 35
# Qwen CN move: a8e8 Move number: 36
# Qwen US move: b3b7 Move number: 37
# Qwen CN move: e8e7 Move number: 38
# Qwen US move: b7b6 Move number: 39
# Qwen CN move: f8g7 Move number: 40
# Qwen US move: f1d1 Move number: 41
# Qwen CN move: Rd7 Move number: 42
# Qwen US move: d1d5 Move number: 43
# Invalid move by Qwen black. Move: Rd6
# New Move: Bh8
# Qwen CN move: Bh8 Move number: 44
# Qwen US move: c1e3 Move number: 45
# Invalid move by Qwen black. Move: Rd4
# New Move: Rg7
# Qwen CN move: Rg7 Move number: 46
# Qwen US move: e3c5 Move number: 47
# Qwen CN move: Rd8 Move number: 48
# Qwen US move: d5d6 Move number: 49
# Qwen CN move: d8d6 Move number: 50
# Qwen US move: c5d6 Move number: 51
# Qwen CN move: f6d8 Move number: 52
# Qwen US move: Bf4 Move number: 53
# Qwen CN move: d8d1 Move number: 54
# Qwen US move: Ne1 Move number: 55
# Qwen CN move: Qxe1# Move number: 56
# Game 10 result: 0-1
#
#
# Starting game 11...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen US move: b5a4 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: e1g1 Move number: 9
# Qwen CN move: f6e4 Move number: 10
# Qwen US move: Bxc6 Move number: 11
# Qwen CN move: d7c6 Move number: 12
# Qwen US move: Ng5 Move number: 13
# Qwen CN move: e4g5 Move number: 14
# Qwen US move: Nc3 Move number: 15
# Qwen CN move: Bd6 Move number: 16
# Invalid move by Qwen white. Move: Nh3
# New Move: h4
# Qwen US move: h4 Move number: 17
# Qwen CN move: g5e6 Move number: 18
# Qwen US move: h4h5 Move number: 19
# Invalid move by Qwen black. Move: Nh3
# New Move: Qf6
# Qwen CN move: Qf6 Move number: 20
# Qwen US move: d2d4 Move number: 21
# Qwen CN move: Qf3 Move number: 22
# Qwen US move: g2f3 Move number: 23
# Qwen CN move: e6d4 Move number: 24
# Qwen US move: c3e4 Move number: 25
# Qwen CN move: c8h3 Move number: 26
# Qwen US move: Nf6+ Move number: 27
# Qwen CN move: g7f6 Move number: 28
# Qwen US move: Qd2 Move number: 29
# Qwen CN move: Rg8+ Move number: 30
# Qwen US move: g1h2 Move number: 31
# Qwen CN move: h3f1 Move number: 32
# Qwen US move: Qe2 Move number: 33
# Qwen CN move: f1e2 Move number: 34
# Qwen US move: c1e3 Move number: 35
# Qwen CN move: d4f3 Move number: 36
# Qwen US move: h2h1 Move number: 37
# Qwen CN move: f3d4 Move number: 38
# Qwen US move: e3d4 Move number: 39
# Qwen CN move: e2f3 Move number: 40
# Qwen US move: Kh2 Move number: 41
# Qwen CN move: e5d4 Move number: 42
# Qwen US move: Kh3 Move number: 43
# Qwen CN move: g8g5 Move number: 44
# Qwen US move: Kh4 Move number: 45
# Qwen CN move: Rg8+ Move number: 46
# Qwen US move: Rf1 Move number: 47
# Qwen CN move: g8g4 Move number: 48
# Qwen US move: h4h3 Move number: 49
# Qwen CN move: f6f5 Move number: 50
# Qwen US move: f1e1 Move number: 51
# Qwen CN move: Re4 Move number: 52
# Qwen US move: e1e4 Move number: 53
# Qwen CN move: f5e4 Move number: 54
# Qwen US move: Kh4 Move number: 55
# Qwen CN move: e8c8 Move number: 56
# Qwen US move: Kg5 Move number: 57
# Qwen CN move: d6e7 Move number: 58
# Qwen US move: g5h6 Move number: 59
# Qwen CN move: d8d6 Move number: 60
# Qwen US move: h6h7 Move number: 61
# Qwen CN move: f3h5 Move number: 62
# Qwen US move: f3 Move number: 63
# Qwen CN move: e4f3 Move number: 64
# Qwen US move: c2c4 Move number: 65
# Qwen CN move: f3f2 Move number: 66
# Qwen US move: b2b4 Move number: 67
# Qwen CN move: f2f1q Move number: 68
# Qwen US move: b4b5 Move number: 69
# Qwen CN move: f1d3 Move number: 70
# Qwen US move: Kh8 Move number: 71
# Qwen CN move: e7f6 Move number: 72
# Qwen US move: h8g8 Move number: 73
# Qwen CN move: Rd8# Move number: 74
# Game 11 result: 0-1
#
#
# Starting game 12...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Qwen CN move: d5 Move number: 6
# Qwen US move: e4d5 Move number: 7
# Qwen CN move: Nxd5 Move number: 8
# Qwen US move: Ng5 Move number: 9
# Qwen CN move: f8e7 Move number: 10
# Invalid move by Qwen white. Move: Nxe5
# New Move: Ba6
# Qwen US move: Ba6 Move number: 11
# Qwen CN move: b8a6 Move number: 12
# Invalid move by Qwen white. Move: Nxe5
# New Move: Rf1
# Qwen US move: Rf1 Move number: 13
# Qwen CN move: e7g5 Move number: 14
# Qwen US move: Qe2 Move number: 15
# Qwen CN move: g5c1 Move number: 16
# Qwen US move: c2c4 Move number: 17
# Qwen CN move: d5f4 Move number: 18
# Qwen US move: e2e5 Move number: 19
# Qwen CN move: Qxe7 Move number: 20
# Qwen US move: e5e7 Move number: 21
# Qwen CN move: Kxe7 Move number: 22
# Invalid move by Qwen white. Move: Nh3
# New Move: Nc3
# Qwen US move: Nc3 Move number: 23
# Qwen CN move: c1b2 Move number: 24
# Qwen US move: Nd5+ Move number: 25
# Qwen CN move: f4d5 Move number: 26
# Qwen US move: c4d5 Move number: 27
# Qwen CN move: b2a1 Move number: 28
# Qwen US move: e1d2 Move number: 29
# Qwen CN move: Rg8 Move number: 30
# Qwen US move: f1a1 Move number: 31
# Qwen CN move: Rb8 Move number: 32
# Qwen US move: Ke1 Move number: 33
# Qwen CN move: a6b4 Move number: 34
# Qwen US move: e1f1 Move number: 35
# Invalid move by Qwen black. Move: Nh4
# New Move: Bg4
# Qwen CN move: Bg4 Move number: 36
# Qwen US move: a1e1 Move number: 37
# Qwen CN move: Kd7 Move number: 38
# Qwen US move: e1e4 Move number: 39
# Qwen CN move: g4f5 Move number: 40
# Qwen US move: e4e5 Move number: 41
# Qwen CN move: f5d3 Move number: 42
# Qwen US move: Re2 Move number: 43
# Qwen CN move: g8e8 Move number: 44
# Invalid move by Qwen white. Move: Re4
# New Move: a4
# Qwen US move: a4 Move number: 45
# Qwen CN move: d3e2 Move number: 46
# Qwen US move: f1g1 Move number: 47
# Qwen CN move: Re3 Move number: 48
# Qwen US move: f2e3 Move number: 49
# Qwen CN move: e2d3 Move number: 50
# Qwen US move: g1f2 Move number: 51
# Qwen CN move: b4d5 Move number: 52
# Qwen US move: h4 Move number: 53
# Qwen CN move: b8e8 Move number: 54
# Qwen US move: g3 Move number: 55
# Invalid move by Qwen black. Move: Re1
# New Move: a6
# Qwen CN move: a6 Move number: 56
# Qwen US move: g3g4 Move number: 57
# Qwen CN move: e8e3 Move number: 58
# Qwen US move: h5 Move number: 59
# Qwen CN move: a6a5 Move number: 60
# Qwen US move: f2g2 Move number: 61
# Qwen CN move: d7d6 Move number: 62
# Qwen US move: g4g5 Move number: 63
# Qwen CN move: Re1+ Move number: 64
# Qwen US move: g2g3 Move number: 65
# Invalid move by Qwen black. Move: Nh2
# New Move: f5
# Qwen CN move: f5 Move number: 66
# Qwen US move: g5g6 Move number: 67
# Qwen CN move: h7h6 Move number: 68
# Qwen US move: Kh3 Move number: 69
# Qwen CN move: e1f1 Move number: 70
# Qwen US move: h3h2 Move number: 71
# Qwen CN move: f5f4 Move number: 72
# Qwen US move: h2h3 Move number: 73
# Invalid move by Qwen black. Move: Kf2
# New Move: Nb4
# Qwen CN move: Nb4 Move number: 74
# Qwen US move: h3g2 Move number: 75
# Qwen CN move: Ke6 Move number: 76
# Qwen US move: g2h2 Move number: 77
# Qwen CN move: b4d5 Move number: 78
# Qwen US move: h2g2 Move number: 79
# Qwen CN move: d5e3 Move number: 80
# Qwen US move: Kh2 Move number: 81
# Qwen CN move: e6d5 Move number: 82
# Qwen US move: Kh3 Move number: 83
# Qwen CN move: Rf3+ Move number: 84
# Qwen US move: h3h2 Move number: 85
# Qwen CN move: f3f1 Move number: 86
# Qwen US move: Kh3 Move number: 87
# Qwen CN move: f1h1 Move number: 88
# Game 12 result: 0-1
#
#
# Starting game 13...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: d7d6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Qwen CN move: g8f6 Move number: 6
# Qwen US move: Nbd2 Move number: 7
# Qwen CN move: c5d4 Move number: 8
# Qwen US move: Nxd4 Move number: 9
# Qwen CN move: g7g6 Move number: 10
# Qwen US move: Nc6 Move number: 11
# Qwen CN move: Nxc6 Move number: 12
# Qwen US move: Nc4 Move number: 13
# Qwen CN move: c8e6 Move number: 14
# Qwen US move: c1f4 Move number: 15
# Qwen CN move: f8g7 Move number: 16
# Qwen US move: d1f3 Move number: 17
# Qwen CN move: Nxe4 Move number: 18
# Qwen US move: f3e4 Move number: 19
# Qwen CN move: d6d5 Move number: 20
# Qwen US move: Bd3 Move number: 21
# Qwen CN move: d5e4 Move number: 22
# Qwen US move: Bd2 Move number: 23
# Qwen CN move: e4d3 Move number: 24
# Qwen US move: c2d3 Move number: 25
# Qwen CN move: e8g8 Move number: 26
# Qwen US move: h2h4 Move number: 27
# Qwen CN move: f7f6 Move number: 28
# Qwen US move: Nxd6 Move number: 29
# Qwen CN move: d8d6 Move number: 30
# Qwen US move: h4h5 Move number: 31
# Qwen CN move: g6h5 Move number: 32
# Qwen US move: h1h5 Move number: 33
# Qwen CN move: f8f7 Move number: 34
# Qwen US move: h5h4 Move number: 35
# Qwen CN move: d6e5 Move number: 36
# Qwen US move: Kf1 Move number: 37
# Qwen CN move: e5d5 Move number: 38
# Qwen US move: f1g1 Move number: 39
# Invalid move by Qwen black. Move: Rhxh8
# New Move: h6
# Qwen CN move: h6 Move number: 40
# Qwen US move: a1e1 Move number: 41
# Qwen CN move: c6e5 Move number: 42
# Qwen US move: Rxh6 Move number: 43
# Qwen CN move: g7h6 Move number: 44
# Qwen US move: d2h6 Move number: 45
# Qwen CN move: f7h7 Move number: 46
# Qwen US move: d3d4 Move number: 47
# Invalid move by Qwen black. Move: Qe5
# New Move: a6
# Qwen CN move: a6 Move number: 48
# Qwen US move: d4e5 Move number: 49
# Qwen CN move: h7h6 Move number: 50
# Invalid move by Qwen white. Move: Rxe8
# New Move: Re2
# Qwen US move: Re2 Move number: 51
# Qwen CN move: d5d1 Move number: 52
# Qwen US move: Re1 Move number: 53
# Qwen CN move: d1e1 Move number: 54
# Game 13 result: 0-1
#
#
# Starting game 14...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: f1c4 Move number: 5
# Qwen CN move: Nf6 Move number: 6
# Qwen US move: Bxf7+ Move number: 7
# Qwen CN move: e8f7 Move number: 8
# Qwen US move: d2d4 Move number: 9
# Qwen CN move: Be7 Move number: 10
# Qwen US move: d4d5 Move number: 11
# Qwen CN move: c6b8 Move number: 12
# Qwen US move: f3e5 Move number: 13
# Qwen CN move: f7g8 Move number: 14
# Qwen US move: b1c3 Move number: 15
# Qwen CN move: e7b4 Move number: 16
# Qwen US move: d1d4 Move number: 17
# Qwen CN move: Nxd5 Move number: 18
# Qwen US move: d4d5 Move number: 19
# Invalid move by Qwen black. Move: Nh3
# New Move: Kf8
# Qwen CN move: Kf8 Move number: 20
# Qwen US move: d5f7 Move number: 21
# Game 14 result: 1-0
#
#
# Starting game 15...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: f3e5 Move number: 5
# Invalid move by Qwen black. Move: Nf3
# New Move: a6
# Qwen CN move: a6 Move number: 6
# Qwen US move: f1c4 Move number: 7
# Qwen CN move: d7d5 Move number: 8
# Invalid move by Qwen white. Move: Nxe5
# New Move: Bxa6
# Qwen US move: Bxa6 Move number: 9
# Qwen CN move: b8a6 Move number: 10
# Qwen US move: Nc3 Move number: 11
# Qwen CN move: d5e4 Move number: 12
# Qwen US move: d2d4 Move number: 13
# Qwen CN move: e4d3 Move number: 14
# Qwen US move: e5d3 Move number: 15
# Invalid move by Qwen black. Move: Nf3
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 16
# Qwen US move: d3e5 Move number: 17
# Invalid move by Qwen black. Move: Nxe6
# New Move: Ke6
# Qwen CN move: Ke6 Move number: 18
# Qwen US move: d1d8 Move number: 19
# Qwen CN move: a6b4 Move number: 20
# Qwen US move: Qe7+ Move number: 21
# Qwen CN move: e6e7 Move number: 22
# Qwen US move: e1g1 Move number: 23
# Qwen CN move: c7c6 Move number: 24
# Qwen US move: c1g5 Move number: 25
# Qwen CN move: Rg8 Move number: 26
# Qwen US move: a1e1 Move number: 27
# Qwen CN move: Bf5 Move number: 28
# Qwen US move: Bh6 Move number: 29
# Qwen CN move: g7h6 Move number: 30
# Qwen US move: e5c6 Move number: 31
# Invalid move by Qwen black. Move: Nxb4
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 32
# Qwen US move: c6e5 Move number: 33
# Invalid move by Qwen black. Move: Nh3
# New Move: Ke6
# Qwen CN move: Ke6 Move number: 34
# Qwen US move: e5c4 Move number: 35
# Qwen CN move: f6e4 Move number: 36
# Qwen US move: Nd6 Move number: 37
# Qwen CN move: e6d6 Move number: 38
# Qwen US move: c3e4 Move number: 39
# Qwen CN move: d6c6 Move number: 40
# Qwen US move: e4f6 Move number: 41
# Qwen CN move: Rh8 Move number: 42
# Qwen US move: a2a3 Move number: 43
# Qwen CN move: Rg8 Move number: 44
# Qwen US move: Ng4 Move number: 45
# Qwen CN move: f5g4 Move number: 46
# Qwen US move: a3b4 Move number: 47
# Qwen CN move: Rb8 Move number: 48
# Qwen US move: e1e4 Move number: 49
# Qwen CN move: g4h3 Move number: 50
# Qwen US move: g2g3 Move number: 51
# Qwen CN move: h3f1 Move number: 52
# Qwen US move: g1f1 Move number: 53
# Qwen CN move: c6b6 Move number: 54
# Qwen US move: e4f4 Move number: 55
# Qwen CN move: Rg7 Move number: 56
# Qwen US move: f4f6 Move number: 57
# Qwen CN move: Bd6 Move number: 58
# Qwen US move: f6d6 Move number: 59
# Qwen CN move: Kb5 Move number: 60
# Qwen US move: Rd8 Move number: 61
# Qwen CN move: Rxd8 Move number: 62
# Qwen US move: f1g2 Move number: 63
# Qwen CN move: g7g8 Move number: 64
# Qwen US move: h2h4 Move number: 65
# Qwen CN move: h6h5 Move number: 66
# Qwen US move: Kh1 Move number: 67
# Qwen CN move: d8c8 Move number: 68
# Qwen US move: c2c3 Move number: 69
# Qwen CN move: Rg4 Move number: 70
# Qwen US move: h1h2 Move number: 71
# Qwen CN move: Rh8 Move number: 72
# Qwen US move: f2f3 Move number: 73
# Qwen CN move: g4g8 Move number: 74
# Qwen US move: g3g4 Move number: 75
# Qwen CN move: b5c4 Move number: 76
# Qwen US move: h2g3 Move number: 77
# Qwen CN move: Rf8 Move number: 78
# Qwen US move: g4h5 Move number: 79
# Qwen CN move: h8g8 Move number: 80
# Qwen US move: g3f4 Move number: 81
# Qwen CN move: f7f5 Move number: 82
# Qwen US move: f4e5 Move number: 83
# Qwen CN move: f5f4 Move number: 84
# Qwen US move: e5d6 Move number: 85
# Qwen CN move: Rh8 Move number: 86
# Qwen US move: b4b5 Move number: 87
# Qwen CN move: h8g8 Move number: 88
# Qwen US move: Ke6 Move number: 89
# Qwen CN move: c4b3 Move number: 90
# Qwen US move: c3c4 Move number: 91
# Qwen CN move: b3c4 Move number: 92
# Qwen US move: e6e5 Move number: 93
# Qwen CN move: c4b3 Move number: 94
# Qwen US move: Ke6 Move number: 95
# Qwen CN move: b3b2 Move number: 96
# Qwen US move: Kd7 Move number: 97
# Invalid move by Qwen black. Move: Rg8
# New Move: Ka2
# Qwen CN move: Ka2 Move number: 98
# Qwen US move: d7c7 Move number: 99
# Qwen CN move: f8f6 Move number: 100
# Qwen US move: Kd7 Move number: 101
# Qwen CN move: g8g7 Move number: 102
# Qwen US move: d7e8 Move number: 103
# Qwen CN move: h7h6 Move number: 104
# Qwen US move: b5b6 Move number: 105
# Qwen CN move: Rg8+ Move number: 106
# Qwen US move: e8e7 Move number: 107
# Qwen CN move: Rg7+ Move number: 108
# Qwen US move: Ke8 Move number: 109
# Qwen CN move: f6f5 Move number: 110
# Qwen US move: e8d8 Move number: 111
# Qwen CN move: Rg8+ Move number: 112
# Qwen US move: d8e7 Move number: 113
# Qwen CN move: a2b2 Move number: 114
# Qwen US move: e7d6 Move number: 115
# Qwen CN move: g8g7 Move number: 116
# Qwen US move: d6e6 Move number: 117
# Qwen CN move: g7f7 Move number: 118
# Qwen US move: e6d6 Move number: 119
# Qwen CN move: Kc1 Move number: 120
# Qwen US move: d6e6 Move number: 121
# Qwen CN move: Re5+ Move number: 122
# Qwen US move: e6e5 Move number: 123
# Qwen CN move: Rf8 Move number: 124
# Qwen US move: Ke6 Move number: 125
# Qwen CN move: Rd8 Move number: 126
# Qwen US move: e6e5 Move number: 127
# Qwen CN move: c1d1 Move number: 128
# Qwen US move: e5f4 Move number: 129
# Qwen CN move: d8d5 Move number: 130
# Qwen US move: Kg3 Move number: 131
# Qwen CN move: d1e2 Move number: 132
# Qwen US move: g3f4 Move number: 133
# Qwen CN move: Rd1 Move number: 134
# Qwen US move: f4e4 Move number: 135
# Qwen CN move: Kf2 Move number: 136
# Qwen US move: f3f4 Move number: 137
# Qwen CN move: f2g3 Move number: 138
# Qwen US move: f4f5 Move number: 139
# Qwen CN move: g3h4 Move number: 140
# Qwen US move: f5f6 Move number: 141
# Qwen CN move: Kg4 Move number: 142
# Qwen US move: e4e5 Move number: 143
# Qwen CN move: d1f1 Move number: 144
# Qwen US move: e5e6 Move number: 145
# Qwen CN move: g4h5 Move number: 146
# Qwen US move: e6f7 Move number: 147
# Qwen CN move: h5g5 Move number: 148
# Qwen US move: f7e6 Move number: 149
# Qwen CN move: Kf4 Move number: 150
# Qwen US move: e6d6 Move number: 151
# Qwen CN move: f4g5 Move number: 152
# Qwen US move: Kc7 Move number: 153
# Qwen CN move: f1f6 Move number: 154
# Qwen US move: c7b7 Move number: 155
# Qwen CN move: f6b6 Move number: 156
# Qwen US move: b7b6 Move number: 157
# Qwen CN move: h6h5 Move number: 158
# Qwen US move: Kc7 Move number: 159
# Qwen CN move: h5h4 Move number: 160
# Qwen US move: Kd8 Move number: 161
# Qwen CN move: Kf6 Move number: 162
# Qwen US move: d8c8 Move number: 163
# Qwen CN move: Kg7 Move number: 164
# Qwen US move: c8b7 Move number: 165
# Qwen CN move: Kh6 Move number: 166
# Qwen US move: b7c7 Move number: 167
# Qwen CN move: h6g6 Move number: 168
# Qwen US move: Kd8 Move number: 169
# Qwen CN move: h4h3 Move number: 170
# Qwen US move: Kc8 Move number: 171
# Qwen CN move: g6g5 Move number: 172
# Qwen US move: c8d7 Move number: 173
# Qwen CN move: g5f4 Move number: 174
# Qwen US move: d7c7 Move number: 175
# Qwen CN move: f4e3 Move number: 176
# Qwen US move: c7d6 Move number: 177
# Qwen CN move: h3h2 Move number: 178
# Qwen US move: Kc7 Move number: 179
# Qwen CN move: e3f3 Move number: 180
# Qwen US move: c7d8 Move number: 181
# Qwen CN move: f3f2 Move number: 182
# Qwen US move: d8d7 Move number: 183
# Qwen CN move: f2e3 Move number: 184
# Qwen US move: Ke7 Move number: 185
# Qwen CN move: e3f4 Move number: 186
# Qwen US move: Kd8 Move number: 187
# Qwen CN move: Kg3 Move number: 188
# Qwen US move: Kc7 Move number: 189
# Qwen CN move: g3f2 Move number: 190
# Qwen US move: Kd8 Move number: 191
# Invalid move by Qwen black. Move: Kf7
# New Move: h1=B
# Qwen CN move: h1=B Move number: 192
# Game 15 result: 1/2-1/2
#
#
# Starting game 16...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen US move: b5a4 Move number: 7
# Qwen CN move: Nge7 Move number: 8
# Qwen US move: c2c3 Move number: 9
# Qwen CN move: Nf5 Move number: 10
# Qwen US move: Bxc6 Move number: 11
# Qwen CN move: d7c6 Move number: 12
# Qwen US move: e4f5 Move number: 13
# Qwen CN move: Qg5 Move number: 14
# Qwen US move: f3g5 Move number: 15
# Qwen CN move: c8f5 Move number: 16
# Qwen US move: d1f3 Move number: 17
# Qwen CN move: f5g6 Move number: 18
# Qwen US move: f3h3 Move number: 19
# Qwen CN move: f8e7 Move number: 20
# Qwen US move: g5f3 Move number: 21
# Qwen CN move: Be4 Move number: 22
# Qwen US move: b1a3 Move number: 23
# Qwen CN move: Bxa3 Move number: 24
# Qwen US move: f3g5 Move number: 25
# Qwen CN move: Bg6 Move number: 26
# Qwen US move: Nxf7 Move number: 27
# Qwen CN move: Rg8 Move number: 28
# Qwen US move: f7e5 Move number: 29
# Qwen CN move: a8d8 Move number: 30
# Qwen US move: d2d4 Move number: 31
# Qwen CN move: a3e7 Move number: 32
# Qwen US move: Nf7 Move number: 33
# Qwen CN move: e8f7 Move number: 34
# Qwen US move: e1g1 Move number: 35
# Qwen CN move: Rd6 Move number: 36
# Qwen US move: f1e1 Move number: 37
# Qwen CN move: Rd5 Move number: 38
# Qwen US move: h3e6 Move number: 39
# Qwen CN move: f7f8 Move number: 40
# Qwen US move: e6e7 Move number: 41
# Game 16 result: 1-0
#
#
# Starting game 17...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen US move: b5a4 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: e1g1 Move number: 9
# Qwen CN move: b7b5 Move number: 10
# Qwen US move: Bxb5 Move number: 11
# Qwen CN move: a6b5 Move number: 12
# Qwen US move: b1c3 Move number: 13
# Qwen CN move: Bb7 Move number: 14
# Qwen US move: c3b5 Move number: 15
# Qwen CN move: f8e7 Move number: 16
# Qwen US move: c2c4 Move number: 17
# Qwen CN move: f6e4 Move number: 18
# Qwen US move: f1e1 Move number: 19
# Qwen CN move: Nd4 Move number: 20
# Qwen US move: f3d4 Move number: 21
# Qwen CN move: Rxa2 Move number: 22
# Qwen US move: Nxc7+ Move number: 23
# Qwen CN move: d8c7 Move number: 24
# Qwen US move: Re2 Move number: 25
# Qwen CN move: a2a1 Move number: 26
# Qwen US move: Re3 Move number: 27
# Qwen CN move: e5d4 Move number: 28
# Qwen US move: e3e1 Move number: 29
# Qwen CN move: Bd6 Move number: 30
# Qwen US move: d2d3 Move number: 31
# Qwen CN move: Qxc4 Move number: 32
# Qwen US move: d3c4 Move number: 33
# Qwen CN move: e8g8 Move number: 34
# Qwen US move: e1f1 Move number: 35
# Qwen CN move: d6e5 Move number: 36
# Qwen US move: d1e1 Move number: 37
# Qwen CN move: d7d6 Move number: 38
# Qwen US move: e1b4 Move number: 39
# Invalid move by Qwen black. Move: Bd6
# New Move: Ba8
# Qwen CN move: Ba8 Move number: 40
# Qwen US move: f2f3 Move number: 41
# Qwen CN move: Bd5 Move number: 42
# Qwen US move: c4d5 Move number: 43
# Qwen CN move: e4c5 Move number: 44
# Qwen US move: b4c4 Move number: 45
# Qwen CN move: f8a8 Move number: 46
# Qwen US move: Qxc5 Move number: 47
# ...
# Qwen US move: d5d2 Move number: 143
# Qwen CN move: f2g3 Move number: 144
# Qwen US move: d2e3 Move number: 145
# Qwen CN move: g3g4 Move number: 146
# Qwen US move: c1c4 Move number: 147
# Game 95 result: 1-0
#
#
# Starting game 96...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Qwen CN move: d5 Move number: 6
# Qwen US move: Nfd2 Move number: 7
# Qwen CN move: Nf6 Move number: 8
# Qwen US move: d4e5 Move number: 9
# Qwen CN move: c6e5 Move number: 10
# Qwen US move: e4d5 Move number: 11
# Qwen CN move: f6d5 Move number: 12
# Qwen US move: Nf3 Move number: 13
# Qwen CN move: c8g4 Move number: 14
# Qwen US move: f1b5 Move number: 15
# Qwen CN move: Bxd7 Move number: 16
# Qwen US move: b5d7 Move number: 17
# Invalid move by Qwen black. Move: Bxf8
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 18
# Qwen US move: f3e5 Move number: 19
# Qwen CN move: Nc3 Move number: 20
# Qwen US move: b1c3 Move number: 21
# Qwen CN move: h7h6 Move number: 22
# Qwen US move: c3d5 Move number: 23
# Qwen CN move: e7d6 Move number: 24
# Qwen US move: Nf3 Move number: 25
# Qwen CN move: d6d7 Move number: 26
# Qwen US move: Ne7+ Move number: 27
# Invalid move by Qwen black. Move: Ne5
# New Move: Ke6
# Qwen CN move: Ke6 Move number: 28
# Qwen US move: d1e2 Move number: 29
# Qwen CN move: e6d7 Move number: 30
# Qwen US move: Qf1 Move number: 31
# Qwen CN move: d8e7 Move number: 32
# Qwen US move: c1e3 Move number: 33
# Qwen CN move: e7b4 Move number: 34
# Qwen US move: c2c3 Move number: 35
# Qwen CN move: Rg8 Move number: 36
# Qwen US move: e1c1 Move number: 37
# Qwen CN move: Bd6 Move number: 38
# Qwen US move: Ng5 Move number: 39
# Qwen CN move: b4a5 Move number: 40
# Qwen US move: g5f7 Move number: 41
# Qwen CN move: Rgf8 Move number: 42
# Qwen US move: f1c4 Move number: 43
# Qwen CN move: a8e8 Move number: 44
# Qwen US move: h1e1 Move number: 45
# Qwen CN move: a5a6 Move number: 46
# Qwen US move: c4a6 Move number: 47
# Qwen CN move: b7a6 Move number: 48
# Qwen US move: f7d6 Move number: 49
# Qwen CN move: Rxf2 Move number: 50
# Qwen US move: d6e8 Move number: 51
# Qwen CN move: Rd2 Move number: 52
# Qwen US move: d1d2 Move number: 53
# Qwen CN move: Kxe8 Move number: 54
# Qwen US move: Bb6+ Move number: 55
# Invalid move by Qwen black. Move: Bc7
# New Move: Kf8
# Qwen CN move: Kf8 Move number: 56
# Qwen US move: b6c7 Move number: 57
# Invalid move by Qwen black. Move: Bxf2+
# New Move: g5
# Qwen CN move: g5 Move number: 58
# Qwen US move: d2d7 Move number: 59
# Qwen CN move: h6h5 Move number: 60
# Qwen US move: Rd8+ Move number: 61
# Qwen CN move: f8g7 Move number: 62
# Qwen US move: d8d4 Move number: 63
# Qwen CN move: a6a5 Move number: 64
# Qwen US move: c7e5 Move number: 65
# Qwen CN move: Kg6 Move number: 66
# Qwen US move: d4d6 Move number: 67
# Invalid move by Qwen black. Move: Rd1
# New Move: Kf5
# Qwen CN move: Kf5 Move number: 68
# Qwen US move: d6f6 Move number: 69
# Qwen CN move: f5g4 Move number: 70
# Qwen US move: Rf5 Move number: 71
# Qwen CN move: g4f5 Move number: 72
# Qwen US move: c1d2 Move number: 73
# Qwen CN move: h5h4 Move number: 74
# Qwen US move: d2d3 Move number: 75
# Qwen CN move: Kg4 Move number: 76
# Qwen US move: e1e4 Move number: 77
# Invalid move by Qwen black. Move: Rxe5
# New Move: Kh5
# Qwen CN move: Kh5 Move number: 78
# Qwen US move: e4a4 Move number: 79
# Qwen CN move: Kg6 Move number: 80
# Qwen US move: e5d4 Move number: 81
# Qwen CN move: g5g4 Move number: 82
# Qwen US move: d4g1 Move number: 83
# Qwen CN move: g6f5 Move number: 84
# Qwen US move: Rd4 Move number: 85
# Qwen CN move: g4g3 Move number: 86
# Qwen US move: Rd6 Move number: 87
# Invalid move by Qwen black. Move: Rd1
# New Move: Ke5
# Qwen CN move: Ke5 Move number: 88
# Qwen US move: d6d8 Move number: 89
# Invalid move by Qwen black. Move: Bxc3
# New Move: Ke6
# Qwen CN move: Ke6 Move number: 90
# Qwen US move: d8d4 Move number: 91
# Invalid move by Qwen black. Move: Bxd6
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 92
# Qwen US move: h2g3 Move number: 93
# Qwen CN move: hxg3 Move number: 94
# Qwen US move: d4a4 Move number: 95
# Qwen CN move: e7f6 Move number: 96
# Qwen US move: a4a5 Move number: 97
# Qwen CN move: a7a6 Move number: 98
# Qwen US move: Rxa6+ Move number: 99
# Qwen CN move: f6e5 Move number: 100
# Qwen US move: Rd6 Move number: 101
# Qwen CN move: Kf4 Move number: 102
# Qwen US move: d6d4 Move number: 103
# Qwen CN move: f4f5 Move number: 104
# Qwen US move: Rd6 Move number: 105
# Qwen CN move: f5e5 Move number: 106
# Qwen US move: d6d4 Move number: 107
# Qwen CN move: e5f5 Move number: 108
# Qwen US move: c3c4 Move number: 109
# Qwen CN move: f5e5 Move number: 110
# Qwen US move: c4c5 Move number: 111
# Qwen CN move: e5e6 Move number: 112
# Qwen US move: Rd8 Move number: 113
# Qwen CN move: e6f6 Move number: 114
# Qwen US move: Rd5 Move number: 115
# Qwen CN move: f6f7 Move number: 116
# Qwen US move: Rd4 Move number: 117
# Invalid move by Qwen black. Move: Rd7
# New Move: Kf8
# Qwen CN move: Kf8 Move number: 118
# Qwen US move: d4d7 Move number: 119
# Invalid move by Qwen black. Move: Rd8
# New Move: Kg8
# Qwen CN move: Kg8 Move number: 120
# Qwen US move: c5c6 Move number: 121
# Invalid move by Qwen black. Move: Rd4
# New Move: Kh8
# Qwen CN move: Kh8 Move number: 122
# Qwen US move: c6c7 Move number: 123
# Invalid move by Qwen black. Move: Rd5
# New Move: Kg8
# Qwen CN move: Kg8 Move number: 124
# Qwen US move: c7c8r Move number: 125
# Game 96 result: 1-0
#
#
# Starting game 97...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Invalid move by Qwen black. Move: Bc4
# New Move: g6
# Qwen CN move: g6 Move number: 6
# Qwen US move: c2c3 Move number: 7
# Qwen CN move: a7a6 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Qwen CN move: d7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: e5d4 Move number: 12
# Qwen US move: c3d4 Move number: 13
# Qwen CN move: Nf6 Move number: 14
# Qwen US move: b1c3 Move number: 15
# Qwen CN move: Be7 Move number: 16
# Invalid move by Qwen white. Move: Nf3
# New Move: Na4
# Qwen US move: Na4 Move number: 17
# Qwen CN move: f6e4 Move number: 18
# Qwen US move: Nc5 Move number: 19
# Qwen CN move: e4c5 Move number: 20
# Qwen US move: d4c5 Move number: 21
# Qwen CN move: d8d1 Move number: 22
# Qwen US move: e1d1 Move number: 23
# Qwen CN move: Rg8 Move number: 24
# Qwen US move: c1f4 Move number: 25
# Qwen CN move: Bxc5 Move number: 26
# Qwen US move: Bxc7 Move number: 27
# Qwen CN move: c5f2 Move number: 28
# Qwen US move: h1f1 Move number: 29
# Qwen CN move: Rh8 Move number: 30
# Qwen US move: f1f2 Move number: 31
# Qwen CN move: f7f6 Move number: 32
# Qwen US move: d1d2 Move number: 33
# Qwen CN move: c6c5 Move number: 34
# Qwen US move: c7b6 Move number: 35
# Qwen CN move: c8e6 Move number: 36
# Qwen US move: a1c1 Move number: 37
# Qwen CN move: Rd8+ Move number: 38
# Qwen US move: b6d8 Move number: 39
# Qwen CN move: Bh3 Move number: 40
# Qwen US move: d8f6 Move number: 41
# Qwen CN move: Rg8 Move number: 42
# Qwen US move: Rxc5 Move number: 43
# Invalid move by Qwen black. Move: Rxc8
# New Move: Kf8
# Qwen CN move: Kf8 Move number: 44
# Qwen US move: g2h3 Move number: 45
# Qwen CN move: Rh8 Move number: 46
# Qwen US move: c5c8 Move number: 47
# Qwen CN move: f8f7 Move number: 48
# Qwen US move: f3g5 Move number: 49
# Game 97 result: 1-0
#
#
# Starting game 98...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: b1c3 Move number: 7
# Qwen CN move: Nf6 Move number: 8
# Qwen US move: d2d4 Move number: 9
# Qwen CN move: e5g6 Move number: 10
# Qwen US move: e4e5 Move number: 11
# Qwen CN move: f6g8 Move number: 12
# Qwen US move: f1c4 Move number: 13
# Qwen CN move: d7d5 Move number: 14
# Qwen US move: c4d5 Move number: 15
# Qwen CN move: Nxe5 Move number: 16
# Qwen US move: d4e5 Move number: 17
# Invalid move by Qwen black. Move: Bf4
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 18
# Qwen US move: d5f7 Move number: 19
# Invalid move by Qwen black. Move: Bxd8
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 20
# Qwen US move: d1d8 Move number: 21
# Qwen CN move: e7d8 Move number: 22
# Qwen US move: Bh6 Move number: 23
# Qwen CN move: g8h6 Move number: 24
# Qwen US move: e1c1 Move number: 25
# Qwen CN move: a3d6 Move number: 26
# Qwen US move: f7h5 Move number: 27
# Qwen CN move: Rg8 Move number: 28
# Qwen US move: e5d6 Move number: 29
# Invalid move by Qwen black. Move: Rxd8
# New Move: b5
# Qwen CN move: b5 Move number: 30
# Qwen US move: h5f3 Move number: 31
# Qwen CN move: c7c6 Move number: 32
# Qwen US move: Bxc6 Move number: 33
# Qwen CN move: a8b8 Move number: 34
# Qwen US move: h1e1 Move number: 35
# Qwen CN move: c8b7 Move number: 36
# Qwen US move: c6b5 Move number: 37
# Invalid move by Qwen black. Move: Bxf7+ Kxf7
# New Move: a5
# Qwen CN move: a5 Move number: 38
# Qwen US move: f2f3 Move number: 39
# Qwen CN move: b7a8 Move number: 40
# Qwen US move: Re2 Move number: 41
# Qwen CN move: h6f5 Move number: 42
# Qwen US move: b5a4 Move number: 43
# Qwen CN move: g8f8 Move number: 44
# Qwen US move: b2b3 Move number: 45
# Qwen CN move: Rb4 Move number: 46
# Qwen US move: d6d7 Move number: 47
# Qwen CN move: Rb8 Move number: 48
# Qwen US move: Re3 Move number: 49
# Qwen CN move: f5e3 Move number: 50
# Qwen US move: d1e1 Move number: 51
# Qwen CN move: Rxf3 Move number: 52
# Qwen US move: g2f3 Move number: 53
# Qwen CN move: b8b6 Move number: 54
# Qwen US move: e1e3 Move number: 55
# Qwen CN move: a8c6 Move number: 56
# Qwen US move: e3d3 Move number: 57
# Qwen CN move: c6b7 Move number: 58
# Qwen US move: c3e4 Move number: 59
# Qwen CN move: Rd6 Move number: 60
# Qwen US move: e4d6 Move number: 61
# Qwen CN move: Bd5 Move number: 62
# Qwen US move: d3d5 Move number: 63
# Invalid move by Qwen black. Move: Re1
# New Move: g5
# Qwen CN move: g5 Move number: 64
# Qwen US move: d6f7 Move number: 65
# Qwen CN move: d8e7 Move number: 66
# Qwen US move: Nxd6 Move number: 67
# Qwen CN move: h7h5 Move number: 68
# Qwen US move: d6c8 Move number: 69
# Qwen CN move: e7d8 Move number: 70
# Qwen US move: c8a7 Move number: 71
# Invalid move by Qwen black. Move: Re1
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 72
# Qwen US move: d7d8q Move number: 73
# Qwen CN move: Ke6 Move number: 74
# Qwen US move: a4e8 Move number: 75
# Qwen CN move: g5g4 Move number: 76
# Qwen US move: d8d6 Move number: 77
# Game 98 result: 1-0
#
#
# Starting game 99...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: b1c3 Move number: 7
# Qwen CN move: Nf6 Move number: 8
# Qwen US move: d2d4 Move number: 9
# Qwen CN move: e5g6 Move number: 10
# Qwen US move: e4e5 Move number: 11
# Qwen CN move: f6g8 Move number: 12
# Qwen US move: f1c4 Move number: 13
# Qwen CN move: d7d5 Move number: 14
# Qwen US move: c4d5 Move number: 15
# Qwen CN move: Be7 Move number: 16
# Qwen US move: d1f3 Move number: 17
# Qwen CN move: Qd6 Move number: 18
# Qwen US move: d5f7 Move number: 19
# Invalid move by Qwen black. Move: Bxd6
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 20
# Qwen US move: e5d6 Move number: 21
# Qwen CN move: c7d6 Move number: 22
# Qwen US move: Bh6 Move number: 23
# Qwen CN move: g8h6 Move number: 24
# Qwen US move: f7g6 Move number: 25
# Qwen CN move: h7g6 Move number: 26
# Qwen US move: c3d5 Move number: 27
# Qwen CN move: Ng4 Move number: 28
# Qwen US move: f3g4 Move number: 29
# Qwen CN move: Ke8 Move number: 30
# Qwen US move: Nxe7 Move number: 31
# Qwen CN move: c8g4 Move number: 32
# Qwen US move: e7g6 Move number: 33
# Qwen CN move: Rg8 Move number: 34
# Qwen US move: g6f4 Move number: 35
# Qwen CN move: e8d7 Move number: 36
# Qwen US move: f2f3 Move number: 37
# Qwen CN move: g8f8 Move number: 38
# Qwen US move: f4d5 Move number: 39
# Qwen CN move: a8c8 Move number: 40
# Qwen US move: d5e3 Move number: 41
# Qwen CN move: Rxf3 Move number: 42
# Qwen US move: g2f3 Move number: 43
# Qwen CN move: Rxc2 Move number: 44
# Qwen US move: e3c2 Move number: 45
# Invalid move by Qwen black. Move: Nxb6
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 46
# Qwen US move: f3g4 Move number: 47
# Invalid move by Qwen black. Move: Nxd6
# New Move: d5
# Qwen CN move: d5 Move number: 48
# Qwen US move: e1c1 Move number: 49
# Qwen CN move: b7b5 Move number: 50
# Qwen US move: Nxb4 Move number: 51
# Qwen CN move: e7d6 Move number: 52
# Qwen US move: h1e1 Move number: 53
# Qwen CN move: a7a5 Move number: 54
# Qwen US move: b4c2 Move number: 55
# Invalid move by Qwen black. Move: Nxb5
# New Move: a4
# Qwen CN move: a4 Move number: 56
# Qwen US move: a2a3 Move number: 57
# Qwen CN move: d6c6 Move number: 58
# Qwen US move: Re8 Move number: 59
# Qwen CN move: c6d7 Move number: 60
# Qwen US move: e8e3 Move number: 61
# Qwen CN move: d7c6 Move number: 62
# Qwen US move: d1e1 Move number: 63
# Qwen CN move: Kd6 Move number: 64
# Qwen US move: e3e7 Move number: 65
# Qwen CN move: Kc6 Move number: 66
# Invalid move by Qwen white. Move: Rxe4
# New Move: R7e6+
# Qwen US move: R7e6+ Move number: 67
# Qwen CN move: c6c7 Move number: 68
# Qwen US move: Re8 Move number: 69
# Qwen CN move: b5b4 Move number: 70
# Qwen US move: e8e7 Move number: 71
# Qwen CN move: c7b6 Move number: 72
# Qwen US move: e1e6 Move number: 73
# Invalid move by Qwen black. Move:  Kb5
# New Move: Kb5
# Qwen CN move: Kb5 Move number: 74
# Qwen US move: e7b7 Move number: 75
# Invalid move by Qwen black. Move: Rxb4
# New Move: Ka5
# Qwen CN move: Ka5 Move number: 76
# Qwen US move: a3b4 Move number: 77
# Game 99 result: 1-0
#
#
# Starting game 100...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: Nf6 Move number: 6
# Qwen US move: b1c3 Move number: 7
# Qwen CN move: Nxe4 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Qwen CN move: e4c3 Move number: 10
# Qwen US move: c6d7 Move number: 11
# Qwen CN move: Bxd7 Move number: 12
# Qwen US move: d2c3 Move number: 13
# Qwen CN move: f7f6 Move number: 14
# Qwen US move: c1e3 Move number: 15
# Qwen CN move: d8b6 Move number: 16
# Qwen US move: b2b3 Move number: 17
# Qwen CN move: b6c6 Move number: 18
# Qwen US move: d1e2 Move number: 19
# Qwen CN move: Rg8 Move number: 20
# Qwen US move: e1c1 Move number: 21
# Qwen CN move: Rh8 Move number: 22
# Qwen US move: d1d2 Move number: 23
# Qwen CN move: Rg8 Move number: 24
# Qwen US move: Nh4 Move number: 25
# Invalid move by Qwen black. Move: Nh4
# New Move: Be6
# Qwen CN move: Be6 Move number: 26
# Qwen US move: f2f4 Move number: 27
# Qwen CN move: Bh3 Move number: 28
# Qwen US move: f4f5 Move number: 29
# Qwen CN move: c6e4 Move number: 30
# Qwen US move: h1e1 Move number: 31
# Qwen CN move: e4h4 Move number: 32
# Qwen US move: Bxc5 Move number: 33
# Qwen CN move: h3f5 Move number: 34
# Qwen US move: Bxe7 Move number: 35
# Qwen CN move: Bxc2 Move number: 36
# Qwen US move: e7f6 Move number: 37
# Qwen CN move: e8f7 Move number: 38
# Qwen US move: Bd8 Move number: 39
# Qwen CN move: h4e1 Move number: 40
# Qwen US move: e2e1 Move number: 41
# Qwen CN move: c2f5 Move number: 42
# Qwen US move: c1b2 Move number: 43
# Qwen CN move: a8d8 Move number: 44
# Qwen US move: d2d8 Move number: 45
# Qwen CN move: f8a3 Move number: 46
# Qwen US move: Kxa3 Move number: 47
# Qwen CN move: g8d8 Move number: 48
# Qwen US move: Qe4 Move number: 49
# Qwen CN move: f5e4 Move number: 50
# Invalid move by Qwen white. Move:  Kb2
# New Move: Ka4
# Qwen US move: Ka4 Move number: 51
# Qwen CN move: e4f5 Move number: 52
# Invalid move by Qwen white. Move:  Kb5
# New Move: g4
# Qwen US move: g4 Move number: 53
# Qwen CN move: f5g4 Move number: 54
# Qwen US move: b3b4 Move number: 55
# Invalid move by Qwen black. Move:  Kb1
# New Move: Rd7
# Qwen CN move: Rd7 Move number: 56
# Qwen US move: b4b5 Move number: 57
# Qwen CN move: Kf6 Move number: 58
# Qwen US move: a4b3 Move number: 59
# Qwen CN move: g4d1 Move number: 60
# Qwen US move: b3b4 Move number: 61
# Qwen CN move: d7e7 Move number: 62
# Invalid move by Qwen white. Move:  Kb5
# New Move: Ka5
# Qwen US move: Ka5 Move number: 63
# Qwen CN move: b7b6 Move number: 64
# Invalid move by Qwen white. Move:  Kb4
# New Move: Ka6
# Qwen US move: Ka6 Move number: 65
# Qwen CN move: d1g4 Move number: 66
# Qwen US move: c4 Move number: 67
# Qwen CN move: g4c8 Move number: 68
# Game 100 result: 0-1

# %%
results = []

# %%
results.append({
            "Qwen US Wins": qwen_us_wins,
            "Qwen CN Wins": qwen_cn_wins,
            "Draws": draws,
        })

print(results)
# Out:
# [{'Qwen US Wins': 93, 'Qwen CN Wins': 96, 'Draws': 11}]

# %%
df = pd.DataFrame(results)
df.to_csv(f"LLM_{QWEN_US_AI}_vs_LLM_{QWEN_CN_AI}.csv", index=False)
print(f"Results saved to LLM_{QWEN_US_AI}_vs_LLM_{QWEN_CN_AI}.csv")
# Out:
# Results saved to LLM_70_vs_LLM_70.csv
