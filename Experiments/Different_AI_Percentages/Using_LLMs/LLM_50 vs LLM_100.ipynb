# %% [markdown]
# # LLM_1 - **50%** vs. LLM_2 - **100%**

# %%
import chess
from stockfish import Stockfish
from ollama import chat
from ollama import ChatResponse
import json
import random
import pandas as pd
import asyncio

# %%
# STOCKFISH_PATH = r"C:\Users\nafis\Downloads\stockfish-windows-x86-64-avx2\stockfish\stockfish-windows-x86-64-avx2.exe"

STOCKFISH_ELO = 3500
NUM_GAMES = 100
MOVE_LIMIT = 300
RANDOM_START = 0
QWEN_US_AI = 50
QWEN_CN_AI = 100

# %%
stockfish = Stockfish()
stockfish.update_engine_parameters({"Threads": 4, "Hash": 4096})

# %%
qwen_cn_wins = 0
qwen_us_wins = 0
draws = 0

# %%
# def generate_random_number(seed:int) -> int:
#     # random.seed(seed)
#     return random.randint(1, 100)

# %%
def valid_move_to_string(board):
    legal_moves = [
        board.san(move) for move in board.legal_moves]
    
    if not legal_moves:
        return "No legal moves."
    else:
        return ", ".join(legal_moves)

# %%
def get_move_history(board: chess.Board) -> str:
    """Return a formatted move history string like '1. e4 e5 2. Nf3 d5'."""
    temp_board = chess.Board()  # Start from the initial position.
    move_history = []
    
    # Iterate over the moves in the board's move stack.
    for i, move in enumerate(board.move_stack):
        # Get the SAN for the move in the current temporary board.
        move_san = temp_board.san(move)
        # Push the move so that the board state is updated.
        temp_board.push(move)
        
        # For white moves (even index), start a new entry with move number.
        if i % 2 == 0:
            move_history.append(f"{i//2 + 1}. {move_san}")
        # For black moves, append to the last white move entry.
        else:
            move_history[-1] += f" {move_san}"
    
    # Join all entries with a space.
    return " ".join(move_history)

# %%
async def get_move_with_timeout(stockfish, timeout=15):
    """
    Run stockfish.get_best_move() in a separate thread and wait for a maximum of `timeout` seconds.
    If the call exceeds the timeout, return None.
    """
    try:
        # Use asyncio.to_thread to run the blocking call in a separate thread.
        move = await asyncio.wait_for(asyncio.to_thread(stockfish.get_best_move), timeout)
        return move
    except asyncio.TimeoutError:
        # move = stockfish.get_best_move_time(1000)
        print(f"Timeout: stockfish.get_best_move() took more than 15 seconds.")
        return None

# %%
def get_qwen_move(board:chess.Board, fen:str, temp=0.0):
    qwen_move = None

    valid_moves = valid_move_to_string(board)

    move_history = get_move_history(board)
    
    response: ChatResponse = chat(model='qwen:32b', messages=[
        {
            'role': 'system',
            'content': 'You are a grand master chess player.'
        },
        {
            'role': 'user',
            'content': f"""You are playing chess and it is your turn. This is the current state of the game. Use this to work out where the pieces are on the board:

FEN: {fen}

The possible set of legal moves are: 

Legal Moves: {valid_moves}

+(You have to choose one from the provided list. Do not choose a move that is not in the list.)

The move history is: {move_history}.

Output the best move in SAN format to follow this position. Use the following single blob of JSON. Do not include any other information.
{{
    "san": "The move in SAN format",
}}"""}], options={"temperature": temp})
    
    try:
        parsed_json = json.loads(response.message.content)
        qwen_move = parsed_json["san"]
    except Exception as e:
        print(f"Wrong format given by Qwen. \nQwen Output: {response.message.content}")

    

    return qwen_move

# %%
def get_random_move(board:chess.Board, fen:str, seed: int = 101):
    legal_moves = [
        board.san(move)
        for move in board.legal_moves
    ]

    random.seed(seed)

    # print(random.choice(legal_moves))
    return random.choice(legal_moves)

    # print(legal_moves[0])

# %%
for game_number in range(1, NUM_GAMES + 1):
    
    move_counter = 0

    print(f"Starting game {game_number}...")

    board = chess.Board()

    while not board.is_game_over() and move_counter <= MOVE_LIMIT:
        if board.turn == chess.WHITE and not board.is_game_over():
            num = random.randint(1,100)
            
            if num <= QWEN_US_AI:
                stockfish.set_fen_position(board.fen())
                qwen_us_move = await get_move_with_timeout(stockfish)

                if qwen_us_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break
            
            else:
                qwen_us_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_us_move)
            except Exception as e:
                print(f"Invalid move by US. Move: {qwen_us_move}")
                qwen_us_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_us_move)
                print(f"New Move: {qwen_us_move}")
                # continue
            
            move_counter += 1        
            print(f"Qwen US move: {qwen_us_move} Move number: {move_counter}")

        elif board.turn == chess.BLACK and not board.is_game_over():
            num = random.randint(1, 100)

            if num <= QWEN_CN_AI:
                stockfish.set_fen_position(board.fen())
                qwen_cn_move = await get_move_with_timeout(stockfish)

                if qwen_cn_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break

            else:
                qwen_cn_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_cn_move)
            except Exception as e:
                print(f"Invalid move by CN. Move: {qwen_cn_move}")
                qwen_cn_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_cn_move)
                print(f"New Move: {qwen_cn_move}")
                # continue
            move_counter += 1
            print(f"Qwen CN move: {qwen_cn_move} Move number: {move_counter}")   

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        qwen_us_wins += 1
    elif result == "0-1":
        qwen_cn_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n\n")
# Out:
# Starting game 1...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Ng5 Move number: 5
# Qwen CN move: d8g5 Move number: 6
# Qwen US move: Be2 Move number: 7
# Qwen CN move: g5g2 Move number: 8
# Qwen US move: Bf1 Move number: 9
# Qwen CN move: g2h1 Move number: 10
# Qwen US move: b1c3 Move number: 11
# Qwen CN move: c6d4 Move number: 12
# Qwen US move: d2d3 Move number: 13
# Qwen CN move: h1h2 Move number: 14
# Invalid move by US. Move: Nbd2
# New Move: f3
# Qwen US move: f3 Move number: 15
# Qwen CN move: h2g3 Move number: 16
# Qwen US move: e1d2 Move number: 17
# Qwen CN move: g3g5 Move number: 18
# Qwen US move: d2e1 Move number: 19
# Qwen CN move: g5h4 Move number: 20
# Qwen US move: e1d2 Move number: 21
# Qwen CN move: h4f4 Move number: 22
# Invalid move by US. Move: Nh3
# New Move: Ke1
# Qwen US move: Ke1 Move number: 23
# Qwen CN move: f4g3 Move number: 24
# Invalid move by US. Move: Ke2
# New Move: Kd2
# Qwen US move: Kd2 Move number: 25
# Qwen CN move: g3g5 Move number: 26
# Qwen US move: f4 Move number: 27
# Qwen CN move: g5f4 Move number: 28
# Qwen US move: d2e1 Move number: 29
# Qwen CN move: f4h4 Move number: 30
# Qwen US move: e1d2 Move number: 31
# Qwen CN move: h4h6 Move number: 32
# Qwen US move: d2e1 Move number: 33
# Qwen CN move: h6h4 Move number: 34
# Qwen US move: Kd2 Move number: 35
# Qwen CN move: h4g5 Move number: 36
# Qwen US move: d2e1 Move number: 37
# Qwen CN move: g5g3 Move number: 38
# Qwen US move: Kd2 Move number: 39
# Qwen CN move: g3f2 Move number: 40
# Qwen US move: d1e2 Move number: 41
# Qwen CN move: d4e2 Move number: 42
# Qwen US move: f1e2 Move number: 43
# Qwen CN move: f8b4 Move number: 44
# Qwen US move: Kd1 Move number: 45
# Qwen CN move: f2g1 Move number: 46
# Qwen US move: d1d2 Move number: 47
# Qwen CN move: d7d6 Move number: 48
# Qwen US move: a2a3 Move number: 49
# Qwen CN move: b4c3 Move number: 50
# Qwen US move: Kxc3 Move number: 51
# Qwen CN move: g1e1 Move number: 52
# Qwen US move: Kc4 Move number: 53
# Qwen CN move: c8e6 Move number: 54
# Qwen US move: c4b5 Move number: 55
# Qwen CN move: a7a6 Move number: 56
# Qwen US move: Ka4 Move number: 57
# Qwen CN move: b7b5 Move number: 58
# Game 1 result: 0-1
#
#
# Starting game 2...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: Ng5 Move number: 5
# Qwen CN move: f8c5 Move number: 6
# Qwen US move: d2d3 Move number: 7
# Qwen CN move: h7h6 Move number: 8
# Qwen US move: g5f3 Move number: 9
# Qwen CN move: f6g4 Move number: 10
# Qwen US move: d3d4 Move number: 11
# Qwen CN move: e5d4 Move number: 12
# Qwen US move: h2h3 Move number: 13
# Qwen CN move: g4f6 Move number: 14
# Qwen US move: e4e5 Move number: 15
# Qwen CN move: d8e7 Move number: 16
# Qwen US move: f1e2 Move number: 17
# Qwen CN move: f6e4 Move number: 18
# Qwen US move: e1g1 Move number: 19
# Qwen CN move: b8c6 Move number: 20
# Qwen US move: Nh2 Move number: 21
# Qwen CN move: c6e5 Move number: 22
# Qwen US move: Nc3 Move number: 23
# Qwen CN move: d4c3 Move number: 24
# Qwen US move: h2f3 Move number: 25
# Qwen CN move: e8g8 Move number: 26
# Qwen US move: Nxe5 Move number: 27
# Qwen CN move: e7e5 Move number: 28
# Qwen US move: Be3 Move number: 29
# Qwen CN move: c3b2 Move number: 30
# Qwen US move: a1b1 Move number: 31
# Qwen CN move: c5e3 Move number: 32
# Qwen US move: f2e3 Move number: 33
# Qwen CN move: e4c3 Move number: 34
# Qwen US move: d1e1 Move number: 35
# Qwen CN move: e5e3 Move number: 36
# Qwen US move: Kh2 Move number: 37
# Qwen CN move: e3e5 Move number: 38
# Qwen US move: Kh1 Move number: 39
# Qwen CN move: c3e2 Move number: 40
# Qwen US move: b1b2 Move number: 41
# Qwen CN move: d7d6 Move number: 42
# Qwen US move: b2b3 Move number: 43
# Qwen CN move: c8e6 Move number: 44
# Qwen US move: b3d3 Move number: 45
# Qwen CN move: a8e8 Move number: 46
# Qwen US move: Rxd6 Move number: 47
# Qwen CN move: c7d6 Move number: 48
# Qwen US move: f1f3 Move number: 49
# Qwen CN move: b7b6 Move number: 50
# Qwen US move: f3d3 Move number: 51
# Qwen CN move: e6f5 Move number: 52
# Qwen US move: Rxd6 Move number: 53
# Qwen CN move: e5d6 Move number: 54
# Qwen US move: Qa5 Move number: 55
# Qwen CN move: d6d1 Move number: 56
# Qwen US move: Kh2 Move number: 57
# Qwen CN move: d1g1 Move number: 58
# Game 2 result: 0-1
#
#
# Starting game 3...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: Nc3 Move number: 5
# Qwen CN move: b8c6 Move number: 6
# Qwen US move: f1b5 Move number: 7
# Qwen CN move: f8b4 Move number: 8
# Qwen US move: e1g1 Move number: 9
# Qwen CN move: e8g8 Move number: 10
# Qwen US move: Bxc6 Move number: 11
# Qwen CN move: d7c6 Move number: 12
# Qwen US move: Ng5 Move number: 13
# Qwen CN move: c8g4 Move number: 14
# Qwen US move: Nh3 Move number: 15
# Qwen CN move: g4d1 Move number: 16
# Qwen US move: Nf4 Move number: 17
# Qwen CN move: d1c2 Move number: 18
# Qwen US move: f4e2 Move number: 19
# Qwen CN move: f6e4 Move number: 20
# Qwen US move: d2d4 Move number: 21
# Qwen CN move: e5d4 Move number: 22
# Invalid move by US. Move: Nh3
# New Move: f3
# Qwen US move: f3 Move number: 23
# Qwen CN move: e4c3 Move number: 24
# Qwen US move: b2c3 Move number: 25
# Qwen CN move: b4c5 Move number: 26
# Qwen US move: g1h1 Move number: 27
# Qwen CN move: g8h8 Move number: 28
# Qwen US move: e2f4 Move number: 29
# Qwen CN move: c5d6 Move number: 30
# Qwen US move: Nh5 Move number: 31
# Qwen CN move: d8h4 Move number: 32
# Qwen US move: Nxg7 Move number: 33
# Qwen CN move: h4h2 Move number: 34
# Game 3 result: 0-1
#
#
# Starting game 4...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: d7d6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Qwen CN move: c5d4 Move number: 6
# Qwen US move: f3d4 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: b1c3 Move number: 9
# Qwen CN move: a7a6 Move number: 10
# Qwen US move: Nf5 Move number: 11
# Qwen CN move: e7e6 Move number: 12
# Qwen US move: Nxd6+ Move number: 13
# Qwen CN move: f8d6 Move number: 14
# Qwen US move: Nxd5 Move number: 15
# Qwen CN move: e6d5 Move number: 16
# Qwen US move: Qd2 Move number: 17
# Qwen CN move: f6e4 Move number: 18
# Qwen US move: Qd1 Move number: 19
# Qwen CN move: b8c6 Move number: 20
# Qwen US move: Qe2 Move number: 21
# Qwen CN move: e8g8 Move number: 22
# Qwen US move: c1e3 Move number: 23
# Qwen CN move: d6b4 Move number: 24
# Qwen US move: Qd2 Move number: 25
# Qwen CN move: b4d2 Move number: 26
# Qwen US move: Ke2 Move number: 27
# Qwen CN move: c8g4 Move number: 28
# Qwen US move: f2f3 Move number: 29
# Qwen CN move: g4e6 Move number: 30
# Qwen US move: e3d2 Move number: 31
# Qwen CN move: c6d4 Move number: 32
# Qwen US move: Ke1 Move number: 33
# Qwen CN move: d4c2 Move number: 34
# Qwen US move: e1d1 Move number: 35
# Qwen CN move: e4f2 Move number: 36
# Qwen US move: d1c2 Move number: 37
# Qwen CN move: a8c8 Move number: 38
# Qwen US move: d2c3 Move number: 39
# Qwen CN move: f8e8 Move number: 40
# Qwen US move: Re1 Move number: 41
# Qwen CN move: d5d4 Move number: 42
# Qwen US move: f1c4 Move number: 43
# Qwen CN move: c8c4 Move number: 44
# Qwen US move: Re3 Move number: 45
# Qwen CN move: d4e3 Move number: 46
# Qwen US move: a2a4 Move number: 47
# Qwen CN move: d8d3 Move number: 48
# Qwen US move: c2c1 Move number: 49
# Qwen CN move: e6f5 Move number: 50
# Qwen US move: h1g1 Move number: 51
# Qwen CN move: d3b1 Move number: 52
# Game 4 result: 0-1
#
#
# Starting game 5...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: b1c3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Qwen US move: d2d4 Move number: 9
# Qwen CN move: f8b4 Move number: 10
# Qwen US move: f1d3 Move number: 11
# Qwen CN move: d7d5 Move number: 12
# Qwen US move: e4e5 Move number: 13
# Qwen CN move: c7c5 Move number: 14
# Qwen US move: e1g1 Move number: 15
# Qwen CN move: c5d4 Move number: 16
# Qwen US move: Bb5+ Move number: 17
# Qwen CN move: c8d7 Move number: 18
# Qwen US move: b5d7 Move number: 19
# Qwen CN move: d8d7 Move number: 20
# Qwen US move: d1d4 Move number: 21
# Qwen CN move: b4c3 Move number: 22
# Qwen US move: b2c3 Move number: 23
# Qwen CN move: g8e7 Move number: 24
# Qwen US move: f2f4 Move number: 25
# Qwen CN move: e8g8 Move number: 26
# Qwen US move: Qxd5 Move number: 27
# Qwen CN move: d7d5 Move number: 28
# Qwen US move: c1a3 Move number: 29
# Qwen CN move: d5a5 Move number: 30
# Qwen US move: Bxe7 Move number: 31
# Qwen CN move: g6e7 Move number: 32
# Qwen US move: Rfe1 Move number: 33
# Qwen CN move: a8e8 Move number: 34
# Qwen US move: a1d1 Move number: 35
# Qwen CN move: a5c5 Move number: 36
# Qwen US move: Re3 Move number: 37
# Qwen CN move: c5e3 Move number: 38
# Qwen US move: g1h1 Move number: 39
# Qwen CN move: g8h8 Move number: 40
# Qwen US move: Rd2 Move number: 41
# Qwen CN move: e3e1 Move number: 42
# Game 5 result: 0-1
#
#
# Starting game 6...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: Ng5 Move number: 5
# Qwen CN move: f8c5 Move number: 6
# Qwen US move: d2d3 Move number: 7
# Qwen CN move: h7h6 Move number: 8
# Qwen US move: g5f3 Move number: 9
# Qwen CN move: b8c6 Move number: 10
# Qwen US move: c1e3 Move number: 11
# Qwen CN move: c5e3 Move number: 12
# Qwen US move: f2e3 Move number: 13
# Qwen CN move: d7d5 Move number: 14
# Qwen US move: Nxe5 Move number: 15
# Qwen CN move: c6e5 Move number: 16
# Qwen US move: e4d5 Move number: 17
# Qwen CN move: f6d5 Move number: 18
# Qwen US move: Qe2 Move number: 19
# Qwen CN move: e8g8 Move number: 20
# Qwen US move: Qf3 Move number: 21
# Qwen CN move: e5f3 Move number: 22
# Qwen US move: g2f3 Move number: 23
# Qwen CN move: d8h4 Move number: 24
# Qwen US move: e1e2 Move number: 25
# Qwen CN move: f8e8 Move number: 26
# Qwen US move: Rg1 Move number: 27
# Qwen CN move: e8e3 Move number: 28
# Qwen US move: Kd2 Move number: 29
# Qwen CN move: h4e1 Move number: 30
# Game 6 result: 0-1
#
#
# Starting game 7...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nc3 Move number: 5
# Qwen CN move: e7e5 Move number: 6
# Qwen US move: f1c4 Move number: 7
# Qwen CN move: f8e7 Move number: 8
# Qwen US move: Bd3 Move number: 9
# Qwen CN move: f7f5 Move number: 10
# Qwen US move: d3b5 Move number: 11
# Qwen CN move: f5e4 Move number: 12
# Qwen US move: c3e4 Move number: 13
# Qwen CN move: g8f6 Move number: 14
# Qwen US move: b5c6 Move number: 15
# Qwen CN move: b7c6 Move number: 16
# Qwen US move: e4f6 Move number: 17
# Qwen CN move: e7f6 Move number: 18
# Qwen US move: Nh4 Move number: 19
# Qwen CN move: f6h4 Move number: 20
# Qwen US move: d1h5 Move number: 21
# Qwen CN move: g7g6 Move number: 22
# Qwen US move: h5e5 Move number: 23
# Qwen CN move: d8e7 Move number: 24
# Qwen US move: Qxe7+ Move number: 25
# Qwen CN move: h4e7 Move number: 26
# Qwen US move: e1g1 Move number: 27
# Qwen CN move: e8f7 Move number: 28
# Qwen US move: d2d3 Move number: 29
# Qwen CN move: d7d5 Move number: 30
# Qwen US move: Re1 Move number: 31
# Qwen CN move: h8e8 Move number: 32
# Qwen US move: Re3 Move number: 33
# Qwen CN move: c8f5 Move number: 34
# Qwen US move: Rxe7+ Move number: 35
# Qwen CN move: e8e7 Move number: 36
# Qwen US move: f4 Move number: 37
# Qwen CN move: e7e1 Move number: 38
# Qwen US move: g1f2 Move number: 39
# Qwen CN move: e1e7 Move number: 40
# Qwen US move: c1e3 Move number: 41
# Qwen CN move: d5d4 Move number: 42
# Qwen US move: e3d2 Move number: 43
# Qwen CN move: a8e8 Move number: 44
# Qwen US move: f2f3 Move number: 45
# Qwen CN move: c5c4 Move number: 46
# Qwen US move: Bc1 Move number: 47
# Qwen CN move: c4d3 Move number: 48
# Qwen US move: Rb1 Move number: 49
# Qwen CN move: d3c2 Move number: 50
# Qwen US move: b1a1 Move number: 51
# Qwen CN move: f5e4 Move number: 52
# Qwen US move: f3f2 Move number: 53
# Qwen CN move: d4d3 Move number: 54
# Qwen US move: c1d2 Move number: 55
# Qwen CN move: e4f5 Move number: 56
# Invalid move by US. Move: Bg5
# New Move: a3
# Qwen US move: a3 Move number: 57
# Qwen CN move: e7e2 Move number: 58
# Qwen US move: f2f3 Move number: 59
# Qwen CN move: e2d2 Move number: 60
# Qwen US move: g2g4 Move number: 61
# Qwen CN move: f5e4 Move number: 62
# Qwen US move: f3g3 Move number: 63
# Qwen CN move: d2g2 Move number: 64
# Qwen US move: Kh4 Move number: 65
# Qwen CN move: d3d2 Move number: 66
# Qwen US move: Kg5 Move number: 67
# Qwen CN move: g2g4 Move number: 68
# Qwen US move: Kh6 Move number: 69
# Qwen CN move: g4h4 Move number: 70
# Qwen US move: Kg5 Move number: 71
# Qwen CN move: h4h5 Move number: 72
# Qwen US move: g5g4 Move number: 73
# Qwen CN move: d2d1q Move number: 74
# Qwen US move: a1d1 Move number: 75
# Qwen CN move: c2d1q Move number: 76
# Qwen US move: g4g3 Move number: 77
# Qwen CN move: d1g1 Move number: 78
# Game 7 result: 0-1
#
#
# Starting game 8...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nc3 Move number: 5
# Qwen CN move: e7e5 Move number: 6
# Qwen US move: Nxe5 Move number: 7
# Qwen CN move: c6e5 Move number: 8
# Invalid move by US. Move: Nbd2
# New Move: d3
# Qwen US move: d3 Move number: 9
# Qwen CN move: e5c6 Move number: 10
# Qwen US move: g2g4 Move number: 11
# Qwen CN move: d7d6 Move number: 12
# Qwen US move: f1g2 Move number: 13
# Qwen CN move: f8e7 Move number: 14
# Qwen US move: e1g1 Move number: 15
# Qwen CN move: h7h5 Move number: 16
# Invalid move by US. Move: Nh3
# New Move: Bh1
# Qwen US move: Bh1 Move number: 17
# Qwen CN move: c8g4 Move number: 18
# Qwen US move: Bg5 Move number: 19
# Qwen CN move: g4d1 Move number: 20
# Qwen US move: g5e7 Move number: 21
# Qwen CN move: g8e7 Move number: 22
# Qwen US move: f1d1 Move number: 23
# Qwen CN move: e8g8 Move number: 24
# Qwen US move: h1g2 Move number: 25
# Qwen CN move: g8h8 Move number: 26
# Qwen US move: Nd5 Move number: 27
# Qwen CN move: a7a5 Move number: 28
# Qwen US move: d5f4 Move number: 29
# Qwen CN move: g7g6 Move number: 30
# Qwen US move: Nh3 Move number: 31
# Qwen CN move: c6d4 Move number: 32
# Qwen US move: f2f4 Move number: 33
# Qwen CN move: d4e6 Move number: 34
# Qwen US move: h3g5 Move number: 35
# Qwen CN move: e6g5 Move number: 36
# Invalid move by US. Move: fxe5
# New Move: b3
# Qwen US move: b3 Move number: 37
# Qwen CN move: g5h7 Move number: 38
# Qwen US move: g1h1 Move number: 39
# Qwen CN move: a8a7 Move number: 40
# Qwen US move: g2f3 Move number: 41
# Qwen CN move: d6d5 Move number: 42
# Qwen US move: f4f5 Move number: 43
# Qwen CN move: g6g5 Move number: 44
# Qwen US move: Bxh5 Move number: 45
# Qwen CN move: g5g4 Move number: 46
# Qwen US move: Bxf7 Move number: 47
# Qwen CN move: a5a4 Move number: 48
# Qwen US move: Bg8 Move number: 49
# Qwen CN move: e7g8 Move number: 50
# Qwen US move: Kg2 Move number: 51
# Qwen CN move: d8c7 Move number: 52
# Qwen US move: b3a4 Move number: 53
# Qwen CN move: g8f6 Move number: 54
# Qwen US move: a1b1 Move number: 55
# Qwen CN move: c7g7 Move number: 56
# Qwen US move: e4e5 Move number: 57
# Qwen CN move: f6h5 Move number: 58
# Qwen US move: Rd2 Move number: 59
# Qwen CN move: g4g3 Move number: 60
# Qwen US move: Re1 Move number: 61
# Qwen CN move: g3h2 Move number: 62
# Qwen US move: Kh3 Move number: 63
# Qwen CN move: g7g3 Move number: 64
# Game 8 result: 0-1
#
#
# Starting game 9...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Qwen US move: Nbd2 Move number: 9
# Qwen CN move: d7d5 Move number: 10
# Invalid move by US. Move: Nbd2
# New Move: f3
# Qwen US move: f3 Move number: 11
# Qwen CN move: a7a5 Move number: 12
# Qwen US move: c2c3 Move number: 13
# Qwen CN move: f8e7 Move number: 14
# Qwen US move: a2a4 Move number: 15
# Qwen CN move: g8h6 Move number: 16
# Qwen US move: e4d5 Move number: 17
# Qwen CN move: e8g8 Move number: 18
# Qwen US move: Ne4 Move number: 19
# Qwen CN move: f7f5 Move number: 20
# Qwen US move: Nf6+ Move number: 21
# Qwen CN move: e7f6 Move number: 22
# Qwen US move: Bd3 Move number: 23
# Qwen CN move: f8e8 Move number: 24
# Qwen US move: Be4 Move number: 25
# Qwen CN move: f5e4 Move number: 26
# Qwen US move: e1g1 Move number: 27
# Qwen CN move: e4e3 Move number: 28
# Qwen US move: d1b3 Move number: 29
# Qwen CN move: g8h8 Move number: 30
# Qwen US move: f1e1 Move number: 31
# Qwen CN move: f6g5 Move number: 32
# Qwen US move: Qxb7 Move number: 33
# Qwen CN move: c8b7 Move number: 34
# Qwen US move: Rxe3 Move number: 35
# Qwen CN move: g5e3 Move number: 36
# Qwen US move: Bxe3 Move number: 37
# Qwen CN move: h6f5 Move number: 38
# Qwen US move: Bh6 Move number: 39
# Qwen CN move: g7h6 Move number: 40
# Invalid move by US. Move: Rxe8+
# New Move: Ra3
# Qwen US move: Ra3 Move number: 41
# Qwen CN move: e8e1 Move number: 42
# Qwen US move: Kf2 Move number: 43
# Qwen CN move: d8h4 Move number: 44
# Qwen US move: g2g3 Move number: 45
# Qwen CN move: h4e7 Move number: 46
# Qwen US move: f2g2 Move number: 47
# Qwen CN move: g6f4 Move number: 48
# Qwen US move: g3f4 Move number: 49
# Qwen CN move: e7e2 Move number: 50
# Qwen US move: Kh3 Move number: 51
# Qwen CN move: e2f3 Move number: 52
# Game 9 result: 0-1
#
#
# Starting game 10...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: f3e5 Move number: 5
# Qwen CN move: d7d6 Move number: 6
# Qwen US move: e5f3 Move number: 7
# Qwen CN move: f6e4 Move number: 8
# Invalid move by US. Move: Nxe4
# New Move: a3
# Qwen US move: a3 Move number: 9
# Qwen CN move: d6d5 Move number: 10
# Qwen US move: c2c4 Move number: 11
# Qwen CN move: c8e6 Move number: 12
# Qwen US move: b1c3 Move number: 13
# Qwen CN move: b8c6 Move number: 14
# Qwen US move: c4d5 Move number: 15
# Qwen CN move: e4c3 Move number: 16
# Invalid move by US. Move: Nxe4
# New Move: bxc3
# Qwen US move: bxc3 Move number: 17
# Qwen CN move: e6d5 Move number: 18
# Qwen US move: d2d4 Move number: 19
# Qwen CN move: c6a5 Move number: 20
# Qwen US move: f1d3 Move number: 21
# Qwen CN move: a5b3 Move number: 22
# Qwen US move: a1b1 Move number: 23
# Qwen CN move: b3c1 Move number: 24
# Qwen US move: Ng5 Move number: 25
# Qwen CN move: c1d3 Move number: 26
# Qwen US move: Kf1 Move number: 27
# Qwen CN move: d8g5 Move number: 28
# Qwen US move: Qe2+ Move number: 29
# Qwen CN move: e8d8 Move number: 30
# Qwen US move: Qe8+ Move number: 31
# Qwen CN move: d8e8 Move number: 32
# Qwen US move: f2f3 Move number: 33
# Qwen CN move: d3f4 Move number: 34
# Qwen US move: g2g4 Move number: 35
# Qwen CN move: d5c4 Move number: 36
# Qwen US move: f1g1 Move number: 37
# Qwen CN move: g5h4 Move number: 38
# Qwen US move: Rxb7 Move number: 39
# Qwen CN move: h4e1 Move number: 40
# Game 10 result: 0-1
#
#
# Starting game 11...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Invalid move by US. Move: Nbd2
# New Move: f3
# Qwen US move: f3 Move number: 9
# Qwen CN move: c7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: d7d5 Move number: 12
# Qwen US move: h2h4 Move number: 13
# Qwen CN move: h7h5 Move number: 14
# Qwen US move: c1g5 Move number: 15
# Qwen CN move: f8e7 Move number: 16
# Qwen US move: Bxe7 Move number: 17
# Qwen CN move: g8e7 Move number: 18
# Qwen US move: Nxb5 Move number: 19
# Qwen CN move: c6b5 Move number: 20
# Qwen US move: Qd2 Move number: 21
# Qwen CN move: c8d7 Move number: 22
# Qwen US move: Qe2 Move number: 23
# Qwen CN move: d8a5 Move number: 24
# Qwen US move: e2d2 Move number: 25
# Qwen CN move: a5d2 Move number: 26
# Qwen US move: e1d2 Move number: 27
# Qwen CN move: e8c8 Move number: 28
# Qwen US move: f1d3 Move number: 29
# Qwen CN move: d5e4 Move number: 30
# Qwen US move: Bxb5 Move number: 31
# Qwen CN move: d7b5 Move number: 32
# Qwen US move: Ke1 Move number: 33
# Qwen CN move: b5a6 Move number: 34
# Qwen US move: Rd1 Move number: 35
# Qwen CN move: e4e3 Move number: 36
# Qwen US move: Rd2 Move number: 37
# Qwen CN move: e3d2 Move number: 38
# Qwen US move: Kf2 Move number: 39
# Qwen CN move: c8b8 Move number: 40
# Invalid move by US. Move: Rd2
# New Move: b4
# Qwen US move: b4 Move number: 41
# Qwen CN move: d8d4 Move number: 42
# Qwen US move: b4b5 Move number: 43
# Qwen CN move: a6b5 Move number: 44
# Qwen US move: h1b1 Move number: 45
# Qwen CN move: d2d1q Move number: 46
# Qwen US move: b1d1 Move number: 47
# Qwen CN move: d4d1 Move number: 48
# Qwen US move: Kg3 Move number: 49
# Qwen CN move: e7f5 Move number: 50
# Qwen US move: Kh2 Move number: 51
# Qwen CN move: b5c6 Move number: 52
# Qwen US move: g3 Move number: 53
# Qwen CN move: c6f3 Move number: 54
# Qwen US move: Kh3 Move number: 55
# Qwen CN move: d1h1 Move number: 56
# Game 11 result: 0-1
#
#
# Starting game 12...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: g7g6 Move number: 6
# Qwen US move: Bxc6 Move number: 7
# Qwen CN move: b7c6 Move number: 8
# Qwen US move: Ng5 Move number: 9
# Qwen CN move: e7e5 Move number: 10
# Qwen US move: Nh3 Move number: 11
# Qwen CN move: d7d5 Move number: 12
# Qwen US move: Ng5 Move number: 13
# Qwen CN move: d8g5 Move number: 14
# Qwen US move: exd5 Move number: 15
# Qwen CN move: g5g2 Move number: 16
# Qwen US move: Qe2 Move number: 17
# Qwen CN move: g2h1 Move number: 18
# Qwen US move: e2f1 Move number: 19
# Qwen CN move: h1e4 Move number: 20
# Qwen US move: Qe2 Move number: 21
# Qwen CN move: e4h1 Move number: 22
# Qwen US move: Qf1 Move number: 23
# Qwen CN move: h1e4 Move number: 24
# Qwen US move: f1e2 Move number: 25
# Qwen CN move: e4h1 Move number: 26
# Qwen US move: e2f1 Move number: 27
# Qwen CN move: h1e4 Move number: 28
# Qwen US move: Qe2 Move number: 29
# Qwen CN move: e4h1 Move number: 30
# Qwen US move: e2f1 Move number: 31
# Qwen CN move: h1f1 Move number: 32
# Qwen US move: e1f1 Move number: 33
# Qwen CN move: c6d5 Move number: 34
# Qwen US move: b1c3 Move number: 35
# Qwen CN move: c8a6 Move number: 36
# Qwen US move: Kg2 Move number: 37
# Qwen CN move: d5d4 Move number: 38
# Qwen US move: c3e4 Move number: 39
# Qwen CN move: a6b7 Move number: 40
# Qwen US move: Kf1 Move number: 41
# Qwen CN move: b7e4 Move number: 42
# Qwen US move: b2b4 Move number: 43
# Qwen CN move: f7f6 Move number: 44
# Qwen US move: d2d3 Move number: 45
# Qwen CN move: e4f3 Move number: 46
# Qwen US move: b4c5 Move number: 47
# Qwen CN move: f8c5 Move number: 48
# Qwen US move: Bd2 Move number: 49
# Qwen CN move: h7h5 Move number: 50
# Qwen US move: Bh6 Move number: 51
# Qwen CN move: h8h6 Move number: 52
# Qwen US move: Rd1 Move number: 53
# Qwen CN move: f3d1 Move number: 54
# Qwen US move: f2f4 Move number: 55
# Qwen CN move: g8e7 Move number: 56
# Qwen US move: a2a4 Move number: 57
# Qwen CN move: e5f4 Move number: 58
# Qwen US move: c2c3 Move number: 59
# Qwen CN move: d4c3 Move number: 60
# Qwen US move: d3d4 Move number: 61
# Qwen CN move: c5d6 Move number: 62
# Qwen US move: f1e1 Move number: 63
# Qwen CN move: d1a4 Move number: 64
# Qwen US move: Ke2 Move number: 65
# Qwen CN move: a8d8 Move number: 66
# Qwen US move: h2h3 Move number: 67
# Qwen CN move: c3c2 Move number: 68
# Qwen US move: e2d2 Move number: 69
# Qwen CN move: f4f3 Move number: 70
# Qwen US move: d4d5 Move number: 71
# Qwen CN move: d6b4 Move number: 72
# Qwen US move: d2c1 Move number: 73
# Qwen CN move: b4a3 Move number: 74
# Qwen US move: Kd2 Move number: 75
# Qwen CN move: c2c1q Move number: 76
# Qwen US move: d2d3 Move number: 77
# Qwen CN move: f6f5 Move number: 78
# Qwen US move: Kd4 Move number: 79
# Qwen CN move: d8d5 Move number: 80
# Game 12 result: 0-1
#
#
# Starting game 13...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nh4 Move number: 5
# Qwen CN move: e7e6 Move number: 6
# Qwen US move: h4f3 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: Nh4 Move number: 9
# Qwen CN move: f6e4 Move number: 10
# Qwen US move: g2g3 Move number: 11
# Qwen CN move: d7d5 Move number: 12
# Qwen US move: d2d3 Move number: 13
# Qwen CN move: e4d6 Move number: 14
# Qwen US move: Nf5 Move number: 15
# Qwen CN move: d6f5 Move number: 16
# Qwen US move: f1g2 Move number: 17
# Qwen CN move: g7g6 Move number: 18
# Qwen US move: h2h4 Move number: 19
# Qwen CN move: h7h5 Move number: 20
# Qwen US move: b1c3 Move number: 21
# Qwen CN move: c8d7 Move number: 22
# Qwen US move: c1g5 Move number: 23
# Qwen CN move: f7f6 Move number: 24
# Qwen US move: Bh6 Move number: 25
# Qwen CN move: f8h6 Move number: 26
# Qwen US move: e1g1 Move number: 27
# Qwen CN move: e8g8 Move number: 28
# Invalid move by US. Move: Nh4
# New Move: Be4
# Qwen US move: Be4 Move number: 29
# Qwen CN move: d5e4 Move number: 30
# Qwen US move: Qe1 Move number: 31
# Qwen CN move: e4d3 Move number: 32
# Qwen US move: e1e4 Move number: 33
# Qwen CN move: c6e5 Move number: 34
# Qwen US move: f2f4 Move number: 35
# Qwen CN move: e5g4 Move number: 36
# Qwen US move: a1e1 Move number: 37
# Qwen CN move: d3d2 Move number: 38
# Qwen US move: Qxb7 Move number: 39
# Qwen CN move: a8b8 Move number: 40
# Qwen US move: b7a6 Move number: 41
# Qwen CN move: d2e1q Move number: 42
# Invalid move by US. Move: Qa6xd2
# New Move: Nb1
# Qwen US move: Nb1 Move number: 43
# Qwen CN move: e1g3 Move number: 44
# Qwen US move: g1h1 Move number: 45
# Qwen CN move: g3h2 Move number: 46
# Game 13 result: 0-1
#
#
# Starting game 14...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Invalid move by US. Move: Nxe5
# New Move: f3
# Qwen US move: f3 Move number: 9
# Qwen CN move: c7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: d7d5 Move number: 12
# Qwen US move: e4d5 Move number: 13
# Qwen CN move: g8f6 Move number: 14
# Qwen US move: d5c6 Move number: 15
# Qwen CN move: b7c6 Move number: 16
# Qwen US move: Nd5 Move number: 17
# Qwen CN move: f6d5 Move number: 18
# Qwen US move: Bd3 Move number: 19
# Qwen CN move: f8b4 Move number: 20
# Qwen US move: Ke2 Move number: 21
# Qwen CN move: d5f4 Move number: 22
# Qwen US move: Ke3 Move number: 23
# Qwen CN move: f4d3 Move number: 24
# Qwen US move: d1d3 Move number: 25
# Qwen CN move: e8g8 Move number: 26
# Qwen US move: e3f2 Move number: 27
# Qwen CN move: a8b8 Move number: 28
# Qwen US move: c2c3 Move number: 29
# Qwen CN move: b4d6 Move number: 30
# Invalid move by US. Move: Qg1
# New Move: Qe2
# Qwen US move: Qe2 Move number: 31
# Qwen CN move: f8e8 Move number: 32
# Qwen US move: Qxe8+ Move number: 33
# Qwen CN move: d8e8 Move number: 34
# Qwen US move: h1e1 Move number: 35
# Qwen CN move: e8f8 Move number: 36
# Qwen US move: b2b4 Move number: 37
# Qwen CN move: h7h6 Move number: 38
# Qwen US move: c1a3 Move number: 39
# Qwen CN move: g8h7 Move number: 40
# Qwen US move: Bb2 Move number: 41
# Qwen CN move: c6c5 Move number: 42
# Qwen US move: b2a3 Move number: 43
# Qwen CN move: c5d4 Move number: 44
# Qwen US move: Bb2 Move number: 45
# Qwen CN move: d4d3 Move number: 46
# Qwen US move: a1d1 Move number: 47
# Qwen CN move: g6f4 Move number: 48
# Qwen US move: f2f1 Move number: 49
# Qwen CN move: f7f6 Move number: 50
# Qwen US move: Re3 Move number: 51
# Qwen CN move: c8f5 Move number: 52
# Qwen US move: g2g4 Move number: 53
# Qwen CN move: f5g6 Move number: 54
# Qwen US move: c3c4 Move number: 55
# Qwen CN move: d6b4 Move number: 56
# Qwen US move: Re2 Move number: 57
# Qwen CN move: d3e2 Move number: 58
# Qwen US move: Kg1 Move number: 59
# Qwen CN move: e2d1q Move number: 60
# Qwen US move: g1f2 Move number: 61
# Qwen CN move: d1e1 Move number: 62
# Game 14 result: 0-1
#
#
# Starting game 15...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: f3e5 Move number: 5
# Qwen CN move: d7d6 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: d6e5 Move number: 8
# Qwen US move: f1b5 Move number: 9
# Qwen CN move: b8c6 Move number: 10
# Qwen US move: d2d3 Move number: 11
# Qwen CN move: f8d6 Move number: 12
# Qwen US move: f2f4 Move number: 13
# Qwen CN move: e5f4 Move number: 14
# Qwen US move: d3d4 Move number: 15
# Qwen CN move: e8g8 Move number: 16
# Qwen US move: e4e5 Move number: 17
# Qwen CN move: c8g4 Move number: 18
# Qwen US move: d1d2 Move number: 19
# Qwen CN move: c6e5 Move number: 20
# Qwen US move: d4e5 Move number: 21
# Qwen CN move: d6e5 Move number: 22
# Qwen US move: Be2 Move number: 23
# Qwen CN move: e5c3 Move number: 24
# Qwen US move: Bf1 Move number: 25
# Qwen CN move: c3d2 Move number: 26
# Qwen US move: c1d2 Move number: 27
# Qwen CN move: d8e7 Move number: 28
# Qwen US move: Be3 Move number: 29
# Qwen CN move: e7e3 Move number: 30
# Qwen US move: Be2 Move number: 31
# Qwen CN move: e3e2 Move number: 32
# Game 15 result: 0-1
#
#
# Starting game 16...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1c4 Move number: 5
# Qwen CN move: f8c5 Move number: 6
# Qwen US move: Bxf7+ Move number: 7
# Qwen CN move: e8f7 Move number: 8
# Qwen US move: Nxe5+ Move number: 9
# Qwen CN move: c6e5 Move number: 10
# Qwen US move: d1h5 Move number: 11
# Qwen CN move: f7f8 Move number: 12
# Qwen US move: h5e5 Move number: 13
# Qwen CN move: d7d6 Move number: 14
# Qwen US move: e5g3 Move number: 15
# Qwen CN move: f8f7 Move number: 16
# Qwen US move: Qxg7+ Move number: 17
# Qwen CN move: f7g7 Move number: 18
# Qwen US move: h1f1 Move number: 19
# Qwen CN move: d8e8 Move number: 20
# Qwen US move: b1c3 Move number: 21
# Qwen CN move: g8f6 Move number: 22
# Qwen US move: Nd5 Move number: 23
# Qwen CN move: f6d5 Move number: 24
# Qwen US move: Rh1 Move number: 25
# Qwen CN move: e8e4 Move number: 26
# Invalid move by US. Move: Ke1
# New Move: Kf1
# Qwen US move: Kf1 Move number: 27
# Qwen CN move: h8e8 Move number: 28
# Qwen US move: Rg1 Move number: 29
# Qwen CN move: e4e1 Move number: 30
# Game 16 result: 0-1
#
#
# Starting game 17...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: f3e5 Move number: 5
# Qwen CN move: d7d6 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: d6e5 Move number: 8
# Qwen US move: f1b5 Move number: 9
# Qwen CN move: b8c6 Move number: 10
# Qwen US move: Bxc6+ Move number: 11
# Qwen CN move: b7c6 Move number: 12
# Qwen US move: d2d3 Move number: 13
# Qwen CN move: a7a5 Move number: 14
# Qwen US move: d1f3 Move number: 15
# Qwen CN move: f8d6 Move number: 16
# Qwen US move: Qxf6 Move number: 17
# Qwen CN move: g7f6 Move number: 18
# Qwen US move: c1e3 Move number: 19
# Qwen CN move: h8g8 Move number: 20
# Qwen US move: e1c1 Move number: 21
# Qwen CN move: c8e6 Move number: 22
# Qwen US move: Bd4 Move number: 23
# Qwen CN move: e5d4 Move number: 24
# Qwen US move: Nd5 Move number: 25
# Qwen CN move: c6d5 Move number: 26
# Qwen US move: e4d5 Move number: 27
# Qwen CN move: d6f4 Move number: 28
# Qwen US move: Rd2 Move number: 29
# Qwen CN move: d8d5 Move number: 30
# Qwen US move: c1d1 Move number: 31
# Qwen CN move: d5g2 Move number: 32
# Qwen US move: h1e1 Move number: 33
# Qwen CN move: f4d2 Move number: 34
# Qwen US move: Rxe6+ Move number: 35
# Qwen CN move: f7e6 Move number: 36
# Qwen US move: c2c3 Move number: 37
# Qwen CN move: g2f1 Move number: 38
# Qwen US move: d1c2 Move number: 39
# Qwen CN move: a8b8 Move number: 40
# Qwen US move: b2b4 Move number: 41
# Qwen CN move: f1c1 Move number: 42
# Qwen US move: c2b3 Move number: 43
# Qwen CN move: c1c3 Move number: 44
# Qwen US move: b3a4 Move number: 45
# Qwen CN move: c3b4 Move number: 46
# Game 17 result: 0-1
#
#
# Starting game 18...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nh4 Move number: 5
# Qwen CN move: g8f6 Move number: 6
# Qwen US move: Nf3 Move number: 7
# Qwen CN move: f6e4 Move number: 8
# Qwen US move: f1b5 Move number: 9
# Qwen CN move: e7e6 Move number: 10
# Qwen US move: Bxc6 Move number: 11
# Qwen CN move: b7c6 Move number: 12
# Qwen US move: Ng5 Move number: 13
# Qwen CN move: d8g5 Move number: 14
# Qwen US move: e1g1 Move number: 15
# Qwen CN move: g5d8 Move number: 16
# Qwen US move: d2d3 Move number: 17
# Qwen CN move: e4f6 Move number: 18
# Qwen US move: d1f3 Move number: 19
# Qwen CN move: f8e7 Move number: 20
# Qwen US move: Qxf6 Move number: 21
# Qwen CN move: e7f6 Move number: 22
# Qwen US move: Nd2 Move number: 23
# Qwen CN move: d7d5 Move number: 24
# Qwen US move: d2b3 Move number: 25
# Qwen CN move: c8a6 Move number: 26
# Qwen US move: f1e1 Move number: 27
# Qwen CN move: e8g8 Move number: 28
# Qwen US move: b3c5 Move number: 29
# Qwen CN move: a6c8 Move number: 30
# Qwen US move: Re4 Move number: 31
# Qwen CN move: g8h8 Move number: 32
# Qwen US move: e4e3 Move number: 33
# Qwen CN move: e6e5 Move number: 34
# Qwen US move: c1d2 Move number: 35
# Qwen CN move: f8e8 Move number: 36
# Qwen US move: Re5 Move number: 37
# Qwen CN move: f6e5 Move number: 38
# Qwen US move: Na4 Move number: 39
# Qwen CN move: d8h4 Move number: 40
# Invalid move by US. Move: Na4
# New Move: h3
# Qwen US move: h3 Move number: 41
# Qwen CN move: c8h3 Move number: 42
# Qwen US move: d3d4 Move number: 43
# Qwen CN move: e5d4 Move number: 44
# Qwen US move: d2e3 Move number: 45
# Qwen CN move: d4e3 Move number: 46
# Qwen US move: f2e3 Move number: 47
# Qwen CN move: h4g3 Move number: 48
# Qwen US move: Rf1 Move number: 49
# Qwen CN move: g3g2 Move number: 50
# Game 18 result: 0-1
#
#
# Starting game 19...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: d7d6 Move number: 6
# Qwen US move: e5f3 Move number: 7
# Qwen CN move: f6e4 Move number: 8
# Qwen US move: d2d4 Move number: 9
# Qwen CN move: d6d5 Move number: 10
# Qwen US move: f1d3 Move number: 11
# Qwen CN move: f8d6 Move number: 12
# Qwen US move: Nfd2 Move number: 13
# Qwen CN move: e8g8 Move number: 14
# Qwen US move: Be2 Move number: 15
# Qwen CN move: b8c6 Move number: 16
# Invalid move by US. Move: Be3
# New Move: g3
# Qwen US move: g3 Move number: 17
# Qwen CN move: e4d2 Move number: 18
# Qwen US move: d1d2 Move number: 19
# Qwen CN move: f8e8 Move number: 20
# Qwen US move: e1g1 Move number: 21
# Qwen CN move: e8e2 Move number: 22
# Qwen US move: d2e2 Move number: 23
# Qwen CN move: c6d4 Move number: 24
# Qwen US move: Qe8+ Move number: 25
# Qwen CN move: d8e8 Move number: 26
# Qwen US move: Bg5 Move number: 27
# Qwen CN move: d4f3 Move number: 28
# Qwen US move: Kg2 Move number: 29
# Qwen CN move: f3g5 Move number: 30
# Qwen US move: Rh1 Move number: 31
# Qwen CN move: c8h3 Move number: 32
# Qwen US move: g2g1 Move number: 33
# Qwen CN move: g5f3 Move number: 34
# Game 19 result: 0-1
#
#
# Starting game 20...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Invalid move by US. Move: Nxe5
# New Move: f3
# Qwen US move: f3 Move number: 9
# Qwen CN move: c7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: d7d5 Move number: 12
# Qwen US move: h2h4 Move number: 13
# Qwen CN move: f8d6 Move number: 14
# Qwen US move: e4e5 Move number: 15
# Qwen CN move: d6e7 Move number: 16
# Qwen US move: Nxd5 Move number: 17
# Qwen CN move: e7h4 Move number: 18
# Qwen US move: Ke2 Move number: 19
# Qwen CN move: d8d5 Move number: 20
# Qwen US move: Rg1 Move number: 21
# Qwen CN move: c8e6 Move number: 22
# Qwen US move: Ke3 Move number: 23
# Qwen CN move: d5d8 Move number: 24
# Qwen US move: g2g3 Move number: 25
# Qwen CN move: g8h6 Move number: 26
# Qwen US move: f1d3 Move number: 27
# Qwen CN move: h4g5 Move number: 28
# Qwen US move: f3f4 Move number: 29
# Qwen CN move: g5e7 Move number: 30
# Qwen US move: Ke4 Move number: 31
# Qwen CN move: h6g4 Move number: 32
# Invalid move by US. Move: Ke5
# New Move: d5
# Qwen US move: d5 Move number: 33
# Qwen CN move: d8d5 Move number: 34
# Game 20 result: 0-1
#
#
# Starting game 21...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen US move: Bxc6 Move number: 7
# Qwen CN move: d7c6 Move number: 8
# Invalid move by US. Move: Nbd4
# New Move: g4
# Qwen US move: g4 Move number: 9
# Qwen CN move: c8g4 Move number: 10
# Qwen US move: h1g1 Move number: 11
# Qwen CN move: g4h5 Move number: 12
# Qwen US move: d2d3 Move number: 13
# Qwen CN move: d8f6 Move number: 14
# Qwen US move: g1g3 Move number: 15
# Qwen CN move: g8e7 Move number: 16
# Qwen US move: Rxg7 Move number: 17
# Qwen CN move: f8g7 Move number: 18
# Qwen US move: Ng5 Move number: 19
# Qwen CN move: h5d1 Move number: 20
# Qwen US move: Nxf7 Move number: 21
# Qwen CN move: f6f7 Move number: 22
# Qwen US move: Nd2 Move number: 23
# Qwen CN move: d1c2 Move number: 24
# Qwen US move: d2b3 Move number: 25
# Qwen CN move: c2b3 Move number: 26
# Qwen US move: a2b3 Move number: 27
# Qwen CN move: h8f8 Move number: 28
# Qwen US move: c1e3 Move number: 29
# Qwen CN move: a6a5 Move number: 30
# Qwen US move: Bd2 Move number: 31
# Qwen CN move: f7f2 Move number: 32
# Qwen US move: Kd1 Move number: 33
# Qwen CN move: f2f1 Move number: 34
# Qwen US move: Kc2 Move number: 35
# Qwen CN move: f1g2 Move number: 36
# Qwen US move: Kd1 Move number: 37
# Qwen CN move: f8f1 Move number: 38
# Qwen US move: Kc2 Move number: 39
# Qwen CN move: g7h6 Move number: 40
# Qwen US move: Kc3 Move number: 41
# Qwen CN move: g2d2 Move number: 42
# Qwen US move: c3c4 Move number: 43
# Qwen CN move: d2c2 Move number: 44
# Game 21 result: 0-1
#
#
# Starting game 22...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: g8f6 Move number: 6
# Qwen US move: e1g1 Move number: 7
# Qwen CN move: f6e4 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Qwen CN move: d7c6 Move number: 10
# Qwen US move: d1e2 Move number: 11
# Qwen CN move: e4g5 Move number: 12
# Qwen US move: e2e5 Move number: 13
# Qwen CN move: g5e6 Move number: 14
# Qwen US move: f1e1 Move number: 15
# Qwen CN move: f8e7 Move number: 16
# Qwen US move: Qxe6 Move number: 17
# Qwen CN move: c8e6 Move number: 18
# Qwen US move: d2d4 Move number: 19
# Qwen CN move: e8g8 Move number: 20
# Qwen US move: Nh4 Move number: 21
# Qwen CN move: e7h4 Move number: 22
# Qwen US move: c1f4 Move number: 23
# Qwen CN move: h4f2 Move number: 24
# Qwen US move: g1f2 Move number: 25
# Qwen CN move: d8d4 Move number: 26
# Qwen US move: f2g3 Move number: 27
# Qwen CN move: d4b2 Move number: 28
# Qwen US move: Re3 Move number: 29
# Qwen CN move: b2a1 Move number: 30
# Qwen US move: Bxc7 Move number: 31
# Qwen CN move: a1b1 Move number: 32
# Qwen US move: Rxe6 Move number: 33
# Qwen CN move: f7e6 Move number: 34
# Qwen US move: g3h3 Move number: 35
# Qwen CN move: b1f1 Move number: 36
# Qwen US move: c7e5 Move number: 37
# Qwen CN move: f8f3 Move number: 38
# Qwen US move: h3g4 Move number: 39
# Qwen CN move: f1g2 Move number: 40
# Qwen US move: e5g3 Move number: 41
# Qwen CN move: f3f5 Move number: 42
# Qwen US move: g4h4 Move number: 43
# Qwen CN move: g2f3 Move number: 44
# Qwen US move: Bxd6 Move number: 45
# Qwen CN move: g7g5 Move number: 46
# Game 22 result: 0-1
#
#
# Starting game 23...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen US move: b5a4 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Qwen CN move: d7c6 Move number: 10
# Qwen US move: b1c3 Move number: 11
# Qwen CN move: f8d6 Move number: 12
# Qwen US move: Nh4 Move number: 13
# Qwen CN move: f6e4 Move number: 14
# Qwen US move: Nxe4 Move number: 15
# Qwen CN move: d8h4 Move number: 16
# Qwen US move: e4d6 Move number: 17
# Qwen CN move: c7d6 Move number: 18
# Qwen US move: Qe2 Move number: 19
# Qwen CN move: c6c5 Move number: 20
# Qwen US move: e1g1 Move number: 21
# Qwen CN move: c8d7 Move number: 22
# Qwen US move: Qe4 Move number: 23
# Qwen CN move: h4e4 Move number: 24
# Qwen US move: f2f4 Move number: 25
# Qwen CN move: d7c6 Move number: 26
# Qwen US move: f1f2 Move number: 27
# Qwen CN move: e4e1 Move number: 28
# Qwen US move: Rf1 Move number: 29
# Qwen CN move: e1e2 Move number: 30
# Qwen US move: f1f2 Move number: 31
# Qwen CN move: e2d1 Move number: 32
# Qwen US move: f2f1 Move number: 33
# Qwen CN move: d1e2 Move number: 34
# Qwen US move: f1f3 Move number: 35
# Qwen CN move: c6f3 Move number: 36
# Qwen US move: g2f3 Move number: 37
# Qwen CN move: e2e1 Move number: 38
# Qwen US move: Kg2 Move number: 39
# Qwen CN move: e1e2 Move number: 40
# Qwen US move: g2g1 Move number: 41
# Qwen CN move: e2e1 Move number: 42
# Qwen US move: Kg2 Move number: 43
# Qwen CN move: e1e2 Move number: 44
# Qwen US move: Kh3 Move number: 45
# Qwen CN move: e2f3 Move number: 46
# Qwen US move: h3h4 Move number: 47
# Qwen CN move: f3f4 Move number: 48
# Qwen US move: h4h3 Move number: 49
# Qwen CN move: f4f3 Move number: 50
# Qwen US move: Kh4 Move number: 51
# Qwen CN move: h7h5 Move number: 52
# Qwen US move: Kg5 Move number: 53
# Qwen CN move: f3f4 Move number: 54
# Game 23 result: 0-1
#
#
# Starting game 24...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: d7d6 Move number: 6
# Qwen US move: e5f3 Move number: 7
# Qwen CN move: f6e4 Move number: 8
# Qwen US move: Nh4 Move number: 9
# Qwen CN move: d8h4 Move number: 10
# Qwen US move: g2g3 Move number: 11
# Qwen CN move: h4d8 Move number: 12
# Qwen US move: f1g2 Move number: 13
# Qwen CN move: e4f6 Move number: 14
# Qwen US move: d2d4 Move number: 15
# Qwen CN move: f8e7 Move number: 16
# Qwen US move: e1g1 Move number: 17
# Qwen CN move: e8g8 Move number: 18
# Qwen US move: Be4 Move number: 19
# Qwen CN move: f6e4 Move number: 20
# Qwen US move: b1c3 Move number: 21
# Qwen CN move: e4c3 Move number: 22
# Qwen US move: b2c3 Move number: 23
# Qwen CN move: f8e8 Move number: 24
# Qwen US move: Qe2 Move number: 25
# Qwen CN move: e7f6 Move number: 26
# Qwen US move: e2h5 Move number: 27
# Qwen CN move: c8d7 Move number: 28
# Qwen US move: c1d2 Move number: 29
# Qwen CN move: b8c6 Move number: 30
# Qwen US move: Qxh7+ Move number: 31
# Qwen CN move: g8h7 Move number: 32
# Qwen US move: Bg5 Move number: 33
# Qwen CN move: h7g8 Move number: 34
# Qwen US move: Bh6 Move number: 35
# Qwen CN move: c6e7 Move number: 36
# Invalid move by US. Move: Bh6
# New Move: f3
# Qwen US move: f3 Move number: 37
# Qwen CN move: e7f5 Move number: 38
# Qwen US move: h6g7 Move number: 39
# Qwen CN move: f6g7 Move number: 40
# Qwen US move: g3g4 Move number: 41
# Qwen CN move: f5e3 Move number: 42
# Qwen US move: f1e1 Move number: 43
# Qwen CN move: d8h4 Move number: 44
# Qwen US move: Re2 Move number: 45
# Qwen CN move: e3g4 Move number: 46
# Qwen US move: Rxe8+ Move number: 47
# Qwen CN move: a8e8 Move number: 48
# Qwen US move: fxg4 Move number: 49
# Qwen CN move: e8e2 Move number: 50
# Qwen US move: d5 Move number: 51
# Qwen CN move: h4f2 Move number: 52
# Qwen US move: g1h1 Move number: 53
# Qwen CN move: f2h2 Move number: 54
# Game 24 result: 0-1
#
#
# Starting game 25...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Invalid move by US. Move: Nxe5
# New Move: f3
# Qwen US move: f3 Move number: 9
# Qwen CN move: c7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: d7d5 Move number: 12
# Qwen US move: h2h4 Move number: 13
# Qwen CN move: h7h5 Move number: 14
# Qwen US move: c1g5 Move number: 15
# Qwen CN move: f7f6 Move number: 16
# Qwen US move: Bh6 Move number: 17
# Qwen CN move: h8h6 Move number: 18
# Qwen US move: Nxd5 Move number: 19
# Qwen CN move: c6d5 Move number: 20
# Qwen US move: Qd3 Move number: 21
# Qwen CN move: f8b4 Move number: 22
# Qwen US move: Qc3 Move number: 23
# Qwen CN move: b4c3 Move number: 24
# Qwen US move: b2c3 Move number: 25
# Qwen CN move: d8a5 Move number: 26
# Qwen US move: a1b1 Move number: 27
# Qwen CN move: a5c3 Move number: 28
# Qwen US move: e1d1 Move number: 29
# Qwen CN move: c3d4 Move number: 30
# Qwen US move: Ke2 Move number: 31
# Qwen CN move: d5e4 Move number: 32
# Qwen US move: Rxb7 Move number: 33
# Qwen CN move: c8b7 Move number: 34
# Qwen US move: g3 Move number: 35
# Qwen CN move: e4f3 Move number: 36
# Qwen US move: Ke1 Move number: 37
# Qwen CN move: f3f2 Move number: 38
# Invalid move by US. Move: Ke1
# New Move: Ke2
# Qwen US move: Ke2 Move number: 39
# Qwen CN move: g6e5 Move number: 40
# Qwen US move: Rh3 Move number: 41
# Qwen CN move: b7f3 Move number: 42
# Game 25 result: 0-1
#
#
# Starting game 26...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: f3e5 Move number: 5
# Qwen CN move: d7d6 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: d6e5 Move number: 8
# Qwen US move: f2f4 Move number: 9
# Qwen CN move: b8c6 Move number: 10
# Invalid move by US. Move: Nxe5
# New Move: h3
# Qwen US move: h3 Move number: 11
# Qwen CN move: e5f4 Move number: 12
# Qwen US move: f1b5 Move number: 13
# Qwen CN move: f8e7 Move number: 14
# Qwen US move: d2d3 Move number: 15
# Qwen CN move: e8g8 Move number: 16
# Qwen US move: b5c6 Move number: 17
# Qwen CN move: b7c6 Move number: 18
# Invalid move by US. Move: Nbd2
# New Move: Rb1
# Qwen US move: Rb1 Move number: 19
# Qwen CN move: e7d6 Move number: 20
# Qwen US move: e1g1 Move number: 21
# Qwen CN move: f6d7 Move number: 22
# Qwen US move: c1f4 Move number: 23
# Qwen CN move: d7e5 Move number: 24
# Qwen US move: d1h5 Move number: 25
# Qwen CN move: f7f6 Move number: 26
# Qwen US move: Qxe5 Move number: 27
# Qwen CN move: f6e5 Move number: 28
# Qwen US move: Bh6 Move number: 29
# Qwen CN move: g7h6 Move number: 30
# Qwen US move: Rxf8+ Move number: 31
# Qwen CN move: d8f8 Move number: 32
# Qwen US move: Rd1 Move number: 33
# Qwen CN move: c8e6 Move number: 34
# Qwen US move: c3a4 Move number: 35
# Qwen CN move: g8h8 Move number: 36
# Qwen US move: d1f1 Move number: 37
# Qwen CN move: f8f1 Move number: 38
# Qwen US move: g1f1 Move number: 39
# Qwen CN move: e6a2 Move number: 40
# Qwen US move: g3 Move number: 41
# Qwen CN move: a2e6 Move number: 42
# Qwen US move: Ke2 Move number: 43
# Qwen CN move: e6h3 Move number: 44
# Qwen US move: g4 Move number: 45
# Qwen CN move: h3g4 Move number: 46
# Qwen US move: Ke1 Move number: 47
# Qwen CN move: a8f8 Move number: 48
# Invalid move by US. Move: Nd2
# New Move: Nc5
# Qwen US move: Nc5 Move number: 49
# Qwen CN move: d6c5 Move number: 50
# Qwen US move: d4 Move number: 51
# Qwen CN move: c5d4 Move number: 52
# Qwen US move: e1d2 Move number: 53
# Qwen CN move: h8g7 Move number: 54
# Qwen US move: c2c3 Move number: 55
# Qwen CN move: d4b6 Move number: 56
# Qwen US move: c3c4 Move number: 57
# Qwen CN move: b6d4 Move number: 58
# Qwen US move: Ke1 Move number: 59
# Qwen CN move: g7g6 Move number: 60
# Qwen US move: e1d2 Move number: 61
# Qwen CN move: f8f2 Move number: 62
# Qwen US move: Kc1 Move number: 63
# Qwen CN move: d4b2 Move number: 64
# Qwen US move: c1b1 Move number: 65
# Qwen CN move: b2c3 Move number: 66
# Qwen US move: b1c1 Move number: 67
# Qwen CN move: g6g5 Move number: 68
# Invalid move by US. Move:  Kb1
# New Move: Kb1
# Qwen US move: Kb1 Move number: 69
# Qwen CN move: c3d4 Move number: 70
# Qwen US move: Kc1 Move number: 71
# Qwen CN move: d4e3 Move number: 72
# Qwen US move: c1b1 Move number: 73
# Qwen CN move: g4f3 Move number: 74
# Qwen US move: b1a1 Move number: 75
# Qwen CN move: f3e4 Move number: 76
# Qwen US move: c4c5 Move number: 77
# Qwen CN move: e3d4 Move number: 78
# Game 26 result: 0-1
#
#
# Starting game 27...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Qwen US move: c2c4 Move number: 9
# Qwen CN move: c7c5 Move number: 10
# Qwen US move: Be2 Move number: 11
# Qwen CN move: c5d4 Move number: 12
# Qwen US move: d1d4 Move number: 13
# Qwen CN move: g8f6 Move number: 14
# Qwen US move: b1c3 Move number: 15
# Qwen CN move: b7b6 Move number: 16
# Qwen US move: Qxd7+ Move number: 17
# Qwen CN move: f6d7 Move number: 18
# Invalid move by US. Move: Nc3
# New Move: Bf3
# ...
# Qwen US move: c3b1 Move number: 17
# Qwen CN move: d8c7 Move number: 18
# Qwen US move: b1a3 Move number: 19
# Qwen CN move: a7a6 Move number: 20
# Qwen US move: Nc4 Move number: 21
# Qwen CN move: b7b5 Move number: 22
# Qwen US move: c4d2 Move number: 23
# Qwen CN move: f8d6 Move number: 24
# Qwen US move: Nf3 Move number: 25
# Qwen CN move: f6g4 Move number: 26
# Qwen US move: Ng5 Move number: 27
# Qwen CN move: d6g3 Move number: 28
# Qwen US move: e1e2 Move number: 29
# Qwen CN move: g3f4 Move number: 30
# Qwen US move: g2g3 Move number: 31
# Qwen CN move: f4c1 Move number: 32
# Qwen US move: Nh3 Move number: 33
# Qwen CN move: c1h6 Move number: 34
# Qwen US move: Nf4 Move number: 35
# Qwen CN move: h6f4 Move number: 36
# Qwen US move: Ke1 Move number: 37
# Qwen CN move: f4g3 Move number: 38
# Qwen US move: Ke2 Move number: 39
# Qwen CN move: c7f4 Move number: 40
# Qwen US move: Rg1 Move number: 41
# Qwen CN move: f4f2 Move number: 42
# Game 93 result: 0-1
#
#
# Starting game 94...
# Qwen US move: d2d4 Move number: 1
# Qwen CN move: d7d5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: c2c4 Move number: 5
# Qwen CN move: e7e6 Move number: 6
# Qwen US move: b1c3 Move number: 7
# Qwen CN move: c7c5 Move number: 8
# Qwen US move: c4d5 Move number: 9
# Qwen CN move: c5d4 Move number: 10
# Qwen US move: d1d4 Move number: 11
# Qwen CN move: e6d5 Move number: 12
# Qwen US move: Qxa7 Move number: 13
# Qwen CN move: a8a7 Move number: 14
# Qwen US move: e2e4 Move number: 15
# Qwen CN move: f8b4 Move number: 16
# Qwen US move: f1b5 Move number: 17
# Qwen CN move: c8d7 Move number: 18
# Qwen US move: Bxd7+ Move number: 19
# Qwen CN move: b8d7 Move number: 20
# Qwen US move: e1g1 Move number: 21
# Qwen CN move: e8g8 Move number: 22
# Qwen US move: c1g5 Move number: 23
# Qwen CN move: d8a8 Move number: 24
# Qwen US move: Bh6 Move number: 25
# Qwen CN move: g7h6 Move number: 26
# Qwen US move: Nh4 Move number: 27
# Qwen CN move: g8h8 Move number: 28
# Qwen US move: Ng6+ Move number: 29
# Qwen CN move: h7g6 Move number: 30
# Qwen US move: Nxd5 Move number: 31
# Qwen CN move: f8g8 Move number: 32
# Qwen US move: d5b4 Move number: 33
# Qwen CN move: a8f8 Move number: 34
# Qwen US move: b4d5 Move number: 35
# Qwen CN move: b7b5 Move number: 36
# Qwen US move: a1c1 Move number: 37
# Qwen CN move: f6h7 Move number: 38
# Qwen US move: f1d1 Move number: 39
# Qwen CN move: h6h5 Move number: 40
# Qwen US move: Ne7 Move number: 41
# Qwen CN move: f8e7 Move number: 42
# Qwen US move: Rxd7 Move number: 43
# Qwen CN move: a7d7 Move number: 44
# Qwen US move: h2h3 Move number: 45
# Qwen CN move: g8f8 Move number: 46
# Qwen US move: e4e5 Move number: 47
# Qwen CN move: e7e5 Move number: 48
# Qwen US move: g2g4 Move number: 49
# Qwen CN move: e5b2 Move number: 50
# Qwen US move: g5 Move number: 51
# Qwen CN move: b2c1 Move number: 52
# Qwen US move: g1h2 Move number: 53
# Qwen CN move: c1f4 Move number: 54
# Qwen US move: h2g2 Move number: 55
# Qwen CN move: f4g5 Move number: 56
# Qwen US move: g2f1 Move number: 57
# Qwen CN move: d7d1 Move number: 58
# Qwen US move: Ke2 Move number: 59
# Qwen CN move: g5d2 Move number: 60
# Qwen US move: e2f3 Move number: 61
# Qwen CN move: d2d5 Move number: 62
# Qwen US move: f3f4 Move number: 63
# Qwen CN move: g6g5 Move number: 64
# Qwen US move: f4g3 Move number: 65
# Qwen CN move: h5h4 Move number: 66
# Qwen US move: g3h2 Move number: 67
# Qwen CN move: d1h1 Move number: 68
# Game 94 result: 0-1
#
#
# Starting game 95...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: d7d6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Qwen CN move: c5d4 Move number: 6
# Qwen US move: Nxd4 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: b1c3 Move number: 9
# Qwen CN move: a7a6 Move number: 10
# Qwen US move: Nf3 Move number: 11
# Qwen CN move: b8d7 Move number: 12
# Qwen US move: f1d3 Move number: 13
# Qwen CN move: e7e6 Move number: 14
# Invalid move by US. Move: Nc3
# New Move: Bb5
# Qwen US move: Bb5 Move number: 15
# Qwen CN move: a6b5 Move number: 16
# Invalid move by US. Move: Nxe6
# New Move: Nxb5
# Qwen US move: Nxb5 Move number: 17
# Qwen CN move: d8a5 Move number: 18
# Qwen US move: Nc3 Move number: 19
# Qwen CN move: f6e4 Move number: 20
# Qwen US move: c1d2 Move number: 21
# Qwen CN move: e4d2 Move number: 22
# Qwen US move: f3d2 Move number: 23
# Qwen CN move: f8e7 Move number: 24
# Qwen US move: d2c4 Move number: 25
# Qwen CN move: a5c5 Move number: 26
# Qwen US move: Ne5 Move number: 27
# Qwen CN move: c5e5 Move number: 28
# Qwen US move: d1e2 Move number: 29
# Qwen CN move: e5e2 Move number: 30
# Qwen US move: Kxe2 Move number: 31
# Qwen CN move: e8g8 Move number: 32
# Qwen US move: h1d1 Move number: 33
# Qwen CN move: d7f6 Move number: 34
# Qwen US move: c3b5 Move number: 35
# Qwen CN move: d6d5 Move number: 36
# Qwen US move: Rd2 Move number: 37
# Qwen CN move: c8d7 Move number: 38
# Qwen US move: c2c4 Move number: 39
# Qwen CN move: g8h8 Move number: 40
# Qwen US move: b5c7 Move number: 41
# Qwen CN move: a8d8 Move number: 42
# Qwen US move: Rxd5 Move number: 43
# Qwen CN move: e6d5 Move number: 44
# Invalid move by US. Move: Rxd8
# New Move: Ke3
# Qwen US move: Ke3 Move number: 45
# Qwen CN move: e7d6 Move number: 46
# Qwen US move: Ne8 Move number: 47
# Qwen CN move: f8e8 Move number: 48
# Qwen US move: e3d2 Move number: 49
# Qwen CN move: d6b4 Move number: 50
# Qwen US move: d2c1 Move number: 51
# Qwen CN move: e8e1 Move number: 52
# Qwen US move: c1c2 Move number: 53
# Qwen CN move: e1a1 Move number: 54
# Qwen US move: Kd3 Move number: 55
# Qwen CN move: d8e8 Move number: 56
# Qwen US move: c4d5 Move number: 57
# Qwen CN move: a1c1 Move number: 58
# Qwen US move: d6 Move number: 59
# Qwen CN move: d7b5 Move number: 60
# Qwen US move: d3d4 Move number: 61
# Qwen CN move: b4c5 Move number: 62
# Game 95 result: 0-1
#
#
# Starting game 96...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen US move: b5a4 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Qwen CN move: d7c6 Move number: 10
# Qwen US move: Nxe5 Move number: 11
# Qwen CN move: d8d4 Move number: 12
# Qwen US move: e5f3 Move number: 13
# Qwen CN move: d4e4 Move number: 14
# Qwen US move: Kf1 Move number: 15
# Qwen CN move: c8f5 Move number: 16
# Qwen US move: d2d3 Move number: 17
# Qwen CN move: e8c8 Move number: 18
# Qwen US move: b1c3 Move number: 19
# Qwen CN move: e4b4 Move number: 20
# Qwen US move: Nd2 Move number: 21
# Qwen CN move: f5e6 Move number: 22
# Qwen US move: a2a3 Move number: 23
# Qwen CN move: b4e7 Move number: 24
# Qwen US move: d2e4 Move number: 25
# Qwen CN move: f6e4 Move number: 26
# Qwen US move: c3e4 Move number: 27
# Qwen CN move: c6c5 Move number: 28
# Qwen US move: h2h4 Move number: 29
# Qwen CN move: c5c4 Move number: 30
# Qwen US move: c1g5 Move number: 31
# Qwen CN move: f7f6 Move number: 32
# Qwen US move: g5f4 Move number: 33
# Qwen CN move: e7d7 Move number: 34
# Qwen US move: f1g1 Move number: 35
# Qwen CN move: d7d4 Move number: 36
# Qwen US move: Bg5 Move number: 37
# Qwen CN move: f6g5 Move number: 38
# Qwen US move: Qe2 Move number: 39
# Qwen CN move: g5g4 Move number: 40
# Qwen US move: e4g5 Move number: 41
# Qwen CN move: e6g8 Move number: 42
# Qwen US move: Nh7 Move number: 43
# Qwen CN move: g8h7 Move number: 44
# Qwen US move: Qe8 Move number: 45
# Qwen CN move: d8e8 Move number: 46
# Qwen US move: c2c3 Move number: 47
# Qwen CN move: d4d6 Move number: 48
# Qwen US move: d3d4 Move number: 49
# Qwen CN move: c8d7 Move number: 50
# Qwen US move: g2g3 Move number: 51
# Qwen CN move: h7d3 Move number: 52
# Qwen US move: Rh3 Move number: 53
# Qwen CN move: d6d5 Move number: 54
# Qwen US move: Rh2 Move number: 55
# Qwen CN move: h8h6 Move number: 56
# Qwen US move: f2f4 Move number: 57
# Qwen CN move: g4f3 Move number: 58
# Qwen US move: a1d1 Move number: 59
# Qwen CN move: h6g6 Move number: 60
# Qwen US move: d1d3 Move number: 61
# Qwen CN move: e8e1 Move number: 62
# Qwen US move: Kf2 Move number: 63
# Qwen CN move: e1e2 Move number: 64
# Qwen US move: f2f1 Move number: 65
# Qwen CN move: c4d3 Move number: 66
# Qwen US move: h2f2 Move number: 67
# Qwen CN move: d3d2 Move number: 68
# Qwen US move: Rxf3 Move number: 69
# Qwen CN move: d2d1q Move number: 70
# Game 96 result: 0-1
#
#
# Starting game 97...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: d7d6 Move number: 6
# Qwen US move: e5f3 Move number: 7
# Qwen CN move: f6e4 Move number: 8
# Qwen US move: Nh4 Move number: 9
# Qwen CN move: d8h4 Move number: 10
# Qwen US move: d1f3 Move number: 11
# Qwen CN move: b8c6 Move number: 12
# Qwen US move: f1b5 Move number: 13
# Qwen CN move: c8d7 Move number: 14
# Qwen US move: Bxc6 Move number: 15
# Qwen CN move: d7c6 Move number: 16
# Qwen US move: Qxf7+ Move number: 17
# Qwen CN move: e8f7 Move number: 18
# Qwen US move: Nc3 Move number: 19
# Qwen CN move: h4f2 Move number: 20
# Qwen US move: Kd1 Move number: 21
# Qwen CN move: f2g2 Move number: 22
# Qwen US move: c3d5 Move number: 23
# Qwen CN move: g2f3 Move number: 24
# Qwen US move: d1e1 Move number: 25
# Qwen CN move: f3h1 Move number: 26
# Invalid move by US. Move: Nh4
# New Move: Ke2
# Qwen US move: Ke2 Move number: 27
# Qwen CN move: h1g2 Move number: 28
# Qwen US move: Ke1 Move number: 29
# Qwen CN move: g2f2 Move number: 30
# Qwen US move: e1d1 Move number: 31
# Qwen CN move: f2f1 Move number: 32
# Game 97 result: 0-1
#
#
# Starting game 98...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Invalid move by US. Move: Nf3
# New Move: b3
# Qwen US move: b3 Move number: 5
# Qwen CN move: d7d6 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: c5d4 Move number: 8
# Qwen US move: f3d4 Move number: 9
# Qwen CN move: g8f6 Move number: 10
# Qwen US move: d4c6 Move number: 11
# Qwen CN move: b7c6 Move number: 12
# Qwen US move: Qd2 Move number: 13
# Qwen CN move: f6e4 Move number: 14
# Qwen US move: Qxd6 Move number: 15
# Qwen CN move: d8d6 Move number: 16
# Qwen US move: Rg1 Move number: 17
# Qwen CN move: d6d4 Move number: 18
# Qwen US move: Be3 Move number: 19
# Qwen CN move: d4a1 Move number: 20
# Qwen US move: f1d3 Move number: 21
# Qwen CN move: a1b1 Move number: 22
# Qwen US move: e1e2 Move number: 23
# Qwen CN move: e4c3 Move number: 24
# Qwen US move: e2d2 Move number: 25
# Qwen CN move: b1a2 Move number: 26
# Invalid move by US. Move: Bxc3
# New Move: Bxh7
# Qwen US move: Bxh7 Move number: 27
# Qwen CN move: h8h7 Move number: 28
# Invalid move by US. Move: Bxc3
# New Move: g3
# Qwen US move: g3 Move number: 29
# Qwen CN move: c3e4 Move number: 30
# Qwen US move: d2d3 Move number: 31
# Qwen CN move: f7f5 Move number: 32
# Qwen US move: e3b6 Move number: 33
# Qwen CN move: a2a6 Move number: 34
# Qwen US move: c2c4 Move number: 35
# Qwen CN move: a6b6 Move number: 36
# Qwen US move: Rg2 Move number: 37
# Qwen CN move: b6d8 Move number: 38
# Qwen US move: Kc2 Move number: 39
# Qwen CN move: d8d2 Move number: 40
# Qwen US move: Kb1 Move number: 41
# Qwen CN move: e4c3 Move number: 42
# Invalid move by US. Move: Rg2
# New Move: Ka1
# Qwen US move: Ka1 Move number: 43
# Qwen CN move: d2c1 Move number: 44
# Game 98 result: 0-1
#
#
# Starting game 99...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: b1c3 Move number: 3
# Qwen CN move: d7d6 Move number: 4
# Qwen US move: g1e2 Move number: 5
# Qwen CN move: e7e5 Move number: 6
# Qwen US move: e2g3 Move number: 7
# Qwen CN move: c8e6 Move number: 8
# Qwen US move: Nh5 Move number: 9
# Qwen CN move: g7g6 Move number: 10
# Qwen US move: f1b5 Move number: 11
# Qwen CN move: b8d7 Move number: 12
# Qwen US move: Nf4 Move number: 13
# Qwen CN move: e5f4 Move number: 14
# Qwen US move: d2d4 Move number: 15
# Qwen CN move: f4f3 Move number: 16
# Qwen US move: d4d5 Move number: 17
# Qwen CN move: e6g4 Move number: 18
# Qwen US move: Bxd7+ Move number: 19
# Qwen CN move: d8d7 Move number: 20
# Qwen US move: g2f3 Move number: 21
# Qwen CN move: g4h5 Move number: 22
# Qwen US move: d1d3 Move number: 23
# Qwen CN move: f8g7 Move number: 24
# Qwen US move: Qd2 Move number: 25
# Qwen CN move: g8e7 Move number: 26
# Qwen US move: Nd1 Move number: 27
# Qwen CN move: e8g8 Move number: 28
# Qwen US move: d2f4 Move number: 29
# Qwen CN move: f7f5 Move number: 30
# Qwen US move: Qh6 Move number: 31
# Qwen CN move: f5e4 Move number: 32
# Qwen US move: h6g7 Move number: 33
# Qwen CN move: g8g7 Move number: 34
# Qwen US move: h2h4 Move number: 35
# Qwen CN move: g7f7 Move number: 36
# Qwen US move: Rh3 Move number: 37
# Qwen CN move: e4f3 Move number: 38
# Qwen US move: c1g5 Move number: 39
# Qwen CN move: e7d5 Move number: 40
# Qwen US move: d1e3 Move number: 41
# Qwen CN move: d5e3 Move number: 42
# Qwen US move: g5e3 Move number: 43
# Qwen CN move: f7g8 Move number: 44
# Qwen US move: h3g3 Move number: 45
# Qwen CN move: a8e8 Move number: 46
# Qwen US move: e1c1 Move number: 47
# Qwen CN move: e8e3 Move number: 48
# Qwen US move: g3g5 Move number: 49
# Qwen CN move: d7e7 Move number: 50
# Qwen US move: g5d5 Move number: 51
# Qwen CN move: e3e1 Move number: 52
# Qwen US move: Rxd6 Move number: 53
# Qwen CN move: e1d1 Move number: 54
# Qwen US move: Kxd1 Move number: 55
# Qwen CN move: e7d6 Move number: 56
# Qwen US move: d1c1 Move number: 57
# Qwen CN move: f8e8 Move number: 58
# Invalid move by US. Move:  Kb1
# New Move: b4
# Qwen US move: b4 Move number: 59
# Qwen CN move: d6f4 Move number: 60
# Qwen US move: c1d1 Move number: 61
# Qwen CN move: e8e1 Move number: 62
# Qwen US move: d1e1 Move number: 63
# Qwen CN move: f4c1 Move number: 64
# Game 99 result: 0-1
#
#
# Starting game 100...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: d7d6 Move number: 4
# Qwen US move: Nh4 Move number: 5
# Qwen CN move: b8c6 Move number: 6
# Invalid move by US. Move: Nh4
# New Move: d3
# Qwen US move: d3 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: b1c3 Move number: 9
# Qwen CN move: g7g6 Move number: 10
# Qwen US move: g2g3 Move number: 11
# Qwen CN move: a8b8 Move number: 12
# Qwen US move: a2a4 Move number: 13
# Qwen CN move: f8g7 Move number: 14
# Invalid move by US. Move: Nh4
# New Move: Na2
# Qwen US move: Na2 Move number: 15
# Qwen CN move: d6d5 Move number: 16
# Qwen US move: Nf3 Move number: 17
# Qwen CN move: d5e4 Move number: 18
# Qwen US move: d3e4 Move number: 19
# Qwen CN move: d8d1 Move number: 20
# Qwen US move: e1d1 Move number: 21
# Qwen CN move: f6e4 Move number: 22
# Qwen US move: d1e1 Move number: 23
# Qwen CN move: c8e6 Move number: 24
# Qwen US move: Ng5 Move number: 25
# Qwen CN move: e4g5 Move number: 26
# Qwen US move: c1g5 Move number: 27
# Qwen CN move: g7b2 Move number: 28
# Qwen US move: Bh6 Move number: 29
# Qwen CN move: b2a1 Move number: 30
# Qwen US move: a2c1 Move number: 31
# Qwen CN move: e6d5 Move number: 32
# Qwen US move: h1g1 Move number: 33
# Qwen CN move: a1c3 Move number: 34
# Qwen US move: Ke2 Move number: 35
# Qwen CN move: b8d8 Move number: 36
# Qwen US move: c1d3 Move number: 37
# Qwen CN move: c6d4 Move number: 38
# Qwen US move: e2d1 Move number: 39
# Qwen CN move: c5c4 Move number: 40
# Qwen US move: Bg2 Move number: 41
# Qwen CN move: c4d3 Move number: 42
# Qwen US move: Bxd5 Move number: 43
# Qwen CN move: d3c2 Move number: 44
# Qwen US move: d1c1 Move number: 45
# Qwen CN move: d8d5 Move number: 46
# Qwen US move: Bd2 Move number: 47
# Qwen CN move: d4e2 Move number: 48
# Qwen US move: c1c2 Move number: 49
# Qwen CN move: d5d2 Move number: 50
# Qwen US move: c2b3 Move number: 51
# Qwen CN move: d2b2 Move number: 52
# Qwen US move: Kc4 Move number: 53
# Qwen CN move: c3f6 Move number: 54
# Qwen US move: g1e1 Move number: 55
# Qwen CN move: e8g8 Move number: 56
# Qwen US move: c4d3 Move number: 57
# Qwen CN move: f8c8 Move number: 58
# Qwen US move: d3e4 Move number: 59
# Qwen CN move: c8c3 Move number: 60
# Qwen US move: e1d1 Move number: 61
# Qwen CN move: b2b4 Move number: 62
# Qwen US move: e4d5 Move number: 63
# Qwen CN move: e7e6 Move number: 64
# Qwen US move: d5d6 Move number: 65
# Qwen CN move: b4b6 Move number: 66
# Qwen US move: d6d7 Move number: 67
# Qwen CN move: h7h5 Move number: 68
# Qwen US move: Rd6 Move number: 69
# Qwen CN move: b6d6 Move number: 70
# Qwen US move: Ke8 Move number: 71
# Qwen CN move: c3c8 Move number: 72
# Game 100 result: 0-1

# %%
results = []

# %%
results.append({
            "Qwen US Wins": qwen_us_wins,
            "Qwen CN Wins": qwen_cn_wins,
            "Draws": draws,
        })

print(results)
# Out:
# [{'Qwen US Wins': 0, 'Qwen CN Wins': 100, 'Draws': 0}]

# %% [markdown]
# ## Swapping sides

# %%
stockfish = Stockfish()
stockfish.update_engine_parameters({"Threads": 4, "Hash": 4096})

# %%
for game_number in range(1, NUM_GAMES + 1):
    
    move_counter = 0

    print(f"Starting game {game_number}...")

    board = chess.Board()

    while not board.is_game_over() and move_counter <= MOVE_LIMIT:
        if board.turn == chess.WHITE and not board.is_game_over():
            num = random.randint(1,100)
            
            if num <= QWEN_CN_AI:
                stockfish.set_fen_position(board.fen())
                qwen_us_move = await get_move_with_timeout(stockfish)

                if qwen_us_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break
            
            else:
                qwen_us_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_us_move)
            except Exception as e:
                print(f"Invalid move by CN. Move: {qwen_us_move}")
                qwen_us_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_us_move)
                print(f"New Move: {qwen_us_move}")
                # continue
            
            move_counter += 1        
            print(f"Qwen CN move: {qwen_us_move} Move number: {move_counter}")

        elif board.turn == chess.BLACK and not board.is_game_over():
            num = random.randint(1, 100)

            if num <= QWEN_US_AI:
                stockfish.set_fen_position(board.fen())
                qwen_cn_move = await get_move_with_timeout(stockfish)

                if qwen_cn_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break

            else:
                qwen_cn_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_cn_move)
            except Exception as e:
                print(f"Invalid move by US. Move: {qwen_cn_move}")
                qwen_cn_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_cn_move)
                print(f"New Move: {qwen_cn_move}")
                # continue
            move_counter += 1
            print(f"Qwen US move: {qwen_cn_move} Move number: {move_counter}")   

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        qwen_cn_wins += 1
    elif result == "0-1":
        qwen_us_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n\n")
# Out:
# Starting game 1...
# Qwen CN move: d2d4 Move number: 1
# Qwen US move: g8f6 Move number: 2
# Qwen CN move: c2c4 Move number: 3
# Qwen US move: e7e6 Move number: 4
# Qwen CN move: g1f3 Move number: 5
# Qwen US move: Nc6 Move number: 6
# Qwen CN move: e2e3 Move number: 7
# Invalid move by US. Move: Nc3
# New Move: h6
# Qwen US move: h6 Move number: 8
# Qwen CN move: a2a3 Move number: 9
# Qwen US move: g7g6 Move number: 10
# Qwen CN move: b2b4 Move number: 11
# Qwen US move: f8g7 Move number: 12
# Qwen CN move: f1e2 Move number: 13
# Qwen US move: e8g8 Move number: 14
# Qwen CN move: c1b2 Move number: 15
# Qwen US move: Nxd4 Move number: 16
# Qwen CN move: e3d4 Move number: 17
# Qwen US move: Qe7 Move number: 18
# Qwen CN move: e1g1 Move number: 19
# Invalid move by US. Move: Nbd2
# New Move: a6
# Qwen US move: a6 Move number: 20
# Qwen CN move: f1e1 Move number: 21
# Qwen US move: b7b6 Move number: 22
# Qwen CN move: b1d2 Move number: 23
# Qwen US move: d7d6 Move number: 24
# Qwen CN move: d1c2 Move number: 25
# Qwen US move: c8b7 Move number: 26
# Qwen CN move: e2f1 Move number: 27
# Invalid move by US. Move: Be2
# New Move: Rad8
# Qwen US move: Rad8 Move number: 28
# Qwen CN move: h2h3 Move number: 29
# Qwen US move: Be4 Move number: 30
# Qwen CN move: d2e4 Move number: 31
# Qwen US move: f6e4 Move number: 32
# Qwen CN move: e1e4 Move number: 33
# Qwen US move: f7f5 Move number: 34
# Qwen CN move: e4e3 Move number: 35
# Qwen US move: g6g5 Move number: 36
# Qwen CN move: d4d5 Move number: 37
# Invalid move by US. Move: Re4
# New Move: Qf6
# Qwen US move: Qf6 Move number: 38
# Qwen CN move: b2f6 Move number: 39
# Qwen US move: g7f6 Move number: 40
# Qwen CN move: a1e1 Move number: 41
# Qwen US move: g5g4 Move number: 42
# Qwen CN move: h3g4 Move number: 43
# Qwen US move: f5g4 Move number: 44
# Qwen CN move: c2g6 Move number: 45
# Qwen US move: Kh8 Move number: 46
# Qwen CN move: g6h6 Move number: 47
# Invalid move by US. Move: Qg4
# New Move: Kg8
# Qwen US move: Kg8 Move number: 48
# Qwen CN move: h6g6 Move number: 49
# Qwen US move: Kh8 Move number: 50
# Qwen CN move: g6h5 Move number: 51
# Qwen US move: h8g8 Move number: 52
# Qwen CN move: h5g4 Move number: 53
# Qwen US move: f6g7 Move number: 54
# Qwen CN move: g4e6 Move number: 55
# Qwen US move: f8f7 Move number: 56
# Qwen CN move: f3g5 Move number: 57
# Invalid move by US. Move: Rxe8+ Qf7 Nxf7 Kxf7
# New Move: c5
# Qwen US move: c5 Move number: 58
# Qwen CN move: e6f7 Move number: 59
# Qwen US move: g8h8 Move number: 60
# Qwen CN move: e3h3 Move number: 61
# Qwen US move: g7h6 Move number: 62
# Qwen CN move: h3h6 Move number: 63
# Game 1 result: 1-0
#
#
# Starting game 2...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: g8f6 Move number: 4
# Qwen CN move: f3e5 Move number: 5
# Invalid move by US. Move: Nxd6
# New Move: a6
# Qwen US move: a6 Move number: 6
# Qwen CN move: f1c4 Move number: 7
# Qwen US move: d7d5 Move number: 8
# Qwen CN move: e4d5 Move number: 9
# Qwen US move: f8d6 Move number: 10
# Qwen CN move: d2d4 Move number: 11
# Qwen US move: b8d7 Move number: 12
# Qwen CN move: f2f4 Move number: 13
# Qwen US move: Nxe5 Move number: 14
# Qwen CN move: f4e5 Move number: 15
# Qwen US move: Bd7 Move number: 16
# Qwen CN move: e1g1 Move number: 17
# Invalid move by US. Move: Nxe5
# New Move: Rc8
# Qwen US move: Rc8 Move number: 18
# Qwen CN move: c1g5 Move number: 19
# Qwen US move: Be6 Move number: 20
# Qwen CN move: d5e6 Move number: 21
# Qwen US move: e8g8 Move number: 22
# Qwen CN move: e5d6 Move number: 23
# Qwen US move: c7d6 Move number: 24
# Qwen CN move: e6f7 Move number: 25
# Qwen US move: g8h8 Move number: 26
# Qwen CN move: c4e6 Move number: 27
# Qwen US move: Rxf7 Move number: 28
# Qwen CN move: e6f7 Move number: 29
# Qwen US move: d8e7 Move number: 30
# Qwen CN move: b1c3 Move number: 31
# Qwen US move: Rxc3 Move number: 32
# Qwen CN move: b2c3 Move number: 33
# Qwen US move: e7f7 Move number: 34
# Qwen CN move: g5f6 Move number: 35
# Qwen US move: g7f6 Move number: 36
# Qwen CN move: f1f3 Move number: 37
# Invalid move by US. Move: Rf1
# New Move: a5
# Qwen US move: a5 Move number: 38
# Qwen CN move: d1f1 Move number: 39
# Qwen US move: h8g7 Move number: 40
# Qwen CN move: f3g3 Move number: 41
# Qwen US move: g7h8 Move number: 42
# Qwen CN move: a1e1 Move number: 43
# Qwen US move: f6f5 Move number: 44
# Qwen CN move: g3f3 Move number: 45
# Qwen US move: Qd5 Move number: 46
# Qwen CN move: f3f5 Move number: 47
# Invalid move by US. Move: Rxf7+
# New Move: h5
# Qwen US move: h5 Move number: 48
# Qwen CN move: f5f8 Move number: 49
# Qwen US move: h8h7 Move number: 50
# Qwen CN move: e1e7 Move number: 51
# Qwen US move: d5f7 Move number: 52
# Qwen CN move: f1f7 Move number: 53
# Qwen US move: h7h6 Move number: 54
# Qwen CN move: f7f6 Move number: 55
# Game 2 result: 1-0
#
#
# Starting game 3...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: Nc6 Move number: 4
# Qwen CN move: f1c4 Move number: 5
# Qwen US move: g8f6 Move number: 6
# Qwen CN move: d2d3 Move number: 7
# Qwen US move: Be7 Move number: 8
# Qwen CN move: e1g1 Move number: 9
# Qwen US move: d7d6 Move number: 10
# Qwen CN move: c2c3 Move number: 11
# Qwen US move: e8g8 Move number: 12
# Qwen CN move: c4b3 Move number: 13
# Qwen US move: Bd7 Move number: 14
# Qwen CN move: h2h3 Move number: 15
# Qwen US move: h7h6 Move number: 16
# Qwen CN move: a2a4 Move number: 17
# Qwen US move: d7e6 Move number: 18
# Qwen CN move: b1d2 Move number: 19
# Qwen US move: Bd5 Move number: 20
# Qwen CN move: e4d5 Move number: 21
# Qwen US move: Nxd5 Move number: 22
# Qwen CN move: b3d5 Move number: 23
# Qwen US move: g8h8 Move number: 24
# Qwen CN move: d5c6 Move number: 25
# Qwen US move: Bg5 Move number: 26
# Qwen CN move: c6b7 Move number: 27
# Qwen US move: a8b8 Move number: 28
# Qwen CN move: b7d5 Move number: 29
# Qwen US move: f7f5 Move number: 30
# Qwen CN move: f1e1 Move number: 31
# Invalid move by US. Move: Re2
# New Move: Qe7
# Qwen US move: Qe7 Move number: 32
# Qwen CN move: b2b4 Move number: 33
# Qwen US move: Rfd8 Move number: 34
# Qwen CN move: g1f1 Move number: 35
# Qwen US move: d8e8 Move number: 36
# Qwen CN move: b4b5 Move number: 37
# Qwen US move: c7c5 Move number: 38
# Qwen CN move: f1g1 Move number: 39
# Qwen US move: g5h4 Move number: 40
# Qwen CN move: d2f1 Move number: 41
# Invalid move by US. Move: Re1
# New Move: Ra8
# Qwen US move: Ra8 Move number: 42
# Qwen CN move: d5a8 Move number: 43
# Qwen US move: Rxa8 Move number: 44
# Qwen CN move: c1d2 Move number: 45
# Qwen US move: a8f8 Move number: 46
# Qwen CN move: f1h2 Move number: 47
# Qwen US move: h8g8 Move number: 48
# Qwen CN move: b5b6 Move number: 49
# Qwen US move: e5e4 Move number: 50
# Qwen CN move: f3h4 Move number: 51
# Qwen US move: Qg5 Move number: 52
# Qwen CN move: d1b3 Move number: 53
# Qwen US move: g8h7 Move number: 54
# Qwen CN move: d2g5 Move number: 55
# Invalid move by US. Move: Re1
# New Move: a5
# Qwen US move: a5 Move number: 56
# Qwen CN move: b6b7 Move number: 57
# Qwen US move: h6g5 Move number: 58
# Qwen CN move: h4f3 Move number: 59
# Qwen US move: e4f3 Move number: 60
# Qwen CN move: h2f3 Move number: 61
# Qwen US move: f5f4 Move number: 62
# Qwen CN move: a1b1 Move number: 63
# Invalid move by US. Move: Rb1
# New Move: Rd8
# Qwen US move: Rd8 Move number: 64
# Qwen CN move: b3f7 Move number: 65
# Invalid move by US. Move: Qxf4
# New Move: d5
# Qwen US move: d5 Move number: 66
# Qwen CN move: e1e7 Move number: 67
# Qwen US move: h7h6 Move number: 68
# Qwen CN move: f7g7 Move number: 69
# Qwen US move: h6h5 Move number: 70
# Qwen CN move: g7g5 Move number: 71
# Game 3 result: 1-0
#
#
# Starting game 4...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: b8c6 Move number: 4
# Qwen CN move: f1c4 Move number: 5
# Qwen US move: Nf6 Move number: 6
# Qwen CN move: d2d3 Move number: 7
# Qwen US move: f8c5 Move number: 8
# Qwen CN move: e1g1 Move number: 9
# Qwen US move: Nh5 Move number: 10
# Qwen CN move: c4f7 Move number: 11
# Qwen US move: e8f7 Move number: 12
# Qwen CN move: f3e5 Move number: 13
# Qwen US move: c6e5 Move number: 14
# Qwen CN move: d1h5 Move number: 15
# Invalid move by US. Move: Nh6
# New Move: Ng6
# Qwen US move: Ng6 Move number: 16
# Qwen CN move: h5f5 Move number: 17
# Qwen US move: f7e8 Move number: 18
# Qwen CN move: f5c5 Move number: 19
# Qwen US move: d7d6 Move number: 20
# Qwen CN move: c5h5 Move number: 21
# Qwen US move: d8e7 Move number: 22
# Qwen CN move: f2f4 Move number: 23
# Qwen US move: Qg5 Move number: 24
# Qwen CN move: f4g5 Move number: 25
# Qwen US move: Rg8 Move number: 26
# Qwen CN move: h5h7 Move number: 27
# Qwen US move: Nh4 Move number: 28
# Qwen CN move: h7g8 Move number: 29
# Qwen US move: Kd7 Move number: 30
# Qwen CN move: f1f7 Move number: 31
# Qwen US move: d7c6 Move number: 32
# Qwen CN move: g8e8 Move number: 33
# Qwen US move: c6b6 Move number: 34
# Qwen CN move: c1e3 Move number: 35
# Qwen US move: c7c5 Move number: 36
# Qwen CN move: e8d8 Move number: 37
# Qwen US move: Kc6 Move number: 38
# Qwen CN move: b1c3 Move number: 39
# Qwen US move: Bd7 Move number: 40
# Qwen CN move: d8d7 Move number: 41
# Invalid move by US. Move: Kb7
# New Move: Kb6
# Qwen US move: Kb6 Move number: 42
# Qwen CN move: d7b5 Move number: 43
# Game 4 result: 1-0
#
#
# Starting game 5...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: c7c5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: b8c6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen US move: Nf6 Move number: 6
# Qwen CN move: b1c3 Move number: 7
# Qwen US move: Nxe4 Move number: 8
# Qwen CN move: c3e4 Move number: 9
# Qwen US move: Nxd4 Move number: 10
# Qwen CN move: f3d4 Move number: 11
# Qwen US move: cxd4 Move number: 12
# Qwen CN move: e1g1 Move number: 13
# Qwen US move: e7e6 Move number: 14
# Qwen CN move: f1e1 Move number: 15
# Qwen US move: b7b6 Move number: 16
# Qwen CN move: b5e2 Move number: 17
# Qwen US move: c8b7 Move number: 18
# Qwen CN move: d2d3 Move number: 19
# Qwen US move: Bd6 Move number: 20
# Qwen CN move: e4d6 Move number: 21
# Invalid move by US. Move: Nxd4
# New Move: Kf8
# Qwen US move: Kf8 Move number: 22
# Qwen CN move: d6b7 Move number: 23
# Qwen US move: Qg5 Move number: 24
# Qwen CN move: c1g5 Move number: 25
# Qwen US move: h7h5 Move number: 26
# Qwen CN move: h2h4 Move number: 27
# Qwen US move: f7f6 Move number: 28
# Qwen CN move: g5d2 Move number: 29
# Qwen US move: g7g5 Move number: 30
# Qwen CN move: e2f3 Move number: 31
# Qwen US move: Rg8 Move number: 32
# Qwen CN move: d2b4 Move number: 33
# Qwen US move: f8g7 Move number: 34
# Qwen CN move: b7d6 Move number: 35
# Invalid move by US. Move: Bxd4
# New Move: b5
# Qwen US move: b5 Move number: 36
# Qwen CN move: h4g5 Move number: 37
# Qwen US move: a8f8 Move number: 38
# Qwen CN move: d6b5 Move number: 39
# Qwen US move: f6g5 Move number: 40
# Qwen CN move: d1d2 Move number: 41
# Qwen US move: f8f4 Move number: 42
# Qwen CN move: a1d1 Move number: 43
# Qwen US move: Re4 Move number: 44
# Qwen CN move: d2g5 Move number: 45
# Qwen US move: Kf7 Move number: 46
# Qwen CN move: f3h5 Move number: 47
# Invalid move by US. Move: Bf3
# New Move: Rg6
# Qwen US move: Rg6 Move number: 48
# Qwen CN move: g5g6 Move number: 49
# Game 5 result: 1-0
#
#
# Starting game 6...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: c7c5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: b8c6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Invalid move by US. Move: Nc6
# New Move: g5
# Qwen US move: g5 Move number: 6
# Qwen CN move: f3g5 Move number: 7
# Qwen US move: g8f6 Move number: 8
# Qwen CN move: b1c3 Move number: 9
# Qwen US move: h8g8 Move number: 10
# Qwen CN move: d2d3 Move number: 11
# Qwen US move: h7h6 Move number: 12
# Qwen CN move: g5f3 Move number: 13
# Qwen US move: Nh5 Move number: 14
# Qwen CN move: g2g3 Move number: 15
# Invalid move by US. Move: Nbd4
# New Move: f6
# Qwen US move: f6 Move number: 16
# Qwen CN move: d3d4 Move number: 17
# Qwen US move: c5d4 Move number: 18
# Qwen CN move: f3d4 Move number: 19
# Qwen US move: h5g7 Move number: 20
# Qwen CN move: c1h6 Move number: 21
# Qwen US move: c6d4 Move number: 22
# Qwen CN move: d1d4 Move number: 23
# Qwen US move: Qa5 Move number: 24
# Qwen CN move: d4d5 Move number: 25
# Qwen US move: Qxd8 Move number: 26
# Qwen CN move: d5g8 Move number: 27
# Qwen US move: Qc7 Move number: 28
# Qwen CN move: h6g7 Move number: 29
# Qwen US move: Qe5 Move number: 30
# Qwen CN move: g8f8 Move number: 31
# Game 6 result: 1-0
#
#
# Starting game 7...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: c7c5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: d7d6 Move number: 4
# Qwen CN move: d2d4 Move number: 5
# Qwen US move: d5 Move number: 6
# Qwen CN move: e4d5 Move number: 7
# Qwen US move: g8f6 Move number: 8
# Qwen CN move: f1b5 Move number: 9
# Qwen US move: c8d7 Move number: 10
# Qwen CN move: b5d7 Move number: 11
# Qwen US move: Nfxd7 Move number: 12
# Qwen CN move: d4c5 Move number: 13
# Qwen US move: Nc6 Move number: 14
# Qwen CN move: d5c6 Move number: 15
# Qwen US move: d7c5 Move number: 16
# Qwen CN move: d1d8 Move number: 17
# Qwen US move: Kxd8 Move number: 18
# Qwen CN move: c1e3 Move number: 19
# Qwen US move: e7e6 Move number: 20
# Qwen CN move: a2a4 Move number: 21
# Qwen US move: b7c6 Move number: 22
# Qwen CN move: f3e5 Move number: 23
# Qwen US move: Nd3+ Move number: 24
# Qwen CN move: e5d3 Move number: 25
# Qwen US move: d8c7 Move number: 26
# Qwen CN move: b1d2 Move number: 27
# Qwen US move: a8d8 Move number: 28
# Qwen CN move: e1c1 Move number: 29
# Qwen US move: d8d5 Move number: 30
# Qwen CN move: h2h4 Move number: 31
# Qwen US move: f8e7 Move number: 32
# Qwen CN move: d2e4 Move number: 33
# Qwen US move: d5h5 Move number: 34
# Qwen CN move: e4g5 Move number: 35
# Qwen US move: e7g5 Move number: 36
# Qwen CN move: e3g5 Move number: 37
# Qwen US move: f7f6 Move number: 38
# Qwen CN move: g2g4 Move number: 39
# Qwen US move: Rg8 Move number: 40
# Qwen CN move: g4h5 Move number: 41
# Qwen US move: Rh8 Move number: 42
# Qwen CN move: g5e3 Move number: 43
# Qwen US move: h8d8 Move number: 44
# Qwen CN move: h1g1 Move number: 45
# Qwen US move: Rd7 Move number: 46
# Qwen CN move: d3c5 Move number: 47
# Qwen US move: Rd2 Move number: 48
# Qwen CN move: g1g7 Move number: 49
# Qwen US move: c7d6 Move number: 50
# Qwen CN move: d1d2 Move number: 51
# Qwen US move: d6e5 Move number: 52
# Qwen CN move: d2d4 Move number: 53
# Qwen US move: e5f5 Move number: 54
# Qwen CN move: d4f4 Move number: 55
# Invalid move by US. Move: Rxf6
# New Move: Ke5
# Qwen US move: Ke5 Move number: 56
# Qwen CN move: c5d3 Move number: 57
# Invalid move by US. Move: Nd3+
# New Move: Kd6
# Qwen US move: Kd6 Move number: 58
# Qwen CN move: f4d4 Move number: 59
# Game 7 result: 1-0
#
#
# Starting game 8...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: g8f6 Move number: 4
# Qwen CN move: f3e5 Move number: 5
# Invalid move by US. Move: Nf3
# New Move: a6
# Qwen US move: a6 Move number: 6
# Qwen CN move: f1c4 Move number: 7
# Qwen US move: d7d5 Move number: 8
# Qwen CN move: e4d5 Move number: 9
# Qwen US move: f8d6 Move number: 10
# Qwen CN move: d2d4 Move number: 11
# Qwen US move: e8g8 Move number: 12
# Qwen CN move: e1g1 Move number: 13
# Invalid move by US. Move: Nxe5
# New Move: Bf5
# Qwen US move: Bf5 Move number: 14
# Qwen CN move: c1f4 Move number: 15
# Qwen US move: Be7 Move number: 16
# Qwen CN move: b1c3 Move number: 17
# Qwen US move: e7b4 Move number: 18
# Qwen CN move: f4g5 Move number: 19
# Qwen US move: b4c3 Move number: 20
# Qwen CN move: b2c3 Move number: 21
# Qwen US move: d8d6 Move number: 22
# Qwen CN move: g5f6 Move number: 23
# Qwen US move: Qd8 Move number: 24
# Qwen CN move: f6d8 Move number: 25
# Qwen US move: f8d8 Move number: 26
# Qwen CN move: g1h1 Move number: 27
# Qwen US move: Rd6 Move number: 28
# Qwen CN move: d1f3 Move number: 29
# Qwen US move: d6f6 Move number: 30
# Qwen CN move: a1e1 Move number: 31
# Qwen US move: b8d7 Move number: 32
# Qwen CN move: f3f4 Move number: 33
# Invalid move by US. Move: Nd2
# New Move: Ra7
# Qwen US move: Ra7 Move number: 34
# Qwen CN move: c4d3 Move number: 35
# Invalid move by US. Move: Nd7
# New Move: h6
# Qwen US move: h6 Move number: 36
# Qwen CN move: d3f5 Move number: 37
# Qwen US move: g7g6 Move number: 38
# Qwen CN move: e5d7 Move number: 39
# Qwen US move: f6f5 Move number: 40
# Qwen CN move: f4h6 Move number: 41
# Qwen US move: a7a8 Move number: 42
# Qwen CN move: d7e5 Move number: 43
# Qwen US move: Rf8 Move number: 44
# Qwen CN move: e5d7 Move number: 45
# Qwen US move: Re8 Move number: 46
# Qwen CN move: e1e8 Move number: 47
# Game 8 result: 1-0
#
#
# Starting game 9...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: Nc6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen US move: a7a6 Move number: 6
# Qwen CN move: b5a4 Move number: 7
# Qwen US move: g8f6 Move number: 8
# Qwen CN move: e1g1 Move number: 9
# Qwen US move: Be7 Move number: 10
# Qwen CN move: f1e1 Move number: 11
# Qwen US move: b7b5 Move number: 12
# Qwen CN move: a4b3 Move number: 13
# Qwen US move: e8g8 Move number: 14
# Qwen CN move: c2c3 Move number: 15
# Qwen US move: Bxd6 Move number: 16
# Qwen CN move: d2d4 Move number: 17
# Qwen US move: Nd5 Move number: 18
# Qwen CN move: b3d5 Move number: 19
# Qwen US move: a8b8 Move number: 20
# Qwen CN move: h2h3 Move number: 21
# Invalid move by US. Move: Bxd6
# New Move: exd4
# Qwen US move: exd4 Move number: 22
# Qwen CN move: c3d4 Move number: 23
# Qwen US move: b8b6 Move number: 24
# Qwen CN move: b1c3 Move number: 25
# Qwen US move: d6b4 Move number: 26
# Qwen CN move: c1g5 Move number: 27
# Qwen US move: b4e7 Move number: 28
# Qwen CN move: g5c1 Move number: 29
# Qwen US move: Bg5 Move number: 30
# Qwen CN move: c1g5 Move number: 31
# Invalid move by US. Move: Re1
# New Move: b4
# Qwen US move: b4 Move number: 32
# Qwen CN move: c3a4 Move number: 33
# Qwen US move: d8e8 Move number: 34
# Qwen CN move: a4b6 Move number: 35
# Qwen US move: c7b6 Move number: 36
# Qwen CN move: g1h1 Move number: 37
# Qwen US move: h7h6 Move number: 38
# Qwen CN move: g5h4 Move number: 39
# Qwen US move: Nxd4 Move number: 40
# Qwen CN move: f3d4 Move number: 41
# Qwen US move: Qe6 Move number: 42
# Qwen CN move: d4f5 Move number: 43
# Qwen US move: Qxe4 Move number: 44
# Qwen CN move: d5e4 Move number: 45
# Invalid move by US. Move: Re1
# New Move: a5
# Qwen US move: a5 Move number: 46
# Qwen CN move: f5h6 Move number: 47
# Qwen US move: g8h8 Move number: 48
# Qwen CN move: h6f7 Move number: 49
# Qwen US move: h8g8 Move number: 50
# Qwen CN move: e4h7 Move number: 51
# Qwen US move: g8h7 Move number: 52
# Qwen CN move: d1h5 Move number: 53
# Invalid move by US. Move: Qg5+
# New Move: Kg8
# Qwen US move: Kg8 Move number: 54
# Qwen CN move: e1e7 Move number: 55
# Qwen US move: Re8 Move number: 56
# Qwen CN move: e7e8 Move number: 57
# Game 9 result: 1-0
#
#
# Starting game 10...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: Nc6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Invalid move by US. Move: Bc4
# New Move: g6
# Qwen US move: g6 Move number: 6
# Qwen CN move: c2c3 Move number: 7
# Qwen US move: f8g7 Move number: 8
# Qwen CN move: d2d4 Move number: 9
# Qwen US move: e5d4 Move number: 10
# Qwen CN move: c3d4 Move number: 11
# Qwen US move: a7a6 Move number: 12
# Qwen CN move: b5a4 Move number: 13
# Qwen US move: Bxd4 Move number: 14
# Qwen CN move: f3d4 Move number: 15
# Qwen US move: Nge7 Move number: 16
# Qwen CN move: b1c3 Move number: 17
# Qwen US move: Nxd4 Move number: 18
# Qwen CN move: d1d4 Move number: 19
# Qwen US move: Nf5 Move number: 20
# Qwen CN move: d4h8 Move number: 21
# Qwen US move: e8e7 Move number: 22
# Qwen CN move: c1g5 Move number: 23
# Qwen US move: e7d6 Move number: 24
# Qwen CN move: e1c1 Move number: 25
# Qwen US move: d6c5 Move number: 26
# Qwen CN move: g5e3 Move number: 27
# Qwen US move: Kb4 Move number: 28
# Qwen CN move: a2a3 Move number: 29
# Invalid move by US. Move: Be3+
# New Move: Ka5
# Qwen US move: Ka5 Move number: 30
# Qwen CN move: b2b4 Move number: 31
# Game 10 result: 1-0
#
#
# Starting game 11...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: c7c5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: d7d6 Move number: 4
# Qwen CN move: d2d4 Move number: 5
# Qwen US move: d5 Move number: 6
# Qwen CN move: e4d5 Move number: 7
# Qwen US move: Qxd5 Move number: 8
# Qwen CN move: b1c3 Move number: 9
# Qwen US move: Nf6 Move number: 10
# Qwen CN move: c3d5 Move number: 11
# Invalid move by US. Move: Nxd7
# New Move: e6
# Qwen US move: e6 Move number: 12
# Qwen CN move: d5c7 Move number: 13
# Qwen US move: e8d8 Move number: 14
# Qwen CN move: c7a8 Move number: 15
# Qwen US move: c5d4 Move number: 16
# Qwen CN move: d1d4 Move number: 17
# Qwen US move: b8d7 Move number: 18
# Qwen CN move: c1d2 Move number: 19
# Invalid move by US. Move: Nc7+
# New Move: g5
# Qwen US move: g5 Move number: 20
# Qwen CN move: d2g5 Move number: 21
# Qwen US move: f8e7 Move number: 22
# Qwen CN move: a2a3 Move number: 23
# Qwen US move: h8g8 Move number: 24
# Qwen CN move: a1d1 Move number: 25
# Qwen US move: f6d5 Move number: 26
# Qwen CN move: g5e7 Move number: 27
# Qwen US move: Ke8 Move number: 28
# Qwen CN move: e7h4 Move number: 29
# Qwen US move: N7f6 Move number: 30
# Qwen CN move: a8c7 Move number: 31
# Invalid move by US. Move: Nxd5
# New Move: Kf8
# Qwen US move: Kf8 Move number: 32
# Qwen CN move: h4f6 Move number: 33
# Invalid move by US. Move: Rg8
# New Move: h5
# Qwen US move: h5 Move number: 34
# Qwen CN move: d4c5 Move number: 35
# Qwen US move: d5e7 Move number: 36
# Qwen CN move: c5e7 Move number: 37
# Game 11 result: 1-0
#
#
# Starting game 12...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: b8c6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen US move: a7a6 Move number: 6
# Qwen CN move: b5a4 Move number: 7
# Qwen US move: Be7 Move number: 8
# Qwen CN move: e1g1 Move number: 9
# Qwen US move: g8f6 Move number: 10
# Qwen CN move: f1e1 Move number: 11
# Invalid move by US. Move: Be7
# New Move: O-O
# Qwen US move: O-O Move number: 12
# Qwen CN move: a4c6 Move number: 13
# Qwen US move: b7c6 Move number: 14
# Qwen CN move: f3e5 Move number: 15
# Qwen US move: f8e8 Move number: 16
# Qwen CN move: d2d4 Move number: 17
# Qwen US move: c6c5 Move number: 18
# Qwen CN move: b1c3 Move number: 19
# Qwen US move: Nd5 Move number: 20
# Qwen CN move: c3d5 Move number: 21
# Invalid move by US. Move: Bxc5
# New Move: g5
# Qwen US move: g5 Move number: 22
# Qwen CN move: d1h5 Move number: 23
# Qwen US move: e8f8 Move number: 24
# Qwen CN move: e5g4 Move number: 25
# Qwen US move: c8b7 Move number: 26
# Qwen CN move: g4h6 Move number: 27
# Qwen US move: g8h8 Move number: 28
# Qwen CN move: h6f7 Move number: 29
# Qwen US move: Rxf7 Move number: 30
# Qwen CN move: h5f7 Move number: 31
# Qwen US move: Qg8 Move number: 32
# Qwen CN move: f7g8 Move number: 33
# Invalid move by US. Move: Qxf7+
# New Move: Kxg8
# Qwen US move: Kxg8 Move number: 34
# Qwen CN move: d5e7 Move number: 35
# Invalid move by US. Move: Nc5
# New Move: Kh8
# Qwen US move: Kh8 Move number: 36
# Qwen CN move: c1g5 Move number: 37
# Qwen US move: Bd5 Move number: 38
# Qwen CN move: g5f6 Move number: 39
# Game 12 result: 1-0
#
#
# Starting game 13...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: c7c5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: Nc6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Invalid move by US. Move: Nc6
# New Move: g5
# Qwen US move: g5 Move number: 6
# Qwen CN move: f3g5 Move number: 7
# Qwen US move: g8f6 Move number: 8
# Qwen CN move: d2d3 Move number: 9
# Qwen US move: c6d4 Move number: 10
# Qwen CN move: b5a4 Move number: 11
# Qwen US move: b7b5 Move number: 12
# Qwen CN move: a4b3 Move number: 13
# Qwen US move: Nh5 Move number: 14
# Qwen CN move: b3f7 Move number: 15
# Game 13 result: 1-0
#
#
# Starting game 14...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: b8c6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen US move: Nge7 Move number: 6
# Qwen CN move: b1c3 Move number: 7
# Qwen US move: e7g6 Move number: 8
# Qwen CN move: h2h4 Move number: 9
# Qwen US move: h7h5 Move number: 10
# Qwen CN move: d2d4 Move number: 11
# Qwen US move: Nge7 Move number: 12
# Qwen CN move: d4d5 Move number: 13
# Qwen US move: c6d4 Move number: 14
# Qwen CN move: f3d4 Move number: 15
# Qwen US move: e5d4 Move number: 16
# Qwen CN move: d1d4 Move number: 17
# Qwen US move: Nxd5 Move number: 18
# Qwen CN move: c3d5 Move number: 19
# Invalid move by US. Move: Bxc6
# New Move: c5
# Qwen US move: c5 Move number: 20
# Qwen CN move: d4e5 Move number: 21
# Qwen US move: f8e7 Move number: 22
# Qwen CN move: e5g7 Move number: 23
# Qwen US move: h8f8 Move number: 24
# Qwen CN move: c1f4 Move number: 25
# Qwen US move: d8a5 Move number: 26
# Qwen CN move: c2c3 Move number: 27
# Qwen US move: Bf6 Move number: 28
# Qwen CN move: g7f6 Move number: 29
# Qwen US move: Qxc3+ Move number: 30
# Qwen CN move: f6c3 Move number: 31
# Qwen US move: Rb8 Move number: 32
# Qwen CN move: c3e5 Move number: 33
# Invalid move by US. Move: Bxd8
# New Move: Kd8
# Qwen US move: Kd8 Move number: 34
# Qwen CN move: e5e7 Move number: 35
# Game 14 result: 1-0
#
#
# Starting game 15...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: b8c6 Move number: 4
# Qwen CN move: f1c4 Move number: 5
# Qwen US move: Nf6 Move number: 6
# Qwen CN move: d2d3 Move number: 7
# Qwen US move: Be7 Move number: 8
# Qwen CN move: e1g1 Move number: 9
# Invalid move by US. Move: Be3
# New Move: g6
# Qwen US move: g6 Move number: 10
# Qwen CN move: a2a4 Move number: 11
# Qwen US move: d7d6 Move number: 12
# Qwen CN move: c2c3 Move number: 13
# Qwen US move: f6h5 Move number: 14
# Qwen CN move: d3d4 Move number: 15
# Qwen US move: e7f6 Move number: 16
# Qwen CN move: a4a5 Move number: 17
# Qwen US move: Nxd4 Move number: 18
# Qwen CN move: c3d4 Move number: 19
# Qwen US move: Nf4 Move number: 20
# Qwen CN move: c1f4 Move number: 21
# Qwen US move: Be7 Move number: 22
# Qwen CN move: d4e5 Move number: 23
# Qwen US move: Bh3 Move number: 24
# Qwen CN move: g2h3 Move number: 25
# Qwen US move: d8d7 Move number: 26
# Qwen CN move: e5e6 Move number: 27
# Qwen US move: f7e6 Move number: 28
# Qwen CN move: f4g3 Move number: 29
# Qwen US move: h7h5 Move number: 30
# Qwen CN move: a1a3 Move number: 31
# Qwen US move: Rg8 Move number: 32
# Qwen CN move: d1b3 Move number: 33
# Invalid move by US. Move: Rg8
# New Move: c6
# Qwen US move: c6 Move number: 34
# Qwen CN move: c4e6 Move number: 35
# Qwen US move: d7e6 Move number: 36
# Qwen CN move: b3e6 Move number: 37
# Qwen US move: g8g7 Move number: 38
# Qwen CN move: e6b3 Move number: 39
# Qwen US move: g7f7 Move number: 40
# Qwen CN move: b3b7 Move number: 41
# Qwen US move: Rf6 Move number: 42
# Qwen CN move: b7a8 Move number: 43
# Qwen US move: Kd7 Move number: 44
# Qwen CN move: g1g2 Move number: 45
# Qwen US move: Rf5 Move number: 46
# Qwen CN move: a8a7 Move number: 47
# Invalid move by US. Move: Kf8
# New Move: Ke8
# Qwen US move: Ke8 Move number: 48
# Qwen CN move: e4f5 Move number: 49
# Qwen US move: Bh4 Move number: 50
# Qwen CN move: a3e3 Move number: 51
# Qwen US move: e8f8 Move number: 52
# Qwen CN move: a7b8 Move number: 53
# Qwen US move: f8g7 Move number: 54
# Qwen CN move: b8c7 Move number: 55
# Qwen US move: g7f8 Move number: 56
# Qwen CN move: f3h4 Move number: 57
# Invalid move by US. Move: Nf3
# New Move: Kg8
# Qwen US move: Kg8 Move number: 58
# Qwen CN move: e3e8 Move number: 59
# Game 15 result: 1-0
#
#
# Starting game 16...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: b8c6 Move number: 4
# Qwen CN move: f1c4 Move number: 5
# Qwen US move: Nf6 Move number: 6
# Qwen CN move: d2d3 Move number: 7
# Invalid move by US. Move: Nbd4
# New Move: g6
# Qwen US move: g6 Move number: 8
# Qwen CN move: f3g5 Move number: 9
# Qwen US move: d7d5 Move number: 10
# Qwen CN move: e4d5 Move number: 11
# Qwen US move: c6a5 Move number: 12
# Qwen CN move: c4b5 Move number: 13
# Qwen US move: c7c6 Move number: 14
# Qwen CN move: d5c6 Move number: 15
# Qwen US move: Nxc6 Move number: 16
# Qwen CN move: b5c4 Move number: 17
# Qwen US move: Bd6 Move number: 18
# Qwen CN move: g5f7 Move number: 19
# Qwen US move: Nxd5 Move number: 20
# Qwen CN move: f7d8 Move number: 21
# Qwen US move: Nxb6 Move number: 22
# Qwen CN move: d8c6 Move number: 23
# Qwen US move: b7c6 Move number: 24
# Qwen CN move: c1e3 Move number: 25
# Qwen US move: d6b4 Move number: 26
# Qwen CN move: e3d2 Move number: 27
# Qwen US move: b6c4 Move number: 28
# Qwen CN move: d3c4 Move number: 29
# Qwen US move: Be7 Move number: 30
# Qwen CN move: d1f3 Move number: 31
# Qwen US move: Bg5 Move number: 32
# Qwen CN move: f3c6 Move number: 33
# Qwen US move: Ke7 Move number: 34
# Qwen CN move: d2g5 Move number: 35
# Qwen US move: Kf7 Move number: 36
# Qwen CN move: c6f6 Move number: 37
# Invalid move by US. Move: Qxf7#
# New Move: Kg8
# Qwen US move: Kg8 Move number: 38
# Qwen CN move: g5h6 Move number: 39
# Invalid move by US. Move: Bh6
# New Move: e4
# Qwen US move: e4 Move number: 40
# Qwen CN move: f6g7 Move number: 41
# Game 16 result: 1-0
#
#
# Starting game 17...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: b8c6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen US move: a7a6 Move number: 6
# Qwen CN move: b5a4 Move number: 7
# Qwen US move: g8f6 Move number: 8
# Qwen CN move: e1g1 Move number: 9
# Qwen US move: Nxe4 Move number: 10
# Qwen CN move: d2d4 Move number: 11
# Qwen US move: b7b5 Move number: 12
# Qwen CN move: a4b3 Move number: 13
# Qwen US move: Bd6 Move number: 14
# Qwen CN move: d4e5 Move number: 15
# Qwen US move: c6e5 Move number: 16
# Qwen CN move: b3d5 Move number: 17
# Qwen US move: f7f5 Move number: 18
# Qwen CN move: f3e5 Move number: 19
# Qwen US move: Bxf8 Move number: 20
# Qwen CN move: d5f7 Move number: 21
# Qwen US move: e8e7 Move number: 22
# Qwen CN move: b1c3 Move number: 23
# Qwen US move: h7h6 Move number: 24
# Qwen CN move: c3d5 Move number: 25
# Invalid move by US. Move: Nc7
# New Move: Kd6
# Qwen US move: Kd6 Move number: 26
# Qwen CN move: c1f4 Move number: 27
# Qwen US move: Nc3 Move number: 28
# Qwen CN move: d5c3 Move number: 29
# Qwen US move: d6c5 Move number: 30
# Qwen CN move: f4e3 Move number: 31
# Qwen US move: c5b4 Move number: 32
# Qwen CN move: a2a3 Move number: 33
# Qwen US move: b4a5 Move number: 34
# Qwen CN move: b2b4 Move number: 35
# Qwen US move: Bxb4 Move number: 36
# Qwen CN move: a3b4 Move number: 37
# Qwen US move: a5b4 Move number: 38
# Qwen CN move: c3d5 Move number: 39
# Game 17 result: 1-0
#
#
# Starting game 18...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: g8f6 Move number: 4
# Qwen CN move: f3e5 Move number: 5
# Qwen US move: d7d6 Move number: 6
# Qwen CN move: e5f3 Move number: 7
# Qwen US move: Nbd7 Move number: 8
# Qwen CN move: b1c3 Move number: 9
# Invalid move by US. Move: Nbd2
# New Move: h5
# Qwen US move: h5 Move number: 10
# Qwen CN move: d2d4 Move number: 11
# Qwen US move: f8e7 Move number: 12
# Qwen CN move: f1d3 Move number: 13
# Qwen US move: c7c5 Move number: 14
# Qwen CN move: e1g1 Move number: 15
# Qwen US move: e8g8 Move number: 16
# Qwen CN move: e4e5 Move number: 17
# Qwen US move: dxe5 Move number: 18
# Qwen CN move: d4e5 Move number: 19
# Qwen US move: Nxe5 Move number: 20
# Qwen CN move: f3e5 Move number: 21
# Qwen US move: Nxe4 Move number: 22
# Qwen CN move: d3e4 Move number: 23
# Invalid move by US. Move: Bxe7
# New Move: Qd5
# Qwen US move: Qd5 Move number: 24
# Qwen CN move: c3d5 Move number: 25
# Qwen US move: Bf6 Move number: 26
# Qwen CN move: d5f6 Move number: 27
# Qwen US move: g7f6 Move number: 28
# Qwen CN move: e5d7 Move number: 29
# Qwen US move: c8d7 Move number: 30
# Qwen CN move: d1d7 Move number: 31
# Qwen US move: a8e8 Move number: 32
# Qwen CN move: e4d3 Move number: 33
# Qwen US move: Re6 Move number: 34
# Qwen CN move: c1e3 Move number: 35
# Qwen US move: b7b5 Move number: 36
# Qwen CN move: a1e1 Move number: 37
# Qwen US move: Re5 Move number: 38
# Qwen CN move: d7h3 Move number: 39
# Qwen US move: c5c4 Move number: 40
# Qwen CN move: d3f5 Move number: 41
# Qwen US move: c4c3 Move number: 42
# Qwen CN move: b2c3 Move number: 43
# Qwen US move: Rxe3 Move number: 44
# Qwen CN move: f2e3 Move number: 45
# Qwen US move: f8d8 Move number: 46
# Qwen CN move: f1f2 Move number: 47
# Qwen US move: g8g7 Move number: 48
# Qwen CN move: h3g3 Move number: 49
# Qwen US move: Kh8 Move number: 50
# Qwen CN move: g3h4 Move number: 51
# Qwen US move: Rd1 Move number: 52
# Qwen CN move: h4f6 Move number: 53
# Qwen US move: h8g8 Move number: 54
# Qwen CN move: e1d1 Move number: 55
# Qwen US move: Kf8 Move number: 56
# Qwen CN move: d1d8 Move number: 57
# Game 18 result: 1-0
#
#
# Starting game 19...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: Nc6 Move number: 4
# Qwen CN move: f1c4 Move number: 5
# Qwen US move: f8c5 Move number: 6
# Qwen CN move: d2d3 Move number: 7
# Qwen US move: g8f6 Move number: 8
# Qwen CN move: e1g1 Move number: 9
# Qwen US move: Be3 Move number: 10
# Qwen CN move: c1e3 Move number: 11
# Qwen US move: d7d5 Move number: 12
# Qwen CN move: e4d5 Move number: 13
# Qwen US move: f6d5 Move number: 14
# Qwen CN move: b1c3 Move number: 15
# Qwen US move: d5c3 Move number: 16
# Qwen CN move: b2c3 Move number: 17
# Qwen US move: Qg5 Move number: 18
# Qwen CN move: f3g5 Move number: 19
# Qwen US move: f7f6 Move number: 20
# Qwen CN move: c4f7 Move number: 21
# Qwen US move: Ke7 Move number: 22
# Qwen CN move: e3c5 Move number: 23
# Qwen US move: e7d8 Move number: 24
# Qwen CN move: d3d4 Move number: 25
# Qwen US move: c8f5 Move number: 26
# Qwen CN move: f7e6 Move number: 27
# Qwen US move: f5e6 Move number: 28
# Qwen CN move: g5e6 Move number: 29
# Invalid move by US. Move: Nxd8
# New Move: Kd7
# Qwen US move: Kd7 Move number: 30
# Qwen CN move: d1g4 Move number: 31
# Qwen US move: d7e8 Move number: 32
# Qwen CN move: e6c7 Move number: 33
# Qwen US move: e8f7 Move number: 34
# Qwen CN move: g4e6 Move number: 35
# Qwen US move: f7g6 Move number: 36
# Qwen CN move: e6g4 Move number: 37
# Invalid move by US. Move: Nxb5
# New Move: Kf7
# Qwen US move: Kf7 Move number: 38
# Qwen CN move: g4d7 Move number: 39
# Qwen US move: Nxe7 Move number: 40
# Qwen CN move: d7e7 Move number: 41
# Qwen US move: f7g6 Move number: 42
# Qwen CN move: a1e1 Move number: 43
# Qwen US move: b7b6 Move number: 44
# Qwen CN move: c7e6 Move number: 45
# Qwen US move: h8g8 Move number: 46
# Qwen CN move: c5a3 Move number: 47
# Qwen US move: Rgf8 Move number: 48
# Qwen CN move: e7g7 Move number: 49
# Qwen US move: g6f5 Move number: 50
# Qwen CN move: d4e5 Move number: 51
# Qwen US move: Rfe8 Move number: 52
# Qwen CN move: g7f6 Move number: 53
# Qwen US move: f5g4 Move number: 54
# Qwen CN move: f6g5 Move number: 55
# Game 19 result: 1-0
#
#
# Starting game 20...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: Nc6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen US move: Be7 Move number: 6
# Qwen CN move: e1g1 Move number: 7
# Qwen US move: Nh6 Move number: 8
# Qwen CN move: d2d3 Move number: 9
# Invalid move by US. Move: Bf1
# New Move: g6
# Qwen US move: g6 Move number: 10
# Qwen CN move: c1h6 Move number: 11
# Qwen US move: g6g5 Move number: 12
# Qwen CN move: b5c6 Move number: 13
# Qwen US move: d7c6 Move number: 14
# Qwen CN move: h6g7 Move number: 15
# Qwen US move: h8g8 Move number: 16
# Qwen CN move: g7e5 Move number: 17
# Invalid move by US. Move: Rg8
# New Move: Qd6
# Qwen US move: Qd6 Move number: 18
# Qwen CN move: e5d6 Move number: 19
# Qwen US move: Rh8 Move number: 20
# Qwen CN move: d6e5 Move number: 21
# Qwen US move: h8g8 Move number: 22
# Qwen CN move: g1h1 Move number: 23
# Qwen US move: c8g4 Move number: 24
# Qwen CN move: b1d2 Move number: 25
# Qwen US move: e8c8 Move number: 26
# Qwen CN move: f1g1 Move number: 27
# Invalid move by US. Move: Rg8
# New Move: Rd7
# Qwen US move: Rd7 Move number: 28
# Qwen CN move: d1f1 Move number: 29
# Invalid move by US. Move: Rg8
# New Move: Kb8
# Qwen US move: Kb8 Move number: 30
# Qwen CN move: h2h3 Move number: 31
# Invalid move by US. Move: Rg8
# New Move: Kc8
# Qwen US move: Kc8 Move number: 32
# Qwen CN move: f3h2 Move number: 33
# Invalid move by US. Move: Rg8
# New Move: Kb8
# Qwen US move: Kb8 Move number: 34
# Qwen CN move: h2g4 Move number: 35
# Invalid move by US. Move: Nh2
# New Move: Rxd3
# Qwen US move: Rxd3 Move number: 36
# Qwen CN move: c2d3 Move number: 37
# Qwen US move: h7h5 Move number: 38
# Qwen CN move: g4h2 Move number: 39
# Qwen US move: g5g4 Move number: 40
# Qwen CN move: a1e1 Move number: 41
# Qwen US move: b8c8 Move number: 42
# Qwen CN move: d2c4 Move number: 43
# Invalid move by US. Move: Rg8
# New Move: f6
# Qwen US move: f6 Move number: 44
# Qwen CN move: e5f4 Move number: 45
# Qwen US move: e7c5 Move number: 46
# Qwen CN move: c4e3 Move number: 47
# Qwen US move: g4h3 Move number: 48
# Qwen CN move: g2g3 Move number: 49
# Qwen US move: g8g4 Move number: 50
# Qwen CN move: f2f3 Move number: 51
# Qwen US move: Rg5 Move number: 52
# Qwen CN move: f1h3 Move number: 53
# Qwen US move: Rg4 Move number: 54
# Qwen CN move: f3g4 Move number: 55
# Qwen US move: Bd6 Move number: 56
# Qwen CN move: h3h5 Move number: 57
# Qwen US move: Bf4 Move number: 58
# Qwen CN move: h5e8 Move number: 59
# Game 20 result: 1-0
#
#
# Starting game 21...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: b8c6 Move number: 4
# Qwen CN move: f1c4 Move number: 5
# Qwen US move: Nf6 Move number: 6
# Qwen CN move: f3g5 Move number: 7
# Qwen US move: d7d5 Move number: 8
# Qwen CN move: e4d5 Move number: 9
# Qwen US move: c6a5 Move number: 10
# Qwen CN move: c4b5 Move number: 11
# Invalid move by US. Move: Bb5+
# New Move: c6
# Qwen US move: c6 Move number: 12
# Qwen CN move: d5c6 Move number: 13
# Qwen US move: b7c6 Move number: 14
# Qwen CN move: b5d3 Move number: 15
# Qwen US move: f6d5 Move number: 16
# Qwen CN move: g5f3 Move number: 17
# Qwen US move: f8d6 Move number: 18
# Qwen CN move: e1g1 Move number: 19
# Qwen US move: Qf6 Move number: 20
# Qwen CN move: b1c3 Move number: 21
# Invalid move by US. Move: Nd2
# New Move: Nb3
# Qwen US move: Nb3 Move number: 22
# Qwen CN move: a2b3 Move number: 23
# Qwen US move: d6b8 Move number: 24
# Qwen CN move: d3e4 Move number: 25
# Qwen US move: d5c3 Move number: 26
# Qwen CN move: d2c3 Move number: 27
# Qwen US move: c8f5 Move number: 28
# Qwen CN move: c1g5 Move number: 29
# Invalid move by US. Move: Bxh6
# New Move: O-O
# Qwen US move: O-O Move number: 30
# Qwen CN move: g5f6 Move number: 31
# Qwen US move: f5e4 Move number: 32
# Qwen CN move: f6e7 Move number: 33
# Qwen US move: f8e8 Move number: 34
# Qwen CN move: g1h1 Move number: 35
# Qwen US move: e4g6 Move number: 36
# Qwen CN move: d1d7 Move number: 37
# Qwen US move: Rxe7 Move number: 38
# Qwen CN move: d7c8 Move number: 39
# Invalid move by US. Move: Qxc6
# New Move: Re8
# Qwen US move: Re8 Move number: 40
# Qwen CN move: c8e8 Move number: 41
# Game 21 result: 1-0
#
#
# Starting game 22...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: b8c6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen US move: Nge7 Move number: 6
# Qwen CN move: b1c3 Move number: 7
# Qwen US move: Nf5 Move number: 8
# Qwen CN move: e4f5 Move number: 9
# Invalid move by US. Move: Nxe5
# New Move: d6
# Qwen US move: d6 Move number: 10
# Qwen CN move: d2d4 Move number: 11
# Qwen US move: c8f5 Move number: 12
# Qwen CN move: e1g1 Move number: 13
# Qwen US move: a7a6 Move number: 14
# Qwen CN move: b5c6 Move number: 15
# Qwen US move: b7c6 Move number: 16
# Qwen CN move: d4e5 Move number: 17
# Qwen US move: Rg8 Move number: 18
# Qwen CN move: f1e1 Move number: 19
# Qwen US move: Qf6 Move number: 20
# Qwen CN move: e5f6 Move number: 21
# Qwen US move: Kd7 Move number: 22
# Qwen CN move: f3h4 Move number: 23
# Invalid move by US. Move: Nh4
# New Move: c5
# Qwen US move: c5 Move number: 24
# Qwen CN move: h4f5 Move number: 25
# Qwen US move: a8e8 Move number: 26
# Qwen CN move: c1e3 Move number: 27
# Qwen US move: g7f6 Move number: 28
# Qwen CN move: d1h5 Move number: 29
# Qwen US move: d7c8 Move number: 30
# Qwen CN move: h5h3 Move number: 31
# Qwen US move: Rg5 Move number: 32
# Qwen CN move: f5d6 Move number: 33
# Invalid move by US. Move: Nh4
# New Move: Kd8
# Qwen US move: Kd8 Move number: 34
# Qwen CN move: d6b7 Move number: 35
# Invalid move by US. Move: Bh6
# New Move: Ke7
# Qwen US move: Ke7 Move number: 36
# Qwen CN move: e3g5 Move number: 37
# Game 22 result: 1-0
#
#
# Starting game 23...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: b8c6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen US move: Nge7 Move number: 6
# Qwen CN move: b1c3 Move number: 7
# Qwen US move: Nf5 Move number: 8
# Qwen CN move: e4f5 Move number: 9
# Invalid move by US. Move: Nxe5
# New Move: d6
# Qwen US move: d6 Move number: 10
# Qwen CN move: e1g1 Move number: 11
# Qwen US move: c8f5 Move number: 12
# Qwen CN move: d2d4 Move number: 13
# Qwen US move: a7a6 Move number: 14
# Qwen CN move: b5c6 Move number: 15
# Qwen US move: b7c6 Move number: 16
# Qwen CN move: d1e2 Move number: 17
# Qwen US move: Qf6 Move number: 18
# Qwen CN move: f1e1 Move number: 19
# Invalid move by US. Move: Re2
# New Move: Rb8
# Qwen US move: Rb8 Move number: 20
# Qwen CN move: c3e4 Move number: 21
# Qwen US move: Rb6 Move number: 22
# Qwen CN move: e4f6 Move number: 23
# Qwen US move: g7f6 Move number: 24
# Qwen CN move: d4e5 Move number: 25
# Qwen US move: d6e5 Move number: 26
# Qwen CN move: f3e5 Move number: 27
# Qwen US move: c6c5 Move number: 28
# Qwen CN move: e5f7 Move number: 29
# Invalid move by US. Move: Nxf7+
# New Move: Be4
# Qwen US move: Be4 Move number: 30
# Qwen CN move: f7g5 Move number: 31
# Qwen US move: b6e6 Move number: 32
# Qwen CN move: g5e4 Move number: 33
# Qwen US move: e8d8 Move number: 34
# Qwen CN move: e2g4 Move number: 35
# Qwen US move: e6e5 Move number: 36
# Qwen CN move: e1d1 Move number: 37
# Qwen US move: Rd5 Move number: 38
# Qwen CN move: d1d5 Move number: 39
# Qwen US move: Ke7 Move number: 40
# Qwen CN move: g4d7 Move number: 41
# Game 23 result: 1-0
#
#
# Starting game 24...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: Nc6 Move number: 4
# Qwen CN move: d2d4 Move number: 5
# Qwen US move: e5d4 Move number: 6
# Qwen CN move: f3d4 Move number: 7
# Qwen US move: g8f6 Move number: 8
# Qwen CN move: d4c6 Move number: 9
# Invalid move by US. Move: Nxc6
# New Move: h5
# Qwen US move: h5 Move number: 10
# Qwen CN move: c6d8 Move number: 11
# Qwen US move: f8c5 Move number: 12
# Qwen CN move: d8f7 Move number: 13
# Qwen US move: f6e4 Move number: 14
# Qwen CN move: c1e3 Move number: 15
# Qwen US move: e8g8 Move number: 16
# Qwen CN move: f1c4 Move number: 17
# Qwen US move: Bxd4 Move number: 18
# Qwen CN move: f7e5 Move number: 19
# Qwen US move: Rf7 Move number: 20
# Qwen CN move: d1d4 Move number: 21
# Invalid move by US. Move: Nh3
# New Move: c5
# Qwen US move: c5 Move number: 22
# Qwen CN move: c4f7 Move number: 23
# Qwen US move: g8f8 Move number: 24
# Qwen CN move: d4e4 Move number: 25
# Qwen US move: f8e7 Move number: 26
# Qwen CN move: e5g6 Move number: 27
# Qwen US move: e7f7 Move number: 28
# Qwen CN move: e4f5 Move number: 29
# Invalid move by US. Move: Qg5
# New Move: Kg8
# Qwen US move: Kg8 Move number: 30
# Qwen CN move: g6e7 Move number: 31
# Invalid move by US. Move: Nc6
# New Move: Kh8
# Qwen US move: Kh8 Move number: 32
# Qwen CN move: f5h5 Move number: 33
# Game 24 result: 1-0
#
#
# Starting game 25...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: b8c6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen US move: Be7 Move number: 6
# Qwen CN move: e1g1 Move number: 7
# Invalid move by US. Move: Bf1
# New Move: b6
# Qwen US move: b6 Move number: 8
# Qwen CN move: f1e1 Move number: 9
# Qwen US move: c6d4 Move number: 10
# Qwen CN move: f3d4 Move number: 11
# Qwen US move: e5d4 Move number: 12
# Qwen CN move: c2c3 Move number: 13
# Qwen US move: c7c6 Move number: 14
# Qwen CN move: b5f1 Move number: 15
# Invalid move by US. Move: Bxc6
# New Move: a6
# Qwen US move: a6 Move number: 16
# Qwen CN move: c3d4 Move number: 17
# Qwen US move: d7d5 Move number: 18
# Qwen CN move: d2d3 Move number: 19
# Qwen US move: c8e6 Move number: 20
# Qwen CN move: b1c3 Move number: 21
# Qwen US move: g8f6 Move number: 22
# Qwen CN move: g2g3 Move number: 23
# Qwen US move: Ng4 Move number: 24
# Qwen CN move: e4d5 Move number: 25
# Qwen US move: Nxe5 Move number: 26
# Qwen CN move: d5e6 Move number: 27
# Invalid move by US. Move: Rxd8+
# New Move: Qd6
# Qwen US move: Qd6 Move number: 28
# Qwen CN move: d4e5 Move number: 29
# Qwen US move: Rg8 Move number: 30
# Qwen CN move: e5d6 Move number: 31
# Qwen US move: f7f5 Move number: 32
# Qwen CN move: d1h5 Move number: 33
# Qwen US move: g7g6 Move number: 34
# Qwen CN move: h5h7 Move number: 35
# Qwen US move: e8c8 Move number: 36
# Qwen CN move: d6d7 Move number: 37
# Qwen US move: Rxd7 Move number: 38
# Qwen CN move: e6d7 Move number: 39
# Qwen US move: c8b7 Move number: 40
# Qwen CN move: h7e7 Move number: 41
# Qwen US move: Rh8 Move number: 42
# Qwen CN move: d7d8r Move number: 43
# Game 25 result: 1-0
#
#
# Starting game 26...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: g8f6 Move number: 4
# Qwen CN move: d2d4 Move number: 5
# Qwen US move: Nxe4 Move number: 6
# Qwen CN move: f3e5 Move number: 7
# Qwen US move: Nc3 Move number: 8
# Qwen CN move: b1c3 Move number: 9
# Invalid move by US. Move: Nc3
# New Move: h5
# Qwen US move: h5 Move number: 10
# Qwen CN move: f1c4 Move number: 11
# Qwen US move: d7d5 Move number: 12
# Qwen CN move: c4d5 Move number: 13
# Qwen US move: f8d6 Move number: 14
# Qwen CN move: e5f7 Move number: 15
# Qwen US move: d8e7 Move number: 16
# Qwen CN move: d1e2 Move number: 17
# Invalid move by US. Move: Nxf7
# New Move: Be6
# Qwen US move: Be6 Move number: 18
# Qwen CN move: d5e6 Move number: 19
# Qwen US move: Qf8 Move number: 20
# Qwen CN move: f7h8 Move number: 21
# Qwen US move: b8d7 Move number: 22
# Qwen CN move: e2h5 Move number: 23
# Qwen US move: e8d8 Move number: 24
# Qwen CN move: c1g5 Move number: 25
# Qwen US move: d7f6 Move number: 26
# Qwen CN move: h8f7 Move number: 27
# Qwen US move: Ke7 Move number: 28
# Qwen CN move: g5f6 Move number: 29
# Qwen US move: e7e6 Move number: 30
# Qwen CN move: f6g5 Move number: 31
# Invalid move by US. Move: Bxf7+
# New Move: Ba3
# Qwen US move: Ba3 Move number: 32
# Qwen CN move: h5g6 Move number: 33
# Qwen US move: e6d7 Move number: 34
# Qwen CN move: f7e5 Move number: 35
# Qwen US move: d7c8 Move number: 36
# Qwen CN move: g6e6 Move number: 37
# Qwen US move: c8b8 Move number: 38
# Qwen CN move: e5d7 Move number: 39
# Invalid move by US. Move: Nxd5
# New Move: Kc8
# Qwen US move: Kc8 Move number: 40
# Qwen CN move: d7f8 Move number: 41
# Invalid move by US. Move: Nf8+
# New Move: Kb8
# Qwen US move: Kb8 Move number: 42
# Qwen CN move: e6e8 Move number: 43
# Game 26 result: 1-0
#
#
# Starting game 27...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: b8c6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen US move: Nf6 Move number: 6
# Qwen CN move: e1g1 Move number: 7
# Qwen US move: Bc5 Move number: 8
# Qwen CN move: c2c3 Move number: 9
# Qwen US move: Nxe4 Move number: 10
# Qwen CN move: d2d4 Move number: 11
# Invalid move by US. Move: dxe5
# New Move: a5
# Qwen US move: a5 Move number: 12
# Qwen CN move: d4c5 Move number: 13
# Qwen US move: e4c5 Move number: 14
# Qwen CN move: b5c6 Move number: 15
# Qwen US move: b7c6 Move number: 16
# Qwen CN move: f3e5 Move number: 17
# Qwen US move: e8g8 Move number: 18
# Qwen CN move: c1e3 Move number: 19
# Qwen US move: Nd3 Move number: 20
# Qwen CN move: e5d3 Move number: 21
# Invalid move by US. Move: Be2
# New Move: f5
# Qwen US move: f5 Move number: 22
# Qwen CN move: b1d2 Move number: 23
# Qwen US move: c8a6 Move number: 24
# Qwen CN move: d2f3 Move number: 25
# Qwen US move: d8f6 Move number: 26
# Qwen CN move: f1e1 Move number: 27
# Qwen US move: d7d6 Move number: 28
# Qwen CN move: d3f4 Move number: 29
# Invalid move by US. Move: Nfd2
# New Move: Rae8
# Qwen US move: Rae8 Move number: 30
# Qwen CN move: d1b3 Move number: 31
# Qwen US move: Re6 Move number: 32
# Qwen CN move: b3e6 Move number: 33
# Qwen US move: f6e6 Move number: 34
# Qwen CN move: f4e6 Move number: 35
# Qwen US move: f8b8 Move number: 36
# Qwen CN move: b2b3 Move number: 37
# Qwen US move: a5a4 Move number: 38
# Qwen CN move: h2h4 Move number: 39
# Qwen US move: Rxb3 Move number: 40
# Qwen CN move: a2b3 Move number: 41
# Qwen US move: a4b3 Move number: 42
# Qwen CN move: a1a6 Move number: 43
# Invalid move by US. Move: Rxa8
# New Move: Kf7
# Qwen US move: Kf7 Move number: 44
# Qwen CN move: e3d4 Move number: 45
# Invalid move by US. Move: Bxb3
# New Move: h5
# Qwen US move: h5 Move number: 46
# Qwen CN move: e6g5 Move number: 47
# Qwen US move: f7f8 Move number: 48
# Qwen CN move: a6a8 Move number: 49
# Game 27 result: 1-0
#
#
# Starting game 28...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: b8c6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen US move: a7a6 Move number: 6
# ...
# Qwen US move: f5 Move number: 10
# Qwen CN move: d2d4 Move number: 11
# Qwen US move: b7b5 Move number: 12
# Qwen CN move: a4b3 Move number: 13
# Qwen US move: f5e4 Move number: 14
# Qwen CN move: f3e5 Move number: 15
# Qwen US move: c6e5 Move number: 16
# Qwen CN move: d4e5 Move number: 17
# Invalid move by US. Move: Nf3
# New Move: Ra7
# Qwen US move: Ra7 Move number: 18
# Qwen CN move: e1g1 Move number: 19
# Qwen US move: Nd5 Move number: 20
# Qwen CN move: d1d5 Move number: 21
# Qwen US move: d8e7 Move number: 22
# Qwen CN move: c1f4 Move number: 23
# Qwen US move: c8b7 Move number: 24
# Qwen CN move: d5d1 Move number: 25
# Qwen US move: e7h4 Move number: 26
# Qwen CN move: f4e3 Move number: 27
# Qwen US move: Bxe7 Move number: 28
# Qwen CN move: b1d2 Move number: 29
# Qwen US move: a7a8 Move number: 30
# Qwen CN move: f2f4 Move number: 31
# Qwen US move: Bxd5 Move number: 32
# Qwen CN move: b3d5 Move number: 33
# Qwen US move: c7c6 Move number: 34
# Qwen CN move: d5e4 Move number: 35
# Qwen US move: e8g8 Move number: 36
# Qwen CN move: d2f3 Move number: 37
# Invalid move by US. Move: Nh4
# New Move: g5
# Qwen US move: g5 Move number: 38
# Qwen CN move: f3h4 Move number: 39
# Qwen US move: d7d5 Move number: 40
# Qwen CN move: e4h7 Move number: 41
# Qwen US move: g8h7 Move number: 42
# Qwen CN move: d1h5 Move number: 43
# Qwen US move: h7g7 Move number: 44
# Qwen CN move: h5g6 Move number: 45
# Invalid move by US. Move: Qxg7#
# New Move: Kh8
# Qwen US move: Kh8 Move number: 46
# Qwen CN move: g6h5 Move number: 47
# Qwen US move: Kg7 Move number: 48
# Qwen CN move: h5g6 Move number: 49
# Qwen US move: g7h8 Move number: 50
# Qwen CN move: g6h6 Move number: 51
# Qwen US move: h8g8 Move number: 52
# Qwen CN move: h4g6 Move number: 53
# Qwen US move: e7f6 Move number: 54
# Qwen CN move: e5f6 Move number: 55
# Qwen US move: Rxf6 Move number: 56
# Qwen CN move: h6h8 Move number: 57
# Qwen US move: g8f7 Move number: 58
# Qwen CN move: h8h7 Move number: 59
# Qwen US move: Ke8 Move number: 60
# Qwen CN move: h7e7 Move number: 61
# Game 93 result: 1-0
#
#
# Starting game 94...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: g8f6 Move number: 4
# Qwen CN move: f3e5 Move number: 5
# Qwen US move: Nxe4 Move number: 6
# Qwen CN move: d1e2 Move number: 7
# Invalid move by US. Move: Nf3
# New Move: Qe7
# Qwen US move: Qe7 Move number: 8
# Qwen CN move: e2e4 Move number: 9
# Invalid move by US. Move: Nc3
# New Move: a6
# Qwen US move: a6 Move number: 10
# Qwen CN move: e4e2 Move number: 11
# Qwen US move: d7d5 Move number: 12
# Qwen CN move: d2d4 Move number: 13
# Qwen US move: c8e6 Move number: 14
# Qwen CN move: c1e3 Move number: 15
# Qwen US move: b8d7 Move number: 16
# Qwen CN move: e5d7 Move number: 17
# Invalid move by US. Move: Nf3
# New Move: Qd8
# Qwen US move: Qd8 Move number: 18
# Qwen CN move: d7f8 Move number: 19
# Qwen US move: Rxf8 Move number: 20
# Qwen CN move: e2d2 Move number: 21
# Qwen US move: d8e7 Move number: 22
# Qwen CN move: f1d3 Move number: 23
# Qwen US move: e8c8 Move number: 24
# Qwen CN move: b1c3 Move number: 25
# Qwen US move: f8e8 Move number: 26
# Qwen CN move: e1d1 Move number: 27
# Invalid move by US. Move: Rf1
# New Move: h6
# Qwen US move: h6 Move number: 28
# Qwen CN move: f2f3 Move number: 29
# Qwen US move: c8b8 Move number: 30
# Qwen CN move: e3f2 Move number: 31
# Qwen US move: e7f6 Move number: 32
# Qwen CN move: h2h4 Move number: 33
# Qwen US move: e6f5 Move number: 34
# Qwen CN move: d3f5 Move number: 35
# Qwen US move: Re1+ Move number: 36
# Qwen CN move: h1e1 Move number: 37
# Qwen US move: Rd6 Move number: 38
# Qwen CN move: f5d3 Move number: 39
# Qwen US move: Qg5 Move number: 40
# Qwen CN move: h4g5 Move number: 41
# Qwen US move: g6 Move number: 42
# Qwen CN move: e1e8 Move number: 43
# Qwen US move: b8a7 Move number: 44
# Qwen CN move: c3b5 Move number: 45
# Qwen US move: a6b5 Move number: 46
# Qwen CN move: d2a5 Move number: 47
# Qwen US move: d6a6 Move number: 48
# Qwen CN move: a5a6 Move number: 49
# Invalid move by US. Move: Qxa6
# New Move: Kxa6
# Qwen US move: Kxa6 Move number: 50
# Qwen CN move: g5h6 Move number: 51
# Invalid move by US. Move: g4
# New Move: Kb6
# Qwen US move: Kb6 Move number: 52
# Qwen CN move: h6h7 Move number: 53
# Qwen US move: f5 Move number: 54
# Qwen CN move: h7h8q Move number: 55
# Qwen US move: f5f4 Move number: 56
# Qwen CN move: h8f6 Move number: 57
# Qwen US move: b6a7 Move number: 58
# Qwen CN move: a2a3 Move number: 59
# Qwen US move: g6g5 Move number: 60
# Qwen CN move: f6f8 Move number: 61
# Invalid move by US. Move: Qxf4
# New Move: b4
# Qwen US move: b4 Move number: 62
# Qwen CN move: f8c5 Move number: 63
# Qwen US move: b7b6 Move number: 64
# Qwen CN move: c5c7 Move number: 65
# Game 94 result: 1-0
#
#
# Starting game 95...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: b8c6 Move number: 4
# Qwen CN move: d2d4 Move number: 5
# Qwen US move: e5d4 Move number: 6
# Qwen CN move: f3d4 Move number: 7
# Invalid move by US. Move: Nf3
# New Move: Ba3
# Qwen US move: Ba3 Move number: 8
# Qwen CN move: b1a3 Move number: 9
# Qwen US move: Nxd4 Move number: 10
# Qwen CN move: d1d4 Move number: 11
# Qwen US move: g8f6 Move number: 12
# Qwen CN move: d4e5 Move number: 13
# Qwen US move: d8e7 Move number: 14
# Qwen CN move: e5e7 Move number: 15
# Qwen US move: e8e7 Move number: 16
# Qwen CN move: e4e5 Move number: 17
# Qwen US move: Nd5 Move number: 18
# Qwen CN move: c2c4 Move number: 19
# Qwen US move: d5b4 Move number: 20
# Qwen CN move: f1e2 Move number: 21
# Qwen US move: Rg8 Move number: 22
# Qwen CN move: c1d2 Move number: 23
# Qwen US move: a7a5 Move number: 24
# Qwen CN move: e1g1 Move number: 25
# Qwen US move: f7f6 Move number: 26
# Qwen CN move: f2f4 Move number: 27
# Qwen US move: Nc6 Move number: 28
# Qwen CN move: a3b5 Move number: 29
# Qwen US move: e7d8 Move number: 30
# Qwen CN move: a1e1 Move number: 31
# Qwen US move: f6e5 Move number: 32
# Qwen CN move: f4e5 Move number: 33
# Qwen US move: Nxe5 Move number: 34
# Qwen CN move: d2g5 Move number: 35
# Invalid move by US. Move: Bxe7
# New Move: Ke8
# Qwen US move: Ke8 Move number: 36
# Qwen CN move: b5c7 Move number: 37
# Game 95 result: 1-0
#
#
# Starting game 96...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: c7c5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: b8c6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Invalid move by US. Move: Nc3
# New Move: g5
# Qwen US move: g5 Move number: 6
# Qwen CN move: f3g5 Move number: 7
# Qwen US move: g8f6 Move number: 8
# Qwen CN move: b1c3 Move number: 9
# Qwen US move: h8g8 Move number: 10
# Qwen CN move: d2d3 Move number: 11
# Qwen US move: h7h6 Move number: 12
# Qwen CN move: g5f3 Move number: 13
# Qwen US move: Nxe4 Move number: 14
# Qwen CN move: d3e4 Move number: 15
# Qwen US move: Nd4 Move number: 16
# Qwen CN move: f3d4 Move number: 17
# Qwen US move: Rg7 Move number: 18
# Qwen CN move: d4e6 Move number: 19
# Invalid move by US. Move: Nxc7
# New Move: Rb8
# Qwen US move: Rb8 Move number: 20
# Qwen CN move: e6d8 Move number: 21
# Qwen US move: Rxg2 Move number: 22
# Qwen CN move: d1h5 Move number: 23
# Qwen US move: g2f2 Move number: 24
# Qwen CN move: e1f2 Move number: 25
# Qwen US move: e8d8 Move number: 26
# Qwen CN move: h5f7 Move number: 27
# Qwen US move: b7b6 Move number: 28
# Qwen CN move: c3d5 Move number: 29
# Invalid move by US. Move: Be3
# New Move: e5
# Qwen US move: e5 Move number: 30
# Qwen CN move: f7f8 Move number: 31
# Game 96 result: 1-0
#
#
# Starting game 97...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: g8f6 Move number: 4
# Qwen CN move: f3e5 Move number: 5
# Qwen US move: d7d6 Move number: 6
# Qwen CN move: e5f3 Move number: 7
# Qwen US move: f6e4 Move number: 8
# Qwen CN move: d2d4 Move number: 9
# Invalid move by US. Move: Nxe4
# New Move: Qg5
# Qwen US move: Qg5 Move number: 10
# Qwen CN move: f3g5 Move number: 11
# Qwen US move: Nc3 Move number: 12
# Qwen CN move: b1c3 Move number: 13
# Qwen US move: f8e7 Move number: 14
# Qwen CN move: f1b5 Move number: 15
# Qwen US move: c8d7 Move number: 16
# Qwen CN move: b5d7 Move number: 17
# Qwen US move: b8d7 Move number: 18
# Qwen CN move: e1g1 Move number: 19
# Invalid move by US. Move: Nbd2
# New Move: g6
# Qwen US move: g6 Move number: 20
# Qwen CN move: f1e1 Move number: 21
# Qwen US move: e8g8 Move number: 22
# Qwen CN move: g1h1 Move number: 23
# Qwen US move: f8e8 Move number: 24
# Qwen CN move: e1f1 Move number: 25
# Qwen US move: c7c5 Move number: 26
# Qwen CN move: g5f3 Move number: 27
# Invalid move by US. Move: Nh4
# New Move: Rad8
# Qwen US move: Rad8 Move number: 28
# Qwen CN move: c1e3 Move number: 29
# Invalid move by US. Move: Nbd2
# New Move: a6
# Qwen US move: a6 Move number: 30
# Qwen CN move: c3d5 Move number: 31
# Qwen US move: d7f6 Move number: 32
# Qwen CN move: d5f4 Move number: 33
# Qwen US move: e7f8 Move number: 34
# Qwen CN move: f3g1 Move number: 35
# Qwen US move: e8e3 Move number: 36
# Qwen CN move: f2e3 Move number: 37
# Qwen US move: Nh5 Move number: 38
# Qwen CN move: f4h5 Move number: 39
# Qwen US move: gxh5 Move number: 40
# Qwen CN move: g1h3 Move number: 41
# Qwen US move: cxd4 Move number: 42
# Qwen CN move: d1h5 Move number: 43
# Qwen US move: dxe3 Move number: 44
# Qwen CN move: h5f7 Move number: 45
# Qwen US move: g8h8 Move number: 46
# Qwen CN move: f7f6 Move number: 47
# Qwen US move: h8g8 Move number: 48
# Qwen CN move: f6d8 Move number: 49
# Qwen US move: h7h6 Move number: 50
# Qwen CN move: d8f8 Move number: 51
# Qwen US move: Kh7 Move number: 52
# Qwen CN move: f8e7 Move number: 53
# Qwen US move: Kh8 Move number: 54
# Qwen CN move: f1f8 Move number: 55
# Game 97 result: 1-0
#
#
# Starting game 98...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: Nc6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen US move: a7a6 Move number: 6
# Qwen CN move: b5a4 Move number: 7
# Qwen US move: Be7 Move number: 8
# Qwen CN move: e1g1 Move number: 9
# Qwen US move: g8f6 Move number: 10
# Qwen CN move: f1e1 Move number: 11
# Qwen US move: b7b5 Move number: 12
# Qwen CN move: a4b3 Move number: 13
# Qwen US move: Bd6 Move number: 14
# Qwen CN move: d2d4 Move number: 15
# Qwen US move: e8g8 Move number: 16
# Qwen CN move: c1g5 Move number: 17
# Qwen US move: f8e8 Move number: 18
# Qwen CN move: c2c3 Move number: 19
# Qwen US move: c8b7 Move number: 20
# Qwen CN move: b1d2 Move number: 21
# Qwen US move: h7h6 Move number: 22
# Qwen CN move: g5h4 Move number: 23
# Qwen US move: e5d4 Move number: 24
# Qwen CN move: c3d4 Move number: 25
# Qwen US move: d6e7 Move number: 26
# Qwen CN move: a1c1 Move number: 27
# Qwen US move: d7d6 Move number: 28
# Qwen CN move: a2a3 Move number: 29
# Qwen US move: Ng4 Move number: 30
# Qwen CN move: h4g3 Move number: 31
# Qwen US move: Nxd4 Move number: 32
# Qwen CN move: f3d4 Move number: 33
# Qwen US move: e7f6 Move number: 34
# Qwen CN move: d4f3 Move number: 35
# Qwen US move: Be5 Move number: 36
# Qwen CN move: f3e5 Move number: 37
# Invalid move by US. Move: Nf3
# New Move: Qc8
# Qwen US move: Qc8 Move number: 38
# Qwen CN move: e5g4 Move number: 39
# Qwen US move: Rxe4 Move number: 40
# Qwen CN move: d2e4 Move number: 41
# Qwen US move: g8h8 Move number: 42
# Qwen CN move: g4h6 Move number: 43
# Qwen US move: c7c5 Move number: 44
# Qwen CN move: h6f7 Move number: 45
# Qwen US move: h8g8 Move number: 46
# Qwen CN move: f7g5 Move number: 47
# Qwen US move: Bd5 Move number: 48
# Qwen CN move: b3d5 Move number: 49
# Qwen US move: g8f8 Move number: 50
# Qwen CN move: d1f3 Move number: 51
# Qwen US move: Qf5 Move number: 52
# Qwen CN move: f3f5 Move number: 53
# Qwen US move: f8e8 Move number: 54
# Qwen CN move: e4f6 Move number: 55
# Qwen US move: e8d8 Move number: 56
# Qwen CN move: f5d7 Move number: 57
# Game 98 result: 1-0
#
#
# Starting game 99...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: Nc6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen US move: Be7 Move number: 6
# Qwen CN move: e1g1 Move number: 7
# Invalid move by US. Move: Bc4
# New Move: b6
# Qwen US move: b6 Move number: 8
# Qwen CN move: b1c3 Move number: 9
# Qwen US move: e7f6 Move number: 10
# Qwen CN move: c3d5 Move number: 11
# Qwen US move: a7a6 Move number: 12
# Qwen CN move: b5a4 Move number: 13
# Qwen US move: b6b5 Move number: 14
# Qwen CN move: a4b3 Move number: 15
# Qwen US move: Be7 Move number: 16
# Qwen CN move: d2d4 Move number: 17
# Qwen US move: Bxd6 Move number: 18
# Qwen CN move: f3e5 Move number: 19
# Qwen US move: Nxe5 Move number: 20
# Qwen CN move: d4e5 Move number: 21
# Qwen US move: Be7 Move number: 22
# Qwen CN move: d1f3 Move number: 23
# Qwen US move: g8h6 Move number: 24
# Qwen CN move: c1h6 Move number: 25
# Qwen US move: g7h6 Move number: 26
# Qwen CN move: d5b6 Move number: 27
# Qwen US move: e8g8 Move number: 28
# Qwen CN move: b6a8 Move number: 29
# Qwen US move: Re8 Move number: 30
# Qwen CN move: b3f7 Move number: 31
# Invalid move by US. Move: Bxf8
# New Move: Kg7
# Qwen US move: Kg7 Move number: 32
# Qwen CN move: f7e8 Move number: 33
# Qwen US move: d7d6 Move number: 34
# Qwen CN move: e8c6 Move number: 35
# Qwen US move: c8e6 Move number: 36
# Qwen CN move: a1d1 Move number: 37
# Qwen US move: g7h8 Move number: 38
# Qwen CN move: a8c7 Move number: 39
# Invalid move by US. Move: Bc6
# New Move: Bg4
# Qwen US move: Bg4 Move number: 40
# Qwen CN move: f3g4 Move number: 41
# Qwen US move: d8c7 Move number: 42
# Qwen CN move: g4d7 Move number: 43
# Qwen US move: c7d7 Move number: 44
# Qwen CN move: c6d7 Move number: 45
# Qwen US move: d6e5 Move number: 46
# Qwen CN move: d7f5 Move number: 47
# Qwen US move: Bxf8 Move number: 48
# Qwen CN move: d1d7 Move number: 49
# Qwen US move: Bd6 Move number: 50
# Qwen CN move: d7d6 Move number: 51
# Invalid move by US. Move: Rd5
# New Move: Kg8
# Qwen US move: Kg8 Move number: 52
# Qwen CN move: d6d8 Move number: 53
# Invalid move by US. Move: Rd7+
# New Move: Kg7
# Qwen US move: Kg7 Move number: 54
# Qwen CN move: f1d1 Move number: 55
# Qwen US move: Kf7 Move number: 56
# Qwen CN move: d1d7 Move number: 57
# Qwen US move: f7f6 Move number: 58
# Qwen CN move: h2h4 Move number: 59
# Qwen US move: b5b4 Move number: 60
# Qwen CN move: d8f8 Move number: 61
# Game 99 result: 1-0
#
#
# Starting game 100...
# Qwen CN move: e2e4 Move number: 1
# Qwen US move: e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen US move: Nc6 Move number: 4
# Qwen CN move: f1c4 Move number: 5
# Qwen US move: Nf6 Move number: 6
# Qwen CN move: d2d3 Move number: 7
# Qwen US move: f8c5 Move number: 8
# Qwen CN move: e1g1 Move number: 9
# Qwen US move: d7d6 Move number: 10
# Qwen CN move: c2c3 Move number: 11
# Qwen US move: a7a6 Move number: 12
# Qwen CN move: h2h3 Move number: 13
# Invalid move by US. Move: Nbd4
# New Move: g5
# Qwen US move: g5 Move number: 14
# Qwen CN move: c1g5 Move number: 15
# Qwen US move: h8g8 Move number: 16
# Qwen CN move: g1h1 Move number: 17
# Qwen US move: d8e7 Move number: 18
# Qwen CN move: b1d2 Move number: 19
# Qwen US move: c5a7 Move number: 20
# Qwen CN move: g5h4 Move number: 21
# Qwen US move: Bg4 Move number: 22
# Qwen CN move: h3g4 Move number: 23
# Qwen US move: Rg5 Move number: 24
# Qwen CN move: f3g5 Move number: 25
# Qwen US move: Bxd4 Move number: 26
# Qwen CN move: c4f7 Move number: 27
# Qwen US move: Kd8 Move number: 28
# Qwen CN move: c3d4 Move number: 29
# Qwen US move: c6d4 Move number: 30
# Qwen CN move: f1g1 Move number: 31
# Qwen US move: h7h6 Move number: 32
# Qwen CN move: g5h3 Move number: 33
# Qwen US move: e7f7 Move number: 34
# Qwen CN move: d2f3 Move number: 35
# Qwen US move: Nc2 Move number: 36
# Qwen CN move: d1c2 Move number: 37
# Qwen US move: Qd5 Move number: 38
# Qwen CN move: e4d5 Move number: 39
# Invalid move by US. Move: Rg1
# New Move: a5
# Qwen US move: a5 Move number: 40
# Qwen CN move: h4f6 Move number: 41
# Qwen US move: d8d7 Move number: 42
# Qwen CN move: c2a4 Move number: 43
# Qwen US move: c7c6 Move number: 44
# Qwen CN move: d5c6 Move number: 45
# Qwen US move: b7c6 Move number: 46
# Qwen CN move: a1c1 Move number: 47
# Qwen US move: Rc8 Move number: 48
# Qwen CN move: a2a3 Move number: 49
# Qwen US move: Rc7 Move number: 50
# Qwen CN move: b2b3 Move number: 51
# Qwen US move: Rb7 Move number: 52
# Qwen CN move: a4c6 Move number: 53
# Invalid move by US. Move: Qxc7
# New Move: Ke6
# Qwen US move: Ke6 Move number: 54
# Qwen CN move: f6e5 Move number: 55
# Qwen US move: Rb6 Move number: 56
# Qwen CN move: c6e8 Move number: 57
# Qwen US move: e6d5 Move number: 58
# Qwen CN move: h3f4 Move number: 59
# Game 100 result: 1-0

# %%
results = []

# %%
results.append({
            "Qwen US Wins": qwen_us_wins,
            "Qwen CN Wins": qwen_cn_wins,
            "Draws": draws,
        })

print(results)
# Out:
# [{'Qwen US Wins': 0, 'Qwen CN Wins': 200, 'Draws': 0}]

# %%
df = pd.DataFrame(results)
df.to_csv(f"LLM_{QWEN_US_AI}_vs_LLM_{QWEN_CN_AI}.csv", index=False)
print(f"Results saved to LLM_{QWEN_US_AI}_vs_LLM_{QWEN_CN_AI}.csv")
# Out:
# Results saved to LLM_50_vs_LLM_100.csv
