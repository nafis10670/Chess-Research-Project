# %% [markdown]
# # LLM_1 - **10%** vs. LLM_2 - **90%**

# %%
import chess
from stockfish import Stockfish
from ollama import chat
from ollama import ChatResponse
import json
import random
import pandas as pd
import asyncio

# %%
# STOCKFISH_PATH = r"C:\Users\nafis\Downloads\stockfish-windows-x86-64-avx2\stockfish\stockfish-windows-x86-64-avx2.exe"

STOCKFISH_ELO = 3500
NUM_GAMES = 100
MOVE_LIMIT = 300
RANDOM_START = 0
QWEN_US_AI = 10
QWEN_CN_AI = 90

# %%
stockfish = Stockfish()
stockfish.update_engine_parameters({"Threads": 4, "Hash": 4096})

# %%
qwen_cn_wins = 0
qwen_us_wins = 0
draws = 0

# %%
# def generate_random_number(seed:int) -> int:
#     # random.seed(seed)
#     return random.randint(1, 100)

# %%
def valid_move_to_string(board):
    legal_moves = [
        board.san(move) for move in board.legal_moves]
    
    if not legal_moves:
        return "No legal moves."
    else:
        return ", ".join(legal_moves)

# %%
def get_move_history(board: chess.Board) -> str:
    """Return a formatted move history string like '1. e4 e5 2. Nf3 d5'."""
    temp_board = chess.Board()  # Start from the initial position.
    move_history = []
    
    # Iterate over the moves in the board's move stack.
    for i, move in enumerate(board.move_stack):
        # Get the SAN for the move in the current temporary board.
        move_san = temp_board.san(move)
        # Push the move so that the board state is updated.
        temp_board.push(move)
        
        # For white moves (even index), start a new entry with move number.
        if i % 2 == 0:
            move_history.append(f"{i//2 + 1}. {move_san}")
        # For black moves, append to the last white move entry.
        else:
            move_history[-1] += f" {move_san}"
    
    # Join all entries with a space.
    return " ".join(move_history)

# %%
async def get_move_with_timeout(stockfish, timeout=15):
    """
    Run stockfish.get_best_move() in a separate thread and wait for a maximum of `timeout` seconds.
    If the call exceeds the timeout, return None.
    """
    try:
        # Use asyncio.to_thread to run the blocking call in a separate thread.
        move = await asyncio.wait_for(asyncio.to_thread(stockfish.get_best_move), timeout)
        return move
    except asyncio.TimeoutError:
        # move = stockfish.get_best_move_time(1000)
        print(f"Timeout: stockfish.get_best_move() took more than 15 seconds.")
        return None

# %%
def get_qwen_move(board:chess.Board, fen:str, temp=0.0):
    valid_moves = valid_move_to_string(board)

    move_history = get_move_history(board)
    
    response: ChatResponse = chat(model='qwen:32b', messages=[
        {
            'role': 'system',
            'content': 'You are a grand master chess player.'
        },
        {
            'role': 'user',
            'content': f"""You are playing chess and it is your turn. This is the current state of the game. Use this to work out where the pieces are on the board:

FEN: {fen}

The possible set of legal moves are: 

Legal Moves: {valid_moves}

+(You have to choose one from the provided list. Do not choose a move that is not in the list.)

The move history is: {move_history}.

Output the best move in SAN format to follow this position. Use the following single blob of JSON. Do not include any other information.
{{
    "san": "The move in SAN format",
}}"""}], options={"temperature": temp})
    
    try:
        parsed_json = json.loads(response.message.content)
        qwen_move = parsed_json["san"]
    except Exception as e:
        print(f"Wrong format given by Qwen. \nQwen Output: {response.message.content}")

    

    return qwen_move

# %%
def get_random_move(board:chess.Board, fen:str, seed: int = 101):
    legal_moves = [
        board.san(move)
        for move in board.legal_moves
    ]

    random.seed(seed)

    # print(random.choice(legal_moves))
    return random.choice(legal_moves)

    # print(legal_moves[0])

# %%
for game_number in range(1, NUM_GAMES + 1):
    
    move_counter = 0

    print(f"Starting game {game_number}...")

    board = chess.Board()

    while not board.is_game_over() and move_counter <= MOVE_LIMIT:
        if board.turn == chess.WHITE and not board.is_game_over():
            num = random.randint(1,100)
            
            if num <= QWEN_US_AI:
                stockfish.set_fen_position(board.fen())
                qwen_us_move = await get_move_with_timeout(stockfish)

                if qwen_us_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break
            
            else:
                qwen_us_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_us_move)
            except Exception as e:
                print(f"Invalid move by Qwen white. Move: {qwen_us_move}")
                qwen_us_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_us_move)
                print(f"New Move: {qwen_us_move}")
                # continue
            
            move_counter += 1        
            print(f"Qwen US move: {qwen_us_move} Move number: {move_counter}")

        elif board.turn == chess.BLACK and not board.is_game_over():
            num = random.randint(1, 100)

            if num <= QWEN_CN_AI:
                stockfish.set_fen_position(board.fen())
                qwen_cn_move = await get_move_with_timeout(stockfish)

                if qwen_cn_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break

            else:
                qwen_cn_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_cn_move)
            except Exception as e:
                print(f"Invalid move by Qwen black. Move: {qwen_cn_move}")
                qwen_cn_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_cn_move)
                print(f"New Move: {qwen_cn_move}")
                # continue
            move_counter += 1
            print(f"Qwen CN move: {qwen_cn_move} Move number: {move_counter}")   

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        qwen_us_wins += 1
    elif result == "0-1":
        qwen_cn_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n\n")
# Out:
# Starting game 1...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Invalid move by Qwen white. Move: Nxe5
# New Move: f3
# Qwen US move: f3 Move number: 9
# Qwen CN move: c7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: Nxe5 Move number: 12
# Invalid move by Qwen white. Move: Nxe5
# New Move: Bb5
# Qwen US move: Bb5 Move number: 13
# Qwen CN move: e5g6 Move number: 14
# Qwen US move: Bxc6 Move number: 15
# Qwen CN move: d7c6 Move number: 16
# Qwen US move: Nd5 Move number: 17
# Qwen CN move: c6d5 Move number: 18
# Invalid move by Qwen white. Move: Nxb7
# New Move: g3
# Qwen US move: g3 Move number: 19
# Qwen CN move: g8e7 Move number: 20
# Qwen US move: d1e2 Move number: 21
# Invalid move by Qwen black. Move: Qe4
# New Move: h6
# Qwen CN move: h6 Move number: 22
# Qwen US move: Qd3 Move number: 23
# Qwen CN move: e7c6 Move number: 24
# Qwen US move: Qe3 Move number: 25
# Qwen CN move: f8e7 Move number: 26
# Qwen US move: Qg5 Move number: 27
# Qwen CN move: h6g5 Move number: 28
# Qwen US move: Rg1 Move number: 29
# Qwen CN move: Rg8 Move number: 30
# Qwen US move: Rg2 Move number: 31
# Qwen CN move: c6d4 Move number: 32
# Qwen US move: Rf2 Move number: 33
# Qwen CN move: d8a5 Move number: 34
# Invalid move by Qwen white. Move: Ke2
# New Move: b4
# Qwen US move: b4 Move number: 35
# Qwen CN move: a5b4 Move number: 36
# Qwen US move: c1d2 Move number: 37
# Invalid move by Qwen black. Move: Nxe7
# New Move: Qb2
# Qwen CN move: Qb2 Move number: 38
# Invalid move by Qwen white. Move: Bxd4
# New Move: c3
# Qwen US move: c3 Move number: 39
# Qwen CN move: b2a1 Move number: 40
# Qwen US move: d2c1 Move number: 41
# Qwen CN move: Nh8 Move number: 42
# Qwen US move: Rg2 Move number: 43
# Qwen CN move: a1c1 Move number: 44
# Qwen US move: Kf2 Move number: 45
# Qwen CN move: c1d2 Move number: 46
# Qwen US move: Kf1 Move number: 47
# Qwen CN move: d2d1 Move number: 48
# Qwen US move: Kf2 Move number: 49
# Qwen CN move: Bg4 Move number: 50
# Qwen US move: exd5 Move number: 51
# Qwen CN move: d1e2 Move number: 52
# Qwen US move: Kg1 Move number: 53
# Qwen CN move: e2e1 Move number: 54
# Game 1 result: 0-1
#
#
# Starting game 2...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: d7d6 Move number: 4
# Qwen US move: Nc3 Move number: 5
# Qwen CN move: e7e5 Move number: 6
# Qwen US move: Nxe5 Move number: 7
# Qwen CN move: d6e5 Move number: 8
# Invalid move by Qwen white. Move: Nxe5
# New Move: d3
# Qwen US move: d3 Move number: 9
# Qwen CN move: b8c6 Move number: 10
# Qwen US move: g2g3 Move number: 11
# Qwen CN move: Nge7 Move number: 12
# Invalid move by Qwen white. Move: Nbd2
# New Move: Bg2
# Qwen US move: Bg2 Move number: 13
# Qwen CN move: h7h5 Move number: 14
# Invalid move by Qwen white. Move: Nbd2
# New Move: Bf1
# Qwen US move: Bf1 Move number: 15
# Qwen CN move: c8g4 Move number: 16
# Invalid move by Qwen white. Move: Nbd2
# New Move: d4
# Qwen US move: d4 Move number: 17
# Qwen CN move: c5d4 Move number: 18
# Qwen US move: f2f3 Move number: 19
# Invalid move by Qwen black. Move: Nxe5
# New Move: Qc7
# Qwen CN move: Qc7 Move number: 20
# Qwen US move: c3b5 Move number: 21
# Invalid move by Qwen black. Move: Nxe7+
# New Move: Rb8
# Qwen CN move: Rb8 Move number: 22
# Qwen US move: b5c7 Move number: 23
# Invalid move by Qwen black. Move: Nxd4
# New Move: Kd8
# Qwen CN move: Kd8 Move number: 24
# Qwen US move: f3g4 Move number: 25
# Qwen CN move: h4 Move number: 26
# Qwen US move: Nxd5 Move number: 27
# Qwen CN move: h4g3 Move number: 28
# Qwen US move: Nxe7 Move number: 29
# Qwen CN move: h8h2 Move number: 30
# Qwen US move: Rg1 Move number: 31
# Qwen CN move: f8e7 Move number: 32
# Qwen US move: Rxg3 Move number: 33
# Qwen CN move: Rd2 Move number: 34
# Qwen US move: Rg1 Move number: 35
# Qwen CN move: d2h2 Move number: 36
# Qwen US move: Rg3 Move number: 37
# Qwen CN move: e7h4 Move number: 38
# Qwen US move: c1g5 Move number: 39
# Qwen CN move: h4g5 Move number: 40
# Qwen US move: Qd2 Move number: 41
# Qwen CN move: g5d2 Move number: 42
# Qwen US move: Kd1 Move number: 43
# Qwen CN move: d2f4 Move number: 44
# Invalid move by Qwen white. Move: Rg3
# New Move: c3
# Qwen US move: c3 Move number: 45
# Qwen CN move: f4g3 Move number: 46
# Qwen US move: g4g5 Move number: 47
# Invalid move by Qwen black. Move: gxf6
# New Move: Ne7
# Qwen CN move: Ne7 Move number: 48
# Qwen US move: a1c1 Move number: 49
# Qwen CN move: Rc2 Move number: 50
# Qwen US move: Rxc2 Move number: 51
# Qwen CN move: b8c8 Move number: 52
# Qwen US move: Rh2 Move number: 53
# Qwen CN move: g3h2 Move number: 54
# Qwen US move: cxd4 Move number: 55
# Qwen CN move: e5d4 Move number: 56
# Invalid move by Qwen white. Move: Bf1
# New Move: Bh3
# Qwen US move: Bh3 Move number: 57
# Qwen CN move: c8c6 Move number: 58
# Qwen US move: Bf1 Move number: 59
# Qwen CN move: h2f4 Move number: 60
# Qwen US move: Bg2 Move number: 61
# Qwen CN move: d4d3 Move number: 62
# Qwen US move: Bh1 Move number: 63
# Qwen CN move: Rc1 Move number: 64
# Game 2 result: 0-1
#
#
# Starting game 3...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Invalid move by Qwen white. Move: Nge2
# New Move: b3
# Qwen US move: b3 Move number: 5
# Qwen CN move: e7e5 Move number: 6
# Qwen US move: b1c3 Move number: 7
# Qwen CN move: Nge7 Move number: 8
# Invalid move by Qwen white. Move: Nbd4
# New Move: Rb1
# Qwen US move: Rb1 Move number: 9
# Qwen CN move: d7d5 Move number: 10
# Qwen US move: e4d5 Move number: 11
# Qwen CN move: Qxd5 Move number: 12
# Qwen US move: Nxe5 Move number: 13
# Qwen CN move: d5e5 Move number: 14
# Qwen US move: Ne4 Move number: 15
# Qwen CN move: e5e4 Move number: 16
# Qwen US move: Be2 Move number: 17
# Qwen CN move: e4g2 Move number: 18
# Qwen US move: Bd3 Move number: 19
# Qwen CN move: Bg4 Move number: 20
# Qwen US move: Bf1 Move number: 21
# Qwen CN move: g2e4 Move number: 22
# Qwen US move: Be2 Move number: 23
# Qwen CN move: e4h1 Move number: 24
# Qwen US move: e2f1 Move number: 25
# Qwen CN move: g4d1 Move number: 26
# Qwen US move: Kxd1 Move number: 27
# Qwen CN move: h1f1 Move number: 28
# Game 3 result: 0-1
#
#
# Starting game 4...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: d7d6 Move number: 6
# Qwen US move: Nxf7 Move number: 7
# Qwen CN move: e8f7 Move number: 8
# Qwen US move: Nc3 Move number: 9
# Qwen CN move: c8g4 Move number: 10
# Invalid move by Qwen white. Move: Nbd2
# New Move: b3
# Qwen US move: b3 Move number: 11
# Qwen CN move: g4d1 Move number: 12
# Qwen US move: c3d1 Move number: 13
# Qwen CN move: Nfd7 Move number: 14
# Invalid move by Qwen white. Move: Nxe5
# New Move: a3
# Qwen US move: a3 Move number: 15
# Qwen CN move: f8e7 Move number: 16
# Qwen US move: c1b2 Move number: 17
# Invalid move by Qwen black. Move: Bf1
# New Move: Nc6
# Qwen CN move: Nc6 Move number: 18
# Qwen US move: d1c3 Move number: 19
# Qwen CN move: Na5 Move number: 20
# Qwen US move: Nd5 Move number: 21
# Qwen CN move: h8e8 Move number: 22
# Qwen US move: Nxe7 Move number: 23
# Qwen CN move: d8e7 Move number: 24
# Qwen US move: Bd4 Move number: 25
# Qwen CN move: e7e4 Move number: 26
# Qwen US move: Kd1 Move number: 27
# Invalid move by Qwen black. Move: Re8
# New Move: Qxg2
# Qwen CN move: Qxg2 Move number: 28
# Qwen US move: Bf6 Move number: 29
# Qwen CN move: g2h1 Move number: 30
# Qwen US move: Bd4 Move number: 31
# Qwen CN move: h1f1 Move number: 32
# Game 4 result: 0-1
#
#
# Starting game 5...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: c7c6 Move number: 8
# Qwen US move: Nd5 Move number: 9
# Qwen CN move: c6d5 Move number: 10
# Invalid move by Qwen white. Move: Nxe5
# New Move: h4
# Qwen US move: h4 Move number: 11
# Qwen CN move: d5e4 Move number: 12
# Qwen US move: d2d4 Move number: 13
# Qwen CN move: Nf3+ Move number: 14
# Qwen US move: Qxf3 Move number: 15
# Qwen CN move: e4f3 Move number: 16
# Qwen US move: Rh3 Move number: 17
# Qwen CN move: f3g2 Move number: 18
# Qwen US move: Rxf3 Move number: 19
# Qwen CN move: d8a5 Move number: 20
# Qwen US move: Ke2 Move number: 21
# Qwen CN move: Qf5 Move number: 22
# Qwen US move: Rxf5 Move number: 23
# Qwen CN move: g2g1r Move number: 24
# Qwen US move: Re5+ Move number: 25
# Qwen CN move: g8e7 Move number: 26
# Qwen US move: f2f3 Move number: 27
# Qwen CN move: f7f6 Move number: 28
# Qwen US move: Rxe7+ Move number: 29
# Qwen CN move: f8e7 Move number: 30
# Qwen US move: Bh3 Move number: 31
# Qwen CN move: d7d5 Move number: 32
# Qwen US move: Bxc8 Move number: 33
# Qwen CN move: a8c8 Move number: 34
# Qwen US move: Bf4 Move number: 35
# Qwen CN move: g1a1 Move number: 36
# Invalid move by Qwen white. Move: Bxd5
# New Move: b4
# Qwen US move: b4 Move number: 37
# Qwen CN move: c8c2 Move number: 38
# Qwen US move: f4d2 Move number: 39
# Qwen CN move: Rxd2+ Move number: 40
# Qwen US move: Ke3 Move number: 41
# Qwen CN move: d2b2 Move number: 42
# Qwen US move: Kd3 Move number: 43
# Qwen CN move: a1a2 Move number: 44
# Qwen US move: Ke3 Move number: 45
# Qwen CN move: e7d6 Move number: 46
# Qwen US move: Kd3 Move number: 47
# Qwen CN move: Rb1 Move number: 48
# Qwen US move: Ke3 Move number: 49
# Qwen CN move: b1b3 Move number: 50
# Game 5 result: 0-1
#
#
# Starting game 6...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: Nc3 Move number: 5
# Qwen CN move: b8c6 Move number: 6
# Qwen US move: Nxe5 Move number: 7
# Qwen CN move: c6e5 Move number: 8
# Invalid move by Qwen white. Move: Nbd2
# New Move: d3
# Qwen US move: d3 Move number: 9
# Qwen CN move: d7d5 Move number: 10
# Qwen US move: d3d4 Move number: 11
# Qwen CN move: Nxe4 Move number: 12
# Qwen US move: Nxd5 Move number: 13
# Qwen CN move: e4f2 Move number: 14
# Qwen US move: Nxe7 Move number: 15
# Qwen CN move: f8e7 Move number: 16
# Qwen US move: Bh6 Move number: 17
# Qwen CN move: g7h6 Move number: 18
# Qwen US move: Qe2 Move number: 19
# Qwen CN move: Qxd4 Move number: 20
# Qwen US move: Qxe5 Move number: 21
# Qwen CN move: d4e5 Move number: 22
# Qwen US move: Kd2 Move number: 23
# Qwen CN move: e7g5 Move number: 24
# Game 6 result: 0-1
#
#
# Starting game 7...
# Qwen US move: d2d4 Move number: 1
# Qwen CN move: d7d5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: e7e6 Move number: 4
# Qwen US move: Nfd2 Move number: 5
# Qwen CN move: c7c5 Move number: 6
# Qwen US move: Nc4 Move number: 7
# Qwen CN move: d5c4 Move number: 8
# Invalid move by Qwen white. Move: Nxc4
# New Move: a3
# Qwen US move: a3 Move number: 9
# Qwen CN move: c5d4 Move number: 10
# Qwen US move: e2e4 Move number: 11
# Qwen CN move: Be7 Move number: 12
# Qwen US move: Bxc4 Move number: 13
# Qwen CN move: g8f6 Move number: 14
# Qwen US move: Bd3 Move number: 15
# Qwen CN move: b8d7 Move number: 16
# Qwen US move: Be2 Move number: 17
# Qwen CN move: e6e5 Move number: 18
# Qwen US move: Be3 Move number: 19
# Invalid move by Qwen black. Move: Be3
# New Move: Bf8
# Qwen CN move: Bf8 Move number: 20
# Qwen US move: e3c1 Move number: 21
# Qwen CN move: Be7 Move number: 22
# Qwen US move: Bd2 Move number: 23
# Qwen CN move: e8g8 Move number: 24
# Qwen US move: Bd3 Move number: 25
# Qwen CN move: d7c5 Move number: 26
# Qwen US move: Be2 Move number: 27
# Qwen CN move: f8e8 Move number: 28
# Qwen US move: Bd3 Move number: 29
# Invalid move by Qwen black. Move: Nbd2
# New Move: Qd5
# Qwen CN move: Qd5 Move number: 30
# Qwen US move: e4d5 Move number: 31
# Qwen CN move: Nh5 Move number: 32
# Qwen US move: Bh6 Move number: 33
# Qwen CN move: h5f6 Move number: 34
# Invalid move by Qwen white. Move: Bh6
# New Move: c4
# Qwen US move: c4 Move number: 35
# Qwen CN move: e5e4 Move number: 36
# Qwen US move: d3f1 Move number: 37
# Qwen CN move: Nxd5 Move number: 38
# Invalid move by Qwen white. Move: Bxd5
# New Move: Bd3
# Qwen US move: Bd3 Move number: 39
# Qwen CN move: c5d3 Move number: 40
# Qwen US move: Ke2 Move number: 41
# Qwen CN move: d5f4 Move number: 42
# Qwen US move: Kd2 Move number: 43
# Qwen CN move: g7h6 Move number: 44
# Qwen US move: Qg4+ Move number: 45
# Qwen CN move: Bxg4 Move number: 46
# Qwen US move: Re1 Move number: 47
# Qwen CN move: e7g5 Move number: 48
# Qwen US move: Rxe4 Move number: 49
# Qwen CN move: e8e4 Move number: 50
# Qwen US move: c5 Move number: 51
# Qwen CN move: e4e2 Move number: 52
# Qwen US move: Kd1 Move number: 53
# Qwen CN move: e2f2 Move number: 54
# Game 7 result: 0-1
#
#
# Starting game 8...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nc3 Move number: 5
# Qwen CN move: g7g6 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: c5d4 Move number: 8
# Qwen US move: Nxd4 Move number: 9
# Qwen CN move: Nxd4 Move number: 10
# Qwen US move: Nd5 Move number: 11
# Qwen CN move: d4e6 Move number: 12
# Qwen US move: Nxe7 Move number: 13
# Qwen CN move: g8e7 Move number: 14
# Qwen US move: Qd2 Move number: 15
# Qwen CN move: d8c7 Move number: 16
# Qwen US move: Qxd7+ Move number: 17
# Qwen CN move: c8d7 Move number: 18
# Qwen US move: c1d2 Move number: 19
# Invalid move by Qwen black. Move: Nxe5
# New Move: b6
# Qwen CN move: b6 Move number: 20
# Qwen US move: Bh6 Move number: 21
# Qwen CN move: f8h6 Move number: 22
# Qwen US move: Rg1 Move number: 23
# Qwen CN move: d7c6 Move number: 24
# Qwen US move: Rd1 Move number: 25
# Qwen CN move: a8d8 Move number: 26
# Qwen US move: Rd2 Move number: 27
# Qwen CN move: Rd3 Move number: 28
# Qwen US move: Rxd3 Move number: 29
# Qwen CN move: h6g7 Move number: 30
# Qwen US move: Rd8+ Move number: 31
# Qwen CN move: c7d8 Move number: 32
# Qwen US move: Rh1 Move number: 33
# Qwen CN move: b6b5 Move number: 34
# Qwen US move: Bc4 Move number: 35
# Qwen CN move: g7b2 Move number: 36
# Qwen US move: c4d3 Move number: 37
# Qwen CN move: b2c3 Move number: 38
# Qwen US move: Ke2 Move number: 39
# Qwen CN move: e6f4 Move number: 40
# Qwen US move: Kf3 Move number: 41
# Qwen CN move: f4d3 Move number: 42
# Qwen US move: f3e2 Move number: 43
# Qwen CN move: d3f4 Move number: 44
# Qwen US move: Ke3 Move number: 45
# Qwen CN move: Nh5 Move number: 46
# Qwen US move: Rg1 Move number: 47
# Qwen CN move: d8d4 Move number: 48
# Qwen US move: Ke2 Move number: 49
# Qwen CN move: h5f4 Move number: 50
# Qwen US move: Kf1 Move number: 51
# Qwen CN move: d4d1 Move number: 52
# Game 8 result: 0-1
#
#
# Starting game 9...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Invalid move by Qwen white. Move: Nxe5
# New Move: f3
# Qwen US move: f3 Move number: 9
# Qwen CN move: c7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Invalid move by Qwen black. Move: Nf3
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 12
# Qwen US move: b2a3 Move number: 13
# Qwen CN move: Nf4 Move number: 14
# Invalid move by Qwen white. Move: Nxe5
# New Move: Rb1
# Qwen US move: Rb1 Move number: 15
# Qwen CN move: f4g6 Move number: 16
# Qwen US move: h2h4 Move number: 17
# Qwen CN move: N8e7 Move number: 18
# Qwen US move: Nd5 Move number: 19
# Qwen CN move: c6d5 Move number: 20
# Invalid move by Qwen white. Move: Rb1
# New Move: Be2
# Qwen US move: Be2 Move number: 21
# Qwen CN move: d8c7 Move number: 22
# Qwen US move: Qd3 Move number: 23
# Qwen CN move: g6f4 Move number: 24
# Qwen US move: Qe3 Move number: 25
# Qwen CN move: f4g2 Move number: 26
# Qwen US move: Kf2 Move number: 27
# Qwen CN move: Nxe3 Move number: 28
# Qwen US move: Bd3 Move number: 29
# Qwen CN move: d5e4 Move number: 30
# Qwen US move: Bxe4 Move number: 31
# Qwen CN move: d7d5 Move number: 32
# Qwen US move: Bxh7 Move number: 33
# Qwen CN move: h8h7 Move number: 34
# Qwen US move: Re1 Move number: 35
# Qwen CN move: c7c2 Move number: 36
# Qwen US move: e1e2 Move number: 37
# Qwen CN move: e3d1 Move number: 38
# Qwen US move: Kg3 Move number: 39
# Qwen CN move: c2e2 Move number: 40
# Qwen US move: Bh6 Move number: 41
# Qwen CN move: e2f2 Move number: 42
# Qwen US move: g3f4 Move number: 43
# Qwen CN move: e7g6 Move number: 44
# Qwen US move: Kg5 Move number: 45
# Qwen CN move: Bf5 Move number: 46
# Qwen US move: Bxg7 Move number: 47
# Qwen CN move: h7h5 Move number: 48
# Qwen US move: Kf6 Move number: 49
# Qwen CN move: f2d4 Move number: 50
# Game 9 result: 0-1
#
#
# Starting game 10...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1c4 Move number: 5
# Qwen CN move: Nf6 Move number: 6
# Qwen US move: Bxf7+ Move number: 7
# Qwen CN move: e8f7 Move number: 8
# Qwen US move: Nxe5+ Move number: 9
# Qwen CN move: c6e5 Move number: 10
# Qwen US move: Nc3 Move number: 11
# Qwen CN move: e5g6 Move number: 12
# Invalid move by Qwen white. Move: Nxe5
# New Move: b3
# Qwen US move: b3 Move number: 13
# Qwen CN move: d7d5 Move number: 14
# Qwen US move: c1b2 Move number: 15
# Qwen CN move: Be6 Move number: 16
# Qwen US move: Nxd5 Move number: 17
# Qwen CN move: e6d5 Move number: 18
# Qwen US move: Bxf6 Move number: 19
# Qwen CN move: d8f6 Move number: 20
# Qwen US move: Qf3 Move number: 21
# Qwen CN move: f6f3 Move number: 22
# Qwen US move: Rg1 Move number: 23
# Qwen CN move: Rg8 Move number: 24
# Qwen US move: Rd1 Move number: 25
# Qwen CN move: f3e4 Move number: 26
# Invalid move by Qwen white. Move: Ke2
# New Move: Kf1
# Qwen US move: Kf1 Move number: 27
# Qwen CN move: a8e8 Move number: 28
# Qwen US move: Rh1 Move number: 29
# Qwen CN move: e4g2 Move number: 30
# Game 10 result: 0-1
#
#
# Starting game 11...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Invalid move by Qwen white. Move: Nf3
# New Move: b3
# Qwen US move: b3 Move number: 5
# Qwen CN move: e7e5 Move number: 6
# Qwen US move: f1c4 Move number: 7
# Qwen CN move: Nge7 Move number: 8
# Qwen US move: Bxf7+ Move number: 9
# Qwen CN move: e8f7 Move number: 10
# Qwen US move: Ng5+ Move number: 11
# Qwen CN move: f7g8 Move number: 12
# Qwen US move: Nf7 Move number: 13
# Qwen CN move: g8f7 Move number: 14
# Qwen US move: Qe2 Move number: 15
# Invalid move by Qwen black. Move: Qe5
# New Move: g6
# Qwen CN move: g6 Move number: 16
# Qwen US move: Qd1 Move number: 17
# Qwen CN move: d7d5 Move number: 18
# Invalid move by Qwen white. Move: Qe4
# New Move: a3
# Qwen US move: a3 Move number: 19
# Qwen CN move: f8g7 Move number: 20
# Qwen US move: b1c3 Move number: 21
# Qwen CN move: Qd6 Move number: 22
# Qwen US move: Qf3+ Move number: 23
# Qwen CN move: d6f6 Move number: 24
# Qwen US move: Qxf6+ Move number: 25
# Qwen CN move: g7f6 Move number: 26
# Qwen US move: Nxd5 Move number: 27
# Qwen CN move: e7d5 Move number: 28
# Qwen US move: Rg1 Move number: 29
# Qwen CN move: Rg8 Move number: 30
# Qwen US move: Rb1 Move number: 31
# Qwen CN move: d5f4 Move number: 32
# Qwen US move: Rb2 Move number: 33
# Qwen CN move: c6d4 Move number: 34
# Qwen US move: e1d1 Move number: 35
# Qwen CN move: g6g5 Move number: 36
# Qwen US move: Re1 Move number: 37
# Qwen CN move: f4g2 Move number: 38
# Qwen US move: Re2 Move number: 39
# Qwen CN move: c8g4 Move number: 40
# Invalid move by Qwen white. Move: Rb2
# New Move: c4
# Qwen US move: c4 Move number: 41
# Qwen CN move: g4e2 Move number: 42
# Game 11 result: 0-1
#
#
# Starting game 12...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: Nc3 Move number: 5
# Qwen CN move: b8c6 Move number: 6
# Qwen US move: Nxe5 Move number: 7
# Qwen CN move: c6e5 Move number: 8
# Qwen US move: Nd5 Move number: 9
# Qwen CN move: Nxe4 Move number: 10
# Qwen US move: Nxc7+ Move number: 11
# Qwen CN move: d8c7 Move number: 12
# Qwen US move: Bb5 Move number: 13
# Qwen CN move: f8e7 Move number: 14
# Qwen US move: e1g1 Move number: 15
# Qwen CN move: e8g8 Move number: 16
# Qwen US move: Bxd7 Move number: 17
# Qwen CN move: c8d7 Move number: 18
# Qwen US move: Qe2 Move number: 19
# Qwen CN move: e5g4 Move number: 20
# Qwen US move: Qxe4 Move number: 21
# Qwen CN move: c7h2 Move number: 22
# Game 12 result: 0-1
#
#
# Starting game 13...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Invalid move by Qwen white. Move: Nxe5
# New Move: f3
# Qwen US move: f3 Move number: 9
# Qwen CN move: c7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Invalid move by Qwen black. Move: dxe5
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 12
# Qwen US move: b2a3 Move number: 13
# Qwen CN move: Nf4 Move number: 14
# Invalid move by Qwen white. Move: Nbd2
# New Move: Rb1
# Qwen US move: Rb1 Move number: 15
# Qwen CN move: f4g6 Move number: 16
# Qwen US move: h2h4 Move number: 17
# Qwen CN move: N8e7 Move number: 18
# Invalid move by Qwen white. Move: Rb1
# New Move: Ba6
# Qwen US move: Ba6 Move number: 19
# Qwen CN move: b7a6 Move number: 20
# Qwen US move: Nd5 Move number: 21
# Qwen CN move: c6d5 Move number: 22
# Qwen US move: Qe2 Move number: 23
# Qwen CN move: h7h5 Move number: 24
# Qwen US move: Qd3 Move number: 25
# Qwen CN move: Nf4 Move number: 26
# Qwen US move: Qe2 Move number: 27
# Qwen CN move: f4e2 Move number: 28
# Qwen US move: Rh3 Move number: 29
# Qwen CN move: a6a5 Move number: 30
# Qwen US move: Rg3 Move number: 31
# Qwen CN move: e2g3 Move number: 32
# Qwen US move: exd5 Move number: 33
# Qwen CN move: g3f5 Move number: 34
# Qwen US move: d5d6 Move number: 35
# Qwen CN move: f5d6 Move number: 36
# Qwen US move: Bf4 Move number: 37
# Qwen CN move: d6f5 Move number: 38
# Qwen US move: Bd2 Move number: 39
# Qwen CN move: d7d6 Move number: 40
# Qwen US move: e1f1 Move number: 41
# Qwen CN move: c8a6 Move number: 42
# Qwen US move: Ke1 Move number: 43
# Qwen CN move: Nxd4 Move number: 44
# Qwen US move: Bh6 Move number: 45
# Qwen CN move: h8h6 Move number: 46
# Qwen US move: Rd1 Move number: 47
# Qwen CN move: d4c2 Move number: 48
# Qwen US move: Kd2 Move number: 49
# Qwen CN move: c2e3 Move number: 50
# Qwen US move: Rc1 Move number: 51
# Qwen CN move: e3f1 Move number: 52
# Qwen US move: d2d1 Move number: 53
# Qwen CN move: Be2+ Move number: 54
# Qwen US move: Kc2 Move number: 55
# Qwen CN move: a8c8 Move number: 56
# Qwen US move: Kb3 Move number: 57
# Qwen CN move: d8b6 Move number: 58
# Invalid move by Qwen white. Move: Ke2
# New Move: Ka4
# Qwen US move: Ka4 Move number: 59
# Qwen CN move: b6b5 Move number: 60
# Game 13 result: 0-1
#
#
# Starting game 14...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: Nxe5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Invalid move by Qwen white. Move: Nxe5
# New Move: f3
# Qwen US move: f3 Move number: 9
# Qwen CN move: c7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: Nf6 Move number: 12
# Invalid move by Qwen white. Move: Nbd2
# New Move: Bb5
# Qwen US move: Bb5 Move number: 13
# Qwen CN move: c6b5 Move number: 14
# Invalid move by Qwen white. Move: Nxe5
# New Move: Kf2
# Qwen US move: Kf2 Move number: 15
# Qwen CN move: b5b4 Move number: 16
# Invalid move by Qwen white. Move: Nbd2
# New Move: Ke2
# Qwen US move: Ke2 Move number: 17
# Qwen CN move: b4c3 Move number: 18
# Qwen US move: Qd2 Move number: 19
# Qwen CN move: c3d2 Move number: 20
# Qwen US move: Re1 Move number: 21
# Qwen CN move: d2c1n Move number: 22
# Qwen US move: Ke3 Move number: 23
# Qwen CN move: Be7 Move number: 24
# Invalid move by Qwen white. Move: Rxc1
# New Move: c4
# Qwen US move: c4 Move number: 25
# Qwen CN move: d8b6 Move number: 26
# Qwen US move: a1c1 Move number: 27
# Qwen CN move: Rg8 Move number: 28
# Invalid move by Qwen white. Move: Ke1
# New Move: a3
# Qwen US move: a3 Move number: 29
# Qwen CN move: b6b2 Move number: 30
# Qwen US move: c4c5 Move number: 31
# Qwen CN move: Qxc1+ Move number: 32
# Qwen US move: Kf2 Move number: 33
# Qwen CN move: c1d2 Move number: 34
# Qwen US move: Kg3 Move number: 35
# Qwen CN move: d2e1 Move number: 36
# Qwen US move: Kh3 Move number: 37
# Qwen CN move: g6f4 Move number: 38
# Game 14 result: 0-1
#
#
# Starting game 15...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Ng5 Move number: 5
# Qwen CN move: d8g5 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: g5g6 Move number: 8
# Qwen US move: Be2 Move number: 9
# Qwen CN move: c6d4 Move number: 10
# Qwen US move: Bd3 Move number: 11
# Qwen CN move: g6g2 Move number: 12
# Qwen US move: Be2 Move number: 13
# Qwen CN move: g2h1 Move number: 14
# Qwen US move: Kd2 Move number: 15
# Qwen CN move: h1e4 Move number: 16
# Qwen US move: Bd3 Move number: 17
# Qwen CN move: d4f3 Move number: 18
# Qwen US move: Kc3 Move number: 19
# Qwen CN move: e4b4 Move number: 20
# Game 15 result: 0-1
#
#
# Starting game 16...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Ng5 Move number: 5
# Qwen CN move: d8g5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: g5g6 Move number: 8
# Invalid move by Qwen white. Move: Nbd2
# New Move: d3
# Qwen US move: d3 Move number: 9
# Qwen CN move: f8b4 Move number: 10
# Qwen US move: f2f4 Move number: 11
# Qwen CN move: Nge7 Move number: 12
# Qwen US move: d4 Move number: 13
# Qwen CN move: g6e4 Move number: 14
# Qwen US move: Be3 Move number: 15
# Qwen CN move: e4e3 Move number: 16
# Qwen US move: Be2 Move number: 17
# Qwen CN move: e3d4 Move number: 18
# Qwen US move: Bd3 Move number: 19
# Qwen CN move: Nf5 Move number: 20
# Qwen US move: Bxf5 Move number: 21
# Qwen CN move: b4c3 Move number: 22
# Qwen US move: Qd2 Move number: 23
# Qwen CN move: d4d2 Move number: 24
# Qwen US move: e1f1 Move number: 25
# Qwen CN move: d2f4 Move number: 26
# Qwen US move: Ke2 Move number: 27
# Qwen CN move: c6d4 Move number: 28
# Qwen US move: Kd3 Move number: 29
# Qwen CN move: f4f5 Move number: 30
# Qwen US move: Kc4 Move number: 31
# Qwen CN move: f5e6 Move number: 32
# Qwen US move: Kd3 Move number: 33
# Qwen CN move: e6f5 Move number: 34
# Qwen US move: Kc4 Move number: 35
# Qwen CN move: d7d5 Move number: 36
# Qwen US move: Kxc3 Move number: 37
# Qwen CN move: f5c2 Move number: 38
# Qwen US move: Kb4 Move number: 39
# Qwen CN move: a7a5 Move number: 40
# Qwen US move: Ka3 Move number: 41
# Qwen CN move: d4b5 Move number: 42
# Game 16 result: 0-1
#
#
# Starting game 17...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Invalid move by Qwen white. Move: Nxe5
# New Move: f3
# Qwen US move: f3 Move number: 9
# Qwen CN move: c7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Invalid move by Qwen black. Move: dxe5
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 12
# Qwen US move: b2a3 Move number: 13
# Qwen CN move: Nf6 Move number: 14
# Qwen US move: Nd5 Move number: 15
# Qwen CN move: c6d5 Move number: 16
# Qwen US move: Be3 Move number: 17
# Qwen CN move: d5e4 Move number: 18
# Qwen US move: Bd2 Move number: 19
# Qwen CN move: e8g8 Move number: 20
# Qwen US move: Bh6 Move number: 21
# Invalid move by Qwen black. Move: Bh5
# New Move: b6
# Qwen CN move: b6 Move number: 22
# Invalid move by Qwen white. Move: Bxe4
# New Move: Ba6
# Qwen US move: Ba6 Move number: 23
# Qwen CN move: c8a6 Move number: 24
# Qwen US move: Bxg7 Move number: 25
# Qwen CN move: g8g7 Move number: 26
# Qwen US move: Qd3 Move number: 27
# Qwen CN move: e4d3 Move number: 28
# Qwen US move: Rg1 Move number: 29
# Qwen CN move: Re8+ Move number: 30
# Qwen US move: Kf2 Move number: 31
# Qwen CN move: f6g4 Move number: 32
# Qwen US move: Kg3 Move number: 33
# Qwen CN move: d8h4 Move number: 34
# Game 17 result: 0-1
#
#
# Starting game 18...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1c4 Move number: 5
# Qwen CN move: f8c5 Move number: 6
# Qwen US move: Bxf7+ Move number: 7
# Qwen CN move: e8f7 Move number: 8
# Qwen US move: Ng5+ Move number: 9
# Qwen CN move: d8g5 Move number: 10
# Qwen US move: e1g1 Move number: 11
# Qwen CN move: g5g6 Move number: 12
# Qwen US move: Qe2 Move number: 13
# Qwen CN move: Qh5 Move number: 14
# Qwen US move: Qe1 Move number: 15
# Qwen CN move: g8f6 Move number: 16
# Qwen US move: Qe3 Move number: 17
# Qwen CN move: c5e3 Move number: 18
# Qwen US move: d4 Move number: 19
# Qwen CN move: e3d4 Move number: 20
# Invalid move by Qwen white. Move: Nh3
# New Move: a4
# Qwen US move: a4 Move number: 21
# Qwen CN move: d7d6 Move number: 22
# Qwen US move: a1a3 Move number: 23
# Qwen CN move: Rd8 Move number: 24
# Qwen US move: Rb3 Move number: 25
# Qwen CN move: f7g8 Move number: 26
# Qwen US move: Rxb7 Move number: 27
# Qwen CN move: c8b7 Move number: 28
# Qwen US move: Bd2 Move number: 29
# Qwen CN move: f6e4 Move number: 30
# Qwen US move: Bh6 Move number: 31
# Invalid move by Qwen black. Move: Bh6xg7+
# New Move: Bxf2+
# Qwen CN move: Bxf2+ Move number: 32
# Qwen US move: Rxf2 Move number: 33
# Qwen CN move: h5d1 Move number: 34
# Qwen US move: Rf1 Move number: 35
# Qwen CN move: d1d4 Move number: 36
# Qwen US move: Kh1 Move number: 37
# Qwen CN move: e4f2 Move number: 38
# Qwen US move: Rxf2 Move number: 39
# Invalid move by Qwen black. Move: Rxf2
# New Move: Rab8
# Qwen CN move: Rab8 Move number: 40
# Qwen US move: f2f1 Move number: 41
# Qwen CN move: Qd2 Move number: 42
# Qwen US move: Rf8+ Move number: 43
# Qwen CN move: d8f8 Move number: 44
# Qwen US move: Bxg7 Move number: 45
# Qwen CN move: d2c1 Move number: 46
# Game 18 result: 0-1
#
#
# Starting game 19...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Nc3 Move number: 5
# Qwen CN move: e7e5 Move number: 6
# Qwen US move: Nxe5 Move number: 7
# Qwen CN move: c6e5 Move number: 8
# Qwen US move: d2d4 Move number: 9
# Qwen CN move: c5d4 Move number: 10
# Invalid move by Qwen white. Move: Nxe5
# New Move: Bb5
# Qwen US move: Bb5 Move number: 11
# Qwen CN move: d4c3 Move number: 12
# Qwen US move: Bxd7+ Move number: 13
# Qwen CN move: c8d7 Move number: 14
# Qwen US move: Qd2 Move number: 15
# Qwen CN move: c3d2 Move number: 16
# Qwen US move: Ke2 Move number: 17
# Qwen CN move: Nf6 Move number: 18
# Qwen US move: Re1 Move number: 19
# Qwen CN move: d7b5 Move number: 20
# Qwen US move: Ke3 Move number: 21
# Qwen CN move: d2e1q Move number: 22
# Qwen US move: Kf4 Move number: 23
# Qwen CN move: e1e4 Move number: 24
# Qwen US move: Kg5 Move number: 25
# Qwen CN move: h7h6 Move number: 26
# Game 19 result: 0-1
#
#
# Starting game 20...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nh4 Move number: 5
# Qwen CN move: e7e6 Move number: 6
# Qwen US move: h4f3 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: Nc3 Move number: 9
# Qwen CN move: Nxe4 Move number: 10
# Qwen US move: Nxe4 Move number: 11
# Qwen CN move: d7d5 Move number: 12
# Qwen US move: Nf6+ Move number: 13
# Qwen CN move: d8f6 Move number: 14
# Invalid move by Qwen white. Move: Nxe6
# New Move: h4
# Qwen US move: h4 Move number: 15
# Qwen CN move: h7h6 Move number: 16
# Qwen US move: d2d3 Move number: 17
# Qwen CN move: Be7 Move number: 18
# Qwen US move: Ng5 Move number: 19
# Qwen CN move: h6g5 Move number: 20
# Qwen US move: Qe2 Move number: 21
# Qwen CN move: g5h4 Move number: 22
# Qwen US move: Qxe6 Move number: 23
# Qwen CN move: f6e6 Move number: 24
# Qwen US move: Kd2 Move number: 25
# Qwen CN move: Rg8 Move number: 26
# Qwen US move: Kc3 Move number: 27
# Qwen CN move: e6e1 Move number: 28
# Qwen US move: Bd2 Move number: 29
# Qwen CN move: d5d4 Move number: 30
# Qwen US move: c3b3 Move number: 31
# Qwen CN move: c8e6 Move number: 32
# Qwen US move: Ka4 Move number: 33
# Qwen CN move: e1a1 Move number: 34
# Qwen US move: Bf4 Move number: 35
# Qwen CN move: a1a2 Move number: 36
# Qwen US move: Kb5 Move number: 37
# Qwen CN move: a2a5 Move number: 38
# Game 20 result: 0-1
#
#
# Starting game 21...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Invalid move by Qwen white. Move: Nbd2
# New Move: f3
# Qwen US move: f3 Move number: 9
# Qwen CN move: c7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Invalid move by Qwen black. Move: dxe5
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 12
# Qwen US move: b2a3 Move number: 13
# Qwen CN move: Nf6 Move number: 14
# Invalid move by Qwen white. Move: Nbd2
# New Move: Bb5
# Qwen US move: Bb5 Move number: 15
# Qwen CN move: c6b5 Move number: 16
# Invalid move by Qwen white. Move: Nbd2
# New Move: Rb1
# Qwen US move: Rb1 Move number: 17
# Qwen CN move: e8g8 Move number: 18
# Qwen US move: h2h4 Move number: 19
# Qwen CN move: h5 Move number: 20
# Qwen US move: Nd5 Move number: 21
# Qwen CN move: f6d5 Move number: 22
# Qwen US move: Rb4 Move number: 23
# Qwen CN move: d5b4 Move number: 24
# Invalid move by Qwen white. Move: Rb1
# New Move: d5
# Qwen US move: d5 Move number: 25
# Qwen CN move: b4c2 Move number: 26
# Qwen US move: d1c2 Move number: 27
# Qwen CN move: Qc7 Move number: 28
# Qwen US move: Qxc7 Move number: 29
# Qwen CN move: b7b6 Move number: 30
# Qwen US move: Qxc8 Move number: 31
# Qwen CN move: a8c8 Move number: 32
# Qwen US move: Rg1 Move number: 33
# Qwen CN move: c8c1 Move number: 34
# Qwen US move: Kf2 Move number: 35
# Qwen CN move: Re1 Move number: 36
# Qwen US move: Kg3 Move number: 37
# Qwen CN move: e1g1 Move number: 38
# Qwen US move: Kh2 Move number: 39
# Qwen CN move: g1f1 Move number: 40
# Qwen US move: a3a4 Move number: 41
# Qwen CN move: g8h7 Move number: 42
# Qwen US move: g3 Move number: 43
# Qwen CN move: f1f2 Move number: 44
# Qwen US move: Kh1 Move number: 45
# Qwen CN move: f2a2 Move number: 46
# Qwen US move: e5 Move number: 47
# Qwen CN move: f8c8 Move number: 48
# Invalid move by Qwen white. Move: e5
# New Move: g4
# Qwen US move: g4 Move number: 49
# Qwen CN move: c8c1 Move number: 50
# Game 21 result: 0-1
#
#
# Starting game 22...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Invalid move by Qwen white. Move: Nxe5
# New Move: f3
# Qwen US move: f3 Move number: 9
# Qwen CN move: c7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: Nf6 Move number: 12
# Invalid move by Qwen white. Move: Nbd2
# New Move: Bb5
# Qwen US move: Bb5 Move number: 13
# Qwen CN move: c6b5 Move number: 14
# Qwen US move: Nxd5 Move number: 15
# Qwen CN move: f6d5 Move number: 16
# Invalid move by Qwen white. Move: Nxb7
# New Move: g3
# Qwen US move: g3 Move number: 17
# Qwen CN move: d5c7 Move number: 18
# Qwen US move: f3f4 Move number: 19
# Qwen CN move: Nxe5 Move number: 20
# Qwen US move: Qe2 Move number: 21
# Qwen CN move: e5c4 Move number: 22
# Qwen US move: Qg4 Move number: 23
# Qwen CN move: h7h5 Move number: 24
# Qwen US move: Qxg7 Move number: 25
# Qwen CN move: f8g7 Move number: 26
# Qwen US move: Rg1 Move number: 27
# Qwen CN move: Rg8 Move number: 28
# Qwen US move: Rg2 Move number: 29
# Qwen CN move: d7d6 Move number: 30
# Qwen US move: Rg1 Move number: 31
# Qwen CN move: d8e7 Move number: 32
# Qwen US move: e4e5 Move number: 33
# Qwen CN move: d6e5 Move number: 34
# Qwen US move: Rg2 Move number: 35
# Qwen CN move: e5d4 Move number: 36
# Qwen US move: Kf1 Move number: 37
# Qwen CN move: c8h3 Move number: 38
# Invalid move by Qwen white. Move: Bg5
# New Move: b4
# Qwen US move: b4 Move number: 39
# Qwen CN move: e8d7 Move number: 40
# Qwen US move: c1d2 Move number: 41
# Qwen CN move: Bg4 Move number: 42
# Qwen US move: Rf2 Move number: 43
# Qwen CN move: g4h3 Move number: 44
# Qwen US move: Rg2 Move number: 45
# Qwen CN move: c4d2 Move number: 46
# Qwen US move: Kf2 Move number: 47
# Qwen CN move: e7e3 Move number: 48
# Game 22 result: 0-1
#
#
# Starting game 23...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: d7d6 Move number: 6
# Qwen US move: e5f3 Move number: 7
# Qwen CN move: f6e4 Move number: 8
# Qwen US move: Nc3 Move number: 9
# Qwen CN move: e4c3 Move number: 10
# Invalid move by Qwen white. Move: Nxe4
# New Move: h4
# Qwen US move: h4 Move number: 11
# Qwen CN move: d8e7 Move number: 12
# Qwen US move: f1e2 Move number: 13
# Qwen CN move: Bf5 Move number: 14
# Qwen US move: Ng5 Move number: 15
# Qwen CN move: c3d1 Move number: 16
# Qwen US move: Nh3 Move number: 17
# Qwen CN move: b8c6 Move number: 18
# Qwen US move: Ng5 Move number: 19
# Qwen CN move: c6d4 Move number: 20
# Qwen US move: Nh3 Move number: 21
# Qwen CN move: Rg8 Move number: 22
# Qwen US move: Ng5 Move number: 23
# Qwen CN move: e7e2 Move number: 24
# Game 23 result: 0-1
#
#
# Starting game 24...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: d7d6 Move number: 4
# Qwen US move: Nh4 Move number: 5
# Qwen CN move: b8c6 Move number: 6
# Invalid move by Qwen white. Move: Nh4
# New Move: d3
# Qwen US move: d3 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: b1c3 Move number: 9
# Invalid move by Qwen black. Move: Nh4
# New Move: Be6
# Qwen CN move: Be6 Move number: 10
# Qwen US move: g2g3 Move number: 11
# Qwen CN move: Nxe4 Move number: 12
# Qwen US move: Nf3 Move number: 13
# Qwen CN move: e4c3 Move number: 14
# Qwen US move: Ng5 Move number: 15
# Qwen CN move: c3d1 Move number: 16
# Qwen US move: Nh3 Move number: 17
# Qwen CN move: e6d5 Move number: 18
# Qwen US move: Ng5 Move number: 19
# Invalid move by Qwen black. Move: Nh5
# New Move: Qa5+
# Qwen CN move: Qa5+ Move number: 20
# Qwen US move: c1d2 Move number: 21
# Invalid move by Qwen black. Move: Bxc6
# New Move: a6
# Qwen CN move: a6 Move number: 22
# Qwen US move: Nxe4 Move number: 23
# Qwen CN move: a5d2 Move number: 24
# Qwen US move: Kxd2 Move number: 25
# Qwen CN move: d5e4 Move number: 26
# Qwen US move: Rg1 Move number: 27
# Qwen CN move: e4d5 Move number: 28
# Qwen US move: Rg2 Move number: 29
# Qwen CN move: Nxe5 Move number: 30
# Qwen US move: Rxd1 Move number: 31
# Qwen CN move: e5f3 Move number: 32
# Qwen US move: Ke2 Move number: 33
# Qwen CN move: f3d4 Move number: 34
# Qwen US move: Ke1 Move number: 35
# Qwen CN move: d4c2 Move number: 36
# Qwen US move: Ke2 Move number: 37
# Qwen CN move: c2d4 Move number: 38
# Qwen US move: e2d2 Move number: 39
# Qwen CN move: e7e6 Move number: 40
# Qwen US move: Rg1 Move number: 41
# Qwen CN move: d4f3 Move number: 42
# Qwen US move: Ke3 Move number: 43
# Qwen CN move: f3g1 Move number: 44
# Qwen US move: f1g2 Move number: 45
# Qwen CN move: d5g2 Move number: 46
# Qwen US move: Rd2 Move number: 47
# Qwen CN move: Rg8 Move number: 48
# Qwen US move: f4 Move number: 49
# Qwen CN move: g2c6 Move number: 50
# Qwen US move: f5 Move number: 51
# Qwen CN move: g1f3 Move number: 52
# Invalid move by Qwen white. Move: Ke1
# New Move: Rg2
# Qwen US move: Rg2 Move number: 53
# Qwen CN move: f3d4 Move number: 54
# Qwen US move: fxe6 Move number: 55
# Qwen CN move: f7e6 Move number: 56
# Invalid move by Qwen white. Move: Ke1
# New Move: b3
# Qwen US move: b3 Move number: 57
# Qwen CN move: c6g2 Move number: 58
# Qwen US move: b3b4 Move number: 59
# Qwen CN move: Nxb5 Move number: 60
# Qwen US move: d4 Move number: 61
# Qwen CN move: c5b4 Move number: 62
# Qwen US move: d5 Move number: 63
# Qwen CN move: g2d5 Move number: 64
# Invalid move by Qwen white. Move: Ke1
# New Move: Kd3
# Qwen US move: Kd3 Move number: 65
# Qwen CN move: a8c8 Move number: 66
# Qwen US move: Ke3 Move number: 67
# Qwen CN move: f8e7 Move number: 68
# Qwen US move: Kf4 Move number: 69
# Qwen CN move: g8f8 Move number: 70
# Qwen US move: Kg4 Move number: 71
# Qwen CN move: Rf2 Move number: 72
# Qwen US move: Kh5 Move number: 73
# Qwen CN move: d5f3 Move number: 74
# Qwen US move: g4 Move number: 75
# Qwen CN move: f2h2 Move number: 76
# Game 24 result: 0-1
#
#
# Starting game 25...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: e5 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: g1f3 Move number: 5
# Qwen CN move: d8c7 Move number: 6
# Invalid move by Qwen white. Move: Nbd4
# New Move: a3
# Qwen US move: a3 Move number: 7
# Qwen CN move: c6e5 Move number: 8
# Qwen US move: f3e5 Move number: 9
# Qwen CN move: Nf6 Move number: 10
# Qwen US move: Nxd7 Move number: 11
# Qwen CN move: c8d7 Move number: 12
# Qwen US move: Nc3 Move number: 13
# Qwen CN move: d7c6 Move number: 14
# Qwen US move: Nd5 Move number: 15
# Qwen CN move: f6d5 Move number: 16
# Qwen US move: Be2 Move number: 17
# Invalid move by Qwen black. Move: Nf3
# New Move: Qc8
# Qwen CN move: Qc8 Move number: 18
# Qwen US move: d2d4 Move number: 19
# Invalid move by Qwen black. Move: d5
# New Move: Qe6
# Qwen CN move: Qe6 Move number: 20
# Qwen US move: c2c4 Move number: 21
# Invalid move by Qwen black. Move: Nxe5
# New Move: a5
# Qwen CN move: a5 Move number: 22
# Qwen US move: Rg1 Move number: 23
# Qwen CN move: c5d4 Move number: 24
# Qwen US move: Qd2 Move number: 25
# Qwen CN move: d5f6 Move number: 26
# Qwen US move: Qh6 Move number: 27
# Qwen CN move: g7h6 Move number: 28
# Qwen US move: Bf4 Move number: 29
# Qwen CN move: Nh5 Move number: 30
# Qwen US move: Bh6 Move number: 31
# Qwen CN move: f8h6 Move number: 32
# Qwen US move: Rd1 Move number: 33
# Qwen CN move: h5f4 Move number: 34
# Qwen US move: Rd2 Move number: 35
# Qwen CN move: d4d3 Move number: 36
# Qwen US move: Rxd3 Move number: 37
# Qwen CN move: e6e2 Move number: 38
# Game 25 result: 0-1
#
#
# Starting game 26...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: d7d6 Move number: 4
# Qwen US move: Nh4 Move number: 5
# Qwen CN move: g8f6 Move number: 6
# Qwen US move: f1b5 Move number: 7
# Qwen CN move: c8d7 Move number: 8
# Qwen US move: Bxd7+ Move number: 9
# Invalid move by Qwen black. Move: Bxd7+
# New Move: Kxd7
# Qwen CN move: Kxd7 Move number: 10
# Qwen US move: e1g1 Move number: 11
# Qwen CN move: Nh5 Move number: 12
# Qwen US move: Nf3 Move number: 13
# Qwen CN move: d7e8 Move number: 14
# Qwen US move: Nh4 Move number: 15
# Qwen CN move: h5f6 Move number: 16
# Invalid move by Qwen white. Move: Nh4
# New Move: g4
# Qwen US move: g4 Move number: 17
# Qwen CN move: e7e6 Move number: 18
# Qwen US move: f2f4 Move number: 19
# Qwen CN move: g5 Move number: 20
# Qwen US move: Ng6 Move number: 21
# Qwen CN move: h7g6 Move number: 22
# Qwen US move: Qe2 Move number: 23
# Qwen CN move: g5f4 Move number: 24
# Qwen US move: Qf3 Move number: 25
# Qwen CN move: b8d7 Move number: 26
# Qwen US move: Qxf4 Move number: 27
# Qwen CN move: Rg8 Move number: 28
# Qwen US move: Qh6 Move number: 29
# Qwen CN move: f8h6 Move number: 30
# Qwen US move: Rxf6 Move number: 31
# Qwen CN move: d8f6 Move number: 32
# Qwen US move: b1c3 Move number: 33
# Qwen CN move: f6h4 Move number: 34
# Qwen US move: Nd5 Move number: 35
# Qwen CN move: h4e1 Move number: 36
# Qwen US move: Kg2 Move number: 37
# Qwen CN move: e1e4 Move number: 38
# Qwen US move: Kh3 Move number: 39
# Qwen CN move: e4f3 Move number: 40
# Qwen US move: Kh4 Move number: 41
# Qwen CN move: g6g5 Move number: 42
# Qwen US move: Kh5 Move number: 43
# Qwen CN move: f3h3 Move number: 44
# Game 26 result: 0-1
#
#
# Starting game 27...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Invalid move by Qwen white. Move: Nxe5
# New Move: f3
# Qwen US move: f3 Move number: 9
# Qwen CN move: c7c6 Move number: 10
# Qwen US move: f3f4 Move number: 11
# Qwen CN move: Nxe5 Move number: 12
# Invalid move by Qwen white. Move: Nbd2
# New Move: h3
# Qwen US move: h3 Move number: 13
# Qwen CN move: d8h4 Move number: 14
# Qwen US move: e1e2 Move number: 15
# Qwen CN move: Nh6 Move number: 16
# Qwen US move: Nxd5 Move number: 17
# Qwen CN move: c6d5 Move number: 18
# Invalid move by Qwen white. Move: Nd5
# New Move: Qe1
# Qwen US move: Qe1 Move number: 19
# Qwen CN move: h4h5 Move number: 20
# Qwen US move: g4 Move number: 21
# Qwen CN move: h6g4 Move number: 22
# Qwen US move: Qf2 Move number: 23
# Qwen CN move: g4f2 Move number: 24
# Qwen US move: Ke1 Move number: 25
# Qwen CN move: Bd6 Move number: 26
# Qwen US move: Bd3 Move number: 27
# Qwen CN move: f2d3 Move number: 28
# Qwen US move: cxd3 Move number: 29
# Qwen CN move: e5d3 Move number: 30
# Invalid move by Qwen white. Move: Ke1
# New Move: Kf1
# Qwen US move: Kf1 Move number: 31
# Qwen CN move: h5f3 Move number: 32
# Qwen US move: Kg1 Move number: 33
# Qwen CN move: f3f2 Move number: 34
# Game 27 result: 0-1
#
#
# Starting game 28...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Invalid move by Qwen white. Move: Nxe5
# New Move: f3
# Qwen US move: f3 Move number: 9
# Qwen CN move: c7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: Nf6 Move number: 12
# Invalid move by Qwen white. Move: Nbd2
# New Move: Bb5
# Qwen US move: Bb5 Move number: 13
# Qwen CN move: c6b5 Move number: 14
# Qwen US move: Nxd5 Move number: 15
# Qwen CN move: f6d5 Move number: 16
# Qwen US move: Qd2 Move number: 17
# Qwen CN move: d5c7 Move number: 18
# Qwen US move: Qf4 Move number: 19
# Qwen CN move: Bd6 Move number: 20
# Qwen US move: Qxf7+ Move number: 21
# Qwen CN move: e8f7 Move number: 22
# Qwen US move: Rg1 Move number: 23
# Qwen CN move: d8h4 Move number: 24
# Qwen US move: Kd2 Move number: 25
# Qwen CN move: h4f2 Move number: 26
# Qwen US move: Kd3 Move number: 27
# Qwen CN move: c7e6 Move number: 28
# Qwen US move: g2g3 Move number: 29
# Qwen CN move: g6e5 Move number: 30
# Qwen US move: Kc3 Move number: 31
# Qwen CN move: f2d4 Move number: 32
# Qwen US move: Kb3 Move number: 33
# Qwen CN move: d4b4 Move number: 34
# Game 28 result: 0-1
#
#
# Starting game 29...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Invalid move by Qwen white. Move: Nbd2
# New Move: f3
# Qwen US move: f3 Move number: 9
# Qwen CN move: c7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: d5 Move number: 12
# Qwen US move: Nxd5 Move number: 13
# Qwen CN move: c6d5 Move number: 14
# Qwen US move: Be2 Move number: 15
# Qwen CN move: c8d7 Move number: 16
# Qwen US move: Be3 Move number: 17
# Qwen CN move: g8h6 Move number: 18
# Invalid move by Qwen white. Move: Be2
# New Move: Ba6
# Qwen US move: Ba6 Move number: 19
# Qwen CN move: b7a6 Move number: 20
# Qwen US move: Bh6 Move number: 21
# Qwen CN move: g7h6 Move number: 22
# Qwen US move: Qd2 Move number: 23
# Qwen CN move: d5e4 Move number: 24
# Invalid move by Qwen white. Move: Qxd8
# New Move: Qc3
# Qwen US move: Qc3 Move number: 25
# Qwen CN move: d8h4 Move number: 26
# Qwen US move: Ke2 Move number: 27
# Qwen CN move: a8c8 Move number: 28
# Qwen US move: Qxc8+ Move number: 29
# Qwen CN move: d7c8 Move number: 30
# Qwen US move: Kd2 Move number: 31
# Qwen CN move: Bb4+ Move number: 32
# Qwen US move: Kd1 Move number: 33
# Qwen CN move: e4e3 Move number: 34
# Qwen US move: Rg1 Move number: 35
# Qwen CN move: h4d4 Move number: 36
# Qwen US move: Ke2 Move number: 37
# Qwen CN move: d4d2 Move number: 38
# Qwen US move: Kf1 Move number: 39
# Qwen CN move: d2f2 Move number: 40
# Game 29 result: 0-1
#
#
# Starting game 30...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nc3 Move number: 5
# Qwen CN move: e7e5 Move number: 6
# Qwen US move: f1c4 Move number: 7
# Qwen CN move: f8e7 Move number: 8
# Qwen US move: Bxf7+ Move number: 9
# Qwen CN move: Kf8 Move number: 10
# Invalid move by Qwen white. Move: Bxf7+
# New Move: Bb3
# Qwen US move: Bb3 Move number: 11
# Qwen CN move: d7d6 Move number: 12
# Qwen US move: Nh4 Move number: 13
# Qwen CN move: e7h4 Move number: 14
# Invalid move by Qwen white. Move: Bxf8
# New Move: O-O
# Qwen US move: O-O Move number: 15
# Qwen CN move: h7h5 Move number: 16
# Qwen US move: d2d3 Move number: 17
# Qwen CN move: Nh6 Move number: 18
# Invalid move by Qwen white. Move: Nbd2
# New Move: Be6
# ...
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Invalid move by Qwen white. Move: Nbd2
# New Move: f3
# Qwen US move: f3 Move number: 9
# Qwen CN move: c7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: Nf6 Move number: 12
# Invalid move by Qwen white. Move: Nbd2
# New Move: Bb5
# Qwen US move: Bb5 Move number: 13
# Qwen CN move: c6b5 Move number: 14
# Invalid move by Qwen white. Move: Nxe5
# New Move: Kf2
# Qwen US move: Kf2 Move number: 15
# Qwen CN move: b5b4 Move number: 16
# Qwen US move: Nd5 Move number: 17
# Qwen CN move: f6d5 Move number: 18
# Qwen US move: Kf1 Move number: 19
# Qwen CN move: d5c7 Move number: 20
# Qwen US move: Rg1 Move number: 21
# Qwen CN move: Rg8 Move number: 22
# Qwen US move: Rb1 Move number: 23
# Qwen CN move: d7d5 Move number: 24
# Qwen US move: Qd3 Move number: 25
# Qwen CN move: c8d7 Move number: 26
# Qwen US move: Qc4 Move number: 27
# Qwen CN move: d5c4 Move number: 28
# Qwen US move: Bg5 Move number: 29
# Qwen CN move: d8c8 Move number: 30
# Qwen US move: d4d5 Move number: 31
# Qwen CN move: h7h6 Move number: 32
# Qwen US move: Bd2 Move number: 33
# Qwen CN move: a7a5 Move number: 34
# Qwen US move: Bxh6 Move number: 35
# Qwen CN move: g7h6 Move number: 36
# Qwen US move: b1d1 Move number: 37
# Qwen CN move: a8a6 Move number: 38
# Qwen US move: Rd2 Move number: 39
# Qwen CN move: Rd6 Move number: 40
# Qwen US move: Rd4 Move number: 41
# Qwen CN move: b7b5 Move number: 42
# Qwen US move: Rxc4 Move number: 43
# Qwen CN move: b5c4 Move number: 44
# Qwen US move: h3 Move number: 45
# Qwen CN move: c8b8 Move number: 46
# Qwen US move: Rh1 Move number: 47
# Qwen CN move: a5a4 Move number: 48
# Qwen US move: f3f4 Move number: 49
# Invalid move by Qwen black. Move: Rd6
# New Move: a3
# Qwen CN move: a3 Move number: 50
# Qwen US move: Rh2 Move number: 51
# Qwen CN move: a3b2 Move number: 52
# Qwen US move: Rh1 Move number: 53
# Qwen CN move: b2b1q Move number: 54
# Qwen US move: Ke2 Move number: 55
# Qwen CN move: b1c2 Move number: 56
# Qwen US move: Kf3 Move number: 57
# Qwen CN move: Qd8 Move number: 58
# Invalid move by Qwen white. Move: Rd2
# New Move: Rg1
# Qwen US move: Rg1 Move number: 59
# Qwen CN move: d8f6 Move number: 60
# Qwen US move: Kg3 Move number: 61
# Qwen CN move: f6f4 Move number: 62
# Game 92 result: 0-1
#
#
# Starting game 93...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Nh4 Move number: 5
# Qwen CN move: g8f6 Move number: 6
# Qwen US move: Nf3 Move number: 7
# Qwen CN move: f6e4 Move number: 8
# Qwen US move: Ng5 Move number: 9
# Qwen CN move: e4g5 Move number: 10
# Qwen US move: Bb5 Move number: 11
# Qwen CN move: a7a6 Move number: 12
# Qwen US move: b5c6 Move number: 13
# Qwen CN move: d7c6 Move number: 14
# Qwen US move: Nc3 Move number: 15
# Qwen CN move: g5e6 Move number: 16
# Qwen US move: Nxe4 Move number: 17
# Qwen CN move: f7f5 Move number: 18
# Qwen US move: e4g3 Move number: 19
# Qwen CN move: g7g6 Move number: 20
# Qwen US move: Nh5 Move number: 21
# Invalid move by Qwen black. Move: Nh5
# New Move: Nf4
# Qwen CN move: Nf4 Move number: 22
# Qwen US move: Ng7+ Move number: 23
# Qwen CN move: f8g7 Move number: 24
# Qwen US move: Qe2 Move number: 25
# Qwen CN move: f4e2 Move number: 26
# Qwen US move: Rg1 Move number: 27
# Qwen CN move: e2d4 Move number: 28
# Qwen US move: Rb1 Move number: 29
# Qwen CN move: Rg8 Move number: 30
# Invalid move by Qwen white. Move: Rb3
# New Move: Kd1
# Qwen US move: Kd1 Move number: 31
# Qwen CN move: g7f6 Move number: 32
# Qwen US move: Rh1 Move number: 33
# Qwen CN move: a6a5 Move number: 34
# Invalid move by Qwen white. Move: Rg3
# New Move: Ke1
# Qwen US move: Ke1 Move number: 35
# Qwen CN move: d4c2 Move number: 36
# Qwen US move: Ke2 Move number: 37
# Qwen CN move: c2d4 Move number: 38
# Qwen US move: Kd3 Move number: 39
# Qwen CN move: c5c4 Move number: 40
# Qwen US move: Kxc4 Move number: 41
# Qwen CN move: Qd5+ Move number: 42
# Qwen US move: Kc3 Move number: 43
# Qwen CN move: d5c5 Move number: 44
# Invalid move by Qwen white. Move: Kd2
# New Move: Kd3
# Qwen US move: Kd3 Move number: 45
# Qwen CN move: c5c2 Move number: 46
# Qwen US move: Ke3 Move number: 47
# Qwen CN move: c2e4 Move number: 48
# Game 93 result: 0-1
#
#
# Starting game 94...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Ng5 Move number: 5
# Qwen CN move: d8g5 Move number: 6
# Invalid move by Qwen white. Move: Nf3
# New Move: h4
# Qwen US move: h4 Move number: 7
# Qwen CN move: g5d8 Move number: 8
# Qwen US move: d2d4 Move number: 9
# Invalid move by Qwen black. Move: dxe5
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 10
# Qwen US move: b1a3 Move number: 11
# Qwen CN move: Nge7 Move number: 12
# Qwen US move: dxe5 Move number: 13
# Qwen CN move: c6e5 Move number: 14
# Qwen US move: Qd2 Move number: 15
# Qwen CN move: f7f6 Move number: 16
# Qwen US move: Qd5 Move number: 17
# Qwen CN move: e7d5 Move number: 18
# Qwen US move: Nxb1 Move number: 19
# Qwen CN move: Nc3 Move number: 20
# Qwen US move: Be2 Move number: 21
# Qwen CN move: c3e4 Move number: 22
# Qwen US move: Bd1 Move number: 23
# Qwen CN move: d7d5 Move number: 24
# Qwen US move: d1h5 Move number: 25
# Qwen CN move: g7g6 Move number: 26
# Qwen US move: Bxg6+ Move number: 27
# Qwen CN move: h7g6 Move number: 28
# Qwen US move: Rg1 Move number: 29
# Qwen CN move: e4d6 Move number: 30
# Qwen US move: Rf1 Move number: 31
# Qwen CN move: c8d7 Move number: 32
# Qwen US move: Rh1 Move number: 33
# Qwen CN move: d8e7 Move number: 34
# Qwen US move: Rh3 Move number: 35
# Qwen CN move: e5f3 Move number: 36
# Qwen US move: Kd1 Move number: 37
# Qwen CN move: e7e1 Move number: 38
# Game 94 result: 0-1
#
#
# Starting game 95...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: d7d6 Move number: 6
# Qwen US move: Nxf7 Move number: 7
# Qwen CN move: e8f7 Move number: 8
# Qwen US move: Be2 Move number: 9
# Qwen CN move: b8c6 Move number: 10
# Qwen US move: Bf1 Move number: 11
# Qwen CN move: d6d5 Move number: 12
# Qwen US move: Be2 Move number: 13
# Qwen CN move: f6e4 Move number: 14
# Qwen US move: Bh5+ Move number: 15
# Qwen CN move: g7g6 Move number: 16
# Qwen US move: Bxg6+ Move number: 17
# Qwen CN move: h7g6 Move number: 18
# Qwen US move: Nc3 Move number: 19
# Qwen CN move: d8e8 Move number: 20
# Qwen US move: Nxe4 Move number: 21
# Qwen CN move: e8e4 Move number: 22
# Invalid move by Qwen white. Move: Ke1
# New Move: Kf1
# Qwen US move: Kf1 Move number: 23
# Qwen CN move: e4g4 Move number: 24
# Qwen US move: Qe2 Move number: 25
# Qwen CN move: c6d4 Move number: 26
# Qwen US move: Qe8+ Move number: 27
# Qwen CN move: f7g8 Move number: 28
# Qwen US move: Qxf8+ Move number: 29
# Qwen CN move: Kxf8 Move number: 30
# Qwen US move: Rg1 Move number: 31
# Qwen CN move: g4d1 Move number: 32
# Game 95 result: 0-1
#
#
# Starting game 96...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Qwen US move: Be2 Move number: 9
# Qwen CN move: d7d5 Move number: 10
# Qwen US move: Be3 Move number: 11
# Qwen CN move: d5e4 Move number: 12
# Qwen US move: c2c4 Move number: 13
# Qwen CN move: g6h4 Move number: 14
# Qwen US move: Bh6 Move number: 15
# Invalid move by Qwen black. Move: Bh6
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 16
# Qwen US move: h6g7 Move number: 17
# Qwen CN move: Qxd4 Move number: 18
# Qwen US move: Bh6 Move number: 19
# Qwen CN move: d4d1 Move number: 20
# Qwen US move: Bxd1 Move number: 21
# Qwen CN move: a3b2 Move number: 22
# Qwen US move: Bd2 Move number: 23
# Qwen CN move: h4g2 Move number: 24
# Qwen US move: Ke2 Move number: 25
# Qwen CN move: Nh4 Move number: 26
# Qwen US move: Bh6 Move number: 27
# Qwen CN move: g8h6 Move number: 28
# Qwen US move: Re1 Move number: 29
# Qwen CN move: e8g8 Move number: 30
# Qwen US move: e1g1 Move number: 31
# Qwen CN move: g8h8 Move number: 32
# Qwen US move: Rg8+ Move number: 33
# Qwen CN move: h6g8 Move number: 34
# Qwen US move: Na3 Move number: 35
# Qwen CN move: b2a1 Move number: 36
# Qwen US move: Nc2 Move number: 37
# Qwen CN move: a1g7 Move number: 38
# Qwen US move: Nd4 Move number: 39
# Qwen CN move: g7d4 Move number: 40
# Qwen US move: Ke1 Move number: 41
# Qwen CN move: c8f5 Move number: 42
# Qwen US move: Kf1 Move number: 43
# Qwen CN move: c7c6 Move number: 44
# Qwen US move: Bh5 Move number: 45
# Qwen CN move: f5g6 Move number: 46
# Qwen US move: Bxg6 Move number: 47
# Qwen CN move: h4g6 Move number: 48
# Qwen US move: Kg2 Move number: 49
# Qwen CN move: h7h6 Move number: 50
# Qwen US move: h3 Move number: 51
# Qwen CN move: h8h7 Move number: 52
# Qwen US move: Kh1 Move number: 53
# Qwen CN move: d4f2 Move number: 54
# Qwen US move: Kh2 Move number: 55
# Qwen CN move: f2h4 Move number: 56
# Qwen US move: Kg1 Move number: 57
# Qwen CN move: g6f4 Move number: 58
# Qwen US move: Kh2 Move number: 59
# Qwen CN move: a8d8 Move number: 60
# Qwen US move: Kh1 Move number: 61
# Qwen CN move: h4g3 Move number: 62
# Qwen US move: a4 Move number: 63
# Qwen CN move: d8d1 Move number: 64
# Game 96 result: 0-1
#
#
# Starting game 97...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: b1c3 Move number: 5
# Qwen CN move: Nf6 Move number: 6
# Qwen US move: Nxe5 Move number: 7
# Qwen CN move: c6e5 Move number: 8
# Invalid move by Qwen white. Move: Nbd2
# New Move: d3
# Qwen US move: d3 Move number: 9
# Qwen CN move: d7d5 Move number: 10
# Qwen US move: d3d4 Move number: 11
# Invalid move by Qwen black. Move: Nbd2
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 12
# Qwen US move: d4e5 Move number: 13
# Qwen CN move: Be7 Move number: 14
# Qwen US move: Nxd5 Move number: 15
# Qwen CN move: f6d5 Move number: 16
# Qwen US move: Qd2 Move number: 17
# Qwen CN move: d7c6 Move number: 18
# Qwen US move: Qh6+ Move number: 19
# Qwen CN move: g7h6 Move number: 20
# Qwen US move: Rg1 Move number: 21
# Qwen CN move: Rg8 Move number: 22
# Qwen US move: Rb1 Move number: 23
# Qwen CN move: d5b4 Move number: 24
# Qwen US move: Bd2 Move number: 25
# Qwen CN move: b4c2 Move number: 26
# Qwen US move: e1e2 Move number: 27
# Qwen CN move: c2d4 Move number: 28
# Qwen US move: Ke1 Move number: 29
# Qwen CN move: d4c2 Move number: 30
# Qwen US move: Ke2 Move number: 31
# Qwen CN move: c2d4 Move number: 32
# Qwen US move: Ke1 Move number: 33
# Qwen CN move: b7b5 Move number: 34
# Qwen US move: Bxh6 Move number: 35
# Qwen CN move: c6b7 Move number: 36
# Qwen US move: Bd3 Move number: 37
# Qwen CN move: c8e6 Move number: 38
# Qwen US move: Bd2 Move number: 39
# Qwen CN move: d8d7 Move number: 40
# Qwen US move: Bxb5 Move number: 41
# Qwen CN move: d4f3 Move number: 42
# Qwen US move: gxf3 Move number: 43
# Qwen CN move: g8g1 Move number: 44
# Qwen US move: Bf1 Move number: 45
# Qwen CN move: d7d3 Move number: 46
# Qwen US move: Bh6 Move number: 47
# Qwen CN move: g1f1 Move number: 48
# Game 97 result: 0-1
#
#
# Starting game 98...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Invalid move by Qwen white. Move: Nxe5
# New Move: f3
# Qwen US move: f3 Move number: 9
# Qwen CN move: c7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Invalid move by Qwen black. Move: dxe5
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 12
# Qwen US move: b2a3 Move number: 13
# Qwen CN move: Nf6 Move number: 14
# Invalid move by Qwen white. Move: Nbd2
# New Move: Bb5
# Qwen US move: Bb5 Move number: 15
# Qwen CN move: c6b5 Move number: 16
# Invalid move by Qwen white. Move: Nxe5
# New Move: Rb1
# Qwen US move: Rb1 Move number: 17
# Qwen CN move: d7d6 Move number: 18
# Qwen US move: e1g1 Move number: 19
# Qwen CN move: Be6 Move number: 20
# Qwen US move: Nd5 Move number: 21
# Qwen CN move: e6d5 Move number: 22
# Qwen US move: Qe2 Move number: 23
# Qwen CN move: d5c4 Move number: 24
# Qwen US move: Qd1 Move number: 25
# Qwen CN move: e8g8 Move number: 26
# Qwen US move: Qd3 Move number: 27
# Invalid move by Qwen black. Move: Qd2
# New Move: Qc7
# Qwen CN move: Qc7 Move number: 28
# Qwen US move: d3c3 Move number: 29
# Invalid move by Qwen black. Move: Qd2
# New Move: b4
# Qwen CN move: b4 Move number: 30
# Qwen US move: Qxc4 Move number: 31
# Qwen CN move: c7c4 Move number: 32
# Qwen US move: Rd1 Move number: 33
# Qwen CN move: g8h8 Move number: 34
# Qwen US move: Rd2 Move number: 35
# Qwen CN move: d6d5 Move number: 36
# Qwen US move: Rd3 Move number: 37
# Qwen CN move: Nd7 Move number: 38
# Qwen US move: Re3 Move number: 39
# Qwen CN move: a8e8 Move number: 40
# Invalid move by Qwen white. Move: Rd1
# New Move: c3
# Qwen US move: c3 Move number: 41
# Qwen CN move: c4a2 Move number: 42
# Qwen US move: b1b4 Move number: 43
# Qwen CN move: Rxe4 Move number: 44
# Qwen US move: Rxb7 Move number: 45
# Qwen CN move: e4e3 Move number: 46
# Qwen US move: Rxd7 Move number: 47
# Qwen CN move: e3e1 Move number: 48
# Game 98 result: 0-1
#
#
# Starting game 99...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Ng5 Move number: 5
# Qwen CN move: d8g5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: g5g6 Move number: 8
# Qwen US move: f2f4 Move number: 9
# Qwen CN move: d7d5 Move number: 10
# Qwen US move: Nxd5 Move number: 11
# Qwen CN move: g6e4 Move number: 12
# Qwen US move: Ne3 Move number: 13
# Qwen CN move: e5f4 Move number: 14
# Qwen US move: Bb5 Move number: 15
# Qwen CN move: f4e3 Move number: 16
# Qwen US move: Bxc6+ Move number: 17
# Qwen CN move: b7c6 Move number: 18
# Qwen US move: dxe3 Move number: 19
# Qwen CN move: e4g2 Move number: 20
# Qwen US move: Qd5 Move number: 21
# Qwen CN move: c6d5 Move number: 22
# Qwen US move: Rg1 Move number: 23
# Qwen CN move: g2g1 Move number: 24
# Qwen US move: Ke2 Move number: 25
# Qwen CN move: g1h2 Move number: 26
# Qwen US move: Kf3 Move number: 27
# Qwen CN move: c8g4 Move number: 28
# Qwen US move: Kxg4 Move number: 29
# Qwen CN move: h7h5 Move number: 30
# Qwen US move: Kf3 Move number: 31
# Qwen CN move: f8d6 Move number: 32
# Qwen US move: Bd2 Move number: 33
# Qwen CN move: g8f6 Move number: 34
# Qwen US move: Bc1 Move number: 35
# Qwen CN move: d6g3 Move number: 36
# Qwen US move: Bd2 Move number: 37
# Qwen CN move: h2f2 Move number: 38
# Game 99 result: 0-1
#
#
# Starting game 100...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nc3 Move number: 5
# Qwen CN move: e7e5 Move number: 6
# Invalid move by Qwen white. Move: Nge2
# New Move: g3
# Qwen US move: g3 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: d2d3 Move number: 9
# Invalid move by Qwen black. Move: Nf3
# New Move: g6
# Qwen CN move: g6 Move number: 10
# Qwen US move: Nh4 Move number: 11
# Qwen CN move: h7h6 Move number: 12
# Qwen US move: Nf3 Move number: 13
# Qwen CN move: f8g7 Move number: 14
# Qwen US move: Ng5 Move number: 15
# Qwen CN move: h6g5 Move number: 16
# Qwen US move: Nd5 Move number: 17
# Invalid move by Qwen black. Move: Nxf6+
# New Move: Rxh2
# Qwen CN move: Rxh2 Move number: 18
# Qwen US move: h1h2 Move number: 19
# Qwen CN move: Nxd5 Move number: 20
# Qwen US move: Rh8+ Move number: 21
# Qwen CN move: g7h8 Move number: 22
# Qwen US move: Qe2 Move number: 23
# Qwen CN move: d5c7 Move number: 24
# Qwen US move: Qh5 Move number: 25
# Qwen CN move: g6h5 Move number: 26
# Qwen US move: Bh3 Move number: 27
# Invalid move by Qwen black. Move: Bh6
# New Move: h4
# Qwen CN move: h4 Move number: 28
# Qwen US move: Bxd7+ Move number: 29
# Qwen CN move: e8d7 Move number: 30
# Qwen US move: Ke2 Move number: 31
# Qwen CN move: c6d4 Move number: 32
# Qwen US move: Ke1 Move number: 33
# Qwen CN move: h4h3 Move number: 34
# Qwen US move: Bxg5 Move number: 35
# Qwen CN move: Bg7 Move number: 36
# Qwen US move: Bh6 Move number: 37
# Qwen CN move: h3h2 Move number: 38
# Qwen US move: Bxg7 Move number: 39
# Qwen CN move: d8g5 Move number: 40
# Qwen US move: Bh8 Move number: 41
# Qwen CN move: h2h1r Move number: 42
# Game 100 result: 0-1

# %%
board.result()
# Out:
# '0-1'

# %%
results = []

# %%
results.append({
            "Qwen US Wins": qwen_us_wins,
            "Qwen CN Wins": qwen_cn_wins,
            "Draws": draws,
        })

print(results)
# Out:
# [{'Qwen US Wins': 0, 'Qwen CN Wins': 100, 'Draws': 0}]

# %%
df = pd.DataFrame(results)
df.to_csv("Qwen vs Qwen.csv", index=False)
print("Results saved to Qwen vs Qwen.csv")
# Out:
# Results saved to Qwen vs Qwen.csv
