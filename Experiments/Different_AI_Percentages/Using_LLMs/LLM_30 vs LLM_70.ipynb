# %% [markdown]
# # LLM_1 - **30%** vs. LLM_2 - **70%**

# %%
import chess
from stockfish import Stockfish
from ollama import chat
from ollama import ChatResponse
import json
import random
import pandas as pd
import asyncio

# %%
# STOCKFISH_PATH = r"C:\Users\nafis\Downloads\stockfish-windows-x86-64-avx2\stockfish\stockfish-windows-x86-64-avx2.exe"

STOCKFISH_ELO = 3500
NUM_GAMES = 100
MOVE_LIMIT = 300
RANDOM_START = 0
QWEN_US_AI = 30
QWEN_CN_AI = 70

# %%
stockfish = Stockfish()
stockfish.update_engine_parameters({"Threads": 4, "Hash": 4096})

# %%
qwen_cn_wins = 0
qwen_us_wins = 0
draws = 0

# %%
# def generate_random_number(seed:int) -> int:
#     # random.seed(seed)
#     return random.randint(1, 100)

# %%
def valid_move_to_string(board):
    legal_moves = [
        board.san(move) for move in board.legal_moves]
    
    if not legal_moves:
        return "No legal moves."
    else:
        return ", ".join(legal_moves)

# %%
def get_move_history(board: chess.Board) -> str:
    """Return a formatted move history string like '1. e4 e5 2. Nf3 d5'."""
    temp_board = chess.Board()  # Start from the initial position.
    move_history = []
    
    # Iterate over the moves in the board's move stack.
    for i, move in enumerate(board.move_stack):
        # Get the SAN for the move in the current temporary board.
        move_san = temp_board.san(move)
        # Push the move so that the board state is updated.
        temp_board.push(move)
        
        # For white moves (even index), start a new entry with move number.
        if i % 2 == 0:
            move_history.append(f"{i//2 + 1}. {move_san}")
        # For black moves, append to the last white move entry.
        else:
            move_history[-1] += f" {move_san}"
    
    # Join all entries with a space.
    return " ".join(move_history)

# %%
async def get_move_with_timeout(stockfish, timeout=15):
    """
    Run stockfish.get_best_move() in a separate thread and wait for a maximum of `timeout` seconds.
    If the call exceeds the timeout, return None.
    """
    try:
        # Use asyncio.to_thread to run the blocking call in a separate thread.
        move = await asyncio.wait_for(asyncio.to_thread(stockfish.get_best_move), timeout)
        return move
    except asyncio.TimeoutError:
        # move = stockfish.get_best_move_time(1000)
        print(f"Timeout: stockfish.get_best_move() took more than 15 seconds.")
        return None

# %%
def get_qwen_move(board:chess.Board, fen:str, temp=0.0):
    valid_moves = valid_move_to_string(board)

    move_history = get_move_history(board)
    
    response: ChatResponse = chat(model='qwen:32b', messages=[
        {
            'role': 'system',
            'content': 'You are a grand master chess player.'
        },
        {
            'role': 'user',
            'content': f"""You are playing chess and it is your turn. This is the current state of the game. Use this to work out where the pieces are on the board:

FEN: {fen}

The possible set of legal moves are: 

Legal Moves: {valid_moves}

+(You have to choose one from the provided list. Do not choose a move that is not in the list.)

The move history is: {move_history}.

Output the best move in SAN format to follow this position. Use the following single blob of JSON. Do not include any other information.
{{
    "san": "The move in SAN format",
}}"""}], options={"temperature": temp})
    
    try:
        parsed_json = json.loads(response.message.content)
        qwen_move = parsed_json["san"]
    except Exception as e:
        print(f"Wrong format given by Qwen. \nQwen Output: {response.message.content}")

    

    return qwen_move

# %%
def get_random_move(board:chess.Board, fen:str, seed: int = 101):
    legal_moves = [
        board.san(move)
        for move in board.legal_moves
    ]

    random.seed(seed)

    # print(random.choice(legal_moves))
    return random.choice(legal_moves)

    # print(legal_moves[0])

# %%
for game_number in range(1, NUM_GAMES + 1):
    
    move_counter = 0

    print(f"Starting game {game_number}...")

    board = chess.Board()

    while not board.is_game_over() and move_counter <= MOVE_LIMIT:
        if board.turn == chess.WHITE and not board.is_game_over():
            num = random.randint(1,100)
            
            if num <= QWEN_US_AI:
                stockfish.set_fen_position(board.fen())
                qwen_us_move = await get_move_with_timeout(stockfish)

                if qwen_us_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break
            
            else:
                qwen_us_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_us_move)
            except Exception as e:
                print(f"Invalid move by Qwen white. Move: {qwen_us_move}")
                qwen_us_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_us_move)
                print(f"New Move: {qwen_us_move}")
                # continue
            
            move_counter += 1        
            print(f"Qwen US move: {qwen_us_move} Move number: {move_counter}")

        elif board.turn == chess.BLACK and not board.is_game_over():
            num = random.randint(1, 100)

            if num <= QWEN_CN_AI:
                stockfish.set_fen_position(board.fen())
                qwen_cn_move = await get_move_with_timeout(stockfish)

                if qwen_cn_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break

            else:
                qwen_cn_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_cn_move)
            except Exception as e:
                print(f"Invalid move by Qwen black. Move: {qwen_cn_move}")
                qwen_cn_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_cn_move)
                print(f"New Move: {qwen_cn_move}")
                # continue
            move_counter += 1
            print(f"Qwen CN move: {qwen_cn_move} Move number: {move_counter}")   

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        qwen_us_wins += 1
    elif result == "0-1":
        qwen_cn_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n\n")
# Out:
# Starting game 1...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: Nxe5 Move number: 6
# Qwen US move: b1c3 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Qwen US move: d2d4 Move number: 9
# Qwen CN move: f8b4 Move number: 10
# Qwen US move: Bd3 Move number: 11
# Qwen CN move: d7d5 Move number: 12
# Qwen US move: e1g1 Move number: 13
# Qwen CN move: Nf6 Move number: 14
# Invalid move by Qwen white. Move: Nxe5
# New Move: Ne2
# Qwen US move: Ne2 Move number: 15
# Qwen CN move: d5e4 Move number: 16
# Invalid move by Qwen white. Move: Bxc6
# New Move: f3
# Qwen US move: f3 Move number: 17
# Qwen CN move: e4d3 Move number: 18
# Qwen US move: d1d3 Move number: 19
# Qwen CN move: Qxd4+ Move number: 20
# Invalid move by Qwen white. Move: Qxe5
# New Move: Be3
# Qwen US move: Be3 Move number: 21
# Qwen CN move: d4d3 Move number: 22
# Qwen US move: c2d3 Move number: 23
# Qwen CN move: Be6 Move number: 24
# Qwen US move: Bd2 Move number: 25
# Qwen CN move: b4d2 Move number: 26
# Qwen US move: f3f4 Move number: 27
# Qwen CN move: g6e7 Move number: 28
# Qwen US move: Nd4 Move number: 29
# Qwen CN move: d2e3 Move number: 30
# Qwen US move: Kh1 Move number: 31
# Invalid move by Qwen black. Move: Nxd5
# New Move: b6
# Qwen CN move: b6 Move number: 32
# Qwen US move: d4b5 Move number: 33
# Qwen CN move: f6d5 Move number: 34
# Qwen US move: Nxc7+ Move number: 35
# Qwen CN move: d5c7 Move number: 36
# Qwen US move: Rfe1 Move number: 37
# Qwen CN move: c7d5 Move number: 38
# Qwen US move: e1e3 Move number: 39
# Qwen CN move: Nf5 Move number: 40
# Qwen US move: e3e5 Move number: 41
# Invalid move by Qwen black. Move: Rxe8+ Kf7
# New Move: Rc8
# Qwen CN move: Rc8 Move number: 42
# Qwen US move: a1e1 Move number: 43
# Qwen CN move: Rg8 Move number: 44
# Qwen US move: Rxe6+ Move number: 45
# Qwen CN move: f7e6 Move number: 46
# Qwen US move: g2g4 Move number: 47
# Qwen CN move: f5e3 Move number: 48
# Qwen US move: Rxe3 Move number: 49
# Qwen CN move: d5e3 Move number: 50
# Qwen US move: g5 Move number: 51
# Qwen CN move: Rc1# Move number: 52
# Game 1 result: 0-1
#
#
# Starting game 2...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1c4 Move number: 5
# Qwen CN move: g8f6 Move number: 6
# Qwen US move: d2d3 Move number: 7
# Qwen CN move: f8c5 Move number: 8
# Qwen US move: c2c3 Move number: 9
# Qwen CN move: d7d6 Move number: 10
# Qwen US move: Bxf7+ Move number: 11
# Qwen CN move: e8f7 Move number: 12
# Qwen US move: Ng5+ Move number: 13
# Qwen CN move: f7e8 Move number: 14
# Qwen US move: Nh3 Move number: 15
# Qwen CN move: Bd4 Move number: 16
# Qwen US move: Nf4 Move number: 17
# Qwen CN move: d4f2 Move number: 18
# Qwen US move: Kxf2 Move number: 19
# Qwen CN move: e5f4 Move number: 20
# Qwen US move: Qg1 Move number: 21
# Qwen CN move: Nh5 Move number: 22
# Qwen US move: Qe1 Move number: 23
# Qwen CN move: c6e5 Move number: 24
# Qwen US move: Qf1 Move number: 25
# Qwen CN move: c8d7 Move number: 26
# Qwen US move: Ke2 Move number: 27
# Qwen CN move: h8f8 Move number: 28
# Qwen US move: Qxf4 Move number: 29
# Qwen CN move: h5f4 Move number: 30
# Qwen US move: c1f4 Move number: 31
# Qwen CN move: d8h4 Move number: 32
# Qwen US move: Bh6 Move number: 33
# Qwen CN move: d7g4 Move number: 34
# Qwen US move: e2d2 Move number: 35
# Qwen CN move: h4f2 Move number: 36
# Qwen US move: Kc1 Move number: 37
# Qwen CN move: e5d3 Move number: 38
# Game 2 result: 0-1
#
#
# Starting game 3...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: Nf6 Move number: 6
# Qwen US move: Bxc6 Move number: 7
# Qwen CN move: d7c6 Move number: 8
# Qwen US move: d2d3 Move number: 9
# Qwen CN move: g7g6 Move number: 10
# Qwen US move: a2a4 Move number: 11
# Qwen CN move: Be6 Move number: 12
# Qwen US move: Ng5 Move number: 13
# Qwen CN move: Nh5 Move number: 14
# Qwen US move: Nh3 Move number: 15
# Qwen CN move: e6h3 Move number: 16
# Qwen US move: Rg1 Move number: 17
# Qwen CN move: h3c8 Move number: 18
# Qwen US move: Qf3 Move number: 19
# Qwen CN move: h5g7 Move number: 20
# Qwen US move: c1e3 Move number: 21
# Qwen CN move: Qd4 Move number: 22
# Qwen US move: e3d4 Move number: 23
# Qwen CN move: Nh5 Move number: 24
# Qwen US move: Bxh8 Move number: 25
# Qwen CN move: f7f6 Move number: 26
# Qwen US move: b1d2 Move number: 27
# Qwen CN move: f8h6 Move number: 28
# Qwen US move: Qg3 Move number: 29
# Qwen CN move: h5g3 Move number: 30
# Invalid move by Qwen white. Move: Nh3
# New Move: d4
# Qwen US move: d4 Move number: 31
# Qwen CN move: h6d2 Move number: 32
# Qwen US move: e1d2 Move number: 33
# Qwen CN move: Nxe4+ Move number: 34
# Qwen US move: Ke1 Move number: 35
# Qwen CN move: e8f7 Move number: 36
# Qwen US move: f2f3 Move number: 37
# Qwen CN move: e4g5 Move number: 38
# Qwen US move: Rf1 Move number: 39
# Qwen CN move: c5d4 Move number: 40
# Qwen US move: Rf2 Move number: 41
# Invalid move by Qwen black. Move: Rxf6
# New Move: d3
# Qwen CN move: d3 Move number: 42
# Qwen US move: b2b4 Move number: 43
# Qwen CN move: c8d7 Move number: 44
# Qwen US move: Rd2 Move number: 45
# Qwen CN move: a8h8 Move number: 46
# Qwen US move: Rxd3 Move number: 47
# Qwen CN move: d7c8 Move number: 48
# Qwen US move: b4b5 Move number: 49
# Qwen CN move: Rg8 Move number: 50
# Qwen US move: b5c6 Move number: 51
# Qwen CN move: Rh8 Move number: 52
# Qwen US move: Rd2 Move number: 53
# Qwen CN move: b7c6 Move number: 54
# Qwen US move: a1b1 Move number: 55
# Qwen CN move: Rg8 Move number: 56
# Invalid move by Qwen white. Move: Rd2
# New Move: Rbd1
# Qwen US move: Rbd1 Move number: 57
# Qwen CN move: g5e6 Move number: 58
# Qwen US move: e1f2 Move number: 59
# Invalid move by Qwen black. Move: Nh3
# New Move: a6
# Qwen CN move: a6 Move number: 60
# Qwen US move: d1b1 Move number: 61
# Qwen CN move: e6c5 Move number: 62
# Qwen US move: Ke2 Move number: 63
# Qwen CN move: c5a4 Move number: 64
# Qwen US move: Ke1 Move number: 65
# Qwen CN move: a4c5 Move number: 66
# Qwen US move: b1b8 Move number: 67
# Invalid move by Qwen black. Move: Rb7
# New Move: Nd3+
# Qwen CN move: Nd3+ Move number: 68
# Qwen US move: c2d3 Move number: 69
# Qwen CN move: f7e6 Move number: 70
# Qwen US move: Rxc8 Move number: 71
# Qwen CN move: g8c8 Move number: 72
# Qwen US move: Rd1 Move number: 73
# Qwen CN move: a6a5 Move number: 74
# Qwen US move: d1a1 Move number: 75
# Invalid move by Qwen black. Move: Rb1
# New Move: Re8
# Qwen CN move: Re8 Move number: 76
# Qwen US move: a1a5 Move number: 77
# Invalid move by Qwen black. Move: Rb1
# New Move: h6
# Qwen CN move: h6 Move number: 78
# Qwen US move: a5a4 Move number: 79
# Qwen CN move: h6h5 Move number: 80
# Qwen US move: Rd4 Move number: 81
# Qwen CN move: e8a8 Move number: 82
# Qwen US move: Rd5 Move number: 83
# Qwen CN move: e6d5 Move number: 84
# Qwen US move: e1d2 Move number: 85
# Qwen CN move: Rd8 Move number: 86
# Qwen US move: d2e3 Move number: 87
# Qwen CN move: Rd6 Move number: 88
# Qwen US move: Kf4 Move number: 89
# Qwen CN move: d5d4 Move number: 90
# Qwen US move: f4g3 Move number: 91
# Qwen CN move: Rd5 Move number: 92
# Qwen US move: Kf4 Move number: 93
# Qwen CN move: d4d3 Move number: 94
# Qwen US move: f4g3 Move number: 95
# Qwen CN move: d5b5 Move number: 96
# Qwen US move: g3h4 Move number: 97
# Qwen CN move: b5b4 Move number: 98
# Qwen US move: Kh3 Move number: 99
# Qwen CN move: Rb8 Move number: 100
# Qwen US move: g2g4 Move number: 101
# Qwen CN move: Rh8 Move number: 102
# Qwen US move: h3h4 Move number: 103
# Invalid move by Qwen black. Move: h5
# New Move: c5
# Qwen CN move: c5 Move number: 104
# Qwen US move: f3f4 Move number: 105
# Qwen CN move: d3d4 Move number: 106
# Qwen US move: g5 Move number: 107
# Qwen CN move: f6f5 Move number: 108
# Qwen US move: Kg3 Move number: 109
# Qwen CN move: h5h4 Move number: 110
# Qwen US move: g3f2 Move number: 111
# Invalid move by Qwen black. Move: Kg4
# New Move: Rd8
# Qwen CN move: Rd8 Move number: 112
# Qwen US move: f2f3 Move number: 113
# Qwen CN move: Rd6 Move number: 114
# Qwen US move: Kf2 Move number: 115
# Qwen CN move: d4e4 Move number: 116
# Qwen US move: f2e2 Move number: 117
# Qwen CN move: e4f4 Move number: 118
# Qwen US move: Kf1 Move number: 119
# Qwen CN move: f4f3 Move number: 120
# Qwen US move: Kg1 Move number: 121
# Qwen CN move: Rd8 Move number: 122
# Qwen US move: Kh1 Move number: 123
# Qwen CN move: d8d1 Move number: 124
# Game 3 result: 0-1
#
#
# Starting game 4...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: g7g6 Move number: 6
# Qwen US move: b5c6 Move number: 7
# Qwen CN move: b7c6 Move number: 8
# Qwen US move: Ng5 Move number: 9
# Qwen CN move: e7e5 Move number: 10
# Qwen US move: Nxf7 Move number: 11
# Qwen CN move: e8f7 Move number: 12
# Qwen US move: Nc3 Move number: 13
# Invalid move by Qwen black. Move: Nxe5
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 14
# Qwen US move: e1g1 Move number: 15
# Qwen CN move: e7e8 Move number: 16
# Qwen US move: Qe2 Move number: 17
# Qwen CN move: d7d6 Move number: 18
# Qwen US move: Nd5 Move number: 19
# Qwen CN move: c6d5 Move number: 20
# Qwen US move: f2f4 Move number: 21
# Qwen CN move: Nf6 Move number: 22
# Qwen US move: f4e5 Move number: 23
# Qwen CN move: Qe7 Move number: 24
# Qwen US move: Qa6 Move number: 25
# Qwen CN move: c8a6 Move number: 26
# Qwen US move: e5f6 Move number: 27
# Qwen CN move: Qe5 Move number: 28
# Qwen US move: Rf2 Move number: 29
# Qwen CN move: e8d7 Move number: 30
# Qwen US move: f6f7 Move number: 31
# Qwen CN move: d5e4 Move number: 32
# Qwen US move: d2d3 Move number: 33
# Qwen CN move: e4e3 Move number: 34
# Qwen US move: Rf6 Move number: 35
# Invalid move by Qwen black. Move: Rf8
# New Move: Rb8
# Qwen CN move: Rb8 Move number: 36
# Qwen US move: f6f3 Move number: 37
# Invalid move by Qwen black. Move: Rxf4
# New Move: Qxb2
# Qwen CN move: Qxb2 Move number: 38
# Qwen US move: c1b2 Move number: 39
# Qwen CN move: b8b2 Move number: 40
# Qwen US move: Rf4 Move number: 41
# Qwen CN move: b2c2 Move number: 42
# Qwen US move: Rf5 Move number: 43
# Qwen CN move: g6f5 Move number: 44
# Qwen US move: h2h3 Move number: 45
# Qwen CN move: Rg8 Move number: 46
# Qwen US move: f7g8q Move number: 47
# Qwen CN move: Bxd3 Move number: 48
# Qwen US move: Qxf8 Move number: 49
# Qwen CN move: d3e4 Move number: 50
# Qwen US move: f8g7 Move number: 51
# Invalid move by Qwen black. Move: Qg5+
# New Move: Ke8
# Qwen CN move: Ke8 Move number: 52
# Qwen US move: a1b1 Move number: 53
# Invalid move by Qwen black. Move: Rb1
# New Move: f4
# Qwen CN move: f4 Move number: 54
# Qwen US move: b1b8 Move number: 55
# Game 4 result: 1-0
#
#
# Starting game 5...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1c4 Move number: 5
# Qwen CN move: g8f6 Move number: 6
# Qwen US move: Bxf7+ Move number: 7
# Qwen CN move: e8f7 Move number: 8
# Qwen US move: Nxe5+ Move number: 9
# Qwen CN move: Nxe5+ Move number: 10
# Qwen US move: Nc3 Move number: 11
# Qwen CN move: f7g8 Move number: 12
# Invalid move by Qwen white. Move: Nbd2
# New Move: a3
# Qwen US move: a3 Move number: 13
# Qwen CN move: e5f7 Move number: 14
# Qwen US move: d2d4 Move number: 15
# Qwen CN move: Nxe4 Move number: 16
# Qwen US move: Nxe4 Move number: 17
# Qwen CN move: d7d5 Move number: 18
# Qwen US move: e4c5 Move number: 19
# Qwen CN move: d8e7 Move number: 20
# Qwen US move: Nxe6 Move number: 21
# Qwen CN move: e7e6 Move number: 22
# Qwen US move: Kf1 Move number: 23
# Qwen CN move: Qe2+ Move number: 24
# Qwen US move: Kg1 Move number: 25
# Qwen CN move: e2d1 Move number: 26
# Game 5 result: 0-1
#
#
# Starting game 6...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen US move: b5a4 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Qwen CN move: d7c6 Move number: 10
# Qwen US move: Nxe5 Move number: 11
# Qwen CN move: d8d4 Move number: 12
# Qwen US move: Nf3 Move number: 13
# Qwen CN move: Be6 Move number: 14
# Qwen US move: Ng5 Move number: 15
# Qwen CN move: f6e4 Move number: 16
# Qwen US move: Nh3 Move number: 17
# Qwen CN move: e6h3 Move number: 18
# Qwen US move: Nc3 Move number: 19
# Qwen CN move: Nxd2 Move number: 20
# Qwen US move: Ne4 Move number: 21
# Qwen CN move: d4e4 Move number: 22
# Qwen US move: Kxd2 Move number: 23
# Qwen CN move: a8d8 Move number: 24
# Qwen US move: Kc3 Move number: 25
# Qwen CN move: e4b4 Move number: 26
# Game 6 result: 0-1
#
#
# Starting game 7...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: Ng5 Move number: 5
# Qwen CN move: d7d5 Move number: 6
# Qwen US move: e4d5 Move number: 7
# Qwen CN move: h7h6 Move number: 8
# Qwen US move: Nxf7 Move number: 9
# Qwen CN move: e8f7 Move number: 10
# Qwen US move: Rg1 Move number: 11
# Qwen CN move: d8d5 Move number: 12
# Qwen US move: Qh5+ Move number: 13
# Qwen CN move: g7g6 Move number: 14
# Qwen US move: h5h4 Move number: 15
# Qwen CN move: Bg7 Move number: 16
# Qwen US move: Qxh6 Move number: 17
# Qwen CN move: g7h6 Move number: 18
# Qwen US move: b1c3 Move number: 19
# Qwen CN move: d5d8 Move number: 20
# Qwen US move: g2g4 Move number: 21
# Qwen CN move: Bg7 Move number: 22
# Invalid move by Qwen white. Move: Nf3
# New Move: g5
# Qwen US move: g5 Move number: 23
# Qwen CN move: c8e6 Move number: 24
# Qwen US move: g5f6 Move number: 25
# Qwen CN move: Rg8 Move number: 26
# Qwen US move: Rxg6 Move number: 27
# Qwen CN move: g7f6 Move number: 28
# Qwen US move: g6h6 Move number: 29
# Qwen CN move: b8c6 Move number: 30
# Qwen US move: Rh7+ Move number: 31
# Qwen CN move: f6g7 Move number: 32
# Qwen US move: Rh8 Move number: 33
# Qwen CN move: Rxh8 Move number: 34
# Invalid move by Qwen white. Move: Nh5
# New Move: b3
# Qwen US move: b3 Move number: 35
# Qwen CN move: c6d4 Move number: 36
# Qwen US move: c3e4 Move number: 37
# Qwen CN move: Bg4 Move number: 38
# Qwen US move: Nf6 Move number: 39
# Qwen CN move: d4c2 Move number: 40
# Game 7 result: 0-1
#
#
# Starting game 8...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: e7e6 Move number: 4
# Qwen US move: Nc3 Move number: 5
# Qwen CN move: Nf6 Move number: 6
# Invalid move by Qwen white. Move: Nf3
# New Move: h3
# Qwen US move: h3 Move number: 7
# Qwen CN move: d7d5 Move number: 8
# Qwen US move: e4d5 Move number: 9
# Qwen CN move: Nxd5 Move number: 10
# Qwen US move: Nh4 Move number: 11
# Qwen CN move: d8h4 Move number: 12
# Qwen US move: f1b5 Move number: 13
# Qwen CN move: b8c6 Move number: 14
# Qwen US move: Bxc6+ Move number: 15
# Qwen CN move: b7c6 Move number: 16
# Qwen US move: Nxd5 Move number: 17
# Invalid move by Qwen black. Move: Nxf7+
# New Move: Ba6
# Qwen CN move: Ba6 Move number: 18
# Qwen US move: d5c7 Move number: 19
# Invalid move by Qwen black. Move: Nxb8
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 20
# Qwen US move: c7a6 Move number: 21
# Qwen CN move: h4a4 Move number: 22
# Qwen US move: Nb8+ Move number: 23
# Qwen CN move: a8b8 Move number: 24
# Qwen US move: Rb1 Move number: 25
# Qwen CN move: a4a2 Move number: 26
# Qwen US move: d2d4 Move number: 27
# Qwen CN move: Rxb2 Move number: 28
# Qwen US move: b1b2 Move number: 29
# Qwen CN move: Qb1 Move number: 30
# Qwen US move: Rb8 Move number: 31
# Qwen CN move: b1b8 Move number: 32
# Qwen US move: d4c5 Move number: 33
# Qwen CN move: Ke8 Move number: 34
# Qwen US move: Qd2 Move number: 35
# Qwen CN move: b8b5 Move number: 36
# Qwen US move: d2d4 Move number: 37
# Qwen CN move: f7f6 Move number: 38
# Qwen US move: c1e3 Move number: 39
# Qwen CN move: f8e7 Move number: 40
# Qwen US move: Qd8+ Move number: 41
# Qwen CN move: Kxd8 Move number: 42
# Qwen US move: e1d2 Move number: 43
# Qwen CN move: Qc4 Move number: 44
# Qwen US move: h1b1 Move number: 45
# Qwen CN move: Qd3+ Move number: 46
# Qwen US move: Kxd3 Move number: 47
# Qwen CN move: Kc7 Move number: 48
# Qwen US move: Bd2 Move number: 49
# Qwen CN move: e7c5 Move number: 50
# Qwen US move: f2f3 Move number: 51
# Qwen CN move: c5b6 Move number: 52
# Qwen US move: Bc1 Move number: 53
# Qwen CN move: h8d8 Move number: 54
# Qwen US move: d3e2 Move number: 55
# Qwen CN move: Rd2+ Move number: 56
# Qwen US move: c1d2 Move number: 57
# Qwen CN move: Be3 Move number: 58
# Qwen US move: Kd3 Move number: 59
# Qwen CN move: e3d2 Move number: 60
# Qwen US move: Ke4 Move number: 61
# Qwen CN move: a7a5 Move number: 62
# Qwen US move: e4d3 Move number: 63
# Qwen CN move: Kc8 Move number: 64
# Qwen US move: Ke2 Move number: 65
# Qwen CN move: d2b4 Move number: 66
# Qwen US move: e2d3 Move number: 67
# Qwen CN move: c8c7 Move number: 68
# Qwen US move: b1a1 Move number: 69
# Qwen CN move: c7b6 Move number: 70
# Qwen US move: Ke2 Move number: 71
# Invalid move by Qwen black. Move: Ke3
# New Move: h5
# Qwen CN move: h5 Move number: 72
# Qwen US move: a1b1 Move number: 73
# Qwen CN move: b6c7 Move number: 74
# Qwen US move: Rxb4 Move number: 75
# Qwen CN move: a5b4 Move number: 76
# Qwen US move: Kd3 Move number: 77
# Qwen CN move: c7d6 Move number: 78
# Qwen US move: h3h4 Move number: 79
# Qwen CN move: Ke7 Move number: 80
# Qwen US move: d3c4 Move number: 81
# Qwen CN move: Kf7 Move number: 82
# Qwen US move: Kd3 Move number: 83
# Qwen CN move: f7e7 Move number: 84
# Qwen US move: d3c4 Move number: 85
# Qwen CN move: Kf7 Move number: 86
# Qwen US move: Kd3 Move number: 87
# Qwen CN move: f7e7 Move number: 88
# Qwen US move: d3d4 Move number: 89
# Qwen CN move: e7d6 Move number: 90
# Qwen US move: g2g4 Move number: 91
# Qwen CN move: c6c5 Move number: 92
# Qwen US move: Ke4 Move number: 93
# Qwen CN move: g5 Move number: 94
# Qwen US move: g4h5 Move number: 95
# Qwen CN move: e5 Move number: 96
# Qwen US move: h5h6 Move number: 97
# Qwen CN move: g4 Move number: 98
# Qwen US move: fxg4 Move number: 99
# Invalid move by Qwen black. Move: fxg4
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 100
# Qwen US move: h6h7 Move number: 101
# Qwen CN move: f5+ Move number: 102
# Qwen US move: Kxf5 Move number: 103
# Qwen CN move: d7c6 Move number: 104
# Qwen US move: h7h8q Move number: 105
# Qwen CN move: c5c4 Move number: 106
# Qwen US move: Qe8+ Move number: 107
# Qwen CN move: c6b6 Move number: 108
# Qwen US move: Qf7 Move number: 109
# Invalid move by Qwen black. Move: Qf6
# New Move: Ka6
# Qwen CN move: Ka6 Move number: 110
# Qwen US move: f7c4 Move number: 111
# Qwen CN move: Kb7 Move number: 112
# Qwen US move: Qc8+ Move number: 113
# Qwen CN move: b7c8 Move number: 114
# Qwen US move: h4h5 Move number: 115
# Qwen CN move: c8d7 Move number: 116
# Qwen US move: Kf6 Move number: 117
# Qwen CN move: e5e4 Move number: 118
# Qwen US move: Kg7 Move number: 119
# Invalid move by Qwen black. Move: Kf6
# New Move: Kd8
# Qwen CN move: Kd8 Move number: 120
# Qwen US move: h5h6 Move number: 121
# Invalid move by Qwen black. Move: Kf5
# New Move: e3
# Qwen CN move: e3 Move number: 122
# Qwen US move: h6h7 Move number: 123
# Qwen CN move: d8d7 Move number: 124
# Qwen US move: h8=Q Move number: 125
# Qwen CN move: d7e7 Move number: 126
# Qwen US move: Qh1 Move number: 127
# Qwen CN move: e7d6 Move number: 128
# Qwen US move: h1h6 Move number: 129
# Invalid move by Qwen black. Move: Kf5
# New Move: Kc5
# Qwen CN move: Kc5 Move number: 130
# Qwen US move: h6e3 Move number: 131
# Qwen CN move: c5b5 Move number: 132
# Qwen US move: Qh6 Move number: 133
# Qwen CN move: b5c5 Move number: 134
# Qwen US move: Qh1 Move number: 135
# Qwen CN move: c5b6 Move number: 136
# Qwen US move: g7f6 Move number: 137
# Qwen CN move: Kc7 Move number: 138
# Qwen US move: h1e1 Move number: 139
# Qwen CN move: Kd6 Move number: 140
# Qwen US move: Qh4 Move number: 141
# Qwen CN move: d6c6 Move number: 142
# Qwen US move: g4g5 Move number: 143
# Invalid move by Qwen black. Move: g4
# New Move: Kc7
# Qwen CN move: Kc7 Move number: 144
# Qwen US move: h4b4 Move number: 145
# Invalid move by Qwen black. Move: Qxb8
# New Move: Kd8
# Qwen CN move: Kd8 Move number: 146
# Qwen US move: b4b7 Move number: 147
# Invalid move by Qwen black. Move: Qb5
# New Move: Ke8
# Qwen CN move: Ke8 Move number: 148
# Qwen US move: b7e7 Move number: 149
# Game 8 result: 1-0
#
#
# Starting game 9...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Invalid move by Qwen black. Move: dxe5
# New Move: b6
# Qwen CN move: b6 Move number: 6
# Qwen US move: d4e5 Move number: 7
# Qwen CN move: f6g8 Move number: 8
# Qwen US move: Nbd2 Move number: 9
# Qwen CN move: b8c6 Move number: 10
# Invalid move by Qwen white. Move: Nbd2
# New Move: b3
# Qwen US move: b3 Move number: 11
# Qwen CN move: g8e7 Move number: 12
# Qwen US move: d2c4 Move number: 13
# Invalid move by Qwen black. Move: Nbd2
# New Move: g5
# Qwen CN move: g5 Move number: 14
# Qwen US move: c1g5 Move number: 15
# Qwen CN move: f8g7 Move number: 16
# Qwen US move: Bxe7 Move number: 17
# Qwen CN move: d8e7 Move number: 18
# Invalid move by Qwen white. Move: Nbd2
# New Move: Ng5
# Qwen US move: Ng5 Move number: 19
# Qwen CN move: e7g5 Move number: 20
# Qwen US move: Nxb6 Move number: 21
# Qwen CN move: a7b6 Move number: 22
# Qwen US move: Qd2 Move number: 23
# Qwen CN move: g5d2 Move number: 24
# Qwen US move: e1d2 Move number: 25
# Qwen CN move: Rg8 Move number: 26
# Qwen US move: f2f4 Move number: 27
# Qwen CN move: Rh8 Move number: 28
# Qwen US move: Ke1 Move number: 29
# Qwen CN move: c6d8 Move number: 30
# Qwen US move: e1f2 Move number: 31
# Qwen CN move: Rg8 Move number: 32
# Qwen US move: Kf3 Move number: 33
# Qwen CN move: c7c6 Move number: 34
# Qwen US move: f1c4 Move number: 35
# Qwen CN move: d7d6 Move number: 36
# Qwen US move: e5d6 Move number: 37
# Qwen CN move: g7d4 Move number: 38
# Qwen US move: Bxf7+ Move number: 39
# Qwen CN move: Kf8 Move number: 40
# Qwen US move: f7g8 Move number: 41
# Qwen CN move: Bf5 Move number: 42
# Qwen US move: a1d1 Move number: 43
# Qwen CN move: Rxa2 Move number: 44
# Qwen US move: Bd5 Move number: 45
# Invalid move by Qwen black. Move: Bxd4
# New Move: Bg6
# Qwen CN move: Bg6 Move number: 46
# Qwen US move: d1d4 Move number: 47
# Invalid move by Qwen black. Move: Rxd6
# New Move: h6
# Qwen CN move: h6 Move number: 48
# Qwen US move: f4f5 Move number: 49
# Qwen CN move: g6h5 Move number: 50
# Qwen US move: Kf4 Move number: 51
# Qwen CN move: c6d5 Move number: 52
# Qwen US move: Rd3 Move number: 53
# Qwen CN move: d5e4 Move number: 54
# Qwen US move: d3c3 Move number: 55
# Qwen CN move: Nc6 Move number: 56
# Qwen US move: c3c6 Move number: 57
# Qwen CN move: Rxc2 Move number: 58
# Qwen US move: Rc8+ Move number: 59
# Qwen CN move: c2c8 Move number: 60
# Qwen US move: g2g4 Move number: 61
# Qwen CN move: Rc7 Move number: 62
# Invalid move by Qwen white. Move: Kf3
# New Move: Ke3
# Qwen US move: Ke3 Move number: 63
# Qwen CN move: c7c5 Move number: 64
# Qwen US move: Kf2 Move number: 65
# Qwen CN move: h5g4 Move number: 66
# Qwen US move: Kf1 Move number: 67
# Qwen CN move: c5c1 Move number: 68
# Qwen US move: f1g2 Move number: 69
# Invalid move by Qwen black. Move: Kf1
# New Move: Re1
# Qwen CN move: Re1 Move number: 70
# Qwen US move: h1e1 Move number: 71
# Qwen CN move: g4f3 Move number: 72
# Qwen US move: Kg1 Move number: 73
# Qwen CN move: f8f7 Move number: 74
# Qwen US move: Rxe4 Move number: 75
# Qwen CN move: f3e4 Move number: 76
# Qwen US move: g1f2 Move number: 77
# Invalid move by Qwen black. Move: Kf3
# New Move: Kg7
# Qwen CN move: Kg7 Move number: 78
# Qwen US move: d6d7 Move number: 79
# Qwen CN move: Bd5 Move number: 80
# Qwen US move: h4 Move number: 81
# Qwen CN move: d5e4 Move number: 82
# Qwen US move: d7d8q Move number: 83
# Qwen CN move: e4f5 Move number: 84
# Qwen US move: Qd1 Move number: 85
# Qwen CN move: f5g6 Move number: 86
# Qwen US move: Qe1 Move number: 87
# Invalid move by Qwen black. Move: Kf3
# New Move: Kh7
# Qwen CN move: Kh7 Move number: 88
# Qwen US move: e1e7 Move number: 89
# Qwen CN move: Kg8 Move number: 90
# Qwen US move: Qf8+ Move number: 91
# Qwen CN move: g8f8 Move number: 92
# Qwen US move: h4h5 Move number: 93
# Qwen CN move: g6f5 Move number: 94
# Qwen US move: Kg3 Move number: 95
# Qwen CN move: f8e7 Move number: 96
# Qwen US move: Kf4 Move number: 97
# Invalid move by Qwen black. Move: Kf3
# New Move: Kf7
# Qwen CN move: Kf7 Move number: 98
# Qwen US move: f4f5 Move number: 99
# Invalid move by Qwen black. Move: Kf6
# New Move: b5
# Qwen CN move: b5 Move number: 100
# Qwen US move: b3b4 Move number: 101
# Qwen CN move: f7e7 Move number: 102
# Qwen US move: Kg6 Move number: 103
# Qwen CN move: e7d6 Move number: 104
# Qwen US move: Kf5 Move number: 105
# Qwen CN move: d6d5 Move number: 106
# Qwen US move: f5g6 Move number: 107
# Qwen CN move: Ke6 Move number: 108
# Qwen US move: g6h6 Move number: 109
# Qwen CN move: Kf7 Move number: 110
# Qwen US move: Kh7 Move number: 111
# Qwen CN move: f7f6 Move number: 112
# Qwen US move: h7h6 Move number: 113
# Qwen CN move: Kf7 Move number: 114
# Qwen US move: Kg5 Move number: 115
# Qwen CN move: f7e6 Move number: 116
# Qwen US move: h5h6 Move number: 117
# Qwen CN move: e6d5 Move number: 118
# Qwen US move: g5f4 Move number: 119
# Qwen CN move: d5c4 Move number: 120
# Qwen US move: Kg5 Move number: 121
# Qwen CN move: Kd3 Move number: 122
# Qwen US move: g5f5 Move number: 123
# Qwen CN move: Kd4 Move number: 124
# Qwen US move: h6h7 Move number: 125
# Invalid move by Qwen black. Move: Kf4
# New Move: Kd5
# Qwen CN move: Kd5 Move number: 126
# Qwen US move: h7h8q Move number: 127
# Qwen CN move: Kc4 Move number: 128
# Qwen US move: Qg8+ Move number: 129
# Qwen CN move: c4b4 Move number: 130
# Qwen US move: g8g3 Move number: 131
# Qwen CN move: b4c4 Move number: 132
# Qwen US move: Qg8+ Move number: 133
# Qwen CN move: c4c3 Move number: 134
# Invalid move by Qwen white. Move: Qg8+
# New Move: Qg1
# Qwen US move: Qg1 Move number: 135
# Qwen CN move: c3d3 Move number: 136
# Qwen US move: g1c5 Move number: 137
# Invalid move by Qwen black. Move: Kf2
# New Move: b4
# Qwen CN move: b4 Move number: 138
# Qwen US move: c5b4 Move number: 139
# Qwen CN move: d3e3 Move number: 140
# Qwen US move: Qc5+ Move number: 141
# Qwen CN move: e3d3 Move number: 142
# Invalid move by Qwen white. Move: Qg8+
# New Move: Qc4+
# Qwen US move: Qc4+ Move number: 143
# Qwen CN move: d3c4 Move number: 144
# Game 9 result: 1/2-1/2
#
#
# Starting game 10...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: f3e5 Move number: 5
# Qwen CN move: d7d6 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: d6e5 Move number: 8
# Qwen US move: Nd5 Move number: 9
# Invalid move by Qwen black. Move: Nxd6
# New Move: Qe7
# Qwen CN move: Qe7 Move number: 10
# Qwen US move: d5e7 Move number: 11
# Invalid move by Qwen black. Move: Nxe7
# New Move: g6
# Qwen CN move: g6 Move number: 12
# Qwen US move: e7c8 Move number: 13
# Qwen CN move: b8c6 Move number: 14
# Qwen US move: Ne7 Move number: 15
# Qwen CN move: f8e7 Move number: 16
# Qwen US move: Rg1 Move number: 17
# Qwen CN move: e8c8 Move number: 18
# Qwen US move: d2d3 Move number: 19
# Qwen CN move: Rxd3 Move number: 20
# Qwen US move: f1d3 Move number: 21
# Qwen CN move: Bd6 Move number: 22
# Qwen US move: Bh6 Move number: 23
# Qwen CN move: h8d8 Move number: 24
# Qwen US move: d1f3 Move number: 25
# Qwen CN move: Nh5 Move number: 26
# Qwen US move: Qxf7 Move number: 27
# Qwen CN move: c6a5 Move number: 28
# Qwen US move: f7e6 Move number: 29
# Qwen CN move: c8b8 Move number: 30
# Qwen US move: e6h3 Move number: 31
# Qwen CN move: d6b4 Move number: 32
# Qwen US move: Bd2 Move number: 33
# Qwen CN move: Rd4 Move number: 34
# Qwen US move: c2c3 Move number: 35
# Invalid move by Qwen black. Move: Rd1
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 36
# Qwen US move: c3d4 Move number: 37
# Qwen CN move: a3b2 Move number: 38
# Qwen US move: Qc8+ Move number: 39
# Qwen CN move: b8c8 Move number: 40
# Invalid move by Qwen white. Move: Bxe5
# New Move: Bh6
# Qwen US move: Bh6 Move number: 41
# Qwen CN move: b2a1 Move number: 42
# Qwen US move: Bf8 Move number: 43
# Qwen CN move: a1d4 Move number: 44
# Qwen US move: Bg7 Move number: 45
# Qwen CN move: h5g7 Move number: 46
# Qwen US move: g1f1 Move number: 47
# Qwen CN move: Nf5 Move number: 48
# Qwen US move: e4f5 Move number: 49
# Qwen CN move: Bxf2+ Move number: 50
# Qwen US move: Kxf2 Move number: 51
# Qwen CN move: g6f5 Move number: 52
# Qwen US move: d3f5 Move number: 53
# Qwen CN move: Kd8 Move number: 54
# Invalid move by Qwen white. Move: Bf1
# New Move: Rd1+
# Qwen US move: Rd1+ Move number: 55
# Qwen CN move: d8e7 Move number: 56
# Qwen US move: f5b1 Move number: 57
# Qwen CN move: Ke6 Move number: 58
# Qwen US move: Rd2 Move number: 59
# Qwen CN move: a5c4 Move number: 60
# Qwen US move: d2e2 Move number: 61
# Qwen CN move: c4d6 Move number: 62
# Qwen US move: Re3 Move number: 63
# Qwen CN move: c7c5 Move number: 64
# Qwen US move: Rxe5+ Move number: 65
# Invalid move by Qwen black. Move: Rxe5
# New Move: Kf7
# Qwen CN move: Kf7 Move number: 66
# Qwen US move: e5h5 Move number: 67
# Invalid move by Qwen black. Move: Rxe8+ Kf7
# New Move: Kg7
# Qwen CN move: Kg7 Move number: 68
# Qwen US move: h5h7 Move number: 69
# Invalid move by Qwen black. Move: Rxd4
# New Move: Kf6
# Qwen CN move: Kf6 Move number: 70
# Qwen US move: h7c7 Move number: 71
# Qwen CN move: c5c4 Move number: 72
# Qwen US move: Rc8 Move number: 73
# Qwen CN move: d6c8 Move number: 74
# Invalid move by Qwen white. Move: Bxc4
# New Move: Ke2
# Qwen US move: Ke2 Move number: 75
# Qwen CN move: b7b5 Move number: 76
# Qwen US move: Ke1 Move number: 77
# Qwen CN move: c8e7 Move number: 78
# Qwen US move: Kf2 Move number: 79
# Qwen CN move: e7d5 Move number: 80
# Qwen US move: a2a3 Move number: 81
# Qwen CN move: Ke6 Move number: 82
# Qwen US move: h2h4 Move number: 83
# Qwen CN move: Kf6 Move number: 84
# Qwen US move: Kg3 Move number: 85
# Qwen CN move: a7a5 Move number: 86
# Qwen US move: g3f2 Move number: 87
# Qwen CN move: Kg7 Move number: 88
# Qwen US move: Kg1 Move number: 89
# Qwen CN move: d5c3 Move number: 90
# Qwen US move: b1f5 Move number: 91
# Qwen CN move: c3d1 Move number: 92
# Qwen US move: f5b1 Move number: 93
# Qwen CN move: c4c3 Move number: 94
# Qwen US move: Kh2 Move number: 95
# Qwen CN move: Kf7 Move number: 96
# Qwen US move: b1a2 Move number: 97
# Invalid move by Qwen black. Move: Bc4
# New Move: Kf6
# Qwen CN move: Kf6 Move number: 98
# Qwen US move: a2b1 Move number: 99
# Qwen CN move: d1e3 Move number: 100
# Qwen US move: Bc2 Move number: 101
# Qwen CN move: e3c2 Move number: 102
# Qwen US move: Kg1 Move number: 103
# Qwen CN move: c2d4 Move number: 104
# Qwen US move: a3a4 Move number: 105
# Invalid move by Qwen black. Move: Bxd4
# New Move: Kg6
# Qwen CN move: Kg6 Move number: 106
# Qwen US move: a4b5 Move number: 107
# Invalid move by Qwen black. Move: Nh6
# New Move: Kh6
# Qwen CN move: Kh6 Move number: 108
# Qwen US move: g2g4 Move number: 109
# Qwen CN move: Nf3+ Move number: 110
# Qwen US move: Kg2 Move number: 111
# Qwen CN move: c3c2 Move number: 112
# Qwen US move: g2f3 Move number: 113
# Qwen CN move: c2c1q Move number: 114
# Qwen US move: Kf2 Move number: 115
# Qwen CN move: c1f4 Move number: 116
# Qwen US move: Kg2 Move number: 117
# Qwen CN move: Qf8 Move number: 118
# Invalid move by Qwen white. Move: Bc5
# New Move: Kg3
# Qwen US move: Kg3 Move number: 119
# Qwen CN move: f8c5 Move number: 120
# Qwen US move: Kf4 Move number: 121
# Qwen CN move: a5a4 Move number: 122
# Qwen US move: Ke4 Move number: 123
# Qwen CN move: a4a3 Move number: 124
# Qwen US move: g4g5 Move number: 125
# Qwen CN move: Kh7 Move number: 126
# Qwen US move: e4f4 Move number: 127
# Qwen CN move: Qc1+ Move number: 128
# Qwen US move: Kg3 Move number: 129
# Qwen CN move: a3a2 Move number: 130
# Qwen US move: g3g4 Move number: 131
# Qwen CN move: Qg1+ Move number: 132
# Qwen US move: Kf5 Move number: 133
# Qwen CN move: a2a1q Move number: 134
# Qwen US move: h4h5 Move number: 135
# Qwen CN move: a1f1 Move number: 136
# Qwen US move: f5e6 Move number: 137
# Qwen CN move: f1c4 Move number: 138
# Qwen US move: Kf5 Move number: 139
# Qwen CN move: Qc2+ Move number: 140
# Qwen US move: f5f6 Move number: 141
# Qwen CN move: Qc4 Move number: 142
# Qwen US move: g5g6 Move number: 143
# Qwen CN move: Kh8 Move number: 144
# Qwen US move: g7+ Move number: 145
# Qwen CN move: Qxg7+ Move number: 146
# Qwen US move: Kf5 Move number: 147
# Qwen CN move: c4g4 Move number: 148
# Game 10 result: 0-1
#
#
# Starting game 11...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Qwen CN move: d5 Move number: 6
# Qwen US move: e4d5 Move number: 7
# Qwen CN move: Nxd4 Move number: 8
# Qwen US move: Nxe5 Move number: 9
# Qwen CN move: d8d5 Move number: 10
# Qwen US move: Nxf7 Move number: 11
# Qwen CN move: d5f7 Move number: 12
# Qwen US move: c2c3 Move number: 13
# Qwen CN move: Nf6 Move number: 14
# Qwen US move: Be2 Move number: 15
# Qwen CN move: d4e2 Move number: 16
# Qwen US move: d1e2 Move number: 17
# Qwen CN move: g7g6 Move number: 18
# Qwen US move: e1g1 Move number: 19
# Qwen CN move: f8g7 Move number: 20
# Qwen US move: Qxe7+ Move number: 21
# Qwen CN move: Qxe7 Move number: 22
# Qwen US move: Re1 Move number: 23
# Qwen CN move: e7e1 Move number: 24
# Game 11 result: 0-1
#
#
# Starting game 12...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: d7d6 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: d6e5 Move number: 8
# Invalid move by Qwen white. Move: Nbd2
# New Move: d3
# Qwen US move: d3 Move number: 9
# Qwen CN move: b8c6 Move number: 10
# Qwen US move: f1e2 Move number: 11
# Qwen CN move: Nxd5 Move number: 12
# Invalid move by Qwen white. Move: Nxe5
# New Move: Bf1
# Qwen US move: Bf1 Move number: 13
# Qwen CN move: d5c3 Move number: 14
# Qwen US move: Be2 Move number: 15
# Qwen CN move: c3d1 Move number: 16
# Qwen US move: Bh5 Move number: 17
# Qwen CN move: f8b4 Move number: 18
# Qwen US move: e1d1 Move number: 19
# Qwen CN move: Qd6 Move number: 20
# Qwen US move: f2f4 Move number: 21
# Qwen CN move: Be6 Move number: 22
# Qwen US move: Bxf7+ Move number: 23
# Qwen CN move: e6f7 Move number: 24
# Qwen US move: h2h3 Move number: 25
# Qwen CN move: Rg8 Move number: 26
# Qwen US move: Rh2 Move number: 27
# Qwen CN move: a8d8 Move number: 28
# Qwen US move: f4f5 Move number: 29
# Qwen CN move: a7a6 Move number: 30
# Qwen US move: g2g4 Move number: 31
# Qwen CN move: a6a5 Move number: 32
# Qwen US move: Rg2 Move number: 33
# Invalid move by Qwen black. Move: Rg8
# New Move: h5
# Qwen CN move: h5 Move number: 34
# Qwen US move: a2a3 Move number: 35
# Qwen CN move: h5g4 Move number: 36
# Qwen US move: Rxg4 Move number: 37
# Qwen CN move: c6d4 Move number: 38
# Qwen US move: Rxg7 Move number: 39
# Qwen CN move: f7h5 Move number: 40
# Qwen US move: g7g4 Move number: 41
# Invalid move by Qwen black. Move: Rg8
# New Move: Bd2
# Qwen CN move: Bd2 Move number: 42
# Qwen US move: c1d2 Move number: 43
# Qwen CN move: d8d7 Move number: 44
# Qwen US move: Bh6 Move number: 45
# Qwen CN move: d6h6 Move number: 46
# Invalid move by Qwen white. Move: Rg4
# New Move: b4
# Qwen US move: b4 Move number: 47
# Qwen CN move: h5g4 Move number: 48
# Qwen US move: h3g4 Move number: 49
# Invalid move by Qwen black. Move: Rxg7
# New Move: Nxf5
# Qwen CN move: Nxf5 Move number: 50
# Qwen US move: g4g5 Move number: 51
# Qwen CN move: f5e3 Move number: 52
# Qwen US move: Ke2 Move number: 53
# Qwen CN move: h6g5 Move number: 54
# Qwen US move: Rd1 Move number: 55
# Qwen CN move: g5g2 Move number: 56
# Qwen US move: e2e3 Move number: 57
# Qwen CN move: Rh7 Move number: 58
# Qwen US move: d1f1 Move number: 59
# Qwen CN move: Rg3+ Move number: 60
# Qwen US move: Rf3 Move number: 61
# Qwen CN move: g3f3 Move number: 62
# Game 12 result: 0-1
#
#
# Starting game 13...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen US move: b5a4 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Invalid move by Qwen black. Move: Bxc6
# New Move: a5
# Qwen CN move: a5 Move number: 10
# Qwen US move: c6a4 Move number: 11
# Qwen CN move: c7c6 Move number: 12
# Qwen US move: Bxc6 Move number: 13
# Qwen CN move: d7c6 Move number: 14
# Qwen US move: Nxe5 Move number: 15
# Qwen CN move: d8d4 Move number: 16
# Qwen US move: e5f3 Move number: 17
# Invalid move by Qwen black. Move: Nxe5
# New Move: Qxb2
# Qwen CN move: Qxb2 Move number: 18
# Qwen US move: c1b2 Move number: 19
# Qwen CN move: f6e4 Move number: 20
# Invalid move by Qwen white. Move: Nf3
# New Move: O-O
# Qwen US move: O-O Move number: 21
# Qwen CN move: c8h3 Move number: 22
# Qwen US move: b1c3 Move number: 23
# Qwen CN move: Nd6 Move number: 24
# Qwen US move: Ng5 Move number: 25
# Qwen CN move: h3f5 Move number: 26
# Qwen US move: f1e1 Move number: 27
# Qwen CN move: f8e7 Move number: 28
# Qwen US move: Nh3 Move number: 29
# Qwen CN move: e8g8 Move number: 30
# Qwen US move: Ng5 Move number: 31
# Invalid move by Qwen black. Move: Nxf7
# New Move: Rac8
# Qwen CN move: Rac8 Move number: 32
# Qwen US move: e1e7 Move number: 33
# Qwen CN move: Rfe8 Move number: 34
# Qwen US move: Re8+ Move number: 35
# Qwen CN move: c8e8 Move number: 36
# Qwen US move: d1f1 Move number: 37
# Qwen CN move: f5c2 Move number: 38
# Qwen US move: Nh3 Move number: 39
# Qwen CN move: b7b5 Move number: 40
# Qwen US move: Nxe4 Move number: 41
# Qwen CN move: Re6 Move number: 42
# Qwen US move: Nxd6 Move number: 43
# Qwen CN move: e6d6 Move number: 44
# Qwen US move: Ng5 Move number: 45
# Qwen CN move: h7h6 Move number: 46
# Qwen US move: g5f3 Move number: 47
# Qwen CN move: c2e4 Move number: 48
# Qwen US move: a1e1 Move number: 49
# Qwen CN move: e4f3 Move number: 50
# Qwen US move: g2f3 Move number: 51
# Qwen CN move: c6c5 Move number: 52
# Qwen US move: Qg2 Move number: 53
# Qwen CN move: d6g6 Move number: 54
# Qwen US move: Qg4 Move number: 55
# Qwen CN move: h6h5 Move number: 56
# Qwen US move: Qg6 Move number: 57
# Qwen CN move: fxg6 Move number: 58
# Qwen US move: Bd4 Move number: 59
# Qwen CN move: c5c4 Move number: 60
# Invalid move by Qwen white. Move: Bxc2
# New Move: Rf1
# Qwen US move: Rf1 Move number: 61
# Qwen CN move: h5h4 Move number: 62
# Qwen US move: f1c1 Move number: 63
# Qwen CN move: g5 Move number: 64
# Qwen US move: Bb2 Move number: 65
# Qwen CN move: g8f7 Move number: 66
# Qwen US move: b2c3 Move number: 67
# Qwen CN move: h4h3 Move number: 68
# Qwen US move: Bd4 Move number: 69
# Qwen CN move: f7e6 Move number: 70
# Qwen US move: Rxc4 Move number: 71
# Qwen CN move: Kf5 Move number: 72
# Invalid move by Qwen white. Move: Bd4
# New Move: Kf1
# Qwen US move: Kf1 Move number: 73
# Qwen CN move: b5c4 Move number: 74
# Qwen US move: a2a4 Move number: 75
# Qwen CN move: Kf4 Move number: 76
# Invalid move by Qwen white. Move: Bxc2
# New Move: Ke2
# Qwen US move: Ke2 Move number: 77
# Qwen CN move: g7g6 Move number: 78
# Qwen US move: d4c3 Move number: 79
# Qwen CN move: g4 Move number: 80
# Qwen US move: Bh8 Move number: 81
# Qwen CN move: g4f3 Move number: 82
# Qwen US move: e2e1 Move number: 83
# Qwen CN move: f4f5 Move number: 84
# Invalid move by Qwen white. Move: Bxc2
# New Move: d4
# Qwen US move: d4 Move number: 85
# Qwen CN move: c4d3 Move number: 86
# Qwen US move: e1d2 Move number: 87
# Qwen CN move: Kf4 Move number: 88
# Qwen US move: Bc3 Move number: 89
# Qwen CN move: f4e4 Move number: 90
# Qwen US move: c3a5 Move number: 91
# Qwen CN move: g6g5 Move number: 92
# Qwen US move: Bd8 Move number: 93
# Qwen CN move: g5g4 Move number: 94
# Qwen US move: Bf6 Move number: 95
# Invalid move by Qwen black. Move: Bxf3
# New Move: Kf5
# Qwen CN move: Kf5 Move number: 96
# Qwen US move: f6h4 Move number: 97
# Qwen CN move: Ke4 Move number: 98
# Invalid move by Qwen white. Move: Bh4
# New Move: Be7
# Qwen US move: Be7 Move number: 99
# Qwen CN move: g4g3 Move number: 100
# Qwen US move: Bh4 Move number: 101
# Qwen CN move: g3g2 Move number: 102
# Qwen US move: Bf6 Move number: 103
# Qwen CN move: g2g1q Move number: 104
# Qwen US move: d2c3 Move number: 105
# Qwen CN move: Qg8 Move number: 106
# Qwen US move: a4a5 Move number: 107
# Invalid move by Qwen black. Move: Qg8
# New Move: Qg1
# Qwen CN move: Qg1 Move number: 108
# Qwen US move: c3b4 Move number: 109
# Qwen CN move: d3d2 Move number: 110
# Qwen US move: Bh8 Move number: 111
# Qwen CN move: g1b1 Move number: 112
# Qwen US move: Kc5 Move number: 113
# Qwen CN move: b1c2 Move number: 114
# Qwen US move: h8c3 Move number: 115
# Qwen CN move: Qxc3+ Move number: 116
# Qwen US move: c5d6 Move number: 117
# Qwen CN move: Kf5 Move number: 118
# Qwen US move: Ke7 Move number: 119
# Qwen CN move: d2d1q Move number: 120
# Qwen US move: e7e8 Move number: 121
# Invalid move by Qwen black. Move: Kd2
# New Move: Qdc2
# Qwen CN move: Qdc2 Move number: 122
# Qwen US move: e8f7 Move number: 123
# Qwen CN move: c3h8 Move number: 124
# Qwen US move: Ke7 Move number: 125
# Qwen CN move: c2c7 Move number: 126
# Game 13 result: 0-1
#
#
# Starting game 14...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: c2c3 Move number: 5
# Invalid move by Qwen black. Move: d4
# New Move: g5
# Qwen CN move: g5 Move number: 6
# Qwen US move: f3g5 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: Nxe6 Move number: 9
# Qwen CN move: d7e6 Move number: 10
# Qwen US move: Bb5 Move number: 11
# Qwen CN move: f6e4 Move number: 12
# Qwen US move: b5c6 Move number: 13
# Invalid move by Qwen black. Move: Bxc6+
# New Move: bxc6
# Qwen CN move: bxc6 Move number: 14
# Qwen US move: d2d3 Move number: 15
# Qwen CN move: e4f6 Move number: 16
# Qwen US move: Qd2 Move number: 17
# Qwen CN move: e6e5 Move number: 18
# Qwen US move: Qe3 Move number: 19
# Qwen CN move: h8g8 Move number: 20
# Qwen US move: b1d2 Move number: 21
# Invalid move by Qwen black. Move: Qg4
# New Move: Bg7
# Qwen CN move: Bg7 Move number: 22
# Qwen US move: e1g1 Move number: 23
# Qwen CN move: Qd4 Move number: 24
# Qwen US move: Qe1 Move number: 25
# Qwen CN move: d4d3 Move number: 26
# Qwen US move: f2f4 Move number: 27
# Qwen CN move: g7h6 Move number: 28
# Qwen US move: Ne4 Move number: 29
# Qwen CN move: d3e4 Move number: 30
# Qwen US move: Qe2 Move number: 31
# Qwen CN move: Rg5 Move number: 32
# Qwen US move: Qa6 Move number: 33
# Qwen CN move: e4g2 Move number: 34
# Game 14 result: 0-1
#
#
# Starting game 15...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Qwen CN move: c5d4 Move number: 6
# Qwen US move: f3d4 Move number: 7
# Qwen CN move: e7e6 Move number: 8
# Qwen US move: Nxc6 Move number: 9
# Qwen CN move: b7c6 Move number: 10
# Qwen US move: Qd2 Move number: 11
# Qwen CN move: d7d5 Move number: 12
# Qwen US move: Qxd5 Move number: 13
# Invalid move by Qwen black. Move: Qd2
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 14
# Qwen US move: d5d8 Move number: 15
# Qwen CN move: Kxd8 Move number: 16
# Qwen US move: Bd3 Move number: 17
# Qwen CN move: a3c5 Move number: 18
# Qwen US move: b1c3 Move number: 19
# Qwen CN move: g8f6 Move number: 20
# Invalid move by Qwen white. Move: Nbd5
# New Move: Na4
# Qwen US move: Na4 Move number: 21
# Qwen CN move: c5b4 Move number: 22
# Qwen US move: Nc3 Move number: 23
# Qwen CN move: e6e5 Move number: 24
# Qwen US move: Be2 Move number: 25
# Qwen CN move: f6e4 Move number: 26
# Qwen US move: a2a3 Move number: 27
# Invalid move by Qwen black. Move: Nh3
# New Move: Bd7
# Qwen CN move: Bd7 Move number: 28
# Qwen US move: a3b4 Move number: 29
# Invalid move by Qwen black. Move: Nh3
# New Move: Rc8
# Qwen CN move: Rc8 Move number: 30
# Qwen US move: c3e4 Move number: 31
# Qwen CN move: Rg8 Move number: 32
# Qwen US move: Bd2 Move number: 33
# Qwen CN move: d7f5 Move number: 34
# Qwen US move: e4c5 Move number: 35
# Qwen CN move: f5c2 Move number: 36
# Qwen US move: Bd1 Move number: 37
# Qwen CN move: c2d1 Move number: 38
# Qwen US move: Rxa7 Move number: 39
# Qwen CN move: Rc7 Move number: 40
# Qwen US move: Ra8+ Move number: 41
# Qwen CN move: c7c8 Move number: 42
# Qwen US move: Rxc8+ Move number: 43
# Qwen CN move: d8c8 Move number: 44
# Qwen US move: e1d1 Move number: 45
# Qwen CN move: c8c7 Move number: 46
# Qwen US move: d1c2 Move number: 47
# Qwen CN move: g8a8 Move number: 48
# Qwen US move: h1e1 Move number: 49
# Qwen CN move: f7f6 Move number: 50
# Qwen US move: Na4 Move number: 51
# Qwen CN move: a8a4 Move number: 52
# Qwen US move: Rxe5 Move number: 53
# Qwen CN move: f6e5 Move number: 54
# Qwen US move: Bh6 Move number: 55
# Invalid move by Qwen black. Move: Bh5
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 56
# Qwen US move: h6g7 Move number: 57
# Invalid move by Qwen black. Move: Kd2
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 58
# Qwen US move: g7e5 Move number: 59
# Invalid move by Qwen black. Move:  Kb1
# New Move: Kf7
# Qwen CN move: Kf7 Move number: 60
# Qwen US move: e5c3 Move number: 61
# Qwen CN move: Kf8 Move number: 62
# Qwen US move: Bh8 Move number: 63
# Qwen CN move: a4b4 Move number: 64
# Qwen US move: g2g3 Move number: 65
# Qwen CN move: f8f7 Move number: 66
# Invalid move by Qwen white. Move: Bh6
# New Move: Bd4
# Qwen US move: Bd4 Move number: 67
# Qwen CN move: b4d4 Move number: 68
# Qwen US move: Kc3 Move number: 69
# Qwen CN move: d4d1 Move number: 70
# Qwen US move: Kc4 Move number: 71
# Qwen CN move: f7e6 Move number: 72
# Qwen US move: b2b4 Move number: 73
# Qwen CN move: Rd2 Move number: 74
# Qwen US move: b4b5 Move number: 75
# Qwen CN move: Rd1 Move number: 76
# Qwen US move: Kc3 Move number: 77
# Qwen CN move: c6b5 Move number: 78
# Qwen US move: c3b4 Move number: 79
# Qwen CN move: Rd2 Move number: 80
# Qwen US move: Kc5 Move number: 81
# Qwen CN move: d2b2 Move number: 82
# Qwen US move: f2f4 Move number: 83
# Qwen CN move: e6f5 Move number: 84
# Qwen US move: c5b6 Move number: 85
# Qwen CN move: b2h2 Move number: 86
# Qwen US move: g4+ Move number: 87
# Qwen CN move: Kg6 Move number: 88
# Qwen US move: b6b5 Move number: 89
# Qwen CN move: Rh6 Move number: 90
# Qwen US move: b5c5 Move number: 91
# Qwen CN move: Rh5+ Move number: 92
# Qwen US move: Kd6 Move number: 93
# Qwen CN move: Rh3 Move number: 94
# Qwen US move: g5 Move number: 95
# Qwen CN move: h3e3 Move number: 96
# Qwen US move: d6d5 Move number: 97
# Qwen CN move: g6f5 Move number: 98
# Qwen US move: Kc6 Move number: 99
# Qwen CN move: f5f4 Move number: 100
# Qwen US move: g5g6 Move number: 101
# Qwen CN move: Kf5 Move number: 102
# Qwen US move: g6h7 Move number: 103
# Qwen CN move: Kf6 Move number: 104
# Qwen US move: Kd5 Move number: 105
# Qwen CN move: e3e8 Move number: 106
# Qwen US move: Kd6 Move number: 107
# Qwen CN move: e8h8 Move number: 108
# Qwen US move: d6d5 Move number: 109
# Invalid move by Qwen black. Move: Kd6
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 110
# Qwen US move: d5c5 Move number: 111
# Qwen CN move: e7d8 Move number: 112
# Qwen US move: Kd6 Move number: 113
# Qwen CN move: h8h7 Move number: 114
# Qwen US move: Kc6 Move number: 115
# Qwen CN move: h7d7 Move number: 116
# Qwen US move: c6c5 Move number: 117
# Invalid move by Qwen black. Move: Kd6
# New Move: Kc7
# Qwen CN move: Kc7 Move number: 118
# Qwen US move: c5b5 Move number: 119
# Qwen CN move: Rd2 Move number: 120
# Qwen US move: Kc4 Move number: 121
# Qwen CN move: c7b7 Move number: 122
# Qwen US move: c4c5 Move number: 123
# Qwen CN move: d2d8 Move number: 124
# Qwen US move: Kb5 Move number: 125
# Qwen CN move: d8c8 Move number: 126
# Qwen US move: Kb4 Move number: 127
# Qwen CN move: Rc1 Move number: 128
# Qwen US move: Kb5 Move number: 129
# Qwen CN move: b7a7 Move number: 130
# Qwen US move: Kb4 Move number: 131
# Qwen CN move: c1c2 Move number: 132
# Qwen US move: b4a3 Move number: 133
# Qwen CN move: a7a6 Move number: 134
# Qwen US move: a3b3 Move number: 135
# Qwen CN move: c2c7 Move number: 136
# Qwen US move: b3a2 Move number: 137
# Qwen CN move: c7b7 Move number: 138
# Invalid move by Qwen white. Move:  Kb4
# New Move: Ka3
# Qwen US move: Ka3 Move number: 139
# Qwen CN move: a6a5 Move number: 140
# Invalid move by Qwen white. Move: Ka3
# New Move: Ka2
# Qwen US move: Ka2 Move number: 141
# Qwen CN move: a5a4 Move number: 142
# Invalid move by Qwen white. Move: Bh8
# New Move: Ka1
# Qwen US move: Ka1 Move number: 143
# Qwen CN move: a4b3 Move number: 144
# Invalid move by Qwen white. Move: Kb2
# New Move: Kb1
# Qwen US move: Kb1 Move number: 145
# Qwen CN move: b7c7 Move number: 146
# Invalid move by Qwen white. Move: Bh5
# New Move: Ka1
# Qwen US move: Ka1 Move number: 147
# Qwen CN move: c7c1 Move number: 148
# Game 15 result: 0-1
#
#
# Starting game 16...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: e5 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: g1f3 Move number: 5
# Qwen CN move: Nxe5 Move number: 6
# Qwen US move: f3e5 Move number: 7
# Qwen CN move: Nf6 Move number: 8
# Qwen US move: Nc4 Move number: 9
# Qwen CN move: d8c7 Move number: 10
# Qwen US move: c4e3 Move number: 11
# Invalid move by Qwen black. Move: Nf3
# New Move: e6
# Qwen CN move: e6 Move number: 12
# Qwen US move: e3g4 Move number: 13
# Qwen CN move: f6g8 Move number: 14
# Invalid move by Qwen white. Move: Nxe6
# New Move: b3
# Qwen US move: b3 Move number: 15
# Qwen CN move: a7a6 Move number: 16
# ...
# Qwen US move: Kg2 Move number: 57
# Qwen CN move: d6e5 Move number: 58
# Qwen US move: Kf3 Move number: 59
# Qwen CN move: b7a7 Move number: 60
# Qwen US move: b2b4 Move number: 61
# Qwen CN move: Rd1 Move number: 62
# Qwen US move: h2h4 Move number: 63
# Qwen CN move: Rf1+ Move number: 64
# Qwen US move: Kg4 Move number: 65
# Qwen CN move: f6f5 Move number: 66
# Qwen US move: g4h5 Move number: 67
# Invalid move by Qwen black. Move: Rf1+
# New Move: c5
# Qwen CN move: c5 Move number: 68
# Qwen US move: b4b5 Move number: 69
# Qwen CN move: e5f4 Move number: 70
# Qwen US move: b6+ Move number: 71
# Qwen CN move: a7b8 Move number: 72
# Qwen US move: b7 Move number: 73
# Qwen CN move: g7g6 Move number: 74
# Game 96 result: 0-1
#
#
# Starting game 97...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: Nf3+ Move number: 8
# Qwen US move: Qxf3 Move number: 9
# Qwen CN move: d8f6 Move number: 10
# Qwen US move: f3e3 Move number: 11
# Qwen CN move: g7g6 Move number: 12
# Qwen US move: b1c3 Move number: 13
# Qwen CN move: f8h6 Move number: 14
# Qwen US move: Qg5 Move number: 15
# Invalid move by Qwen black. Move: Qxf7+
# New Move: Qxd4
# Qwen CN move: Qxd4 Move number: 16
# Qwen US move: g5g3 Move number: 17
# Qwen CN move: d7d6 Move number: 18
# Qwen US move: Qg5 Move number: 19
# Qwen CN move: h6g5 Move number: 20
# Qwen US move: Nd5 Move number: 21
# Qwen CN move: d4e4 Move number: 22
# Qwen US move: d5e3 Move number: 23
# Qwen CN move: Nf6 Move number: 24
# Qwen US move: f1c4 Move number: 25
# Qwen CN move: Bd7 Move number: 26
# Qwen US move: Bxf7+ Move number: 27
# Qwen CN move: e8f7 Move number: 28
# Qwen US move: h2h4 Move number: 29
# Qwen CN move: Be6 Move number: 30
# Qwen US move: Rh3 Move number: 31
# Qwen CN move: g5h4 Move number: 32
# Qwen US move: g2g4 Move number: 33
# Qwen CN move: h4f2 Move number: 34
# Qwen US move: e1f2 Move number: 35
# Qwen CN move: h8f8 Move number: 36
# Qwen US move: Rxh7+ Move number: 37
# Qwen CN move: Kg8 Move number: 38
# Qwen US move: h7c7 Move number: 39
# Qwen CN move: Rfc8 Move number: 40
# Qwen US move: c7e7 Move number: 41
# Invalid move by Qwen black. Move: Rxe8+ Qf7 Rxg7#
# New Move: Qg2+
# Qwen CN move: Qg2+ Move number: 42
# Qwen US move: f2g2 Move number: 43
# Qwen CN move: e6d7 Move number: 44
# Qwen US move: Re8+ Move number: 45
# Qwen CN move: c8e8 Move number: 46
# Qwen US move: Nf5 Move number: 47
# Qwen CN move: g6f5 Move number: 48
# Qwen US move: g4g5 Move number: 49
# Qwen CN move: Re1 Move number: 50
# Qwen US move: g5f6 Move number: 51
# Qwen CN move: Re5 Move number: 52
# Qwen US move: Kh3 Move number: 53
# Qwen CN move: f5f4 Move number: 54
# Qwen US move: h3g2 Move number: 55
# Qwen CN move: Rf5 Move number: 56
# Qwen US move: Kh1 Move number: 57
# Qwen CN move: g8f7 Move number: 58
# Qwen US move: h1g1 Move number: 59
# Qwen CN move: a8g8 Move number: 60
# Qwen US move: g1f2 Move number: 61
# Qwen CN move: d7c6 Move number: 62
# Qwen US move: Bxf4 Move number: 63
# Invalid move by Qwen black. Move: Rg8
# New Move: b5
# Qwen CN move: b5 Move number: 64
# Qwen US move: f2e3 Move number: 65
# Qwen CN move: g8e8 Move number: 66
# Qwen US move: Kd2 Move number: 67
# Qwen CN move: f5f4 Move number: 68
# Qwen US move: Kd3 Move number: 69
# Qwen CN move: f4f3 Move number: 70
# Qwen US move: d3d2 Move number: 71
# Qwen CN move: Rf1 Move number: 72
# Qwen US move: a1f1 Move number: 73
# Invalid move by Qwen black. Move: Rf1+
# New Move: Bb7
# Qwen CN move: Bb7 Move number: 74
# Qwen US move: b2b3 Move number: 75
# Qwen CN move: b7e4 Move number: 76
# Invalid move by Qwen white. Move: Rf1
# New Move: c4
# Qwen US move: c4 Move number: 77
# Qwen CN move: b5c4 Move number: 78
# Qwen US move: d2c3 Move number: 79
# Qwen CN move: Rf8 Move number: 80
# Qwen US move: Rd1 Move number: 81
# Qwen CN move: d6d5 Move number: 82
# Qwen US move: b3c4 Move number: 83
# Qwen CN move: f8c8 Move number: 84
# Qwen US move: Rxd5 Move number: 85
# Qwen CN move: e4d5 Move number: 86
# Qwen US move: Kd3 Move number: 87
# Qwen CN move: Rc6 Move number: 88
# Qwen US move: Kc2 Move number: 89
# Qwen CN move: c6c4 Move number: 90
# Qwen US move: Kd1 Move number: 91
# Qwen CN move: c4a4 Move number: 92
# Qwen US move: d1d2 Move number: 93
# Qwen CN move: a4a3 Move number: 94
# Qwen US move: d2c2 Move number: 95
# Qwen CN move: f7f6 Move number: 96
# Qwen US move: c2d2 Move number: 97
# Qwen CN move: d5e6 Move number: 98
# Qwen US move: Kc1 Move number: 99
# Qwen CN move: a3a2 Move number: 100
# Qwen US move: Kd1 Move number: 101
# Qwen CN move: e6f5 Move number: 102
# Qwen US move: Ke1 Move number: 103
# Qwen CN move: Kf7 Move number: 104
# Qwen US move: Kd1 Move number: 105
# Qwen CN move: f7f6 Move number: 106
# Qwen US move: Ke1 Move number: 107
# Qwen CN move: a7a5 Move number: 108
# Qwen US move: Kf1 Move number: 109
# Invalid move by Qwen black. Move: Kf2
# New Move: Rh2
# Qwen CN move: Rh2 Move number: 110
# Qwen US move: f1g1 Move number: 111
# Qwen CN move: h2b2 Move number: 112
# Qwen US move: Kf1 Move number: 113
# Qwen CN move: a5a4 Move number: 114
# Qwen US move: Kg1 Move number: 115
# Qwen CN move: a4a3 Move number: 116
# Qwen US move: g1h1 Move number: 117
# Qwen CN move: Kg6 Move number: 118
# Qwen US move: h1g1 Move number: 119
# Invalid move by Qwen black. Move: Kf2
# New Move: Rb4
# Qwen CN move: Rb4 Move number: 120
# Qwen US move: g1f2 Move number: 121
# Qwen CN move: a3a2 Move number: 122
# Qwen US move: Kg3 Move number: 123
# Qwen CN move: a2a1q Move number: 124
# Qwen US move: Kf2 Move number: 125
# Qwen CN move: a1a7 Move number: 126
# Qwen US move: f2f3 Move number: 127
# Qwen CN move: Qa1 Move number: 128
# Qwen US move: f3f2 Move number: 129
# Invalid move by Qwen black. Move: Kg1
# New Move: Qc3
# Qwen CN move: Qc3 Move number: 130
# Qwen US move: f2f1 Move number: 131
# Qwen CN move: c3d2 Move number: 132
# Qwen US move: Kg1 Move number: 133
# Qwen CN move: b4b1 Move number: 134
# Game 97 result: 0-1
#
#
# Starting game 98...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: Nge7 Move number: 6
# Qwen US move: Bxc6 Move number: 7
# Qwen CN move: d7c6 Move number: 8
# Qwen US move: b1c3 Move number: 9
# Qwen CN move: Be6 Move number: 10
# Qwen US move: Ng5 Move number: 11
# Qwen CN move: e6c8 Move number: 12
# Qwen US move: g5f3 Move number: 13
# Qwen CN move: e7g6 Move number: 14
# Qwen US move: d2d4 Move number: 15
# Qwen CN move: e5d4 Move number: 16
# Qwen US move: Nh4 Move number: 17
# Qwen CN move: Nxe7 Move number: 18
# Qwen US move: c3e2 Move number: 19
# Qwen CN move: d3 Move number: 20
# Qwen US move: c2d3 Move number: 21
# Invalid move by Qwen black. Move: Nxe7
# New Move: b6
# Qwen CN move: b6 Move number: 22
# Qwen US move: e1g1 Move number: 23
# Qwen CN move: d8d7 Move number: 24
# Invalid move by Qwen white. Move: Nbd2
# New Move: e5
# Qwen US move: e5 Move number: 25
# Qwen CN move: c8b7 Move number: 26
# Qwen US move: d3d4 Move number: 27
# Qwen CN move: Nxd5 Move number: 28
# Invalid move by Qwen white. Move: Nh4
# New Move: e6
# Qwen US move: e6 Move number: 29
# Qwen CN move: f7e6 Move number: 30
# Qwen US move: h4f3 Move number: 31
# Invalid move by Qwen black. Move: Nxd5
# New Move: Kf7
# Qwen CN move: Kf7 Move number: 32
# Qwen US move: f3e5 Move number: 33
# Invalid move by Qwen black. Move: Nxe6
# New Move: Kg8
# Qwen CN move: Kg8 Move number: 34
# Qwen US move: e5d7 Move number: 35
# Invalid move by Qwen black. Move: Nc4
# New Move: a6
# Qwen CN move: a6 Move number: 36
# Qwen US move: d7f8 Move number: 37
# Qwen CN move: a8f8 Move number: 38
# Qwen US move: Nf4 Move number: 39
# Qwen CN move: d5f4 Move number: 40
# Qwen US move: Qe2 Move number: 41
# Qwen CN move: f4e2 Move number: 42
# Qwen US move: g1h1 Move number: 43
# Qwen CN move: Rxf2 Move number: 44
# Qwen US move: f1f2 Move number: 45
# Qwen CN move: Ng1 Move number: 46
# Qwen US move: Rf8+ Move number: 47
# Qwen CN move: g8f8 Move number: 48
# Qwen US move: h1g1 Move number: 49
# Invalid move by Qwen black. Move: Bg7
# New Move: c5
# Qwen CN move: c5 Move number: 50
# Qwen US move: d4c5 Move number: 51
# Qwen CN move: b6c5 Move number: 52
# Qwen US move: Bh6 Move number: 53
# Qwen CN move: g7h6 Move number: 54
# Qwen US move: Rf1+ Move number: 55
# Qwen CN move: f8e7 Move number: 56
# Qwen US move: f1f4 Move number: 57
# Invalid move by Qwen black. Move: Rf5
# New Move: e5
# Qwen CN move: e5 Move number: 58
# Qwen US move: f4f5 Move number: 59
# Qwen CN move: e7e6 Move number: 60
# Qwen US move: Rf2 Move number: 61
# Qwen CN move: h8g8 Move number: 62
# Qwen US move: Rf5 Move number: 63
# Qwen CN move: g8g2 Move number: 64
# Qwen US move: g1f1 Move number: 65
# Qwen CN move: Rg1+ Move number: 66
# Qwen US move: f1g1 Move number: 67
# Qwen CN move: Bc8 Move number: 68
# Qwen US move: Rf8 Move number: 69
# Qwen CN move: c8b7 Move number: 70
# Qwen US move: g1f2 Move number: 71
# Invalid move by Qwen black. Move: Bh6
# New Move: Bd5
# Qwen CN move: Bd5 Move number: 72
# Qwen US move: a2a3 Move number: 73
# Qwen CN move: Be4 Move number: 74
# Qwen US move: Rf5 Move number: 75
# Qwen CN move: e4f5 Move number: 76
# Qwen US move: f2g3 Move number: 77
# Qwen CN move: e6d6 Move number: 78
# Qwen US move: Kf2 Move number: 79
# Qwen CN move: f5e6 Move number: 80
# Qwen US move: Kg3 Move number: 81
# Qwen CN move: Bf5 Move number: 82
# Qwen US move: Kg2 Move number: 83
# Qwen CN move: h6h5 Move number: 84
# Qwen US move: Kf3 Move number: 85
# Qwen CN move: h5h4 Move number: 86
# Qwen US move: f3e2 Move number: 87
# Qwen CN move: a6a5 Move number: 88
# Qwen US move: e2e3 Move number: 89
# Qwen CN move: c5c4 Move number: 90
# Qwen US move: e3d2 Move number: 91
# Qwen CN move: f5d7 Move number: 92
# Qwen US move: Ke3 Move number: 93
# Qwen CN move: d7g4 Move number: 94
# Qwen US move: Ke4 Move number: 95
# Qwen CN move: g4e6 Move number: 96
# Qwen US move: Ke3 Move number: 97
# Qwen CN move: Bf5 Move number: 98
# Qwen US move: Ke2 Move number: 99
# Qwen CN move: d6e6 Move number: 100
# Qwen US move: Ke3 Move number: 101
# Qwen CN move: h7h6 Move number: 102
# Qwen US move: Ke2 Move number: 103
# Invalid move by Qwen black. Move: Kf3
# New Move: c5
# Qwen CN move: c5 Move number: 104
# Qwen US move: e2f2 Move number: 105
# Qwen CN move: f5g4 Move number: 106
# Qwen US move: Kf1 Move number: 107
# Qwen CN move: e5e4 Move number: 108
# Qwen US move: Kg2 Move number: 109
# Qwen CN move: a5a4 Move number: 110
# Qwen US move: g2f2 Move number: 111
# Invalid move by Qwen black. Move: Ke3
# New Move: Kf6
# Qwen CN move: Kf6 Move number: 112
# Qwen US move: f2e3 Move number: 113
# Invalid move by Qwen black. Move: Bh6
# New Move: Kg6
# Qwen CN move: Kg6 Move number: 114
# Qwen US move: e3e4 Move number: 115
# Qwen CN move: Kf7 Move number: 116
# Qwen US move: Ke5 Move number: 117
# Qwen CN move: g4f3 Move number: 118
# Qwen US move: e5d6 Move number: 119
# Qwen CN move: f3d1 Move number: 120
# Qwen US move: Kc7 Move number: 121
# Qwen CN move: f7e6 Move number: 122
# Invalid move by Qwen white. Move: Kf1
# New Move: Kc8
# Qwen US move: Kc8 Move number: 123
# Qwen CN move: d1h5 Move number: 124
# Invalid move by Qwen white. Move: Kf3
# New Move: b3
# Qwen US move: b3 Move number: 125
# Qwen CN move: c4b3 Move number: 126
# Qwen US move: c8b7 Move number: 127
# Qwen CN move: Kf5 Move number: 128
# Qwen US move: Kc7 Move number: 129
# Qwen CN move: b3b2 Move number: 130
# Qwen US move: c7b6 Move number: 131
# Qwen CN move: b2b1q Move number: 132
# Qwen US move: Kxc5 Move number: 133
# Qwen CN move: f5e4 Move number: 134
# Qwen US move: Kc6 Move number: 135
# Qwen CN move: Bf7 Move number: 136
# Qwen US move: Kd7 Move number: 137
# Qwen CN move: b1b6 Move number: 138
# Qwen US move: Kc8 Move number: 139
# Qwen CN move: f7e6 Move number: 140
# Game 98 result: 0-1
#
#
# Starting game 99...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen US move: Bxc6 Move number: 7
# Qwen CN move: d7c6 Move number: 8
# Invalid move by Qwen white. Move: Nge2
# New Move: g4
# Qwen US move: g4 Move number: 9
# Qwen CN move: c8g4 Move number: 10
# Qwen US move: h1g1 Move number: 11
# Qwen CN move: Nf6 Move number: 12
# Qwen US move: Ng5 Move number: 13
# Qwen CN move: g4d1 Move number: 14
# Qwen US move: e1d1 Move number: 15
# Qwen CN move: h7h6 Move number: 16
# Qwen US move: Nh7 Move number: 17
# Qwen CN move: h8h7 Move number: 18
# Qwen US move: Rg7 Move number: 19
# Invalid move by Qwen black. Move: Rxh6
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 20
# Qwen US move: g7g1 Move number: 21
# Qwen CN move: Bd6 Move number: 22
# Qwen US move: Rg8 Move number: 23
# Qwen CN move: d8g8 Move number: 24
# Qwen US move: d2d3 Move number: 25
# Qwen CN move: d7d8 Move number: 26
# Qwen US move: Ke2 Move number: 27
# Qwen CN move: g8g4 Move number: 28
# Qwen US move: Ke1 Move number: 29
# Qwen CN move: Nxe4 Move number: 30
# Qwen US move: Bxh6 Move number: 31
# Qwen CN move: g4g1 Move number: 32
# Qwen US move: Ke2 Move number: 33
# Qwen CN move: g1f2 Move number: 34
# Qwen US move: e2d1 Move number: 35
# Qwen CN move: f2f1 Move number: 36
# Game 99 result: 0-1
#
#
# Starting game 100...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: Ng5 Move number: 5
# Qwen CN move: d7d5 Move number: 6
# Invalid move by Qwen white. Move: Nxe5
# New Move: Bb5+
# Qwen US move: Bb5+ Move number: 7
# Qwen CN move: c7c6 Move number: 8
# Qwen US move: Bxc6+ Move number: 9
# Qwen CN move: b8c6 Move number: 10
# Qwen US move: Nf3 Move number: 11
# Qwen CN move: d5e4 Move number: 12
# Qwen US move: f3e5 Move number: 13
# Invalid move by Qwen black. Move: Nc4
# New Move: g5
# Qwen CN move: g5 Move number: 14
# Qwen US move: e5c6 Move number: 15
# Qwen CN move: b7c6 Move number: 16
# Qwen US move: Nc3 Move number: 17
# Qwen CN move: c8g4 Move number: 18
# Qwen US move: Nd5 Move number: 19
# Qwen CN move: d8d5 Move number: 20
# Qwen US move: d2d3 Move number: 21
# Qwen CN move: Qe5 Move number: 22
# Qwen US move: d3d4 Move number: 23
# Qwen CN move: Be7 Move number: 24
# Qwen US move: Qd2 Move number: 25
# Qwen CN move: e5b5 Move number: 26
# Qwen US move: d2e3 Move number: 27
# Invalid move by Qwen black. Move: Nxe4
# New Move: Bh3
# Qwen CN move: Bh3 Move number: 28
# Qwen US move: e3h3 Move number: 29
# Qwen CN move: h8g8 Move number: 30
# Qwen US move: Qc8+ Move number: 31
# Qwen CN move: a8c8 Move number: 32
# Qwen US move: Rg1 Move number: 33
# Qwen CN move: b5b4 Move number: 34
# Qwen US move: c2c3 Move number: 35
# Qwen CN move: Rg6 Move number: 36
# Qwen US move: c3b4 Move number: 37
# Qwen CN move: Rd8 Move number: 38
# Qwen US move: Bd2 Move number: 39
# Qwen CN move: f6d5 Move number: 40
# Qwen US move: e1e2 Move number: 41
# Invalid move by Qwen black. Move: Nh4
# New Move: Bf8
# Qwen CN move: Bf8 Move number: 42
# Qwen US move: g1h1 Move number: 43
# Invalid move by Qwen black. Move: Rxd8
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 44
# Qwen US move: h2h4 Move number: 45
# Invalid move by Qwen black. Move: Rb1
# New Move: Rc8
# Qwen CN move: Rc8 Move number: 46
# Qwen US move: h4g5 Move number: 47
# Qwen CN move: Bh6 Move number: 48
# Qwen US move: Rh5 Move number: 49
# Qwen CN move: h6g7 Move number: 50
# Qwen US move: h5h7 Move number: 51
# Qwen CN move: c8f8 Move number: 52
# Qwen US move: Rh8 Move number: 53
# Qwen CN move: f8h8 Move number: 54
# Invalid move by Qwen white. Move: Rh8#
# New Move: g4
# Qwen US move: g4 Move number: 55
# Qwen CN move: g7d4 Move number: 56
# Qwen US move: a1c1 Move number: 57
# Qwen CN move: Rxh7 Move number: 58
# Qwen US move: Rc5 Move number: 59
# Qwen CN move: d4c5 Move number: 60
# Qwen US move: b4c5 Move number: 61
# Qwen CN move: h7h1 Move number: 62
# Qwen US move: Bf4 Move number: 63
# Qwen CN move: d5f4 Move number: 64
# Qwen US move: Ke3 Move number: 65
# Qwen CN move: Rh8 Move number: 66
# Qwen US move: Kd2 Move number: 67
# Qwen CN move: g6e6 Move number: 68
# Qwen US move: Ke3 Move number: 69
# Qwen CN move: h8h3 Move number: 70
# Qwen US move: e3d4 Move number: 71
# Qwen CN move: h3d3 Move number: 72
# Qwen US move: d4c4 Move number: 73
# Qwen CN move: e4e3 Move number: 74
# Qwen US move: c4b4 Move number: 75
# Qwen CN move: e3e2 Move number: 76
# Qwen US move: Kc4 Move number: 77
# Qwen CN move: e6e4 Move number: 78
# Game 100 result: 0-1

# %%
board.result()
# Out:
# '0-1'

# %%
results = []

# %%
results.append({
            "Qwen US Wins": qwen_us_wins,
            "Qwen CN Wins": qwen_cn_wins,
            "Draws": draws,
        })

print(results)
# Out:
# [{'Qwen US Wins': 8, 'Qwen CN Wins': 84, 'Draws': 8}]

# %%
df = pd.DataFrame(results)
df.to_csv(f"LLM_{QWEN_US_AI}_vs_LLM_{QWEN_CN_AI}.csv", index=False)
print(f"Results saved to LLM_{QWEN_US_AI}_vs_LLM_{QWEN_CN_AI}.csv")
# Out:
# Results saved to LLM_30_vs_LLM_70.csv
