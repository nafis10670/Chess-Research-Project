# %% [markdown]
# # LLM_1 - **80%** vs. LLM_2 - **80%**

# %%
import chess
from stockfish import Stockfish
from ollama import chat
from ollama import ChatResponse
import json
import random
import pandas as pd
import asyncio

# %%
# STOCKFISH_PATH = r"C:\Users\nafis\Downloads\stockfish-windows-x86-64-avx2\stockfish\stockfish-windows-x86-64-avx2.exe"

STOCKFISH_ELO = 3500
NUM_GAMES = 100
MOVE_LIMIT = 300
RANDOM_START = 0
QWEN_US_AI = 80
QWEN_CN_AI = 80

# %%
stockfish = Stockfish()
stockfish.update_engine_parameters({"Threads": 4, "Hash": 4096})

# %%
qwen_cn_wins = 0
qwen_us_wins = 0
draws = 0

# %%
def valid_move_to_string(board):
    legal_moves = [
        board.san(move) for move in board.legal_moves]
    
    if not legal_moves:
        return "No legal moves."
    else:
        return ", ".join(legal_moves)

# %%
def get_move_history(board: chess.Board) -> str:
    """Return a formatted move history string like '1. e4 e5 2. Nf3 d5'."""
    temp_board = chess.Board()  # Start from the initial position.
    move_history = []
    
    # Iterate over the moves in the board's move stack.
    for i, move in enumerate(board.move_stack):
        # Get the SAN for the move in the current temporary board.
        move_san = temp_board.san(move)
        # Push the move so that the board state is updated.
        temp_board.push(move)
        
        # For white moves (even index), start a new entry with move number.
        if i % 2 == 0:
            move_history.append(f"{i//2 + 1}. {move_san}")
        # For black moves, append to the last white move entry.
        else:
            move_history[-1] += f" {move_san}"
    
    # Join all entries with a space.
    return " ".join(move_history)

# %%
async def get_move_with_timeout(stockfish, timeout=15):
    """
    Run stockfish.get_best_move() in a separate thread and wait for a maximum of `timeout` seconds.
    If the call exceeds the timeout, return None.
    """
    try:
        # Use asyncio.to_thread to run the blocking call in a separate thread.
        move = await asyncio.wait_for(asyncio.to_thread(stockfish.get_best_move), timeout)
        return move
    except asyncio.TimeoutError:
        # move = stockfish.get_best_move_time(1000)
        print(f"Timeout: stockfish.get_best_move() took more than 15 seconds.")
        return None

# %%
def get_qwen_move(board:chess.Board, fen:str, temp=0.0):
    valid_moves = valid_move_to_string(board)

    move_history = get_move_history(board)
    
    response: ChatResponse = chat(model='qwen:32b', messages=[
        {
            'role': 'system',
            'content': 'You are a grand master chess player.'
        },
        {
            'role': 'user',
            'content': f"""You are playing chess and it is your turn. This is the current state of the game. Use this to work out where the pieces are on the board:

FEN: {fen}

The possible set of legal moves are: 

Legal Moves: {valid_moves}

+(You have to choose one from the provided list. Do not choose a move that is not in the list.)

The move history is: {move_history}.

Output the best move in SAN format to follow this position. Use the following single blob of JSON. Do not include any other information.
{{
    "san": "The move in SAN format",
}}"""}], options={"temperature": temp})
    
    try:
        parsed_json = json.loads(response.message.content)
        qwen_move = parsed_json["san"]
    except Exception as e:
        print(f"Wrong format given by Qwen. \nQwen Output: {response.message.content}")

    

    return qwen_move

# %%
def get_random_move(board:chess.Board, fen:str, seed: int = 101):
    legal_moves = [
        board.san(move)
        for move in board.legal_moves
    ]

    random.seed(seed)

    # print(random.choice(legal_moves))
    return random.choice(legal_moves)

    # print(legal_moves[0])

# %%
for game_number in range(1, NUM_GAMES + 1):
    
    move_counter = 0

    print(f"Starting game {game_number}...")

    board = chess.Board()

    while not board.is_game_over() and move_counter <= MOVE_LIMIT:
        if board.turn == chess.WHITE and not board.is_game_over():
            num = random.randint(1,100)
            
            if num <= QWEN_US_AI:
                stockfish.set_fen_position(board.fen())
                qwen_us_move = await get_move_with_timeout(stockfish)

                if qwen_us_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break
            
            else:
                qwen_us_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_us_move)
            except Exception as e:
                print(f"Invalid move by Qwen white. Move: {qwen_us_move}")
                qwen_us_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_us_move)
                print(f"New Move: {qwen_us_move}")
                # continue
            
            move_counter += 1        
            print(f"Qwen US move: {qwen_us_move} Move number: {move_counter}")

        elif board.turn == chess.BLACK and not board.is_game_over():
            num = random.randint(1, 100)

            if num <= QWEN_CN_AI:
                stockfish.set_fen_position(board.fen())
                qwen_cn_move = await get_move_with_timeout(stockfish)

                if qwen_cn_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break

            else:
                qwen_cn_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_cn_move)
            except Exception as e:
                print(f"Invalid move by Qwen black. Move: {qwen_cn_move}")
                qwen_cn_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_cn_move)
                print(f"New Move: {qwen_cn_move}")
                # continue
            move_counter += 1
            print(f"Qwen CN move: {qwen_cn_move} Move number: {move_counter}")   

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        qwen_us_wins += 1
    elif result == "0-1":
        qwen_cn_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n\n")
# Out:
# Starting game 1...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: g8f6 Move number: 6
# Qwen US move: d2d3 Move number: 7
# Qwen CN move: f8c5 Move number: 8
# Qwen US move: c2c3 Move number: 9
# Qwen CN move: e8g8 Move number: 10
# Qwen US move: e1g1 Move number: 11
# Qwen CN move: d7d5 Move number: 12
# Qwen US move: e4d5 Move number: 13
# Qwen CN move: d8d5 Move number: 14
# Qwen US move: Nbd2 Move number: 15
# Invalid move by Qwen black. Move: Nc4
# New Move: g6
# Qwen CN move: g6 Move number: 16
# Qwen US move: b5c4 Move number: 17
# Qwen CN move: d5d8 Move number: 18
# Qwen US move: Bxf7+ Move number: 19
# Qwen CN move: f8f7 Move number: 20
# Qwen US move: b2b4 Move number: 21
# Qwen CN move: c5d6 Move number: 22
# Qwen US move: f1e1 Move number: 23
# Qwen CN move: Be7 Move number: 24
# Qwen US move: b4b5 Move number: 25
# Invalid move by Qwen black. Move: bxc6
# New Move: Qd5
# Qwen CN move: Qd5 Move number: 26
# Qwen US move: b5c6 Move number: 27
# Qwen CN move: Bd6 Move number: 28
# Qwen US move: h2h3 Move number: 29
# Qwen CN move: b7b5 Move number: 30
# Qwen US move: c3c4 Move number: 31
# Qwen CN move: d5c6 Move number: 32
# Qwen US move: Ng5 Move number: 33
# Qwen CN move: c8b7 Move number: 34
# Qwen US move: Nf1 Move number: 35
# Invalid move by Qwen black. Move: Re1
# New Move: h5
# Qwen CN move: h5 Move number: 36
# Qwen US move: f1e3 Move number: 37
# Qwen CN move: f7e7 Move number: 38
# Qwen US move: Nh7 Move number: 39
# Qwen CN move: g8h7 Move number: 40
# Qwen US move: c4b5 Move number: 41
# Qwen CN move: c6b5 Move number: 42
# Qwen US move: d1d2 Move number: 43
# Qwen CN move: Qc4 Move number: 44
# Qwen US move: e3c4 Move number: 45
# Qwen CN move: Rb8 Move number: 46
# Qwen US move: Nxd6 Move number: 47
# Qwen CN move: c7d6 Move number: 48
# Qwen US move: a1b1 Move number: 49
# Qwen CN move: e7g7 Move number: 50
# Qwen US move: h3h4 Move number: 51
# Qwen CN move: g6g5 Move number: 52
# Qwen US move: b1b7 Move number: 53
# Qwen CN move: g7b7 Move number: 54
# Qwen US move: h4g5 Move number: 55
# Qwen CN move: f6d5 Move number: 56
# Qwen US move: d2e2 Move number: 57
# Qwen CN move: h7g7 Move number: 58
# Qwen US move: e2f3 Move number: 59
# Qwen CN move: b7b5 Move number: 60
# Qwen US move: f3h3 Move number: 61
# Qwen CN move: R5b7 Move number: 62
# Qwen US move: Qg3 Move number: 63
# Qwen CN move: Rb1 Move number: 64
# Qwen US move: g3h3 Move number: 65
# Qwen CN move: b8b7 Move number: 66
# Qwen US move: h3e6 Move number: 67
# Qwen CN move: d5f4 Move number: 68
# Qwen US move: e6d6 Move number: 69
# Qwen CN move: f4g6 Move number: 70
# Qwen US move: d6f6 Move number: 71
# Invalid move by Qwen black. Move: Qxf4
# New Move: Kg8
# Qwen CN move: Kg8 Move number: 72
# Qwen US move: f6g6 Move number: 73
# Invalid move by Qwen black. Move: Qh3
# New Move: Rg7
# Qwen CN move: Rg7 Move number: 74
# Qwen US move: g6e6 Move number: 75
# Qwen CN move: g8h7 Move number: 76
# Qwen US move: Qg8+ Move number: 77
# Qwen CN move: g7g8 Move number: 78
# Qwen US move: e1f1 Move number: 79
# Qwen CN move: g8c8 Move number: 80
# Qwen US move: c1e3 Move number: 81
# Invalid move by Qwen black. Move: Rc8
# New Move: Rc7
# Qwen CN move: Rc7 Move number: 82
# Qwen US move: f1b1 Move number: 83
# Invalid move by Qwen black. Move: Rb1
# New Move: Kg6
# Qwen CN move: Kg6 Move number: 84
# Qwen US move: b1c1 Move number: 85
# Qwen CN move: Rc8 Move number: 86
# Qwen US move: c1c8 Move number: 87
# Qwen CN move: h5h4 Move number: 88
# Qwen US move: c8c6 Move number: 89
# Qwen CN move: g6h7 Move number: 90
# Qwen US move: Rc5 Move number: 91
# Qwen CN move: h7g7 Move number: 92
# Qwen US move: Rc4 Move number: 93
# Qwen CN move: Kf8 Move number: 94
# Qwen US move: c4c7 Move number: 95
# Qwen CN move: f8e8 Move number: 96
# Qwen US move: c7a7 Move number: 97
# Qwen CN move: e8f8 Move number: 98
# Qwen US move: g1h2 Move number: 99
# Qwen CN move: e5e4 Move number: 100
# Qwen US move: d3e4 Move number: 101
# Qwen CN move: f8e8 Move number: 102
# Qwen US move: e3b6 Move number: 103
# Qwen CN move: e8f8 Move number: 104
# Qwen US move: f2f3 Move number: 105
# Qwen CN move: f8e8 Move number: 106
# Qwen US move: b6a5 Move number: 107
# Qwen CN move: h4h3 Move number: 108
# Qwen US move: Rd7 Move number: 109
# Qwen CN move: Kf8 Move number: 110
# Qwen US move: Rd8+ Move number: 111
# Qwen CN move: f8f7 Move number: 112
# Qwen US move: h2h3 Move number: 113
# Qwen CN move: f7g6 Move number: 114
# Qwen US move: d8d5 Move number: 115
# Qwen CN move: g6f7 Move number: 116
# Qwen US move: a2a4 Move number: 117
# Qwen CN move: f7e7 Move number: 118
# Invalid move by Qwen white. Move: Rd5
# New Move: Kg3
# Qwen US move: Kg3 Move number: 119
# Qwen CN move: e7f7 Move number: 120
# Qwen US move: a5d8 Move number: 121
# Qwen CN move: Kg8 Move number: 122
# Qwen US move: g3h3 Move number: 123
# Qwen CN move: g8f7 Move number: 124
# Qwen US move: d5f5 Move number: 125
# Qwen CN move: f7g7 Move number: 126
# Invalid move by Qwen white. Move: Rf5
# New Move: a5
# Qwen US move: a5 Move number: 127
# Qwen CN move: g7g6 Move number: 128
# Qwen US move: a5a6 Move number: 129
# Invalid move by Qwen black. Move: Rf5+
# New Move: Kh5
# Qwen CN move: Kh5 Move number: 130
# Qwen US move: d8a5 Move number: 131
# Qwen CN move: h5g6 Move number: 132
# Qwen US move: Rf4 Move number: 133
# Qwen CN move: g6h5 Move number: 134
# Qwen US move: f4f5 Move number: 135
# Qwen CN move: h5g6 Move number: 136
# Qwen US move: a5c3 Move number: 137
# Invalid move by Qwen black. Move: Bxf7+
# New Move: Kh7
# Qwen CN move: Kh7 Move number: 138
# Qwen US move: a6a7 Move number: 139
# Invalid move by Qwen black. Move: Rf5
# New Move: Kg8
# Qwen CN move: Kg8 Move number: 140
# Qwen US move: a7a8q Move number: 141
# Invalid move by Qwen black. Move: Qg3
# New Move: Kh7
# Qwen CN move: Kh7 Move number: 142
# Qwen US move: a8a7 Move number: 143
# Invalid move by Qwen black. Move: Qa5+
# New Move: Kg8
# Qwen CN move: Kg8 Move number: 144
# Qwen US move: a7f7 Move number: 145
# Game 1 result: 1-0
#
#
# Starting game 2...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1c4 Move number: 5
# Qwen CN move: Nf6 Move number: 6
# Qwen US move: d2d3 Move number: 7
# Invalid move by Qwen black. Move: Nf3
# New Move: g6
# Qwen CN move: g6 Move number: 8
# Qwen US move: f3g5 Move number: 9
# Qwen CN move: d7d5 Move number: 10
# Qwen US move: Nh3 Move number: 11
# Qwen CN move: d5c4 Move number: 12
# Qwen US move: h3g5 Move number: 13
# Qwen CN move: c4d3 Move number: 14
# Qwen US move: b1c3 Move number: 15
# Qwen CN move: Bxd6 Move number: 16
# Qwen US move: d1d3 Move number: 17
# Invalid move by Qwen black. Move: Qd4
# New Move: Bd7
# Qwen CN move: Bd7 Move number: 18
# Qwen US move: g5f3 Move number: 19
# Invalid move by Qwen black. Move: Nh3
# New Move: Rc8
# Qwen CN move: Rc8 Move number: 20
# Qwen US move: c1g5 Move number: 21
# Invalid move by Qwen black. Move: Bxd7
# New Move: Be6
# Qwen CN move: Be6 Move number: 22
# Qwen US move: c3d5 Move number: 23
# Qwen CN move: Nxe4 Move number: 24
# Qwen US move: g5d8 Move number: 25
# Qwen CN move: c8d8 Move number: 26
# Qwen US move: d3e4 Move number: 27
# Qwen CN move: e6d5 Move number: 28
# Qwen US move: Qxe5+ Move number: 29
# Qwen CN move: c6e5 Move number: 30
# Invalid move by Qwen white. Move: Nxd7
# New Move: b3
# Qwen US move: b3 Move number: 31
# Qwen CN move: e5f3 Move number: 32
# Qwen US move: g2f3 Move number: 33
# Qwen CN move: Rg8 Move number: 34
# Qwen US move: e1c1 Move number: 35
# Qwen CN move: e8e7 Move number: 36
# Qwen US move: c1b1 Move number: 37
# Qwen CN move: d5e6 Move number: 38
# Qwen US move: Rxd6 Move number: 39
# Qwen CN move: d8d6 Move number: 40
# Qwen US move: Rg1 Move number: 41
# Qwen CN move: Rg7 Move number: 42
# Qwen US move: b1c1 Move number: 43
# Qwen CN move: g7g8 Move number: 44
# Qwen US move: a2a4 Move number: 45
# Qwen CN move: g8d8 Move number: 46
# Qwen US move: g1e1 Move number: 47
# Qwen CN move: h7h5 Move number: 48
# Qwen US move: c1b2 Move number: 49
# Qwen CN move: b7b6 Move number: 50
# Qwen US move: b2c1 Move number: 51
# Qwen CN move: h5h4 Move number: 52
# Qwen US move: e1e5 Move number: 53
# Qwen CN move: d6d5 Move number: 54
# Qwen US move: e5e4 Move number: 55
# Qwen CN move: d5d1 Move number: 56
# Qwen US move: Kb2 Move number: 57
# Qwen CN move: Rg1 Move number: 58
# Qwen US move: Rxe6+ Move number: 59
# Qwen CN move: e7e6 Move number: 60
# Qwen US move: a4a5 Move number: 61
# Qwen CN move: b6a5 Move number: 62
# Qwen US move: c2c4 Move number: 63
# Qwen CN move: d8d2 Move number: 64
# Qwen US move: b2c3 Move number: 65
# Qwen CN move: g1d1 Move number: 66
# Qwen US move: f4 Move number: 67
# Qwen CN move: d2d3 Move number: 68
# Qwen US move: Kc2 Move number: 69
# Qwen CN move: d1d2 Move number: 70
# Qwen US move: c2b1 Move number: 71
# Qwen CN move: e6f5 Move number: 72
# Qwen US move: b3b4 Move number: 73
# Qwen CN move: d2f2 Move number: 74
# Qwen US move: c5 Move number: 75
# Qwen CN move: d3d1 Move number: 76
# Game 2 result: 0-1
#
#
# Starting game 3...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: g7g6 Move number: 6
# Qwen US move: e1g1 Move number: 7
# Qwen CN move: f8g7 Move number: 8
# Qwen US move: b5c6 Move number: 9
# Invalid move by Qwen black. Move: Bxc6
# New Move: a6
# Qwen CN move: a6 Move number: 10
# Qwen US move: c6d5 Move number: 11
# Qwen CN move: g8f6 Move number: 12
# Qwen US move: Bxf7+ Move number: 13
# Qwen CN move: e8f7 Move number: 14
# Qwen US move: e4e5 Move number: 15
# Qwen CN move: f6g8 Move number: 16
# Qwen US move: d2d4 Move number: 17
# Invalid move by Qwen black. Move: dxe5
# New Move: b6
# Qwen CN move: b6 Move number: 18
# Qwen US move: f3g5 Move number: 19
# Qwen CN move: f7e8 Move number: 20
# Qwen US move: Nh3 Move number: 21
# Qwen CN move: c5d4 Move number: 22
# Qwen US move: d1d4 Move number: 23
# Qwen CN move: d7d6 Move number: 24
# Qwen US move: h3g5 Move number: 25
# Invalid move by Qwen black. Move: Nxe4
# New Move: e6
# Qwen CN move: e6 Move number: 26
# Qwen US move: d4f4 Move number: 27
# Qwen CN move: a8a7 Move number: 28
# Qwen US move: Nh3 Move number: 29
# Qwen CN move: g7e5 Move number: 30
# Qwen US move: f4a4 Move number: 31
# Qwen CN move: b6b5 Move number: 32
# Qwen US move: a4b3 Move number: 33
# Qwen CN move: Nf6 Move number: 34
# Qwen US move: c1e3 Move number: 35
# Qwen CN move: Nh5 Move number: 36
# Qwen US move: Ng5 Move number: 37
# Qwen CN move: a7e7 Move number: 38
# Qwen US move: a2a4 Move number: 39
# Qwen CN move: b5a4 Move number: 40
# Qwen US move: a1a4 Move number: 41
# Qwen CN move: e7b7 Move number: 42
# Qwen US move: b3a3 Move number: 43
# Qwen CN move: h8f8 Move number: 44
# Qwen US move: a4a6 Move number: 45
# Qwen CN move: h5f4 Move number: 46
# Qwen US move: g5e4 Move number: 47
# Qwen CN move: d8h4 Move number: 48
# Qwen US move: e4d6 Move number: 49
# Qwen CN move: e5d6 Move number: 50
# Qwen US move: a3d6 Move number: 51
# Invalid move by Qwen black. Move: Rb1
# New Move: Rb8
# Qwen CN move: Rb8 Move number: 52
# Qwen US move: d6b8 Move number: 53
# Qwen CN move: Nh5 Move number: 54
# Qwen US move: b8c8 Move number: 55
# Qwen CN move: e8f7 Move number: 56
# Qwen US move: a6a7 Move number: 57
# Qwen CN move: h4e7 Move number: 58
# Qwen US move: Qxf8+ Move number: 59
# Qwen CN move: f7f8 Move number: 60
# Qwen US move: Ra8+ Move number: 61
# Qwen CN move: Kf7 Move number: 62
# Qwen US move: a8a7 Move number: 63
# Qwen CN move: e7a7 Move number: 64
# Qwen US move: e3a7 Move number: 65
# Qwen CN move: h5f6 Move number: 66
# Qwen US move: b1c3 Move number: 67
# Qwen CN move: h7h5 Move number: 68
# Qwen US move: f1d1 Move number: 69
# Qwen CN move: h5h4 Move number: 70
# Qwen US move: h2h3 Move number: 71
# Qwen CN move: g6g5 Move number: 72
# Qwen US move: a7d4 Move number: 73
# Qwen CN move: f6h5 Move number: 74
# Qwen US move: d4e3 Move number: 75
# Qwen CN move: g5g4 Move number: 76
# Qwen US move: Bd4 Move number: 77
# Invalid move by Qwen black. Move: Nh3
# New Move: e5
# Qwen CN move: e5 Move number: 78
# Qwen US move: d4e5 Move number: 79
# Qwen CN move: g4h3 Move number: 80
# Qwen US move: Bd4 Move number: 81
# Qwen CN move: h5f4 Move number: 82
# Qwen US move: g2h3 Move number: 83
# Qwen CN move: f4h3 Move number: 84
# Qwen US move: g1g2 Move number: 85
# Qwen CN move: Ng1 Move number: 86
# Qwen US move: d1g1 Move number: 87
# Qwen CN move: Kf8 Move number: 88
# Qwen US move: Bh8 Move number: 89
# Qwen CN move: f8e7 Move number: 90
# Qwen US move: c3e2 Move number: 91
# Qwen CN move: e7e6 Move number: 92
# Qwen US move: g2h2 Move number: 93
# Qwen CN move: e6f5 Move number: 94
# Qwen US move: f2f3 Move number: 95
# Qwen CN move: f5e6 Move number: 96
# Qwen US move: g1g4 Move number: 97
# Qwen CN move: e6d7 Move number: 98
# Qwen US move: h8d4 Move number: 99
# Qwen CN move: d7d6 Move number: 100
# Qwen US move: g4f4 Move number: 101
# Qwen CN move: d6e6 Move number: 102
# Qwen US move: b2b4 Move number: 103
# Invalid move by Qwen black. Move: Rg4
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 104
# Qwen US move: b4b5 Move number: 105
# Qwen CN move: Kd7 Move number: 106
# Qwen US move: c2c4 Move number: 107
# Qwen CN move: d7c8 Move number: 108
# Qwen US move: b5b6 Move number: 109
# Qwen CN move: h4h3 Move number: 110
# Qwen US move: Rf8+ Move number: 111
# Qwen CN move: c8d7 Move number: 112
# Qwen US move: Rg8 Move number: 113
# Invalid move by Qwen black. Move: Rg8
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 114
# Qwen US move: b6b7 Move number: 115
# Invalid move by Qwen black. Move: Rg8
# New Move: Kf7
# Qwen CN move: Kf7 Move number: 116
# Qwen US move: g8g7 Move number: 117
# Qwen CN move: Kf8 Move number: 118
# Qwen US move: b7b8r Move number: 119
# Game 3 result: 1-0
#
#
# Starting game 4...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: b1c3 Move number: 3
# Invalid move by Qwen black. Move: Nf3
# New Move: b5
# Qwen CN move: b5 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: c8b7 Move number: 6
# Qwen US move: Bd3 Move number: 7
# ---------------------------------------------------------------------------
# StockfishException                        Traceback (most recent call last)
# Cell In[21], line 41
#      38 num = random.randint(1, 100)
#      40 if num <= QWEN_CN_AI:
# ---> 41     stockfish.set_fen_position(board.fen())
#      42     qwen_cn_move = await get_move_with_timeout(stockfish)
#      44     if qwen_cn_move is None:
#
# File /opt/anaconda3/envs/env/lib/python3.12/site-packages/stockfish/models.py:207, in Stockfish.set_fen_position(self, fen_position, send_ucinewgame_token)
#     190 def set_fen_position(
#     191     self, fen_position: str, send_ucinewgame_token: bool = True
#     192 ) -> None:
#     193     """Sets current board position in Forsyth–Edwards notation (FEN).
#     194
#     195     Args:
#    (...)
#     205         None
#     206     """
# --> 207     self._prepare_for_new_position(send_ucinewgame_token)
#     208     self._put(f"position fen {fen_position}")
#
# File /opt/anaconda3/envs/env/lib/python3.12/site-packages/stockfish/models.py:144, in Stockfish._prepare_for_new_position(self, send_ucinewgame_token)
#     142 if send_ucinewgame_token:
#     143     self._put("ucinewgame")
# --> 144 self._is_ready()
#     145 self.info = ""
#
# File /opt/anaconda3/envs/env/lib/python3.12/site-packages/stockfish/models.py:173, in Stockfish._is_ready(self)
#     171 def _is_ready(self) -> None:
#     172     self._put("isready")
# --> 173     while self._read_line() != "readyok":
#     174         pass
#
# File /opt/anaconda3/envs/env/lib/python3.12/site-packages/stockfish/models.py:160, in Stockfish._read_line(self)
#     158     raise BrokenPipeError()
#     159 if self._stockfish.poll() is not None:
# --> 160     raise StockfishException("The Stockfish process has crashed")
#     161 return self._stockfish.stdout.readline().strip()
#
# StockfishException: The Stockfish process has crashed

# %%
results = []

# %%
results.append({
            "Qwen US Wins": qwen_us_wins,
            "Qwen CN Wins": qwen_cn_wins,
            "Draws": draws,
        })

print(results)
# Out:
# [{'Qwen US Wins': 57, 'Qwen CN Wins': 35, 'Draws': 8}]

# %% [markdown]
# ## Swapping the sides

# %%
qwen_us_wins = 57
qwen_cn_wins = 35
draws = 8

# %%
for game_number in range(1, NUM_GAMES + 1):
    
    move_counter = 0

    print(f"Starting game {game_number}...")

    board = chess.Board()

    while not board.is_game_over() and move_counter <= MOVE_LIMIT:
        if board.turn == chess.WHITE and not board.is_game_over():
            num = random.randint(1,100)
            
            if num <= QWEN_CN_AI:
                stockfish.set_fen_position(board.fen())
                qwen_cn_move = await get_move_with_timeout(stockfish)

                if qwen_cn_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break
            
            else:
                qwen_cn_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_cn_move)
            except Exception as e:
                print(f"Invalid move by Qwen CN. Move: {qwen_cn_move}")
                qwen_cn_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_cn_move)
                print(f"New Move: {qwen_cn_move}")
                # continue
            
            move_counter += 1        
            print(f"Qwen CN move: {qwen_cn_move} Move number: {move_counter}")

        elif board.turn == chess.BLACK and not board.is_game_over():
            num = random.randint(1, 100)

            if num <= QWEN_US_AI:
                stockfish.set_fen_position(board.fen())
                qwen_us_move = await get_move_with_timeout(stockfish)

                if qwen_us_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break

            else:
                qwen_us_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_us_move)
            except Exception as e:
                print(f"Invalid move by Qwen black. Move: {qwen_us_move}")
                qwen_us_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_us_move)
                print(f"New Move: {qwen_us_move}")
                # continue
            move_counter += 1
            print(f"Qwen CN move: {qwen_us_move} Move number: {move_counter}")   

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        qwen_cn_wins += 1
    elif result == "0-1":
        qwen_us_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n\n")
# Out:
# Starting game 1...
# Qwen CN move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Invalid move by Qwen black. Move: Nc6
# New Move: g5
# Qwen CN move: g5 Move number: 6
# Qwen CN move: f3g5 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen CN move: Nh3 Move number: 9
# Qwen CN move: d7d5 Move number: 10
# Qwen CN move: h3f4 Move number: 11
# Qwen CN move: d5e4 Move number: 12
# Qwen CN move: b1c3 Move number: 13
# Qwen CN move: Bg4 Move number: 14
# Qwen CN move: f2f3 Move number: 15
# Qwen CN move: Bh6 Move number: 16
# Qwen CN move: Bxc6+ Move number: 17
# Qwen CN move: b7c6 Move number: 18
# Qwen CN move: f3g4 Move number: 19
# Qwen CN move: h6f4 Move number: 20
# Qwen CN move: d1e2 Move number: 21
# Qwen CN move: h8g8 Move number: 22
# Qwen CN move: c3e4 Move number: 23
# Qwen CN move: f6e4 Move number: 24
# Qwen CN move: e2e4 Move number: 25
# Qwen CN move: d8d6 Move number: 26
# Qwen CN move: g2g3 Move number: 27
# Qwen CN move: f4e5 Move number: 28
# Qwen CN move: d2d3 Move number: 29
# Qwen CN move: g8g6 Move number: 30
# Qwen CN move: e1g1 Move number: 31
# Invalid move by Qwen black. Move: Qe5
# New Move: Rg7
# Qwen CN move: Rg7 Move number: 32
# Qwen CN move: c2c3 Move number: 33
# Qwen CN move: Rg5 Move number: 34
# Qwen CN move: c1g5 Move number: 35
# Qwen CN move: f7f6 Move number: 36
# Qwen CN move: g5f4 Move number: 37
# Qwen CN move: e5f4 Move number: 38
# Qwen CN move: Qg2 Move number: 39
# Qwen CN move: f4e5 Move number: 40
# Qwen CN move: Qxc6+ Move number: 41
# Qwen CN move: Qd7 Move number: 42
# Qwen CN move: c6a8 Move number: 43
# Qwen CN move: e8f7 Move number: 44
# Qwen CN move: a8f3 Move number: 45
# Qwen CN move: c5c4 Move number: 46
# Qwen CN move: d3c4 Move number: 47
# Qwen CN move: e5d6 Move number: 48
# Qwen CN move: b2b4 Move number: 49
# Qwen CN move: d6b4 Move number: 50
# Qwen CN move: c3b4 Move number: 51
# Qwen CN move: d7d4 Move number: 52
# Qwen CN move: f3f2 Move number: 53
# Qwen CN move: d4c4 Move number: 54
# Qwen CN move: f2f4 Move number: 55
# Qwen CN move: c4b5 Move number: 56
# Qwen CN move: Qe4 Move number: 57
# Qwen CN move: Qf5 Move number: 58
# Qwen CN move: Qxe7+ Move number: 59
# Qwen CN move: f7e7 Move number: 60
# Qwen CN move: g4f5 Move number: 61
# Qwen CN move: e7f7 Move number: 62
# Qwen CN move: f1f2 Move number: 63
# Qwen CN move: f7f8 Move number: 64
# Qwen CN move: a1e1 Move number: 65
# Qwen CN move: f8g7 Move number: 66
# Qwen CN move: Rf4 Move number: 67
# Qwen CN move: g7h6 Move number: 68
# Qwen CN move: Rfe4 Move number: 69
# Qwen CN move: h6g5 Move number: 70
# Qwen CN move: e4f4 Move number: 71
# Qwen CN move: h7h5 Move number: 72
# Qwen CN move: f4f2 Move number: 73
# Qwen CN move: g5h6 Move number: 74
# Invalid move by Qwen CN. Move: Rfe4
# New Move: Rc1
# Qwen CN move: Rc1 Move number: 75
# Qwen CN move: h6h7 Move number: 76
# Qwen CN move: b4b5 Move number: 77
# Qwen CN move: Kh8 Move number: 78
# Qwen CN move: a2a4 Move number: 79
# Qwen CN move: h5h4 Move number: 80
# Qwen CN move: g3h4 Move number: 81
# Qwen CN move: h8g7 Move number: 82
# Qwen CN move: Rf4 Move number: 83
# Qwen CN move: g7h7 Move number: 84
# Qwen CN move: Rg4 Move number: 85
# Invalid move by Qwen black. Move: Rg4
# New Move: Kh8
# Qwen CN move: Kh8 Move number: 86
# Qwen CN move: c1c8 Move number: 87
# Invalid move by Qwen black. Move: Rxc4
# New Move: Kh7
# Qwen CN move: Kh7 Move number: 88
# Qwen CN move: g4g3 Move number: 89
# Invalid move by Qwen black. Move: Rg4
# New Move: a5
# Qwen CN move: a5 Move number: 90
# Qwen CN move: h2h3 Move number: 91
# Qwen CN move: h7h6 Move number: 92
# Qwen CN move: Rh8# Move number: 93
# Game 1 result: 1-0
#
#
# Starting game 2...
# Qwen CN move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen CN move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen CN move: Nc3 Move number: 7
# Invalid move by Qwen black. Move: Nxe5
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 8
# Qwen CN move: b2a3 Move number: 9
# Qwen CN move: Nf6 Move number: 10
# Qwen CN move: d2d4 Move number: 11
# Qwen CN move: e5g6 Move number: 12
# Qwen CN move: e4e5 Move number: 13
# Qwen CN move: f6g8 Move number: 14
# Invalid move by Qwen CN. Move: Nbd2
# New Move: Ba6
# Qwen CN move: Ba6 Move number: 15
# Qwen CN move: b7a6 Move number: 16
# Qwen CN move: Nd5 Move number: 17
# Qwen CN move: g8e7 Move number: 18
# Qwen CN move: c1g5 Move number: 19
# Qwen CN move: d7d6 Move number: 20
# Qwen CN move: d5e7 Move number: 21
# Qwen CN move: Qxe7 Move number: 22
# Qwen CN move: g5e7 Move number: 23
# Qwen CN move: Rg8 Move number: 24
# Qwen CN move: Bxd6 Move number: 25
# Qwen CN move: c7d6 Move number: 26
# Qwen CN move: d1f3 Move number: 27
# Qwen CN move: a8b8 Move number: 28
# Qwen CN move: e5d6 Move number: 29
# Qwen CN move: c8b7 Move number: 30
# Qwen CN move: f3f5 Move number: 31
# Qwen CN move: b8d8 Move number: 32
# Qwen CN move: e1c1 Move number: 33
# Qwen CN move: d8d6 Move number: 34
# Qwen CN move: h1f1 Move number: 35
# Qwen CN move: d6f6 Move number: 36
# Qwen CN move: f5c5 Move number: 37
# Qwen CN move: e8d8 Move number: 38
# Qwen CN move: c5a7 Move number: 39
# Qwen CN move: Rf8 Move number: 40
# Qwen CN move: Qb8+ Move number: 41
# Invalid move by Qwen black. Move: Qxb7
# New Move: Bc8
# Qwen CN move: Bc8 Move number: 42
# Qwen CN move: f1e1 Move number: 43
# Qwen CN move: f6f2 Move number: 44
# Qwen CN move: Qxc8+ Move number: 45
# Qwen CN move: d8c8 Move number: 46
# Qwen CN move: d1d2 Move number: 47
# Qwen CN move: f2f4 Move number: 48
# Qwen CN move: c2c3 Move number: 49
# Invalid move by Qwen black. Move: Rd2
# New Move: Rf2
# Qwen CN move: Rf2 Move number: 50
# Qwen CN move: d2f2 Move number: 51
# Qwen CN move: c8c7 Move number: 52
# Qwen CN move: Rxf7+ Move number: 53
# Qwen CN move: f8f7 Move number: 54
# Qwen CN move: c1d2 Move number: 55
# Qwen CN move: c7d7 Move number: 56
# Qwen CN move: c3c4 Move number: 57
# Qwen CN move: Rf8 Move number: 58
# Qwen CN move: g2g3 Move number: 59
# Qwen CN move: Rf1 Move number: 60
# Qwen CN move: Kd3 Move number: 61
# Qwen CN move: f1e1 Move number: 62
# Qwen CN move: h2h4 Move number: 63
# Qwen CN move: e1g1 Move number: 64
# Qwen CN move: c4c5 Move number: 65
# Qwen CN move: g1g3 Move number: 66
# Qwen CN move: d3d2 Move number: 67
# Qwen CN move: g6e7 Move number: 68
# Qwen CN move: a3a4 Move number: 69
# Qwen CN move: d7e6 Move number: 70
# Qwen CN move: d2e2 Move number: 71
# Qwen CN move: g3g4 Move number: 72
# Qwen CN move: e2d3 Move number: 73
# Qwen CN move: e7c6 Move number: 74
# Qwen CN move: d4d5 Move number: 75
# Qwen CN move: Kd7 Move number: 76
# Qwen CN move: dxc6+ Move number: 77
# Invalid move by Qwen black. Move: Kd2
# New Move: Ke6
# Qwen CN move: Ke6 Move number: 78
# Qwen CN move: h4h5 Move number: 79
# Qwen CN move: g4h4 Move number: 80
# Invalid move by Qwen CN. Move: Kd3
# New Move: Kc3
# Qwen CN move: Kc3 Move number: 81
# Qwen CN move: e6e7 Move number: 82
# Qwen CN move: Kd2 Move number: 83
# Qwen CN move: h4h5 Move number: 84
# Qwen CN move: d2e3 Move number: 85
# Qwen CN move: h5c5 Move number: 86
# Qwen CN move: e3d4 Move number: 87
# Qwen CN move: Rc4+ Move number: 88
# Qwen CN move: d4c4 Move number: 89
# Invalid move by Qwen black. Move: Kd3
# New Move: h5
# Qwen CN move: h5 Move number: 90
# Qwen CN move: c4c5 Move number: 91
# Qwen CN move: e7d8 Move number: 92
# Qwen CN move: Kc4 Move number: 93
# Qwen CN move: h5h4 Move number: 94
# Qwen CN move: c4d5 Move number: 95
# Qwen CN move: h4h3 Move number: 96
# Qwen CN move: d5d6 Move number: 97
# Qwen CN move: g5 Move number: 98
# Qwen CN move: c6c7 Move number: 99
# Qwen CN move: Kc8 Move number: 100
# Invalid move by Qwen CN. Move: Kd6
# New Move: Ke6
# Qwen CN move: Ke6 Move number: 101
# Qwen CN move: c8c7 Move number: 102
# Qwen CN move: Kf7 Move number: 103
# Qwen CN move: h3h2 Move number: 104
# Qwen CN move: f7e6 Move number: 105
# Qwen CN move: h2h1q Move number: 106
# Qwen CN move: e6f5 Move number: 107
# Qwen CN move: Kd6 Move number: 108
# Qwen CN move: f5g5 Move number: 109
# Qwen CN move: Qe1 Move number: 110
# Qwen CN move: Kf6 Move number: 111
# Qwen CN move: e1a5 Move number: 112
# Qwen CN move: f6g7 Move number: 113
# Qwen CN move: d6e6 Move number: 114
# Qwen CN move: g7g6 Move number: 115
# Qwen CN move: a5f5 Move number: 116
# Qwen CN move: g6g7 Move number: 117
# Qwen CN move: f5g4 Move number: 118
# Qwen CN move: g7h8 Move number: 119
# Qwen CN move: e6f7 Move number: 120
# Qwen CN move: a4a5 Move number: 121
# Qwen CN move: g4h3 Move number: 122
# Game 2 result: 0-1
#
#
# Starting game 3...
# Qwen CN move: d2d4 Move number: 1
# Qwen CN move: d7d5 Move number: 2
# Qwen CN move: c2c4 Move number: 3
# Qwen CN move: dxc4 Move number: 4
# Qwen CN move: Nf3 Move number: 5
# Invalid move by Qwen black. Move: Nxd4
# New Move: b6
# Qwen CN move: b6 Move number: 6
# Qwen CN move: e2e4 Move number: 7
# Qwen CN move: c8a6 Move number: 8
# Invalid move by Qwen CN. Move: Nxd5
# New Move: Bd3
# Qwen CN move: Bd3 Move number: 9
# Qwen CN move: c4d3 Move number: 10
# Qwen CN move: Nh4 Move number: 11
# Qwen CN move: e7e6 Move number: 12
# Qwen CN move: h4f3 Move number: 13
# Qwen CN move: g8f6 Move number: 14
# Qwen CN move: b1c3 Move number: 15
# Qwen CN move: Bd6 Move number: 16
# Qwen CN move: e4e5 Move number: 17
# Qwen CN move: Bxe5 Move number: 18
# Qwen CN move: Nh4 Move number: 19
# Qwen CN move: e5d4 Move number: 20
# Qwen CN move: e1g1 Move number: 21
# Qwen CN move: d8d7 Move number: 22
# Qwen CN move: f1e1 Move number: 23
# Qwen CN move: b8c6 Move number: 24
# Qwen CN move: h4f5 Move number: 25
# Qwen CN move: e8c8 Move number: 26
# Qwen CN move: f5d4 Move number: 27
# Qwen CN move: c6d4 Move number: 28
# Qwen CN move: c1f4 Move number: 29
# Qwen CN move: d4c2 Move number: 30
# Qwen CN move: a1c1 Move number: 31
# Qwen CN move: c8b7 Move number: 32
# Qwen CN move: d1f3 Move number: 33
# Qwen CN move: Qd5 Move number: 34
# Qwen CN move: Qh5 Move number: 35
# Qwen CN move: Qg5 Move number: 36
# Qwen CN move: h5g5 Move number: 37
# Qwen CN move: h8e8 Move number: 38
# Qwen CN move: e1d1 Move number: 39
# Qwen CN move: c2d4 Move number: 40
# Qwen CN move: f4c7 Move number: 41
# Qwen CN move: b7c7 Move number: 42
# Qwen CN move: g5g7 Move number: 43
# Qwen CN move: Nd5 Move number: 44
# Qwen CN move: c3d5 Move number: 45
# Invalid move by Qwen black. Move: Nxe7+
# New Move: Kb8
# Qwen CN move: Kb8 Move number: 46
# Qwen CN move: g7e5 Move number: 47
# Invalid move by Qwen black. Move:  Kb7
# New Move: Rd6
# Qwen CN move: Rd6 Move number: 48
# Qwen CN move: e5d6 Move number: 49
# Qwen CN move: b8a8 Move number: 50
# Qwen CN move: Qe7 Move number: 51
# Qwen CN move: d4e2 Move number: 52
# Qwen CN move: g1h1 Move number: 53
# Qwen CN move: e8e7 Move number: 54
# Qwen CN move: d5e7 Move number: 55
# Qwen CN move: Nxc1 Move number: 56
# Qwen CN move: d1c1 Move number: 57
# Invalid move by Qwen black. Move: Rc5
# New Move: d2
# Qwen CN move: d2 Move number: 58
# Qwen CN move: c1d1 Move number: 59
# Qwen CN move: a8b7 Move number: 60
# Qwen CN move: Ng6 Move number: 61
# Qwen CN move: f7g6 Move number: 62
# Qwen CN move: d1d2 Move number: 63
# Qwen CN move: b7c7 Move number: 64
# Qwen CN move: h1g1 Move number: 65
# Qwen CN move: Bd3 Move number: 66
# Qwen CN move: d2d3 Move number: 67
# Invalid move by Qwen black. Move:  Rd1
# New Move: a5
# Qwen CN move: a5 Move number: 68
# Qwen CN move: d3h3 Move number: 69
# Qwen CN move: h7h5 Move number: 70
# Invalid move by Qwen CN. Move: Rxd6
# New Move: Rf3
# Qwen CN move: Rf3 Move number: 71
# Qwen CN move: g6g5 Move number: 72
# Qwen CN move: Rf4 Move number: 73
# Qwen CN move: g5f4 Move number: 74
# Qwen CN move: g2g3 Move number: 75
# Qwen CN move: c7d6 Move number: 76
# Qwen CN move: g3f4 Move number: 77
# Qwen CN move: Kd7 Move number: 78
# Qwen CN move: g1g2 Move number: 79
# Qwen CN move: e5 Move number: 80
# Qwen CN move: fxe5 Move number: 81
# Qwen CN move: d7c6 Move number: 82
# Qwen CN move: g2f3 Move number: 83
# Qwen CN move: a5a4 Move number: 84
# Qwen CN move: f3f4 Move number: 85
# Qwen CN move: c6d7 Move number: 86
# Qwen CN move: f4f5 Move number: 87
# Qwen CN move: d7e7 Move number: 88
# Qwen CN move: h2h4 Move number: 89
# Qwen CN move: e7f7 Move number: 90
# Qwen CN move: e5e6 Move number: 91
# Qwen CN move: f7e8 Move number: 92
# Qwen CN move: f5f6 Move number: 93
# Qwen CN move: a4a3 Move number: 94
# Qwen CN move: b2a3 Move number: 95
# Qwen CN move: Kf8 Move number: 96
# Qwen CN move: Kg6 Move number: 97
# Qwen CN move: Kg8 Move number: 98
# Qwen CN move: e6e7 Move number: 99
# Qwen CN move: b6b5 Move number: 100
# Qwen CN move: e7e8r Move number: 101
# Game 3 result: 1-0
#
#
# Starting game 4...
# Qwen CN move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen CN move: b1c3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen CN move: Nf3 Move number: 5
# Qwen CN move: e7e5 Move number: 6
# Qwen CN move: Nh4 Move number: 7
# Qwen CN move: d8h4 Move number: 8
# Qwen CN move: f1c4 Move number: 9
# Qwen CN move: d7d5 Move number: 10
# Qwen CN move: c4d5 Move number: 11
# Qwen CN move: c6d4 Move number: 12
# Qwen CN move: Bxf7+ Move number: 13
# Qwen CN move: e8f7 Move number: 14
# Qwen CN move: e1g1 Move number: 15
# Qwen CN move: g8f6 Move number: 16
# Qwen CN move: d2d3 Move number: 17
# Qwen CN move: h4h5 Move number: 18
# Qwen CN move: d1h5 Move number: 19
# Qwen CN move: f6h5 Move number: 20
# Qwen CN move: f2f4 Move number: 21
# Qwen CN move: e5f4 Move number: 22
# Qwen CN move: c1f4 Move number: 23
# Qwen CN move: Nf6 Move number: 24
# Qwen CN move: e4e5 Move number: 25
# Qwen CN move: f6h5 Move number: 26
# Qwen CN move: f4e3 Move number: 27
# Qwen CN move: f7e8 Move number: 28
# Qwen CN move: e3d4 Move number: 29
# Qwen CN move: c5d4 Move number: 30
# Qwen CN move: c3b5 Move number: 31
# Qwen CN move: Bxd7 Move number: 32
# Qwen CN move: b5c7 Move number: 33
# Qwen CN move: e8d8 Move number: 34
# Qwen CN move: c7a8 Move number: 35
# Qwen CN move: g7g5 Move number: 36
# Qwen CN move: Rxf8+ Move number: 37
# Qwen CN move: h8f8 Move number: 38
# Qwen CN move: h2h4 Move number: 39
# Qwen CN move: Rf2 Move number: 40
# Qwen CN move: g1f2 Move number: 41
# Invalid move by Qwen black. Move: g3
# New Move: g4
# Qwen CN move: g4 Move number: 42
# Qwen CN move: a1f1 Move number: 43
# Qwen CN move: h5g7 Move number: 44
# Qwen CN move: Nc7 Move number: 45
# Qwen CN move: d8c7 Move number: 46
# Qwen CN move: c2c3 Move number: 47
# Qwen CN move: d7e6 Move number: 48
# Qwen CN move: c3d4 Move number: 49
# Qwen CN move: Bf5 Move number: 50
# Qwen CN move: d4d5 Move number: 51
# Qwen CN move: Ne8 Move number: 52
# Qwen CN move: Kg3 Move number: 53
# Qwen CN move: e8g7 Move number: 54
# Qwen CN move: g3f4 Move number: 55
# Qwen CN move: f5d3 Move number: 56
# Qwen CN move: f1d1 Move number: 57
# Qwen CN move: d3g6 Move number: 58
# Qwen CN move: d1d2 Move number: 59
# Qwen CN move: g4g3 Move number: 60
# Qwen CN move: f4g3 Move number: 61
# Qwen CN move: g7f5 Move number: 62
# Qwen CN move: g3g4 Move number: 63
# Qwen CN move: f5e3 Move number: 64
# Qwen CN move: g4f4 Move number: 65
# Qwen CN move: e3c4 Move number: 66
# Qwen CN move: d5d6 Move number: 67
# Qwen CN move: Kd7 Move number: 68
# Qwen CN move: Rd1 Move number: 69
# Invalid move by Qwen black. Move: Rd2
# New Move: Nxb2
# Qwen CN move: Nxb2 Move number: 70
# Qwen CN move: e5e6 Move number: 71
# Qwen CN move: d7d8 Move number: 72
# Qwen CN move: Rf1 Move number: 73
# Qwen CN move: b2d3 Move number: 74
# Qwen CN move: f4g5 Move number: 75
# Qwen CN move: d3c5 Move number: 76
# Qwen CN move: f1f8 Move number: 77
# Qwen CN move: Be8 Move number: 78
# Qwen CN move: g5f5 Move number: 79
# Qwen CN move: Nd3 Move number: 80
# Qwen CN move: Rh8 Move number: 81
# Qwen CN move: d3c5 Move number: 82
# Qwen CN move: h8h7 Move number: 83
# Qwen CN move: b7b5 Move number: 84
# Qwen CN move: h7a7 Move number: 85
# Qwen CN move: e8g6 Move number: 86
# Qwen CN move: f5g6 Move number: 87
# Qwen CN move: c5e6 Move number: 88
# Qwen CN move: a7f7 Move number: 89
# Qwen CN move: e6c5 Move number: 90
# Qwen CN move: h4h5 Move number: 91
# Qwen CN move: c5d7 Move number: 92
# Qwen CN move: f7d7 Move number: 93
# Qwen CN move: d8d7 Move number: 94
# Qwen CN move: h5h6 Move number: 95
# Invalid move by Qwen black. Move: Kf5
# New Move: Kc6
# Qwen CN move: Kc6 Move number: 96
# Qwen CN move: h6h7 Move number: 97
# Qwen CN move: c6d6 Move number: 98
# Qwen CN move: Kg7 Move number: 99
# Qwen CN move: d6c5 Move number: 100
# Qwen CN move: g7f6 Move number: 101
# Qwen CN move: c5b4 Move number: 102
# Qwen CN move: h7h8q Move number: 103
# Invalid move by Qwen black. Move: Kf5
# New Move: Ka3
# Qwen CN move: Ka3 Move number: 104
# Qwen CN move: h8g8 Move number: 105
# Qwen CN move: a3b4 Move number: 106
# Qwen CN move: Qg6 Move number: 107
# Qwen CN move: b4c5 Move number: 108
# Qwen CN move: g6c2 Move number: 109
# Qwen CN move: c5b6 Move number: 110
# Qwen CN move: c2c3 Move number: 111
# Qwen CN move: Kb7 Move number: 112
# Qwen CN move: g2g4 Move number: 113
# Invalid move by Qwen black. Move: g5
# New Move: b4
# Qwen CN move: b4 Move number: 114
# Qwen CN move: c3b4 Move number: 115
# Qwen CN move: b7a7 Move number: 116
# Invalid move by Qwen CN. Move: Qg8
# New Move: Ke5
# Qwen CN move: Ke5 Move number: 117
# Qwen CN move: a7a8 Move number: 118
# Qwen CN move: Qc3 Move number: 119
# Qwen CN move: a8b8 Move number: 120
# Qwen CN move: c3c6 Move number: 121
# Qwen CN move: b8a7 Move number: 122
# Qwen CN move: g4g5 Move number: 123
# Invalid move by Qwen black. Move: g4
# New Move: Kb8
# Qwen CN move: Kb8 Move number: 124
# Qwen CN move: c6d7 Move number: 125
# Invalid move by Qwen black. Move: Qxd8
# New Move: Ka8
# Qwen CN move: Ka8 Move number: 126
# Qwen CN move: e5d6 Move number: 127
# Qwen CN move: Kb8 Move number: 128
# Qwen CN move: d6c6 Move number: 129
# Qwen CN move: b8a8 Move number: 130
# Qwen CN move: d7b7 Move number: 131
# Game 4 result: 1-0
#
#
# Starting game 5...
# Qwen CN move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen CN move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen CN move: d2d4 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Qwen CN move: c2c4 Move number: 9
# Qwen CN move: f8b4 Move number: 10
# Qwen CN move: b1c3 Move number: 11
# Qwen CN move: c7c5 Move number: 12
# Qwen CN move: h2h4 Move number: 13
# Qwen CN move: h7h5 Move number: 14
# Qwen CN move: f1e2 Move number: 15
# Qwen CN move: g8f6 Move number: 16
# Qwen CN move: e1g1 Move number: 17
# Qwen CN move: c5d4 Move number: 18
# Qwen CN move: d1d4 Move number: 19
# Qwen CN move: Qa5 Move number: 20
# Qwen CN move: Qxf6 Move number: 21
# Qwen CN move: Qxe5 Move number: 22
# Qwen CN move: f6e5 Move number: 23
# Qwen CN move: g6e5 Move number: 24
# Qwen CN move: c3d5 Move number: 25
# Qwen CN move: b4a5 Move number: 26
# Qwen CN move: c1f4 Move number: 27
# Qwen CN move: f7f6 Move number: 28
# Qwen CN move: c4c5 Move number: 29
# Qwen CN move: Nf7 Move number: 30
# Qwen CN move: f4c7 Move number: 31
# Qwen CN move: Rg8 Move number: 32
# Qwen CN move: c7a5 Move number: 33
# Qwen CN move: e8f8 Move number: 34
# Qwen CN move: f2f4 Move number: 35
# Qwen CN move: b7b6 Move number: 36
# Qwen CN move: c5b6 Move number: 37
# Qwen CN move: axb6 Move number: 38
# Qwen CN move: a5b4 Move number: 39
# Qwen CN move: d7d6 Move number: 40
# Qwen CN move: d5b6 Move number: 41
# Qwen CN move: a8b8 Move number: 42
# Qwen CN move: b4a5 Move number: 43
# Qwen CN move: c8g4 Move number: 44
# Qwen CN move: e2g4 Move number: 45
# Qwen CN move: h5g4 Move number: 46
# Qwen CN move: b6d7 Move number: 47
# Qwen CN move: f8e7 Move number: 48
# Invalid move by Qwen CN. Move: Nh4
# New Move: Bc7
# Qwen CN move: Bc7 Move number: 49
# Qwen CN move: b8b2 Move number: 50
# Qwen CN move: Rfe1 Move number: 51
# Qwen CN move: e7d7 Move number: 52
# Qwen CN move: c7a5 Move number: 53
# Qwen CN move: g8a8 Move number: 54
# Qwen CN move: a5c3 Move number: 55
# Qwen CN move: Rb1 Move number: 56
# Qwen CN move: e1b1 Move number: 57
# Qwen CN move: Rxa2 Move number: 58
# Qwen CN move: Rxb8 Move number: 59
# Qwen CN move: a2a1 Move number: 60
# Qwen CN move: c3a1 Move number: 61
# Qwen CN move: f7d8 Move number: 62
# Qwen CN move: g1h2 Move number: 63
# Qwen CN move: d8e6 Move number: 64
# Qwen CN move: h2g3 Move number: 65
# Qwen CN move: e6c5 Move number: 66
# Qwen CN move: g3g4 Move number: 67
# Qwen CN move: c5e4 Move number: 68
# Qwen CN move: b8b7 Move number: 69
# Qwen CN move: d7e6 Move number: 70
# Qwen CN move: f4f5 Move number: 71
# Qwen CN move: e6d5 Move number: 72
# Qwen CN move: b7g7 Move number: 73
# Qwen CN move: Ng5 Move number: 74
# Qwen CN move: Rg6 Move number: 75
# Qwen CN move: Nh7 Move number: 76
# Qwen CN move: g6g7 Move number: 77
# Qwen CN move: h7f8 Move number: 78
# Qwen CN move: a1f6 Move number: 79
# Qwen CN move: d5c6 Move number: 80
# Qwen CN move: g4h5 Move number: 81
# Qwen CN move: f8d7 Move number: 82
# Qwen CN move: f6b2 Move number: 83
# Qwen CN move: Nf6+ Move number: 84
# Qwen CN move: b2f6 Move number: 85
# Qwen CN move: Kb5 Move number: 86
# Qwen CN move: f6g5 Move number: 87
# Qwen CN move: b5a6 Move number: 88
# Qwen CN move: f5f6 Move number: 89
# Qwen CN move: a6b5 Move number: 90
# Qwen CN move: f6f7 Move number: 91
# Qwen CN move: Kc6 Move number: 92
# Qwen CN move: f7f8q Move number: 93
# Qwen CN move: c6d5 Move number: 94
# Qwen CN move: f8f3 Move number: 95
# Qwen CN move: d5c4 Move number: 96
# Qwen CN move: g7c7 Move number: 97
# Qwen CN move: c4b4 Move number: 98
# Qwen CN move: g5d2 Move number: 99
# Qwen CN move: b4a4 Move number: 100
# Qwen CN move: c7c4 Move number: 101
# Qwen CN move: a4b5 Move number: 102
# Qwen CN move: Rc8 Move number: 103
# Qwen CN move: b5a6 Move number: 104
# Qwen CN move: f3c6 Move number: 105
# Qwen CN move: a6a7 Move number: 106
# Qwen CN move: d2e3 Move number: 107
# Game 5 result: 1-0
#
#
# Starting game 6...
# Qwen CN move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen CN move: g7g6 Move number: 6
# Qwen CN move: e1g1 Move number: 7
# Qwen CN move: f8g7 Move number: 8
# Qwen CN move: Bxc6 Move number: 9
# Qwen CN move: b7c6 Move number: 10
# Qwen CN move: f1e1 Move number: 11
# Qwen CN move: Be5 Move number: 12
# Qwen CN move: f3e5 Move number: 13
# Qwen CN move: Nh6 Move number: 14
# Qwen CN move: e5f3 Move number: 15
# Qwen CN move: d7d6 Move number: 16
# Qwen CN move: d2d4 Move number: 17
# Qwen CN move: g6g5 Move number: 18
# Qwen CN move: d4c5 Move number: 19
# Qwen CN move: g5g4 Move number: 20
# Qwen CN move: f3h4 Move number: 21
# Qwen CN move: Rg8 Move number: 22
# Qwen CN move: c1h6 Move number: 23
# Qwen CN move: a8b8 Move number: 24
# Qwen CN move: c5d6 Move number: 25
# Qwen CN move: b8b2 Move number: 26
# Qwen CN move: h4f5 Move number: 27
# Qwen CN move: Rb1 Move number: 28
# Qwen CN move: a1b1 Move number: 29
# Qwen CN move: Rg7 Move number: 30
# Qwen CN move: Re3 Move number: 31
# Qwen CN move: exd6 Move number: 32
# Qwen CN move: f5g7 Move number: 33
# Qwen CN move: e8e7 Move number: 34
# Qwen CN move: Nh5 Move number: 35
# Qwen CN move: d8a5 Move number: 36
# Qwen CN move: h6f4 Move number: 37
# Qwen CN move: Bd7 Move number: 38
# Qwen CN move: d1d6 Move number: 39
# Qwen CN move: e7e8 Move number: 40
# Qwen CN move: h5f6 Move number: 41
# Qwen CN move: e8d8 Move number: 42
# Qwen CN move: d6d7 Move number: 43
# Game 6 result: 1-0
#
#
# Starting game 7...
# Qwen CN move: e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen CN move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen CN move: Nc3 Move number: 7
# Qwen CN move: Nf6 Move number: 8
# Qwen CN move: d2d4 Move number: 9
# Qwen CN move: e5g6 Move number: 10
# Qwen CN move: e4e5 Move number: 11
# Qwen CN move: f6g8 Move number: 12
# Qwen CN move: f1c4 Move number: 13
# Qwen CN move: d7d5 Move number: 14
# Qwen CN move: c4d5 Move number: 15
# Qwen CN move: g8e7 Move number: 16
# Qwen CN move: c1g5 Move number: 17
# Qwen CN move: Bxd7 Move number: 18
# Qwen CN move: d1f3 Move number: 19
# Qwen CN move: d7e6 Move number: 20
# Qwen CN move: Bxe7 Move number: 21
# Qwen CN move: e6d5 Move number: 22
# Qwen CN move: f3d5 Move number: 23
# Qwen CN move: Qxe7 Move number: 24
# Qwen CN move: d5b7 Move number: 25
# Qwen CN move: a8d8 Move number: 26
# Qwen CN move: c3d5 Move number: 27
# Qwen CN move: d8d5 Move number: 28
# Qwen CN move: b7d5 Move number: 29
# Qwen CN move: Qxe5+ Move number: 30
# Qwen CN move: d4e5 Move number: 31
# Qwen CN move: f8b4 Move number: 32
# Qwen CN move: c2c3 Move number: 33
# Qwen CN move: Nxe5 Move number: 34
# Qwen CN move: d5e5 Move number: 35
# Qwen CN move: e8d7 Move number: 36
# Qwen CN move: e5f5 Move number: 37
# Qwen CN move: d7d8 Move number: 38
# Qwen CN move: f5d5 Move number: 39
# Qwen CN move: b4d6 Move number: 40
# Qwen CN move: d5a8 Move number: 41
# Qwen CN move: d8d7 Move number: 42
# Qwen CN move: a8h8 Move number: 43
# Qwen CN move: a7a6 Move number: 44
# Qwen CN move: Qg8 Move number: 45
# Qwen CN move: f7f6 Move number: 46
# Qwen CN move: g8g7 Move number: 47
# Qwen CN move: d7c8 Move number: 48
# Qwen CN move: Qh8+ Move number: 49
# Qwen CN move: c8b7 Move number: 50
# Qwen CN move: Qg8 Move number: 51
# Qwen CN move: b7a7 Move number: 52
# Qwen CN move: g8h7 Move number: 53
# Qwen CN move: d6f4 Move number: 54
# Qwen CN move: e1f1 Move number: 55
# Qwen CN move: f6f5 Move number: 56
# Qwen CN move: h2h4 Move number: 57
# Qwen CN move: f4e5 Move number: 58
# Qwen CN move: a1e1 Move number: 59
# Qwen CN move: e5f4 Move number: 60
# Qwen CN move: c3c4 Move number: 61
# Qwen CN move: a6a5 Move number: 62
# Qwen CN move: Qxc7+ Move number: 63
# Qwen CN move: Bxc7 Move number: 64
# Qwen CN move: e1e6 Move number: 65
# Qwen CN move: Bf4 Move number: 66
# Qwen CN move: h1h3 Move number: 67
# Qwen CN move: Bg3 Move number: 68
# Qwen CN move: h3g3 Move number: 69
# Invalid move by Qwen black. Move: Rxh7
# New Move: Kb8
# Qwen CN move: Kb8 Move number: 70
# Qwen CN move: e6e7 Move number: 71
# Qwen CN move: Kc8 Move number: 72
# Qwen CN move: g3g8 Move number: 73
# Game 7 result: 1-0
#
#
# Starting game 8...
# Qwen CN move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen CN move: e5 Move number: 4
# Qwen CN move: f3e5 Move number: 5
# Qwen CN move: Nc6 Move number: 6
# Qwen CN move: Nxc6 Move number: 7
# Qwen CN move: d7c6 Move number: 8
# Qwen CN move: d2d3 Move number: 9
# Qwen CN move: f8d6 Move number: 10
# Qwen CN move: f1e2 Move number: 11
# Qwen CN move: d8c7 Move number: 12
# Qwen CN move: d1d2 Move number: 13
# Qwen CN move: c8e6 Move number: 14
# Qwen CN move: f2f4 Move number: 15
# Qwen CN move: f7f6 Move number: 16
# Qwen CN move: b1c3 Move number: 17
# Qwen CN move: e8c8 Move number: 18
# Qwen CN move: d2e3 Move number: 19
# Qwen CN move: h7h5 Move number: 20
# Qwen CN move: c1d2 Move number: 21
# Qwen CN move: Nh6 Move number: 22
# Qwen CN move: Qg3 Move number: 23
# Invalid move by Qwen black. Move: Qg5
# New Move: g5
# Qwen CN move: g5 Move number: 24
# Qwen CN move: h1f1 Move number: 25
# Qwen CN move: d8g8 Move number: 26
# Qwen CN move: Qg5 Move number: 27
# Qwen CN move: f6g5 Move number: 28
# Qwen CN move: f4g5 Move number: 29
# Qwen CN move: h6f7 Move number: 30
# Qwen CN move: f1f6 Move number: 31
# Qwen CN move: Rh6 Move number: 32
# Qwen CN move: g5h6 Move number: 33
# Qwen CN move: Bxh2 Move number: 34
# Qwen CN move: Rxf7 Move number: 35
# Qwen CN move: c7f7 Move number: 36
# Qwen CN move: e1c1 Move number: 37
# Qwen CN move: h2f4 Move number: 38
# Qwen CN move: c3a4 Move number: 39
# Qwen CN move: g8g2 Move number: 40
# Qwen CN move: c2c3 Move number: 41
# Qwen CN move: g2e2 Move number: 42
# Qwen CN move: h6h7 Move number: 43
# Qwen CN move: f4d2 Move number: 44
# Qwen CN move: d1d2 Move number: 45
# Qwen CN move: f7h7 Move number: 46
# Qwen CN move: d2e2 Move number: 47
# Qwen CN move: h7g8 Move number: 48
# Qwen CN move: c1c2 Move number: 49
# Qwen CN move: Qg1 Move number: 50
# Qwen CN move: Nb6+ Move number: 51
# Invalid move by Qwen black. Move:  Kb8
# New Move: Kd8
# Qwen CN move: Kd8 Move number: 52
# Qwen CN move: b6c4 Move number: 53
# Invalid move by Qwen black. Move: Nh5
# New Move: Bf7
# Qwen CN move: Bf7 Move number: 54
# Qwen CN move: c4d6 Move number: 55
# Invalid move by Qwen black. Move: Nxb7
# New Move: Bd5
# Qwen CN move: Bd5 Move number: 56
# Qwen CN move: e4d5 Move number: 57
# Qwen CN move: Qg8 Move number: 58
# Qwen CN move: d6b7 Move number: 59
# Qwen CN move: d8c8 Move number: 60
# Qwen CN move: e2e8 Move number: 61
# Qwen CN move: g8e8 Move number: 62
# Qwen CN move: Nd8 Move number: 63
# Qwen CN move: c6d5 Move number: 64
# Qwen CN move: Nf7 Move number: 65
# Qwen CN move: Qe4 Move number: 66
# Qwen CN move: d3e4 Move number: 67
# Qwen CN move: d5e4 Move number: 68
# Qwen CN move: c2d2 Move number: 69
# Qwen CN move: h5h4 Move number: 70
# Qwen CN move: f7g5 Move number: 71
# Qwen CN move: c5c4 Move number: 72
# Qwen CN move: d2e3 Move number: 73
# Qwen CN move: c8c7 Move number: 74
# Qwen CN move: e3e4 Move number: 75
# Qwen CN move: c7d6 Move number: 76
# Qwen CN move: e4d4 Move number: 77
# Qwen CN move: d6e7 Move number: 78
# Qwen CN move: g5f3 Move number: 79
# Qwen CN move: h4h3 Move number: 80
# Qwen CN move: Ng5 Move number: 81
# Invalid move by Qwen black. Move: Nf7
# New Move: Ke8
# Qwen CN move: Ke8 Move number: 82
# Qwen CN move: g5h3 Move number: 83
# Invalid move by Qwen black. Move: Nh5
# New Move: a6
# Qwen CN move: a6 Move number: 84
# Qwen CN move: d4c4 Move number: 85
# Qwen CN move: e8e7 Move number: 86
# Qwen CN move: Ng5 Move number: 87
# Qwen CN move: e7d6 Move number: 88
# Qwen CN move: c4d4 Move number: 89
# Qwen CN move: d6c6 Move number: 90
# Qwen CN move: c3c4 Move number: 91
# Qwen CN move: Kd7 Move number: 92
# Qwen CN move: d4d5 Move number: 93
# Invalid move by Qwen black. Move: Nh3
# New Move: a5
# Qwen CN move: a5 Move number: 94
# Qwen CN move: a2a4 Move number: 95
# Qwen CN move: d7c7 Move number: 96
# Qwen CN move: Nh3 Move number: 97
# Qwen CN move: c7d7 Move number: 98
# Qwen CN move: h3f4 Move number: 99
# Qwen CN move: d7e7 Move number: 100
# Qwen CN move: c4c5 Move number: 101
# Invalid move by Qwen black. Move: Nh3
# New Move: Kf6
# Qwen CN move: Kf6 Move number: 102
# Qwen CN move: c5c6 Move number: 103
# Qwen CN move: f6e7 Move number: 104
# Qwen CN move: Nh3 Move number: 105
# Qwen CN move: e7d8 Move number: 106
# Qwen CN move: d5c5 Move number: 107
# Qwen CN move: d8c7 Move number: 108
# Qwen CN move: h3f2 Move number: 109
# Invalid move by Qwen black. Move: Nd6
# New Move: Kb8
# Qwen CN move: Kb8 Move number: 110
# Qwen CN move: c5b6 Move number: 111
# Qwen CN move: b8c8 Move number: 112
# Qwen CN move: Nh3 Move number: 113
# Qwen CN move: c8b8 Move number: 114
# Qwen CN move: c6c7 Move number: 115
# Qwen CN move: b8c8 Move number: 116
# Qwen CN move: b2b3 Move number: 117
# Qwen CN move: Kd7 Move number: 118
# Qwen CN move: b6b7 Move number: 119
# Invalid move by Qwen black. Move: Kd5
# New Move: Ke8
# Qwen CN move: Ke8 Move number: 120
# Qwen CN move: c7c8q Move number: 121
# Qwen CN move: Kf7 Move number: 122
# Qwen CN move: b7c6 Move number: 123
# Qwen CN move: f7g6 Move number: 124
# Qwen CN move: c8g8 Move number: 125
# Qwen CN move: g6f5 Move number: 126
# Qwen CN move: Qh7+ Move number: 127
# Qwen CN move: f5g4 Move number: 128
# Qwen CN move: Qg8+ Move number: 129
# Qwen CN move: Kf3 Move number: 130
# Qwen CN move: h3g5 Move number: 131
# Qwen CN move: f3g4 Move number: 132
# Qwen CN move: g8d8 Move number: 133
# Qwen CN move: g4f5 Move number: 134
# Qwen CN move: d8a5 Move number: 135
# Qwen CN move: f5g4 Move number: 136
# Qwen CN move: a5e5 Move number: 137
# Qwen CN move: g4h5 Move number: 138
# Qwen CN move: e5f6 Move number: 139
# Qwen CN move: h5g4 Move number: 140
# Qwen CN move: a4a5 Move number: 141
# Qwen CN move: g4g3 Move number: 142
# Qwen CN move: a5a6 Move number: 143
# Qwen CN move: g3h4 Move number: 144
# Qwen CN move: Qh8+ Move number: 145
# Invalid move by Qwen black. Move: Nf4
# New Move: Kg3
# Qwen CN move: Kg3 Move number: 146
# Qwen CN move: h8h6 Move number: 147
# Qwen CN move: g3f4 Move number: 148
# Qwen CN move: Qh8 Move number: 149
# Qwen CN move: f4g5 Move number: 150
# Qwen CN move: h8h7 Move number: 151
# Qwen CN move: g5f6 Move number: 152
# Qwen CN move: b3b4 Move number: 153
# Qwen CN move: Kg5 Move number: 154
# Qwen CN move: b4b5 Move number: 155
# Invalid move by Qwen black. Move: Nf4
# New Move: Kf4
# Qwen CN move: Kf4 Move number: 156
# Qwen CN move: a6a7 Move number: 157
# Qwen CN move: f4g5 Move number: 158
# Qwen CN move: Qh8 Move number: 159
# Qwen CN move: g5f5 Move number: 160
# Qwen CN move: b5b6 Move number: 161
# Qwen CN move: f5e4 Move number: 162
# Qwen CN move: h8f6 Move number: 163
# Qwen CN move: Kd3 Move number: 164
# Qwen CN move: f6e6 Move number: 165
# Qwen CN move: Kd2 Move number: 166
# Invalid move by Qwen CN. Move: Qh8
# New Move: Qg6
# Qwen CN move: Qg6 Move number: 167
# Qwen CN move: d2e3 Move number: 168
# Qwen CN move: Qg8 Move number: 169
# Qwen CN move: e3f2 Move number: 170
# Qwen CN move: b6b7 Move number: 171
# Qwen CN move: f2e3 Move number: 172
# Qwen CN move: a7a8q Move number: 173
# Invalid move by Qwen black. Move: Nd6
# New Move: Ke4
# Qwen CN move: Ke4 Move number: 174
# Qwen CN move: g8g4 Move number: 175
# Invalid move by Qwen black. Move: Nf7
# New Move: Kd3
# Qwen CN move: Kd3 Move number: 176
# Qwen CN move: a8a3 Move number: 177
# Qwen CN move: d3c2 Move number: 178
# Qwen CN move: Qg8 Move number: 179
# Qwen CN move: c2d1 Move number: 180
# Qwen CN move: g8a2 Move number: 181
# Qwen CN move: d1e1 Move number: 182
# Qwen CN move: a3c1 Move number: 183
# Game 8 result: 1-0
#
#
# Starting game 9...
# Qwen CN move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen CN move: Nf3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen CN move: g7g6 Move number: 6
# Qwen CN move: e1g1 Move number: 7
# Qwen CN move: f8g7 Move number: 8
# Qwen CN move: c2c3 Move number: 9
# Qwen CN move: g8f6 Move number: 10
# Qwen CN move: f1e1 Move number: 11
# Qwen CN move: e8g8 Move number: 12
# Qwen CN move: d2d4 Move number: 13
# Qwen CN move: d7d5 Move number: 14
# Qwen CN move: e4e5 Move number: 15
# Qwen CN move: f6e4 Move number: 16
# Qwen CN move: c1e3 Move number: 17
# Qwen CN move: d8b6 Move number: 18
# Qwen CN move: Bxc6 Move number: 19
# Invalid move by Qwen black. Move: Bxc3
# New Move: Bh3
# Qwen CN move: Bh3 Move number: 20
# Qwen CN move: c6d5 Move number: 21
# Qwen CN move: Nf6 Move number: 22
# Qwen CN move: e5f6 Move number: 23
# Qwen CN move: b6f6 Move number: 24
# Qwen CN move: d5e4 Move number: 25
# Qwen CN move: h3d7 Move number: 26
# Qwen CN move: Bxb7 Move number: 27
# Qwen CN move: a8b8 Move number: 28
# Qwen CN move: Bh6 Move number: 29
# Qwen CN move: Rxb7 Move number: 30
# Qwen CN move: h6g7 Move number: 31
# Qwen CN move: g8g7 Move number: 32
# Qwen CN move: b2b3 Move number: 33
# Qwen CN move: d7g4 Move number: 34
# Qwen CN move: b1d2 Move number: 35
# Qwen CN move: c5d4 Move number: 36
# Qwen CN move: c3c4 Move number: 37
# Qwen CN move: e7e5 Move number: 38
# Qwen CN move: h2h3 Move number: 39
# Qwen CN move: g4f3 Move number: 40
# Qwen CN move: d1f3 Move number: 41
# Qwen CN move: f6f3 Move number: 42
# Qwen CN move: d2f3 Move number: 43
# Qwen CN move: f7f6 Move number: 44
# Qwen CN move: Nh2 Move number: 45
# Qwen CN move: Rb6 Move number: 46
# Qwen CN move: Re4 Move number: 47
# Qwen CN move: f8e8 Move number: 48
# Qwen CN move: e4e1 Move number: 49
# Qwen CN move: e5e4 Move number: 50
# Qwen CN move: a1d1 Move number: 51
# Qwen CN move: d4d3 Move number: 52
# Qwen CN move: h2f1 Move number: 53
# Qwen CN move: b6d6 Move number: 54
# Qwen CN move: Nh2 Move number: 55
# Qwen CN move: f6f5 Move number: 56
# Qwen CN move: Ng4 Move number: 57
# Qwen CN move: f5g4 Move number: 58
# Qwen CN move: e1e3 Move number: 59
# Qwen CN move: g4g3 Move number: 60
# Qwen CN move: f2f3 Move number: 61
# Qwen CN move: d6e6 Move number: 62
# Qwen CN move: Rxe4 Move number: 63
# Qwen CN move: e6e4 Move number: 64
# Qwen CN move: f3e4 Move number: 65
# Qwen CN move: e8e4 Move number: 66
# Qwen CN move: g1f1 Move number: 67
# Qwen CN move: e4d4 Move number: 68
# Qwen CN move: c4c5 Move number: 69
# Qwen CN move: g7f7 Move number: 70
# Qwen CN move: f1e1 Move number: 71
# Qwen CN move: d4e4 Move number: 72
# Qwen CN move: e1d2 Move number: 73
# Invalid move by Qwen black. Move: Kf1
# New Move: Re1
# Qwen CN move: Re1 Move number: 74
# Qwen CN move: d1e1 Move number: 75
# Qwen CN move: g6g5 Move number: 76
# Qwen CN move: Re2 Move number: 77
# Qwen CN move: d3e2 Move number: 78
# Qwen CN move: d2e2 Move number: 79
# Qwen CN move: f7e6 Move number: 80
# Qwen CN move: e2f3 Move number: 81
# Invalid move by Qwen black. Move: Kf2
# New Move: h5
# Qwen CN move: h5 Move number: 82
# Qwen CN move: f3g3 Move number: 83
# Qwen CN move: e6e5 Move number: 84
# Invalid move by Qwen CN. Move: Ke4
# New Move: Kh2
# Qwen CN move: Kh2 Move number: 85
# Qwen CN move: e5d5 Move number: 86
# Qwen CN move: g3 Move number: 87
# Qwen CN move: d5c5 Move number: 88
# Qwen CN move: h2g2 Move number: 89
# Qwen CN move: g5g4 Move number: 90
# Qwen CN move: h3g4 Move number: 91
# Invalid move by Qwen black. Move: Kf2
# New Move: a5
# Qwen CN move: a5 Move number: 92
# Qwen CN move: g4h5 Move number: 93
# Qwen CN move: c5b4 Move number: 94
# Qwen CN move: Kh1 Move number: 95
# Qwen CN move: b4a3 Move number: 96
# Qwen CN move: h5h6 Move number: 97
# Qwen CN move: a3a2 Move number: 98
# Qwen CN move: h6h7 Move number: 99
# Qwen CN move: Kxb3 Move number: 100
# Qwen CN move: h7h8q Move number: 101
# Qwen CN move: Kc4 Move number: 102
# Qwen CN move: Qg8+ Move number: 103
# Qwen CN move: c4b5 Move number: 104
# Qwen CN move: g8b8 Move number: 105
# Qwen CN move: b5c6 Move number: 106
# Qwen CN move: h1g2 Move number: 107
# Qwen CN move: c6c5 Move number: 108
# Qwen CN move: g2h3 Move number: 109
# Qwen CN move: a5a4 Move number: 110
# Qwen CN move: b8b2 Move number: 111
# Qwen CN move: c5c6 Move number: 112
# Qwen CN move: b2b4 Move number: 113
# Qwen CN move: c6d5 Move number: 114
# Qwen CN move: b4a4 Move number: 115
# Qwen CN move: d5e6 Move number: 116
# Qwen CN move: g3g4 Move number: 117
# Qwen CN move: Kf7 Move number: 118
# Qwen CN move: Qe8+ Move number: 119
# Qwen CN move: Kf6 Move number: 120
# Qwen CN move: h3h4 Move number: 121
# Qwen CN move: f6g7 Move number: 122
# Qwen CN move: h4g5 Move number: 123
# Qwen CN move: g7h7 Move number: 124
# Qwen CN move: g5f6 Move number: 125
# Qwen CN move: h7h6 Move number: 126
# Qwen CN move: e8h5 Move number: 127
# Game 9 result: 1-0
#
#
# Starting game 10...
# Qwen CN move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen CN move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen CN move: d2d4 Move number: 5
# Qwen CN move: e5d4 Move number: 6
# Qwen CN move: f3d4 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen CN move: Nxc6 Move number: 9
# Qwen CN move: b7c6 Move number: 10
# Qwen CN move: f1d3 Move number: 11
# Qwen CN move: d7d5 Move number: 12
# Qwen CN move: e4e5 Move number: 13
# Qwen CN move: f6g4 Move number: 14
# Qwen CN move: e1g1 Move number: 15
# Qwen CN move: f8c5 Move number: 16
# Qwen CN move: c1f4 Move number: 17
# Qwen CN move: g7g5 Move number: 18
# Qwen CN move: f4d2 Move number: 19
# Invalid move by Qwen black. Move: Bxd5
# New Move: Qf6
# Qwen CN move: Qf6 Move number: 20
# Qwen CN move: e5f6 Move number: 21
# Qwen CN move: Bxf2+ Move number: 22
# Qwen CN move: f1f2 Move number: 23
# Qwen CN move: e8d8 Move number: 24
# Qwen CN move: f2e2 Move number: 25
# Qwen CN move: g4h2 Move number: 26
# Qwen CN move: Bxh7 Move number: 27
# Qwen CN move: h2g4 Move number: 28
# Qwen CN move: Re3 Move number: 29
# Qwen CN move: Rxh7 Move number: 30
# Qwen CN move: e3h3 Move number: 31
# Qwen CN move: h7h3 Move number: 32
# Qwen CN move: g2h3 Move number: 33
# Qwen CN move: g4e5 Move number: 34
# Qwen CN move: d1e2 Move number: 35
# Qwen CN move: e5g6 Move number: 36
# Qwen CN move: g1f2 Move number: 37
# Qwen CN move: c8h3 Move number: 38
# Qwen CN move: a2a4 Move number: 39
# Qwen CN move: a8b8 Move number: 40
# Qwen CN move: b2b4 Move number: 41
# Qwen CN move: d8d7 Move number: 42
# Qwen CN move: b4b5 Move number: 43
# Qwen CN move: c6b5 Move number: 44
# Qwen CN move: Qe8+ Move number: 45
# Qwen CN move: Kd6 Move number: 46
# Qwen CN move: Qxf7 Move number: 47
# Qwen CN move: b5a4 Move number: 48
# Qwen CN move: f7g6 Move number: 49
# Qwen CN move: a7a5 Move number: 50
# Qwen CN move: d2g5 Move number: 51
# Qwen CN move: d6c6 Move number: 52
# Qwen CN move: f6f7 Move number: 53
# Qwen CN move: c6b7 Move number: 54
# Qwen CN move: Qg8 Move number: 55
# Qwen CN move: h3d7 Move number: 56
# Qwen CN move: Qh8 Move number: 57
# Qwen CN move: b8h8 Move number: 58
# Qwen CN move: g5e7 Move number: 59
# Qwen CN move: h8h1 Move number: 60
# Qwen CN move: f7f8q Move number: 61
# Qwen CN move: d5d4 Move number: 62
# Qwen CN move: Qh6 Move number: 63
# Qwen CN move: h1h6 Move number: 64
# Qwen CN move: b1a3 Move number: 65
# Qwen CN move: h6h5 Move number: 66
# Qwen CN move: a1e1 Move number: 67
# Qwen CN move: c7c5 Move number: 68
# Qwen CN move: f2e2 Move number: 69
# Qwen CN move: b7c6 Move number: 70
# Qwen CN move: e2d2 Move number: 71
# Qwen CN move: h5h3 Move number: 72
# Qwen CN move: a3c4 Move number: 73
# Qwen CN move: Be8 Move number: 74
# Qwen CN move: c4e5 Move number: 75
# Qwen CN move: c6d5 Move number: 76
# Qwen CN move: e5d3 Move number: 77
# Qwen CN move: h3h2 Move number: 78
# Qwen CN move: d2c1 Move number: 79
# Qwen CN move: c5c4 Move number: 80
# Qwen CN move: d3f4 Move number: 81
# Invalid move by Qwen black. Move: Nxf2+
# New Move: Kc6
# Qwen CN move: Kc6 Move number: 82
# Qwen CN move: e1e6 Move number: 83
# Invalid move by Qwen black. Move: Re8
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 84
# Qwen CN move: e7c5 Move number: 85
# Invalid move by Qwen black. Move: Bxc4
# New Move: a3
# Qwen CN move: a3 Move number: 86
# Qwen CN move: e6e7 Move number: 87
# Qwen CN move: d7c6 Move number: 88
# Qwen CN move: Re1 Move number: 89
# Qwen CN move: c6c5 Move number: 90
# Qwen CN move: f4e6 Move number: 91
# Qwen CN move: c5b4 Move number: 92
# Qwen CN move: e6d4 Move number: 93
# Qwen CN move: Rxc2+ Move number: 94
# Qwen CN move: d4c2 Move number: 95
# Invalid move by Qwen black. Move: Nc4
# New Move: Kc5
# Qwen CN move: Kc5 Move number: 96
# Qwen CN move: e1e8 Move number: 97
# Invalid move by Qwen black. Move: Re1
# New Move: Kc6
# Qwen CN move: Kc6 Move number: 98
# Qwen CN move: c2a3 Move number: 99
# Invalid move by Qwen black. Move: Rd1
# New Move: Kc7
# Qwen CN move: Kc7 Move number: 100
# Qwen CN move: a3c4 Move number: 101
# Invalid move by Qwen black. Move: Re1
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 102
# Qwen CN move: e8e5 Move number: 103
# Invalid move by Qwen black. Move: Re1
# New Move: Kd8
# Qwen CN move: Kd8 Move number: 104
# Qwen CN move: c4a5 Move number: 105
# Invalid move by Qwen black. Move: Re1
# New Move: Kc7
# Qwen CN move: Kc7 Move number: 106
# Qwen CN move: e5d5 Move number: 107
# Qwen CN move: c7c8 Move number: 108
# Qwen CN move: Rd8+ Move number: 109
# Qwen CN move: c8d8 Move number: 110
# Game 10 result: 1/2-1/2
#
#
# Starting game 11...
# Qwen CN move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Invalid move by Qwen black. Move: Nc6
# New Move: g5
# Qwen CN move: g5 Move number: 6
# Qwen CN move: f3g5 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen CN move: Nxe6 Move number: 9
# Qwen CN move: d7e6 Move number: 10
# Qwen CN move: e4e5 Move number: 11
# Qwen CN move: f6d7 Move number: 12
# Qwen CN move: b5c6 Move number: 13
# Invalid move by Qwen black. Move: Bxc6
# New Move: Qc7
# Qwen CN move: Qc7 Move number: 14
# Qwen CN move: c6d7 Move number: 15
# Qwen CN move: Bxd7 Move number: 16
# Qwen CN move: d1e2 Move number: 17
# Qwen CN move: d7c6 Move number: 18
# Qwen CN move: e1g1 Move number: 19
# Qwen CN move: h8g8 Move number: 20
# Qwen CN move: Qe4 Move number: 21
# Qwen CN move: c6e4 Move number: 22
# Qwen CN move: d3 Move number: 23
# Qwen CN move: Rg5 Move number: 24
# Qwen CN move: c1g5 Move number: 25
# Qwen CN move: e4d5 Move number: 26
# Qwen CN move: f1e1 Move number: 27
# Qwen CN move: c7c6 Move number: 28
# Qwen CN move: b1c3 Move number: 29
# Qwen CN move: d5g2 Move number: 30
# Qwen CN move: e1e3 Move number: 31
# Qwen CN move: g2f3 Move number: 32
# Qwen CN move: c3e4 Move number: 33
# Qwen CN move: f3e4 Move number: 34
# Qwen CN move: d3e4 Move number: 35
# Qwen CN move: c5c4 Move number: 36
# Qwen CN move: b2b3 Move number: 37
# Qwen CN move: a8d8 Move number: 38
# Qwen CN move: Bh4 Move number: 39
# Qwen CN move: Rd1+ Move number: 40
# Qwen CN move: Re1 Move number: 41
# Qwen CN move: d1a1 Move number: 42
# Qwen CN move: e1a1 Move number: 43
# Qwen CN move: c6e4 Move number: 44
# Qwen CN move: h4g3 Move number: 45
# Qwen CN move: e4c2 Move number: 46
# Qwen CN move: b3c4 Move number: 47
# Qwen CN move: f7f5 Move number: 48
# Qwen CN move: Bh4 Move number: 49
# Qwen CN move: c2c4 Move number: 50
# Qwen CN move: Bxe7 Move number: 51
# Qwen CN move: e8e7 Move number: 52
# Qwen CN move: a1b1 Move number: 53
# Qwen CN move: c4g4 Move number: 54
# Qwen CN move: g1f1 Move number: 55
# Qwen CN move: g4c4 Move number: 56
# Qwen CN move: Kg2 Move number: 57
# Qwen CN move: c4e4 Move number: 58
# Qwen CN move: g2f1 Move number: 59
# Qwen CN move: e4b1 Move number: 60
# Qwen CN move: f1g2 Move number: 61
# Qwen CN move: e7d7 Move number: 62
# Qwen CN move: h2h4 Move number: 63
# Qwen CN move: d7c6 Move number: 64
# Qwen CN move: h4h5 Move number: 65
# Qwen CN move: b1e4 Move number: 66
# Qwen CN move: g2g3 Move number: 67
# Invalid move by Qwen black. Move: Bh4
# New Move: Kd7
# Qwen CN move: Kd7 Move number: 68
# Qwen CN move: h5h6 Move number: 69
# Qwen CN move: Bxh6 Move number: 70
# Qwen CN move: f2f3 Move number: 71
# Qwen CN move: e4e1 Move number: 72
# Qwen CN move: g3g2 Move number: 73
# Qwen CN move: d7d8 Move number: 74
# Qwen CN move: f4 Move number: 75
# Qwen CN move: h6f4 Move number: 76
# Qwen CN move: Kh3 Move number: 77
# Qwen CN move: Qf1+ Move number: 78
# Qwen CN move: h3h4 Move number: 79
# Qwen CN move: f1h1 Move number: 80
# Game 11 result: 0-1
#
#
# Starting game 12...
# Qwen CN move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen CN move: b5a4 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen CN move: e1g1 Move number: 9
# Qwen CN move: f6e4 Move number: 10
# Qwen CN move: d2d4 Move number: 11
# Qwen CN move: b7b5 Move number: 12
# Qwen CN move: Bb3 Move number: 13
# Qwen CN move: Bd6 Move number: 14
# Qwen CN move: Nxe5 Move number: 15
# Qwen CN move: e8g8 Move number: 16
# Qwen CN move: f1e1 Move number: 17
# Qwen CN move: e4g5 Move number: 18
# Qwen CN move: a2a4 Move number: 19
# Qwen CN move: a8b8 Move number: 20
# Qwen CN move: b1c3 Move number: 21
# Qwen CN move: d6e5 Move number: 22
# Qwen CN move: Re2 Move number: 23
# Qwen CN move: e5f6 Move number: 24
# Qwen CN move: Nd5 Move number: 25
# Qwen CN move: c6d4 Move number: 26
# Qwen CN move: e2e3 Move number: 27
# Qwen CN move: c8b7 Move number: 28
# Qwen CN move: a4b5 Move number: 29
# Qwen CN move: a6b5 Move number: 30
# Qwen CN move: Nxc7 Move number: 31
# Qwen CN move: d8c7 Move number: 32
# Qwen CN move: e3g3 Move number: 33
# Qwen CN move: g5e6 Move number: 34
# Qwen CN move: a1a3 Move number: 35
# Qwen CN move: d4f5 Move number: 36
# Qwen CN move: g3d3 Move number: 37
# Qwen CN move: b8a8 Move number: 38
# Qwen CN move: a3a8 Move number: 39
# Qwen CN move: f8a8 Move number: 40
# Qwen CN move: b3e6 Move number: 41
# Invalid move by Qwen black. Move: Rd1
# New Move: Bh4
# Qwen CN move: Bh4 Move number: 42
# Qwen CN move: e6f5 Move number: 43
# Qwen CN move: c7c5 Move number: 44
# Qwen CN move: Bxd7 Move number: 45
# Qwen CN move: c5f2 Move number: 46
# Qwen CN move: g1h1 Move number: 47
# Qwen CN move: b7g2 Move number: 48
# Game 12 result: 0-1
#
#
# Starting game 13...
# Qwen CN move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen CN move: Nxe5 Move number: 5
# Qwen CN move: c6e5 Move number: 6
# Qwen CN move: d2d4 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Qwen CN move: c2c4 Move number: 9
# Qwen CN move: f8b4 Move number: 10
# Qwen CN move: b1c3 Move number: 11
# Qwen CN move: c7c5 Move number: 12
# Qwen CN move: h2h4 Move number: 13
# Qwen CN move: h7h5 Move number: 14
# Qwen CN move: f1e2 Move number: 15
# Qwen CN move: c5d4 Move number: 16
# Qwen CN move: d1d4 Move number: 17
# Qwen CN move: d8f6 Move number: 18
# Qwen CN move: c1e3 Move number: 19
# Qwen CN move: Nh6 Move number: 20
# Qwen CN move: Qxd7+ Move number: 21
# Invalid move by Qwen black. Move: Qxe5
# New Move: Bxd7
# Qwen CN move: Bxd7 Move number: 22
# Qwen CN move: e1c1 Move number: 23
# Qwen CN move: b4c3 Move number: 24
# Qwen CN move: Bf1 Move number: 25
# Qwen CN move: c3b2 Move number: 26
# Qwen CN move: c1b1 Move number: 27
# Qwen CN move: d7c6 Move number: 28
# Qwen CN move: e3g5 Move number: 29
# Qwen CN move: Ng4 Move number: 30
# Qwen CN move: f2f3 Move number: 31
# Qwen CN move: Rg8 Move number: 32
# Qwen CN move: Bh6 Move number: 33
# Qwen CN move: g7h6 Move number: 34
# Qwen CN move: c4c5 Move number: 35
# Qwen CN move: g4f2 Move number: 36
# Qwen CN move: d1d6 Move number: 37
# Qwen CN move: b2e5 Move number: 38
# Qwen CN move: d6f6 Move number: 39
# Qwen CN move: e5f6 Move number: 40
# Qwen CN move: f1c4 Move number: 41
# Qwen CN move: f2h1 Move number: 42
# Qwen CN move: g2g4 Move number: 43
# Qwen CN move: h1f2 Move number: 44
# Qwen CN move: g4h5 Move number: 45
# Qwen CN move: g6e5 Move number: 46
# ...
# Qwen CN move: b8c6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen CN move: b5a4 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen CN move: e1g1 Move number: 9
# Qwen CN move: b7b5 Move number: 10
# Qwen CN move: Bxb5 Move number: 11
# Qwen CN move: a6b5 Move number: 12
# Qwen CN move: Nxe5 Move number: 13
# Qwen CN move: c6e5 Move number: 14
# Qwen CN move: d2d4 Move number: 15
# Qwen CN move: e5g6 Move number: 16
# Qwen CN move: e4e5 Move number: 17
# Qwen CN move: f6d5 Move number: 18
# Qwen CN move: Qe2 Move number: 19
# Qwen CN move: a8b8 Move number: 20
# Qwen CN move: a2a4 Move number: 21
# Qwen CN move: b8a8 Move number: 22
# Qwen CN move: e2b5 Move number: 23
# Qwen CN move: c7c6 Move number: 24
# Qwen CN move: b5e2 Move number: 25
# Qwen CN move: c8a6 Move number: 26
# Qwen CN move: c2c4 Move number: 27
# Qwen CN move: d5f4 Move number: 28
# Qwen CN move: e2c2 Move number: 29
# Qwen CN move: Bxc4 Move number: 30
# Qwen CN move: c2c4 Move number: 31
# Qwen CN move: d8a5 Move number: 32
# Qwen CN move: c1d2 Move number: 33
# Qwen CN move: a5a6 Move number: 34
# Qwen CN move: c4a6 Move number: 35
# Qwen CN move: a8a6 Move number: 36
# Qwen CN move: b1c3 Move number: 37
# Qwen CN move: Nh4 Move number: 38
# Qwen CN move: d2f4 Move number: 39
# Qwen CN move: f8b4 Move number: 40
# Qwen CN move: f1d1 Move number: 41
# Qwen CN move: h4g6 Move number: 42
# Qwen CN move: Bh6 Move number: 43
# Qwen CN move: g7h6 Move number: 44
# Qwen CN move: c3e4 Move number: 45
# Qwen CN move: Nf4 Move number: 46
# Qwen CN move: e4f6 Move number: 47
# Qwen CN move: Kd8 Move number: 48
# Qwen CN move: d4d5 Move number: 49
# Qwen CN move: f4d5 Move number: 50
# Qwen CN move: f6d5 Move number: 51
# Qwen CN move: c6d5 Move number: 52
# Qwen CN move: d1d5 Move number: 53
# Qwen CN move: a6a5 Move number: 54
# Qwen CN move: d5d4 Move number: 55
# Invalid move by Qwen black. Move: Rd7
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 56
# Qwen CN move: a1a3 Move number: 57
# Qwen CN move: a5e5 Move number: 58
# Qwen CN move: Rxd7+ Move number: 59
# Qwen CN move: d8d7 Move number: 60
# Qwen CN move: g2g3 Move number: 61
# Qwen CN move: h6h5 Move number: 62
# Qwen CN move: b2b4 Move number: 63
# Qwen CN move: Re1+ Move number: 64
# Qwen CN move: g1g2 Move number: 65
# Invalid move by Qwen black. Move: Re1
# New Move: Ke8
# Qwen CN move: Ke8 Move number: 66
# Qwen CN move: b4b5 Move number: 67
# Qwen CN move: Re2 Move number: 68
# Qwen CN move: a4a5 Move number: 69
# Qwen CN move: e2b2 Move number: 70
# Qwen CN move: b5b6 Move number: 71
# Qwen CN move: e8e7 Move number: 72
# Qwen CN move: Rd3 Move number: 73
# Qwen CN move: b2b5 Move number: 74
# Qwen CN move: Rd8 Move number: 75
# Invalid move by Qwen black. Move: Rd4
# New Move: h4
# Qwen CN move: h4 Move number: 76
# Qwen CN move: d8h8 Move number: 77
# Qwen CN move: e7f6 Move number: 78
# Qwen CN move: Rd8 Move number: 79
# Qwen CN move: f6e7 Move number: 80
# Qwen CN move: d8a8 Move number: 81
# Qwen CN move: h4g3 Move number: 82
# Qwen CN move: h2g3 Move number: 83
# Invalid move by Qwen black. Move: Rd8
# New Move: Kd6
# Qwen CN move: Kd6 Move number: 84
# Qwen CN move: a5a6 Move number: 85
# Qwen CN move: Rxb6 Move number: 86
# Qwen CN move: a6a7 Move number: 87
# Qwen CN move: b6a6 Move number: 88
# Qwen CN move: a8d8 Move number: 89
# Qwen CN move: d6c5 Move number: 90
# Qwen CN move: Rd4 Move number: 91
# Qwen CN move: c5d4 Move number: 92
# Qwen CN move: Kh3 Move number: 93
# Qwen CN move: Rd6 Move number: 94
# Qwen CN move: a7a8q Move number: 95
# Qwen CN move: d4e5 Move number: 96
# Qwen CN move: a8f8 Move number: 97
# Qwen CN move: d6d7 Move number: 98
# Qwen CN move: f8e8 Move number: 99
# Qwen CN move: e5d6 Move number: 100
# Qwen CN move: h3h4 Move number: 101
# Qwen CN move: d7e7 Move number: 102
# Qwen CN move: e8d8 Move number: 103
# Qwen CN move: e7d7 Move number: 104
# Qwen CN move: d8f6 Move number: 105
# Qwen CN move: d6d5 Move number: 106
# Qwen CN move: f2f4 Move number: 107
# Qwen CN move: d5c5 Move number: 108
# Qwen CN move: Qf5+ Move number: 109
# Qwen CN move: Rd5 Move number: 110
# Qwen CN move: Qc8+ Move number: 111
# Qwen CN move: c5d4 Move number: 112
# Qwen CN move: c8h8 Move number: 113
# Qwen CN move: d4c4 Move number: 114
# Qwen CN move: h8h7 Move number: 115
# Qwen CN move: d5d7 Move number: 116
# Qwen CN move: h7f5 Move number: 117
# Qwen CN move: d7a7 Move number: 118
# Qwen CN move: Qh7 Move number: 119
# Qwen CN move: c4d5 Move number: 120
# Qwen CN move: Qh8 Move number: 121
# Qwen CN move: d5c6 Move number: 122
# Qwen CN move: h8e8 Move number: 123
# Qwen CN move: a7d7 Move number: 124
# Qwen CN move: h4g5 Move number: 125
# Qwen CN move: c6c7 Move number: 126
# Qwen CN move: Qh8 Move number: 127
# Qwen CN move: d7d1 Move number: 128
# Qwen CN move: h8e8 Move number: 129
# Qwen CN move: f7f5 Move number: 130
# Qwen CN move: g5f5 Move number: 131
# Qwen CN move: d1c1 Move number: 132
# Qwen CN move: g3g4 Move number: 133
# Qwen CN move: c7b7 Move number: 134
# Qwen CN move: e8e7 Move number: 135
# Qwen CN move: b7c6 Move number: 136
# Qwen CN move: g4g5 Move number: 137
# Invalid move by Qwen black. Move: Rd8+
# New Move: Re1
# Qwen CN move: Re1 Move number: 138
# Qwen CN move: e7e1 Move number: 139
# Qwen CN move: c6b5 Move number: 140
# Invalid move by Qwen CN. Move: Qh8+
# New Move: Qh1
# Qwen CN move: Qh1 Move number: 141
# Qwen CN move: b5c5 Move number: 142
# Qwen CN move: f5f6 Move number: 143
# Qwen CN move: Kd4 Move number: 144
# Qwen CN move: h1c6 Move number: 145
# Qwen CN move: d4e3 Move number: 146
# Qwen CN move: g5g6 Move number: 147
# Qwen CN move: e3d2 Move number: 148
# Qwen CN move: Qh1 Move number: 149
# Qwen CN move: d2c3 Move number: 150
# Qwen CN move: Qh8 Move number: 151
# Invalid move by Qwen black. Move: Qh5
# New Move: Kc4
# Qwen CN move: Kc4 Move number: 152
# Qwen CN move: h8c8 Move number: 153
# Qwen CN move: Kd3 Move number: 154
# Qwen CN move: c8e6 Move number: 155
# Qwen CN move: d3d4 Move number: 156
# Qwen CN move: f4f5 Move number: 157
# Qwen CN move: d4d3 Move number: 158
# Invalid move by Qwen CN. Move: Qe6
# New Move: Qb3+
# Qwen CN move: Qb3+ Move number: 159
# Qwen CN move: d3d2 Move number: 160
# Qwen CN move: g6g7 Move number: 161
# Qwen CN move: Kc1 Move number: 162
# Qwen CN move: g7g8q Move number: 163
# Qwen CN move: c1d2 Move number: 164
# Qwen CN move: g8g2 Move number: 165
# Qwen CN move: d2e1 Move number: 166
# Qwen CN move: Qd1+ Move number: 167
# Qwen CN move: e1d1 Move number: 168
# Invalid move by Qwen CN. Move: Qh8+
# New Move: Qh2
# Qwen CN move: Qh2 Move number: 169
# Qwen CN move: d1c1 Move number: 170
# Qwen CN move: f6e6 Move number: 171
# Invalid move by Qwen black. Move: Qh5
# New Move: Kd1
# Qwen CN move: Kd1 Move number: 172
# Qwen CN move: f5f6 Move number: 173
# Invalid move by Qwen black. Move: Qh5
# New Move: Ke1
# Qwen CN move: Ke1 Move number: 174
# Qwen CN move: f6f7 Move number: 175
# Qwen CN move: Kd1 Move number: 176
# Qwen CN move: f7f8q Move number: 177
# Qwen CN move: d1e1 Move number: 178
# Qwen CN move: f8b4 Move number: 179
# Qwen CN move: e1f1 Move number: 180
# Invalid move by Qwen CN. Move: Qb4+
# New Move: Qhf4+
# Qwen CN move: Qhf4+ Move number: 181
# Qwen CN move: f1g2 Move number: 182
# Qwen CN move: b4b1 Move number: 183
# Invalid move by Qwen black. Move: Qb5+
# New Move: Kh3
# Qwen CN move: Kh3 Move number: 184
# Qwen CN move: b1f1 Move number: 185
# Game 97 result: 1-0
#
#
# Starting game 98...
# Qwen CN move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen CN move: f1b5 Move number: 5
# Qwen CN move: Nge7 Move number: 6
# Qwen CN move: b1c3 Move number: 7
# Qwen CN move: Nf5 Move number: 8
# Qwen CN move: Bxc6 Move number: 9
# Qwen CN move: d7c6 Move number: 10
# Qwen CN move: e4f5 Move number: 11
# Qwen CN move: c8f5 Move number: 12
# Qwen CN move: e1g1 Move number: 13
# Qwen CN move: d8f6 Move number: 14
# Qwen CN move: f1e1 Move number: 15
# Qwen CN move: e8c8 Move number: 16
# Qwen CN move: d2d3 Move number: 17
# Qwen CN move: f5g4 Move number: 18
# Qwen CN move: h2h3 Move number: 19
# Qwen CN move: h7h5 Move number: 20
# Qwen CN move: d1e2 Move number: 21
# Qwen CN move: g4f3 Move number: 22
# Qwen CN move: e2f3 Move number: 23
# Qwen CN move: Rg8 Move number: 24
# Qwen CN move: Qxf6 Move number: 25
# Qwen CN move: Rd5 Move number: 26
# Qwen CN move: f6f7 Move number: 27
# Qwen CN move: d5d8 Move number: 28
# Qwen CN move: f7e6 Move number: 29
# Qwen CN move: c8b8 Move number: 30
# Qwen CN move: e6g8 Move number: 31
# Qwen CN move: f8e7 Move number: 32
# Qwen CN move: g8d8 Move number: 33
# Qwen CN move: Bxd8 Move number: 34
# Qwen CN move: c1e3 Move number: 35
# Qwen CN move: Be7 Move number: 36
# Qwen CN move: c3e4 Move number: 37
# Qwen CN move: b8c8 Move number: 38
# Qwen CN move: a2a3 Move number: 39
# Qwen CN move: g7g5 Move number: 40
# Qwen CN move: e4g5 Move number: 41
# Qwen CN move: Bxg5 Move number: 42
# Qwen CN move: e3g5 Move number: 43
# Qwen CN move: c8d7 Move number: 44
# Qwen CN move: e1e5 Move number: 45
# Qwen CN move: d7c8 Move number: 46
# Qwen CN move: e5e8 Move number: 47
# Qwen CN move: c8d7 Move number: 48
# Qwen CN move: e8d8 Move number: 49
# Qwen CN move: d7e6 Move number: 50
# Qwen CN move: a1e1 Move number: 51
# Qwen CN move: e6f5 Move number: 52
# Qwen CN move: Rd4 Move number: 53
# Qwen CN move: f5g5 Move number: 54
# Qwen CN move: e1e6 Move number: 55
# Qwen CN move: b7b6 Move number: 56
# Qwen CN move: e6c6 Move number: 57
# Qwen CN move: b6b5 Move number: 58
# Qwen CN move: g2g3 Move number: 59
# Qwen CN move: b5b4 Move number: 60
# Qwen CN move: Rxc7 Move number: 61
# Qwen CN move: g5f6 Move number: 62
# Qwen CN move: d4d6 Move number: 63
# Qwen CN move: f6e5 Move number: 64
# Qwen CN move: c7d7 Move number: 65
# Invalid move by Qwen black. Move: Rxd8+
# New Move: a5
# Qwen CN move: a5 Move number: 66
# Qwen CN move: f2f4 Move number: 67
# Qwen CN move: e5f5 Move number: 68
# Qwen CN move: Rd5+ Move number: 69
# Qwen CN move: f5e6 Move number: 70
# Qwen CN move: d5d6 Move number: 71
# Qwen CN move: e6f5 Move number: 72
# Qwen CN move: d7f7 Move number: 73
# Game 98 result: 1-0
#
#
# Starting game 99...
# Qwen CN move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen CN move: e5 Move number: 3
# Qwen CN move: e6 Move number: 4
# Qwen CN move: g1f3 Move number: 5
# Qwen CN move: b8c6 Move number: 6
# Qwen CN move: c2c3 Move number: 7
# Qwen CN move: d7d6 Move number: 8
# Qwen CN move: e5d6 Move number: 9
# Qwen CN move: g8f6 Move number: 10
# Qwen CN move: d2d4 Move number: 11
# Qwen CN move: c5d4 Move number: 12
# Qwen CN move: f3d4 Move number: 13
# Qwen CN move: d8d6 Move number: 14
# Qwen CN move: d4c6 Move number: 15
# Qwen CN move: d6c6 Move number: 16
# Qwen CN move: b1d2 Move number: 17
# Qwen CN move: c8d7 Move number: 18
# Qwen CN move: Ne4 Move number: 19
# Invalid move by Qwen black. Move: Nc3
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 20
# Qwen CN move: e4f6 Move number: 21
# Qwen CN move: Qc5 Move number: 22
# Qwen CN move: f6d7 Move number: 23
# Qwen CN move: c5f5 Move number: 24
# Qwen CN move: d7f8 Move number: 25
# Qwen CN move: a8d8 Move number: 26
# Qwen CN move: Nh7 Move number: 27
# Qwen CN move: d8d1 Move number: 28
# Qwen CN move: Ke2 Move number: 29
# Qwen CN move: Rg8 Move number: 30
# Qwen CN move: c1g5 Move number: 31
# Qwen CN move: f7f6 Move number: 32
# Qwen CN move: a1d1 Move number: 33
# Qwen CN move: f6g5 Move number: 34
# Qwen CN move: e2e1 Move number: 35
# Qwen CN move: f5e4 Move number: 36
# Qwen CN move: f1e2 Move number: 37
# Qwen CN move: g8h8 Move number: 38
# Qwen CN move: f2f3 Move number: 39
# Qwen CN move: e4h7 Move number: 40
# Qwen CN move: e1d2 Move number: 41
# Qwen CN move: h8d8 Move number: 42
# Qwen CN move: d2c1 Move number: 43
# Qwen CN move: d8d1 Move number: 44
# Qwen CN move: Kxd1 Move number: 45
# Qwen CN move: Qe4 Move number: 46
# Qwen CN move: Bd3 Move number: 47
# Qwen CN move: e4d3 Move number: 48
# Qwen CN move: d1c1 Move number: 49
# Qwen CN move: d3e3 Move number: 50
# Qwen CN move: c1b1 Move number: 51
# Qwen CN move: e3e2 Move number: 52
# Qwen CN move: g2g3 Move number: 53
# Qwen CN move: g5g4 Move number: 54
# Qwen CN move: Rg1 Move number: 55
# Qwen CN move: g4f3 Move number: 56
# Qwen CN move: Rg2 Move number: 57
# Qwen CN move: e2d1 Move number: 58
# Game 99 result: 0-1
#
#
# Starting game 100...
# Qwen CN move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen CN move: g1f3 Move number: 3
# Qwen CN move: d7d6 Move number: 4
# Qwen CN move: Ng5 Move number: 5
# Qwen CN move: g8f6 Move number: 6
# Qwen CN move: f1b5 Move number: 7
# Qwen CN move: c8d7 Move number: 8
# Qwen CN move: b5d7 Move number: 9
# Qwen CN move: d8d7 Move number: 10
# Qwen CN move: b1c3 Move number: 11
# Qwen CN move: b8c6 Move number: 12
# Qwen CN move: e1g1 Move number: 13
# Qwen CN move: h7h6 Move number: 14
# Qwen CN move: g5f3 Move number: 15
# Qwen CN move: Nh5 Move number: 16
# Qwen CN move: d2d4 Move number: 17
# Qwen CN move: c5d4 Move number: 18
# Qwen CN move: f3d4 Move number: 19
# Qwen CN move: g7g6 Move number: 20
# Qwen CN move: c1e3 Move number: 21
# Qwen CN move: f8g7 Move number: 22
# Qwen CN move: h2h3 Move number: 23
# Qwen CN move: Rg8 Move number: 24
# Qwen CN move: a2a4 Move number: 25
# Qwen CN move: c6e5 Move number: 26
# Qwen CN move: a4a5 Move number: 27
# Qwen CN move: e5c4 Move number: 28
# Qwen CN move: Nf3 Move number: 29
# Qwen CN move: g7c3 Move number: 30
# Qwen CN move: b2c3 Move number: 31
# Qwen CN move: Nxe5 Move number: 32
# Qwen CN move: f3e5 Move number: 33
# Invalid move by Qwen black. Move: Nxe5
# New Move: Rb8
# Qwen CN move: Rb8 Move number: 34
# Qwen CN move: e5d7 Move number: 35
# Invalid move by Qwen black. Move: Rg8
# New Move: b5
# Qwen CN move: b5 Move number: 36
# Qwen CN move: f1e1 Move number: 37
# Qwen CN move: e8d7 Move number: 38
# Qwen CN move: Bh6 Move number: 39
# Qwen CN move: g8h8 Move number: 40
# Qwen CN move: d1d4 Move number: 41
# Qwen CN move: e7e5 Move number: 42
# Qwen CN move: d4a7 Move number: 43
# Invalid move by Qwen black. Move: Qxa8
# New Move: Rb7
# Qwen CN move: Rb7 Move number: 44
# Qwen CN move: a7b7 Move number: 45
# Qwen CN move: d7e6 Move number: 46
# Qwen CN move: Qc8+ Move number: 47
# Qwen CN move: h8c8 Move number: 48
# Qwen CN move: a5a6 Move number: 49
# Qwen CN move: c8a8 Move number: 50
# Qwen CN move: h6g5 Move number: 51
# Invalid move by Qwen black. Move: Bh4
# New Move: Re8
# Qwen CN move: Re8 Move number: 52
# Qwen CN move: g1h1 Move number: 53
# Invalid move by Qwen black. Move: Nh3+
# New Move: Rd8
# Qwen CN move: Rd8 Move number: 54
# Qwen CN move: g5d8 Move number: 55
# Qwen CN move: Nf4 Move number: 56
# Qwen CN move: a6a7 Move number: 57
# Qwen CN move: f7f5 Move number: 58
# Qwen CN move: a7a8q Move number: 59
# Qwen CN move: f5e4 Move number: 60
# Qwen CN move: Bf6 Move number: 61
# Qwen CN move: f4h3 Move number: 62
# Qwen CN move: Qb7 Move number: 63
# Invalid move by Qwen black. Move: Qxb5
# New Move: Kf5
# Qwen CN move: Kf5 Move number: 64
# Qwen CN move: b7c8 Move number: 65
# Invalid move by Qwen black. Move: Qc7
# New Move: Kxf6
# Qwen CN move: Kxf6 Move number: 66
# Qwen CN move: c8h8 Move number: 67
# Invalid move by Qwen black. Move: Qh7+
# New Move: Kf7
# Qwen CN move: Kf7 Move number: 68
# Qwen CN move: a1a7 Move number: 69
# Invalid move by Qwen black. Move: Ra1
# New Move: Ke6
# Qwen CN move: Ke6 Move number: 70
# Qwen CN move: h8c8 Move number: 71
# Invalid move by Qwen black. Move: Qh6
# New Move: Kf6
# Qwen CN move: Kf6 Move number: 72
# Qwen CN move: c8h3 Move number: 73
# Invalid move by Qwen black. Move: Qh7
# New Move: Kg5
# Qwen CN move: Kg5 Move number: 74
# Qwen CN move: h1g1 Move number: 75
# Qwen CN move: d5 Move number: 76
# Qwen CN move: h3g3 Move number: 77
# Qwen CN move: g5f6 Move number: 78
# Qwen CN move: g3h4 Move number: 79
# Qwen CN move: g6g5 Move number: 80
# Qwen CN move: Rxe4 Move number: 81
# Qwen CN move: g5h4 Move number: 82
# Qwen CN move: Re1 Move number: 83
# Invalid move by Qwen black. Move: Re5
# New Move: Ke6
# Qwen CN move: Ke6 Move number: 84
# Qwen CN move: a7a6 Move number: 85
# Invalid move by Qwen black. Move: Ra1
# New Move: Kf7
# Qwen CN move: Kf7 Move number: 86
# Qwen CN move: e1e5 Move number: 87
# Invalid move by Qwen black. Move: Rxe8
# New Move: h3
# Qwen CN move: h3 Move number: 88
# Qwen CN move: g2h3 Move number: 89
# Qwen CN move: b5b4 Move number: 90
# Qwen CN move: Re1 Move number: 91
# Qwen CN move: d5d4 Move number: 92
# Qwen CN move: c3b4 Move number: 93
# Qwen CN move: f7g8 Move number: 94
# Qwen CN move: a6a7 Move number: 95
# Qwen CN move: Kh8 Move number: 96
# Qwen CN move: e1e8 Move number: 97
# Game 100 result: 1-0

# %%
results = []

# %%
results.append({
            "Qwen US Wins": qwen_us_wins,
            "Qwen CN Wins": qwen_cn_wins,
            "Draws": draws,
        })

print(results)
# Out:
# [{'Qwen US Wins': 91, 'Qwen CN Wins': 96, 'Draws': 13}]

# %% [markdown]
# ## Saving the data to a CSV file

# %%
df = pd.DataFrame(results)
df.to_csv(f"LLM_{QWEN_US_AI}_vs_LLM_{QWEN_CN_AI}.csv", index=False)
print(f"Results saved to LLM_{QWEN_US_AI}_vs_LLM_{QWEN_CN_AI}.csv")
# Out:
# Results saved to LLM_80_vs_LLM_80.csv
