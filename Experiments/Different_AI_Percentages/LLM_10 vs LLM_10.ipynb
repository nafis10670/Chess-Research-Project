# %% [markdown]
# # LLM_1 - **10%** vs. LLM_2 - **10%**

# %%
import chess
from stockfish import Stockfish
from ollama import chat
from ollama import ChatResponse
import json
import random
import pandas as pd
import asyncio

# %%
# STOCKFISH_PATH = r"C:\Users\nafis\Downloads\stockfish-windows-x86-64-avx2\stockfish\stockfish-windows-x86-64-avx2.exe"

STOCKFISH_ELO = 3500
NUM_GAMES = 100
MOVE_LIMIT = 300
RANDOM_START = 0
QWEN_US_AI = 10
QWEN_CN_AI = 10

# %%
stockfish = Stockfish()
stockfish.update_engine_parameters({"Threads": 4, "Hash": 4096})

# %%
qwen_cn_wins = 0
qwen_us_wins = 0
draws = 0

# %%
def valid_move_to_string(board):
    legal_moves = [
        board.san(move) for move in board.legal_moves]
    
    if not legal_moves:
        return "No legal moves."
    else:
        return ", ".join(legal_moves)

# %%
def get_move_history(board: chess.Board) -> str:
    """Return a formatted move history string like '1. e4 e5 2. Nf3 d5'."""
    temp_board = chess.Board()  # Start from the initial position.
    move_history = []
    
    # Iterate over the moves in the board's move stack.
    for i, move in enumerate(board.move_stack):
        # Get the SAN for the move in the current temporary board.
        move_san = temp_board.san(move)
        # Push the move so that the board state is updated.
        temp_board.push(move)
        
        # For white moves (even index), start a new entry with move number.
        if i % 2 == 0:
            move_history.append(f"{i//2 + 1}. {move_san}")
        # For black moves, append to the last white move entry.
        else:
            move_history[-1] += f" {move_san}"
    
    # Join all entries with a space.
    return " ".join(move_history)

# %%
async def get_move_with_timeout(stockfish, timeout=15):
    """
    Run stockfish.get_best_move() in a separate thread and wait for a maximum of `timeout` seconds.
    If the call exceeds the timeout, return None.
    """
    try:
        # Use asyncio.to_thread to run the blocking call in a separate thread.
        move = await asyncio.wait_for(asyncio.to_thread(stockfish.get_best_move), timeout)
        return move
    except asyncio.TimeoutError:
        # move = stockfish.get_best_move_time(1000)
        print(f"Timeout: stockfish.get_best_move() took more than 15 seconds.")
        return None

# %%
def get_qwen_move(board:chess.Board, fen:str, temp=0.0):
    qwen_move = None

    valid_moves = valid_move_to_string(board)

    move_history = get_move_history(board)
    
    response: ChatResponse = chat(model='qwen:32b', messages=[
        {
            'role': 'system',
            'content': 'You are a grand master chess player.'
        },
        {
            'role': 'user',
            'content': f"""You are playing chess and it is your turn. This is the current state of the game. Use this to work out where the pieces are on the board:

FEN: {fen}

The possible set of legal moves are: 

Legal Moves: {valid_moves}

+(You have to choose one from the provided list. Do not choose a move that is not in the list.)

The move history is: {move_history}.

Output the best move in SAN format to follow this position. Use the following single blob of JSON. Do not include any other information.
{{
    "san": "The move in SAN format",
}}"""}], options={"temperature": temp})
    
    try:
        parsed_json = json.loads(response.message.content)
        qwen_move = parsed_json["san"]
    except Exception as e:
        print(f"Wrong format given by Qwen. \nQwen Output: {response.message.content}")

    

    return qwen_move

# %%
def get_random_move(board:chess.Board, fen:str, seed: int = 101):
    legal_moves = [
        board.san(move)
        for move in board.legal_moves
    ]

    random.seed(seed)

    # print(random.choice(legal_moves))
    return random.choice(legal_moves)

    # print(legal_moves[0])

# %%
for game_number in range(1, NUM_GAMES + 1):
    
    move_counter = 0

    print(f"Starting game {game_number}...")

    board = chess.Board()

    while not board.is_game_over() and move_counter <= MOVE_LIMIT:
        if board.turn == chess.WHITE and not board.is_game_over():
            num = random.randint(1,100)
            
            if num <= QWEN_US_AI:
                stockfish.set_fen_position(board.fen())
                qwen_us_move = await get_move_with_timeout(stockfish)

                if qwen_us_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break
            
            else:
                qwen_us_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_us_move)
            except Exception as e:
                print(f"Invalid move by Qwen white. Move: {qwen_us_move}")
                qwen_us_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_us_move)
                print(f"New Move: {qwen_us_move}")
                # continue
            
            move_counter += 1        
            print(f"Qwen US move: {qwen_us_move} Move number: {move_counter}")

        elif board.turn == chess.BLACK and not board.is_game_over():
            num = random.randint(1, 100)

            if num <= QWEN_CN_AI:
                stockfish.set_fen_position(board.fen())
                qwen_cn_move = await get_move_with_timeout(stockfish)

                if qwen_cn_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break

            else:
                qwen_cn_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_cn_move)
            except Exception as e:
                print(f"Invalid move by Qwen black. Move: {qwen_cn_move}")
                qwen_cn_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_cn_move)
                print(f"New Move: {qwen_cn_move}")
                # continue
            move_counter += 1
            print(f"Qwen CN move: {qwen_cn_move} Move number: {move_counter}")   

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        qwen_us_wins += 1
    elif result == "0-1":
        qwen_cn_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n\n")
# Out:
# Starting game 1...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Ng5 Move number: 5
# Qwen CN move: Nh6 Move number: 6
# Qwen US move: Nh3 Move number: 7
# Qwen CN move: Ng4 Move number: 8
# Qwen US move: Nf4 Move number: 9
# Qwen CN move: g4f2 Move number: 10
# Qwen US move: Nh3 Move number: 11
# Qwen CN move: Be7 Move number: 12
# Qwen US move: Ng5 Move number: 13
# Qwen CN move: Bxg5 Move number: 14
# Invalid move by Qwen white. Move: Bg5
# New Move: h4
# Qwen US move: h4 Move number: 15
# Qwen CN move: Nh3 Move number: 16
# Qwen US move: h4g5 Move number: 17
# Qwen CN move: Nf4 Move number: 18
# Qwen US move: Rxh7 Move number: 19
# Qwen CN move: Rxh7 Move number: 20
# Qwen US move: Qe2 Move number: 21
# Qwen CN move: Qxg5 Move number: 22
# Qwen US move: Qa6 Move number: 23
# Invalid move by Qwen black. Move: Qxa8
# New Move: b6
# Qwen CN move: b6 Move number: 24
# Qwen US move: Qxc8+ Move number: 25
# Qwen CN move: a8c8 Move number: 26
# Qwen US move: Bd3 Move number: 27
# Qwen CN move: Rd8 Move number: 28
# Qwen US move: Bf1 Move number: 29
# Qwen CN move: Nd4 Move number: 30
# Qwen US move: Bb5 Move number: 31
# Qwen CN move: Ng6 Move number: 32
# Qwen US move: Bxd7+ Move number: 33
# Qwen CN move: Kf8 Move number: 34
# Qwen US move: Be6 Move number: 35
# Qwen CN move: Ke7 Move number: 36
# Qwen US move: Bxf7 Move number: 37
# Qwen CN move: Rdh8 Move number: 38
# Qwen US move: Bg8 Move number: 39
# Qwen CN move: h7h1 Move number: 40
# Qwen US move: e1f2 Move number: 41
# Qwen CN move: Rxg8 Move number: 42
# Qwen US move: Nc3 Move number: 43
# Qwen CN move: Nh8 Move number: 44
# Qwen US move: Nd5+ Move number: 45
# Qwen CN move: Kd8 Move number: 46
# Qwen US move: g2g3 Move number: 47
# Qwen CN move: Qf5+ Move number: 48
# Qwen US move: Ke3 Move number: 49
# Qwen CN move: Qf1 Move number: 50
# Qwen US move: Ne7 Move number: 51
# Qwen CN move: Nf5+ Move number: 52
# Qwen US move: Nxf5 Move number: 53
# Qwen CN move: Ng6 Move number: 54
# Qwen US move: Nxg7 Move number: 55
# Qwen CN move: Nf4 Move number: 56
# Qwen US move: Nh5 Move number: 57
# Qwen CN move: Rh8 Move number: 58
# Qwen US move: h5f4 Move number: 59
# Qwen CN move: Rg8 Move number: 60
# Qwen US move: Nh5 Move number: 61
# Invalid move by Qwen black. Move: Rxh6
# New Move: Rxg3+
# Qwen CN move: Rxg3+ Move number: 62
# Qwen US move: h5g3 Move number: 63
# Qwen CN move: Qe2+ Move number: 64
# Qwen US move: Nxe2 Move number: 65
# Qwen CN move: Re1 Move number: 66
# Invalid move by Qwen white. Move: Nf4
# New Move: b4
# Qwen US move: b4 Move number: 67
# Qwen CN move: Rxe2+ Move number: 68
# Qwen US move: e3e2 Move number: 69
# Qwen CN move: Ke7 Move number: 70
# Qwen US move: Ke1 Move number: 71
# Invalid move by Qwen black. Move: Ke2
# New Move: b5
# Qwen CN move: b5 Move number: 72
# Qwen US move: Ke2 Move number: 73
# Qwen CN move: e7d6 Move number: 74
# Qwen US move: Kf3 Move number: 75
# Qwen CN move: Ke6 Move number: 76
# Qwen US move: Ke2 Move number: 77
# Qwen CN move: Kf6 Move number: 78
# Qwen US move: Ke1 Move number: 79
# Invalid move by Qwen black. Move: Nh5
# New Move: Kf7
# Qwen CN move: Kf7 Move number: 80
# Qwen US move: e1f2 Move number: 81
# Qwen CN move: Ke6 Move number: 82
# Qwen US move: Kg3 Move number: 83
# Invalid move by Qwen black. Move: Kg4
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 84
# Qwen US move: d2d3 Move number: 85
# Invalid move by Qwen black. Move: Ke2
# New Move: c5
# Qwen CN move: c5 Move number: 86
# Qwen US move: Kf2 Move number: 87
# Qwen CN move: e7d6 Move number: 88
# Qwen US move: Ke1 Move number: 89
# Qwen CN move: cxb4 Move number: 90
# Qwen US move: Kf2 Move number: 91
# Qwen CN move: Ke6 Move number: 92
# Qwen US move: Kg1 Move number: 93
# Qwen CN move: Kf6 Move number: 94
# Qwen US move: Bh6 Move number: 95
# Invalid move by Qwen black. Move: Ke2
# New Move: b3
# Qwen CN move: b3 Move number: 96
# Qwen US move: Bf4 Move number: 97
# Qwen CN move: e5f4 Move number: 98
# Invalid move by Qwen white. Move: Kg1
# New Move: Kh1
# Qwen US move: Kh1 Move number: 99
# Qwen CN move: b3c2 Move number: 100
# Qwen US move: Kg1 Move number: 101
# Qwen CN move: c1=Q+ Move number: 102
# Qwen US move: Kf2 Move number: 103
# Qwen CN move: Qc5+ Move number: 104
# Qwen US move: Kf3 Move number: 105
# Qwen CN move: Qg5+ Move number: 106
# Qwen US move: Kf2 Move number: 107
# Invalid move by Qwen black. Move: Kf3
# New Move: a6
# Qwen CN move: a6 Move number: 108
# Qwen US move: Kf3 Move number: 109
# Qwen CN move: g5g3 Move number: 110
# Qwen US move: Ke2 Move number: 111
# Qwen CN move: Qg8 Move number: 112
# Qwen US move: Ke1 Move number: 113
# Invalid move by Qwen black. Move: Qg8
# New Move: Qg1+
# Qwen CN move: Qg1+ Move number: 114
# Qwen US move: Ke2 Move number: 115
# Qwen CN move: g1a1 Move number: 116
# Qwen US move: Kf3 Move number: 117
# Qwen CN move: Kg5 Move number: 118
# Qwen US move: e5 Move number: 119
# Qwen CN move: Qxe5 Move number: 120
# Qwen US move: Kf2 Move number: 121
# Qwen CN move: Qd4+ Move number: 122
# Qwen US move: Kf3 Move number: 123
# Qwen CN move: Qd8 Move number: 124
# Qwen US move: Kf2 Move number: 125
# Qwen CN move: Qa8 Move number: 126
# Qwen US move: Kf1 Move number: 127
# Invalid move by Qwen black. Move: Qxa1
# New Move: Kh4
# Qwen CN move: Kh4 Move number: 128
# Qwen US move: d4 Move number: 129
# Qwen CN move: a8e4 Move number: 130
# Qwen US move: d5 Move number: 131
# Qwen CN move: Qxd5 Move number: 132
# Qwen US move: Ke2 Move number: 133
# Qwen CN move: Qg8 Move number: 134
# Qwen US move: Kf3 Move number: 135
# Qwen CN move: Qa8+ Move number: 136
# Qwen US move: Kxf4 Move number: 137
# Qwen CN move: Qb7 Move number: 138
# Qwen US move: Kf5 Move number: 139
# Qwen CN move: Qc8+ Move number: 140
# Qwen US move: Kf6 Move number: 141
# Qwen CN move: Qh8+ Move number: 142
# Qwen US move: Kf7 Move number: 143
# Qwen CN move: h8e5 Move number: 144
# Qwen US move: f7g6 Move number: 145
# Invalid move by Qwen black. Move: Qg8
# New Move: Qh2
# Qwen CN move: Qh2 Move number: 146
# Qwen US move: Kf7 Move number: 147
# Qwen CN move: h2a2 Move number: 148
# Qwen US move: Kg6 Move number: 149
# Qwen CN move: Qg8+ Move number: 150
# Qwen US move: Kf5 Move number: 151
# Invalid move by Qwen black. Move: Qg8+
# New Move: Qg1
# Qwen CN move: Qg1 Move number: 152
# Qwen US move: Kf6 Move number: 153
# Qwen CN move: g1d4 Move number: 154
# Qwen US move: Kg6 Move number: 155
# Qwen CN move: Qg1+ Move number: 156
# Qwen US move: Kh7 Move number: 157
# Qwen CN move: Qg8+ Move number: 158
# Qwen US move: Kxg8 Move number: 159
# Invalid move by Qwen black. Move: Kf5
# New Move: a5
# Qwen CN move: a5 Move number: 160
# Qwen US move: Kh8 Move number: 161
# Qwen CN move: b5b4 Move number: 162
# Qwen US move: Kg7 Move number: 163
# Qwen CN move: Kg4 Move number: 164
# Qwen US move: Kf8 Move number: 165
# Qwen CN move: Kf5 Move number: 166
# Qwen US move: Kg8 Move number: 167
# Qwen CN move: Kg6 Move number: 168
# Qwen US move: Kh8 Move number: 169
# Invalid move by Qwen black. Move: Kg6
# New Move: Kh6
# Qwen CN move: Kh6 Move number: 170
# Qwen US move: h8g8 Move number: 171
# Invalid move by Qwen black. Move: Nh5
# New Move: Kg6
# Qwen CN move: Kg6 Move number: 172
# Qwen US move: g8f8 Move number: 173
# Qwen CN move: Kf6 Move number: 174
# Qwen US move: Kg8 Move number: 175
# Qwen CN move: Ke7 Move number: 176
# Qwen US move: Kh7 Move number: 177
# Qwen CN move: Kf8 Move number: 178
# Qwen US move: Kh8 Move number: 179
# Qwen CN move: Kf7 Move number: 180
# Qwen US move: Kh7 Move number: 181
# Qwen CN move: Kf8 Move number: 182
# Qwen US move: Kg6 Move number: 183
# Qwen CN move: Kg8 Move number: 184
# Qwen US move: Kf6 Move number: 185
# Invalid move by Qwen black. Move: Nh5
# New Move: Kh8
# Qwen CN move: Kh8 Move number: 186
# Qwen US move: f6e5 Move number: 187
# Qwen CN move: Kg8 Move number: 188
# Qwen US move: Ke6 Move number: 189
# Invalid move by Qwen black. Move: Ke7
# New Move: b3
# Qwen CN move: b3 Move number: 190
# Qwen US move: Kd5 Move number: 191
# Qwen CN move: b3b2 Move number: 192
# Qwen US move: Ke6 Move number: 193
# Qwen CN move: Kg7 Move number: 194
# Qwen US move: Ke5 Move number: 195
# Invalid move by Qwen black. Move: Ke6
# New Move: b1=B
# Qwen CN move: b1=B Move number: 196
# Qwen US move: Ke6 Move number: 197
# Qwen CN move: a5a4 Move number: 198
# Qwen US move: Ke7 Move number: 199
# Invalid move by Qwen black. Move: Ke8
# New Move: Bc2
# Qwen CN move: Bc2 Move number: 200
# Qwen US move: Ke8 Move number: 201
# Qwen CN move: g7f6 Move number: 202
# Qwen US move: Kd7 Move number: 203
# Qwen CN move: Kg6 Move number: 204
# Qwen US move: Ke8 Move number: 205
# Qwen CN move: Kf6 Move number: 206
# Qwen US move: Kd7 Move number: 207
# Qwen CN move: Kg6 Move number: 208
# Invalid move by Qwen white. Move: Kf6
# New Move: Kd8
# Qwen US move: Kd8 Move number: 209
# Qwen CN move: a4a3 Move number: 210
# Invalid move by Qwen white. Move: Kf7
# New Move: Ke8
# Qwen US move: Ke8 Move number: 211
# Qwen CN move: a3a2 Move number: 212
# Invalid move by Qwen white. Move: Kf7
# New Move: Kf8
# Qwen US move: Kf8 Move number: 213
# Qwen CN move: a2a1q Move number: 214
# Qwen US move: Kg8 Move number: 215
# Qwen CN move: Bd1 Move number: 216
# Invalid move by Qwen white. Move: Kf2
# New Move: Kf8
# Qwen US move: Kf8 Move number: 217
# Qwen CN move: a1f6 Move number: 218
# Qwen US move: Kg8 Move number: 219
# Qwen CN move: Qg7# Move number: 220
# Game 1 result: 0-1
#
#
# Starting game 2...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Ng5 Move number: 5
# Qwen CN move: Nh6 Move number: 6
# Qwen US move: Nh3 Move number: 7
# Invalid move by Qwen black. Move: Nf3
# New Move: g6
# Qwen CN move: g6 Move number: 8
# Qwen US move: Nf4 Move number: 9
# Qwen CN move: e5f4 Move number: 10
# Qwen US move: Nc3 Move number: 11
# Qwen CN move: Nxe5 Move number: 12
# Qwen US move: Nxd5 Move number: 13
# Invalid move by Qwen black. Move: Nxe5
# New Move: f6
# Qwen CN move: f6 Move number: 14
# Qwen US move: Nxc7+ Move number: 15
# Qwen CN move: d8c7 Move number: 16
# Qwen US move: Bb5 Move number: 17
# Invalid move by Qwen black. Move: Bxc6
# New Move: Kd8
# Qwen CN move: Kd8 Move number: 18
# Qwen US move: e1g1 Move number: 19
# Qwen CN move: Be7 Move number: 20
# Qwen US move: Bxd7 Move number: 21
# Qwen CN move: Bxd6 Move number: 22
# Qwen US move: Bxc8 Move number: 23
# Qwen CN move: Rg8 Move number: 24
# Qwen US move: Bd7 Move number: 25
# Invalid move by Qwen black. Move: Nh8
# New Move: Rb8
# Qwen CN move: Rb8 Move number: 26
# Qwen US move: d7e6 Move number: 27
# Qwen CN move: Rf8 Move number: 28
# Qwen US move: Bg4 Move number: 29
# Invalid move by Qwen black. Move: Bxf6
# New Move: b5
# Qwen CN move: b5 Move number: 30
# Qwen US move: Bf5 Move number: 31
# Qwen CN move: g6f5 Move number: 32
# Qwen US move: Qe2 Move number: 33
# Qwen CN move: Rc8 Move number: 34
# Qwen US move: Qh5 Move number: 35
# Qwen CN move: Rf7 Move number: 36
# Qwen US move: Qxf7 Move number: 37
# Qwen CN move: Qxf7 Move number: 38
# Qwen US move: exf5 Move number: 39
# Qwen CN move: Rxc2 Move number: 40
# Qwen US move: h3 Move number: 41
# Qwen CN move: Qd5 Move number: 42
# Qwen US move: Re1 Move number: 43
# Invalid move by Qwen black. Move: Rxe8+ Kf8
# New Move: Rc8
# Qwen CN move: Rc8 Move number: 44
# Qwen US move: Re3 Move number: 45
# Qwen CN move: f4e3 Move number: 46
# Qwen US move: dxe3 Move number: 47
# Qwen CN move: Rxc1+ Move number: 48
# Qwen US move: Kh2 Move number: 49
# Invalid move by Qwen black. Move: Nh3
# New Move: Qd1
# Qwen CN move: Qd1 Move number: 50
# Qwen US move: Rxc1 Move number: 51
# Qwen CN move: e5f3 Move number: 52
# Game 2 result: 0-1
#
#
# Starting game 3...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: Nxe5 Move number: 6
# Qwen US move: Nc3 Move number: 7
# Qwen CN move: Nf3+ Move number: 8
# Qwen US move: Qxf3 Move number: 9
# Qwen CN move: Nxe7 Move number: 10
# Qwen US move: Qxf7+ Move number: 11
# Invalid move by Qwen black. Move: Qxf7#
# New Move: Kxf7
# Qwen CN move: Kxf7 Move number: 12
# Qwen US move: f1c4 Move number: 13
# Invalid move by Qwen black. Move: Bxf7
# New Move: Ke8
# Qwen CN move: Ke8 Move number: 14
# Qwen US move: d2d4 Move number: 15
# Qwen CN move: Nd5 Move number: 16
# Qwen US move: Bxd5 Move number: 17
# Qwen CN move: Bxd6 Move number: 18
# Qwen US move: Bf4 Move number: 19
# Invalid move by Qwen black. Move: Bxd6
# New Move: a6
# Qwen CN move: a6 Move number: 20
# Qwen US move: Bg5 Move number: 21
# Qwen CN move: d8g5 Move number: 22
# Invalid move by Qwen white. Move: Bxd6
# New Move: Nb5
# Qwen US move: Nb5 Move number: 23
# Qwen CN move: a6b5 Move number: 24
# Qwen US move: Bxb7 Move number: 25
# Qwen CN move: Rg8 Move number: 26
# Qwen US move: Bxc8 Move number: 27
# Qwen CN move: Rb8 Move number: 28
# Qwen US move: Bxd7+ Move number: 29
# Qwen CN move: Kf8 Move number: 30
# Qwen US move: Rd1 Move number: 31
# Qwen CN move: Rd8 Move number: 32
# Qwen US move: Rd2 Move number: 33
# Qwen CN move: Rxd7 Move number: 34
# Qwen US move: Rd3 Move number: 35
# Qwen CN move: Rd8 Move number: 36
# Qwen US move: Rd2 Move number: 37
# Qwen CN move: g5g2 Move number: 38
# Qwen US move: e4e5 Move number: 39
# Invalid move by Qwen black. Move: Rd1
# New Move: Ra8
# Qwen CN move: Ra8 Move number: 40
# Qwen US move: h1f1 Move number: 41
# Invalid move by Qwen black. Move: Rxf2+
# New Move: c5
# Qwen CN move: c5 Move number: 42
# Qwen US move: Rd3 Move number: 43
# Qwen CN move: c5c4 Move number: 44
# Qwen US move: Rd1 Move number: 45
# Invalid move by Qwen black. Move: Rd2
# New Move: h5
# Qwen CN move: h5 Move number: 46
# Qwen US move: exd6 Move number: 47
# Qwen CN move: g2e4 Move number: 48
# Qwen US move: Kd2 Move number: 49
# Qwen CN move: Rxa2 Move number: 50
# Qwen US move: Rfe1 Move number: 51
# Qwen CN move: Qf3 Move number: 52
# Qwen US move: Re8+ Move number: 53
# Invalid move by Qwen black. Move: Rxe8
# New Move: Kxe8
# Qwen CN move: Kxe8 Move number: 54
# Qwen US move: d1e1 Move number: 55
# Qwen CN move: Qe4 Move number: 56
# Qwen US move: Re2 Move number: 57
# Invalid move by Qwen black. Move: Rd1
# New Move: h4
# Qwen CN move: h4 Move number: 58
# Qwen US move: Rxe4+ Move number: 59
# Qwen CN move: e8d7 Move number: 60
# Qwen US move: Re1 Move number: 61
# Invalid move by Qwen black. Move: Rd2
# New Move: b4
# Qwen CN move: b4 Move number: 62
# Qwen US move: Re3 Move number: 63
# Qwen CN move: a2b2 Move number: 64
# Qwen US move: Re8 Move number: 65
# Qwen CN move: Rxc2+ Move number: 66
# Qwen US move: Ke3 Move number: 67
# Qwen CN move: Rxe8+ Move number: 68
# Qwen US move: Kf4 Move number: 69
# Qwen CN move: Rd8 Move number: 70
# Qwen US move: Kf3 Move number: 71
# Qwen CN move: Rh8 Move number: 72
# Qwen US move: Kg4 Move number: 73
# Qwen CN move: Rh7 Move number: 74
# Qwen US move: Kf5 Move number: 75
# Qwen CN move: Rh6 Move number: 76
# Qwen US move: Kg4 Move number: 77
# Qwen CN move: c2f2 Move number: 78
# Qwen US move: g4g5 Move number: 79
# Qwen CN move: Rf5+ Move number: 80
# Qwen US move: Kxf5 Move number: 81
# Qwen CN move: g6+ Move number: 82
# Qwen US move: Kg4 Move number: 83
# Invalid move by Qwen black. Move: Kg6
# New Move: h3
# Qwen CN move: h3 Move number: 84
# Qwen US move: Kg5 Move number: 85
# Qwen CN move: h6h5 Move number: 86
# Qwen US move: Kg4 Move number: 87
# Qwen CN move: Rh4+ Move number: 88
# Qwen US move: Kg3 Move number: 89
# Invalid move by Qwen black. Move: Kg4
# New Move: Ke6
# Qwen CN move: Ke6 Move number: 90
# Qwen US move: g3h4 Move number: 91
# Qwen CN move: g5+ Move number: 92
# Qwen US move: Kg3 Move number: 93
# Qwen CN move: Kf5 Move number: 94
# Qwen US move: Kf2 Move number: 95
# Qwen CN move: Kg4 Move number: 96
# Invalid move by Qwen white. Move: Kf3
# New Move: d7
# Qwen US move: d7 Move number: 97
# Qwen CN move: Kf5 Move number: 98
# Qwen US move: d7d8q Move number: 99
# Qwen CN move: Kg6 Move number: 100
# Qwen US move: Qe7 Move number: 101
# Qwen CN move: Kh5 Move number: 102
# Qwen US move: Qd8 Move number: 103
# Qwen CN move: g4 Move number: 104
# Qwen US move: Qh8+ Move number: 105
# Qwen CN move: Kg6 Move number: 106
# Qwen US move: Qg8+ Move number: 107
# Qwen CN move: Kf5 Move number: 108
# Qwen US move: Qh7+ Move number: 109
# Qwen CN move: Kf6 Move number: 110
# Qwen US move: Qh8+ Move number: 111
# Qwen CN move: Kf7 Move number: 112
# Qwen US move: h8h5 Move number: 113
# Qwen CN move: f7f6 Move number: 114
# Qwen US move: Qh8+ Move number: 115
# Qwen CN move: Kf7 Move number: 116
# Qwen US move: Qg8+ Move number: 117
# Qwen CN move: Kf6 Move number: 118
# Qwen US move: Qh8+ Move number: 119
# Qwen CN move: f6f7 Move number: 120
# Qwen US move: Qg8+ Move number: 121
# Qwen CN move: Kf6 Move number: 122
# Qwen US move: Qh8+ Move number: 123
# Qwen CN move: Kf7 Move number: 124
# Qwen US move: Qg8+ Move number: 125
# Qwen CN move: Kf6 Move number: 126
# Qwen US move: Qh8+ Move number: 127
# Game 3 result: 1/2-1/2

# %%
results = []

# %%
results.append({
            "Qwen US Wins": qwen_us_wins,
            "Qwen CN Wins": qwen_cn_wins,
            "Draws": draws,
        })

print(results)

# %% [markdown]
# ## Swapping sides

# %%
stockfish = Stockfish()
stockfish.update_engine_parameters({"Threads": 4, "Hash": 4096})

# %%
for game_number in range(1, NUM_GAMES + 1):
    
    move_counter = 0

    print(f"Starting game {game_number}...")

    board = chess.Board()

    while not board.is_game_over() and move_counter <= MOVE_LIMIT:
        if board.turn == chess.WHITE and not board.is_game_over():
            num = random.randint(1,100)
            
            if num <= QWEN_US_AI:
                stockfish.set_fen_position(board.fen())
                qwen_us_move = await get_move_with_timeout(stockfish)

                if qwen_us_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break
            
            else:
                qwen_us_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_us_move)
            except Exception as e:
                print(f"Invalid move by Qwen white. Move: {qwen_us_move}")
                qwen_us_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_us_move)
                print(f"New Move: {qwen_us_move}")
                # continue
            
            move_counter += 1        
            print(f"Qwen US move: {qwen_us_move} Move number: {move_counter}")

        elif board.turn == chess.BLACK and not board.is_game_over():
            num = random.randint(1, 100)

            if num <= QWEN_CN_AI:
                stockfish.set_fen_position(board.fen())
                qwen_cn_move = await get_move_with_timeout(stockfish)

                if qwen_cn_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break

            else:
                qwen_cn_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_cn_move)
            except Exception as e:
                print(f"Invalid move by Qwen black. Move: {qwen_cn_move}")
                qwen_cn_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_cn_move)
                print(f"New Move: {qwen_cn_move}")
                # continue
            move_counter += 1
            print(f"Qwen CN move: {qwen_cn_move} Move number: {move_counter}")   

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        qwen_cn_wins += 1
    elif result == "0-1":
        qwen_us_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n\n")

# %%
results = []

# %%
results.append({
            "Qwen US Wins": qwen_us_wins,
            "Qwen CN Wins": qwen_cn_wins,
            "Draws": draws,
        })

print(results)

# %%
df = pd.DataFrame(results)
df.to_csv(f"LLM_{QWEN_US_AI}_vs_LLM_{QWEN_CN_AI}.csv", index=False)
print(f"Results saved to LLM_{QWEN_US_AI}_vs_LLM_{QWEN_CN_AI}.csv")
