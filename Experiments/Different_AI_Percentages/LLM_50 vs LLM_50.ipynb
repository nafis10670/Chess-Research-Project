# %% [markdown]
# # LLM_1 - **50%** vs. LLM_2 - **50%**

# %%
import chess
from stockfish import Stockfish
from ollama import chat
from ollama import ChatResponse
import json
import random
import pandas as pd
import asyncio

# %%
# STOCKFISH_PATH = r"C:\Users\nafis\Downloads\stockfish-windows-x86-64-avx2\stockfish\stockfish-windows-x86-64-avx2.exe"

STOCKFISH_ELO = 3500
NUM_GAMES = 100
MOVE_LIMIT = 300
RANDOM_START = 0
QWEN_US_AI = 50
QWEN_CN_AI = 50

# %%
stockfish = Stockfish()
stockfish.update_engine_parameters({"Threads": 4, "Hash": 4096})

# %%
qwen_cn_wins = 0
qwen_us_wins = 0
draws = 0

# %%
# def generate_random_number(seed:int) -> int:
#     # random.seed(seed)
#     return random.randint(1, 100)

# %%
def valid_move_to_string(board):
    legal_moves = [
        board.san(move) for move in board.legal_moves]
    
    if not legal_moves:
        return "No legal moves."
    else:
        return ", ".join(legal_moves)

# %%
def get_move_history(board: chess.Board) -> str:
    """Return a formatted move history string like '1. e4 e5 2. Nf3 d5'."""
    temp_board = chess.Board()  # Start from the initial position.
    move_history = []
    
    # Iterate over the moves in the board's move stack.
    for i, move in enumerate(board.move_stack):
        # Get the SAN for the move in the current temporary board.
        move_san = temp_board.san(move)
        # Push the move so that the board state is updated.
        temp_board.push(move)
        
        # For white moves (even index), start a new entry with move number.
        if i % 2 == 0:
            move_history.append(f"{i//2 + 1}. {move_san}")
        # For black moves, append to the last white move entry.
        else:
            move_history[-1] += f" {move_san}"
    
    # Join all entries with a space.
    return " ".join(move_history)

# %%
async def get_move_with_timeout(stockfish, timeout=15):
    """
    Run stockfish.get_best_move() in a separate thread and wait for a maximum of `timeout` seconds.
    If the call exceeds the timeout, return None.
    """
    try:
        # Use asyncio.to_thread to run the blocking call in a separate thread.
        move = await asyncio.wait_for(asyncio.to_thread(stockfish.get_best_move), timeout)
        return move
    except asyncio.TimeoutError:
        # move = stockfish.get_best_move_time(1000)
        print(f"Timeout: stockfish.get_best_move() took more than 15 seconds.")
        return None

# %%
def get_qwen_move(board:chess.Board, fen:str, temp=0.0):
    valid_moves = valid_move_to_string(board)

    move_history = get_move_history(board)
    
    response: ChatResponse = chat(model='qwen:32b', messages=[
        {
            'role': 'system',
            'content': 'You are a grand master chess player.'
        },
        {
            'role': 'user',
            'content': f"""You are playing chess and it is your turn. This is the current state of the game. Use this to work out where the pieces are on the board:

FEN: {fen}

The possible set of legal moves are: 

Legal Moves: {valid_moves}

+(You have to choose one from the provided list. Do not choose a move that is not in the list.)

The move history is: {move_history}.

Output the best move in SAN format to follow this position. Use the following single blob of JSON. Do not include any other information.
{{
    "san": "The move in SAN format",
}}"""}], options={"temperature": temp})
    
    try:
        parsed_json = json.loads(response.message.content)
        qwen_move = parsed_json["san"]
    except Exception as e:
        print(f"Wrong format given by Qwen. \nQwen Output: {response.message.content}")

    

    return qwen_move

# %%
def get_random_move(board:chess.Board, fen:str, seed: int = 101):
    legal_moves = [
        board.san(move)
        for move in board.legal_moves
    ]

    random.seed(seed)

    # print(random.choice(legal_moves))
    return random.choice(legal_moves)

    # print(legal_moves[0])

# %%
for game_number in range(1, NUM_GAMES + 1):
    
    move_counter = 0

    print(f"Starting game {game_number}...")

    board = chess.Board()

    while not board.is_game_over() and move_counter <= MOVE_LIMIT:
        if board.turn == chess.WHITE and not board.is_game_over():
            num = random.randint(1,100)
            
            if num <= QWEN_US_AI:
                stockfish.set_fen_position(board.fen())
                qwen_us_move = await get_move_with_timeout(stockfish)

                if qwen_us_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break
            
            else:
                qwen_us_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_us_move)
            except Exception as e:
                print(f"Invalid move by Qwen white. Move: {qwen_us_move}")
                qwen_us_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_us_move)
                print(f"New Move: {qwen_us_move}")
                # continue
            
            move_counter += 1        
            print(f"Qwen US move: {qwen_us_move} Move number: {move_counter}")

        elif board.turn == chess.BLACK and not board.is_game_over():
            num = random.randint(1, 100)

            if num <= QWEN_CN_AI:
                stockfish.set_fen_position(board.fen())
                qwen_cn_move = await get_move_with_timeout(stockfish)

                if qwen_cn_move is None:
                    print("No move received. Reinitializing Stockfish.")
                    stockfish = Stockfish(parameters={"Threads": 4, "Hash": 4096})  # Reinitialize Stockfish for the next game.
                    break

            else:
                qwen_cn_move = get_qwen_move(board, board.fen(), 2.0)

            try:
                board.push_san(qwen_cn_move)
            except Exception as e:
                print(f"Invalid move by Qwen black. Move: {qwen_cn_move}")
                qwen_cn_move = get_random_move(board, board.fen(), 42)
                board.push_san(qwen_cn_move)
                print(f"New Move: {qwen_cn_move}")
                # continue
            move_counter += 1
            print(f"Qwen CN move: {qwen_cn_move} Move number: {move_counter}")   

    # Record the result of the game
    result = board.result()
    if result == "1-0":
        qwen_us_wins += 1
    elif result == "0-1":
        qwen_cn_wins += 1
    else:
        draws += 1

    print(f"Game {game_number} result: {result}\n\n")
# Out:
# Starting game 1...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Ng5 Move number: 5
# Qwen CN move: d8g5 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Invalid move by Qwen black. Move: dxe5
# New Move: f5
# Qwen CN move: f5 Move number: 8
# Qwen US move: c1g5 Move number: 9
# Qwen CN move: c6d4 Move number: 10
# Qwen US move: Bd2 Move number: 11
# Qwen CN move: f5e4 Move number: 12
# Qwen US move: d1h5 Move number: 13
# Qwen CN move: e8d8 Move number: 14
# Qwen US move: h5d1 Move number: 15
# Qwen CN move: Nf3+ Move number: 16
# Qwen US move: g2f3 Move number: 17
# Qwen CN move: Nf6 Move number: 18
# Qwen US move: Bh6 Move number: 19
# Invalid move by Qwen black. Move: Bh6
# New Move: a6
# Qwen CN move: a6 Move number: 20
# Qwen US move: h6g5 Move number: 21
# Qwen CN move: e4f3 Move number: 22
# Qwen US move: Bh4 Move number: 23
# Qwen CN move: f8c5 Move number: 24
# Qwen US move: h4f6 Move number: 25
# Qwen CN move: g7f6 Move number: 26
# Qwen US move: d1f3 Move number: 27
# Qwen CN move: Bd4 Move number: 28
# Qwen US move: f3f6 Move number: 29
# Qwen CN move: Ke8 Move number: 30
# Qwen US move: Qxh8+ Move number: 31
# Qwen CN move: Kf7 Move number: 32
# Qwen US move: f1c4 Move number: 33
# Invalid move by Qwen black. Move: Bg6
# New Move: d5
# Qwen CN move: d5 Move number: 34
# Qwen US move: c4d5 Move number: 35
# Qwen CN move: f7e7 Move number: 36
# Qwen US move: Qg8 Move number: 37
# Qwen CN move: c7c6 Move number: 38
# Qwen US move: g8h7 Move number: 39
# Qwen CN move: e7d8 Move number: 40
# Qwen US move: c2c3 Move number: 41
# Qwen CN move: Bxc3+ Move number: 42
# Qwen US move: b1c3 Move number: 43
# Qwen CN move: Bxd7 Move number: 44
# Qwen US move: Qh8+ Move number: 45
# Invalid move by Qwen black. Move: Bc4
# New Move: Be8
# Qwen CN move: Be8 Move number: 46
# Qwen US move: d5e4 Move number: 47
# Qwen CN move: d8c7 Move number: 48
# Qwen US move: Qg8 Move number: 49
# Qwen CN move: a8d8 Move number: 50
# Qwen US move: g8g3 Move number: 51
# Qwen CN move: c7c8 Move number: 52
# Qwen US move: e4f5 Move number: 53
# Invalid move by Qwen black. Move: Bxf3
# New Move: Kb8
# Qwen CN move: Kb8 Move number: 54
# Qwen US move: g3e5 Move number: 55
# Qwen CN move: Rd6 Move number: 56
# Qwen US move: e5d6 Move number: 57
# Qwen CN move: b8a7 Move number: 58
# Qwen US move: d6c5 Move number: 59
# Qwen CN move: a7b8 Move number: 60
# Qwen US move: Bxd7 Move number: 61
# Qwen CN move: e8g6 Move number: 62
# Qwen US move: Qxc6 Move number: 63
# Qwen CN move: Bf5 Move number: 64
# Qwen US move: Qxe4 Move number: 65
# Qwen CN move: f5e4 Move number: 66
# Qwen US move: Be8 Move number: 67
# Qwen CN move: Bf5 Move number: 68
# Qwen US move: h1g1 Move number: 69
# Qwen CN move: f5e6 Move number: 70
# Qwen US move: a1d1 Move number: 71
# Qwen CN move: a6a5 Move number: 72
# Qwen US move: c3b5 Move number: 73
# Qwen CN move: Bf5 Move number: 74
# Invalid move by Qwen white. Move: Bxf7+
# New Move: a4
# Qwen US move: a4 Move number: 75
# Qwen CN move: b7b6 Move number: 76
# Qwen US move: d1d8 Move number: 77
# Invalid move by Qwen black. Move: Rd7
# New Move: Kb7
# Qwen CN move: Kb7 Move number: 78
# Qwen US move: g1g7 Move number: 79
# Qwen CN move: Bd7 Move number: 80
# Qwen US move: g7d7 Move number: 81
# Qwen CN move: b7a6 Move number: 82
# Qwen US move: d7a7 Move number: 83
# Game 1 result: 1-0
#
#
# Starting game 2...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Ng5 Move number: 5
# Qwen CN move: Nh6 Move number: 6
# Qwen US move: g5f3 Move number: 7
# Invalid move by Qwen black. Move: Nc3
# New Move: g6
# Qwen CN move: g6 Move number: 8
# Qwen US move: d2d4 Move number: 9
# Qwen CN move: e5d4 Move number: 10
# Qwen US move: Nxd4 Move number: 11
# Qwen CN move: f8g7 Move number: 12
# Qwen US move: d4f3 Move number: 13
# Qwen CN move: e8g8 Move number: 14
# Qwen US move: f1c4 Move number: 15
# Qwen CN move: Bxd4 Move number: 16
# Qwen US move: f3d4 Move number: 17
# Qwen CN move: Nxe5 Move number: 18
# Qwen US move: Be2 Move number: 19
# Invalid move by Qwen black. Move: Nbd2
# New Move: a6
# Qwen CN move: a6 Move number: 20
# Qwen US move: c1h6 Move number: 21
# Qwen CN move: d7d5 Move number: 22
# Qwen US move: Bxf8 Move number: 23
# Qwen CN move: d8g5 Move number: 24
# Qwen US move: b1c3 Move number: 25
# Qwen CN move: g5g2 Move number: 26
# Qwen US move: e2f3 Move number: 27
# Invalid move by Qwen black. Move: Nh3
# New Move: Rb8
# Qwen CN move: Rb8 Move number: 28
# Qwen US move: f3g2 Move number: 29
# Invalid move by Qwen black. Move: Nbd3+
# New Move: a5
# Qwen CN move: a5 Move number: 30
# Qwen US move: e4d5 Move number: 31
# Qwen CN move: g8f8 Move number: 32
# Qwen US move: Ne6+ Move number: 33
# Qwen CN move: c8e6 Move number: 34
# Qwen US move: d5e6 Move number: 35
# Qwen CN move: b8e8 Move number: 36
# Qwen US move: e6e7 Move number: 37
# Qwen CN move: Kg8 Move number: 38
# Qwen US move: h2h4 Move number: 39
# Qwen CN move: Rxe7 Move number: 40
# Invalid move by Qwen white. Move: Nh6
# New Move: f4
# Qwen US move: f4 Move number: 41
# Qwen CN move: e5g4 Move number: 42
# Qwen US move: c3e4 Move number: 43
# Qwen CN move: Re5 Move number: 44
# Qwen US move: f4e5 Move number: 45
# Qwen CN move: h7h5 Move number: 46
# Qwen US move: d1d8 Move number: 47
# Qwen CN move: g8g7 Move number: 48
# Qwen US move: Qe8 Move number: 49
# Qwen CN move: c7c5 Move number: 50
# Qwen US move: Qf8+ Move number: 51
# Qwen CN move: Kxf8 Move number: 52
# Qwen US move: Nxd6 Move number: 53
# Qwen CN move: g4e3 Move number: 54
# Invalid move by Qwen white. Move: Nxd5
# New Move: Nc4
# Qwen US move: Nc4 Move number: 55
# Qwen CN move: e3c4 Move number: 56
# Invalid move by Qwen white. Move: Bxc5
# New Move: e6
# Qwen US move: e6 Move number: 57
# Qwen CN move: f7f5 Move number: 58
# Qwen US move: e1c1 Move number: 59
# Qwen CN move: Nxb2 Move number: 60
# Qwen US move: c1b2 Move number: 61
# Qwen CN move: a5a4 Move number: 62
# Qwen US move: d1d7 Move number: 63
# Qwen CN move: f5f4 Move number: 64
# Qwen US move: Rd8+ Move number: 65
# Qwen CN move: f8g7 Move number: 66
# Qwen US move: Rd6 Move number: 67
# Invalid move by Qwen black. Move: Kf7
# New Move: a3+
# Qwen CN move: a3+ Move number: 68
# Qwen US move: b2c1 Move number: 69
# Qwen CN move: b7b6 Move number: 70
# Qwen US move: Rd8 Move number: 71
# Qwen CN move: g7f6 Move number: 72
# Qwen US move: h1e1 Move number: 73
# Qwen CN move: g6g5 Move number: 74
# Qwen US move: c1d2 Move number: 75
# Invalid move by Qwen black. Move: Rxe5
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 76
# Qwen US move: d8d7 Move number: 77
# Invalid move by Qwen black. Move: Rd6
# New Move: Kf6
# Qwen CN move: Kf6 Move number: 78
# Qwen US move: d7f7 Move number: 79
# Qwen CN move: f6g6 Move number: 80
# Qwen US move: Rd1 Move number: 81
# Qwen CN move: f4f3 Move number: 82
# Qwen US move: g2f3 Move number: 83
# Qwen CN move: g6h6 Move number: 84
# Qwen US move: f3e4 Move number: 85
# Qwen CN move: gxh4 Move number: 86
# Qwen US move: d1g1 Move number: 87
# Qwen CN move: h3 Move number: 88
# Qwen US move: Rf8 Move number: 89
# Invalid move by Qwen black. Move: Rg1
# New Move: b5
# Qwen CN move: b5 Move number: 90
# Qwen US move: f8f6 Move number: 91
# Game 2 result: 1-0
#
#
# Starting game 3...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: Nge7 Move number: 6
# Qwen US move: b1c3 Move number: 7
# Qwen CN move: Nf5 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Invalid move by Qwen black. Move: Bxc6
# New Move: bxc6
# Qwen CN move: bxc6 Move number: 10
# Qwen US move: e4f5 Move number: 11
# Qwen CN move: f7f6 Move number: 12
# Qwen US move: Ng5 Move number: 13
# Qwen CN move: f6g5 Move number: 14
# Qwen US move: d1h5 Move number: 15
# Qwen CN move: g7g6 Move number: 16
# Qwen US move: f5g6 Move number: 17
# Invalid move by Qwen black. Move: Bxc4
# New Move: e4
# Qwen CN move: e4 Move number: 18
# Qwen US move: g6g7 Move number: 19
# Qwen CN move: e8e7 Move number: 20
# Invalid move by Qwen white. Move: Qxh8
# New Move: f3
# Qwen US move: f3 Move number: 21
# Qwen CN move: f8g7 Move number: 22
# Qwen US move: h5g5 Move number: 23
# Qwen CN move: Kf8 Move number: 24
# Qwen US move: g5d8 Move number: 25
# Qwen CN move: f8f7 Move number: 26
# Qwen US move: d8g5 Move number: 27
# Qwen CN move: e4f3 Move number: 28
# Qwen US move: Qe5 Move number: 29
# Qwen CN move: g7e5 Move number: 30
# Qwen US move: Nd5 Move number: 31
# Qwen CN move: Rg8 Move number: 32
# Qwen US move: Ne7 Move number: 33
# Qwen CN move: f3g2 Move number: 34
# Qwen US move: Nxg8 Move number: 35
# Qwen CN move: Bd4 Move number: 36
# Qwen US move: h1f1 Move number: 37
# Qwen CN move: g2f1q Move number: 38
# Qwen US move: e1f1 Move number: 39
# Qwen CN move: c8a6 Move number: 40
# Qwen US move: d2d3 Move number: 41
# Qwen CN move: Rg8 Move number: 42
# Qwen US move: Ke1 Move number: 43
# Qwen CN move: g8g2 Move number: 44
# Qwen US move: Kf1 Move number: 45
# Qwen CN move: g2c2 Move number: 46
# Qwen US move: Bh6 Move number: 47
# Qwen CN move: Bf2 Move number: 48
# Invalid move by Qwen white. Move: Bh6
# New Move: Bf4
# Qwen US move: Bf4 Move number: 49
# Qwen CN move: f2d4 Move number: 50
# Qwen US move: Bxc7 Move number: 51
# Qwen CN move: a6d3 Move number: 52
# Qwen US move: f1e1 Move number: 53
# Qwen CN move: d4b2 Move number: 54
# Qwen US move: e1d1 Move number: 55
# Invalid move by Qwen black. Move: Bf4
# New Move: a5
# Qwen CN move: a5 Move number: 56
# Qwen US move: a1b1 Move number: 57
# Qwen CN move: c2g2 Move number: 58
# Qwen US move: Bd6 Move number: 59
# Qwen CN move: d3c2 Move number: 60
# Qwen US move: d1e1 Move number: 61
# Qwen CN move: c2b1 Move number: 62
# Qwen US move: e1d1 Move number: 63
# Qwen CN move: Rg1+ Move number: 64
# Qwen US move: d1e2 Move number: 65
# Qwen CN move: Rg8 Move number: 66
# Qwen US move: Bf4 Move number: 67
# Invalid move by Qwen black. Move: Rg8
# New Move: h5
# Qwen CN move: h5 Move number: 68
# Qwen US move: e2d2 Move number: 69
# Qwen CN move: g8g2 Move number: 70
# Qwen US move: Ke1 Move number: 71
# Qwen CN move: b2c3 Move number: 72
# Qwen US move: e1f1 Move number: 73
# Qwen CN move: g2a2 Move number: 74
# Qwen US move: f4e3 Move number: 75
# Invalid move by Qwen black. Move: Bf4
# New Move: Ke6
# Qwen CN move: Ke6 Move number: 76
# Qwen US move: e3f2 Move number: 77
# Invalid move by Qwen black. Move: Bxf3+
# New Move: Bh8
# Qwen CN move: Bh8 Move number: 78
# Qwen US move: f2c5 Move number: 79
# Qwen CN move: Bxc3 Move number: 80
# Qwen US move: c5f2 Move number: 81
# Qwen CN move: a2f2 Move number: 82
# Qwen US move: f1f2 Move number: 83
# Qwen CN move: c3d2 Move number: 84
# Qwen US move: Kg3 Move number: 85
# Qwen CN move: b1g6 Move number: 86
# Qwen US move: Kf2 Move number: 87
# Qwen CN move: Be8 Move number: 88
# Qwen US move: Kg3 Move number: 89
# Qwen CN move: e6d5 Move number: 90
# Invalid move by Qwen white. Move: Kg3
# New Move: h3
# Qwen US move: h3 Move number: 91
# Qwen CN move: e8g6 Move number: 92
# Qwen US move: g3g2 Move number: 93
# Qwen CN move: Bh6 Move number: 94
# Qwen US move: g2g3 Move number: 95
# Qwen CN move: d5d4 Move number: 96
# Qwen US move: g3f2 Move number: 97
# Qwen CN move: g6e4 Move number: 98
# Qwen US move: Kg3 Move number: 99
# Qwen CN move: a5a4 Move number: 100
# Qwen US move: Kh4 Move number: 101
# Qwen CN move: Bf4 Move number: 102
# Qwen US move: Kxh5 Move number: 103
# Qwen CN move: f4d2 Move number: 104
# Qwen US move: Kg4 Move number: 105
# Qwen CN move: Bh7 Move number: 106
# Qwen US move: g4f3 Move number: 107
# Qwen CN move: h7d3 Move number: 108
# Qwen US move: f3g3 Move number: 109
# Qwen CN move: a4a3 Move number: 110
# Qwen US move: h3h4 Move number: 111
# Qwen CN move: Bf4+ Move number: 112
# Qwen US move: Kg4 Move number: 113
# Qwen CN move: d4e3 Move number: 114
# Qwen US move: Kh5 Move number: 115
# Qwen CN move: a3a2 Move number: 116
# Qwen US move: Kg4 Move number: 117
# Invalid move by Qwen black. Move: Kf3
# New Move: Be2+
# Qwen CN move: Be2+ Move number: 118
# Qwen US move: g4f5 Move number: 119
# Qwen CN move: e2h5 Move number: 120
# Qwen US move: Kf6 Move number: 121
# Qwen CN move: a2a1q Move number: 122
# Qwen US move: f6e7 Move number: 123
# Qwen CN move: a1g7 Move number: 124
# Qwen US move: e7d8 Move number: 125
# Qwen CN move: Qg1 Move number: 126
# Qwen US move: d8c8 Move number: 127
# Qwen CN move: Be8 Move number: 128
# Qwen US move: Kd8 Move number: 129
# Qwen CN move: Bh2 Move number: 130
# Qwen US move: h4h5 Move number: 131
# Qwen CN move: Bf7 Move number: 132
# Qwen US move: Kc8 Move number: 133
# Qwen CN move: g1g8 Move number: 134
# Qwen US move: c8b7 Move number: 135
# Qwen CN move: g8b8 Move number: 136
# Qwen US move: b7a6 Move number: 137
# Qwen CN move: f7c4 Move number: 138
# Invalid move by Qwen white. Move: Kd7
# New Move: Ka5
# Qwen US move: Ka5 Move number: 139
# Qwen CN move: b8b5 Move number: 140
# Game 3 result: 0-1
#
#
# Starting game 4...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: Nf6 Move number: 6
# Qwen US move: e1g1 Move number: 7
# Qwen CN move: Bb4 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Qwen CN move: Nxe4 Move number: 10
# Qwen US move: c6e4 Move number: 11
# Qwen CN move: Bxc3 Move number: 12
# Invalid move by Qwen white. Move: Bxc3
# New Move: h3
# Qwen US move: h3 Move number: 13
# Qwen CN move: c3a5 Move number: 14
# Qwen US move: e4d5 Move number: 15
# Qwen CN move: Rg8 Move number: 16
# Qwen US move: d2d4 Move number: 17
# Qwen CN move: d7d6 Move number: 18
# Qwen US move: f3g5 Move number: 19
# Qwen CN move: g8f8 Move number: 20
# Qwen US move: Be3 Move number: 21
# Qwen CN move: a5b6 Move number: 22
# Qwen US move: Be6 Move number: 23
# Qwen CN move: Qf6 Move number: 24
# Qwen US move: Bxc8 Move number: 25
# Qwen CN move: a8c8 Move number: 26
# Qwen US move: Nf3 Move number: 27
# Qwen CN move: Qg5 Move number: 28
# Qwen US move: e3g5 Move number: 29
# Qwen CN move: f7f6 Move number: 30
# Qwen US move: g5e3 Move number: 31
# Qwen CN move: f6f5 Move number: 32
# Qwen US move: d4e5 Move number: 33
# Qwen CN move: Rh8 Move number: 34
# Qwen US move: Nh2 Move number: 35
# Qwen CN move: b6e3 Move number: 36
# Qwen US move: Qxd6 Move number: 37
# Qwen CN move: c7d6 Move number: 38
# Qwen US move: Ng4 Move number: 39
# Qwen CN move: Rxc2 Move number: 40
# Qwen US move: Nh6 Move number: 41
# Qwen CN move: Rg8 Move number: 42
# Qwen US move: Nf7 Move number: 43
# Qwen CN move: e8f7 Move number: 44
# Qwen US move: Re1 Move number: 45
# Invalid move by Qwen black. Move: Rxc2
# New Move: g5
# Qwen CN move: g5 Move number: 46
# Qwen US move: e5e6 Move number: 47
# Qwen CN move: f7e7 Move number: 48
# Qwen US move: Re2 Move number: 49
# Qwen CN move: c2e2 Move number: 50
# Qwen US move: f2e3 Move number: 51
# Qwen CN move: e2e1 Move number: 52
# Qwen US move: g1f2 Move number: 53
# Invalid move by Qwen black. Move: Rg8
# New Move: Rc1
# Qwen CN move: Rc1 Move number: 54
# Qwen US move: g2g4 Move number: 55
# Qwen CN move: f5g4 Move number: 56
# Invalid move by Qwen white. Move:  hxg4
# New Move: a3
# Qwen US move: a3 Move number: 57
# Qwen CN move: g4h3 Move number: 58
# Qwen US move: e3e4 Move number: 59
# Invalid move by Qwen black. Move: Rg8
# New Move: Rg7
# Qwen CN move: Rg7 Move number: 60
# Qwen US move: f2g3 Move number: 61
# Qwen CN move: Rg8 Move number: 62
# Qwen US move: g3h3 Move number: 63
# Qwen CN move: g8c8 Move number: 64
# Qwen US move: h3g4 Move number: 65
# Qwen CN move: c1g1 Move number: 66
# Qwen US move: Kf5 Move number: 67
# Qwen CN move: c8f8 Move number: 68
# Game 4 result: 0-1
#
#
# Starting game 5...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Qwen CN move: Nxe5 Move number: 6
# Qwen US move: d2d4 Move number: 7
# Qwen CN move: e5g6 Move number: 8
# Qwen US move: c2c4 Move number: 9
# Qwen CN move: c7c5 Move number: 10
# Qwen US move: b1c3 Move number: 11
# Invalid move by Qwen black. Move: Nf3
# New Move: f6
# Qwen CN move: f6 Move number: 12
# Qwen US move: h2h4 Move number: 13
# Qwen CN move: c5d4 Move number: 14
# Invalid move by Qwen white. Move: Nbd2
# New Move: Rg1
# Qwen US move: Rg1 Move number: 15
# Qwen CN move: d4c3 Move number: 16
# Qwen US move: Qxd7+ Move number: 17
# Qwen CN move: c8d7 Move number: 18
# Qwen US move: b2c3 Move number: 19
# Qwen CN move: f8c5 Move number: 20
# Qwen US move: h4h5 Move number: 21
# Qwen CN move: N8e7 Move number: 22
# Qwen US move: h5g6 Move number: 23
# Qwen CN move: Bxf2+ Move number: 24
# Qwen US move: Ke2 Move number: 25
# Qwen CN move: Bf5 Move number: 26
# Qwen US move: e2f2 Move number: 27
# Qwen CN move: Ng8 Move number: 28
# Qwen US move: Bd3 Move number: 29
# Qwen CN move: d8d3 Move number: 30
# Qwen US move: g1e1 Move number: 31
# Qwen CN move: d3c2 Move number: 32
# Qwen US move: f2g1 Move number: 33
# Qwen CN move: f5h3 Move number: 34
# Qwen US move: Rd1 Move number: 35
# Qwen CN move: Rd8 Move number: 36
# Qwen US move: d1d8 Move number: 37
# Qwen CN move: Kxd8 Move number: 38
# Qwen US move: g2h3 Move number: 39
# Qwen CN move: Ne7 Move number: 40
# Qwen US move: Be3 Move number: 41
# Qwen CN move: Nf5 Move number: 42
# Qwen US move: Bh6 Move number: 43
# Qwen CN move: Ne3 Move number: 44
# Qwen US move: h6e3 Move number: 45
# Qwen CN move: Qe2 Move number: 46
# Qwen US move: Bf4 Move number: 47
# Qwen CN move: h7g6 Move number: 48
# Qwen US move: f4h6 Move number: 49
# Qwen CN move: Rg8 Move number: 50
# Qwen US move: h6f4 Move number: 51
# Qwen CN move: Qe1+ Move number: 52
# Qwen US move: Kh2 Move number: 53
# Qwen CN move: e1a1 Move number: 54
# Qwen US move: f4d6 Move number: 55
# Qwen CN move: a1b2 Move number: 56
# Qwen US move: h2g3 Move number: 57
# Qwen CN move: Qxc3+ Move number: 58
# Qwen US move: g3g4 Move number: 59
# Qwen CN move: c3d3 Move number: 60
# Qwen US move: e4e5 Move number: 61
# Qwen CN move: f6f5 Move number: 62
# Qwen US move: g4f4 Move number: 63
# Qwen CN move: d8e8 Move number: 64
# Qwen US move: e5e6 Move number: 65
# Qwen CN move: Qc2 Move number: 66
# Qwen US move: c4c5 Move number: 67
# Qwen CN move: c2f2 Move number: 68
# Qwen US move: Kg5 Move number: 69
# Qwen CN move: Qf1 Move number: 70
# Qwen US move: Bxe7 Move number: 71
# Qwen CN move: f1g2 Move number: 72
# Qwen US move: g5f4 Move number: 73
# Qwen CN move: e8e7 Move number: 74
# Qwen US move: Ke5 Move number: 75
# Qwen CN move: g2e4 Move number: 76
# Game 5 result: 0-1
#
#
# Starting game 6...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: Be7 Move number: 6
# Qwen US move: e1g1 Move number: 7
# Qwen CN move: a7a6 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Qwen CN move: d7c6 Move number: 10
# Qwen US move: Nxe5 Move number: 11
# Qwen CN move: d8d4 Move number: 12
# Qwen US move: d1h5 Move number: 13
# Qwen CN move: c8e6 Move number: 14
# Qwen US move: d2d3 Move number: 15
# Qwen CN move: g8f6 Move number: 16
# Qwen US move: h5g5 Move number: 17
# Qwen CN move: Qxe5 Move number: 18
# Qwen US move: Qxf6 Move number: 19
# Qwen CN move: e5f6 Move number: 20
# Qwen US move: f2f4 Move number: 21
# Qwen CN move: f6d4 Move number: 22
# Qwen US move: g1h1 Move number: 23
# Qwen CN move: d4a7 Move number: 24
# Qwen US move: Re1 Move number: 25
# Qwen CN move: e7h4 Move number: 26
# Qwen US move: Re3 Move number: 27
# Qwen CN move: Rg8 Move number: 28
# Qwen US move: Re2 Move number: 29
# Qwen CN move: e6g4 Move number: 30
# Qwen US move: Re1 Move number: 31
# Qwen CN move: Rd8 Move number: 32
# Qwen US move: c1e3 Move number: 33
# Qwen CN move: Rd6 Move number: 34
# Qwen US move: Bd2 Move number: 35
# Qwen CN move: a7b6 Move number: 36
# Qwen US move: e1c1 Move number: 37
# Qwen CN move: Rd4 Move number: 38
# Qwen US move: d2e3 Move number: 39
# Qwen CN move: c6c5 Move number: 40
# Qwen US move: Bxd4 Move number: 41
# Invalid move by Qwen black. Move: Bh6
# New Move: c4
# Qwen CN move: c4 Move number: 42
# Qwen US move: d4b6 Move number: 43
# Qwen CN move: c7b6 Move number: 44
# Qwen US move: e5 Move number: 45
# Qwen CN move: h4f2 Move number: 46
# Qwen US move: c1f1 Move number: 47
# Qwen CN move: f2d4 Move number: 48
# Qwen US move: c2c3 Move number: 49
# Qwen CN move: Bxc3 Move number: 50
# Qwen US move: b1c3 Move number: 51
# Qwen CN move: Bf5 Move number: 52
# Qwen US move: Nd5 Move number: 53
# Qwen CN move: Bxd3 Move number: 54
# Qwen US move: f1d1 Move number: 55
# Qwen CN move: Rh8 Move number: 56
# Qwen US move: Nc3 Move number: 57
# Qwen CN move: e8d7 Move number: 58
# Qwen US move: d1e1 Move number: 59
# Qwen CN move: b6b5 Move number: 60
# Qwen US move: a2a3 Move number: 61
# Qwen CN move: h8e8 Move number: 62
# Qwen US move: Nd5 Move number: 63
# Invalid move by Qwen black. Move: Re1
# New Move: Bb1
# Qwen CN move: Bb1 Move number: 64
# Qwen US move: a1b1 Move number: 65
# Qwen CN move: e8d8 Move number: 66
# Qwen US move: Ne7 Move number: 67
# Qwen CN move: d7e7 Move number: 68
# Qwen US move: f4f5 Move number: 69
# Qwen CN move: g7g6 Move number: 70
# Qwen US move: f5f6 Move number: 71
# Qwen CN move: Kf8 Move number: 72
# Qwen US move: b1d1 Move number: 73
# Qwen CN move: Rd2 Move number: 74
# Qwen US move: Re4 Move number: 75
# Qwen CN move: Rd4 Move number: 76
# Qwen US move: e4d4 Move number: 77
# Invalid move by Qwen black. Move: Re8
# New Move: Ke8
# Qwen CN move: Ke8 Move number: 78
# Qwen US move: d4d8 Move number: 79
# Game 6 result: 1-0
#
#
# Starting game 7...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Qwen CN move: d5 Move number: 6
# Qwen US move: e4d5 Move number: 7
# Qwen CN move: Nxd4 Move number: 8
# Qwen US move: Nfd2 Move number: 9
# Qwen CN move: Nf6 Move number: 10
# Qwen US move: c2c3 Move number: 11
# Invalid move by Qwen black. Move: Nbd2
# New Move: Qa5
# Qwen CN move: Qa5 Move number: 12
# Qwen US move: d2c4 Move number: 13
# Qwen CN move: Nxe6 Move number: 14
# Qwen US move: c4a5 Move number: 15
# Qwen CN move: e6c7 Move number: 16
# Qwen US move: b1a3 Move number: 17
# Qwen CN move: f6d5 Move number: 18
# Qwen US move: Nxb7 Move number: 19
# Qwen CN move: c8b7 Move number: 20
# Qwen US move: Nc4 Move number: 21
# Qwen CN move: Rg8 Move number: 22
# Qwen US move: Nd2 Move number: 23
# Qwen CN move: e8c8 Move number: 24
# Qwen US move: Ne4 Move number: 25
# Qwen CN move: Ne3 Move number: 26
# Qwen US move: d1d8 Move number: 27
# Qwen CN move: c8d8 Move number: 28
# Qwen US move: c1e3 Move number: 29
# Qwen CN move: b7e4 Move number: 30
# Qwen US move: e3c5 Move number: 31
# Invalid move by Qwen black. Move: Bxd6
# New Move: Bb1
# Qwen CN move: Bb1 Move number: 32
# Qwen US move: a1b1 Move number: 33
# Qwen CN move: g7g6 Move number: 34
# Qwen US move: Bxe7+ Move number: 35
# Qwen CN move: d8e7 Move number: 36
# Qwen US move: e1d1 Move number: 37
# Qwen CN move: f8h6 Move number: 38
# Qwen US move: d1c2 Move number: 39
# Qwen CN move: Rd8 Move number: 40
# Qwen US move: b1d1 Move number: 41
# Qwen CN move: Rd2+ Move number: 42
# Qwen US move: Kb3 Move number: 43
# Qwen CN move: Kd7 Move number: 44
# Qwen US move: d1d2 Move number: 45
# Qwen CN move: Ke7 Move number: 46
# Qwen US move: Rd4 Move number: 47
# Qwen CN move: c7e6 Move number: 48
# Qwen US move: d4d5 Move number: 49
# Qwen CN move: h6f4 Move number: 50
# Qwen US move: g2g3 Move number: 51
# Qwen CN move: f4c7 Move number: 52
# Qwen US move: Rd8 Move number: 53
# Qwen CN move: Bxd8 Move number: 54
# Qwen US move: b3c4 Move number: 55
# Invalid move by Qwen black. Move: Nxd5
# New Move: f5
# Qwen CN move: f5 Move number: 56
# Qwen US move: f1g2 Move number: 57
# Qwen CN move: e7f6 Move number: 58
# Qwen US move: Kd3 Move number: 59
# Qwen CN move: f5f4 Move number: 60
# Qwen US move: h1d1 Move number: 61
# Qwen CN move: d8b6 Move number: 62
# Qwen US move: d3e2 Move number: 63
# Qwen CN move: Kf7 Move number: 64
# Qwen US move: g2d5 Move number: 65
# Qwen CN move: Kf6 Move number: 66
# Invalid move by Qwen white. Move: Bxd8
# New Move: Bb3
# Qwen US move: Bb3 Move number: 67
# Qwen CN move: f4g3 Move number: 68
# Qwen US move: Bxe6 Move number: 69
# Qwen CN move: g3h2 Move number: 70
# Qwen US move: e6d5 Move number: 71
# Qwen CN move: g6g5 Move number: 72
# Qwen US move: d1h1 Move number: 73
# Invalid move by Qwen black. Move: Rd5
# New Move: Kf5
# Qwen CN move: Kf5 Move number: 74
# Qwen US move: h1h2 Move number: 75
# Qwen CN move: Bd4 Move number: 76
# Qwen US move: c3d4 Move number: 77
# Qwen CN move: f5f4 Move number: 78
# Qwen US move: h2h7 Move number: 79
# Qwen CN move: f4g4 Move number: 80
# Qwen US move: Rh8 Move number: 81
# Qwen CN move: g4f5 Move number: 82
# Invalid move by Qwen white. Move: Bxd4
# New Move: Rh7
# Qwen US move: Rh7 Move number: 83
# Qwen CN move: f5g6 Move number: 84
# Qwen US move: Rh8 Move number: 85
# Qwen CN move: g6f5 Move number: 86
# Qwen US move: e2e3 Move number: 87
# Qwen CN move: a7a5 Move number: 88
# Qwen US move: h8h6 Move number: 89
# Invalid move by Qwen black. Move: Rh8
# New Move: a4
# Qwen CN move: a4 Move number: 90
# Qwen US move: d5e6 Move number: 91
# Game 7 result: 1-0
#
#
# Starting game 8...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: a7a6 Move number: 6
# Qwen US move: Bxc6 Move number: 7
# Qwen CN move: d7c6 Move number: 8
# Qwen US move: Ng5 Move number: 9
# Qwen CN move: Nxe7+ Move number: 10
# Qwen US move: Nh3 Move number: 11
# Qwen CN move: e7g6 Move number: 12
# Qwen US move: Ng5 Move number: 13
# Qwen CN move: Bd6 Move number: 14
# Qwen US move: d2d3 Move number: 15
# Qwen CN move: h7h6 Move number: 16
# Qwen US move: g5f3 Move number: 17
# Qwen CN move: a6a5 Move number: 18
# Qwen US move: b1d2 Move number: 19
# Qwen CN move: Nf4 Move number: 20
# Qwen US move: Nh4 Move number: 21
# Qwen CN move: d8h4 Move number: 22
# Qwen US move: Nc4 Move number: 23
# Qwen CN move: d6b4 Move number: 24
# Invalid move by Qwen white. Move: Nf3
# New Move: Kf1
# Qwen US move: Kf1 Move number: 25
# Qwen CN move: c8g4 Move number: 26
# Qwen US move: Qe2 Move number: 27
# Qwen CN move: g4e2 Move number: 28
# Qwen US move: f1g1 Move number: 29
# Qwen CN move: e2h5 Move number: 30
# Qwen US move: c1f4 Move number: 31
# Qwen CN move: Rg8 Move number: 32
# Qwen US move: f4e5 Move number: 33
# Qwen CN move: Bxd6 Move number: 34
# Qwen US move: Bxd6 Move number: 35
# Qwen CN move: Rd8 Move number: 36
# Qwen US move: d6c7 Move number: 37
# Qwen CN move: Rd6 Move number: 38
# Qwen US move: Bxd8 Move number: 39
# Qwen CN move: d6d8 Move number: 40
# Qwen US move: e4e5 Move number: 41
# Qwen CN move: g7g5 Move number: 42
# Qwen US move: a1e1 Move number: 43
# Qwen CN move: e8f8 Move number: 44
# Qwen US move: Re2 Move number: 45
# Qwen CN move: Rd4 Move number: 46
# Qwen US move: e2e1 Move number: 47
# Invalid move by Qwen black. Move: Rg8
# New Move: Bg4
# Qwen CN move: Bg4 Move number: 48
# Qwen US move: c4d6 Move number: 49
# Invalid move by Qwen black. Move: Nxe7+
# New Move: Qg3
# Qwen CN move: Qg3 Move number: 50
# Qwen US move: h2g3 Move number: 51
# Qwen CN move: Rxd3 Move number: 52
# Qwen US move: c2d3 Move number: 53
# Qwen CN move: g4e6 Move number: 54
# Qwen US move: a2a3 Move number: 55
# Qwen CN move: b7b5 Move number: 56
# Qwen US move: Rxh6 Move number: 57
# Qwen CN move: f8g7 Move number: 58
# Invalid move by Qwen white. Move: Re1
# New Move: Rh3
# Qwen US move: Rh3 Move number: 59
# Qwen CN move: e6h3 Move number: 60
# Qwen US move: Nxf7 Move number: 61
# Qwen CN move: g7f7 Move number: 62
# Qwen US move: g2h3 Move number: 63
# Qwen CN move: g8d8 Move number: 64
# Qwen US move: e5e6 Move number: 65
# Qwen CN move: Kg7 Move number: 66
# Qwen US move: e6e7 Move number: 67
# Qwen CN move: Rd5 Move number: 68
# Qwen US move: Re6 Move number: 69
# Qwen CN move: Rd4 Move number: 70
# Qwen US move: g1g2 Move number: 71
# Invalid move by Qwen black. Move: Rd1
# New Move: Kf7
# Qwen CN move: Kf7 Move number: 72
# Qwen US move: e7e8q Move number: 73
# Qwen CN move: Kg7 Move number: 74
# Qwen US move: e8g6 Move number: 75
# Qwen CN move: g7f8 Move number: 76
# Qwen US move: e6e8 Move number: 77
# Game 8 result: 1-0
#
#
# Starting game 9...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Invalid move by Qwen black. Move: Nc6
# New Move: Ba3
# Qwen CN move: Ba3 Move number: 6
# Qwen US move: e5c6 Move number: 7
# Invalid move by Qwen black. Move: Nxc6
# New Move: d6
# Qwen CN move: d6 Move number: 8
# Qwen US move: c6d8 Move number: 9
# Qwen CN move: g8f6 Move number: 10
# Qwen US move: Nxb7 Move number: 11
# Qwen CN move: f6e4 Move number: 12
# Qwen US move: f1b5 Move number: 13
# Qwen CN move: e8f8 Move number: 14
# Qwen US move: d2d3 Move number: 15
# Qwen CN move: Bxb2 Move number: 16
# Qwen US move: c1b2 Move number: 17
# Qwen CN move: Bd7 Move number: 18
# Qwen US move: Bd4 Move number: 19
# Invalid move by Qwen black. Move: Bd5
# New Move: Rb8
# Qwen CN move: Rb8 Move number: 20
# Qwen US move: b5d7 Move number: 21
# Qwen CN move: Rxb7 Move number: 22
# Qwen US move: d4e3 Move number: 23
# Qwen CN move: e4f6 Move number: 24
# Qwen US move: d7c6 Move number: 25
# Qwen CN move: b7b8 Move number: 26
# Qwen US move: Bxd7 Move number: 27
# Qwen CN move: f6d7 Move number: 28
# Qwen US move: Bd4 Move number: 29
# Qwen CN move: Rb6 Move number: 30
# Qwen US move: Bxg7+ Move number: 31
# Qwen CN move: f8g7 Move number: 32
# Qwen US move: Qe2 Move number: 33
# Qwen CN move: Rd8 Move number: 34
# Qwen US move: e1g1 Move number: 35
# Qwen CN move: b6b4 Move number: 36
# Qwen US move: g1h1 Move number: 37
# Qwen CN move: b4h4 Move number: 38
# Qwen US move: e2e7 Move number: 39
# Qwen CN move: Re8 Move number: 40
# Qwen US move: Qf8+ Move number: 41
# Qwen CN move: d7f8 Move number: 42
# Qwen US move: Rd1 Move number: 43
# Qwen CN move: e8e2 Move number: 44
# Qwen US move: Rd2 Move number: 45
# Invalid move by Qwen black. Move: Rd6
# New Move: Kf6
# Qwen CN move: Kf6 Move number: 46
# Qwen US move: d2e2 Move number: 47
# Qwen CN move: Nd7 Move number: 48
# Qwen US move: g2g3 Move number: 49
# Qwen CN move: h4h5 Move number: 50
# Qwen US move: b1c3 Move number: 51
# Qwen CN move: d7e5 Move number: 52
# Qwen US move: Nd5+ Move number: 53
# Qwen CN move: f6g7 Move number: 54
# Qwen US move: Nc3 Move number: 55
# Qwen CN move: Ng4 Move number: 56
# Qwen US move: Nd5 Move number: 57
# Qwen CN move: h5d5 Move number: 58
# Qwen US move: Re8 Move number: 59
# Qwen CN move: Rd4 Move number: 60
# Qwen US move: h1g2 Move number: 61
# Qwen CN move: g4f6 Move number: 62
# Qwen US move: e8c8 Move number: 63
# Qwen CN move: f6d5 Move number: 64
# Qwen US move: a2a4 Move number: 65
# Qwen CN move: Nf4+ Move number: 66
# Qwen US move: Kf3 Move number: 67
# Qwen CN move: f4e6 Move number: 68
# Qwen US move: Rxc7 Move number: 69
# Qwen CN move: e6c7 Move number: 70
# Qwen US move: Rd1 Move number: 71
# Qwen CN move: Rd5 Move number: 72
# Qwen US move: Rd2 Move number: 73
# Qwen CN move: Rd4 Move number: 74
# Qwen US move: Ke2 Move number: 75
# Qwen CN move: d4a4 Move number: 76
# Qwen US move: Kf3 Move number: 77
# Invalid move by Qwen black. Move: Re1
# New Move: Rb4
# Qwen CN move: Rb4 Move number: 78
# Qwen US move: c2c4 Move number: 79
# Qwen CN move: a7a5 Move number: 80
# Qwen US move: Kg4 Move number: 81
# Qwen CN move: d6d5 Move number: 82
# Qwen US move: d2c2 Move number: 83
# Qwen CN move: c7e6 Move number: 84
# Qwen US move: f2f4 Move number: 85
# Qwen CN move: dxc4 Move number: 86
# Qwen US move: d3c4 Move number: 87
# Qwen CN move: Rb1 Move number: 88
# Qwen US move: Kh3 Move number: 89
# Qwen CN move: Ng5+ Move number: 90
# Qwen US move: f4g5 Move number: 91
# Invalid move by Qwen black. Move: Kf2
# New Move: a4
# Qwen CN move: a4 Move number: 92
# Qwen US move: c4c5 Move number: 93
# Qwen CN move: a4a3 Move number: 94
# Qwen US move: Rc4 Move number: 95
# Qwen CN move: a3a2 Move number: 96
# Qwen US move: c5c6 Move number: 97
# Qwen CN move: a2a1q Move number: 98
# Qwen US move: c6c7 Move number: 99
# Qwen CN move: Kg6 Move number: 100
# Qwen US move: c7c8q Move number: 101
# Qwen CN move: Qa5 Move number: 102
# Qwen US move: Qd8 Move number: 103
# Qwen CN move: Qxd5 Move number: 104
# Qwen US move: d8f6 Move number: 105
# Qwen CN move: Kh5 Move number: 106
# Qwen US move: Qh8 Move number: 107
# Qwen CN move: d5c4 Move number: 108
# Qwen US move: h8h7 Move number: 109
# Qwen CN move: h5g5 Move number: 110
# Qwen US move: h7g7 Move number: 111
# Qwen CN move: g5f5 Move number: 112
# Qwen US move: Qh8 Move number: 113
# Qwen CN move: Qh4+ Move number: 114
# Qwen US move: h8h4 Move number: 115
# Qwen CN move: Kg6 Move number: 116
# Qwen US move: h4e4 Move number: 117
# Qwen CN move: Kg5 Move number: 118
# Invalid move by Qwen white. Move: Qg7+
# New Move: Qd3
# Qwen US move: Qd3 Move number: 119
# Qwen CN move: b1b2 Move number: 120
# Qwen US move: d3c3 Move number: 121
# Qwen CN move: Rb1 Move number: 122
# Qwen US move: c3g7 Move number: 123
# Qwen CN move: g5f5 Move number: 124
# Qwen US move: g7f7 Move number: 125
# Qwen CN move: f5e5 Move number: 126
# Qwen US move: Qg8 Move number: 127
# Qwen CN move: e5f6 Move number: 128
# Qwen US move: Qh8+ Move number: 129
# Invalid move by Qwen black. Move: Qg8
# New Move: Kf5
# Qwen CN move: Kf5 Move number: 130
# Qwen US move: h8h7 Move number: 131
# Qwen CN move: f5e6 Move number: 132
# Invalid move by Qwen white. Move: Qh7+
# New Move: Kg2
# Qwen US move: Kg2 Move number: 133
# Qwen CN move: b1e1 Move number: 134
# Qwen US move: g3g4 Move number: 135
# Qwen CN move: Kf6 Move number: 136
# Qwen US move: h7h4 Move number: 137
# Qwen CN move: f6e6 Move number: 138
# Qwen US move: h4e1 Move number: 139
# Qwen CN move: e6d6 Move number: 140
# Invalid move by Qwen white. Move: Qh4+
# New Move: Qd2+
# Qwen US move: Qd2+ Move number: 141
# Qwen CN move: d6c6 Move number: 142
# Qwen US move: g2f3 Move number: 143
# Qwen CN move: Kb6 Move number: 144
# Qwen US move: d2d8 Move number: 145
# Qwen CN move: b6c5 Move number: 146
# Qwen US move: f3f4 Move number: 147
# Qwen CN move: c5c4 Move number: 148
# Qwen US move: Qh8 Move number: 149
# Qwen CN move: c4d3 Move number: 150
# Qwen US move: Qg8 Move number: 151
# Qwen CN move: Kd4 Move number: 152
# Qwen US move: Qh8+ Move number: 153
# Qwen CN move: d4d3 Move number: 154
# Qwen US move: Qg8 Move number: 155
# Qwen CN move: Kd4 Move number: 156
# Qwen US move: f4f5 Move number: 157
# Qwen CN move: d4c3 Move number: 158
# Qwen US move: h2h4 Move number: 159
# Qwen CN move: c3d4 Move number: 160
# Qwen US move: g8d8 Move number: 161
# Invalid move by Qwen black. Move: Qg8+
# New Move: Kc5
# Qwen CN move: Kc5 Move number: 162
# Qwen US move: f5f6 Move number: 163
# Qwen CN move: Kc4 Move number: 164
# Qwen US move: g4g5 Move number: 165
# Qwen CN move: c4c5 Move number: 166
# Qwen US move: h4h5 Move number: 167
# Qwen CN move: c5c6 Move number: 168
# Invalid move by Qwen white. Move: Qh7+
# New Move: Ke7
# Qwen US move: Ke7 Move number: 169
# Qwen CN move: c6c5 Move number: 170
# Qwen US move: d8d6 Move number: 171
# Qwen CN move: Kb5 Move number: 172
# Qwen US move: g5g6 Move number: 173
# Qwen CN move: b5c4 Move number: 174
# Qwen US move: g6g7 Move number: 175
# Qwen CN move: c4b3 Move number: 176
# Qwen US move: Qd8+ Move number: 177
# Qwen CN move: b3b4 Move number: 178
# Invalid move by Qwen white. Move: Qh7+
# New Move: Kd7
# Qwen US move: Kd7 Move number: 179
# Qwen CN move: b4b5 Move number: 180
# Qwen US move: g7g8q Move number: 181
# Qwen CN move: Kb4 Move number: 182
# Qwen US move: d8b6 Move number: 183
# Qwen CN move: b4c3 Move number: 184
# Qwen US move: g8b3 Move number: 185
# Qwen CN move: c3d2 Move number: 186
# Qwen US move: Qg1 Move number: 187
# Qwen CN move: d2e2 Move number: 188
# Invalid move by Qwen white. Move: Qb6+
# New Move: Qgg3
# Qwen US move: Qgg3 Move number: 189
# Qwen CN move: e2d2 Move number: 190
# Qwen US move: g3e3 Move number: 191
# Game 9 result: 1-0
#
#
# Starting game 10...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Qwen CN move: Nf6 Move number: 6
# Qwen US move: e4e5 Move number: 7
# Qwen CN move: Nxe5 Move number: 8
# Qwen US move: Ng5 Move number: 9
# Invalid move by Qwen black. Move: Nxe6
# New Move: d6
# Qwen CN move: d6 Move number: 10
# Qwen US move: d4e5 Move number: 11
# Qwen CN move: h7h6 Move number: 12
# Qwen US move: Nxe6 Move number: 13
# Qwen CN move: c8e6 Move number: 14
# Qwen US move: e5f6 Move number: 15
# Qwen CN move: g7f6 Move number: 16
# Qwen US move: b1c3 Move number: 17
# Invalid move by Qwen black. Move: Be3
# New Move: Bxa2
# Qwen CN move: Bxa2 Move number: 18
# Qwen US move: f1b5 Move number: 19
# Qwen CN move: d8d7 Move number: 20
# Qwen US move: Bxd7+ Move number: 21
# Qwen CN move: e8d7 Move number: 22
# Qwen US move: d1f3 Move number: 23
# Qwen CN move: d6d5 Move number: 24
# Qwen US move: c3a2 Move number: 25
# Qwen CN move: Rg8 Move number: 26
# Qwen US move: f3d5 Move number: 27
# Invalid move by Qwen black. Move: Qf3
# New Move: Kc7
# Qwen CN move: Kc7 Move number: 28
# Qwen US move: c1f4 Move number: 29
# Qwen CN move: e7e5 Move number: 30
# Qwen US move: Qd8+ Move number: 31
# Qwen CN move: a8d8 Move number: 32
# Qwen US move: f4g3 Move number: 33
# Qwen CN move: c7c6 Move number: 34
# Qwen US move: a2c3 Move number: 35
# Qwen CN move: Rd1+ Move number: 36
# Qwen US move: c3d1 Move number: 37
# Qwen CN move: Rxg3 Move number: 38
# Qwen US move: Rxa7 Move number: 39
# Qwen CN move: Rg4 Move number: 40
# Qwen US move: d1e3 Move number: 41
# Qwen CN move: Bd6 Move number: 42
# Qwen US move: Rxb7 Move number: 43
# Qwen CN move: g4g2 Move number: 44
# Qwen US move: b7f7 Move number: 45
# Qwen CN move: g2g6 Move number: 46
# Qwen US move: e1e2 Move number: 47
# Qwen CN move: c5c4 Move number: 48
# Qwen US move: Rc1 Move number: 49
# Qwen CN move: Rg8 Move number: 50
# Qwen US move: f7f6 Move number: 51
# Qwen CN move: Rf8 Move number: 52
# Qwen US move: f6h6 Move number: 53
# Qwen CN move: Rxf2+ Move number: 54
# Qwen US move: Kxf2 Move number: 55
# Invalid move by Qwen black. Move: Ke1
# New Move: Kc7
# Qwen CN move: Kc7 Move number: 56
# Qwen US move: c1f1 Move number: 57
# Qwen CN move: Kd7 Move number: 58
# Qwen US move: h6d6 Move number: 59
# Qwen CN move: d7d6 Move number: 60
# Qwen US move: c2c3 Move number: 61
# Qwen CN move: d6c5 Move number: 62
# Qwen US move: Nf5 Move number: 63
# Qwen CN move: c5d5 Move number: 64
# Invalid move by Qwen white. Move: Nf5
# New Move: Rb1
# Qwen US move: Rb1 Move number: 65
# Qwen CN move: d5e6 Move number: 66
# Qwen US move: f5e3 Move number: 67
# Qwen CN move: Kf7 Move number: 68
# Qwen US move: f2f3 Move number: 69
# Qwen CN move: f7f6 Move number: 70
# Qwen US move: f3e4 Move number: 71
# Qwen CN move: f6e6 Move number: 72
# Invalid move by Qwen white. Move: Nh5
# New Move: Ng4
# Qwen US move: Ng4 Move number: 73
# Qwen CN move: e6f7 Move number: 74
# Qwen US move: Nh6+ Move number: 75
# Qwen CN move: f7e7 Move number: 76
# Qwen US move: h6f5 Move number: 77
# Qwen CN move: e7e6 Move number: 78
# Qwen US move: h2h4 Move number: 79
# Qwen CN move: Kf6 Move number: 80
# Qwen US move: b1a1 Move number: 81
# Invalid move by Qwen black. Move: Nf5+
# New Move: Ke6
# Qwen CN move: Ke6 Move number: 82
# Qwen US move: a1f1 Move number: 83
# Qwen CN move: e6d7 Move number: 84
# Qwen US move: Ng7 Move number: 85
# Qwen CN move: d7c6 Move number: 86
# Qwen US move: h4h5 Move number: 87
# Qwen CN move: c6c5 Move number: 88
# Qwen US move: f1f6 Move number: 89
# Invalid move by Qwen black. Move: Ng7
# New Move: Kb5
# Qwen CN move: Kb5 Move number: 90
# Qwen US move: e4e5 Move number: 91
# Invalid move by Qwen black. Move: Nf5+
# New Move: Ka4
# Qwen CN move: Ka4 Move number: 92
# Qwen US move: f6b6 Move number: 93
# Qwen CN move: a4a5 Move number: 94
# Qwen US move: Rf6 Move number: 95
# Qwen CN move: a5b5 Move number: 96
# Qwen US move: e5d6 Move number: 97
# Qwen CN move: b5a4 Move number: 98
# Qwen US move: f6g6 Move number: 99
# Invalid move by Qwen black. Move: Ng7
# New Move: Kb3
# Qwen CN move: Kb3 Move number: 100
# Qwen US move: g6g2 Move number: 101
# Qwen CN move: b3a2 Move number: 102
# Qwen US move: Ne8 Move number: 103
# Qwen CN move: a2b1 Move number: 104
# Qwen US move: h5h6 Move number: 105
# Qwen CN move: b1a2 Move number: 106
# Qwen US move: h6h7 Move number: 107
# Invalid move by Qwen black. Move: Nh6+
# New Move: Ka1
# Qwen CN move: Ka1 Move number: 108
# Qwen US move: h7h8q Move number: 109
# Qwen CN move: a1a2 Move number: 110
# Qwen US move: Ng7 Move number: 111
# Qwen CN move: a2b3 Move number: 112
# Qwen US move: h8b8 Move number: 113
# Qwen CN move: b3a2 Move number: 114
# Qwen US move: b8a7 Move number: 115
# Invalid move by Qwen black. Move: Qa6+
# New Move: Kb3
# Qwen CN move: Kb3 Move number: 116
# Qwen US move: a7a3 Move number: 117
# Game 10 result: 1-0
#
#
# Starting game 11...
# Qwen US move: e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: Nf6 Move number: 6
# Qwen US move: b1c3 Move number: 7
# Qwen CN move: Nxe4 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Invalid move by Qwen black. Move: Bxc7
# New Move: c4
# Qwen CN move: c4 Move number: 10
# Qwen US move: c6e4 Move number: 11
# Qwen CN move: e7e6 Move number: 12
# Invalid move by Qwen white. Move: Bxc7
# New Move: Ng5
# Qwen US move: Ng5 Move number: 13
# Qwen CN move: d8g5 Move number: 14
# Invalid move by Qwen white. Move: Bxc4
# New Move: Bd3
# Qwen US move: Bd3 Move number: 15
# Qwen CN move: c4d3 Move number: 16
# Qwen US move: Nxd5 Move number: 17
# Qwen CN move: g5g2 Move number: 18
# Qwen US move: h1f1 Move number: 19
# Qwen CN move: g2d5 Move number: 20
# Qwen US move: c2d3 Move number: 21
# Qwen CN move: Rg8 Move number: 22
# Qwen US move: d1g4 Move number: 23
# Qwen CN move: Qf3 Move number: 24
# Qwen US move: Qxf3 Move number: 25
# Qwen CN move: Rh8 Move number: 26
# Qwen US move: f1g1 Move number: 27
# Qwen CN move: Rg8 Move number: 28
# Qwen US move: Qxf7+ Move number: 29
# Qwen CN move: e8f7 Move number: 30
# Qwen US move: b2b3 Move number: 31
# Qwen CN move: g7g6 Move number: 32
# Qwen US move: c1b2 Move number: 33
# Qwen CN move: f8e7 Move number: 34
# Qwen US move: Bd4 Move number: 35
# Invalid move by Qwen black. Move: Be5
# New Move: a6
# Qwen CN move: a6 Move number: 36
# Qwen US move: a1c1 Move number: 37
# Qwen CN move: b7b5 Move number: 38
# Qwen US move: Bf6 Move number: 39
# Qwen CN move: e7f6 Move number: 40
# Qwen US move: d3d4 Move number: 41
# Qwen CN move: c8b7 Move number: 42
# Qwen US move: g1g3 Move number: 43
# Invalid move by Qwen black. Move: Rg8
# New Move: Raf8
# Qwen CN move: Raf8 Move number: 44
# Qwen US move: c1c7 Move number: 45
# Invalid move by Qwen black. Move: Rc6
# New Move: Ke8
# Qwen CN move: Ke8 Move number: 46
# Qwen US move: c7b7 Move number: 47
# Qwen CN move: Bh4 Move number: 48
# Qwen US move: g3h3 Move number: 49
# Qwen CN move: g6g5 Move number: 50
# Qwen US move: d4d5 Move number: 51
# Qwen CN move: e6d5 Move number: 52
# Qwen US move: Rb8+ Move number: 53
# Qwen CN move: e8f7 Move number: 54
# Qwen US move: Rxf8+ Move number: 55
# Qwen CN move: Rxf8 Move number: 56
# Qwen US move: Rxh4 Move number: 57
# Qwen CN move: g5h4 Move number: 58
# Qwen US move: Kf1 Move number: 59
# Qwen CN move: Rh8 Move number: 60
# Qwen US move: f1e2 Move number: 61
# Qwen CN move: h8e8 Move number: 62
# Qwen US move: e2f3 Move number: 63
# Qwen CN move: f7g6 Move number: 64
# Qwen US move: f3g2 Move number: 65
# Qwen CN move: h6 Move number: 66
# Qwen US move: Kf3 Move number: 67
# Qwen CN move: d5d4 Move number: 68
# Qwen US move: Kg2 Move number: 69
# Qwen CN move: g6f5 Move number: 70
# Qwen US move: Kf3 Move number: 71
# Qwen CN move: Re1 Move number: 72
# Qwen US move: Kg2 Move number: 73
# Invalid move by Qwen black. Move: Kf3
# New Move: Rb1
# Qwen CN move: Rb1 Move number: 74
# Qwen US move: d2d3 Move number: 75
# Qwen CN move: f5f4 Move number: 76
# Qwen US move: h3 Move number: 77
# Qwen CN move: b5b4 Move number: 78
# Qwen US move: f2f3 Move number: 79
# Qwen CN move: b1b2 Move number: 80
# Qwen US move: g2g1 Move number: 81
# Qwen CN move: Rxb3 Move number: 82
# Qwen US move: a2b3 Move number: 83
# Qwen CN move: d6 Move number: 84
# Qwen US move: Kh2 Move number: 85
# Qwen CN move: Kf5 Move number: 86
# Qwen US move: h2g2 Move number: 87
# Invalid move by Qwen black. Move: Kf3
# New Move: Kf6
# Qwen CN move: Kf6 Move number: 88
# Qwen US move: g2f2 Move number: 89
# Invalid move by Qwen black. Move: Kf3
# New Move: a5
# Qwen CN move: a5 Move number: 90
# Qwen US move: f2e2 Move number: 91
# Qwen CN move: f6e5 Move number: 92
# Qwen US move: Kf2 Move number: 93
# Qwen CN move: e5f4 Move number: 94
# Qwen US move: f2g2 Move number: 95
# Qwen CN move: f4e3 Move number: 96
# Qwen US move: f3f4 Move number: 97
# Qwen CN move: Kxf4 Move number: 98
# Qwen US move: g2f2 Move number: 99
# Qwen CN move: Ke5 Move number: 100
# Qwen US move: Kg1 Move number: 101
# Qwen CN move: Kf4 Move number: 102
# Qwen US move: g1g2 Move number: 103
# Invalid move by Qwen black. Move: Kf3
# New Move: d5
# Qwen CN move: d5 Move number: 104
# Qwen US move: g2f1 Move number: 105
# Qwen CN move: f4e3 Move number: 106
# Qwen US move: Kg1 Move number: 107
# Qwen CN move: e3d3 Move number: 108
# Qwen US move: g1f2 Move number: 109
# Qwen CN move: d3c2 Move number: 110
# Qwen US move: f2f3 Move number: 111
# Qwen CN move: Kd1 Move number: 112
# Qwen US move: f3g4 Move number: 113
# Invalid move by Qwen black. Move: Kf2
# New Move: Kd2
# Qwen CN move: Kd2 Move number: 114
# Qwen US move: g4h4 Move number: 115
# Invalid move by Qwen black. Move: Kg4
# New Move: d3
# Qwen CN move: d3 Move number: 116
# Qwen US move: h4h5 Move number: 117
# Qwen CN move: d2c3 Move number: 118
# Qwen US move: Kg4 Move number: 119
# Qwen CN move: d3d2 Move number: 120
# Qwen US move: g4h5 Move number: 121
# Qwen CN move: d5d4 Move number: 122
# Qwen US move: h5g6 Move number: 123
# Qwen CN move: d1=Q Move number: 124
# Qwen US move: g6h7 Move number: 125
# Invalid move by Qwen black. Move: Kf2
# New Move: h5
# Qwen CN move: h5 Move number: 126
# Qwen US move: h7g6 Move number: 127
# Qwen CN move: d4d3 Move number: 128
# Qwen US move: Kg7 Move number: 129
# Qwen CN move: d3d2 Move number: 130
# Qwen US move: g7f6 Move number: 131
# Qwen CN move: d1g1 Move number: 132
# Qwen US move: f6e5 Move number: 133
# Invalid move by Qwen black. Move: Kf6
# New Move: Qe1+
# Qwen CN move: Qe1+ Move number: 134
# Qwen US move: e5f6 Move number: 135
# Qwen CN move: d2d1q Move number: 136
# Qwen US move: Kg7 Move number: 137
# Qwen CN move: e1e7 Move number: 138
# Qwen US move: g7g6 Move number: 139
# Qwen CN move: d1g1 Move number: 140
# Qwen US move: g6h6 Move number: 141
# Qwen CN move: Qg8 Move number: 142
# Qwen US move: h6h5 Move number: 143
# Invalid move by Qwen black. Move: Qg8#
# New Move: Qe1
# Qwen CN move: Qe1 Move number: 144
# Qwen US move: h3h4 Move number: 145
# Qwen CN move: c3b3 Move number: 146
# Qwen US move: Kh6 Move number: 147
# Qwen CN move: e1h4 Move number: 148
# Game 11 result: 0-1
#
#
# Starting game 12...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: Nc6 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Invalid move by Qwen black. Move: Bc4
# New Move: g6
# Qwen CN move: g6 Move number: 6
# Qwen US move: c2c3 Move number: 7
# Qwen CN move: a7a6 Move number: 8
# Qwen US move: Bxc6 Move number: 9
# Qwen CN move: d7c6 Move number: 10
# Qwen US move: d2d4 Move number: 11
# Qwen CN move: e5d4 Move number: 12
# Qwen US move: c3d4 Move number: 13
# Qwen CN move: Nf6 Move number: 14
# Qwen US move: b1c3 Move number: 15
# Qwen CN move: Bg7 Move number: 16
# Invalid move by Qwen white. Move: Nbd2
# New Move: Na4
# Qwen US move: Na4 Move number: 17
# Qwen CN move: f6e4 Move number: 18
# Qwen US move: Nc5 Move number: 19
# Qwen CN move: e4c5 Move number: 20
# Qwen US move: d4c5 Move number: 21
# Qwen CN move: d8d1 Move number: 22
# Qwen US move: e1d1 Move number: 23
# Qwen CN move: Rg8 Move number: 24
# Qwen US move: c1f4 Move number: 25
# Invalid move by Qwen black. Move: Bxc6
# New Move: Bxb2
# Qwen CN move: Bxb2 Move number: 26
# Qwen US move: a1b1 Move number: 27
# Qwen CN move: b2f6 Move number: 28
# Qwen US move: Bxc7 Move number: 29
# Qwen CN move: f6e7 Move number: 30
# Qwen US move: h1e1 Move number: 31
# Qwen CN move: e8f8 Move number: 32
# Qwen US move: c7b6 Move number: 33
# Qwen CN move: Bxc5 Move number: 34
# Qwen US move: b6c5 Move number: 35
# Qwen CN move: Kg7 Move number: 36
# Qwen US move: Bd6 Move number: 37
# Qwen CN move: Bxd7 Move number: 38
# Qwen US move: d6e5 Move number: 39
# Invalid move by Qwen black. Move: Ke2
# New Move: f6
# Qwen CN move: f6 Move number: 40
# Qwen US move: b1b7 Move number: 41
# Qwen CN move: g8d8 Move number: 42
# Qwen US move: Rb8 Move number: 43
# Qwen CN move: a8b8 Move number: 44
# Qwen US move: e5b8 Move number: 45
# Qwen CN move: d7f5 Move number: 46
# Qwen US move: f3d2 Move number: 47
# Qwen CN move: Rd3 Move number: 48
# Qwen US move: e1e7 Move number: 49
# Invalid move by Qwen black. Move: Rd1
# New Move: Kh8
# Qwen CN move: Kh8 Move number: 50
# Qwen US move: b8f4 Move number: 51
# Qwen CN move: Bh3 Move number: 52
# Qwen US move: g2h3 Move number: 53
# Qwen CN move: d3h3 Move number: 54
# Qwen US move: f4g3 Move number: 55
# Qwen CN move: h3h5 Move number: 56
# Qwen US move: Re8+ Move number: 57
# Qwen CN move: h8g7 Move number: 58
# Qwen US move: Re1 Move number: 59
# Invalid move by Qwen black. Move: Re7+
# New Move: a5
# ...
# Qwen US move: d3b5 Move number: 97
# Qwen CN move: d7c7 Move number: 98
# Qwen US move: e8e3 Move number: 99
# Invalid move by Qwen black. Move: Re1
# New Move: Kd8
# Qwen CN move: Kd8 Move number: 100
# Qwen US move: b3b4 Move number: 101
# Invalid move by Qwen black. Move: Re3
# New Move: Kc8
# Qwen CN move: Kc8 Move number: 102
# Qwen US move: d1d2 Move number: 103
# Invalid move by Qwen black. Move: Re3
# New Move: Kd8
# Qwen CN move: Kd8 Move number: 104
# Qwen US move: a5a6 Move number: 105
# Qwen CN move: Kc7 Move number: 106
# Qwen US move: h2h3 Move number: 107
# Qwen CN move: c7b8 Move number: 108
# Qwen US move: a6a7 Move number: 109
# Qwen CN move: b8c7 Move number: 110
# Qwen US move: Re2 Move number: 111
# Qwen CN move: c7b7 Move number: 112
# Qwen US move: Re3 Move number: 113
# Invalid move by Qwen black. Move: Re1
# New Move: Kc7
# Qwen CN move: Kc7 Move number: 114
# Qwen US move: a7a8r Move number: 115
# Qwen CN move: c7b7 Move number: 116
# Qwen US move: R1a5 Move number: 117
# Qwen CN move: b7c7 Move number: 118
# Qwen US move: e3e7 Move number: 119
# Game 60 result: 1-0
#
#
# Starting game 61...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: e7e5 Move number: 2
# Qwen US move: Nf3 Move number: 3
# Qwen CN move: g8f6 Move number: 4
# Qwen US move: Nxe5 Move number: 5
# Invalid move by Qwen black. Move: Nf3
# New Move: a6
# Qwen CN move: a6 Move number: 6
# Qwen US move: f1c4 Move number: 7
# Qwen CN move: d7d5 Move number: 8
# Invalid move by Qwen white. Move: Nxe5
# New Move: Bxa6
# Qwen US move: Bxa6 Move number: 9
# Qwen CN move: a8a6 Move number: 10
# Invalid move by Qwen white. Move: Nxe5
# New Move: Nd3
# Qwen US move: Nd3 Move number: 11
# Qwen CN move: d5e4 Move number: 12
# Qwen US move: Ne5 Move number: 13
# Qwen CN move: f8c5 Move number: 14
# Qwen US move: d2d3 Move number: 15
# Qwen CN move: d8d4 Move number: 16
# Qwen US move: c1e3 Move number: 17
# Invalid move by Qwen black. Move: Bxe4
# New Move: Qb4+
# Qwen CN move: Qb4+ Move number: 18
# Qwen US move: c2c3 Move number: 19
# Qwen CN move: b4b6 Move number: 20
# Qwen US move: Nxf7 Move number: 21
# Qwen CN move: c5e3 Move number: 22
# Qwen US move: e1g1 Move number: 23
# Qwen CN move: e8f7 Move number: 24
# Qwen US move: f2e3 Move number: 25
# Qwen CN move: Rg8 Move number: 26
# Qwen US move: d1h5 Move number: 27
# Qwen CN move: g6 Move number: 28
# Qwen US move: Qxh7+ Move number: 29
# Qwen CN move: Ke6 Move number: 30
# Qwen US move: f1f6 Move number: 31
# Qwen CN move: Kd5 Move number: 32
# Qwen US move: Qxc7 Move number: 33
# Qwen CN move: b6c7 Move number: 34
# Qwen US move: c3c4 Move number: 35
# Qwen CN move: d5e5 Move number: 36
# Qwen US move: f6a6 Move number: 37
# Qwen CN move: b8a6 Move number: 38
# Qwen US move: Nd2 Move number: 39
# Qwen CN move: Rd8 Move number: 40
# Qwen US move: d3d4 Move number: 41
# Qwen CN move: Rxd4 Move number: 42
# Qwen US move: e3d4 Move number: 43
# Qwen CN move: Kf5 Move number: 44
# Qwen US move: Nxe4 Move number: 45
# Qwen CN move: Qe7 Move number: 46
# Qwen US move: Nf6 Move number: 47
# Qwen CN move: Qe4 Move number: 48
# Qwen US move: a1f1 Move number: 49
# Qwen CN move: Qf4 Move number: 50
# Qwen US move: Nh5 Move number: 51
# Qwen CN move: f4f1 Move number: 52
# Qwen US move: g1f1 Move number: 53
# Invalid move by Qwen black. Move: Nh5
# New Move: gxh5
# Qwen CN move: gxh5 Move number: 54
# Qwen US move: f1e2 Move number: 55
# Qwen CN move: f5e4 Move number: 56
# Qwen US move: Ke1 Move number: 57
# Qwen CN move: e4d4 Move number: 58
# Qwen US move: e1f2 Move number: 59
# Qwen CN move: d4e5 Move number: 60
# Qwen US move: f2g3 Move number: 61
# Qwen CN move: Bh3 Move number: 62
# Qwen US move: g3h3 Move number: 63
# Invalid move by Qwen black. Move: Nh5
# New Move: Kd4
# Qwen CN move: Kd4 Move number: 64
# Qwen US move: h3h4 Move number: 65
# Qwen CN move: d4c4 Move number: 66
# Qwen US move: Kg5 Move number: 67
# Qwen CN move: c4d5 Move number: 68
# Qwen US move: g5h5 Move number: 69
# Qwen CN move: a6c5 Move number: 70
# Qwen US move: h5g6 Move number: 71
# Invalid move by Qwen black. Move: Kg5
# New Move: Ke5
# Qwen CN move: Ke5 Move number: 72
# Qwen US move: h2h4 Move number: 73
# Qwen CN move: Kf4 Move number: 74
# Qwen US move: h4h5 Move number: 75
# Qwen CN move: c5d7 Move number: 76
# Qwen US move: h5h6 Move number: 77
# Qwen CN move: d7f8 Move number: 78
# Qwen US move: Kg7 Move number: 79
# Qwen CN move: f8e6 Move number: 80
# Qwen US move: Kg6 Move number: 81
# Qwen CN move: Nf8+ Move number: 82
# Qwen US move: Kg7 Move number: 83
# Qwen CN move: f8e6 Move number: 84
# Qwen US move: Kg6 Move number: 85
# Qwen CN move: Nf8+ Move number: 86
# Qwen US move: g6f7 Move number: 87
# Qwen CN move: f8h7 Move number: 88
# Qwen US move: f7g7 Move number: 89
# Qwen CN move: h7g5 Move number: 90
# Qwen US move: h6h7 Move number: 91
# Qwen CN move: Nf7 Move number: 92
# Qwen US move: Kg8 Move number: 93
# Qwen CN move: f7h6 Move number: 94
# Invalid move by Qwen white. Move: Kg8
# New Move: Kg7
# Qwen US move: Kg7 Move number: 95
# Qwen CN move: h6f5 Move number: 96
# Qwen US move: g7f6 Move number: 97
# Invalid move by Qwen black. Move: Nh7
# New Move: Kg3
# Qwen CN move: Kg3 Move number: 98
# Qwen US move: f6f5 Move number: 99
# Qwen CN move: g3g2 Move number: 100
# Qwen US move: h8=N Move number: 101
# Qwen CN move: g2f3 Move number: 102
# Qwen US move: f5e5 Move number: 103
# Qwen CN move: f3e2 Move number: 104
# Qwen US move: e5d5 Move number: 105
# Qwen CN move: Kf3 Move number: 106
# Qwen US move: a2a4 Move number: 107
# Invalid move by Qwen black. Move: Kf6
# New Move: Kf4
# Qwen CN move: Kf4 Move number: 108
# Qwen US move: a4a5 Move number: 109
# Qwen CN move: Kg5 Move number: 110
# Qwen US move: h8f7 Move number: 111
# Qwen CN move: g5f6 Move number: 112
# Qwen US move: f7d6 Move number: 113
# Qwen CN move: f6e7 Move number: 114
# Invalid move by Qwen white. Move: Nd6
# New Move: Nxb7
# Qwen US move: Nxb7 Move number: 115
# Qwen CN move: e7d7 Move number: 116
# Qwen US move: Nd8 Move number: 117
# Qwen CN move: d7d8 Move number: 118
# Qwen US move: d5c6 Move number: 119
# Qwen CN move: d8c8 Move number: 120
# Qwen US move: c6b6 Move number: 121
# Qwen CN move: Kd7 Move number: 122
# Qwen US move: a5a6 Move number: 123
# Qwen CN move: Ke7 Move number: 124
# Invalid move by Qwen white. Move: a6
# New Move: Kb7
# Qwen US move: Kb7 Move number: 125
# Qwen CN move: e7d6 Move number: 126
# Invalid move by Qwen white. Move: a5
# New Move: Kb8
# Qwen US move: Kb8 Move number: 127
# Qwen CN move: d6c5 Move number: 128
# Qwen US move: Kb7 Move number: 129
# Qwen CN move: c5c4 Move number: 130
# Qwen US move: b7b6 Move number: 131
# Qwen CN move: c4b3 Move number: 132
# Qwen US move: b6c7 Move number: 133
# Invalid move by Qwen black. Move: Kb6
# New Move: Ka2
# Qwen CN move: Ka2 Move number: 134
# Qwen US move: b2b4 Move number: 135
# Qwen CN move: a2a3 Move number: 136
# Qwen US move: Kb7 Move number: 137
# Qwen CN move: a3b4 Move number: 138
# Qwen US move: b7b6 Move number: 139
# Qwen CN move: b4c4 Move number: 140
# Qwen US move: b6c6 Move number: 141
# Qwen CN move: Kd4 Move number: 142
# Qwen US move: c6d6 Move number: 143
# Qwen CN move: Kc3 Move number: 144
# Qwen US move: Kd7 Move number: 145
# Invalid move by Qwen black. Move: Kd6
# New Move: Kc4
# Qwen CN move: Kc4 Move number: 146
# Qwen US move: d7c6 Move number: 147
# Qwen CN move: Kd3 Move number: 148
# Qwen US move: c6b7 Move number: 149
# Qwen CN move: d3e2 Move number: 150
# Qwen US move: a6a7 Move number: 151
# Qwen CN move: e2f2 Move number: 152
# Qwen US move: a8=Q Move number: 153
# Qwen CN move: f2e3 Move number: 154
# Qwen US move: Qa1 Move number: 155
# Invalid move by Qwen black. Move: Qa4
# New Move: Ke2
# Qwen CN move: Ke2 Move number: 156
# Qwen US move: a1e5 Move number: 157
# Qwen CN move: e2f3 Move number: 158
# Qwen US move: Qe4+ Move number: 159
# Qwen CN move: f3e4 Move number: 160
# Game 61 result: 1/2-1/2
#
#
# Starting game 62...
# Qwen US move: e2e4 Move number: 1
# Qwen CN move: c7c5 Move number: 2
# Qwen US move: c2c3 Move number: 3
# Invalid move by Qwen black. Move: d4
# New Move: b5
# Qwen CN move: b5 Move number: 4
# Qwen US move: f1b5 Move number: 5
# Qwen CN move: e7e6 Move number: 6
# Invalid move by Qwen white. Move: Bxc7
# New Move: Bf1
# Qwen US move: Bf1 Move number: 7
# Qwen CN move: g8f6 Move number: 8
# Qwen US move: Nf3 Move number: 9
# Qwen CN move: f6e4 Move number: 10
# Qwen US move: f1e2 Move number: 11
# Qwen CN move: d7d5 Move number: 12
# Qwen US move: d2d4 Move number: 13
# Qwen CN move: Be7 Move number: 14
# Qwen US move: b1d2 Move number: 15
# Invalid move by Qwen black. Move: Be3
# New Move: Qb6
# Qwen CN move: Qb6 Move number: 16
# Qwen US move: e1g1 Move number: 17
# Qwen CN move: Nd2 Move number: 18
# Qwen US move: c1d2 Move number: 19
# Qwen CN move: c5d4 Move number: 20
# Qwen US move: f3d4 Move number: 21
# Qwen CN move: e8g8 Move number: 22
# Qwen US move: Nxe6 Move number: 23
# Qwen CN move: c8e6 Move number: 24
# Qwen US move: Bh6 Move number: 25
# Qwen CN move: Bh4 Move number: 26
# Qwen US move: Qxd5 Move number: 27
# Qwen CN move: e6d5 Move number: 28
# Qwen US move: Bd1 Move number: 29
# Qwen CN move: Qd4 Move number: 30
# Qwen US move: c3d4 Move number: 31
# Qwen CN move: g7h6 Move number: 32
# Qwen US move: d1a4 Move number: 33
# Qwen CN move: b8c6 Move number: 34
# Qwen US move: f1c1 Move number: 35
# Qwen CN move: Rfe8 Move number: 36
# Qwen US move: Bxc6 Move number: 37
# Qwen CN move: d5c6 Move number: 38
# Qwen US move: Rc5 Move number: 39
# Qwen CN move: c6e4 Move number: 40
# Qwen US move: Rc8 Move number: 41
# Invalid move by Qwen black. Move: Rxc8
# New Move: Bd3
# Qwen CN move: Bd3 Move number: 42
# Qwen US move: c8a8 Move number: 43
# Qwen CN move: e8a8 Move number: 44
# Qwen US move: Re1 Move number: 45
# Qwen CN move: a8d8 Move number: 46
# Qwen US move: e1c1 Move number: 47
# Qwen CN move: h4f6 Move number: 48
# Qwen US move: h2h3 Move number: 49
# Qwen CN move: Rd6 Move number: 50
# Qwen US move: d4d5 Move number: 51
# Invalid move by Qwen black. Move: Rc1
# New Move: Bg5
# Qwen CN move: Bg5 Move number: 52
# Qwen US move: c1c5 Move number: 53
# Invalid move by Qwen black. Move: Rc7
# New Move: Re6
# Qwen CN move: Re6 Move number: 54
# Qwen US move: c5c8 Move number: 55
# Invalid move by Qwen black. Move: Rc1
# New Move: Bd8
# Qwen CN move: Bd8 Move number: 56
# Qwen US move: d5e6 Move number: 57
# Qwen CN move: g8g7 Move number: 58
# Qwen US move: Rxd8 Move number: 59
# Qwen CN move: d3b5 Move number: 60
# Qwen US move: e6e7 Move number: 61
# Qwen CN move: f7f5 Move number: 62
# Qwen US move: e7e8q Move number: 63
# Qwen CN move: Bxc4 Move number: 64
# Qwen US move: e8f8 Move number: 65
# Qwen CN move: Kg6 Move number: 66
# Qwen US move: Qg7+ Move number: 67
# Qwen CN move: Kxg7 Move number: 68
# Qwen US move: d8d7 Move number: 69
# Qwen CN move: Kf8 Move number: 70
# Qwen US move: Rd8+ Move number: 71
# Qwen CN move: f8e7 Move number: 72
# Qwen US move: d8a8 Move number: 73
# Qwen CN move: a7a6 Move number: 74
# Qwen US move: a8h8 Move number: 75
# Qwen CN move: e7f7 Move number: 76
# Qwen US move: Rg8 Move number: 77
# Invalid move by Qwen black. Move: Rg8xf7+
# New Move: Bxa2
# Qwen CN move: Bxa2 Move number: 78
# Qwen US move: g8c8 Move number: 79
# Qwen CN move: a2d5 Move number: 80
# Qwen US move: Rg8 Move number: 81
# Qwen CN move: f7g8 Move number: 82
# Qwen US move: f2f4 Move number: 83
# Qwen CN move: g8f7 Move number: 84
# Qwen US move: g1f2 Move number: 85
# Qwen CN move: Kf6 Move number: 86
# Qwen US move: b2b4 Move number: 87
# Qwen CN move: Bc4 Move number: 88
# Qwen US move: Kg3 Move number: 89
# Qwen CN move: Kg6 Move number: 90
# Qwen US move: g3f2 Move number: 91
# Qwen CN move: Kg7 Move number: 92
# Qwen US move: g3 Move number: 93
# Qwen CN move: g7f6 Move number: 94
# Qwen US move: g3g4 Move number: 95
# Qwen CN move: c4e6 Move number: 96
# Qwen US move: f2g3 Move number: 97
# Qwen CN move: e6d7 Move number: 98
# Qwen US move: gxf5 Move number: 99
# Qwen CN move: Be6 Move number: 100
# Qwen US move: f5e6 Move number: 101
# Invalid move by Qwen black. Move: Rg8
# New Move: h5
# Qwen CN move: h5 Move number: 102
# Qwen US move: f4f5 Move number: 103
# Qwen CN move: f6e7 Move number: 104
# Qwen US move: f6+ Move number: 105
# Qwen CN move: e7f6 Move number: 106
# Qwen US move: g3h4 Move number: 107
# Qwen CN move: f6e6 Move number: 108
# Qwen US move: h4h5 Move number: 109
# Invalid move by Qwen black. Move: Kg4
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 110
# Qwen US move: h5h6 Move number: 111
# Qwen CN move: Kf7 Move number: 112
# Qwen US move: h6h7 Move number: 113
# Qwen CN move: f7e6 Move number: 114
# Qwen US move: h7g6 Move number: 115
# Qwen CN move: e6d5 Move number: 116
# Qwen US move: Kh7 Move number: 117
# Qwen CN move: d5c4 Move number: 118
# Qwen US move: Kg7 Move number: 119
# Qwen CN move: Kd5 Move number: 120
# Qwen US move: Kf6 Move number: 121
# Qwen CN move: d5c4 Move number: 122
# Qwen US move: Kg7 Move number: 123
# Invalid move by Qwen black. Move: Kf6
# New Move: Kb5
# Qwen CN move: Kb5 Move number: 124
# Qwen US move: h3h4 Move number: 125
# Qwen CN move: Kc6 Move number: 126
# Qwen US move: g7f6 Move number: 127
# Qwen CN move: c6b5 Move number: 128
# Qwen US move: f6e5 Move number: 129
# Qwen CN move: b5b4 Move number: 130
# Qwen US move: Kf6 Move number: 131
# Qwen CN move: a6a5 Move number: 132
# Qwen US move: Kg7 Move number: 133
# Invalid move by Qwen black. Move: Kf6
# New Move: Kb5
# Qwen CN move: Kb5 Move number: 134
# Qwen US move: h4h5 Move number: 135
# Invalid move by Qwen black. Move: Kg7
# New Move: Kb6
# Qwen CN move: Kb6 Move number: 136
# Qwen US move: h5h6 Move number: 137
# Invalid move by Qwen black. Move: Kf6
# New Move: Kb7
# Qwen CN move: Kb7 Move number: 138
# Qwen US move: g7f6 Move number: 139
# Invalid move by Qwen black. Move: Kf7
# New Move: Kb8
# Qwen CN move: Kb8 Move number: 140
# Qwen US move: f6e6 Move number: 141
# Invalid move by Qwen black. Move: Kf6
# New Move: a4
# Qwen CN move: a4 Move number: 142
# Qwen US move: h6h7 Move number: 143
# Qwen CN move: a4a3 Move number: 144
# Qwen US move: Kf7 Move number: 145
# Qwen CN move: b8a7 Move number: 146
# Qwen US move: h7h8q Move number: 147
# Qwen CN move: a7b6 Move number: 148
# Qwen US move: h8c3 Move number: 149
# Invalid move by Qwen black. Move: Qa5+
# New Move: Kb7
# Qwen CN move: Kb7 Move number: 150
# Qwen US move: c3a3 Move number: 151
# Qwen CN move: Kc7 Move number: 152
# Qwen US move: a3b4 Move number: 153
# Qwen CN move: c7c6 Move number: 154
# Qwen US move: f7e6 Move number: 155
# Qwen CN move: c6c7 Move number: 156
# Qwen US move: Qb5 Move number: 157
# Qwen CN move: c7c8 Move number: 158
# Qwen US move: Qxb7+ Move number: 159
# Qwen CN move: Kd8 Move number: 160
# Qwen US move: Qc8+ Move number: 161
# Qwen CN move: d8c8 Move number: 162
# Game 62 result: 1/2-1/2
#
#
# Starting game 63...
# Qwen US move: e4 Move number: 1
# Qwen CN move: e5 Move number: 2
# Qwen US move: g1f3 Move number: 3
# Qwen CN move: b8c6 Move number: 4
# Qwen US move: d2d4 Move number: 5
# Qwen CN move: e5d4 Move number: 6
# Qwen US move: f3d4 Move number: 7
# Qwen CN move: Nxd4 Move number: 8
# Qwen US move: Nc3 Move number: 9
# Qwen CN move: d4c6 Move number: 10
# Qwen US move: Nxd5 Move number: 11
# Qwen CN move: g8f6 Move number: 12
# Qwen US move: Nxc7+ Move number: 13
# Invalid move by Qwen black. Move: Nxc7+
# New Move: Ke7
# Qwen CN move: Ke7 Move number: 14
# Qwen US move: c7a8 Move number: 15
# Invalid move by Qwen black. Move: Nxb6
# New Move: d6
# Qwen CN move: d6 Move number: 16
# Qwen US move: b2b4 Move number: 17
# Qwen CN move: c8d7 Move number: 18
# Qwen US move: Qd2 Move number: 19
# Qwen CN move: d8a8 Move number: 20
# Qwen US move: b4b5 Move number: 21
# Qwen CN move: c6d8 Move number: 22
# Qwen US move: c1a3 Move number: 23
# Qwen CN move: Bxc6 Move number: 24
# Qwen US move: a3d6 Move number: 25
# Invalid move by Qwen black. Move: Bxc4
# New Move: Ke6
# Qwen CN move: Ke6 Move number: 26
# Qwen US move: f1c4 Move number: 27
# Qwen CN move: e6d7 Move number: 28
# Wrong format given by Qwen.
# Qwen Output: { "san": "Bxd6+", }
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[11], line 23
#      20         break
#      22 else:
# ---> 23     qwen_us_move = get_qwen_move(board, board.fen(), 2.0)
#      25 try:
#      26     board.push_san(qwen_us_move)
#
# Cell In[9], line 38, in get_qwen_move(board, fen, temp)
#      33 except Exception as e:
#      34     print(f"Wrong format given by Qwen. \nQwen Output: {response.message.content}")
# ---> 38 return qwen_move
#
# UnboundLocalError: cannot access local variable 'qwen_move' where it is not associated with a value

# %%
board.result()

# %%
results = []

# %%
results.append({
            "Qwen US Wins": qwen_us_wins,
            "Qwen CN Wins": qwen_cn_wins,
            "Draws": draws,
        })

print(results)
# Out:
# [{'Qwen US Wins': 40, 'Qwen CN Wins': 19, 'Draws': 3}]

# %%
df = pd.DataFrame(results)
df.to_csv(f"LLM_{QWEN_US_AI}_vs_LLM_{QWEN_CN_AI}.csv", index=False)
print(f"Results saved to LLM_{QWEN_US_AI}_vs_LLM_{QWEN_CN_AI}.csv")
