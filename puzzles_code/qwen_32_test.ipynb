# %%
import chess
from stockfish import Stockfish
from ollama import chat
from ollama import ChatResponse
import json
import pandas as pd

# %%
stockfish = Stockfish()

# %%
csv_file = "/Users/nafis-mac/GitHub Repos/Chess-Research-Project/puzzles_code/filtered_fen.csv"

# Read the first 100 rows of the CSV file
df = pd.read_csv(csv_file, nrows=100)

# Convert the DataFrame rows to a list of lists
fen_notations = df["FEN"].tolist()

print(len(fen_notations))
# Out:
# 100

# %%
print(fen_notations[0])
# Out:
# rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2

# %%
# # URL to scrape the text from.
# url = "https://wtharvey.com/inst.html"

# # Download the text from the website.
# response = requests.get(url)
# if response.status_code == 200:
#     text = response.text
# else:
#     print(f"Failed to retrieve content. Status code: {response.status_code}")
#     text = ""

# # Regular expression pattern for matching FEN strings.
# fen_pattern = re.compile(
#     r'([prnbqkPRNBQK\d/]+\s+[wb]\s+(?:K?Q?k?q?|-)\s+(?:[a-h][36]|-)\s+\d+\s+\d+)'
# )

# # Find all FEN notations in the text.
# fen_notations = fen_pattern.findall(text)

# # Print the extracted FEN notations.
# print("Extracted FEN Notations:")
# # for fen in fen_notations:
# #     print(fen)

# print(fen_notations[:3])

# %%
# fen_notations_ten = fen_notations[:10]

# len(fen_notations_ten)

# print(fen_notations_ten[0])

# %%
def valid_move_to_string(board):
    legal_moves = [
        board.san(move)
        for move in board.legal_moves
]
    
    moves = str(legal_moves[0])  # Start with the first move

    for move in legal_moves[1:]:  # Skip the first move and iterate over the rest
        moves = moves + " " + move
    return moves

# %%
def get_qwen_move(board:chess.Board, fen:str, temp=0.0):
    valid_moves = valid_move_to_string(board)
    
    response: ChatResponse = chat(model='qwen:32b', messages=[
        {
            'role': 'user',
            'content': f"""You are playing chess and it is your turn. This is the current state of the game. Use this to work out where the pieces are on the board:

FEN: {fen}

The possible set of legal moves are: 

Legal Moves: {valid_moves}

You have to choose one from the provided list. Do not choose a move that is not in the list.

Output the best move in SAN format to follow this position. Use the following single blob of JSON. Do not include any other information.
{{
    "san": "The move in SAN format",
    "reason": "Why this is a good move"
}}"""}], options={"temperature": temp})
    
    try:
        parsed_json = json.loads(response.message.content)
        qwen_move = parsed_json["san"]
    except Exception as e:
        print(f"Wrong format given by Qwen. \nQwen Output: {response.message.content}")

    

    return qwen_move

# %%
results = []

# %%
puzzle_id = 1


for fen in fen_notations:
    for i in range (50):
        print(f"Processing puzzle_id: {puzzle_id} Iteration: {i+1}\nPosition: {fen}")

        board_stockfish = chess.Board(fen=fen)
        board_qwen = chess.Board(fen=fen)

        assert board_qwen == board_stockfish, "Two boards are not equal"

        stockfish.set_fen_position(fen_position=fen)

        best_move = stockfish.get_best_move()

        board_stockfish.push(chess.Move.from_uci(best_move))
        stockfish.set_fen_position(fen_position=board_stockfish.fen())
        best_eval = stockfish.get_evaluation()  # evaluation in centipawns (or mate score)
        
        # print(f"Stockfish best move: {best_move} with evaluation: {best_eval}")
        if best_eval["type"] == "mate":
            break

        qwen_move = get_qwen_move(board_qwen, fen, 0.6)

        try:
            board_qwen.push_san(qwen_move)
        except Exception as e:
            print(f"Exception captured: {type(e)}")
            continue

        stockfish.set_fen_position(fen_position=board_qwen.fen())
        provided_eval = stockfish.get_evaluation()

        if provided_eval["type"] == "mate":
            # print("ITERATION SKIPPED")
            continue

        score_difference = (best_eval["value"]) - (provided_eval["value"])

        print(f"Stockfish best move: {best_move} with evaluation: {best_eval["value"]}")
        print(f"Qwen move: {qwen_move} with evaluation: {provided_eval["value"]}\n")

        results.append({
            "Iteration": i+1,
            "Puzzle ID": puzzle_id,
            "Method": "Qwen:32B",
            "Best Move Score": best_eval["value"],
            "Qwen Move Score": provided_eval["value"],
            # "Score Difference": score_difference
        })
    
    puzzle_id += 1
# Out:
# Processing puzzle_id: 1 Iteration: 1
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 2
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 3
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 4
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nh3 with evaluation: 41
#
# Processing puzzle_id: 1 Iteration: 5
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 6
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 7
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nh3 with evaluation: 41
#
# Processing puzzle_id: 1 Iteration: 8
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 9
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 10
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nh3 with evaluation: 41
#
# Processing puzzle_id: 1 Iteration: 11
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 12
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 13
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nh3 with evaluation: 41
#
# Processing puzzle_id: 1 Iteration: 14
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 15
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 16
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nh3 with evaluation: 41
#
# Processing puzzle_id: 1 Iteration: 17
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 18
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 19
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nh3 with evaluation: 41
#
# Processing puzzle_id: 1 Iteration: 20
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 21
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 22
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 23
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 24
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 25
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 26
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 27
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nh3 with evaluation: 41
#
# Processing puzzle_id: 1 Iteration: 28
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 29
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 30
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 31
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 32
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nh3 with evaluation: 41
#
# Processing puzzle_id: 1 Iteration: 33
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 34
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 35
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 36
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 37
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 38
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nh3 with evaluation: 41
#
# Processing puzzle_id: 1 Iteration: 39
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nh3 with evaluation: 41
#
# Processing puzzle_id: 1 Iteration: 40
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 41
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 42
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 43
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 44
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nh3 with evaluation: 41
#
# Processing puzzle_id: 1 Iteration: 45
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 46
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 47
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 48
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nh3 with evaluation: 41
#
# Processing puzzle_id: 1 Iteration: 49
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 1 Iteration: 50
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: f1b5 with evaluation: 195
# Qwen move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 2 Iteration: 1
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 2
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 3
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 4
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 5
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 6
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 7
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 8
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 9
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 10
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 11
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 12
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 13
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 14
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 15
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 16
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 17
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 18
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 19
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 20
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 21
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 22
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 23
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 24
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 25
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 26
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 27
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 28
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 29
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 30
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 31
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 32
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 33
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 34
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 35
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 36
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 37
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 38
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 39
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 40
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 41
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 42
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 43
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 44
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 45
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nf3 with evaluation: -8
#
# Processing puzzle_id: 2 Iteration: 46
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 47
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 48
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 49
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 2 Iteration: 50
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: e4f5 with evaluation: 156
# Qwen move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 3 Iteration: 1
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 2
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 3
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 4
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 5
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 6
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 7
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 8
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 9
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 10
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 11
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 12
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 13
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 14
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 15
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 16
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 17
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 18
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 19
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 20
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 21
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 22
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 23
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 24
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 25
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 26
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 27
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 28
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 29
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 30
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 31
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 32
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 33
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 34
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 35
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 36
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 37
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 38
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 39
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 40
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 41
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 42
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nh3 with evaluation: -79
#
# Processing puzzle_id: 3 Iteration: 43
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 44
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 45
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 46
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 47
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 48
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 49
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 3 Iteration: 50
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 75
# Qwen move: Nf3 with evaluation: 50
#
# Processing puzzle_id: 4 Iteration: 1
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 2
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 3
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 4
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 5
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 6
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 7
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 8
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 9
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 10
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 11
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 12
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 13
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 14
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 15
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 16
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 17
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 18
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 19
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 20
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 21
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 22
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 23
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 24
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 25
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nh3 with evaluation: 7
#
# Processing puzzle_id: 4 Iteration: 26
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nh3 with evaluation: 7
#
# Processing puzzle_id: 4 Iteration: 27
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 28
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 29
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 30
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 31
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 32
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 33
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 34
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 35
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 36
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 37
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 38
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 39
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 40
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 41
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 42
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 43
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 44
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 45
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 46
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 47
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 48
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 49
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 4 Iteration: 50
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 96
# Qwen move: Nf3 with evaluation: 70
#
# Processing puzzle_id: 5 Iteration: 1
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 2
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 3
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 4
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 5
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 6
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 7
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 8
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 9
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 10
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nh3 with evaluation: 108
#
# Processing puzzle_id: 5 Iteration: 11
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 12
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 13
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 14
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 15
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 16
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 17
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 18
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nh3 with evaluation: 108
#
# Processing puzzle_id: 5 Iteration: 19
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 20
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 21
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 22
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 23
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 24
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 25
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 26
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 27
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 28
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 29
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 30
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 31
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 32
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 33
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 34
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 35
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 36
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 37
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 38
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 39
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 40
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nh3 with evaluation: 108
#
# Processing puzzle_id: 5 Iteration: 41
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 42
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 43
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 44
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 45
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 46
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 47
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 48
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 49
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 5 Iteration: 50
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d2d4 with evaluation: 160
# Qwen move: Nf3 with evaluation: 144
#
# Processing puzzle_id: 6 Iteration: 1
# Position: rnbqkbnr/ppppppp1/7p/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# ...
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 19
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 20
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 21
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 22
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 23
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nh3 with evaluation: 67
#
# Processing puzzle_id: 99 Iteration: 24
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nh3 with evaluation: 67
#
# Processing puzzle_id: 99 Iteration: 25
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nh3 with evaluation: 67
#
# Processing puzzle_id: 99 Iteration: 26
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nh3 with evaluation: 67
#
# Processing puzzle_id: 99 Iteration: 27
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 28
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 29
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nh3 with evaluation: 67
#
# Processing puzzle_id: 99 Iteration: 30
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Be3 with evaluation: 83
#
# Processing puzzle_id: 99 Iteration: 31
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 32
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 33
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 34
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 35
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 36
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nh3 with evaluation: 67
#
# Processing puzzle_id: 99 Iteration: 37
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 38
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 39
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 40
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nh3 with evaluation: 67
#
# Processing puzzle_id: 99 Iteration: 41
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nh3 with evaluation: 67
#
# Processing puzzle_id: 99 Iteration: 42
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 43
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 44
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 45
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 46
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 99 Iteration: 47
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Be3 with evaluation: 83
#
# Processing puzzle_id: 99 Iteration: 48
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nh3 with evaluation: 67
#
# Processing puzzle_id: 99 Iteration: 49
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nh3 with evaluation: 67
#
# Processing puzzle_id: 99 Iteration: 50
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a2a4 with evaluation: 262
# Qwen move: Nf3 with evaluation: 107
#
# Processing puzzle_id: 100 Iteration: 1
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 2
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 3
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 4
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 5
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 6
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 7
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 8
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 9
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 10
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 11
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 12
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 13
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 14
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 15
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 16
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 17
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 18
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 19
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 20
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 21
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 22
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 23
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 24
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 25
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 26
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 27
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 28
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 29
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 30
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 31
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 32
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 33
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 34
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 35
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 36
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 37
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 38
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 39
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 40
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Be3 with evaluation: 54
#
# Processing puzzle_id: 100 Iteration: 41
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 42
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 43
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 44
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 45
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 46
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Be3 with evaluation: 54
#
# Processing puzzle_id: 100 Iteration: 47
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 48
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nf3 with evaluation: 88
#
# Processing puzzle_id: 100 Iteration: 49
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 100 Iteration: 50
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: f1d3 with evaluation: 96
# Qwen move: Nh3 with evaluation: 31

# %%
stockfish.set_fen_position(fen_notations[0])

moves = stockfish.get_top_moves(3)

print(moves)
# Out:
# [{'Move': 'f1b5', 'Centipawn': 183, 'Mate': None}, {'Move': 'd2d4', 'Centipawn': 122, 'Mate': None}, {'Move': 'g1f3', 'Centipawn': 86, 'Mate': None}]

# %%
puzzle_id = 1

for fen in fen_notations_ten:
    for i in range (100):
        if not stockfish.is_fen_valid(fen): exit
        
        print(f"Processing puzzle_id: {puzzle_id} Iteration: {i}\nPosition: {fen}")

        board_stockfish = chess.Board(fen=fen)
        board_qwen = chess.Board(fen=fen)

        stockfish.set_fen_position(fen_position=fen)

        best_move = stockfish.get_best_move()

        board_stockfish.push(chess.Move.from_uci(best_move))
        # best_eval_info = stockfish.get_evaluation()
        best_eval = stockfish.get_evaluation()["value"]  # evaluation in centipawns (or mate score)
        print(f"Stockfish best move: {best_move} with evaluation: {best_eval}")




        qwen_move = get_qwen_move(board_qwen, fen)

        board_qwen.parse_san(qwen_move)

        # chess.Move.from_uci(board_qwen.parse_san(qwen_move))

        # print(f"QWEN MOVE: {qwen_move}\nQWEN MOVE TYPE: {type(qwen_move)}")

        # try:
        #     print(board_qwen.legal_moves)
        #     chess.Move.from_uci(board_qwen.parse_san(qwen_move))
        # except Exception as e:
        #     print(f"Invalid move geenrated by Qwen. The move is: {qwen_move}")
        #     print(f"Exception type: {type(e)}")
        #     continue

        stockfish.set_fen_position(fen_position=board_qwen.fen())
        provided_eval = stockfish.get_evaluation()["value"]

        score_difference = best_eval - provided_eval

        results.append({
            "Iteration": i,
            "Puzzle ID": puzzle_id,
            "Method": "Qwen 32B",
            "Best Move Score": best_eval,
            "Move made by Qwen:32B Score": provided_eval,
            "Score Difference": score_difference
        })
    
    puzzle_id += 1

# %%
df = pd.DataFrame(results)
df.to_csv("evaluation_results_qwen32b.csv", index=False)
print("Results saved to evaluation_results.csv")
# Out:
# Results saved to evaluation_results.csv

# %%
f"""You are playing chess and it is your turn.

    This is the current state of the game. Use this to work out where the pieces are on the board:

    FEN: {fen}

    The possible set of legal moves are: Bxe7 Bh6 Bf6 Bh4 Bf4 Be3 Bd2 Bc1 Nxf7 Nd7 Ng6 Nc6 Ng4 Nf3 Nxe7 Nc7+ Nf6+ Nb6 Nf4 Nb4 Ne3 Nc3 Ba6 Bb5+ Bb3 Rg1 Rf1 Kd2 Kf1 Kxd1 Rxd1 Rc1 Rb1 O-O h3 g3 f3 c3 b3 a3 h4 g4 f4 b4 a4. You have to choose one from this list. Do not choose a move that is not in this list.
    
    Output the best move in SAN format to follow this position. Use the following single blob of JSON. Do not include any other information.

    {{
    "san": "The move in SAN format",
    "reason": "Why this is a good move"
    }}
    """

# %%
fen = fen_notations[99]

board_test = chess.Board(fen)

board_test.legal_moves
# Out:
# <LegalMoveGenerator at 0x1230a9fa0 (Nh3, Nf3, Ne2, Bd3, Be2, Ke2, Kd2, Qh5, Qg4, Qa4, Qf3, Qd3, Qb3, Qe2, Qd2, Qc2, Bh6, Bg5, Bf4, Be3, Bd2, Nc3, Na3, Nd2, dxe7, d7+, d5, c5, h3, g3, f3, b3, a3, h4, g4, f4, b4, a4)>
