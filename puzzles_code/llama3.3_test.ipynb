# %%
import chess
from stockfish import Stockfish
import re
import requests
from ollama import chat
from ollama import ChatResponse
import json
import pandas as pd

# %%
stockfish = Stockfish()

# %%
csv_file = "/Users/nafis-mac/GitHub Repos/Chess-Research-Project/puzzles_code/filtered_fen.csv"

# Read the first 100 rows of the CSV file
df = pd.read_csv(csv_file, nrows=100)

# Convert the DataFrame rows to a list of lists
fen_notations = df["FEN"].tolist()

print(len(fen_notations))
# Out:
# 100

# %%
def valid_move_to_string(board):
    legal_moves = [
        board.san(move)
        for move in board.legal_moves
]
    
    moves = str(legal_moves[0])  # Start with the first move

    for move in legal_moves[1:]:  # Skip the first move and iterate over the rest
        moves = moves + " " + move
    return moves

# %%
def get_phi_move(board:chess.Board, fen:str, temp=0.0):
    valid_moves = valid_move_to_string(board)
    
    response: ChatResponse = chat(model='llama3.3', messages=[
        {
            'role': 'user',
            'content': f"""You are playing chess and it is your turn. This is the current state of the game. Use this to work out where the pieces are on the board:

FEN: {fen}

The possible set of legal moves are: 

Legal Moves: {valid_moves}

You have to choose one from the provided list. Do not choose a move that is not in the list.

Output the best move in SAN format to follow this position. Use the following single blob of JSON. Do not include any other information.
{{
    "san": "The move in SAN format",
    "reason": "Why this is a good move"
}}"""}], options={"temperature": temp})
    
    try:
        parsed_json = json.loads(response.message.content)
        qwen_move = parsed_json["san"]
    except Exception as e:
        print(f"Wrong format given by Qwen. \nQwen Output: {response.message.content}")

    

    return qwen_move

# %%
results = []

# %%
puzzle_id = 1

for fen in fen_notations:
    print(f"Processing puzzle_id: {puzzle_id}\nPosition: {fen}")

    board_stockfish = chess.Board(fen=fen)
    board_phi = chess.Board(fen=fen)

    stockfish.set_fen_position(fen_position=fen)

    best_move = stockfish.get_best_move()
    best_move_san = board_stockfish.san(chess.Move.from_uci(best_move))

    board_stockfish.push(chess.Move.from_uci(best_move))
    stockfish.set_fen_position(fen_position=board_stockfish.fen())
    best_eval = stockfish.get_evaluation()  # evaluation in centipawns (or mate score)
        
    # print(f"Stockfish best move: {best_move} with evaluation: {best_eval}")
    if best_eval["type"] == "mate":
        break

    phi_move = get_phi_move(board_phi, fen, 0.6)

    try:
        board_phi.push_san(phi_move)
    except Exception as e:
        print(f"Exception captured: {type(e)}")
        continue

    stockfish.set_fen_position(fen_position=board_phi.fen())
    provided_eval = stockfish.get_evaluation()

    if provided_eval["type"] == "mate":
        # print("ITERATION SKIPPED")
        continue

    print(f"Stockfish best move: {best_move_san} with evaluation: {best_eval["value"]}")
    print(f"Llama move: {phi_move} with evaluation: {provided_eval["value"]}\n")

    results.append({
            # "Iteration": i+1,
            "Puzzle ID": puzzle_id,
            "Method": "Llama3.3",
            "Best Move": best_move_san,
            "Best Move Score": best_eval["value"],
            "Llama Move": {phi_move},
            "Llama Move Score": provided_eval["value"],
            # "Score Difference": score_difference
    })
    puzzle_id += 1
# Out:
# Processing puzzle_id: 1
# Position: rnbqkbnr/p1pppppp/8/1p6/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: Bxb5 with evaluation: 195
# Llama move: Nf3 with evaluation: 77
#
# Processing puzzle_id: 2
# Position: rnbqkbnr/ppppp1pp/8/5p2/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: exf5 with evaluation: 156
# Llama move: Nh3 with evaluation: 43
#
# Processing puzzle_id: 3
# Position: rnbqkbnr/1ppppppp/p7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d4 with evaluation: 75
# Llama move: Nh3 with evaluation: -79
#
# Processing puzzle_id: 4
# Position: rnbqkbnr/p1pppppp/1p6/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d4 with evaluation: 96
# Llama move: Nh3 with evaluation: 7
#
# Processing puzzle_id: 5
# Position: rnbqkbnr/ppppp1pp/5p2/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d4 with evaluation: 160
# Llama move: Nh3 with evaluation: 108
#
# Processing puzzle_id: 6
# Position: rnbqkbnr/ppppppp1/7p/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d4 with evaluation: 73
# Llama move: Nh3 with evaluation: -58
#
# Processing puzzle_id: 7
# Position: rnbqkbnr/pppppp1p/8/6p1/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d4 with evaluation: 205
# Llama move: Nh3 with evaluation: 68
#
# Processing puzzle_id: 8
# Position: rnbqkbnr/ppppppp1/8/7p/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: d4 with evaluation: 135
# Llama move: Nh3 with evaluation: -24
#
# Processing puzzle_id: 9
# Position: rnbqkb1r/pppppppp/7n/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 1 2
# Stockfish best move: d4 with evaluation: 126
# Llama move: Nh3 with evaluation: -20
#
# Processing puzzle_id: 10
# Position: rnbqkbnr/1ppppppp/8/p7/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# Stockfish best move: Nf3 with evaluation: 86
# Llama move: Nh3 with evaluation: -59
#
# Processing puzzle_id: 11
# Position: r1bqkbnr/pppppppp/n7/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 1 2
# Stockfish best move: Nc3 with evaluation: 115
# Llama move: Nh3 with evaluation: 1
#
# Processing puzzle_id: 12
# Position: r1bqkb1r/pppppppp/n4n2/4P3/8/8/PPPP1PPP/RNBQKBNR w KQkq - 1 3
# Stockfish best move: exf6 with evaluation: 499
# Llama move: Nf3 with evaluation: 134
#
# Processing puzzle_id: 13
# Position: rnbqkbr1/pppppppp/5n2/4P3/8/8/PPPP1PPP/RNBQKBNR w KQq - 1 3
# Stockfish best move: exf6 with evaluation: 385
# Llama move: Nf3 with evaluation: 227
#
# Processing puzzle_id: 14
# Position: rnbqkb1r/ppppppp1/5n1p/4P3/8/8/PPPP1PPP/RNBQKBNR w KQkq - 0 3
# Stockfish best move: exf6 with evaluation: 466
# Llama move: Nf3 with evaluation: 140
#
# Processing puzzle_id: 15
# Position: r1bqkb1r/pppppppp/2n2n2/4P3/8/8/PPPP1PPP/RNBQKBNR w KQkq - 1 3
# Stockfish best move: exf6 with evaluation: 354
# Llama move: Nf3 with evaluation: 125
#
# Processing puzzle_id: 16
# Position: rnbqkb1r/pppppppp/8/4P3/6n1/8/PPPP1PPP/RNBQKBNR w KQkq - 1 3
# Stockfish best move: Qxg4 with evaluation: 415
# Llama move: Nf3 with evaluation: 56
#
# Processing puzzle_id: 17
# Position: rnbqkb1r/pppppp1p/5np1/4P3/8/8/PPPP1PPP/RNBQKBNR w KQkq - 0 3
# Stockfish best move: exf6 with evaluation: 455
# Llama move: Nf3 with evaluation: 122
#
# Processing puzzle_id: 18
# Position: rnbqkb1r/pppppppp/8/4P2n/8/8/PPPP1PPP/RNBQKBNR w KQkq - 1 3
# Stockfish best move: Qxh5 with evaluation: 478
# Llama move: Nf3 with evaluation: 111
#
# Processing puzzle_id: 19
# Position: rnbqkb1r/pp1ppppp/2p2n2/4P3/8/8/PPPP1PPP/RNBQKBNR w KQkq - 0 3
# Stockfish best move: exf6 with evaluation: 435
# Llama move: Nf3 with evaluation: 82
#
# Processing puzzle_id: 20
# Position: rnbqkb1r/ppppppp1/5n2/4P2p/8/8/PPPP1PPP/RNBQKBNR w KQkq - 0 3
# Stockfish best move: exf6 with evaluation: 419
# Llama move: Nf3 with evaluation: 147
#
# Processing puzzle_id: 21
# Position: rnbqkb1r/pppp1ppp/4pn2/4P3/8/8/PPPP1PPP/RNBQKBNR w KQkq - 0 3
# Stockfish best move: exf6 with evaluation: 427
# Llama move: Nf3 with evaluation: 111
#
# Processing puzzle_id: 22
# Position: rnbqkb1r/1ppppppp/5n2/p3P3/8/8/PPPP1PPP/RNBQKBNR w KQkq - 0 3
# Stockfish best move: exf6 with evaluation: 449
# Llama move: Nh3 with evaluation: 94
#
# Processing puzzle_id: 23
# Position: rnbqkb1r/1ppppppp/p4n2/4P3/8/8/PPPP1PPP/RNBQKBNR w KQkq - 0 3
# Stockfish best move: exf6 with evaluation: 429
# Llama move: Nf3 with evaluation: 133
#
# Processing puzzle_id: 24
# Position: rnbqkb1r/ppp1pppp/5n2/3pP3/8/8/PPPP1PPP/RNBQKBNR w KQkq d6 0 3
# Stockfish best move: exf6 with evaluation: 371
# Llama move: Nf3 with evaluation: 89
#
# Processing puzzle_id: 25
# Position: rnbqkb1r/pp1ppppp/5n2/2p1P3/8/8/PPPP1PPP/RNBQKBNR w KQkq - 0 3
# Stockfish best move: exf6 with evaluation: 397
# Llama move: Nh3 with evaluation: -11
#
# Processing puzzle_id: 26
# Position: rnbqkb1r/p1pppppp/1p3n2/4P3/8/8/PPPP1PPP/RNBQKBNR w KQkq - 0 3
# Stockfish best move: exf6 with evaluation: 448
# Llama move: Nf3 with evaluation: 159
#
# Processing puzzle_id: 27
# Position: rnbqkb1r/p1pppppp/5n2/1p2P3/8/8/PPPP1PPP/RNBQKBNR w KQkq - 0 3
# Stockfish best move: exf6 with evaluation: 481
# Llama move: Nf3 with evaluation: 211
#
# Processing puzzle_id: 28
# Position: rnbqkb1r/pppppppp/8/4P3/4n3/8/PPPP1PPP/RNBQKBNR w KQkq - 1 3
# Stockfish best move: d4 with evaluation: 178
# Llama move: Nf3 with evaluation: 124
#
# Processing puzzle_id: 29
# Position: rnbqkb1r/pppppp1p/5n2/4P1p1/8/8/PPPP1PPP/RNBQKBNR w KQkq - 0 3
# Stockfish best move: exf6 with evaluation: 475
# Llama move: Nf3 with evaluation: 132
#
# Processing puzzle_id: 30
# Position: r1bqkb1r/pppppppp/2n5/3nP3/3P4/8/PPP2PPP/RNBQKBNR w KQkq - 1 4
# Stockfish best move: c4 with evaluation: 162
# Llama move: Nf3 with evaluation: 113
#
# Processing puzzle_id: 31
# Position: rnbqkb1r/pppppppp/8/4P3/3P1n2/8/PPP2PPP/RNBQKBNR w KQkq - 1 4
# Stockfish best move: Bxf4 with evaluation: 624
# Llama move: Nf3 with evaluation: 237
#
# Processing puzzle_id: 32
# Position: rnbqkb1r/pppppppp/5n2/4P3/3P4/8/PPP2PPP/RNBQKBNR w KQkq - 1 4
# Stockfish best move: exf6 with evaluation: 523
# Llama move: Nf3 with evaluation: 195
#
# Processing puzzle_id: 33
# Position: r1bqkb1r/pppppppp/n7/3nP3/3P4/8/PPP2PPP/RNBQKBNR w KQkq - 1 4
# Stockfish best move: c4 with evaluation: 163
# Llama move: Nf3 with evaluation: 130
#
# Processing puzzle_id: 34
# Position: rnbqkbr1/pppppppp/8/3nP3/3P4/8/PPP2PPP/RNBQKBNR w KQq - 1 4
# Stockfish best move: c4 with evaluation: 222
# Llama move: Nf3 with evaluation: 211
#
# Processing puzzle_id: 35
# Position: rnbqkb1r/pp1ppppp/2p5/3nP3/3P4/8/PPP2PPP/RNBQKBNR w KQkq - 0 4
# Stockfish best move: c4 with evaluation: 117
# Llama move: Nh3 with evaluation: 11
#
# Processing puzzle_id: 36
# Position: rnbqkb1r/p1pppppp/1p6/3nP3/3P4/8/PPP2PPP/RNBQKBNR w KQkq - 0 4
# Stockfish best move: c4 with evaluation: 245
# Llama move: Nf3 with evaluation: 155
#
# Processing puzzle_id: 37
# Position: rnbqkb1r/ppppppp1/7p/3nP3/3P4/8/PPP2PPP/RNBQKBNR w KQkq - 0 4
# Stockfish best move: c4 with evaluation: 161
# Llama move: Nh3 with evaluation: 31
#
# Processing puzzle_id: 38
# Position: rnbqkb1r/pppppppp/8/4P3/3P4/2n5/PPP2PPP/RNBQKBNR w KQkq - 1 4
# Stockfish best move: Nxc3 with evaluation: 635
# Llama move: Nf3 with evaluation: -593
#
# Processing puzzle_id: 39
# Position: rnbqkb1r/ppppp1pp/5p2/3nP3/3P4/8/PPP2PPP/RNBQKBNR w KQkq - 0 4
# Stockfish best move: c4 with evaluation: 225
# Llama move: Nf3 with evaluation: 168
#
# Processing puzzle_id: 40
# Position: rnbqkb1r/pppppppp/8/4P3/3P4/4n3/PPP2PPP/RNBQKBNR w KQkq - 1 4
# Stockfish best move: Bxe3 with evaluation: 639
# Llama move: Nf3 with evaluation: -561
#
# Processing puzzle_id: 41
# Position: rnbqkb1r/pppppp1p/6p1/3nP3/3P4/8/PPP2PPP/RNBQKBNR w KQkq - 0 4
# Stockfish best move: c4 with evaluation: 136
# Llama move: Nf3 with evaluation: 62
#
# Processing puzzle_id: 42
# Position: rnbqkb1r/ppppppp1/8/3nP2p/3P4/8/PPP2PPP/RNBQKBNR w KQkq - 0 4
# Stockfish best move: c4 with evaluation: 170
# Llama move: Nh3 with evaluation: 116
#
# Processing puzzle_id: 43
# Position: rnbqkb1r/1ppppppp/p7/3nP3/3P4/8/PPP2PPP/RNBQKBNR w KQkq - 0 4
# Stockfish best move: c4 with evaluation: 121
# Llama move: Nf3 with evaluation: 114
#
# Processing puzzle_id: 44
# Position: rnbqkb1r/pppppppp/8/4P3/1n1P4/8/PPP2PPP/RNBQKBNR w KQkq - 1 4
# Stockfish best move: a3 with evaluation: 190
# Llama move: Nf3 with evaluation: 156
#
# Processing puzzle_id: 45
# Position: rnbqkb1r/ppppp1pp/8/3nPp2/3P4/8/PPP2PPP/RNBQKBNR w KQkq f6 0 4
# Stockfish best move: c4 with evaluation: 239
# Llama move: Nf3 with evaluation: 159
#
# Processing puzzle_id: 46
# Position: rnbqkb1r/pppppppp/1n6/4P3/3P4/8/PPP2PPP/RNBQKBNR w KQkq - 1 4
# Stockfish best move: Nc3 with evaluation: 99
# Llama move: Nf3 with evaluation: 94
#
# Processing puzzle_id: 47
# Position: rnbqkb1r/p1pppppp/8/1p1nP3/3P4/8/PPP2PPP/RNBQKBNR w KQkq - 0 4
# Stockfish best move: Bxb5 with evaluation: 208
# Llama move: Nf3 with evaluation: 159
#
# Processing puzzle_id: 48
# Position: rnbqkb1r/1ppppppp/8/p2nP3/3P4/8/PPP2PPP/RNBQKBNR w KQkq - 0 4
# Stockfish best move: c4 with evaluation: 130
# Llama move: Nh3 with evaluation: 25
#
# Processing puzzle_id: 49
# Position: rnbqkb1r/pppppp1p/8/3nP1p1/3P4/8/PPP2PPP/RNBQKBNR w KQkq - 0 4
# Stockfish best move: c4 with evaluation: 245
# Llama move: Nf3 with evaluation: 178
#
# Processing puzzle_id: 50
# Position: rnbqkb1r/pp1ppppp/8/2pnP3/3P4/8/PPP2PPP/RNBQKBNR w KQkq - 0 4
# Stockfish best move: dxc5 with evaluation: 151
# Llama move: Nf3 with evaluation: 44
#
# Processing puzzle_id: 51
# Position: rn1qkb1r/pppbpppp/3p4/3nP3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 5
# Stockfish best move: cxd5 with evaluation: 509
# Llama move: Nf3 with evaluation: 122
#
# Processing puzzle_id: 52
# Position: rn1qkb1r/ppp1pppp/3pb3/3nP3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 5
# Stockfish best move: cxd5 with evaluation: 448
# Llama move: Nf3 with evaluation: 135
#
# Processing puzzle_id: 53
# Position: rnb1kb1r/pppqpppp/3p4/3nP3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 5
# Stockfish best move: cxd5 with evaluation: 531
# Llama move: Nf3 with evaluation: 211
#
# Processing puzzle_id: 54
# Position: rn1qkb1r/ppp1pppp/3p4/3nP3/2PP2b1/8/PP3PPP/RNBQKBNR w KQkq - 1 5
# Stockfish best move: Qxg4 with evaluation: 500
# Llama move: Nh3 with evaluation: -495
#
# Processing puzzle_id: 55
# Position: rnbqkb1r/ppp1pppp/3p4/4P3/2PP1n2/8/PP3PPP/RNBQKBNR w KQkq - 1 5
# Stockfish best move: Bxf4 with evaluation: 438
# Llama move: Nf3 with evaluation: 63
#
# Processing puzzle_id: 56
# Position: rnbqkbr1/ppp1pppp/3p4/3nP3/2PP4/8/PP3PPP/RNBQKBNR w KQq - 1 5
# Stockfish best move: cxd5 with evaluation: 618
# Llama move: Nh3 with evaluation: 125
#
# Processing puzzle_id: 57
# Position: r1bqkb1r/ppp1pppp/n2p4/3nP3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 5
# Stockfish best move: cxd5 with evaluation: 523
# Llama move: Nh3 with evaluation: 61
#
# Processing puzzle_id: 58
# Position: rn1qkb1r/ppp1pppp/3p4/3nP3/2PP4/7b/PP3PPP/RNBQKBNR w KQkq - 1 5
# Stockfish best move: Nxh3 with evaluation: 684
# Llama move: Nf3 with evaluation: 513
#
# Processing puzzle_id: 59
# Position: rnbqkb1r/ppp1ppp1/3p3p/3nP3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 5
# Stockfish best move: cxd5 with evaluation: 518
# Llama move: Nf3 with evaluation: 128
#
# Processing puzzle_id: 60
# Position: rnbq1b1r/pppkpppp/3p4/3nP3/2PP4/8/PP3PPP/RNBQKBNR w KQ - 1 5
# Stockfish best move: cxd5 with evaluation: 652
# Llama move: Nf3 with evaluation: 311
#
# Processing puzzle_id: 61
# Position: rnbqkb1r/ppp1pppp/8/3np3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 5
# Stockfish best move: cxd5 with evaluation: 332
# Llama move: Nf3 with evaluation: 56
#
# Processing puzzle_id: 62
# Position: r1bqkb1r/ppp1pppp/2np4/3nP3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 5
# Stockfish best move: cxd5 with evaluation: 596
# Llama move: Nh3 with evaluation: -57
#
# Processing puzzle_id: 63
# Position: rnbqkb1r/ppp1pppp/3p4/4P3/2PP4/4n3/PP3PPP/RNBQKBNR w KQkq - 1 5
# Stockfish best move: Bxe3 with evaluation: 505
# Llama move: Nh3 with evaluation: -665
#
# Processing puzzle_id: 64
# Position: rnbqkb1r/pp2pppp/2pp4/3nP3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 5
# Stockfish best move: cxd5 with evaluation: 459
# Llama move: Nh3 with evaluation: 16
#
# Processing puzzle_id: 65
# Position: rnbqkb1r/ppp1pppp/3p4/4P3/2PP4/2n5/PP3PPP/RNBQKBNR w KQkq - 1 5
# Stockfish best move: Nxc3 with evaluation: 517
# Llama move: Nf3 with evaluation: -610
#
# Processing puzzle_id: 66
# Position: rnbqkb1r/ppp1pppp/3p1n2/4P3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 5
# Stockfish best move: exf6 with evaluation: 531
# Llama move: Nf3 with evaluation: 59
#
# Processing puzzle_id: 67
# Position: rnbqkb1r/ppp1pppp/3p4/4P3/1nPP4/8/PP3PPP/RNBQKBNR w KQkq - 1 5
# Stockfish best move: Qa4+ with evaluation: 215
# Llama move: Nf3 with evaluation: -20
#
# Processing puzzle_id: 68
# Position: rn1qkb1r/ppp1pppp/3p4/3nPb2/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 5
# Stockfish best move: cxd5 with evaluation: 477
# Llama move: Nf3 with evaluation: -16
#
# Processing puzzle_id: 69
# Position: rnbqkb1r/ppp2ppp/3pp3/3nP3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 5
# Stockfish best move: cxd5 with evaluation: 411
# Llama move: Nf3 with evaluation: 113
#
# Processing puzzle_id: 70
# Position: rnbqkb1r/1pp1pppp/p2p4/3nP3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 5
# Stockfish best move: cxd5 with evaluation: 483
# Llama move: Nf3 with evaluation: 125
#
# Processing puzzle_id: 71
# Position: rnbqkb1r/ppp1p1pp/3p1p2/3nP3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 5
# Stockfish best move: cxd5 with evaluation: 498
# Llama move: Nf3 with evaluation: 166
#
# Processing puzzle_id: 72
# Position: r1bqkb1r/pppnpppp/3p4/3nP3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 5
# Stockfish best move: cxd5 with evaluation: 539
# Llama move: Nf3 with evaluation: 170
#
# Processing puzzle_id: 73
# Position: rnbqkb1r/1pp1pppp/3p4/p2nP3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 5
# Stockfish best move: cxd5 with evaluation: 498
# Llama move: Nf3 with evaluation: 111
#
# Processing puzzle_id: 74
# Position: rnbqkb1r/pp2pppp/3p4/2pnP3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 5
# Stockfish best move: cxd5 with evaluation: 499
# Llama move: Nf3 with evaluation: 55
#
# Processing puzzle_id: 75
# Position: rnbqkb1r/ppp1pp1p/3p4/3nP1p1/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 5
# Stockfish best move: cxd5 with evaluation: 526
# Llama move: Nf3 with evaluation: 238
#
# Processing puzzle_id: 76
# Position: rnbqkb1r/ppp1ppp1/3p4/3nP2p/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 5
# Stockfish best move: cxd5 with evaluation: 557
# Llama move: Nh3 with evaluation: 121
#
# Processing puzzle_id: 77
# Position: rnbqkb1r/p1p1pppp/3p4/1p1nP3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 5
# Stockfish best move: cxd5 with evaluation: 547
# Llama move: Nh3 with evaluation: 48
#
# Processing puzzle_id: 78
# Position: rnbqkb1r/ppp1pp1p/3p2p1/3nP3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 5
# Stockfish best move: cxd5 with evaluation: 471
# Llama move: Nh3 with evaluation: -23
#
# Processing puzzle_id: 79
# Position: rnbqkb1r/ppp1p1pp/3p4/3nPp2/2PP4/8/PP3PPP/RNBQKBNR w KQkq f6 0 5
# Stockfish best move: cxd5 with evaluation: 578
# Llama move: Nh3 with evaluation: 238
#
# Processing puzzle_id: 80
# Position: rnbqkb1r/p1p1pppp/1p1p4/3nP3/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 5
# Stockfish best move: cxd5 with evaluation: 571
# Llama move: Nh3 with evaluation: 184
#
# Processing puzzle_id: 81
# Position: rn1qkb1r/pppbpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: dxc7 with evaluation: 209
# Llama move: d5 with evaluation: 33
#
# Processing puzzle_id: 82
# Position: rnb1kb1r/ppp1pppp/1n1q4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: c5 with evaluation: 143
# Llama move: Nh3 with evaluation: -42
#
# Processing puzzle_id: 83
# Position: rnbqkb1r/ppp1pppp/3P4/3n4/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: cxd5 with evaluation: 621
# Llama move: dxe7 with evaluation: 222
#
# Processing puzzle_id: 84
# Position: rn1qkb1r/ppp1pppp/1n1P4/5b2/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: c5 with evaluation: 194
# Llama move: d5 with evaluation: 32
#
# Processing puzzle_id: 85
# Position: rn1qkb1r/ppp1pppp/1n1Pb3/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: dxc7 with evaluation: 207
# Llama move: d5 with evaluation: 185
#
# Processing puzzle_id: 86
# Position: rnbqkb1r/ppp1pppp/3P4/8/n1PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: Qxa4+ with evaluation: 593
# Llama move: d5 with evaluation: 180
#
# Processing puzzle_id: 87
# Position: rnb1kb1r/pppqpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: dxc7 with evaluation: 254
# Llama move: d5 with evaluation: 92
#
# Processing puzzle_id: 88
# Position: rn1qkb1r/ppp1pppp/1n1P4/8/2PP4/7b/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: Nxh3 with evaluation: 656
# Llama move: dxe7 with evaluation: 190
#
# Processing puzzle_id: 89
# Position: r1bqkb1r/ppp1pppp/1nnP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: d5 with evaluation: 208
# Llama move: d5 with evaluation: 208
#
# Processing puzzle_id: 90
# Position: rn1qkb1r/ppp1pppp/1n1P4/8/2PP2b1/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: Qxg4 with evaluation: 594
# Llama move: d5 with evaluation: -591
#
# Processing puzzle_id: 91
# Position: rnbqkb1r/ppp1pppp/3P4/8/2nP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: Bxc4 with evaluation: 546
# Llama move: d5 with evaluation: -77
#
# Processing puzzle_id: 92
# Position: rnbq1b1r/pppkpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQ - 1 6
# Stockfish best move: dxc7 with evaluation: 346
# Llama move: d5 with evaluation: 173
#
# Processing puzzle_id: 93
# Position: rnbqkb1r/pppnpppp/3P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: dxc7 with evaluation: 253
# Llama move: d5 with evaluation: 50
#
# Processing puzzle_id: 94
# Position: rnbqkb1r/ppp1pp1p/1n1P2p1/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: c5 with evaluation: 197
# Llama move: d5 with evaluation: 3
#
# Processing puzzle_id: 95
# Position: rnbqkbr1/ppp1pppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQq - 1 6
# Stockfish best move: dxc7 with evaluation: 312
# Llama move: d5 with evaluation: 149
#
# Processing puzzle_id: 96
# Position: r1bqkb1r/ppp1pppp/nn1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: dxc7 with evaluation: 246
# Llama move: d5 with evaluation: 2
#
# Processing puzzle_id: 97
# Position: rnbqkb1r/ppp1p1pp/1n1P1p2/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: c5 with evaluation: 275
# Llama move: d5 with evaluation: 120
#
# Processing puzzle_id: 98
# Position: rnbqkb1r/ppp1ppp1/1n1P3p/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: dxc7 with evaluation: 224
# Llama move: d5 with evaluation: 56
#
# Processing puzzle_id: 99
# Position: r1bqkb1r/pppnpppp/1n1P4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 1 6
# Stockfish best move: a4 with evaluation: 262
# Llama move: d5 with evaluation: 22
#
# Processing puzzle_id: 100
# Position: rnbqkb1r/pp2pppp/1npP4/8/2PP4/8/PP3PPP/RNBQKBNR w KQkq - 0 6
# Stockfish best move: Bd3 with evaluation: 96
# Llama move: d5 with evaluation: 6

# %%
df = pd.DataFrame(results)
df.to_csv("evaluation_results_llama3.3_noIter.csv", index=False)
print("Results saved to evaluation_results_llama3.3_noIter.csv")
# Out:
# Results saved to evaluation_results_llama3.3_noIter.csv
